# %%
from bs4 import BeautifulSoup
with open('work_test.htm') as file:
    data = file.read()
soup = BeautifulSoup(data,'html.parser')

main = soup.find('div', attrs={'id':'Page'})
len(main)
# Out:
# 786

# %%
divpm = main.findAll('div',attrs = {'parameters':True})
len(divpm)
# Out:
# 337

# %%
total = {}
for i,div in enumerate(divpm):
    
    total[div['id']] = {'id':div['id'], 'no':i}
    
    param = {}
    for p in div['parameters'].split(';'):
        param.update(dict(zip(p.split(':')[::2], p.split(':')[1::2])))
    total[div['id']].update(param)
    
    style = {}
    for s in div['style'].split('; '):
        style.update(dict(zip(s.split(':')[::2], s.split(': ')[1::2])))
    total[div['id']].update(style)
    
    properties = {}
    for t in div['hdxproperties'].split(';'):
        properties.update(dict(zip(t.split(':')[::2], t.split(':')[1::2])))
    
    total[div['id']].update(properties)
    
total

# %%
total = {}
for i,div in enumerate(divpm):
    total[div['id']] = {'id':div['id'], 'no':i, 'src':div['src']}
    for p in div['parameters'].split(';'):
        total[div['id']].update(dict(zip(p.split(':')[::2], p.split(':')[1::2])))
    for s in div['style'].split('; '):
        total[div['id']].update(dict(zip(s.split(':')[::2], s.split(': ')[1::2])))
    for t in div['hdxproperties'].split(';'):
        total[div['id']].update(dict(zip(t.split(':')[::2], t.split(':')[1::2])))
total
# Out:
# {'PseudoValve039': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '85px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve039',
#   'lineColorBlink': 'False',
#   'no': 228,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve040': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '75px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve040',
#   'lineColorBlink': 'False',
#   'no': 229,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve041': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '295px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve041',
#   'lineColorBlink': 'False',
#   'no': 230,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve042': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '280px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve042',
#   'lineColorBlink': 'False',
#   'no': 231,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve043': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '435px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve043',
#   'lineColorBlink': 'False',
#   'no': 232,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve044': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve044',
#   'lineColorBlink': 'False',
#   'no': 233,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve045': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '585px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve045',
#   'lineColorBlink': 'False',
#   'no': 234,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve046': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '570px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve046',
#   'lineColorBlink': 'False',
#   'no': 235,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve047': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '685px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve047',
#   'lineColorBlink': 'False',
#   'no': 236,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve048': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '670px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve048',
#   'lineColorBlink': 'False',
#   'no': 237,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve049': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '840px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve049',
#   'lineColorBlink': 'False',
#   'no': 238,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve050': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1235px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '825px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve050',
#   'lineColorBlink': 'False',
#   'no': 239,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'shape001': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '29px',
#   'Height': '29',
#   'LEFT': '5px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '0px',
#   'WIDTH': '103px',
#   'Width': '103',
#   'fillColorBlink': 'False',
#   'id': 'shape001',
#   'lineColorBlink': 'False',
#   'no': 2,
#   'src': '.\\MA_CH_OS1_WAXY_files\\General Script Holder_rev0.sha'},
#  'shape015': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '36px',
#   'Height': '36',
#   'LEFT': '0px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TEXT?ACTIVITY': 'CH',
#   'TEXT?AREA': '제품운영1과',
#   'TEXT?PRODUCT': 'WAXY',
#   'TEXT?TANK': '-',
#   'TOP': '0px',
#   'WIDTH': '1910px',
#   'Width': '1910',
#   'fillColorBlink': 'False',
#   'id': 'shape015',
#   'lineColorBlink': 'False',
#   'no': 7,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MA_Toolbar.sha'},
#  'shape023': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53104',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31',
#   'TOP': '115px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape023',
#   'lineColorBlink': 'False',
#   'no': 14,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape024': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53105',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-96S',
#   'TOP': '220px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape024',
#   'lineColorBlink': 'False',
#   'no': 18,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape025': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53106',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-20',
#   'TOP': '325px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape025',
#   'lineColorBlink': 'False',
#   'no': 22,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape027': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-2400',
#   'TEXT-DECORATION': 'none',
#   'TOP': '70px',
#   'WIDTH': '95px',
#   'Width': '95',
#   'fillColorBlink': 'False',
#   'id': 'shape027',
#   'lineColorBlink': 'False',
#   'no': 8,
#   'src': '.\\MA_CH_OS1_WAXY_files\\NameTag.sha'},
#  'shape028': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53107',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-116',
#   'TOP': '430px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape028',
#   'lineColorBlink': 'False',
#   'no': 26,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape029': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53109',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-480',
#   'TOP': '540px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape029',
#   'lineColorBlink': 'False',
#   'no': 30,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape030': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31S',
#   'TOP': '650px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape030',
#   'lineColorBlink': 'False',
#   'no': 34,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape031': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31S',
#   'TOP': '765px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape031',
#   'lineColorBlink': 'False',
#   'no': 38,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape032': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK5397',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'Mix-W',
#   'TOP': '865px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape032',
#   'lineColorBlink': 'False',
#   'no': 42,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape033': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-2600',
#   'TEXT-DECORATION': 'none',
#   'TOP': '415px',
#   'WIDTH': '95px',
#   'Width': '95',
#   'fillColorBlink': 'False',
#   'id': 'shape033',
#   'lineColorBlink': 'False',
#   'no': 53,
#   'src': '.\\MA_CH_OS1_WAXY_files\\NameTag.sha'},
#  'shape035': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-20200',
#   'TEXT-DECORATION': 'none',
#   'TOP': '820px',
#   'WIDTH': '95px',
#   'Width': '95',
#   'fillColorBlink': 'False',
#   'id': 'shape035',
#   'lineColorBlink': 'False',
#   'no': 175,
#   'src': '.\\MA_CH_OS1_WAXY_files\\NameTag.sha'},
#  'shape050': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53104',
#   'TEXT-DECORATION': 'none',
#   'TOP': '40px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape050',
#   'lineColorBlink': 'False',
#   'no': 11,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape050_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '24',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape050_shaTank',
#   'lineColorBlink': 'False',
#   'no': 12,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape050_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '27',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape050_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 13,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape051': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53105',
#   'TEXT-DECORATION': 'none',
#   'TOP': '145px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape051',
#   'lineColorBlink': 'False',
#   'no': 15,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape051_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '68',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape051_shaTank',
#   'lineColorBlink': 'False',
#   'no': 16,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape051_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '71',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape051_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 17,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape052': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53106',
#   'TEXT-DECORATION': 'none',
#   'TOP': '250px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape052',
#   'lineColorBlink': 'False',
#   'no': 19,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape052_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '82',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape052_shaTank',
#   'lineColorBlink': 'False',
#   'no': 20,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape052_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '85',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape052_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 21,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape053': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53107',
#   'TEXT-DECORATION': 'none',
#   'TOP': '355px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape053',
#   'lineColorBlink': 'False',
#   'no': 23,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape053_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '96',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape053_shaTank',
#   'lineColorBlink': 'False',
#   'no': 24,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape053_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '99',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape053_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 25,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape054': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53109',
#   'TEXT-DECORATION': 'none',
#   'TOP': '465px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape054',
#   'lineColorBlink': 'False',
#   'no': 27,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape054_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '110',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape054_shaTank',
#   'lineColorBlink': 'False',
#   'no': 28,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape054_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '113',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape054_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 29,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape055': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TOP': '575px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape055',
#   'lineColorBlink': 'False',
#   'no': 31,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape055_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '124',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape055_shaTank',
#   'lineColorBlink': 'False',
#   'no': 32,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape055_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '127',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape055_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 33,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape056': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53111',
#   'TEXT-DECORATION': 'none',
#   'TOP': '690px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape056',
#   'lineColorBlink': 'False',
#   'no': 35,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape056_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '138',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape056_shaTank',
#   'lineColorBlink': 'False',
#   'no': 36,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape056_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '141',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape056_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 37,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape057': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK5397',
#   'TEXT-DECORATION': 'none',
#   'TOP': '790px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape057',
#   'lineColorBlink': 'False',
#   'no': 39,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape057_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '152',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape057_shaTank',
#   'lineColorBlink': 'False',
#   'no': 40,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape057_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '155',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape057_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 41,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape104': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_218',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_002',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape104',
#   'lineColorBlink': 'False',
#   'no': 43,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape108': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_220',
#   'TEXT-DECORATION': 'none',
#   'TOP': '180px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_017',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape108',
#   'lineColorBlink': 'False',
#   'no': 44,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape109': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_021',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape109',
#   'lineColorBlink': 'False',
#   'no': 45,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape110': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_232',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_026',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape110',
#   'lineColorBlink': 'False',
#   'no': 46,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape111': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_202',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_053_027',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape111',
#   'lineColorBlink': 'False',
#   'no': 47,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape112': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'Width': '80',
#   'fillColorBlink': 'False',
#   'id': 'shape112',
#   'lineColorBlink': 'False',
#   'no': 48,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape115': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_059_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'Width': '80',
#   'fillColorBlink': 'False',
#   'id': 'shape115',
#   'lineColorBlink': 'False',
#   'no': 49,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape116': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '730px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_013',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'Width': '80',
#   'fillColorBlink': 'False',
#   'id': 'shape116',
#   'lineColorBlink': 'False',
#   'no': 213,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape223': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_218',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '435px',
#   'Width': '435',
#   'fillColorBlink': 'False',
#   'id': 'shape223',
#   'lineColorBlink': 'False',
#   'no': 63,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape226': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '1655px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_7280',
#   'TEXT-DECORATION': 'none',
#   'TOP': '110px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_013_014',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape226',
#   'lineColorBlink': 'False',
#   'no': 200,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape232': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_220',
#   'TEXT-DECORATION': 'none',
#   'TOP': '180px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '210px',
#   'Width': '210',
#   'fillColorBlink': 'False',
#   'id': 'shape232',
#   'lineColorBlink': 'False',
#   'no': 64,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape240': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '255px',
#   'Width': '255',
#   'fillColorBlink': 'False',
#   'id': 'shape240',
#   'lineColorBlink': 'False',
#   'no': 65,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape250': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_232',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '145px',
#   'Width': '145',
#   'fillColorBlink': 'False',
#   'id': 'shape250',
#   'lineColorBlink': 'False',
#   'no': 67,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape254': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_202',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '275px',
#   'Width': '275',
#   'fillColorBlink': 'False',
#   'id': 'shape254',
#   'lineColorBlink': 'False',
#   'no': 68,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape255': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '590px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_104',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 'shape255',
#   'lineColorBlink': 'False',
#   'no': 69,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape262': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '275px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape262',
#   'lineColorBlink': 'False',
#   'no': 210,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape266': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape266',
#   'lineColorBlink': 'False',
#   'no': 71,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape269': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_059_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '170px',
#   'Width': '170',
#   'fillColorBlink': 'False',
#   'id': 'shape269',
#   'lineColorBlink': 'False',
#   'no': 72,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape271': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '275px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004~MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '120px',
#   'Width': '120',
#   'fillColorBlink': 'False',
#   'id': 'shape271',
#   'lineColorBlink': 'False',
#   'no': 212,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape272': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102B',
#   'TEXT-DECORATION': 'none',
#   'TOP': '280px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 'shape272',
#   'lineColorBlink': 'False',
#   'no': 50,
#   'src': '.\\MA_CH_OS1_WAXY_files\\CPUMP_R.sha'},
#  'shape273': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102A',
#   'TEXT-DECORATION': 'none',
#   'TOP': '75px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 'shape273',
#   'lineColorBlink': 'False',
#   'no': 10,
#   'src': '.\\MA_CH_OS1_WAXY_files\\CPUMP_R.sha'},
#  'shape274': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_122',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape274',
#   'lineColorBlink': 'False',
#   'no': 73,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape275': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '520px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_065',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '70px',
#   'Width': '70',
#   'fillColorBlink': 'False',
#   'id': 'shape275',
#   'lineColorBlink': 'False',
#   'no': 336,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape276': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '785px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_117',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape276',
#   'lineColorBlink': 'False',
#   'no': 76,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape277': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
# ...
#  'shape681': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '905px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_011',
#   'Rotation': '270',
#   'TEXT-DECORATION': 'none',
#   'TOP': '390px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape681',
#   'lineColorBlink': 'False',
#   'no': 308,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TFGValveMAN_H.sha'},
#  'shape682': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '20px',
#   'Height': '20',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_011',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape682',
#   'lineColorBlink': 'False',
#   'no': 309,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha'},
#  'shape683': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '425px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape683',
#   'lineColorBlink': 'False',
#   'no': 313,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha'},
#  'shape684': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '45px',
#   'Height': '45',
#   'LEFT': '835px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '455px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape684',
#   'lineColorBlink': 'False',
#   'no': 314,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha'},
#  'shape686': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '835px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '590px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_064',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape686',
#   'lineColorBlink': 'False',
#   'no': 316,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape689': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '865px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_013',
#   'Rotation': '0',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape689',
#   'lineColorBlink': 'False',
#   'no': 317,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TFGValveMAN_H.sha'},
#  'shape690': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '780px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_100',
#   'Rotation': '0',
#   'TEXT-DECORATION': 'none',
#   'TOP': '450px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape690',
#   'lineColorBlink': 'False',
#   'no': 318,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TFGValveMAN_H.sha'},
#  'shape691': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '780px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_172',
#   'Rotation': '0',
#   'TEXT-DECORATION': 'none',
#   'TOP': '495px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape691',
#   'lineColorBlink': 'False',
#   'no': 319,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TFGValveMAN_H.sha'},
#  'shape692': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '105px',
#   'Width': '105',
#   'fillColorBlink': 'False',
#   'id': 'shape692',
#   'lineColorBlink': 'False',
#   'no': 321,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape693': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape693',
#   'lineColorBlink': 'False',
#   'no': 322,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha'},
#  'shape694': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_022_065',
#   'TEXT-DECORATION': 'none',
#   'TOP': '690px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape694',
#   'lineColorBlink': 'False',
#   'no': 325,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TFGValveMAN_H.sha'},
#  'shape695': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '885px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2430',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '45px',
#   'Width': '45',
#   'fillColorBlink': 'False',
#   'id': 'shape695',
#   'lineColorBlink': 'False',
#   'no': 326,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape696': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_022_066',
#   'TEXT-DECORATION': 'none',
#   'TOP': '655px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape696',
#   'lineColorBlink': 'False',
#   'no': 327,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TFGValveMAN_H.sha'},
#  'shape697': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '885px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2430',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '40px',
#   'Width': '40',
#   'fillColorBlink': 'False',
#   'id': 'shape697',
#   'lineColorBlink': 'False',
#   'no': 328,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape698': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape698',
#   'lineColorBlink': 'False',
#   'no': 329,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha'},
#  'shape699': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '105px',
#   'Width': '105',
#   'fillColorBlink': 'False',
#   'id': 'shape699',
#   'lineColorBlink': 'False',
#   'no': 330,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape792': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN2400_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '70px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'Width': '26',
#   'fillColorBlink': 'False',
#   'id': 'shape792',
#   'lineColorBlink': 'False',
#   'no': 52,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgBoundaryPointR.sha'},
#  'shape793': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN2600_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '415px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'Width': '26',
#   'fillColorBlink': 'False',
#   'id': 'shape793',
#   'lineColorBlink': 'False',
#   'no': 54,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgBoundaryPointR.sha'},
#  'shape794': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN20200_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '820px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'Width': '26',
#   'fillColorBlink': 'False',
#   'id': 'shape794',
#   'lineColorBlink': 'False',
#   'no': 56,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgBoundaryPointR.sha'},
#  'tfgOffDisplayEndPoints': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'Height': '14',
#   'LEFT': '175px',
#   'POSITION': 'absolute',
#   'Point?Element1': '',
#   'Point?Element10': '',
#   'Point?Element11': '',
#   'Point?Element12': '',
#   'Point?Element13': '',
#   'Point?Element14': '',
#   'Point?Element15': '',
#   'Point?Element16': '',
#   'Point?Element17': '',
#   'Point?Element18': '',
#   'Point?Element19': '',
#   'Point?Element2': '',
#   'Point?Element20': '',
#   'Point?Element21': '',
#   'Point?Element22': '',
#   'Point?Element23': '',
#   'Point?Element24': '',
#   'Point?Element25': '',
#   'Point?Element26': '',
#   'Point?Element27': '',
#   'Point?Element28': '',
#   'Point?Element29': '',
#   'Point?Element3': '',
#   'Point?Element30': '',
#   'Point?Element31': '',
#   'Point?Element32': '',
#   'Point?Element33': '',
#   'Point?Element34': '',
#   'Point?Element35': '',
#   'Point?Element36': '',
#   'Point?Element37': '',
#   'Point?Element38': '',
#   'Point?Element39': '',
#   'Point?Element4': '',
#   'Point?Element40': '',
#   'Point?Element5': '',
#   'Point?Element6': '',
#   'Point?Element7': '',
#   'Point?Element8': '',
#   'Point?Element9': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '19px',
#   'WIDTH': '92px',
#   'Width': '92',
#   'fillColorBlink': 'False',
#   'id': 'tfgOffDisplayEndPoints',
#   'lineColorBlink': 'False',
#   'no': 6,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgOffDisplayEndPoints.sha'},
#  'tfgOperDataReInit': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'Height': '14',
#   'LEFT': '230px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'WIDTH': '92px',
#   'Width': '92',
#   'fillColorBlink': 'False',
#   'id': 'tfgOperDataReInit',
#   'lineColorBlink': 'False',
#   'no': 5,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgOperDataReInit.sha'},
#  'tfgPlanningData': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'Height': '14',
#   'LEFT': '138px',
#   'POSITION': 'absolute',
#   'Point?DestElement': '',
#   'Point?SrcElement': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'Value?IgnoreOnDataChange': '"True"',
#   'WIDTH': '92px',
#   'Width': '92',
#   'fillColorBlink': 'False',
#   'id': 'tfgPlanningData',
#   'lineColorBlink': 'False',
#   'no': 3,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgPlanningData.sha'},
#  'tfgSelectTimeout': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '16px',
#   'Height': '16',
#   'LEFT': '77px',
#   'POSITION': 'absolute',
#   'Point?DestElement': '',
#   'Point?SrcElement': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'Value?IgnoreOnDataChange': '"True"',
#   'WIDTH': '60px',
#   'Width': '60',
#   'fillColorBlink': 'False',
#   'id': 'tfgSelectTimeout',
#   'lineColorBlink': 'False',
#   'no': 4,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgSelectTimeout.sha'}}

# %%
total['shape553']['src']
# Out:
# '.\\MA_CH_OS1_WAXY_files\\MALineU.sha'

# %%
total['shape553']['src'][-11::]
# Out:
# 'MALineU.sha'

# %%
for i,v in total.items():
    if 'Value?ShapeID' in v and v['Value?ShapeID'] == 'Line':
        print('\n',v)
# Out:
#  {'id': 'shape385', 'no': 0, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_7280', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_013_014~MAV_OS1_013_013', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '30px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '80px', 'LEFT': '1685px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '30'}
#
#  {'id': 'shape554', 'no': 1, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108', 'Value?EndPoint2': 'MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '40px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '130px', 'LEFT': '1070px', 'fillColorBlink': 'False', 'Height': '40', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape104', 'no': 43, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_218', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_054_002', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '75px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '90px', 'LEFT': '130px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '75'}
#
#  {'id': 'shape108', 'no': 44, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_220', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_054_017', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '75px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '180px', 'LEFT': '130px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '75'}
#
#  {'id': 'shape109', 'no': 45, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_230', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_054_021', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '75px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '300px', 'LEFT': '130px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '75'}
#
#  {'id': 'shape110', 'no': 46, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_232', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_054_026', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '75px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '405px', 'LEFT': '130px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '75'}
#
#  {'id': 'shape111', 'no': 47, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_202', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_053_027', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '75px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '505px', 'LEFT': '130px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '75'}
#
#  {'id': 'shape112', 'no': 48, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_062_004', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '80px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '630px', 'LEFT': '125px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '80'}
#
#  {'id': 'shape115', 'no': 49, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_417', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_059_006', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '80px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '845px', 'LEFT': '125px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '80'}
#
#  {'id': 'shape310', 'no': 51, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_360', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_021_122', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '585px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '845px', 'LEFT': '465px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '585'}
#
#  {'id': 'shape392', 'no': 55, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_359', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_136', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '275px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '830px', 'LEFT': '1510px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '275'}
#
#  {'id': 'shape223', 'no': 63, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_218', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '435px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '90px', 'LEFT': '225px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '435'}
#
#  {'id': 'shape232', 'no': 64, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_220', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '210px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '180px', 'LEFT': '225px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '210'}
#
#  {'id': 'shape240', 'no': 65, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_230', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '255px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '300px', 'LEFT': '225px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '255'}
#
#  {'id': 'shape250', 'no': 67, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_232', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '145px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '405px', 'LEFT': '225px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '145'}
#
#  {'id': 'shape254', 'no': 68, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_202', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '275px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '505px', 'LEFT': '225px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '275'}
#
#  {'id': 'shape255', 'no': 69, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_312', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_104', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '35px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '505px', 'LEFT': '590px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '35'}
#
#  {'id': 'shape266', 'no': 71, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_062_004', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '630px', 'LEFT': '225px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape269', 'no': 72, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_417', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_059_006', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '170px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '845px', 'LEFT': '225px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '170'}
#
#  {'id': 'shape274', 'no': 73, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_417', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_021_122', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '845px', 'LEFT': '395px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape551', 'no': 75, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_417', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_021_140~MAV_OS1_021_117', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '815px', 'LEFT': '395px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape276', 'no': 76, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_417', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_021_117', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '785px', 'LEFT': '395px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape552', 'no': 78, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_417', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_021_117', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '785px', 'LEFT': '395px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape277', 'no': 79, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_417', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_021_140', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '815px', 'LEFT': '395px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape281', 'no': 83, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_271', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '90px', 'LEFT': '1150px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape282', 'no': 85, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_272', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '300px', 'LEFT': '1150px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape283', 'no': 87, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_109', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '100px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '90px', 'LEFT': '970px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '100'}
#
#  {'id': 'shape284', 'no': 88, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_007', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '60px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '90px', 'LEFT': '1070px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '60'}
#
#  {'id': 'shape289', 'no': 89, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_008', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '60px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '300px', 'LEFT': '1070px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '60'}
#
#  {'id': 'shape553', 'no': 90, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_007~MAV_OS1_018_109', 'Value?EndPoint2': 'MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110~MAV_OS1_018_108', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '40px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '90px', 'LEFT': '1070px', 'fillColorBlink': 'False', 'Height': '40', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape301', 'no': 91, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2432', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '440px', 'LEFT': '1150px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape303', 'no': 93, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '440px', 'LEFT': '1080px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape563', 'no': 94, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '45px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '395px', 'LEFT': '1080px', 'fillColorBlink': 'False', 'Height': '45', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape304', 'no': 95, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '120px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '395px', 'LEFT': '1080px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '120'}
#
#  {'id': 'shape305', 'no': 97, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2433', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '120px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '395px', 'LEFT': '1220px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '120'}
#
#  {'id': 'shape564', 'no': 98, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_2433', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '5px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '395px', 'LEFT': '1340px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '5'}
#
#  {'id': 'shape314', 'no': 99, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2433', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '120px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '425px', 'LEFT': '1220px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '120'}
#
#  {'id': 'shape315', 'no': 100, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2433', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '425px', 'LEFT': '1340px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape329', 'no': 102, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2433', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_073', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '425px', 'LEFT': '1390px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape565', 'no': 103, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_2433', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_074', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '425px', 'LEFT': '1390px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape330', 'no': 105, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2433', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_074', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '455px', 'LEFT': '1390px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape334', 'no': 106, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '90px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '440px', 'LEFT': '990px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '90'}
#
#  {'id': 'shape566', 'no': 107, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '35px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '440px', 'LEFT': '990px', 'fillColorBlink': 'False', 'Height': '35', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape371', 'no': 109, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_072', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '30px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '475px', 'LEFT': '960px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '30'}
#
#  {'id': 'shape568', 'no': 111, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '25px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '475px', 'LEFT': '990px', 'fillColorBlink': 'False', 'Height': '25', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape393', 'no': 112, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_033', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '30px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '500px', 'LEFT': '960px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '30'}
#
#  {'id': 'shape569', 'no': 114, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '25px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '500px', 'LEFT': '990px', 'fillColorBlink': 'False', 'Height': '25', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape394', 'no': 115, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_057', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '30px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '525px', 'LEFT': '960px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '30'}
#
#  {'id': 'shape570', 'no': 117, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_061', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '15px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '25px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '525px', 'LEFT': '990px', 'fillColorBlink': 'False', 'Height': '25', 'lineColorBlink': 'False', 'Width': '15'}
#
#  {'id': 'shape395', 'no': 118, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2428', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '590px', 'LEFT': '1150px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape396', 'no': 120, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_060', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '590px', 'LEFT': '1080px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape571', 'no': 121, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '45px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '545px', 'LEFT': '1080px', 'fillColorBlink': 'False', 'Height': '45', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape397', 'no': 122, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '120px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '545px', 'LEFT': '1080px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '120'}
#
#  {'id': 'shape398', 'no': 124, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2424', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '120px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '545px', 'LEFT': '1220px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '120'}
#
#  {'id': 'shape577', 'no': 125, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_2424', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '5px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '545px', 'LEFT': '1340px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '5'}
#
#  {'id': 'shape399', 'no': 126, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067~MAV_OS1_022_063~MAV_OS1_022_061', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '90px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '590px', 'LEFT': '990px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '90'}
#
#  {'id': 'shape400', 'no': 127, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2424', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '115px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '575px', 'LEFT': '1225px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '115'}
#
#  {'id': 'shape401', 'no': 128, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2424', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '575px', 'LEFT': '1340px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape404', 'no': 130, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_073', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '425px', 'LEFT': '1460px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape608', 'no': 131, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_059', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '150px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '425px', 'LEFT': '1510px', 'fillColorBlink': 'False', 'Height': '150', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape405', 'no': 132, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_059', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '575px', 'LEFT': '1460px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape406', 'no': 133, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'UN2600_WAXY', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '425px', 'LEFT': '1510px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape609', 'no': 134, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_019_004', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '425px', 'LEFT': '1560px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape407', 'no': 136, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_019_004', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '455px', 'LEFT': '1560px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape408', 'no': 137, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'UN2600_WAXY', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '100px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '425px', 'LEFT': '1560px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '100'}
#
#  {'id': 'shape610', 'no': 138, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_014_003', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '425px', 'LEFT': '1660px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape409', 'no': 140, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_014_003', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '455px', 'LEFT': '1660px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape410', 'no': 141, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'UN2600_WAXY', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '125px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '425px', 'LEFT': '1660px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '125'}
#
#  {'id': 'shape523', 'no': 142, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_246', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '140px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '405px', 'LEFT': '390px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '140'}
#
#  {'id': 'shape627', 'no': 143, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_069', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '365px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '630px', 'LEFT': '395px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '365'}
#
#  {'id': 'shape651', 'no': 144, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_064', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '90px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '500px', 'LEFT': '835px', 'fillColorBlink': 'False', 'Height': '90', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape312', 'no': 147, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_289', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '45px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '845px', 'LEFT': '1155px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '45'}
#
#  {'id': 'shape313', 'no': 149, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_289', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_043', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '45px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '845px', 'LEFT': '1110px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '45'}
#
#  {'id': 'shape316', 'no': 150, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_360', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_043', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '40px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '845px', 'LEFT': '1050px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '40'}
#
#  {'id': 'shape572', 'no': 152, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_289', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'OMAVALVE', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '45px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '800px', 'LEFT': '1155px', 'fillColorBlink': 'False', 'Height': '45', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape318', 'no': 153, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_289', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'OMAVALVE', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '45px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '800px', 'LEFT': '1155px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '45'}
#
# ...
#
#  {'id': 'shape680', 'no': 300, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_312', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_130', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '145px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '360px', 'LEFT': '590px', 'fillColorBlink': 'False', 'Height': '145', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape373', 'no': 301, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_327', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_130', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '45px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '360px', 'LEFT': '795px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '45'}
#
#  {'id': 'shape374', 'no': 303, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_312', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_130', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '185px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '360px', 'LEFT': '590px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '185'}
#
#  {'id': 'shape375', 'no': 304, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_326', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_141', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '45px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '330px', 'LEFT': '760px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '45'}
#
#  {'id': 'shape376', 'no': 306, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_323', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_134', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '45px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '270px', 'LEFT': '690px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '45'}
#
#  {'id': 'shape682', 'no': 309, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_011', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '20px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '405px', 'LEFT': '920px', 'fillColorBlink': 'False', 'Height': '20', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape377', 'no': 310, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_013', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '30px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '425px', 'LEFT': '890px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '30'}
#
#  {'id': 'shape378', 'no': 311, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_100', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '30px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '455px', 'LEFT': '805px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '30'}
#
#  {'id': 'shape379', 'no': 312, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_172', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '30px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '500px', 'LEFT': '805px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '30'}
#
#  {'id': 'shape683', 'no': 313, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011', 'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '425px', 'LEFT': '920px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape684', 'no': 314, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100', 'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '45px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '455px', 'LEFT': '835px', 'fillColorBlink': 'False', 'Height': '45', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape380', 'no': 315, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2427', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '40px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '590px', 'LEFT': '885px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '40'}
#
#  {'id': 'shape686', 'no': 316, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_064', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '30px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '590px', 'LEFT': '835px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '30'}
#
#  {'id': 'shape382', 'no': 320, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011', 'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '85px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '455px', 'LEFT': '835px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '85'}
#
#  {'id': 'shape692', 'no': 321, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_491', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_068', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '105px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '695px', 'LEFT': '760px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '105'}
#
#  {'id': 'shape693', 'no': 322, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_491', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_068', 'Value?EndPoint2': 'MAV010', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '35px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '695px', 'LEFT': '760px', 'fillColorBlink': 'False', 'Height': '35', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape383', 'no': 323, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_220', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '30px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '130px', 'LEFT': '405px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '30'}
#
#  {'id': 'shape695', 'no': 326, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2430', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '45px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '695px', 'LEFT': '885px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '45'}
#
#  {'id': 'shape697', 'no': 328, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2430', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '40px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '660px', 'LEFT': '885px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '40'}
#
#  {'id': 'shape698', 'no': 329, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_069', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '630px', 'LEFT': '760px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape699', 'no': 330, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_069', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '105px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '660px', 'LEFT': '760px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '105'}
#
#  {'id': 'shape592', 'no': 331, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha', 'Point?element': 'MAL_OS1_2424', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_162', 'Value?EndPoint2': 'MAV010', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '10px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '575px', 'LEFT': '1390px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '10'}
#
#  {'id': 'shape384', 'no': 333, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2424', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_162', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '605px', 'LEFT': '1390px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape402', 'no': 334, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_2424', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_059', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '50px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '10px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '575px', 'LEFT': '1390px', 'fillColorBlink': 'False', 'Height': '10', 'lineColorBlink': 'False', 'Width': '50'}
#
#  {'id': 'shape275', 'no': 336, 'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha', 'Point?element': 'MAL_OS1_312', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_065', 'Value?EndPoint2': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '70px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '15px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '505px', 'LEFT': '520px', 'fillColorBlink': 'False', 'Height': '15', 'lineColorBlink': 'False', 'Width': '70'}

# %%
for i,v in total.items():
    if 'Value?ShapeID' in v:
        print('{:15} {:15} {:15}'.format(i,v['Value?ShapeID'], v['Point?element']))
# Out:
# shape385        Line            MAL_OS1_7280
# shape554        Line            MAL_OS1_314
# shape414        ValveMan        MAV_OS1_054_002
# shape273        CPump           _P53102A
# shape050        TankNozzle      TK53104
# shape051        TankNozzle      TK53105
# shape052        TankNozzle      TK53106
# shape053        TankNozzle      TK53107
# shape054        TankNozzle      TK53109
# shape055        TankNozzle      TK53110
# shape056        TankNozzle      TK53111
# shape057        TankNozzle      TK5397
# shape104        Line            MAL_OS1_218
# shape108        Line            MAL_OS1_220
# shape109        Line            MAL_OS1_230
# shape110        Line            MAL_OS1_232
# shape111        Line            MAL_OS1_202
# shape112        Line            MAL_OS1_483
# shape115        Line            MAL_OS1_417
# shape272        CPump           _P53102B
# shape310        Line            MAL_OS1_360
# shape792        BP              UN2400_WAXY
# shape793        BP              UN2600_WAXY
# shape392        Line            MAL_OS1_359
# shape794        BP              UN20200_WAXY
# shape415        ValveMan        MAV_OS1_054_017
# shape416        ValveMan        MAV_OS1_054_021
# shape417        ValveMan        MAV_OS1_054_026
# shape418        ValveMan        MAV_OS1_053_027
# shape421        ValveMan        MAV_OS1_062_004
# shape423        ValveMan        MAV_OS1_059_006
# shape223        Line            MAL_OS1_218
# shape232        Line            MAL_OS1_220
# shape240        Line            MAL_OS1_230
# shape444        ValveMan        MAV_OS1_017_024
# shape250        Line            MAL_OS1_232
# shape254        Line            MAL_OS1_202
# shape255        Line            MAL_OS1_312
# shape447        ValveMan        MAV_OS1_018_104
# shape266        Line            MAL_OS1_483
# shape269        Line            MAL_OS1_417
# shape274        Line            MAL_OS1_417
# shape457        ValveMan        MAV_OS1_021_122
# shape551        Line            MAL_OS1_417
# shape276        Line            MAL_OS1_417
# shape458        ValveMan        MAV_OS1_021_117
# shape552        Line            MAL_OS1_417
# shape277        Line            MAL_OS1_417
# shape459        ValveMan        MAV_OS1_021_140
# shape278        CPump           _P53104A
# shape279        CPump           _P53104B
# shape281        Line            MAL_OS1_271
# shape462        ValveMan        MAV_OS1_018_007
# shape282        Line            MAL_OS1_272
# shape463        ValveMan        MAV_OS1_018_008
# shape283        Line            MAL_OS1_314
# shape284        Line            MAL_OS1_314
# shape289        Line            MAL_OS1_314
# shape553        Line            MAL_OS1_314
# shape301        Line            MAL_OS1_2432
# shape506        ValveMan        MAV_OS1_022_062
# shape303        Line            MAL_OS1_2431
# shape563        Line            MAL_OS1_2431
# shape304        Line            MAL_OS1_2431
# shape507        ValveMan        OMAVALVE
# shape305        Line            MAL_OS1_2433
# shape564        Line            MAL_OS1_2433
# shape314        Line            MAL_OS1_2433
# shape315        Line            MAL_OS1_2433
# shape508        ValveMan        MAV_OS1_022_073
# shape329        Line            MAL_OS1_2433
# shape565        Line            MAL_OS1_2433
# shape509        ValveMan        MAV_OS1_022_074
# shape330        Line            MAL_OS1_2433
# shape334        Line            MAL_OS1_2431
# shape566        Line            MAL_OS1_2431
# shape510        ValveMan        MAV_OS1_022_061
# shape371        Line            MAL_OS1_2431
# shape511        ValveMan        MAV_OS1_022_072
# shape568        Line            MAL_OS1_2431
# shape393        Line            MAL_OS1_2431
# shape512        ValveMan        MAV_OS1_022_033
# shape569        Line            MAL_OS1_2431
# shape394        Line            MAL_OS1_2431
# shape513        ValveMan        MAV_OS1_022_057
# shape570        Line            MAL_OS1_2431
# shape395        Line            MAL_OS1_2428
# shape514        ValveMan        MAV_OS1_022_060
# shape396        Line            MAL_OS1_2426
# shape571        Line            MAL_OS1_2426
# shape397        Line            MAL_OS1_2426
# shape515        ValveMan        OMAVALVE
# shape398        Line            MAL_OS1_2424
# shape577        Line            MAL_OS1_2424
# shape399        Line            MAL_OS1_2426
# shape400        Line            MAL_OS1_2424
# shape401        Line            MAL_OS1_2424
# shape516        ValveMan        MAV_OS1_022_059
# shape404        Line            MAL_OS1_5002
# shape608        Line            MAL_OS1_5002
# shape405        Line            MAL_OS1_5002
# shape406        Line            MAL_OS1_5002
# shape609        Line            MAL_OS1_5002
# shape518        ValveMan        MAV_OS1_019_004
# shape407        Line            MAL_OS1_5002
# shape408        Line            MAL_OS1_5002
# shape610        Line            MAL_OS1_5002
# shape519        ValveMan        MAV_OS1_014_003
# shape409        Line            MAL_OS1_5002
# shape410        Line            MAL_OS1_5002
# shape523        Line            MAL_OS1_246
# shape627        Line            MAL_OS1_483
# shape651        Line            MAL_OS1_325
# shape308        CPump           _P5399A
# shape309        CPump           _P5399B
# shape312        Line            MAL_OS1_289
# shape468        ValveMan        MAV_OS1_018_043
# shape313        Line            MAL_OS1_289
# shape316        Line            MAL_OS1_360
# shape469        ValveMan        OMAVALVE
# shape572        Line            MAL_OS1_289
# shape318        Line            MAL_OS1_289
# shape319        Line            MAL_OS1_288
# shape573        Line            MAL_OS1_288
# shape320        Line            MAL_OS1_288
# shape321        Line            MAL_OS1_288
# shape574        Line            MAL_OS1_360
# shape470        ValveMan        MAV_OS1_018_042
# shape322        Line            MAL_OS1_360
# shape323        Line            MAL_OS1_287
# shape324        Line            MAL_OS1_287
# shape471        ValveMan        OMAVALVE
# shape575        Line            MAL_OS1_287
# shape325        Line            MAL_OS1_287
# shape326        Line            MAL_OS1_286
# shape576        Line            MAL_OS1_286
# shape327        Line            MAL_OS1_286
# shape328        Line            MAL_OS1_286
# shape472        ValveMan        MAV_OS1_018_038
# shape473        ValveMan        MAV_OS1_018_136
# shape390        Line            MAL_OS1_359
# shape391        Line            MAL_OS1_359
# shape607        Line            MAL_OS1_359
# shape286        Line            MAL_OS1_270
# shape467        ValveMan        MAV_OS1_018_006
# shape287        Line            MAL_OS1_273
# shape476        ValveMan        MAV_OS1_018_009
# shape288        Line            MAL_OS1_313
# shape302        Line            MAL_OS1_313
# shape558        Line            MAL_OS1_313
# shape306        Line            MAL_OS1_313
# shape477        ValveMan        MAV_OS1_018_067
# shape527        ValveMan        MAV_OS1_018_106
# shape331        Line            MAL_OS1_313
# shape559        Line            MAL_OS1_313
# shape529        ValveMan        MAV_OS1_018_107
# shape332        Line            MAL_OS1_313
# shape578        Line            MAL_OS1_313
# shape307        Line            MAL_OS1_376
# shape317        Line            MAL_OS1_376
# shape579        Line            MAL_OS1_376
# shape333        Line            MAL_OS1_376
# shape479        ValveMan        MAV_OS1_014_004
# shape480        ValveMan        MAV_OS1_013_012
# shape335        Line            MAL_OS1_7279
# shape481        ValveMan        MAV_OS1_013_013
# shape534        Line            MAL_OS1_7280
# shape226        Line            MAL_OS1_7280
# shape433        ValveMan        MAV_OS1_013_014
# shape536        Line            MAL_OS1_7280
# shape442        ValveMan        MAV_OS1_013_015
# shape336        Line            MAL_OS1_7280
# shape337        Line            MAL_OS1_7280
# shape659        Line            MAL_OS1_483
# shape660        ValveMan        MAV_OS1_021_047
# shape661        Line            MAL_OS1_483
# shape580        Line            MAL_OS1_483
# shape262        Line            MAL_OS1_483
# shape455        ValveMan        MAV_OS1_024_031
# shape271        Line            MAL_OS1_483
# shape116        Line            MAL_OS1_491
# shape422        ValveMan        MAV_OS1_062_013
# shape341        Line            MAL_OS1_491
# shape584        Line            MAL_OS1_2426
# shape640        ValveMan        MAV_OS1_022_068
# shape641        ValveMan        MAV_OS1_022_069
# shape642        ValveMan        MAV_OS1_022_067
# shape643        Line            MAL_OS1_2426
# shape644        Line            MAL_OS1_2426
# shape645        Line            MAL_OS1_2426
# shape646        Line            MAL_OS1_2426
# shape647        Line            MAL_OS1_2426
# shape648        Line            MAL_OS1_2426
# shape649        ValveMan        MAV_OS1_022_064
# shape668        Line            MAL_OS1_2426
# PseudoValve039  ValvePseudo     _P53102AL
# PseudoValve040  ValvePseudo     _P53102AR
# PseudoValve041  ValvePseudo     _P53102BL
# PseudoValve042  ValvePseudo     _P53102BR
# PseudoValve043  ValvePseudo     _P53104AL
# PseudoValve044  ValvePseudo     _P53104AR
# PseudoValve045  ValvePseudo     _P53104BL
# PseudoValve046  ValvePseudo     _P53104BR
# PseudoValve047  ValvePseudo     _P5399AL
# PseudoValve048  ValvePseudo     _P5399AR
# PseudoValve049  ValvePseudo     _P5399BL
# PseudoValve050  ValvePseudo     _P5399BR
# shape619        Line            MAL_OS1_368
# shape650        ValveMan        MAV_OS1_022_063
# shape438        ValveMan        MAV_OS1_018_109
# shape292        Line            MAL_OS1_314
# shape439        ValveMan        MAV_OS1_018_108
# shape293        Line            MAL_OS1_314
# shape461        ValveMan        MAV_OS1_018_110
# shape587        Line            MAL_OS1_314
# shape297        Line            MAL_OS1_314
# shape464        ValveMan        MAV_OS1_018_111
# shape311        Line            MAL_OS1_323
# shape347        Line            MAL_OS1_321
# shape348        Line            MAL_OS1_326
# shape349        Line            MAL_OS1_327
# shape588        Line            MAL_OS1_314
# shape465        ValveMan        MAV_OS1_018_072
# shape617        Line            MAL_OS1_323
# shape622        Line            MAL_OS1_323
# shape637        Line            MAL_OS1_323
# shape350        Line            MAL_OS1_323
# shape475        ValveMan        MAV_OS1_018_071
# shape483        ValveMan        MAV_OS1_018_074
# shape484        ValveMan        MAV_OS1_018_075
# shape638        Line            MAL_OS1_323
# shape655        Line            MAL_OS1_321
# shape352        Line            MAL_OS1_321
# shape672        Line            MAL_OS1_321
# shape673        Line            MAL_OS1_321
# shape674        Line            MAL_OS1_326
# shape675        Line            MAL_OS1_326
# shape676        Line            MAL_OS1_327
# shape353        Line            MAL_OS1_326
# shape354        Line            MAL_OS1_327
# shape677        Line            MAL_OS1_220
# shape355        Line            MAL_OS1_220
# shape678        Line            MAL_OS1_230
# shape356        Line            MAL_OS1_230
# shape679        Line            MAL_OS1_246
# shape357        Line            MAL_OS1_246
# shape589        Line            MAL_OS1_368
# shape358        Line            MAL_OS1_327
# shape485        ValveMan        MAV_OS1_018_114
# shape359        Line            MAL_OS1_368
# shape360        Line            MAL_OS1_326
# shape486        ValveMan        MAV_OS1_018_115
# shape361        Line            MAL_OS1_368
# shape362        Line            MAL_OS1_321
# shape487        ValveMan        MAV_OS1_018_117
# shape363        Line            MAL_OS1_368
# shape364        Line            MAL_OS1_323
# shape488        ValveMan        MAV_OS1_018_116
# shape365        Line            MAL_OS1_368
# shape590        Line            MAL_OS1_368
# shape591        Line            MAL_OS1_368
# shape366        Line            MAL_OS1_326
# shape367        Line            MAL_OS1_321
# shape368        Line            MAL_OS1_321
# shape369        Line            MAL_OS1_323
# shape370        Line            MAL_OS1_323
# shape372        Line            MAL_OS1_323
# shape680        Line            MAL_OS1_312
# shape373        Line            MAL_OS1_327
# shape490        ValveMan        MAV_OS1_018_130
# shape374        Line            MAL_OS1_312
# shape375        Line            MAL_OS1_326
# shape491        ValveMan        MAV_OS1_018_141
# shape376        Line            MAL_OS1_323
# shape492        ValveMan        MAV_OS1_018_134
# shape681        ValveMan        MAV_OS1_018_011
# shape682        Line            MAL_OS1_325
# shape377        Line            MAL_OS1_325
# shape378        Line            MAL_OS1_325
# shape379        Line            MAL_OS1_325
# shape683        Line            MAL_OS1_325
# shape684        Line            MAL_OS1_325
# shape380        Line            MAL_OS1_2427
# shape686        Line            MAL_OS1_325
# shape689        ValveMan        MAV_OS1_018_013
# shape690        ValveMan        MAV_OS1_018_100
# shape691        ValveMan        MAV_OS1_018_172
# shape382        Line            MAL_OS1_325
# shape692        Line            MAL_OS1_491
# shape693        Line            MAL_OS1_491
# shape383        Line            MAL_OS1_220
# shape493        ValveMan        MAV_OS1_018_073
# shape694        ValveMan        MAV_OS1_022_065
# shape695        Line            MAL_OS1_2430
# shape696        ValveMan        MAV_OS1_022_066
# shape697        Line            MAL_OS1_2430
# shape698        Line            MAL_OS1_483
# shape699        Line            MAL_OS1_483
# shape592        Line            MAL_OS1_2424
# shape517        ValveMan        MAV_OS1_022_162
# shape384        Line            MAL_OS1_2424
# shape402        Line            MAL_OS1_2424
# shape494        ValveMan        MAV_OS1_018_065
# shape275        Line            MAL_OS1_312

# %%
# all element
result = {}
for i in total:
    temp = {}
    if 'Value?ShapeID' in total[i]:
        temp['type'] = total[i]['Value?ShapeID']
    else :
        temp['type'] = ''
        
    if 'Point?element' in total[i]:
        temp['element'] = total[i]['Point?element']
    else :
        temp['element'] = ''
        
    if 'Rotation' in total[i]:
        temp['rotation'] = total[i]['Rotation']
    else : 
        temp['rotation'] = ''
    
    temp['left'] = total[i]['LEFT'].rstrip('px')
    temp['top'] = total[i]['TOP'].rstrip('px')
    temp['height'] = total[i]['HEIGHT'].rstrip('px')
    temp['width'] = total[i]['WIDTH'].rstrip('px')
    temp['L'] = ''
    temp['T'] = ''
    temp['R'] = ''
    temp['B'] = ''
    temp['x1'] = ''
    temp['y1'] = ''
    temp['x2'] = ''
    temp['y2'] = ''
    if temp['type'] != '':
        temp['left'] = int(temp['left'])
        temp['top'] = int(temp['top'])
        temp['height'] = int(temp['height'])
        temp['width'] = int(temp['width'])
        temp['L'] = temp['left']
        temp['T'] = temp['top']
        temp['R'] = temp['left'] + temp['width']
        temp['B'] = temp['top'] + temp['height']
        temp['x1'] = temp['L']
        temp['y1'] = temp['T'] + temp['height']/2
        temp['x2'] = temp['R']
        temp['y2'] = temp['B'] - temp['height']/2
        if (temp['rotation'] == '90' or temp['rotation'] == '270'):
            temp['L'] = temp['L'] + temp['width']/2 - temp['height']/2
            temp['T'] = temp['T'] - temp['width']/2 + temp['height']/2
            temp['R'] = temp['R']  - temp['width']/2 + temp['height']/2
            temp['B'] = temp['B'] + temp['width']/2 - temp['height']/2
            temp['x1'] = temp['x1'] + temp['width']/2
            temp['y1'] = temp['y1'] - temp['width']/2
            temp['x2'] = temp['x2'] - temp['width']/2
            temp['y2'] = temp['y2'] + temp['width']/2
    result[i] = temp
for r,k in result.items():
    print(r,k)

# %%
# line, valve
result = {}
for i,each in total.items():
    temp = dict(zip(['type','element','rotation','Value?EndPoint1','Value?EndPoint2'],['','','','','']))
    if 'Value?ShapeID' in each:
        temp['type'] = each['Value?ShapeID']
    if 'Point?element' in each:
        temp['element'] = each['Point?element']
    if 'Rotation' in each:
        temp['rotation'] = each['Rotation']
    if 'Value?EndPoint1' in each:
        temp['endpoint1'] = each['Value?EndPoint1']
    if 'Value?EndPoint2' in each:
        temp['endpoint2'] = each['Value?EndPoint2']
    temp['left'] = each['LEFT'].rstrip('px')
    temp['top'] = each['TOP'].rstrip('px')
    temp['height'] = each['HEIGHT'].rstrip('px')
    temp['width'] = each['WIDTH'].rstrip('px')
    temp.update(dict(zip(['x1','y1','x2','y2'],[0,0,0,0])))
    if temp['type'] == 'Line':
        if each['src'][-11::] == 'MALineU.sha':
            temp['direction'] = 'V'
        else : 
            temp['direction'] = 'H'
        if temp['direction'] == 'H':
            temp['x1'] = int(temp['left'])
            temp['y1'] = int(temp['top'])
            temp['x2'] = int(temp['left']) + int(temp['width'])
            temp['y2'] = temp['y1']
        elif temp['direction'] == 'V':
            temp['x1'] = int(temp['left'])
            temp['y1'] = int(temp['top'])
            temp['x2'] = temp['x1'] 
            temp['y2'] = int(temp['top']) + int(temp['height'])

    elif temp['type'] == 'ValveMan':
        temp['x1'] = int(temp['left'])
        temp['y1'] = int(temp['top']) + int(temp['height'])/2
        temp['x2'] = temp['x1'] + int(temp['width'])
        temp['y2'] = temp['y1']
        if temp['rotation'] == '90' or temp['rotation'] == '270':
            temp['x1'] = temp['x1'] + int(temp['width'])/2
            temp['y1'] = temp['y1'] - int(temp['width'])/2
            temp['x2'] = temp['x2'] - int(temp['width'])/2
            temp['y2'] = temp['y2'] + int(temp['width'])/2   
    result[i] = temp
for i,each in result.items():
    if each['type'] != '':
        each['point1'] = {}
        each['point2'] = {}
        for j,target in result.items():
            if target['type'] != '' and j != i:
                value = ((target['x1'] - each['x1'])**2 + (target['y1'] - each['y1'])**2)**0.5
                if value < 10:
                    each['point1'][j] = {'distance':value, 'point':'1','element':target['element'],'type':target['type']}
                    
                value = ((target['x2'] - each['x1'])**2 + (target['y2'] - each['y1'])**2)**0.5
                if value < 10:
                    each['point1'][j] = {'distance':value, 'point':'2','element':target['element'],'type':target['type']}
                    
                value = ((target['x1'] - each['x2'])**2 + (target['y1'] - each['y2'])**2)**0.5
                if value < 10:
                    each['point2'][j] = {'distance':value, 'point':'1','element':target['element'],'type':target['type']}
                    
                value = ((target['x2'] - each['x2'])**2 + (target['y2'] - each['y2'])**2)**0.5
                if value < 10:
                    each['point2'][j] = {'distance':value, 'point':'2','element':target['element'],'type':target['type']}

for i,v in result.items():
    if v['type'] == 'Line':
        print('\n',i)
        print(v['point1'],v['point2'])
        print('endpoint1: {:50}  endpoint2: {}'.format(v['endpoint1'],v['endpoint2']))
# Out:
#  shape385
# {'shape534': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_7280', 'type': 'Line'}, 'shape336': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_7280', 'type': 'Line'}} {'shape536': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_7280', 'type': 'Line'}, 'shape337': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_7280', 'type': 'Line'}}
# endpoint1: MAV_OS1_013_014~MAV_OS1_013_013                     endpoint2:
#
#  shape554
# {'shape553': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}, 'shape292': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}} {'shape293': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}, 'shape587': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_314', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108     endpoint2: MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110
#
#  shape104
# {} {'shape414': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_054_002', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_054_002                                     endpoint2:
#
#  shape108
# {} {'shape415': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_054_017', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_054_017                                     endpoint2:
#
#  shape109
# {} {'shape416': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_054_021', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_054_021                                     endpoint2:
#
#  shape110
# {} {'shape417': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_054_026', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_054_026                                     endpoint2:
#
#  shape111
# {} {'shape418': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_053_027', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_053_027                                     endpoint2:
#
#  shape112
# {} {'shape421': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_062_004', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_062_004                                     endpoint2:
#
#  shape115
# {} {'shape423': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_059_006', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_059_006                                     endpoint2:
#
#  shape310
# {'shape457': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_021_122', 'type': 'ValveMan'}} {'shape316': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_360', 'type': 'Line'}, 'shape574': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_360', 'type': 'Line'}}
# endpoint1: MAV_OS1_021_122                                     endpoint2:
#
#  shape392
# {'shape391': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_359', 'type': 'Line'}, 'shape607': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_359', 'type': 'Line'}} {}
# endpoint1: MAV_OS1_018_136                                     endpoint2:
#
#  shape223
# {'shape414': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_054_002', 'type': 'ValveMan'}} {'shape465': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_072', 'type': 'ValveMan'}}
# endpoint1:                                                     endpoint2:
#
#  shape232
# {'shape415': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_054_017', 'type': 'ValveMan'}} {'shape677': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_220', 'type': 'Line'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape240
# {'shape416': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_054_021', 'type': 'ValveMan'}} {'shape678': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_230', 'type': 'Line'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape250
# {'shape417': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_054_026', 'type': 'ValveMan'}} {'shape444': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_017_024', 'type': 'ValveMan'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape254
# {'shape418': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_053_027', 'type': 'ValveMan'}} {'shape494': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_065', 'type': 'ValveMan'}}
# endpoint1:                                                     endpoint2:
#
#  shape255
# {'shape680': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_312', 'type': 'Line'}, 'shape275': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_312', 'type': 'Line'}} {'shape447': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_104', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_104                                     endpoint2:
#
#  shape266
# {'shape421': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_062_004', 'type': 'ValveMan'}} {'shape580': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_483', 'type': 'Line'}, 'shape271': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_483', 'type': 'Line'}}
# endpoint1: MAV_OS1_062_004                                     endpoint2:
#
#  shape269
# {'shape423': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_059_006', 'type': 'ValveMan'}} {'shape274': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_417', 'type': 'Line'}, 'shape551': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_417', 'type': 'Line'}}
# endpoint1: MAV_OS1_059_006                                     endpoint2:
#
#  shape274
# {'shape269': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_417', 'type': 'Line'}, 'shape551': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_417', 'type': 'Line'}} {'shape457': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_021_122', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_021_122                                     endpoint2:
#
#  shape551
# {'shape552': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_417', 'type': 'Line'}, 'shape277': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_417', 'type': 'Line'}} {'shape269': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_417', 'type': 'Line'}, 'shape274': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_417', 'type': 'Line'}}
# endpoint1: MAV_OS1_021_140~MAV_OS1_021_117                     endpoint2:
#
#  shape276
# {'shape552': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_417', 'type': 'Line'}} {'shape458': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_021_117', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_021_117                                     endpoint2:
#
#  shape552
# {'shape276': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_417', 'type': 'Line'}} {'shape551': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_417', 'type': 'Line'}, 'shape277': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_417', 'type': 'Line'}}
# endpoint1: MAV_OS1_021_117                                     endpoint2:
#
#  shape277
# {'shape551': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_417', 'type': 'Line'}, 'shape552': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_417', 'type': 'Line'}} {'shape459': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_021_140', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_021_140                                     endpoint2:
#
#  shape281
# {'shape462': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_007', 'type': 'ValveMan'}} {}
# endpoint1:                                                     endpoint2:
#
#  shape282
# {'shape463': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_008', 'type': 'ValveMan'}} {}
# endpoint1:                                                     endpoint2:
#
#  shape283
# {'shape438': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_109', 'type': 'ValveMan'}} {'shape284': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_314', 'type': 'Line'}, 'shape553': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_314', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_109                                     endpoint2:
#
#  shape284
# {'shape283': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}, 'shape553': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_314', 'type': 'Line'}} {'shape462': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_007', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_007                                     endpoint2:
#
#  shape289
# {'shape588': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}} {'shape463': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_008', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_008                                     endpoint2:
#
#  shape553
# {'shape283': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}, 'shape284': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_314', 'type': 'Line'}} {'shape554': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_314', 'type': 'Line'}, 'shape292': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_007~MAV_OS1_018_109                     endpoint2: MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110~MAV_OS1_018_108
#
#  shape301
# {'shape506': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_062', 'type': 'ValveMan'}} {}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape303
# {'shape563': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}, 'shape334': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}} {'shape506': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_022_062', 'type': 'ValveMan'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape563
# {'shape304': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2431', 'type': 'Line'}} {'shape303': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2431', 'type': 'Line'}, 'shape334': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}}
# endpoint1: MAV005~MAV004                                       endpoint2: MAV010
#
#  shape304
# {'shape563': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2431', 'type': 'Line'}} {'shape507': {'distance': 5.0, 'point': '1', 'element': 'OMAVALVE', 'type': 'ValveMan'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape305
# {'shape507': {'distance': 5.0, 'point': '2', 'element': 'OMAVALVE', 'type': 'ValveMan'}} {'shape564': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2433', 'type': 'Line'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape564
# {'shape305': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2433', 'type': 'Line'}} {'shape314': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2433', 'type': 'Line'}, 'shape315': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2433', 'type': 'Line'}}
# endpoint1: MAV005~MAV004                                       endpoint2: MAV010
#
#  shape314
# {} {'shape564': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2433', 'type': 'Line'}, 'shape315': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2433', 'type': 'Line'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape315
# {'shape564': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2433', 'type': 'Line'}, 'shape314': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2433', 'type': 'Line'}} {'shape329': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2433', 'type': 'Line'}, 'shape565': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2433', 'type': 'Line'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape329
# {'shape315': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2433', 'type': 'Line'}, 'shape565': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2433', 'type': 'Line'}} {'shape508': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_022_073', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_022_073                                     endpoint2:
#
#  shape565
# {'shape315': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2433', 'type': 'Line'}, 'shape329': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2433', 'type': 'Line'}} {'shape330': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2433', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_074                                     endpoint2:
#
#  shape330
# {'shape565': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2433', 'type': 'Line'}} {'shape509': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_022_074', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_022_074                                     endpoint2:
#
#  shape334
# {'shape566': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2431', 'type': 'Line'}} {'shape303': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2431', 'type': 'Line'}, 'shape563': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape566
# {'shape334': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2431', 'type': 'Line'}} {'shape371': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}, 'shape568': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2431', 'type': 'Line'}}
# endpoint1: MAV005~MAV004                                       endpoint2: MAV010
#
#  shape371
# {'shape511': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_072', 'type': 'ValveMan'}} {'shape566': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}, 'shape568': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2431', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_072                                     endpoint2:
#
#  shape568
# {'shape566': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}, 'shape371': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}} {'shape393': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}, 'shape569': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2431', 'type': 'Line'}}
# endpoint1: MAV005~MAV004                                       endpoint2: MAV010
#
#  shape393
# {'shape512': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_033', 'type': 'ValveMan'}} {'shape568': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}, 'shape569': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2431', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_033                                     endpoint2:
#
#  shape569
# {'shape568': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}, 'shape393': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}} {'shape394': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}, 'shape570': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2431', 'type': 'Line'}}
# endpoint1: MAV005~MAV004                                       endpoint2: MAV010
#
#  shape394
# {'shape513': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_057', 'type': 'ValveMan'}} {'shape569': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}, 'shape570': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2431', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_057                                     endpoint2:
#
#  shape570
# {'shape569': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}, 'shape394': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2431', 'type': 'Line'}} {'shape510': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_022_061', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_022_061                                     endpoint2:
#
#  shape395
# {'shape514': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_060', 'type': 'ValveMan'}} {}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape396
# {'shape571': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape399': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}} {'shape514': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_022_060', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_022_060                                     endpoint2:
#
#  shape571
# {'shape397': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2426', 'type': 'Line'}} {'shape396': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape399': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}}
# endpoint1: MAV005~MAV004                                       endpoint2: MAV010
#
#  shape397
# {'shape571': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2426', 'type': 'Line'}} {'shape515': {'distance': 5.0, 'point': '1', 'element': 'OMAVALVE', 'type': 'ValveMan'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape398
# {'shape515': {'distance': 5.0, 'point': '2', 'element': 'OMAVALVE', 'type': 'ValveMan'}} {'shape577': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2424', 'type': 'Line'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape577
# {'shape398': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2424', 'type': 'Line'}} {'shape400': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2424', 'type': 'Line'}, 'shape401': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2424', 'type': 'Line'}}
# endpoint1: MAV005~MAV004                                       endpoint2: MAV010
#
#  shape399
# {'shape584': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape646': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape668': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}} {'shape396': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape571': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067~MAV_OS1_022_063~MAV_OS1_022_061  endpoint2:
#
#  shape400
# {} {'shape577': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2424', 'type': 'Line'}, 'shape401': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2424', 'type': 'Line'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape401
# {'shape577': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2424', 'type': 'Line'}, 'shape400': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2424', 'type': 'Line'}} {'shape592': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2424', 'type': 'Line'}, 'shape402': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2424', 'type': 'Line'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape404
# {'shape508': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_073', 'type': 'ValveMan'}} {'shape608': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_5002', 'type': 'Line'}, 'shape406': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_5002', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_073                                     endpoint2:
#
#  shape608
# {'shape404': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_5002', 'type': 'Line'}, 'shape406': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_5002', 'type': 'Line'}} {'shape405': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_5002', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_059                                     endpoint2:
#
#  shape405
# {'shape516': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_059', 'type': 'ValveMan'}} {'shape608': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_5002', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_059                                     endpoint2:
#
#  shape406
# {'shape404': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_5002', 'type': 'Line'}, 'shape608': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_5002', 'type': 'Line'}} {'shape609': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_5002', 'type': 'Line'}, 'shape408': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_5002', 'type': 'Line'}}
# endpoint1: UN2600_WAXY                                         endpoint2:
#
#  shape609
# {'shape406': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_5002', 'type': 'Line'}, 'shape408': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_5002', 'type': 'Line'}} {'shape407': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_5002', 'type': 'Line'}}
# endpoint1: MAV_OS1_019_004                                     endpoint2:
#
#  shape407
# {'shape609': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_5002', 'type': 'Line'}} {'shape518': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_019_004', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_019_004                                     endpoint2:
#
#  shape408
# {'shape406': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_5002', 'type': 'Line'}, 'shape609': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_5002', 'type': 'Line'}} {'shape610': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_5002', 'type': 'Line'}, 'shape410': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_5002', 'type': 'Line'}}
# endpoint1: UN2600_WAXY                                         endpoint2:
#
#  shape610
# {'shape408': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_5002', 'type': 'Line'}, 'shape410': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_5002', 'type': 'Line'}} {'shape409': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_5002', 'type': 'Line'}}
# endpoint1: MAV_OS1_014_003                                     endpoint2:
#
#  shape409
# {'shape610': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_5002', 'type': 'Line'}} {'shape519': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_014_003', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_014_003                                     endpoint2:
#
#  shape410
# {'shape408': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_5002', 'type': 'Line'}, 'shape610': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_5002', 'type': 'Line'}} {}
# endpoint1: UN2600_WAXY                                         endpoint2:
#
#  shape523
# {'shape444': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_017_024', 'type': 'ValveMan'}} {'shape679': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_246', 'type': 'Line'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape627
# {'shape661': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_483', 'type': 'Line'}, 'shape271': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_483', 'type': 'Line'}} {'shape698': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_483', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_069                                     endpoint2:
#
#  shape651
# {'shape379': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_325', 'type': 'Line'}, 'shape684': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_325', 'type': 'Line'}} {'shape686': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_325', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_064                                     endpoint2:
#
#  shape312
# {'shape313': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_289', 'type': 'Line'}, 'shape572': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_289', 'type': 'Line'}} {}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape313
# {'shape468': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_043', 'type': 'ValveMan'}} {'shape312': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_289', 'type': 'Line'}, 'shape572': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_289', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_043                                     endpoint2:
#
#  shape316
# {'shape310': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_360', 'type': 'Line'}, 'shape574': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_360', 'type': 'Line'}} {'shape468': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_043', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_043                                     endpoint2:
#
#  shape572
# {'shape318': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_289', 'type': 'Line'}} {'shape312': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_289', 'type': 'Line'}, 'shape313': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_289', 'type': 'Line'}}
# endpoint1: OMAVALVE                                            endpoint2:
#
#  shape318
# {'shape572': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_289', 'type': 'Line'}} {'shape469': {'distance': 5.0, 'point': '1', 'element': 'OMAVALVE', 'type': 'ValveMan'}}
# endpoint1: OMAVALVE                                            endpoint2:
#
#  shape319
# {'shape469': {'distance': 5.0, 'point': '2', 'element': 'OMAVALVE', 'type': 'ValveMan'}} {'shape573': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_288', 'type': 'Line'}}
# endpoint1: OMAVALVE                                            endpoint2:
#
#  shape573
# {'shape319': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_288', 'type': 'Line'}} {'shape320': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_288', 'type': 'Line'}, 'shape321': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_288', 'type': 'Line'}}
# endpoint1: OMAVALVE                                            endpoint2:
#
#  shape320
# {} {'shape573': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_288', 'type': 'Line'}, 'shape321': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_288', 'type': 'Line'}}
# endpoint1: _P5399BR                                            endpoint2:
#
#  shape321
# {'shape573': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_288', 'type': 'Line'}, 'shape320': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_288', 'type': 'Line'}} {'shape473': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_136', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_136                                     endpoint2:
#
#  shape574
# {'shape322': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_360', 'type': 'Line'}} {'shape310': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_360', 'type': 'Line'}, 'shape316': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_360', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_042                                     endpoint2:
#
#  shape322
# {'shape574': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_360', 'type': 'Line'}} {'shape470': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_042', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_042                                     endpoint2:
#
#  shape323
# {'shape324': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_287', 'type': 'Line'}, 'shape575': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_287', 'type': 'Line'}} {}
# endpoint1: _P5399AL                                            endpoint2:
#
#  shape324
# {'shape470': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_042', 'type': 'ValveMan'}} {'shape323': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_287', 'type': 'Line'}, 'shape575': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_287', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_042                                     endpoint2:
#
#  shape575
# {'shape325': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_287', 'type': 'Line'}} {'shape323': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_287', 'type': 'Line'}, 'shape324': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_287', 'type': 'Line'}}
# endpoint1: OMAVALVE                                            endpoint2:
#
#  shape325
# {'shape575': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_287', 'type': 'Line'}} {'shape471': {'distance': 5.0, 'point': '1', 'element': 'OMAVALVE', 'type': 'ValveMan'}}
# endpoint1: OMAVALVE                                            endpoint2:
#
#  shape326
# {'shape471': {'distance': 5.0, 'point': '2', 'element': 'OMAVALVE', 'type': 'ValveMan'}} {'shape576': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_286', 'type': 'Line'}}
# endpoint1: OMAVALVE                                            endpoint2:
#
#  shape576
# {'shape326': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_286', 'type': 'Line'}} {'shape327': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_286', 'type': 'Line'}, 'shape328': {'distance': 5.0, 'point': '1', 'element': 'MAL_OS1_286', 'type': 'Line'}}
# endpoint1: OMAVALVE                                            endpoint2:
#
#  shape327
# {} {'shape576': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_286', 'type': 'Line'}, 'shape328': {'distance': 5.0, 'point': '1', 'element': 'MAL_OS1_286', 'type': 'Line'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape328
# {'shape576': {'distance': 5.0, 'point': '2', 'element': 'MAL_OS1_286', 'type': 'Line'}, 'shape327': {'distance': 5.0, 'point': '2', 'element': 'MAL_OS1_286', 'type': 'Line'}} {'shape472': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_038', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_038                                     endpoint2:
#
#  shape390
# {'shape472': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_038', 'type': 'ValveMan'}} {'shape607': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_359', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_038                                     endpoint2:
#
#  shape391
# {'shape473': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_136', 'type': 'ValveMan'}} {'shape392': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_359', 'type': 'Line'}, 'shape607': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_359', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_136                                     endpoint2:
#
#  shape607
# {'shape390': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_359', 'type': 'Line'}} {'shape392': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_359', 'type': 'Line'}, 'shape391': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_359', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_038                                     endpoint2:
#
#  shape286
# {} {'shape467': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_006', 'type': 'ValveMan'}}
# endpoint1:                                                     endpoint2:
#
#  shape287
# {} {'shape476': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_009', 'type': 'ValveMan'}}
# endpoint1:                                                     endpoint2:
#
#  shape288
# {'shape476': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_009', 'type': 'ValveMan'}} {'shape578': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_313', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_009                                     endpoint2:
#
#  shape302
# {'shape467': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_006', 'type': 'ValveMan'}} {'shape558': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_313', 'type': 'Line'}, 'shape306': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_313', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_006                                     endpoint2:
#
#  shape558
# {'shape302': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_313', 'type': 'Line'}, 'shape306': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_313', 'type': 'Line'}} {'shape331': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_313', 'type': 'Line'}, 'shape559': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_313', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_067~MAV_OS1_018_006                     endpoint2:
#
#  shape306
# {'shape302': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_313', 'type': 'Line'}, 'shape558': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_313', 'type': 'Line'}} {'shape477': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_067', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_067                                     endpoint2:
#
#  shape331
# {'shape558': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_313', 'type': 'Line'}, 'shape559': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_313', 'type': 'Line'}} {'shape527': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_106', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_106                                     endpoint2:
#
#  shape559
# {'shape558': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_313', 'type': 'Line'}, 'shape331': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_313', 'type': 'Line'}} {'shape332': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_313', 'type': 'Line'}, 'shape578': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_313', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_067~MAV_OS1_018_006~MAV_OS1_018_106     endpoint2: MAV_OS1_018_107~MAV_OS1_018_009
#
#  shape332
# {'shape559': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_313', 'type': 'Line'}, 'shape578': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_313', 'type': 'Line'}} {'shape529': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_107', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_107                                     endpoint2:
#
#  shape578
# {'shape559': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_313', 'type': 'Line'}, 'shape332': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_313', 'type': 'Line'}} {'shape288': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_313', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_009                                     endpoint2:
#
#  shape307
# {'shape477': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_067', 'type': 'ValveMan'}} {'shape317': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_376', 'type': 'Line'}, 'shape579': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_376', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_067                                     endpoint2:
#
#  shape317
# {'shape307': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_376', 'type': 'Line'}, 'shape579': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_376', 'type': 'Line'}} {'shape480': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_013_012', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_013_012                                     endpoint2:
#
#  shape579
# {'shape307': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_376', 'type': 'Line'}, 'shape317': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_376', 'type': 'Line'}} {'shape333': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_376', 'type': 'Line'}}
# endpoint1: MAV_OS1_014_004                                     endpoint2:
#
#  shape333
# {'shape579': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_376', 'type': 'Line'}} {}
# endpoint1: MAV_OS1_014_004                                     endpoint2:
#
#  shape335
# {'shape480': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_013_012', 'type': 'ValveMan'}} {'shape481': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_013_013', 'type': 'ValveMan'}}
# endpoint1:                                                     endpoint2:
#
#  shape534
# {'shape385': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_7280', 'type': 'Line'}, 'shape336': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_7280', 'type': 'Line'}} {'shape226': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_7280', 'type': 'Line'}}
# endpoint1: MAV_OS1_013_014                                     endpoint2:
#
#  shape226
# {'shape433': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_013_014', 'type': 'ValveMan'}} {'shape534': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_7280', 'type': 'Line'}}
# endpoint1: MAV_OS1_013_014                                     endpoint2:
#
#  shape536
# {'shape385': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_7280', 'type': 'Line'}, 'shape337': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_7280', 'type': 'Line'}} {'shape442': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_013_015', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_013_015                                     endpoint2:
#
#  shape336
# {'shape481': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_013_013', 'type': 'ValveMan'}} {'shape385': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_7280', 'type': 'Line'}, 'shape534': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_7280', 'type': 'Line'}}
# endpoint1: MAV_OS1_013_013                                     endpoint2:
#
#  shape337
# {'shape385': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_7280', 'type': 'Line'}, 'shape536': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_7280', 'type': 'Line'}} {}
# endpoint1: UN2400_WAXY                                         endpoint2:
#
#  shape659
# {'shape661': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_483', 'type': 'Line'}} {'shape660': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_021_047', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_021_047                                     endpoint2:
#
#  shape661
# {'shape627': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_483', 'type': 'Line'}, 'shape271': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_483', 'type': 'Line'}} {'shape659': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_483', 'type': 'Line'}}
# endpoint1: MAV_OS1_021_047                                     endpoint2:
#
#  shape580
# {'shape266': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_483', 'type': 'Line'}, 'shape271': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_483', 'type': 'Line'}} {'shape262': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_483', 'type': 'Line'}}
# endpoint1: MAV_OS1_024_031                                     endpoint2:
#
#  shape262
# {'shape580': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_483', 'type': 'Line'}} {'shape455': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_024_031', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_024_031                                     endpoint2:
#
#  shape271
# {'shape266': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_483', 'type': 'Line'}, 'shape580': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_483', 'type': 'Line'}} {'shape627': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_483', 'type': 'Line'}, 'shape661': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_483', 'type': 'Line'}}
# endpoint1: MAV_OS1_062_004~MAV_OS1_024_031                     endpoint2:
#
#  shape116
# {} {'shape422': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_062_013', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_062_013                                     endpoint2:
#
#  shape341
# {'shape422': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_062_013', 'type': 'ValveMan'}} {'shape693': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_491', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_068                                     endpoint2:
#
#  shape584
# {'shape510': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_061', 'type': 'ValveMan'}} {'shape399': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape646': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape668': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_061                                     endpoint2:
#
#  shape643
# {'shape694': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_065', 'type': 'ValveMan'}} {'shape648': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_065                                     endpoint2:
#
#  shape644
# {'shape696': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_066', 'type': 'ValveMan'}} {'shape647': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape648': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2426', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_066                                     endpoint2:
#
#  shape645
# {'shape642': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_067', 'type': 'ValveMan'}} {'shape646': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape647': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2426', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_067                                     endpoint2:
#
#  shape646
# {'shape399': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape584': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape668': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}} {'shape645': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape647': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2426', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067     endpoint2:
#
#  shape647
# {'shape645': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape646': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}} {'shape644': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape648': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2426', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_065~MAV_OS1_022_066                     endpoint2:
#
#  shape648
# {'shape644': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape647': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}} {'shape643': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_065                                     endpoint2:
#
#  shape668
# {'shape650': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_063', 'type': 'ValveMan'}} {'shape399': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape584': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2426', 'type': 'Line'}, 'shape646': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2426', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_063                                     endpoint2:
#
#  shape619
# {'shape589': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_368', 'type': 'Line'}, 'shape359': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_368', 'type': 'Line'}} {'shape681': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_011', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_011                                     endpoint2:
#
#  shape292
# {'shape439': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_108', 'type': 'ValveMan'}} {'shape554': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_314', 'type': 'Line'}, 'shape553': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_108                                     endpoint2:
#
#  shape293
# {'shape461': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_110', 'type': 'ValveMan'}} {'shape554': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}, 'shape587': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_314', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_110                                     endpoint2:
#
#  shape587
# {'shape554': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}, 'shape293': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}} {'shape297': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}, 'shape588': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_314', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108~MAV_OS1_018_110  endpoint2: MAV_OS1_018_111~MAV_OS1_018_008
#
#  shape297
# {'shape464': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_111', 'type': 'ValveMan'}} {'shape587': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}, 'shape588': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_314', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_111                                     endpoint2:
#
#  shape311
# {'shape617': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_323', 'type': 'Line'}, 'shape350': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_323', 'type': 'Line'}} {'shape438': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_109', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_109                                     endpoint2:
#
#  shape347
# {'shape655': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_321', 'type': 'Line'}, 'shape352': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_321', 'type': 'Line'}} {'shape439': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_108', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_108                                     endpoint2:
#
#  shape348
# {'shape674': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_326', 'type': 'Line'}, 'shape353': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_326', 'type': 'Line'}} {'shape461': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_110', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_110                                     endpoint2:
#
#  shape349
# {'shape484': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_075', 'type': 'ValveMan'}} {'shape676': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_327', 'type': 'Line'}, 'shape354': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_327', 'type': 'Line'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape588
# {'shape587': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}, 'shape297': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_314', 'type': 'Line'}} {'shape289': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_314', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_008                                     endpoint2:
#
#  shape617
# {'shape311': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_323', 'type': 'Line'}, 'shape350': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_323', 'type': 'Line'}} {}
# endpoint1: MAV_OS1_018_134~MAV_OS1_018_116                     endpoint2: MAV_OS1_018_072~MAV_OS1_018_109
#
#  shape622
# {} {}
# endpoint1: MAV_OS1_018_134~MAV_OS1_018_116                     endpoint2: MAV_OS1_018_072~MAV_OS1_018_109
#
#  shape637
# {} {}
# endpoint1: MAV_OS1_018_134~MAV_OS1_018_116                     endpoint2: MAV_OS1_018_072~MAV_OS1_018_109
#
#  shape350
# {'shape465': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_072', 'type': 'ValveMan'}} {'shape311': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_323', 'type': 'Line'}, 'shape617': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_323', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_072                                     endpoint2:
#
#  shape638
# {} {'shape372': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_323', 'type': 'Line'}, 'shape376': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_323', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_134~MAV_OS1_018_116                     endpoint2: MAV_OS1_018_072~MAV_OS1_018_109
#
#  shape655
# {'shape347': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_321', 'type': 'Line'}, 'shape352': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_321', 'type': 'Line'}} {}
# endpoint1: MAV_OS1_018_117                                     endpoint2: MAV010
#
#  shape352
# {'shape475': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_071', 'type': 'ValveMan'}} {'shape347': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_321', 'type': 'Line'}, 'shape655': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_321', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_071                                     endpoint2:
#
#  shape672
# {} {}
# endpoint1: MAV_OS1_018_117                                     endpoint2: MAV010
#
#  shape673
# {} {'shape368': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_321', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_117                                     endpoint2: MAV010
#
#  shape674
# {'shape348': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_326', 'type': 'Line'}, 'shape353': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_326', 'type': 'Line'}} {}
# endpoint1: MAV_OS1_018_141~MAV_OS1_018_115                     endpoint2:
#
#  shape675
# {} {'shape366': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_326', 'type': 'Line'}, 'shape375': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_326', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_141~MAV_OS1_018_115                     endpoint2:
#
#  shape676
# {'shape349': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_327', 'type': 'Line'}, 'shape354': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_327', 'type': 'Line'}} {'shape358': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_327', 'type': 'Line'}, 'shape373': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_327', 'type': 'Line'}}
# endpoint1: MAV005~MAV004                                       endpoint2: MAV010
#
#  shape353
# {'shape483': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_074', 'type': 'ValveMan'}} {'shape348': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_326', 'type': 'Line'}, 'shape674': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_326', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_074                                     endpoint2:
#
#  shape354
# {'shape349': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_327', 'type': 'Line'}, 'shape676': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_327', 'type': 'Line'}} {'shape464': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_111', 'type': 'ValveMan'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape677
# {'shape355': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_220', 'type': 'Line'}, 'shape383': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_220', 'type': 'Line'}} {'shape232': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_220', 'type': 'Line'}}
# endpoint1: MAV005~MAV004                                       endpoint2: MAV010
#
#  shape355
# {'shape677': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_220', 'type': 'Line'}, 'shape383': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_220', 'type': 'Line'}} {'shape475': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_071', 'type': 'ValveMan'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape678
# {'shape356': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_230', 'type': 'Line'}} {'shape240': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_230', 'type': 'Line'}}
# endpoint1: MAV005~MAV004                                       endpoint2: MAV010
#
#  shape356
# {'shape678': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_230', 'type': 'Line'}} {'shape483': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_074', 'type': 'ValveMan'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape679
# {'shape357': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_246', 'type': 'Line'}} {'shape523': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_246', 'type': 'Line'}}
# endpoint1: MAV005~MAV004                                       endpoint2: MAV010
#
#  shape357
# {'shape679': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_246', 'type': 'Line'}} {'shape484': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_075', 'type': 'ValveMan'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape589
# {'shape361': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_368', 'type': 'Line'}, 'shape590': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_368', 'type': 'Line'}} {'shape619': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_368', 'type': 'Line'}, 'shape359': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_368', 'type': 'Line'}}
# endpoint1: MAV005~MAV004                                       endpoint2: MAV010
#
#  shape358
# {'shape676': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_327', 'type': 'Line'}, 'shape373': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_327', 'type': 'Line'}} {'shape485': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_114', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_114                                     endpoint2:
#
#  shape359
# {'shape485': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_114', 'type': 'ValveMan'}} {'shape619': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_368', 'type': 'Line'}, 'shape589': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_368', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_114                                     endpoint2:
#
#  shape360
# {} {'shape486': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_115', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_115                                     endpoint2:
#
#  shape361
# {'shape486': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_115', 'type': 'ValveMan'}} {'shape589': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_368', 'type': 'Line'}, 'shape590': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_368', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_115                                     endpoint2:
#
#  shape362
# {} {'shape487': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_117', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_117                                     endpoint2:
#
#  shape363
# {'shape487': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_117', 'type': 'ValveMan'}} {'shape590': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_368', 'type': 'Line'}, 'shape591': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_368', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_117                                     endpoint2:
#
#  shape364
# {} {'shape488': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_116', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_116                                     endpoint2:
#
#  shape365
# {'shape488': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_116', 'type': 'ValveMan'}} {'shape591': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_368', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_116                                     endpoint2:
#
#  shape590
# {'shape363': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_368', 'type': 'Line'}, 'shape591': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_368', 'type': 'Line'}} {'shape589': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_368', 'type': 'Line'}, 'shape361': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_368', 'type': 'Line'}}
# endpoint1: MAV005~MAV004                                       endpoint2: MAV010
#
#  shape591
# {'shape365': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_368', 'type': 'Line'}} {'shape363': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_368', 'type': 'Line'}, 'shape590': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_368', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_116                                     endpoint2: MAV010
#
#  shape366
# {'shape675': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_326', 'type': 'Line'}, 'shape375': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_326', 'type': 'Line'}} {}
# endpoint1: MAV_OS1_018_115                                     endpoint2:
#
#  shape367
# {} {}
# endpoint1: MAV_OS1_018_117                                     endpoint2:
#
#  shape368
# {'shape673': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_321', 'type': 'Line'}} {}
# endpoint1: MAV_OS1_018_117                                     endpoint2:
#
#  shape369
# {} {}
# endpoint1: MAV_OS1_018_116                                     endpoint2:
#
#  shape370
# {} {}
# endpoint1: MAV_OS1_018_116                                     endpoint2:
#
#  shape372
# {'shape638': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_323', 'type': 'Line'}, 'shape376': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_323', 'type': 'Line'}} {}
# endpoint1: MAV_OS1_018_116                                     endpoint2:
#
#  shape680
# {'shape374': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_312', 'type': 'Line'}} {'shape255': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_312', 'type': 'Line'}, 'shape275': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_312', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_130                                     endpoint2:
#
#  shape373
# {'shape490': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_130', 'type': 'ValveMan'}} {'shape676': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_327', 'type': 'Line'}, 'shape358': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_327', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_130                                     endpoint2:
#
#  shape374
# {'shape680': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_312', 'type': 'Line'}} {'shape490': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_018_130', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_018_130                                     endpoint2:
#
#  shape375
# {'shape491': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_141', 'type': 'ValveMan'}} {'shape675': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_326', 'type': 'Line'}, 'shape366': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_326', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_141                                     endpoint2:
#
#  shape376
# {'shape492': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_134', 'type': 'ValveMan'}} {'shape638': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_323', 'type': 'Line'}, 'shape372': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_323', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_134                                     endpoint2:
#
#  shape682
# {'shape681': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_011', 'type': 'ValveMan'}} {'shape377': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_325', 'type': 'Line'}, 'shape683': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_325', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_011                                     endpoint2:
#
#  shape377
# {'shape689': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_013', 'type': 'ValveMan'}} {'shape682': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_325', 'type': 'Line'}, 'shape683': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_325', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_013                                     endpoint2:
#
#  shape378
# {'shape690': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_100', 'type': 'ValveMan'}} {'shape684': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_325', 'type': 'Line'}, 'shape382': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_325', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_100                                     endpoint2:
#
#  shape379
# {'shape691': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_172', 'type': 'ValveMan'}} {'shape651': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_325', 'type': 'Line'}, 'shape684': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_325', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_172                                     endpoint2:
#
#  shape683
# {'shape682': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_325', 'type': 'Line'}, 'shape377': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_325', 'type': 'Line'}} {'shape382': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_325', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_013~MAV_OS1_018_011                     endpoint2: MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100
#
#  shape684
# {'shape378': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_325', 'type': 'Line'}, 'shape382': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_325', 'type': 'Line'}} {'shape651': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_325', 'type': 'Line'}, 'shape379': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_325', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100     endpoint2: MAV_OS1_022_064~MAV_OS1_018_172
#
#  shape380
# {'shape649': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_064', 'type': 'ValveMan'}} {'shape650': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_022_063', 'type': 'ValveMan'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape686
# {'shape651': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_325', 'type': 'Line'}} {'shape649': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_022_064', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_022_064                                     endpoint2:
#
#  shape382
# {'shape378': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_325', 'type': 'Line'}, 'shape684': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_325', 'type': 'Line'}} {'shape683': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_325', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_013~MAV_OS1_018_011                     endpoint2: MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100
#
#  shape692
# {'shape693': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_491', 'type': 'Line'}} {'shape640': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_022_068', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_022_068                                     endpoint2:
#
#  shape693
# {'shape692': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_491', 'type': 'Line'}} {'shape341': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_491', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_068                                     endpoint2: MAV010
#
#  shape383
# {'shape493': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_073', 'type': 'ValveMan'}} {'shape677': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_220', 'type': 'Line'}, 'shape355': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_220', 'type': 'Line'}}
# endpoint1: PSP5383L                                            endpoint2:
#
#  shape695
# {'shape640': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_068', 'type': 'ValveMan'}} {}
# endpoint1:                                                     endpoint2:
#
#  shape697
# {'shape641': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_022_069', 'type': 'ValveMan'}} {'shape696': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_022_066', 'type': 'ValveMan'}}
# endpoint1:                                                     endpoint2:
#
#  shape698
# {'shape627': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_483', 'type': 'Line'}} {'shape699': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_483', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_069                                     endpoint2:
#
#  shape699
# {'shape698': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_483', 'type': 'Line'}} {'shape641': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_022_069', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_022_069                                     endpoint2:
#
#  shape592
# {'shape401': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2424', 'type': 'Line'}, 'shape402': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2424', 'type': 'Line'}} {'shape384': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2424', 'type': 'Line'}}
# endpoint1: MAV_OS1_022_162                                     endpoint2: MAV010
#
#  shape384
# {'shape592': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2424', 'type': 'Line'}} {'shape517': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_022_162', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_022_162                                     endpoint2:
#
#  shape402
# {'shape401': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_2424', 'type': 'Line'}, 'shape592': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_2424', 'type': 'Line'}} {'shape516': {'distance': 5.0, 'point': '1', 'element': 'MAV_OS1_022_059', 'type': 'ValveMan'}}
# endpoint1: MAV_OS1_022_059                                     endpoint2:
#
#  shape275
# {'shape494': {'distance': 5.0, 'point': '2', 'element': 'MAV_OS1_018_065', 'type': 'ValveMan'}} {'shape255': {'distance': 0.0, 'point': '1', 'element': 'MAL_OS1_312', 'type': 'Line'}, 'shape680': {'distance': 0.0, 'point': '2', 'element': 'MAL_OS1_312', 'type': 'Line'}}
# endpoint1: MAV_OS1_018_065                                     endpoint2:

# %%
for i,each in result.items():
    if each['type'] != '':
        each['point1'] = {}
        for j,target in result.items():
            if target['type'] != '' and j != i:
                value = ((target['x1'] - each['x1'])**2 + (target['y1'] - each['y1'])**2)**0.5
                if value < 10:
                    each['point1'][j] = {'distance':value, 'point':'1'}
                value = ((target['x2'] - each['x1'])**2 + (target['y2'] - each['y1'])**2)**0.5
                if value < 10:
                    each['point1'][j] = {'distance':value, 'point':'2'}

# %%
for i,each in result.items():
    if each['type'] == 'Line':
        print(i,each)
# Out:
# shape385 {'type': 'Line', 'element': 'MAL_OS1_7280', 'rotation': '', 'left': '1685', 'top': '80', 'height': '10', 'width': '30', 'x1': 1685, 'y1': 80, 'x2': 1715, 'y2': 80, 'direction': 'H', 'point1': {'shape534': {'distance': 0.0, 'point': '1'}, 'shape336': {'distance': 0.0, 'point': '2'}}}
# shape554 {'type': 'Line', 'element': 'MAL_OS1_314', 'rotation': '', 'left': '1070', 'top': '130', 'height': '40', 'width': '10', 'x1': 1070, 'y1': 130, 'x2': 1070, 'y2': 170, 'direction': 'V', 'point1': {'shape553': {'distance': 0.0, 'point': '2'}, 'shape292': {'distance': 0.0, 'point': '2'}}}
# shape104 {'type': 'Line', 'element': 'MAL_OS1_218', 'rotation': '', 'left': '130', 'top': '90', 'height': '10', 'width': '75', 'x1': 130, 'y1': 90, 'x2': 205, 'y2': 90, 'direction': 'H', 'point1': {}}
# shape108 {'type': 'Line', 'element': 'MAL_OS1_220', 'rotation': '', 'left': '130', 'top': '180', 'height': '10', 'width': '75', 'x1': 130, 'y1': 180, 'x2': 205, 'y2': 180, 'direction': 'H', 'point1': {}}
# shape109 {'type': 'Line', 'element': 'MAL_OS1_230', 'rotation': '', 'left': '130', 'top': '300', 'height': '10', 'width': '75', 'x1': 130, 'y1': 300, 'x2': 205, 'y2': 300, 'direction': 'H', 'point1': {}}
# shape110 {'type': 'Line', 'element': 'MAL_OS1_232', 'rotation': '', 'left': '130', 'top': '405', 'height': '10', 'width': '75', 'x1': 130, 'y1': 405, 'x2': 205, 'y2': 405, 'direction': 'H', 'point1': {}}
# shape111 {'type': 'Line', 'element': 'MAL_OS1_202', 'rotation': '', 'left': '130', 'top': '505', 'height': '10', 'width': '75', 'x1': 130, 'y1': 505, 'x2': 205, 'y2': 505, 'direction': 'H', 'point1': {}}
# shape112 {'type': 'Line', 'element': 'MAL_OS1_483', 'rotation': '', 'left': '125', 'top': '630', 'height': '10', 'width': '80', 'x1': 125, 'y1': 630, 'x2': 205, 'y2': 630, 'direction': 'H', 'point1': {}}
# shape115 {'type': 'Line', 'element': 'MAL_OS1_417', 'rotation': '', 'left': '125', 'top': '845', 'height': '10', 'width': '80', 'x1': 125, 'y1': 845, 'x2': 205, 'y2': 845, 'direction': 'H', 'point1': {}}
# shape310 {'type': 'Line', 'element': 'MAL_OS1_360', 'rotation': '', 'left': '465', 'top': '845', 'height': '10', 'width': '585', 'x1': 465, 'y1': 845, 'x2': 1050, 'y2': 845, 'direction': 'H', 'point1': {'shape457': {'distance': 5.0, 'point': '2'}}}
# shape392 {'type': 'Line', 'element': 'MAL_OS1_359', 'rotation': '', 'left': '1510', 'top': '830', 'height': '10', 'width': '275', 'x1': 1510, 'y1': 830, 'x2': 1785, 'y2': 830, 'direction': 'H', 'point1': {'shape391': {'distance': 0.0, 'point': '2'}, 'shape607': {'distance': 0.0, 'point': '2'}}}
# shape223 {'type': 'Line', 'element': 'MAL_OS1_218', 'rotation': '', 'left': '225', 'top': '90', 'height': '10', 'width': '435', 'x1': 225, 'y1': 90, 'x2': 660, 'y2': 90, 'direction': 'H', 'point1': {'shape414': {'distance': 5.0, 'point': '2'}}}
# shape232 {'type': 'Line', 'element': 'MAL_OS1_220', 'rotation': '', 'left': '225', 'top': '180', 'height': '10', 'width': '210', 'x1': 225, 'y1': 180, 'x2': 435, 'y2': 180, 'direction': 'H', 'point1': {'shape415': {'distance': 5.0, 'point': '2'}}}
# shape240 {'type': 'Line', 'element': 'MAL_OS1_230', 'rotation': '', 'left': '225', 'top': '300', 'height': '10', 'width': '255', 'x1': 225, 'y1': 300, 'x2': 480, 'y2': 300, 'direction': 'H', 'point1': {'shape416': {'distance': 5.0, 'point': '2'}}}
# shape250 {'type': 'Line', 'element': 'MAL_OS1_232', 'rotation': '', 'left': '225', 'top': '405', 'height': '15', 'width': '145', 'x1': 225, 'y1': 405, 'x2': 370, 'y2': 405, 'direction': 'H', 'point1': {'shape417': {'distance': 5.0, 'point': '2'}}}
# shape254 {'type': 'Line', 'element': 'MAL_OS1_202', 'rotation': '', 'left': '225', 'top': '505', 'height': '10', 'width': '275', 'x1': 225, 'y1': 505, 'x2': 500, 'y2': 505, 'direction': 'H', 'point1': {'shape418': {'distance': 5.0, 'point': '2'}}}
# shape255 {'type': 'Line', 'element': 'MAL_OS1_312', 'rotation': '', 'left': '590', 'top': '505', 'height': '15', 'width': '35', 'x1': 590, 'y1': 505, 'x2': 625, 'y2': 505, 'direction': 'H', 'point1': {'shape680': {'distance': 0.0, 'point': '2'}, 'shape275': {'distance': 0.0, 'point': '2'}}}
# shape266 {'type': 'Line', 'element': 'MAL_OS1_483', 'rotation': '', 'left': '225', 'top': '630', 'height': '15', 'width': '50', 'x1': 225, 'y1': 630, 'x2': 275, 'y2': 630, 'direction': 'H', 'point1': {'shape421': {'distance': 5.0, 'point': '2'}}}
# shape269 {'type': 'Line', 'element': 'MAL_OS1_417', 'rotation': '', 'left': '225', 'top': '845', 'height': '15', 'width': '170', 'x1': 225, 'y1': 845, 'x2': 395, 'y2': 845, 'direction': 'H', 'point1': {'shape423': {'distance': 5.0, 'point': '2'}}}
# shape274 {'type': 'Line', 'element': 'MAL_OS1_417', 'rotation': '', 'left': '395', 'top': '845', 'height': '10', 'width': '50', 'x1': 395, 'y1': 845, 'x2': 445, 'y2': 845, 'direction': 'H', 'point1': {'shape269': {'distance': 0.0, 'point': '2'}, 'shape551': {'distance': 0.0, 'point': '2'}}}
# shape551 {'type': 'Line', 'element': 'MAL_OS1_417', 'rotation': '', 'left': '395', 'top': '815', 'height': '30', 'width': '10', 'x1': 395, 'y1': 815, 'x2': 395, 'y2': 845, 'direction': 'V', 'point1': {'shape552': {'distance': 0.0, 'point': '2'}, 'shape277': {'distance': 0.0, 'point': '1'}}}
# shape276 {'type': 'Line', 'element': 'MAL_OS1_417', 'rotation': '', 'left': '395', 'top': '785', 'height': '10', 'width': '50', 'x1': 395, 'y1': 785, 'x2': 445, 'y2': 785, 'direction': 'H', 'point1': {'shape552': {'distance': 0.0, 'point': '1'}}}
# shape552 {'type': 'Line', 'element': 'MAL_OS1_417', 'rotation': '', 'left': '395', 'top': '785', 'height': '30', 'width': '10', 'x1': 395, 'y1': 785, 'x2': 395, 'y2': 815, 'direction': 'V', 'point1': {'shape276': {'distance': 0.0, 'point': '1'}}}
# shape277 {'type': 'Line', 'element': 'MAL_OS1_417', 'rotation': '', 'left': '395', 'top': '815', 'height': '10', 'width': '50', 'x1': 395, 'y1': 815, 'x2': 445, 'y2': 815, 'direction': 'H', 'point1': {'shape551': {'distance': 0.0, 'point': '1'}, 'shape552': {'distance': 0.0, 'point': '2'}}}
# shape281 {'type': 'Line', 'element': 'MAL_OS1_271', 'rotation': '', 'left': '1150', 'top': '90', 'height': '10', 'width': '50', 'x1': 1150, 'y1': 90, 'x2': 1200, 'y2': 90, 'direction': 'H', 'point1': {'shape462': {'distance': 5.0, 'point': '2'}}}
# shape282 {'type': 'Line', 'element': 'MAL_OS1_272', 'rotation': '', 'left': '1150', 'top': '300', 'height': '10', 'width': '50', 'x1': 1150, 'y1': 300, 'x2': 1200, 'y2': 300, 'direction': 'H', 'point1': {'shape463': {'distance': 5.0, 'point': '2'}}}
# shape283 {'type': 'Line', 'element': 'MAL_OS1_314', 'rotation': '', 'left': '970', 'top': '90', 'height': '15', 'width': '100', 'x1': 970, 'y1': 90, 'x2': 1070, 'y2': 90, 'direction': 'H', 'point1': {'shape438': {'distance': 5.0, 'point': '2'}}}
# shape284 {'type': 'Line', 'element': 'MAL_OS1_314', 'rotation': '', 'left': '1070', 'top': '90', 'height': '15', 'width': '60', 'x1': 1070, 'y1': 90, 'x2': 1130, 'y2': 90, 'direction': 'H', 'point1': {'shape283': {'distance': 0.0, 'point': '2'}, 'shape553': {'distance': 0.0, 'point': '1'}}}
# shape289 {'type': 'Line', 'element': 'MAL_OS1_314', 'rotation': '', 'left': '1070', 'top': '300', 'height': '10', 'width': '60', 'x1': 1070, 'y1': 300, 'x2': 1130, 'y2': 300, 'direction': 'H', 'point1': {'shape588': {'distance': 0.0, 'point': '2'}}}
# shape553 {'type': 'Line', 'element': 'MAL_OS1_314', 'rotation': '', 'left': '1070', 'top': '90', 'height': '40', 'width': '10', 'x1': 1070, 'y1': 90, 'x2': 1070, 'y2': 130, 'direction': 'V', 'point1': {'shape283': {'distance': 0.0, 'point': '2'}, 'shape284': {'distance': 0.0, 'point': '1'}}}
# shape301 {'type': 'Line', 'element': 'MAL_OS1_2432', 'rotation': '', 'left': '1150', 'top': '440', 'height': '10', 'width': '50', 'x1': 1150, 'y1': 440, 'x2': 1200, 'y2': 440, 'direction': 'H', 'point1': {'shape506': {'distance': 5.0, 'point': '2'}}}
# shape303 {'type': 'Line', 'element': 'MAL_OS1_2431', 'rotation': '', 'left': '1080', 'top': '440', 'height': '10', 'width': '50', 'x1': 1080, 'y1': 440, 'x2': 1130, 'y2': 440, 'direction': 'H', 'point1': {'shape563': {'distance': 0.0, 'point': '2'}, 'shape334': {'distance': 0.0, 'point': '2'}}}
# shape563 {'type': 'Line', 'element': 'MAL_OS1_2431', 'rotation': '', 'left': '1080', 'top': '395', 'height': '45', 'width': '10', 'x1': 1080, 'y1': 395, 'x2': 1080, 'y2': 440, 'direction': 'V', 'point1': {'shape304': {'distance': 0.0, 'point': '1'}}}
# shape304 {'type': 'Line', 'element': 'MAL_OS1_2431', 'rotation': '', 'left': '1080', 'top': '395', 'height': '10', 'width': '120', 'x1': 1080, 'y1': 395, 'x2': 1200, 'y2': 395, 'direction': 'H', 'point1': {'shape563': {'distance': 0.0, 'point': '1'}}}
# shape305 {'type': 'Line', 'element': 'MAL_OS1_2433', 'rotation': '', 'left': '1220', 'top': '395', 'height': '10', 'width': '120', 'x1': 1220, 'y1': 395, 'x2': 1340, 'y2': 395, 'direction': 'H', 'point1': {'shape507': {'distance': 5.0, 'point': '2'}}}
# shape564 {'type': 'Line', 'element': 'MAL_OS1_2433', 'rotation': '', 'left': '1340', 'top': '395', 'height': '30', 'width': '5', 'x1': 1340, 'y1': 395, 'x2': 1340, 'y2': 425, 'direction': 'V', 'point1': {'shape305': {'distance': 0.0, 'point': '2'}}}
# shape314 {'type': 'Line', 'element': 'MAL_OS1_2433', 'rotation': '', 'left': '1220', 'top': '425', 'height': '10', 'width': '120', 'x1': 1220, 'y1': 425, 'x2': 1340, 'y2': 425, 'direction': 'H', 'point1': {}}
# shape315 {'type': 'Line', 'element': 'MAL_OS1_2433', 'rotation': '', 'left': '1340', 'top': '425', 'height': '10', 'width': '50', 'x1': 1340, 'y1': 425, 'x2': 1390, 'y2': 425, 'direction': 'H', 'point1': {'shape564': {'distance': 0.0, 'point': '2'}, 'shape314': {'distance': 0.0, 'point': '2'}}}
# shape329 {'type': 'Line', 'element': 'MAL_OS1_2433', 'rotation': '', 'left': '1390', 'top': '425', 'height': '10', 'width': '50', 'x1': 1390, 'y1': 425, 'x2': 1440, 'y2': 425, 'direction': 'H', 'point1': {'shape315': {'distance': 0.0, 'point': '2'}, 'shape565': {'distance': 0.0, 'point': '1'}}}
# shape565 {'type': 'Line', 'element': 'MAL_OS1_2433', 'rotation': '', 'left': '1390', 'top': '425', 'height': '30', 'width': '10', 'x1': 1390, 'y1': 425, 'x2': 1390, 'y2': 455, 'direction': 'V', 'point1': {'shape315': {'distance': 0.0, 'point': '2'}, 'shape329': {'distance': 0.0, 'point': '1'}}}
# shape330 {'type': 'Line', 'element': 'MAL_OS1_2433', 'rotation': '', 'left': '1390', 'top': '455', 'height': '10', 'width': '50', 'x1': 1390, 'y1': 455, 'x2': 1440, 'y2': 455, 'direction': 'H', 'point1': {'shape565': {'distance': 0.0, 'point': '2'}}}
# shape334 {'type': 'Line', 'element': 'MAL_OS1_2431', 'rotation': '', 'left': '990', 'top': '440', 'height': '10', 'width': '90', 'x1': 990, 'y1': 440, 'x2': 1080, 'y2': 440, 'direction': 'H', 'point1': {'shape566': {'distance': 0.0, 'point': '1'}}}
# shape566 {'type': 'Line', 'element': 'MAL_OS1_2431', 'rotation': '', 'left': '990', 'top': '440', 'height': '35', 'width': '10', 'x1': 990, 'y1': 440, 'x2': 990, 'y2': 475, 'direction': 'V', 'point1': {'shape334': {'distance': 0.0, 'point': '1'}}}
# shape371 {'type': 'Line', 'element': 'MAL_OS1_2431', 'rotation': '', 'left': '960', 'top': '475', 'height': '10', 'width': '30', 'x1': 960, 'y1': 475, 'x2': 990, 'y2': 475, 'direction': 'H', 'point1': {'shape511': {'distance': 5.0, 'point': '2'}}}
# shape568 {'type': 'Line', 'element': 'MAL_OS1_2431', 'rotation': '', 'left': '990', 'top': '475', 'height': '25', 'width': '10', 'x1': 990, 'y1': 475, 'x2': 990, 'y2': 500, 'direction': 'V', 'point1': {'shape566': {'distance': 0.0, 'point': '2'}, 'shape371': {'distance': 0.0, 'point': '2'}}}
# shape393 {'type': 'Line', 'element': 'MAL_OS1_2431', 'rotation': '', 'left': '960', 'top': '500', 'height': '10', 'width': '30', 'x1': 960, 'y1': 500, 'x2': 990, 'y2': 500, 'direction': 'H', 'point1': {'shape512': {'distance': 5.0, 'point': '2'}}}
# shape569 {'type': 'Line', 'element': 'MAL_OS1_2431', 'rotation': '', 'left': '990', 'top': '500', 'height': '25', 'width': '10', 'x1': 990, 'y1': 500, 'x2': 990, 'y2': 525, 'direction': 'V', 'point1': {'shape568': {'distance': 0.0, 'point': '2'}, 'shape393': {'distance': 0.0, 'point': '2'}}}
# shape394 {'type': 'Line', 'element': 'MAL_OS1_2431', 'rotation': '', 'left': '960', 'top': '525', 'height': '10', 'width': '30', 'x1': 960, 'y1': 525, 'x2': 990, 'y2': 525, 'direction': 'H', 'point1': {'shape513': {'distance': 5.0, 'point': '2'}}}
# shape570 {'type': 'Line', 'element': 'MAL_OS1_2431', 'rotation': '', 'left': '990', 'top': '525', 'height': '25', 'width': '15', 'x1': 990, 'y1': 525, 'x2': 990, 'y2': 550, 'direction': 'V', 'point1': {'shape569': {'distance': 0.0, 'point': '2'}, 'shape394': {'distance': 0.0, 'point': '2'}}}
# shape395 {'type': 'Line', 'element': 'MAL_OS1_2428', 'rotation': '', 'left': '1150', 'top': '590', 'height': '10', 'width': '50', 'x1': 1150, 'y1': 590, 'x2': 1200, 'y2': 590, 'direction': 'H', 'point1': {'shape514': {'distance': 5.0, 'point': '2'}}}
# shape396 {'type': 'Line', 'element': 'MAL_OS1_2426', 'rotation': '', 'left': '1080', 'top': '590', 'height': '10', 'width': '50', 'x1': 1080, 'y1': 590, 'x2': 1130, 'y2': 590, 'direction': 'H', 'point1': {'shape571': {'distance': 0.0, 'point': '2'}, 'shape399': {'distance': 0.0, 'point': '2'}}}
# shape571 {'type': 'Line', 'element': 'MAL_OS1_2426', 'rotation': '', 'left': '1080', 'top': '545', 'height': '45', 'width': '10', 'x1': 1080, 'y1': 545, 'x2': 1080, 'y2': 590, 'direction': 'V', 'point1': {'shape397': {'distance': 0.0, 'point': '1'}}}
# shape397 {'type': 'Line', 'element': 'MAL_OS1_2426', 'rotation': '', 'left': '1080', 'top': '545', 'height': '10', 'width': '120', 'x1': 1080, 'y1': 545, 'x2': 1200, 'y2': 545, 'direction': 'H', 'point1': {'shape571': {'distance': 0.0, 'point': '1'}}}
# shape398 {'type': 'Line', 'element': 'MAL_OS1_2424', 'rotation': '', 'left': '1220', 'top': '545', 'height': '10', 'width': '120', 'x1': 1220, 'y1': 545, 'x2': 1340, 'y2': 545, 'direction': 'H', 'point1': {'shape515': {'distance': 5.0, 'point': '2'}}}
# shape577 {'type': 'Line', 'element': 'MAL_OS1_2424', 'rotation': '', 'left': '1340', 'top': '545', 'height': '30', 'width': '5', 'x1': 1340, 'y1': 545, 'x2': 1340, 'y2': 575, 'direction': 'V', 'point1': {'shape398': {'distance': 0.0, 'point': '2'}}}
# shape399 {'type': 'Line', 'element': 'MAL_OS1_2426', 'rotation': '', 'left': '990', 'top': '590', 'height': '10', 'width': '90', 'x1': 990, 'y1': 590, 'x2': 1080, 'y2': 590, 'direction': 'H', 'point1': {'shape584': {'distance': 0.0, 'point': '2'}, 'shape646': {'distance': 0.0, 'point': '1'}, 'shape668': {'distance': 0.0, 'point': '2'}}}
# shape400 {'type': 'Line', 'element': 'MAL_OS1_2424', 'rotation': '', 'left': '1225', 'top': '575', 'height': '10', 'width': '115', 'x1': 1225, 'y1': 575, 'x2': 1340, 'y2': 575, 'direction': 'H', 'point1': {}}
# shape401 {'type': 'Line', 'element': 'MAL_OS1_2424', 'rotation': '', 'left': '1340', 'top': '575', 'height': '10', 'width': '50', 'x1': 1340, 'y1': 575, 'x2': 1390, 'y2': 575, 'direction': 'H', 'point1': {'shape577': {'distance': 0.0, 'point': '2'}, 'shape400': {'distance': 0.0, 'point': '2'}}}
# shape404 {'type': 'Line', 'element': 'MAL_OS1_5002', 'rotation': '', 'left': '1460', 'top': '425', 'height': '10', 'width': '50', 'x1': 1460, 'y1': 425, 'x2': 1510, 'y2': 425, 'direction': 'H', 'point1': {'shape508': {'distance': 5.0, 'point': '2'}}}
# shape608 {'type': 'Line', 'element': 'MAL_OS1_5002', 'rotation': '', 'left': '1510', 'top': '425', 'height': '150', 'width': '10', 'x1': 1510, 'y1': 425, 'x2': 1510, 'y2': 575, 'direction': 'V', 'point1': {'shape404': {'distance': 0.0, 'point': '2'}, 'shape406': {'distance': 0.0, 'point': '1'}}}
# shape405 {'type': 'Line', 'element': 'MAL_OS1_5002', 'rotation': '', 'left': '1460', 'top': '575', 'height': '10', 'width': '50', 'x1': 1460, 'y1': 575, 'x2': 1510, 'y2': 575, 'direction': 'H', 'point1': {'shape516': {'distance': 5.0, 'point': '2'}}}
# shape406 {'type': 'Line', 'element': 'MAL_OS1_5002', 'rotation': '', 'left': '1510', 'top': '425', 'height': '10', 'width': '50', 'x1': 1510, 'y1': 425, 'x2': 1560, 'y2': 425, 'direction': 'H', 'point1': {'shape404': {'distance': 0.0, 'point': '2'}, 'shape608': {'distance': 0.0, 'point': '1'}}}
# shape609 {'type': 'Line', 'element': 'MAL_OS1_5002', 'rotation': '', 'left': '1560', 'top': '425', 'height': '30', 'width': '10', 'x1': 1560, 'y1': 425, 'x2': 1560, 'y2': 455, 'direction': 'V', 'point1': {'shape406': {'distance': 0.0, 'point': '2'}, 'shape408': {'distance': 0.0, 'point': '1'}}}
# shape407 {'type': 'Line', 'element': 'MAL_OS1_5002', 'rotation': '', 'left': '1560', 'top': '455', 'height': '10', 'width': '50', 'x1': 1560, 'y1': 455, 'x2': 1610, 'y2': 455, 'direction': 'H', 'point1': {'shape609': {'distance': 0.0, 'point': '2'}}}
# shape408 {'type': 'Line', 'element': 'MAL_OS1_5002', 'rotation': '', 'left': '1560', 'top': '425', 'height': '10', 'width': '100', 'x1': 1560, 'y1': 425, 'x2': 1660, 'y2': 425, 'direction': 'H', 'point1': {'shape406': {'distance': 0.0, 'point': '2'}, 'shape609': {'distance': 0.0, 'point': '1'}}}
# shape610 {'type': 'Line', 'element': 'MAL_OS1_5002', 'rotation': '', 'left': '1660', 'top': '425', 'height': '30', 'width': '10', 'x1': 1660, 'y1': 425, 'x2': 1660, 'y2': 455, 'direction': 'V', 'point1': {'shape408': {'distance': 0.0, 'point': '2'}, 'shape410': {'distance': 0.0, 'point': '1'}}}
# shape409 {'type': 'Line', 'element': 'MAL_OS1_5002', 'rotation': '', 'left': '1660', 'top': '455', 'height': '10', 'width': '50', 'x1': 1660, 'y1': 455, 'x2': 1710, 'y2': 455, 'direction': 'H', 'point1': {'shape610': {'distance': 0.0, 'point': '2'}}}
# shape410 {'type': 'Line', 'element': 'MAL_OS1_5002', 'rotation': '', 'left': '1660', 'top': '425', 'height': '15', 'width': '125', 'x1': 1660, 'y1': 425, 'x2': 1785, 'y2': 425, 'direction': 'H', 'point1': {'shape408': {'distance': 0.0, 'point': '2'}, 'shape610': {'distance': 0.0, 'point': '1'}}}
# shape523 {'type': 'Line', 'element': 'MAL_OS1_246', 'rotation': '', 'left': '390', 'top': '405', 'height': '10', 'width': '140', 'x1': 390, 'y1': 405, 'x2': 530, 'y2': 405, 'direction': 'H', 'point1': {'shape444': {'distance': 5.0, 'point': '2'}}}
# shape627 {'type': 'Line', 'element': 'MAL_OS1_483', 'rotation': '', 'left': '395', 'top': '630', 'height': '10', 'width': '365', 'x1': 395, 'y1': 630, 'x2': 760, 'y2': 630, 'direction': 'H', 'point1': {'shape661': {'distance': 0.0, 'point': '1'}, 'shape271': {'distance': 0.0, 'point': '2'}}}
# shape651 {'type': 'Line', 'element': 'MAL_OS1_325', 'rotation': '', 'left': '835', 'top': '500', 'height': '90', 'width': '10', 'x1': 835, 'y1': 500, 'x2': 835, 'y2': 590, 'direction': 'V', 'point1': {'shape379': {'distance': 0.0, 'point': '2'}, 'shape684': {'distance': 0.0, 'point': '2'}}}
# shape312 {'type': 'Line', 'element': 'MAL_OS1_289', 'rotation': '', 'left': '1155', 'top': '845', 'height': '10', 'width': '45', 'x1': 1155, 'y1': 845, 'x2': 1200, 'y2': 845, 'direction': 'H', 'point1': {'shape313': {'distance': 0.0, 'point': '2'}, 'shape572': {'distance': 0.0, 'point': '2'}}}
# shape313 {'type': 'Line', 'element': 'MAL_OS1_289', 'rotation': '', 'left': '1110', 'top': '845', 'height': '10', 'width': '45', 'x1': 1110, 'y1': 845, 'x2': 1155, 'y2': 845, 'direction': 'H', 'point1': {'shape468': {'distance': 5.0, 'point': '2'}}}
# shape316 {'type': 'Line', 'element': 'MAL_OS1_360', 'rotation': '', 'left': '1050', 'top': '845', 'height': '10', 'width': '40', 'x1': 1050, 'y1': 845, 'x2': 1090, 'y2': 845, 'direction': 'H', 'point1': {'shape310': {'distance': 0.0, 'point': '2'}, 'shape574': {'distance': 0.0, 'point': '2'}}}
# shape572 {'type': 'Line', 'element': 'MAL_OS1_289', 'rotation': '', 'left': '1155', 'top': '800', 'height': '45', 'width': '10', 'x1': 1155, 'y1': 800, 'x2': 1155, 'y2': 845, 'direction': 'V', 'point1': {'shape318': {'distance': 0.0, 'point': '1'}}}
# shape318 {'type': 'Line', 'element': 'MAL_OS1_289', 'rotation': '', 'left': '1155', 'top': '800', 'height': '10', 'width': '45', 'x1': 1155, 'y1': 800, 'x2': 1200, 'y2': 800, 'direction': 'H', 'point1': {'shape572': {'distance': 0.0, 'point': '1'}}}
# shape319 {'type': 'Line', 'element': 'MAL_OS1_288', 'rotation': '', 'left': '1220', 'top': '800', 'height': '10', 'width': '45', 'x1': 1220, 'y1': 800, 'x2': 1265, 'y2': 800, 'direction': 'H', 'point1': {'shape469': {'distance': 5.0, 'point': '2'}}}
# shape573 {'type': 'Line', 'element': 'MAL_OS1_288', 'rotation': '', 'left': '1265', 'top': '800', 'height': '30', 'width': '10', 'x1': 1265, 'y1': 800, 'x2': 1265, 'y2': 830, 'direction': 'V', 'point1': {'shape319': {'distance': 0.0, 'point': '2'}}}
# shape320 {'type': 'Line', 'element': 'MAL_OS1_288', 'rotation': '', 'left': '1225', 'top': '830', 'height': '10', 'width': '40', 'x1': 1225, 'y1': 830, 'x2': 1265, 'y2': 830, 'direction': 'H', 'point1': {}}
# shape321 {'type': 'Line', 'element': 'MAL_OS1_288', 'rotation': '', 'left': '1265', 'top': '830', 'height': '10', 'width': '115', 'x1': 1265, 'y1': 830, 'x2': 1380, 'y2': 830, 'direction': 'H', 'point1': {'shape573': {'distance': 0.0, 'point': '2'}, 'shape320': {'distance': 0.0, 'point': '2'}}}
# shape574 {'type': 'Line', 'element': 'MAL_OS1_360', 'rotation': '', 'left': '1050', 'top': '690', 'height': '155', 'width': '10', 'x1': 1050, 'y1': 690, 'x2': 1050, 'y2': 845, 'direction': 'V', 'point1': {'shape322': {'distance': 0.0, 'point': '1'}}}
# shape322 {'type': 'Line', 'element': 'MAL_OS1_360', 'rotation': '', 'left': '1050', 'top': '690', 'height': '20', 'width': '40', 'x1': 1050, 'y1': 690, 'x2': 1090, 'y2': 690, 'direction': 'H', 'point1': {'shape574': {'distance': 0.0, 'point': '1'}}}
# shape323 {'type': 'Line', 'element': 'MAL_OS1_287', 'rotation': '', 'left': '1155', 'top': '690', 'height': '10', 'width': '45', 'x1': 1155, 'y1': 690, 'x2': 1200, 'y2': 690, 'direction': 'H', 'point1': {'shape324': {'distance': 0.0, 'point': '2'}, 'shape575': {'distance': 0.0, 'point': '2'}}}
# shape324 {'type': 'Line', 'element': 'MAL_OS1_287', 'rotation': '', 'left': '1110', 'top': '690', 'height': '10', 'width': '45', 'x1': 1110, 'y1': 690, 'x2': 1155, 'y2': 690, 'direction': 'H', 'point1': {'shape470': {'distance': 5.0, 'point': '2'}}}
# shape575 {'type': 'Line', 'element': 'MAL_OS1_287', 'rotation': '', 'left': '1155', 'top': '645', 'height': '45', 'width': '10', 'x1': 1155, 'y1': 645, 'x2': 1155, 'y2': 690, 'direction': 'V', 'point1': {'shape325': {'distance': 0.0, 'point': '1'}}}
# shape325 {'type': 'Line', 'element': 'MAL_OS1_287', 'rotation': '', 'left': '1155', 'top': '645', 'height': '10', 'width': '45', 'x1': 1155, 'y1': 645, 'x2': 1200, 'y2': 645, 'direction': 'H', 'point1': {'shape575': {'distance': 0.0, 'point': '1'}}}
# shape326 {'type': 'Line', 'element': 'MAL_OS1_286', 'rotation': '', 'left': '1220', 'top': '645', 'height': '10', 'width': '45', 'x1': 1220, 'y1': 645, 'x2': 1265, 'y2': 645, 'direction': 'H', 'point1': {'shape471': {'distance': 5.0, 'point': '2'}}}
# shape576 {'type': 'Line', 'element': 'MAL_OS1_286', 'rotation': '', 'left': '1265', 'top': '645', 'height': '30', 'width': '10', 'x1': 1265, 'y1': 645, 'x2': 1265, 'y2': 675, 'direction': 'V', 'point1': {'shape326': {'distance': 0.0, 'point': '2'}}}
# shape327 {'type': 'Line', 'element': 'MAL_OS1_286', 'rotation': '', 'left': '1225', 'top': '675', 'height': '10', 'width': '40', 'x1': 1225, 'y1': 675, 'x2': 1265, 'y2': 675, 'direction': 'H', 'point1': {}}
# shape328 {'type': 'Line', 'element': 'MAL_OS1_286', 'rotation': '', 'left': '1270', 'top': '675', 'height': '10', 'width': '110', 'x1': 1270, 'y1': 675, 'x2': 1380, 'y2': 675, 'direction': 'H', 'point1': {'shape576': {'distance': 5.0, 'point': '2'}, 'shape327': {'distance': 5.0, 'point': '2'}}}
# shape390 {'type': 'Line', 'element': 'MAL_OS1_359', 'rotation': '', 'left': '1400', 'top': '675', 'height': '20', 'width': '110', 'x1': 1400, 'y1': 675, 'x2': 1510, 'y2': 675, 'direction': 'H', 'point1': {'shape472': {'distance': 5.0, 'point': '2'}}}
# shape391 {'type': 'Line', 'element': 'MAL_OS1_359', 'rotation': '', 'left': '1400', 'top': '830', 'height': '20', 'width': '110', 'x1': 1400, 'y1': 830, 'x2': 1510, 'y2': 830, 'direction': 'H', 'point1': {'shape473': {'distance': 5.0, 'point': '2'}}}
# shape607 {'type': 'Line', 'element': 'MAL_OS1_359', 'rotation': '', 'left': '1510', 'top': '675', 'height': '155', 'width': '10', 'x1': 1510, 'y1': 675, 'x2': 1510, 'y2': 830, 'direction': 'V', 'point1': {'shape390': {'distance': 0.0, 'point': '2'}}}
# shape286 {'type': 'Line', 'element': 'MAL_OS1_270', 'rotation': '', 'left': '1225', 'top': '80', 'height': '10', 'width': '50', 'x1': 1225, 'y1': 80, 'x2': 1275, 'y2': 80, 'direction': 'H', 'point1': {}}
# shape287 {'type': 'Line', 'element': 'MAL_OS1_273', 'rotation': '', 'left': '1225', 'top': '285', 'height': '10', 'width': '50', 'x1': 1225, 'y1': 285, 'x2': 1275, 'y2': 285, 'direction': 'H', 'point1': {}}
# shape288 {'type': 'Line', 'element': 'MAL_OS1_313', 'rotation': '', 'left': '1295', 'top': '285', 'height': '10', 'width': '50', 'x1': 1295, 'y1': 285, 'x2': 1345, 'y2': 285, 'direction': 'H', 'point1': {'shape476': {'distance': 5.0, 'point': '2'}}}
# shape302 {'type': 'Line', 'element': 'MAL_OS1_313', 'rotation': '', 'left': '1295', 'top': '80', 'height': '10', 'width': '50', 'x1': 1295, 'y1': 80, 'x2': 1345, 'y2': 80, 'direction': 'H', 'point1': {'shape467': {'distance': 5.0, 'point': '2'}}}
# shape558 {'type': 'Line', 'element': 'MAL_OS1_313', 'rotation': '', 'left': '1345', 'top': '80', 'height': '60', 'width': '15', 'x1': 1345, 'y1': 80, 'x2': 1345, 'y2': 140, 'direction': 'V', 'point1': {'shape302': {'distance': 0.0, 'point': '2'}, 'shape306': {'distance': 0.0, 'point': '1'}}}
# shape306 {'type': 'Line', 'element': 'MAL_OS1_313', 'rotation': '', 'left': '1345', 'top': '80', 'height': '10', 'width': '50', 'x1': 1345, 'y1': 80, 'x2': 1395, 'y2': 80, 'direction': 'H', 'point1': {'shape302': {'distance': 0.0, 'point': '2'}, 'shape558': {'distance': 0.0, 'point': '1'}}}
# shape331 {'type': 'Line', 'element': 'MAL_OS1_313', 'rotation': '', 'left': '1345', 'top': '140', 'height': '10', 'width': '50', 'x1': 1345, 'y1': 140, 'x2': 1395, 'y2': 140, 'direction': 'H', 'point1': {'shape558': {'distance': 0.0, 'point': '2'}, 'shape559': {'distance': 0.0, 'point': '1'}}}
# shape559 {'type': 'Line', 'element': 'MAL_OS1_313', 'rotation': '', 'left': '1345', 'top': '140', 'height': '80', 'width': '15', 'x1': 1345, 'y1': 140, 'x2': 1345, 'y2': 220, 'direction': 'V', 'point1': {'shape558': {'distance': 0.0, 'point': '2'}, 'shape331': {'distance': 0.0, 'point': '1'}}}
# shape332 {'type': 'Line', 'element': 'MAL_OS1_313', 'rotation': '', 'left': '1345', 'top': '220', 'height': '10', 'width': '50', 'x1': 1345, 'y1': 220, 'x2': 1395, 'y2': 220, 'direction': 'H', 'point1': {'shape559': {'distance': 0.0, 'point': '2'}, 'shape578': {'distance': 0.0, 'point': '1'}}}
# shape578 {'type': 'Line', 'element': 'MAL_OS1_313', 'rotation': '', 'left': '1345', 'top': '220', 'height': '65', 'width': '15', 'x1': 1345, 'y1': 220, 'x2': 1345, 'y2': 285, 'direction': 'V', 'point1': {'shape559': {'distance': 0.0, 'point': '2'}, 'shape332': {'distance': 0.0, 'point': '1'}}}
# shape307 {'type': 'Line', 'element': 'MAL_OS1_376', 'rotation': '', 'left': '1415', 'top': '80', 'height': '10', 'width': '50', 'x1': 1415, 'y1': 80, 'x2': 1465, 'y2': 80, 'direction': 'H', 'point1': {'shape477': {'distance': 5.0, 'point': '2'}}}
# shape317 {'type': 'Line', 'element': 'MAL_OS1_376', 'rotation': '', 'left': '1465', 'top': '80', 'height': '10', 'width': '120', 'x1': 1465, 'y1': 80, 'x2': 1585, 'y2': 80, 'direction': 'H', 'point1': {'shape307': {'distance': 0.0, 'point': '2'}, 'shape579': {'distance': 0.0, 'point': '1'}}}
# shape579 {'type': 'Line', 'element': 'MAL_OS1_376', 'rotation': '', 'left': '1465', 'top': '80', 'height': '30', 'width': '15', 'x1': 1465, 'y1': 80, 'x2': 1465, 'y2': 110, 'direction': 'V', 'point1': {'shape307': {'distance': 0.0, 'point': '2'}, 'shape317': {'distance': 0.0, 'point': '1'}}}
# shape333 {'type': 'Line', 'element': 'MAL_OS1_376', 'rotation': '', 'left': '1465', 'top': '110', 'height': '10', 'width': '30', 'x1': 1465, 'y1': 110, 'x2': 1495, 'y2': 110, 'direction': 'H', 'point1': {'shape579': {'distance': 0.0, 'point': '2'}}}
# shape335 {'type': 'Line', 'element': 'MAL_OS1_7279', 'rotation': '', 'left': '1605', 'top': '80', 'height': '10', 'width': '30', 'x1': 1605, 'y1': 80, 'x2': 1635, 'y2': 80, 'direction': 'H', 'point1': {'shape480': {'distance': 5.0, 'point': '2'}}}
# shape534 {'type': 'Line', 'element': 'MAL_OS1_7280', 'rotation': '', 'left': '1685', 'top': '80', 'height': '30', 'width': '10', 'x1': 1685, 'y1': 80, 'x2': 1685, 'y2': 110, 'direction': 'V', 'point1': {'shape385': {'distance': 0.0, 'point': '1'}, 'shape336': {'distance': 0.0, 'point': '2'}}}
# shape226 {'type': 'Line', 'element': 'MAL_OS1_7280', 'rotation': '', 'left': '1655', 'top': '110', 'height': '10', 'width': '30', 'x1': 1655, 'y1': 110, 'x2': 1685, 'y2': 110, 'direction': 'H', 'point1': {'shape433': {'distance': 5.0, 'point': '2'}}}
# shape536 {'type': 'Line', 'element': 'MAL_OS1_7280', 'rotation': '', 'left': '1715', 'top': '80', 'height': '30', 'width': '10', 'x1': 1715, 'y1': 80, 'x2': 1715, 'y2': 110, 'direction': 'V', 'point1': {'shape385': {'distance': 0.0, 'point': '2'}, 'shape337': {'distance': 0.0, 'point': '1'}}}
# shape336 {'type': 'Line', 'element': 'MAL_OS1_7280', 'rotation': '', 'left': '1655', 'top': '80', 'height': '10', 'width': '30', 'x1': 1655, 'y1': 80, 'x2': 1685, 'y2': 80, 'direction': 'H', 'point1': {'shape481': {'distance': 5.0, 'point': '2'}}}
# shape337 {'type': 'Line', 'element': 'MAL_OS1_7280', 'rotation': '', 'left': '1715', 'top': '80', 'height': '10', 'width': '70', 'x1': 1715, 'y1': 80, 'x2': 1785, 'y2': 80, 'direction': 'H', 'point1': {'shape385': {'distance': 0.0, 'point': '2'}, 'shape536': {'distance': 0.0, 'point': '1'}}}
# shape659 {'type': 'Line', 'element': 'MAL_OS1_483', 'rotation': '', 'left': '395', 'top': '660', 'height': '10', 'width': '50', 'x1': 395, 'y1': 660, 'x2': 445, 'y2': 660, 'direction': 'H', 'point1': {'shape661': {'distance': 0.0, 'point': '2'}}}
# shape661 {'type': 'Line', 'element': 'MAL_OS1_483', 'rotation': '', 'left': '395', 'top': '630', 'height': '30', 'width': '10', 'x1': 395, 'y1': 630, 'x2': 395, 'y2': 660, 'direction': 'V', 'point1': {'shape627': {'distance': 0.0, 'point': '1'}, 'shape271': {'distance': 0.0, 'point': '2'}}}
# shape580 {'type': 'Line', 'element': 'MAL_OS1_483', 'rotation': '', 'left': '275', 'top': '630', 'height': '30', 'width': '10', 'x1': 275, 'y1': 630, 'x2': 275, 'y2': 660, 'direction': 'V', 'point1': {'shape266': {'distance': 0.0, 'point': '2'}, 'shape271': {'distance': 0.0, 'point': '1'}}}
# shape262 {'type': 'Line', 'element': 'MAL_OS1_483', 'rotation': '', 'left': '275', 'top': '660', 'height': '10', 'width': '50', 'x1': 275, 'y1': 660, 'x2': 325, 'y2': 660, 'direction': 'H', 'point1': {'shape580': {'distance': 0.0, 'point': '2'}}}
# shape271 {'type': 'Line', 'element': 'MAL_OS1_483', 'rotation': '', 'left': '275', 'top': '630', 'height': '10', 'width': '120', 'x1': 275, 'y1': 630, 'x2': 395, 'y2': 630, 'direction': 'H', 'point1': {'shape266': {'distance': 0.0, 'point': '2'}, 'shape580': {'distance': 0.0, 'point': '1'}}}
# shape116 {'type': 'Line', 'element': 'MAL_OS1_491', 'rotation': '', 'left': '125', 'top': '730', 'height': '10', 'width': '80', 'x1': 125, 'y1': 730, 'x2': 205, 'y2': 730, 'direction': 'H', 'point1': {}}
# shape341 {'type': 'Line', 'element': 'MAL_OS1_491', 'rotation': '', 'left': '225', 'top': '730', 'height': '10', 'width': '535', 'x1': 225, 'y1': 730, 'x2': 760, 'y2': 730, 'direction': 'H', 'point1': {'shape422': {'distance': 5.0, 'point': '2'}}}
# shape584 {'type': 'Line', 'element': 'MAL_OS1_2426', 'rotation': '', 'left': '990', 'top': '570', 'height': '20', 'width': '15', 'x1': 990, 'y1': 570, 'x2': 990, 'y2': 590, 'direction': 'V', 'point1': {'shape510': {'distance': 5.0, 'point': '2'}}}
# shape643 {'type': 'Line', 'element': 'MAL_OS1_2426', 'rotation': '', 'left': '945', 'top': '695', 'height': '10', 'width': '45', 'x1': 945, 'y1': 695, 'x2': 990, 'y2': 695, 'direction': 'H', 'point1': {'shape694': {'distance': 5.0, 'point': '2'}}}
# shape644 {'type': 'Line', 'element': 'MAL_OS1_2426', 'rotation': '', 'left': '945', 'top': '660', 'height': '10', 'width': '45', 'x1': 945, 'y1': 660, 'x2': 990, 'y2': 660, 'direction': 'H', 'point1': {'shape696': {'distance': 5.0, 'point': '2'}}}
# shape645 {'type': 'Line', 'element': 'MAL_OS1_2426', 'rotation': '', 'left': '885', 'top': '625', 'height': '10', 'width': '105', 'x1': 885, 'y1': 625, 'x2': 990, 'y2': 625, 'direction': 'H', 'point1': {'shape642': {'distance': 5.0, 'point': '2'}}}
# shape646 {'type': 'Line', 'element': 'MAL_OS1_2426', 'rotation': '', 'left': '990', 'top': '590', 'height': '35', 'width': '10', 'x1': 990, 'y1': 590, 'x2': 990, 'y2': 625, 'direction': 'V', 'point1': {'shape399': {'distance': 0.0, 'point': '1'}, 'shape584': {'distance': 0.0, 'point': '2'}, 'shape668': {'distance': 0.0, 'point': '2'}}}
# shape647 {'type': 'Line', 'element': 'MAL_OS1_2426', 'rotation': '', 'left': '990', 'top': '625', 'height': '35', 'width': '10', 'x1': 990, 'y1': 625, 'x2': 990, 'y2': 660, 'direction': 'V', 'point1': {'shape645': {'distance': 0.0, 'point': '2'}, 'shape646': {'distance': 0.0, 'point': '2'}}}
# shape648 {'type': 'Line', 'element': 'MAL_OS1_2426', 'rotation': '', 'left': '990', 'top': '660', 'height': '35', 'width': '10', 'x1': 990, 'y1': 660, 'x2': 990, 'y2': 695, 'direction': 'V', 'point1': {'shape644': {'distance': 0.0, 'point': '2'}, 'shape647': {'distance': 0.0, 'point': '2'}}}
# shape668 {'type': 'Line', 'element': 'MAL_OS1_2426', 'rotation': '', 'left': '945', 'top': '590', 'height': '10', 'width': '45', 'x1': 945, 'y1': 590, 'x2': 990, 'y2': 590, 'direction': 'H', 'point1': {'shape650': {'distance': 5.0, 'point': '2'}}}
# shape619 {'type': 'Line', 'element': 'MAL_OS1_368', 'rotation': '', 'left': '920', 'top': '360', 'height': '25', 'width': '10', 'x1': 920, 'y1': 360, 'x2': 920, 'y2': 385, 'direction': 'V', 'point1': {'shape589': {'distance': 0.0, 'point': '2'}, 'shape359': {'distance': 0.0, 'point': '2'}}}
# shape292 {'type': 'Line', 'element': 'MAL_OS1_314', 'rotation': '', 'left': '970', 'top': '130', 'height': '15', 'width': '100', 'x1': 970, 'y1': 130, 'x2': 1070, 'y2': 130, 'direction': 'H', 'point1': {'shape439': {'distance': 5.0, 'point': '2'}}}
# shape293 {'type': 'Line', 'element': 'MAL_OS1_314', 'rotation': '', 'left': '970', 'top': '170', 'height': '15', 'width': '100', 'x1': 970, 'y1': 170, 'x2': 1070, 'y2': 170, 'direction': 'H', 'point1': {'shape461': {'distance': 5.0, 'point': '2'}}}
# shape587 {'type': 'Line', 'element': 'MAL_OS1_314', 'rotation': '', 'left': '1070', 'top': '170', 'height': '40', 'width': '10', 'x1': 1070, 'y1': 170, 'x2': 1070, 'y2': 210, 'direction': 'V', 'point1': {'shape554': {'distance': 0.0, 'point': '2'}, 'shape293': {'distance': 0.0, 'point': '2'}}}
# shape297 {'type': 'Line', 'element': 'MAL_OS1_314', 'rotation': '', 'left': '970', 'top': '210', 'height': '15', 'width': '100', 'x1': 970, 'y1': 210, 'x2': 1070, 'y2': 210, 'direction': 'H', 'point1': {'shape464': {'distance': 5.0, 'point': '2'}}}
# shape311 {'type': 'Line', 'element': 'MAL_OS1_323', 'rotation': '', 'left': '735', 'top': '90', 'height': '15', 'width': '215', 'x1': 735, 'y1': 90, 'x2': 950, 'y2': 90, 'direction': 'H', 'point1': {'shape617': {'distance': 0.0, 'point': '1'}, 'shape350': {'distance': 0.0, 'point': '2'}}}
# shape347 {'type': 'Line', 'element': 'MAL_OS1_321', 'rotation': '', 'left': '770', 'top': '130', 'height': '15', 'width': '180', 'x1': 770, 'y1': 130, 'x2': 950, 'y2': 130, 'direction': 'H', 'point1': {'shape655': {'distance': 0.0, 'point': '1'}, 'shape352': {'distance': 0.0, 'point': '2'}}}
# shape348 {'type': 'Line', 'element': 'MAL_OS1_326', 'rotation': '', 'left': '805', 'top': '170', 'height': '15', 'width': '145', 'x1': 805, 'y1': 170, 'x2': 950, 'y2': 170, 'direction': 'H', 'point1': {'shape674': {'distance': 0.0, 'point': '1'}, 'shape353': {'distance': 0.0, 'point': '2'}}}
# shape349 {'type': 'Line', 'element': 'MAL_OS1_327', 'rotation': '', 'left': '680', 'top': '210', 'height': '15', 'width': '160', 'x1': 680, 'y1': 210, 'x2': 840, 'y2': 210, 'direction': 'H', 'point1': {'shape484': {'distance': 5.0, 'point': '2'}}}
# shape588 {'type': 'Line', 'element': 'MAL_OS1_314', 'rotation': '', 'left': '1070', 'top': '210', 'height': '90', 'width': '10', 'x1': 1070, 'y1': 210, 'x2': 1070, 'y2': 300, 'direction': 'V', 'point1': {'shape587': {'distance': 0.0, 'point': '2'}, 'shape297': {'distance': 0.0, 'point': '2'}}}
# shape617 {'type': 'Line', 'element': 'MAL_OS1_323', 'rotation': '', 'left': '735', 'top': '90', 'height': '35', 'width': '10', 'x1': 735, 'y1': 90, 'x2': 735, 'y2': 125, 'direction': 'V', 'point1': {'shape311': {'distance': 0.0, 'point': '1'}, 'shape350': {'distance': 0.0, 'point': '2'}}}
# shape622 {'type': 'Line', 'element': 'MAL_OS1_323', 'rotation': '', 'left': '735', 'top': '135', 'height': '30', 'width': '10', 'x1': 735, 'y1': 135, 'x2': 735, 'y2': 165, 'direction': 'V', 'point1': {}}
# shape637 {'type': 'Line', 'element': 'MAL_OS1_323', 'rotation': '', 'left': '735', 'top': '175', 'height': '30', 'width': '10', 'x1': 735, 'y1': 175, 'x2': 735, 'y2': 205, 'direction': 'V', 'point1': {}}
# shape350 {'type': 'Line', 'element': 'MAL_OS1_323', 'rotation': '', 'left': '680', 'top': '90', 'height': '15', 'width': '55', 'x1': 680, 'y1': 90, 'x2': 735, 'y2': 90, 'direction': 'H', 'point1': {'shape465': {'distance': 5.0, 'point': '2'}}}
# shape638 {'type': 'Line', 'element': 'MAL_OS1_323', 'rotation': '', 'left': '735', 'top': '215', 'height': '55', 'width': '10', 'x1': 735, 'y1': 215, 'x2': 735, 'y2': 270, 'direction': 'V', 'point1': {}}
# shape655 {'type': 'Line', 'element': 'MAL_OS1_321', 'rotation': '', 'left': '770', 'top': '130', 'height': '35', 'width': '10', 'x1': 770, 'y1': 130, 'x2': 770, 'y2': 165, 'direction': 'V', 'point1': {'shape347': {'distance': 0.0, 'point': '1'}, 'shape352': {'distance': 0.0, 'point': '2'}}}
# shape352 {'type': 'Line', 'element': 'MAL_OS1_321', 'rotation': '', 'left': '680', 'top': '130', 'height': '15', 'width': '90', 'x1': 680, 'y1': 130, 'x2': 770, 'y2': 130, 'direction': 'H', 'point1': {'shape475': {'distance': 5.0, 'point': '2'}}}
# shape672 {'type': 'Line', 'element': 'MAL_OS1_321', 'rotation': '', 'left': '770', 'top': '175', 'height': '30', 'width': '10', 'x1': 770, 'y1': 175, 'x2': 770, 'y2': 205, 'direction': 'V', 'point1': {}}
# shape673 {'type': 'Line', 'element': 'MAL_OS1_321', 'rotation': '', 'left': '770', 'top': '215', 'height': '85', 'width': '10', 'x1': 770, 'y1': 215, 'x2': 770, 'y2': 300, 'direction': 'V', 'point1': {}}
# shape674 {'type': 'Line', 'element': 'MAL_OS1_326', 'rotation': '', 'left': '805', 'top': '170', 'height': '35', 'width': '10', 'x1': 805, 'y1': 170, 'x2': 805, 'y2': 205, 'direction': 'V', 'point1': {'shape348': {'distance': 0.0, 'point': '1'}, 'shape353': {'distance': 0.0, 'point': '2'}}}
# shape675 {'type': 'Line', 'element': 'MAL_OS1_326', 'rotation': '', 'left': '805', 'top': '215', 'height': '115', 'width': '10', 'x1': 805, 'y1': 215, 'x2': 805, 'y2': 330, 'direction': 'V', 'point1': {}}
# shape676 {'type': 'Line', 'element': 'MAL_OS1_327', 'rotation': '', 'left': '840', 'top': '210', 'height': '150', 'width': '10', 'x1': 840, 'y1': 210, 'x2': 840, 'y2': 360, 'direction': 'V', 'point1': {'shape349': {'distance': 0.0, 'point': '2'}, 'shape354': {'distance': 0.0, 'point': '1'}}}
# shape353 {'type': 'Line', 'element': 'MAL_OS1_326', 'rotation': '', 'left': '680', 'top': '170', 'height': '15', 'width': '125', 'x1': 680, 'y1': 170, 'x2': 805, 'y2': 170, 'direction': 'H', 'point1': {'shape483': {'distance': 5.0, 'point': '2'}}}
# shape354 {'type': 'Line', 'element': 'MAL_OS1_327', 'rotation': '', 'left': '840', 'top': '210', 'height': '15', 'width': '110', 'x1': 840, 'y1': 210, 'x2': 950, 'y2': 210, 'direction': 'H', 'point1': {'shape349': {'distance': 0.0, 'point': '2'}, 'shape676': {'distance': 0.0, 'point': '1'}}}
# shape677 {'type': 'Line', 'element': 'MAL_OS1_220', 'rotation': '', 'left': '435', 'top': '130', 'height': '50', 'width': '10', 'x1': 435, 'y1': 130, 'x2': 435, 'y2': 180, 'direction': 'V', 'point1': {'shape355': {'distance': 0.0, 'point': '1'}, 'shape383': {'distance': 0.0, 'point': '2'}}}
# shape355 {'type': 'Line', 'element': 'MAL_OS1_220', 'rotation': '', 'left': '435', 'top': '130', 'height': '15', 'width': '225', 'x1': 435, 'y1': 130, 'x2': 660, 'y2': 130, 'direction': 'H', 'point1': {'shape677': {'distance': 0.0, 'point': '1'}, 'shape383': {'distance': 0.0, 'point': '2'}}}
# shape678 {'type': 'Line', 'element': 'MAL_OS1_230', 'rotation': '', 'left': '480', 'top': '170', 'height': '130', 'width': '10', 'x1': 480, 'y1': 170, 'x2': 480, 'y2': 300, 'direction': 'V', 'point1': {'shape356': {'distance': 0.0, 'point': '1'}}}
# shape356 {'type': 'Line', 'element': 'MAL_OS1_230', 'rotation': '', 'left': '480', 'top': '170', 'height': '15', 'width': '180', 'x1': 480, 'y1': 170, 'x2': 660, 'y2': 170, 'direction': 'H', 'point1': {'shape678': {'distance': 0.0, 'point': '1'}}}
# shape679 {'type': 'Line', 'element': 'MAL_OS1_246', 'rotation': '', 'left': '530', 'top': '210', 'height': '195', 'width': '10', 'x1': 530, 'y1': 210, 'x2': 530, 'y2': 405, 'direction': 'V', 'point1': {'shape357': {'distance': 0.0, 'point': '1'}}}
# shape357 {'type': 'Line', 'element': 'MAL_OS1_246', 'rotation': '', 'left': '530', 'top': '210', 'height': '15', 'width': '130', 'x1': 530, 'y1': 210, 'x2': 660, 'y2': 210, 'direction': 'H', 'point1': {'shape679': {'distance': 0.0, 'point': '1'}}}
# shape589 {'type': 'Line', 'element': 'MAL_OS1_368', 'rotation': '', 'left': '920', 'top': '330', 'height': '30', 'width': '10', 'x1': 920, 'y1': 330, 'x2': 920, 'y2': 360, 'direction': 'V', 'point1': {'shape361': {'distance': 0.0, 'point': '2'}, 'shape590': {'distance': 0.0, 'point': '2'}}}
# shape358 {'type': 'Line', 'element': 'MAL_OS1_327', 'rotation': '', 'left': '840', 'top': '360', 'height': '15', 'width': '30', 'x1': 840, 'y1': 360, 'x2': 870, 'y2': 360, 'direction': 'H', 'point1': {'shape676': {'distance': 0.0, 'point': '2'}, 'shape373': {'distance': 0.0, 'point': '2'}}}
# shape359 {'type': 'Line', 'element': 'MAL_OS1_368', 'rotation': '', 'left': '890', 'top': '360', 'height': '15', 'width': '30', 'x1': 890, 'y1': 360, 'x2': 920, 'y2': 360, 'direction': 'H', 'point1': {'shape485': {'distance': 5.0, 'point': '2'}}}
# shape360 {'type': 'Line', 'element': 'MAL_OS1_326', 'rotation': '', 'left': '845', 'top': '330', 'height': '15', 'width': '25', 'x1': 845, 'y1': 330, 'x2': 870, 'y2': 330, 'direction': 'H', 'point1': {}}
# shape361 {'type': 'Line', 'element': 'MAL_OS1_368', 'rotation': '', 'left': '890', 'top': '330', 'height': '15', 'width': '30', 'x1': 890, 'y1': 330, 'x2': 920, 'y2': 330, 'direction': 'H', 'point1': {'shape486': {'distance': 5.0, 'point': '2'}}}
# shape362 {'type': 'Line', 'element': 'MAL_OS1_321', 'rotation': '', 'left': '845', 'top': '300', 'height': '15', 'width': '25', 'x1': 845, 'y1': 300, 'x2': 870, 'y2': 300, 'direction': 'H', 'point1': {}}
# shape363 {'type': 'Line', 'element': 'MAL_OS1_368', 'rotation': '', 'left': '890', 'top': '300', 'height': '15', 'width': '30', 'x1': 890, 'y1': 300, 'x2': 920, 'y2': 300, 'direction': 'H', 'point1': {'shape487': {'distance': 5.0, 'point': '2'}}}
# shape364 {'type': 'Line', 'element': 'MAL_OS1_323', 'rotation': '', 'left': '845', 'top': '270', 'height': '15', 'width': '25', 'x1': 845, 'y1': 270, 'x2': 870, 'y2': 270, 'direction': 'H', 'point1': {}}
# shape365 {'type': 'Line', 'element': 'MAL_OS1_368', 'rotation': '', 'left': '890', 'top': '270', 'height': '15', 'width': '30', 'x1': 890, 'y1': 270, 'x2': 920, 'y2': 270, 'direction': 'H', 'point1': {'shape488': {'distance': 5.0, 'point': '2'}}}
# shape590 {'type': 'Line', 'element': 'MAL_OS1_368', 'rotation': '', 'left': '920', 'top': '300', 'height': '30', 'width': '10', 'x1': 920, 'y1': 300, 'x2': 920, 'y2': 330, 'direction': 'V', 'point1': {'shape363': {'distance': 0.0, 'point': '2'}, 'shape591': {'distance': 0.0, 'point': '2'}}}
# shape591 {'type': 'Line', 'element': 'MAL_OS1_368', 'rotation': '', 'left': '920', 'top': '270', 'height': '30', 'width': '10', 'x1': 920, 'y1': 270, 'x2': 920, 'y2': 300, 'direction': 'V', 'point1': {'shape365': {'distance': 0.0, 'point': '2'}}}
# shape366 {'type': 'Line', 'element': 'MAL_OS1_326', 'rotation': '', 'left': '805', 'top': '330', 'height': '15', 'width': '30', 'x1': 805, 'y1': 330, 'x2': 835, 'y2': 330, 'direction': 'H', 'point1': {'shape675': {'distance': 0.0, 'point': '2'}, 'shape375': {'distance': 0.0, 'point': '2'}}}
# shape367 {'type': 'Line', 'element': 'MAL_OS1_321', 'rotation': '', 'left': '810', 'top': '300', 'height': '15', 'width': '25', 'x1': 810, 'y1': 300, 'x2': 835, 'y2': 300, 'direction': 'H', 'point1': {}}
# shape368 {'type': 'Line', 'element': 'MAL_OS1_321', 'rotation': '', 'left': '770', 'top': '300', 'height': '15', 'width': '30', 'x1': 770, 'y1': 300, 'x2': 800, 'y2': 300, 'direction': 'H', 'point1': {'shape673': {'distance': 0.0, 'point': '2'}}}
# shape369 {'type': 'Line', 'element': 'MAL_OS1_323', 'rotation': '', 'left': '810', 'top': '270', 'height': '15', 'width': '25', 'x1': 810, 'y1': 270, 'x2': 835, 'y2': 270, 'direction': 'H', 'point1': {}}
# shape370 {'type': 'Line', 'element': 'MAL_OS1_323', 'rotation': '', 'left': '775', 'top': '270', 'height': '15', 'width': '25', 'x1': 775, 'y1': 270, 'x2': 800, 'y2': 270, 'direction': 'H', 'point1': {}}
# shape372 {'type': 'Line', 'element': 'MAL_OS1_323', 'rotation': '', 'left': '735', 'top': '270', 'height': '15', 'width': '30', 'x1': 735, 'y1': 270, 'x2': 765, 'y2': 270, 'direction': 'H', 'point1': {'shape638': {'distance': 0.0, 'point': '2'}, 'shape376': {'distance': 0.0, 'point': '2'}}}
# shape680 {'type': 'Line', 'element': 'MAL_OS1_312', 'rotation': '', 'left': '590', 'top': '360', 'height': '145', 'width': '10', 'x1': 590, 'y1': 360, 'x2': 590, 'y2': 505, 'direction': 'V', 'point1': {'shape374': {'distance': 0.0, 'point': '1'}}}
# shape373 {'type': 'Line', 'element': 'MAL_OS1_327', 'rotation': '', 'left': '795', 'top': '360', 'height': '15', 'width': '45', 'x1': 795, 'y1': 360, 'x2': 840, 'y2': 360, 'direction': 'H', 'point1': {'shape490': {'distance': 5.0, 'point': '2'}}}
# shape374 {'type': 'Line', 'element': 'MAL_OS1_312', 'rotation': '', 'left': '590', 'top': '360', 'height': '15', 'width': '185', 'x1': 590, 'y1': 360, 'x2': 775, 'y2': 360, 'direction': 'H', 'point1': {'shape680': {'distance': 0.0, 'point': '1'}}}
# shape375 {'type': 'Line', 'element': 'MAL_OS1_326', 'rotation': '', 'left': '760', 'top': '330', 'height': '15', 'width': '45', 'x1': 760, 'y1': 330, 'x2': 805, 'y2': 330, 'direction': 'H', 'point1': {'shape491': {'distance': 5.0, 'point': '2'}}}
# shape376 {'type': 'Line', 'element': 'MAL_OS1_323', 'rotation': '', 'left': '690', 'top': '270', 'height': '15', 'width': '45', 'x1': 690, 'y1': 270, 'x2': 735, 'y2': 270, 'direction': 'H', 'point1': {'shape492': {'distance': 5.0, 'point': '2'}}}
# shape682 {'type': 'Line', 'element': 'MAL_OS1_325', 'rotation': '', 'left': '920', 'top': '405', 'height': '20', 'width': '10', 'x1': 920, 'y1': 405, 'x2': 920, 'y2': 425, 'direction': 'V', 'point1': {'shape681': {'distance': 5.0, 'point': '2'}}}
# shape377 {'type': 'Line', 'element': 'MAL_OS1_325', 'rotation': '', 'left': '890', 'top': '425', 'height': '15', 'width': '30', 'x1': 890, 'y1': 425, 'x2': 920, 'y2': 425, 'direction': 'H', 'point1': {'shape689': {'distance': 5.0, 'point': '2'}}}
# shape378 {'type': 'Line', 'element': 'MAL_OS1_325', 'rotation': '', 'left': '805', 'top': '455', 'height': '10', 'width': '30', 'x1': 805, 'y1': 455, 'x2': 835, 'y2': 455, 'direction': 'H', 'point1': {'shape690': {'distance': 5.0, 'point': '2'}}}
# shape379 {'type': 'Line', 'element': 'MAL_OS1_325', 'rotation': '', 'left': '805', 'top': '500', 'height': '10', 'width': '30', 'x1': 805, 'y1': 500, 'x2': 835, 'y2': 500, 'direction': 'H', 'point1': {'shape691': {'distance': 5.0, 'point': '2'}}}
# shape683 {'type': 'Line', 'element': 'MAL_OS1_325', 'rotation': '', 'left': '920', 'top': '425', 'height': '30', 'width': '10', 'x1': 920, 'y1': 425, 'x2': 920, 'y2': 455, 'direction': 'V', 'point1': {'shape682': {'distance': 0.0, 'point': '2'}, 'shape377': {'distance': 0.0, 'point': '2'}}}
# shape684 {'type': 'Line', 'element': 'MAL_OS1_325', 'rotation': '', 'left': '835', 'top': '455', 'height': '45', 'width': '10', 'x1': 835, 'y1': 455, 'x2': 835, 'y2': 500, 'direction': 'V', 'point1': {'shape378': {'distance': 0.0, 'point': '2'}, 'shape382': {'distance': 0.0, 'point': '1'}}}
# shape380 {'type': 'Line', 'element': 'MAL_OS1_2427', 'rotation': '', 'left': '885', 'top': '590', 'height': '15', 'width': '40', 'x1': 885, 'y1': 590, 'x2': 925, 'y2': 590, 'direction': 'H', 'point1': {'shape649': {'distance': 5.0, 'point': '2'}}}
# shape686 {'type': 'Line', 'element': 'MAL_OS1_325', 'rotation': '', 'left': '835', 'top': '590', 'height': '10', 'width': '30', 'x1': 835, 'y1': 590, 'x2': 865, 'y2': 590, 'direction': 'H', 'point1': {'shape651': {'distance': 0.0, 'point': '2'}}}
# shape382 {'type': 'Line', 'element': 'MAL_OS1_325', 'rotation': '', 'left': '835', 'top': '455', 'height': '10', 'width': '85', 'x1': 835, 'y1': 455, 'x2': 920, 'y2': 455, 'direction': 'H', 'point1': {'shape378': {'distance': 0.0, 'point': '2'}, 'shape684': {'distance': 0.0, 'point': '1'}}}
# shape692 {'type': 'Line', 'element': 'MAL_OS1_491', 'rotation': '', 'left': '760', 'top': '695', 'height': '10', 'width': '105', 'x1': 760, 'y1': 695, 'x2': 865, 'y2': 695, 'direction': 'H', 'point1': {'shape693': {'distance': 0.0, 'point': '1'}}}
# shape693 {'type': 'Line', 'element': 'MAL_OS1_491', 'rotation': '', 'left': '760', 'top': '695', 'height': '35', 'width': '10', 'x1': 760, 'y1': 695, 'x2': 760, 'y2': 730, 'direction': 'V', 'point1': {'shape692': {'distance': 0.0, 'point': '1'}}}
# shape383 {'type': 'Line', 'element': 'MAL_OS1_220', 'rotation': '', 'left': '405', 'top': '130', 'height': '15', 'width': '30', 'x1': 405, 'y1': 130, 'x2': 435, 'y2': 130, 'direction': 'H', 'point1': {'shape493': {'distance': 5.0, 'point': '2'}}}
# shape695 {'type': 'Line', 'element': 'MAL_OS1_2430', 'rotation': '', 'left': '885', 'top': '695', 'height': '10', 'width': '45', 'x1': 885, 'y1': 695, 'x2': 930, 'y2': 695, 'direction': 'H', 'point1': {'shape640': {'distance': 5.0, 'point': '2'}}}
# shape697 {'type': 'Line', 'element': 'MAL_OS1_2430', 'rotation': '', 'left': '885', 'top': '660', 'height': '10', 'width': '40', 'x1': 885, 'y1': 660, 'x2': 925, 'y2': 660, 'direction': 'H', 'point1': {'shape641': {'distance': 5.0, 'point': '2'}}}
# shape698 {'type': 'Line', 'element': 'MAL_OS1_483', 'rotation': '', 'left': '760', 'top': '630', 'height': '30', 'width': '10', 'x1': 760, 'y1': 630, 'x2': 760, 'y2': 660, 'direction': 'V', 'point1': {'shape627': {'distance': 0.0, 'point': '2'}}}
# shape699 {'type': 'Line', 'element': 'MAL_OS1_483', 'rotation': '', 'left': '760', 'top': '660', 'height': '10', 'width': '105', 'x1': 760, 'y1': 660, 'x2': 865, 'y2': 660, 'direction': 'H', 'point1': {'shape698': {'distance': 0.0, 'point': '2'}}}
# shape592 {'type': 'Line', 'element': 'MAL_OS1_2424', 'rotation': '', 'left': '1390', 'top': '575', 'height': '30', 'width': '10', 'x1': 1390, 'y1': 575, 'x2': 1390, 'y2': 605, 'direction': 'V', 'point1': {'shape401': {'distance': 0.0, 'point': '2'}, 'shape402': {'distance': 0.0, 'point': '1'}}}
# shape384 {'type': 'Line', 'element': 'MAL_OS1_2424', 'rotation': '', 'left': '1390', 'top': '605', 'height': '10', 'width': '50', 'x1': 1390, 'y1': 605, 'x2': 1440, 'y2': 605, 'direction': 'H', 'point1': {'shape592': {'distance': 0.0, 'point': '2'}}}
# shape402 {'type': 'Line', 'element': 'MAL_OS1_2424', 'rotation': '', 'left': '1390', 'top': '575', 'height': '10', 'width': '50', 'x1': 1390, 'y1': 575, 'x2': 1440, 'y2': 575, 'direction': 'H', 'point1': {'shape401': {'distance': 0.0, 'point': '2'}, 'shape592': {'distance': 0.0, 'point': '1'}}}
# shape275 {'type': 'Line', 'element': 'MAL_OS1_312', 'rotation': '', 'left': '520', 'top': '505', 'height': '15', 'width': '70', 'x1': 520, 'y1': 505, 'x2': 590, 'y2': 505, 'direction': 'H', 'point1': {'shape494': {'distance': 5.0, 'point': '2'}}}

# %%
elem = {}
for i in result:
    if result[i]['element'] != '':
        if result[i]['element'] not in elem:
            elem[result[i]['element']] = {i:result[i]}
        else:
            elem[result[i]['element']].update({i:result[i]})
elem
# Out:
# {'MAL_OS1_202': {'shape111': {'element': 'MAL_OS1_202',
#    'height': '10',
#    'left': '130',
#    'rotation': '',
#    'top': '505',
#    'type': 'Line',
#    'width': '75'},
#   'shape254': {'element': 'MAL_OS1_202',
#    'height': '10',
#    'left': '225',
#    'rotation': '',
#    'top': '505',
#    'type': 'Line',
#    'width': '275'}},
#  'MAL_OS1_218': {'shape104': {'element': 'MAL_OS1_218',
#    'height': '10',
#    'left': '130',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '75'},
#   'shape223': {'element': 'MAL_OS1_218',
#    'height': '10',
#    'left': '225',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '435'}},
#  'MAL_OS1_220': {'shape108': {'element': 'MAL_OS1_220',
#    'height': '10',
#    'left': '130',
#    'rotation': '',
#    'top': '180',
#    'type': 'Line',
#    'width': '75'},
#   'shape232': {'element': 'MAL_OS1_220',
#    'height': '10',
#    'left': '225',
#    'rotation': '',
#    'top': '180',
#    'type': 'Line',
#    'width': '210'},
#   'shape355': {'element': 'MAL_OS1_220',
#    'height': '15',
#    'left': '435',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '225'},
#   'shape383': {'element': 'MAL_OS1_220',
#    'height': '15',
#    'left': '405',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '30'},
#   'shape677': {'element': 'MAL_OS1_220',
#    'height': '50',
#    'left': '435',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_230': {'shape109': {'element': 'MAL_OS1_230',
#    'height': '10',
#    'left': '130',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '75'},
#   'shape240': {'element': 'MAL_OS1_230',
#    'height': '10',
#    'left': '225',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '255'},
#   'shape356': {'element': 'MAL_OS1_230',
#    'height': '15',
#    'left': '480',
#    'rotation': '',
#    'top': '170',
#    'type': 'Line',
#    'width': '180'},
#   'shape678': {'element': 'MAL_OS1_230',
#    'height': '130',
#    'left': '480',
#    'rotation': '',
#    'top': '170',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_232': {'shape110': {'element': 'MAL_OS1_232',
#    'height': '10',
#    'left': '130',
#    'rotation': '',
#    'top': '405',
#    'type': 'Line',
#    'width': '75'},
#   'shape250': {'element': 'MAL_OS1_232',
#    'height': '15',
#    'left': '225',
#    'rotation': '',
#    'top': '405',
#    'type': 'Line',
#    'width': '145'}},
#  'MAL_OS1_2424': {'shape384': {'element': 'MAL_OS1_2424',
#    'height': '10',
#    'left': '1390',
#    'rotation': '',
#    'top': '605',
#    'type': 'Line',
#    'width': '50'},
#   'shape398': {'element': 'MAL_OS1_2424',
#    'height': '10',
#    'left': '1220',
#    'rotation': '',
#    'top': '545',
#    'type': 'Line',
#    'width': '120'},
#   'shape400': {'element': 'MAL_OS1_2424',
#    'height': '10',
#    'left': '1225',
#    'rotation': '',
#    'top': '575',
#    'type': 'Line',
#    'width': '115'},
#   'shape401': {'element': 'MAL_OS1_2424',
#    'height': '10',
#    'left': '1340',
#    'rotation': '',
#    'top': '575',
#    'type': 'Line',
#    'width': '50'},
#   'shape402': {'element': 'MAL_OS1_2424',
#    'height': '10',
#    'left': '1390',
#    'rotation': '',
#    'top': '575',
#    'type': 'Line',
#    'width': '50'},
#   'shape577': {'element': 'MAL_OS1_2424',
#    'height': '30',
#    'left': '1340',
#    'rotation': '',
#    'top': '545',
#    'type': 'Line',
#    'width': '5'},
#   'shape592': {'element': 'MAL_OS1_2424',
#    'height': '30',
#    'left': '1390',
#    'rotation': '',
#    'top': '575',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_2426': {'shape396': {'element': 'MAL_OS1_2426',
#    'height': '10',
#    'left': '1080',
#    'rotation': '',
#    'top': '590',
#    'type': 'Line',
#    'width': '50'},
#   'shape397': {'element': 'MAL_OS1_2426',
#    'height': '10',
#    'left': '1080',
#    'rotation': '',
#    'top': '545',
#    'type': 'Line',
#    'width': '120'},
#   'shape399': {'element': 'MAL_OS1_2426',
#    'height': '10',
#    'left': '990',
#    'rotation': '',
#    'top': '590',
#    'type': 'Line',
#    'width': '90'},
#   'shape571': {'element': 'MAL_OS1_2426',
#    'height': '45',
#    'left': '1080',
#    'rotation': '',
#    'top': '545',
#    'type': 'Line',
#    'width': '10'},
#   'shape584': {'element': 'MAL_OS1_2426',
#    'height': '20',
#    'left': '990',
#    'rotation': '',
#    'top': '570',
#    'type': 'Line',
#    'width': '15'},
#   'shape643': {'element': 'MAL_OS1_2426',
#    'height': '10',
#    'left': '945',
#    'rotation': '',
#    'top': '695',
#    'type': 'Line',
#    'width': '45'},
#   'shape644': {'element': 'MAL_OS1_2426',
#    'height': '10',
#    'left': '945',
#    'rotation': '',
#    'top': '660',
#    'type': 'Line',
#    'width': '45'},
#   'shape645': {'element': 'MAL_OS1_2426',
#    'height': '10',
#    'left': '885',
#    'rotation': '',
#    'top': '625',
#    'type': 'Line',
#    'width': '105'},
#   'shape646': {'element': 'MAL_OS1_2426',
#    'height': '35',
#    'left': '990',
#    'rotation': '',
#    'top': '590',
#    'type': 'Line',
#    'width': '10'},
#   'shape647': {'element': 'MAL_OS1_2426',
#    'height': '35',
#    'left': '990',
#    'rotation': '',
#    'top': '625',
#    'type': 'Line',
#    'width': '10'},
#   'shape648': {'element': 'MAL_OS1_2426',
#    'height': '35',
#    'left': '990',
#    'rotation': '',
#    'top': '660',
#    'type': 'Line',
#    'width': '10'},
#   'shape668': {'element': 'MAL_OS1_2426',
#    'height': '10',
#    'left': '945',
#    'rotation': '',
#    'top': '590',
#    'type': 'Line',
#    'width': '45'}},
#  'MAL_OS1_2427': {'shape380': {'element': 'MAL_OS1_2427',
#    'height': '15',
#    'left': '885',
#    'rotation': '',
#    'top': '590',
#    'type': 'Line',
#    'width': '40'}},
#  'MAL_OS1_2428': {'shape395': {'element': 'MAL_OS1_2428',
#    'height': '10',
#    'left': '1150',
#    'rotation': '',
#    'top': '590',
#    'type': 'Line',
#    'width': '50'}},
#  'MAL_OS1_2430': {'shape695': {'element': 'MAL_OS1_2430',
#    'height': '10',
#    'left': '885',
#    'rotation': '',
#    'top': '695',
#    'type': 'Line',
#    'width': '45'},
#   'shape697': {'element': 'MAL_OS1_2430',
#    'height': '10',
#    'left': '885',
#    'rotation': '',
#    'top': '660',
#    'type': 'Line',
#    'width': '40'}},
#  'MAL_OS1_2431': {'shape303': {'element': 'MAL_OS1_2431',
#    'height': '10',
#    'left': '1080',
#    'rotation': '',
#    'top': '440',
#    'type': 'Line',
#    'width': '50'},
#   'shape304': {'element': 'MAL_OS1_2431',
#    'height': '10',
#    'left': '1080',
#    'rotation': '',
#    'top': '395',
#    'type': 'Line',
#    'width': '120'},
#   'shape334': {'element': 'MAL_OS1_2431',
#    'height': '10',
#    'left': '990',
#    'rotation': '',
#    'top': '440',
#    'type': 'Line',
#    'width': '90'},
#   'shape371': {'element': 'MAL_OS1_2431',
#    'height': '10',
#    'left': '960',
#    'rotation': '',
#    'top': '475',
#    'type': 'Line',
#    'width': '30'},
#   'shape393': {'element': 'MAL_OS1_2431',
#    'height': '10',
#    'left': '960',
#    'rotation': '',
#    'top': '500',
#    'type': 'Line',
#    'width': '30'},
#   'shape394': {'element': 'MAL_OS1_2431',
#    'height': '10',
#    'left': '960',
#    'rotation': '',
#    'top': '525',
#    'type': 'Line',
#    'width': '30'},
#   'shape563': {'element': 'MAL_OS1_2431',
#    'height': '45',
#    'left': '1080',
#    'rotation': '',
#    'top': '395',
#    'type': 'Line',
#    'width': '10'},
#   'shape566': {'element': 'MAL_OS1_2431',
#    'height': '35',
#    'left': '990',
#    'rotation': '',
#    'top': '440',
#    'type': 'Line',
#    'width': '10'},
#   'shape568': {'element': 'MAL_OS1_2431',
#    'height': '25',
#    'left': '990',
#    'rotation': '',
#    'top': '475',
#    'type': 'Line',
#    'width': '10'},
#   'shape569': {'element': 'MAL_OS1_2431',
#    'height': '25',
#    'left': '990',
#    'rotation': '',
#    'top': '500',
#    'type': 'Line',
#    'width': '10'},
#   'shape570': {'element': 'MAL_OS1_2431',
#    'height': '25',
#    'left': '990',
#    'rotation': '',
#    'top': '525',
#    'type': 'Line',
#    'width': '15'}},
#  'MAL_OS1_2432': {'shape301': {'element': 'MAL_OS1_2432',
#    'height': '10',
#    'left': '1150',
#    'rotation': '',
#    'top': '440',
#    'type': 'Line',
#    'width': '50'}},
#  'MAL_OS1_2433': {'shape305': {'element': 'MAL_OS1_2433',
#    'height': '10',
#    'left': '1220',
#    'rotation': '',
#    'top': '395',
#    'type': 'Line',
#    'width': '120'},
#   'shape314': {'element': 'MAL_OS1_2433',
#    'height': '10',
#    'left': '1220',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '120'},
#   'shape315': {'element': 'MAL_OS1_2433',
#    'height': '10',
#    'left': '1340',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '50'},
#   'shape329': {'element': 'MAL_OS1_2433',
#    'height': '10',
#    'left': '1390',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '50'},
#   'shape330': {'element': 'MAL_OS1_2433',
#    'height': '10',
#    'left': '1390',
#    'rotation': '',
#    'top': '455',
#    'type': 'Line',
#    'width': '50'},
#   'shape564': {'element': 'MAL_OS1_2433',
#    'height': '30',
#    'left': '1340',
#    'rotation': '',
#    'top': '395',
#    'type': 'Line',
#    'width': '5'},
#   'shape565': {'element': 'MAL_OS1_2433',
#    'height': '30',
#    'left': '1390',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_246': {'shape357': {'element': 'MAL_OS1_246',
#    'height': '15',
#    'left': '530',
#    'rotation': '',
#    'top': '210',
#    'type': 'Line',
#    'width': '130'},
#   'shape523': {'element': 'MAL_OS1_246',
#    'height': '10',
#    'left': '390',
#    'rotation': '',
#    'top': '405',
#    'type': 'Line',
#    'width': '140'},
#   'shape679': {'element': 'MAL_OS1_246',
#    'height': '195',
#    'left': '530',
#    'rotation': '',
#    'top': '210',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_270': {'shape286': {'element': 'MAL_OS1_270',
#    'height': '10',
#    'left': '1225',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '50'}},
#  'MAL_OS1_271': {'shape281': {'element': 'MAL_OS1_271',
#    'height': '10',
#    'left': '1150',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '50'}},
#  'MAL_OS1_272': {'shape282': {'element': 'MAL_OS1_272',
#    'height': '10',
#    'left': '1150',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '50'}},
#  'MAL_OS1_273': {'shape287': {'element': 'MAL_OS1_273',
#    'height': '10',
#    'left': '1225',
#    'rotation': '',
#    'top': '285',
#    'type': 'Line',
#    'width': '50'}},
#  'MAL_OS1_286': {'shape326': {'element': 'MAL_OS1_286',
#    'height': '10',
#    'left': '1220',
#    'rotation': '',
#    'top': '645',
#    'type': 'Line',
#    'width': '45'},
#   'shape327': {'element': 'MAL_OS1_286',
#    'height': '10',
#    'left': '1225',
#    'rotation': '',
#    'top': '675',
#    'type': 'Line',
#    'width': '40'},
#   'shape328': {'element': 'MAL_OS1_286',
#    'height': '10',
#    'left': '1270',
#    'rotation': '',
#    'top': '675',
#    'type': 'Line',
#    'width': '110'},
#   'shape576': {'element': 'MAL_OS1_286',
#    'height': '30',
#    'left': '1265',
#    'rotation': '',
#    'top': '645',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_287': {'shape323': {'element': 'MAL_OS1_287',
#    'height': '10',
#    'left': '1155',
#    'rotation': '',
#    'top': '690',
#    'type': 'Line',
#    'width': '45'},
#   'shape324': {'element': 'MAL_OS1_287',
#    'height': '10',
#    'left': '1110',
#    'rotation': '',
#    'top': '690',
#    'type': 'Line',
#    'width': '45'},
#   'shape325': {'element': 'MAL_OS1_287',
#    'height': '10',
#    'left': '1155',
#    'rotation': '',
#    'top': '645',
#    'type': 'Line',
#    'width': '45'},
#   'shape575': {'element': 'MAL_OS1_287',
#    'height': '45',
#    'left': '1155',
#    'rotation': '',
#    'top': '645',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_288': {'shape319': {'element': 'MAL_OS1_288',
#    'height': '10',
#    'left': '1220',
#    'rotation': '',
#    'top': '800',
#    'type': 'Line',
#    'width': '45'},
#   'shape320': {'element': 'MAL_OS1_288',
#    'height': '10',
#    'left': '1225',
#    'rotation': '',
#    'top': '830',
#    'type': 'Line',
#    'width': '40'},
#   'shape321': {'element': 'MAL_OS1_288',
#    'height': '10',
#    'left': '1265',
#    'rotation': '',
#    'top': '830',
#    'type': 'Line',
#    'width': '115'},
#   'shape573': {'element': 'MAL_OS1_288',
#    'height': '30',
#    'left': '1265',
#    'rotation': '',
#    'top': '800',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_289': {'shape312': {'element': 'MAL_OS1_289',
#    'height': '10',
#    'left': '1155',
#    'rotation': '',
#    'top': '845',
#    'type': 'Line',
#    'width': '45'},
#   'shape313': {'element': 'MAL_OS1_289',
#    'height': '10',
#    'left': '1110',
#    'rotation': '',
#    'top': '845',
#    'type': 'Line',
#    'width': '45'},
#   'shape318': {'element': 'MAL_OS1_289',
#    'height': '10',
#    'left': '1155',
#    'rotation': '',
#    'top': '800',
#    'type': 'Line',
#    'width': '45'},
#   'shape572': {'element': 'MAL_OS1_289',
#    'height': '45',
#    'left': '1155',
#    'rotation': '',
#    'top': '800',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_312': {'shape255': {'element': 'MAL_OS1_312',
#    'height': '15',
#    'left': '590',
#    'rotation': '',
#    'top': '505',
#    'type': 'Line',
#    'width': '35'},
#   'shape275': {'element': 'MAL_OS1_312',
#    'height': '15',
#    'left': '520',
#    'rotation': '',
#    'top': '505',
#    'type': 'Line',
#    'width': '70'},
#   'shape374': {'element': 'MAL_OS1_312',
#    'height': '15',
#    'left': '590',
#    'rotation': '',
#    'top': '360',
#    'type': 'Line',
#    'width': '185'},
#   'shape680': {'element': 'MAL_OS1_312',
#    'height': '145',
#    'left': '590',
#    'rotation': '',
#    'top': '360',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_313': {'shape288': {'element': 'MAL_OS1_313',
#    'height': '10',
#    'left': '1295',
#    'rotation': '',
#    'top': '285',
#    'type': 'Line',
#    'width': '50'},
#   'shape302': {'element': 'MAL_OS1_313',
#    'height': '10',
#    'left': '1295',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '50'},
#   'shape306': {'element': 'MAL_OS1_313',
#    'height': '10',
#    'left': '1345',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '50'},
#   'shape331': {'element': 'MAL_OS1_313',
#    'height': '10',
#    'left': '1345',
#    'rotation': '',
#    'top': '140',
#    'type': 'Line',
#    'width': '50'},
#   'shape332': {'element': 'MAL_OS1_313',
#    'height': '10',
#    'left': '1345',
#    'rotation': '',
#    'top': '220',
#    'type': 'Line',
#    'width': '50'},
#   'shape558': {'element': 'MAL_OS1_313',
#    'height': '60',
#    'left': '1345',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '15'},
#   'shape559': {'element': 'MAL_OS1_313',
#    'height': '80',
#    'left': '1345',
#    'rotation': '',
#    'top': '140',
#    'type': 'Line',
#    'width': '15'},
#   'shape578': {'element': 'MAL_OS1_313',
#    'height': '65',
#    'left': '1345',
#    'rotation': '',
#    'top': '220',
#    'type': 'Line',
#    'width': '15'}},
#  'MAL_OS1_314': {'shape283': {'element': 'MAL_OS1_314',
#    'height': '15',
#    'left': '970',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '100'},
#   'shape284': {'element': 'MAL_OS1_314',
#    'height': '15',
#    'left': '1070',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '60'},
#   'shape289': {'element': 'MAL_OS1_314',
#    'height': '10',
#    'left': '1070',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '60'},
#   'shape292': {'element': 'MAL_OS1_314',
#    'height': '15',
#    'left': '970',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '100'},
#   'shape293': {'element': 'MAL_OS1_314',
#    'height': '15',
#    'left': '970',
#    'rotation': '',
#    'top': '170',
#    'type': 'Line',
#    'width': '100'},
#   'shape297': {'element': 'MAL_OS1_314',
#    'height': '15',
#    'left': '970',
#    'rotation': '',
#    'top': '210',
#    'type': 'Line',
#    'width': '100'},
#   'shape553': {'element': 'MAL_OS1_314',
#    'height': '40',
#    'left': '1070',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '10'},
#   'shape554': {'element': 'MAL_OS1_314',
#    'height': '40',
#    'left': '1070',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '10'},
#   'shape587': {'element': 'MAL_OS1_314',
#    'height': '40',
#    'left': '1070',
#    'rotation': '',
#    'top': '170',
#    'type': 'Line',
#    'width': '10'},
#   'shape588': {'element': 'MAL_OS1_314',
#    'height': '90',
#    'left': '1070',
#    'rotation': '',
#    'top': '210',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_321': {'shape347': {'element': 'MAL_OS1_321',
#    'height': '15',
#    'left': '770',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '180'},
#   'shape352': {'element': 'MAL_OS1_321',
#    'height': '15',
#    'left': '680',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '90'},
#   'shape362': {'element': 'MAL_OS1_321',
#    'height': '15',
#    'left': '845',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '25'},
#   'shape367': {'element': 'MAL_OS1_321',
#    'height': '15',
#    'left': '810',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '25'},
#   'shape368': {'element': 'MAL_OS1_321',
#    'height': '15',
#    'left': '770',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '30'},
#   'shape655': {'element': 'MAL_OS1_321',
#    'height': '35',
#    'left': '770',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '10'},
#   'shape672': {'element': 'MAL_OS1_321',
#    'height': '30',
#    'left': '770',
#    'rotation': '',
#    'top': '175',
#    'type': 'Line',
#    'width': '10'},
#   'shape673': {'element': 'MAL_OS1_321',
#    'height': '85',
#    'left': '770',
#    'rotation': '',
#    'top': '215',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_323': {'shape311': {'element': 'MAL_OS1_323',
#    'height': '15',
#    'left': '735',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '215'},
#   'shape350': {'element': 'MAL_OS1_323',
#    'height': '15',
#    'left': '680',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '55'},
#   'shape364': {'element': 'MAL_OS1_323',
#    'height': '15',
#    'left': '845',
#    'rotation': '',
#    'top': '270',
#    'type': 'Line',
#    'width': '25'},
#   'shape369': {'element': 'MAL_OS1_323',
#    'height': '15',
#    'left': '810',
#    'rotation': '',
#    'top': '270',
#    'type': 'Line',
#    'width': '25'},
#   'shape370': {'element': 'MAL_OS1_323',
#    'height': '15',
#    'left': '775',
#    'rotation': '',
#    'top': '270',
#    'type': 'Line',
#    'width': '25'},
#   'shape372': {'element': 'MAL_OS1_323',
#    'height': '15',
#    'left': '735',
#    'rotation': '',
#    'top': '270',
#    'type': 'Line',
#    'width': '30'},
#   'shape376': {'element': 'MAL_OS1_323',
#    'height': '15',
#    'left': '690',
#    'rotation': '',
#    'top': '270',
#    'type': 'Line',
#    'width': '45'},
#   'shape617': {'element': 'MAL_OS1_323',
#    'height': '35',
#    'left': '735',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '10'},
#   'shape622': {'element': 'MAL_OS1_323',
#    'height': '30',
#    'left': '735',
#    'rotation': '',
#    'top': '135',
#    'type': 'Line',
#    'width': '10'},
#   'shape637': {'element': 'MAL_OS1_323',
#    'height': '30',
#    'left': '735',
#    'rotation': '',
#    'top': '175',
#    'type': 'Line',
#    'width': '10'},
#   'shape638': {'element': 'MAL_OS1_323',
#    'height': '55',
#    'left': '735',
#    'rotation': '',
#    'top': '215',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_325': {'shape377': {'element': 'MAL_OS1_325',
#    'height': '15',
#    'left': '890',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '30'},
#   'shape378': {'element': 'MAL_OS1_325',
#    'height': '10',
#    'left': '805',
#    'rotation': '',
#    'top': '455',
#    'type': 'Line',
#    'width': '30'},
#   'shape379': {'element': 'MAL_OS1_325',
#    'height': '10',
#    'left': '805',
#    'rotation': '',
#    'top': '500',
#    'type': 'Line',
#    'width': '30'},
#   'shape382': {'element': 'MAL_OS1_325',
#    'height': '10',
#    'left': '835',
#    'rotation': '',
#    'top': '455',
#    'type': 'Line',
#    'width': '85'},
#   'shape651': {'element': 'MAL_OS1_325',
#    'height': '90',
#    'left': '835',
#    'rotation': '',
#    'top': '500',
#    'type': 'Line',
#    'width': '10'},
#   'shape682': {'element': 'MAL_OS1_325',
#    'height': '20',
#    'left': '920',
#    'rotation': '',
#    'top': '405',
#    'type': 'Line',
#    'width': '10'},
#   'shape683': {'element': 'MAL_OS1_325',
#    'height': '30',
#    'left': '920',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '10'},
#   'shape684': {'element': 'MAL_OS1_325',
#    'height': '45',
#    'left': '835',
#    'rotation': '',
#    'top': '455',
#    'type': 'Line',
#    'width': '10'},
#   'shape686': {'element': 'MAL_OS1_325',
#    'height': '10',
#    'left': '835',
#    'rotation': '',
#    'top': '590',
#    'type': 'Line',
#    'width': '30'}},
#  'MAL_OS1_326': {'shape348': {'element': 'MAL_OS1_326',
#    'height': '15',
#    'left': '805',
#    'rotation': '',
#    'top': '170',
#    'type': 'Line',
#    'width': '145'},
#   'shape353': {'element': 'MAL_OS1_326',
#    'height': '15',
#    'left': '680',
#    'rotation': '',
#    'top': '170',
#    'type': 'Line',
#    'width': '125'},
#   'shape360': {'element': 'MAL_OS1_326',
#    'height': '15',
#    'left': '845',
#    'rotation': '',
#    'top': '330',
#    'type': 'Line',
#    'width': '25'},
#   'shape366': {'element': 'MAL_OS1_326',
#    'height': '15',
#    'left': '805',
#    'rotation': '',
#    'top': '330',
#    'type': 'Line',
#    'width': '30'},
#   'shape375': {'element': 'MAL_OS1_326',
#    'height': '15',
#    'left': '760',
#    'rotation': '',
#    'top': '330',
#    'type': 'Line',
#    'width': '45'},
#   'shape674': {'element': 'MAL_OS1_326',
#    'height': '35',
#    'left': '805',
#    'rotation': '',
#    'top': '170',
#    'type': 'Line',
#    'width': '10'},
#   'shape675': {'element': 'MAL_OS1_326',
#    'height': '115',
#    'left': '805',
#    'rotation': '',
#    'top': '215',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_327': {'shape349': {'element': 'MAL_OS1_327',
#    'height': '15',
#    'left': '680',
#    'rotation': '',
#    'top': '210',
#    'type': 'Line',
#    'width': '160'},
#   'shape354': {'element': 'MAL_OS1_327',
#    'height': '15',
#    'left': '840',
#    'rotation': '',
#    'top': '210',
#    'type': 'Line',
#    'width': '110'},
#   'shape358': {'element': 'MAL_OS1_327',
#    'height': '15',
#    'left': '840',
#    'rotation': '',
#    'top': '360',
#    'type': 'Line',
#    'width': '30'},
#   'shape373': {'element': 'MAL_OS1_327',
#    'height': '15',
#    'left': '795',
#    'rotation': '',
#    'top': '360',
#    'type': 'Line',
#    'width': '45'},
#   'shape676': {'element': 'MAL_OS1_327',
#    'height': '150',
#    'left': '840',
#    'rotation': '',
#    'top': '210',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_359': {'shape390': {'element': 'MAL_OS1_359',
#    'height': '20',
#    'left': '1400',
#    'rotation': '',
#    'top': '675',
#    'type': 'Line',
#    'width': '110'},
#   'shape391': {'element': 'MAL_OS1_359',
#    'height': '20',
#    'left': '1400',
#    'rotation': '',
#    'top': '830',
#    'type': 'Line',
#    'width': '110'},
#   'shape392': {'element': 'MAL_OS1_359',
#    'height': '10',
#    'left': '1510',
#    'rotation': '',
#    'top': '830',
#    'type': 'Line',
#    'width': '275'},
#   'shape607': {'element': 'MAL_OS1_359',
#    'height': '155',
#    'left': '1510',
#    'rotation': '',
#    'top': '675',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_360': {'shape310': {'element': 'MAL_OS1_360',
#    'height': '10',
#    'left': '465',
#    'rotation': '',
#    'top': '845',
#    'type': 'Line',
#    'width': '585'},
#   'shape316': {'element': 'MAL_OS1_360',
#    'height': '10',
#    'left': '1050',
#    'rotation': '',
#    'top': '845',
#    'type': 'Line',
#    'width': '40'},
#   'shape322': {'element': 'MAL_OS1_360',
#    'height': '20',
#    'left': '1050',
#    'rotation': '',
#    'top': '690',
#    'type': 'Line',
#    'width': '40'},
#   'shape574': {'element': 'MAL_OS1_360',
#    'height': '155',
#    'left': '1050',
#    'rotation': '',
#    'top': '690',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_368': {'shape359': {'element': 'MAL_OS1_368',
#    'height': '15',
#    'left': '890',
#    'rotation': '',
#    'top': '360',
#    'type': 'Line',
#    'width': '30'},
#   'shape361': {'element': 'MAL_OS1_368',
#    'height': '15',
#    'left': '890',
#    'rotation': '',
#    'top': '330',
#    'type': 'Line',
#    'width': '30'},
#   'shape363': {'element': 'MAL_OS1_368',
#    'height': '15',
#    'left': '890',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '30'},
#   'shape365': {'element': 'MAL_OS1_368',
#    'height': '15',
#    'left': '890',
#    'rotation': '',
#    'top': '270',
#    'type': 'Line',
#    'width': '30'},
#   'shape589': {'element': 'MAL_OS1_368',
#    'height': '30',
#    'left': '920',
#    'rotation': '',
#    'top': '330',
#    'type': 'Line',
#    'width': '10'},
#   'shape590': {'element': 'MAL_OS1_368',
#    'height': '30',
#    'left': '920',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '10'},
#   'shape591': {'element': 'MAL_OS1_368',
#    'height': '30',
#    'left': '920',
#    'rotation': '',
#    'top': '270',
#    'type': 'Line',
#    'width': '10'},
#   'shape619': {'element': 'MAL_OS1_368',
#    'height': '25',
#    'left': '920',
#    'rotation': '',
#    'top': '360',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_376': {'shape307': {'element': 'MAL_OS1_376',
#    'height': '10',
#    'left': '1415',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '50'},
#   'shape317': {'element': 'MAL_OS1_376',
#    'height': '10',
#    'left': '1465',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '120'},
#   'shape333': {'element': 'MAL_OS1_376',
#    'height': '10',
#    'left': '1465',
#    'rotation': '',
#    'top': '110',
#    'type': 'Line',
#    'width': '30'},
#   'shape579': {'element': 'MAL_OS1_376',
#    'height': '30',
#    'left': '1465',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '15'}},
#  'MAL_OS1_417': {'shape115': {'element': 'MAL_OS1_417',
#    'height': '10',
#    'left': '125',
#    'rotation': '',
#    'top': '845',
#    'type': 'Line',
#    'width': '80'},
#   'shape269': {'element': 'MAL_OS1_417',
#    'height': '15',
#    'left': '225',
#    'rotation': '',
#    'top': '845',
#    'type': 'Line',
#    'width': '170'},
#   'shape274': {'element': 'MAL_OS1_417',
#    'height': '10',
#    'left': '395',
#    'rotation': '',
#    'top': '845',
#    'type': 'Line',
#    'width': '50'},
#   'shape276': {'element': 'MAL_OS1_417',
#    'height': '10',
#    'left': '395',
#    'rotation': '',
#    'top': '785',
#    'type': 'Line',
#    'width': '50'},
#   'shape277': {'element': 'MAL_OS1_417',
#    'height': '10',
#    'left': '395',
#    'rotation': '',
#    'top': '815',
#    'type': 'Line',
#    'width': '50'},
#   'shape551': {'element': 'MAL_OS1_417',
#    'height': '30',
#    'left': '395',
#    'rotation': '',
#    'top': '815',
#    'type': 'Line',
#    'width': '10'},
#   'shape552': {'element': 'MAL_OS1_417',
#    'height': '30',
#    'left': '395',
#    'rotation': '',
#    'top': '785',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_483': {'shape112': {'element': 'MAL_OS1_483',
#    'height': '10',
#    'left': '125',
#    'rotation': '',
#    'top': '630',
#    'type': 'Line',
#    'width': '80'},
#   'shape262': {'element': 'MAL_OS1_483',
#    'height': '10',
#    'left': '275',
#    'rotation': '',
#    'top': '660',
#    'type': 'Line',
#    'width': '50'},
#   'shape266': {'element': 'MAL_OS1_483',
#    'height': '15',
#    'left': '225',
#    'rotation': '',
#    'top': '630',
#    'type': 'Line',
#    'width': '50'},
#   'shape271': {'element': 'MAL_OS1_483',
#    'height': '10',
#    'left': '275',
#    'rotation': '',
#    'top': '630',
#    'type': 'Line',
#    'width': '120'},
#   'shape580': {'element': 'MAL_OS1_483',
#    'height': '30',
#    'left': '275',
#    'rotation': '',
#    'top': '630',
#    'type': 'Line',
#    'width': '10'},
#   'shape627': {'element': 'MAL_OS1_483',
#    'height': '10',
#    'left': '395',
#    'rotation': '',
#    'top': '630',
#    'type': 'Line',
#    'width': '365'},
#   'shape659': {'element': 'MAL_OS1_483',
#    'height': '10',
#    'left': '395',
#    'rotation': '',
#    'top': '660',
#    'type': 'Line',
#    'width': '50'},
#   'shape661': {'element': 'MAL_OS1_483',
#    'height': '30',
#    'left': '395',
#    'rotation': '',
#    'top': '630',
#    'type': 'Line',
#    'width': '10'},
#   'shape698': {'element': 'MAL_OS1_483',
#    'height': '30',
#    'left': '760',
#    'rotation': '',
#    'top': '630',
#    'type': 'Line',
#    'width': '10'},
#   'shape699': {'element': 'MAL_OS1_483',
#    'height': '10',
#    'left': '760',
#    'rotation': '',
#    'top': '660',
#    'type': 'Line',
#    'width': '105'}},
#  'MAL_OS1_491': {'shape116': {'element': 'MAL_OS1_491',
#    'height': '10',
#    'left': '125',
#    'rotation': '',
#    'top': '730',
#    'type': 'Line',
#    'width': '80'},
#   'shape341': {'element': 'MAL_OS1_491',
#    'height': '10',
#    'left': '225',
#    'rotation': '',
#    'top': '730',
#    'type': 'Line',
#    'width': '535'},
#   'shape692': {'element': 'MAL_OS1_491',
#    'height': '10',
#    'left': '760',
#    'rotation': '',
#    'top': '695',
#    'type': 'Line',
#    'width': '105'},
#   'shape693': {'element': 'MAL_OS1_491',
#    'height': '35',
#    'left': '760',
#    'rotation': '',
#    'top': '695',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_5002': {'shape404': {'element': 'MAL_OS1_5002',
#    'height': '10',
#    'left': '1460',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '50'},
#   'shape405': {'element': 'MAL_OS1_5002',
#    'height': '10',
#    'left': '1460',
#    'rotation': '',
#    'top': '575',
#    'type': 'Line',
#    'width': '50'},
#   'shape406': {'element': 'MAL_OS1_5002',
#    'height': '10',
#    'left': '1510',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '50'},
#   'shape407': {'element': 'MAL_OS1_5002',
#    'height': '10',
#    'left': '1560',
#    'rotation': '',
#    'top': '455',
#    'type': 'Line',
#    'width': '50'},
#   'shape408': {'element': 'MAL_OS1_5002',
#    'height': '10',
#    'left': '1560',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '100'},
#   'shape409': {'element': 'MAL_OS1_5002',
#    'height': '10',
#    'left': '1660',
#    'rotation': '',
#    'top': '455',
#    'type': 'Line',
#    'width': '50'},
#   'shape410': {'element': 'MAL_OS1_5002',
#    'height': '15',
#    'left': '1660',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '125'},
#   'shape608': {'element': 'MAL_OS1_5002',
#    'height': '150',
#    'left': '1510',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '10'},
#   'shape609': {'element': 'MAL_OS1_5002',
#    'height': '30',
#    'left': '1560',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '10'},
#   'shape610': {'element': 'MAL_OS1_5002',
#    'height': '30',
#    'left': '1660',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_7279': {'shape335': {'element': 'MAL_OS1_7279',
#    'height': '10',
#    'left': '1605',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '30'}},
#  'MAL_OS1_7280': {'shape226': {'element': 'MAL_OS1_7280',
#    'height': '10',
#    'left': '1655',
#    'rotation': '',
#    'top': '110',
#    'type': 'Line',
#    'width': '30'},
#   'shape336': {'element': 'MAL_OS1_7280',
#    'height': '10',
#    'left': '1655',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '30'},
#   'shape337': {'element': 'MAL_OS1_7280',
#    'height': '10',
#    'left': '1715',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '70'},
#   'shape385': {'element': 'MAL_OS1_7280',
#    'height': '10',
#    'left': '1685',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '30'},
#   'shape534': {'element': 'MAL_OS1_7280',
#    'height': '30',
#    'left': '1685',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '10'},
#   'shape536': {'element': 'MAL_OS1_7280',
#    'height': '30',
#    'left': '1715',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '10'}},
#  'MAV_OS1_013_012': {'shape480': {'element': 'MAV_OS1_013_012',
#    'height': '10',
#    'left': '1580',
#    'rotation': '',
#    'top': '75',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_013_013': {'shape481': {'element': 'MAV_OS1_013_013',
#    'height': '10',
#    'left': '1630',
#    'rotation': '',
#    'top': '75',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_013_014': {'shape433': {'element': 'MAV_OS1_013_014',
#    'height': '10',
#    'left': '1630',
#    'rotation': '',
#    'top': '105',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_013_015': {'shape442': {'element': 'MAV_OS1_013_015',
#    'height': '10',
#    'left': '1700',
#    'rotation': '270',
#    'top': '115',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_014_003': {'shape519': {'element': 'MAV_OS1_014_003',
#    'height': '10',
#    'left': '1705',
#    'rotation': '',
#    'top': '450',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_014_004': {'shape479': {'element': 'MAV_OS1_014_004',
#    'height': '10',
#    'left': '1485',
#    'rotation': '',
#    'top': '105',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_017_024': {'shape444': {'element': 'MAV_OS1_017_024',
#    'height': '10',
#    'left': '365',
#    'rotation': '',
#    'top': '400',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_006': {'shape467': {'element': 'MAV_OS1_018_006',
#    'height': '10',
#    'left': '1270',
#    'rotation': '',
#    'top': '75',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_007': {'shape462': {'element': 'MAV_OS1_018_007',
#    'height': '10',
#    'left': '1125',
#    'rotation': '',
#    'top': '85',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_008': {'shape463': {'element': 'MAV_OS1_018_008',
#    'height': '10',
#    'left': '1125',
#    'rotation': '',
#    'top': '295',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_009': {'shape476': {'element': 'MAV_OS1_018_009',
#    'height': '10',
#    'left': '1270',
#    'rotation': '',
#    'top': '280',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_011': {'shape681': {'element': 'MAV_OS1_018_011',
#    'height': '10',
#    'left': '905',
#    'rotation': '270',
#    'top': '390',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_013': {'shape689': {'element': 'MAV_OS1_018_013',
#    'height': '10',
#    'left': '865',
#    'rotation': '0',
#    'top': '420',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_038': {'shape472': {'element': 'MAV_OS1_018_038',
#    'height': '10',
#    'left': '1375',
#    'rotation': '',
#    'top': '670',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_042': {'shape470': {'element': 'MAV_OS1_018_042',
#    'height': '10',
#    'left': '1085',
#    'rotation': '',
#    'top': '685',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_043': {'shape468': {'element': 'MAV_OS1_018_043',
#    'height': '10',
#    'left': '1085',
#    'rotation': '',
#    'top': '840',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_065': {'shape494': {'element': 'MAV_OS1_018_065',
#    'height': '10',
#    'left': '495',
#    'rotation': '',
#    'top': '500',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_067': {'shape477': {'element': 'MAV_OS1_018_067',
#    'height': '10',
#    'left': '1390',
#    'rotation': '',
#    'top': '75',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_071': {'shape475': {'element': 'MAV_OS1_018_071',
#    'height': '10',
#    'left': '655',
#    'rotation': '',
#    'top': '125',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_072': {'shape465': {'element': 'MAV_OS1_018_072',
#    'height': '10',
#    'left': '655',
#    'rotation': '',
#    'top': '85',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_073': {'shape493': {'element': 'MAV_OS1_018_073',
#    'height': '10',
#    'left': '380',
#    'rotation': '',
#    'top': '125',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_074': {'shape483': {'element': 'MAV_OS1_018_074',
#    'height': '10',
#    'left': '655',
#    'rotation': '',
#    'top': '165',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_075': {'shape484': {'element': 'MAV_OS1_018_075',
#    'height': '10',
#    'left': '655',
#    'rotation': '',
#    'top': '205',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_100': {'shape690': {'element': 'MAV_OS1_018_100',
#    'height': '10',
#    'left': '780',
#    'rotation': '0',
#    'top': '450',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_104': {'shape447': {'element': 'MAV_OS1_018_104',
#    'height': '10',
#    'left': '620',
#    'rotation': '',
#    'top': '500',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_106': {'shape527': {'element': 'MAV_OS1_018_106',
#    'height': '10',
#    'left': '1390',
#    'rotation': '',
#    'top': '135',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_107': {'shape529': {'element': 'MAV_OS1_018_107',
#    'height': '10',
#    'left': '1390',
#    'rotation': '',
#    'top': '215',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_108': {'shape439': {'element': 'MAV_OS1_018_108',
#    'height': '10',
#    'left': '945',
#    'rotation': '',
#    'top': '125',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_109': {'shape438': {'element': 'MAV_OS1_018_109',
#    'height': '10',
#    'left': '945',
#    'rotation': '',
#    'top': '85',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_110': {'shape461': {'element': 'MAV_OS1_018_110',
#    'height': '10',
#    'left': '945',
#    'rotation': '',
#    'top': '165',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_111': {'shape464': {'element': 'MAV_OS1_018_111',
#    'height': '10',
#    'left': '945',
#    'rotation': '',
#    'top': '205',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_114': {'shape485': {'element': 'MAV_OS1_018_114',
#    'height': '10',
#    'left': '865',
#    'rotation': '',
#    'top': '355',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_115': {'shape486': {'element': 'MAV_OS1_018_115',
#    'height': '10',
#    'left': '865',
#    'rotation': '',
#    'top': '325',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_116': {'shape488': {'element': 'MAV_OS1_018_116',
#    'height': '10',
#    'left': '865',
#    'rotation': '',
#    'top': '265',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_117': {'shape487': {'element': 'MAV_OS1_018_117',
#    'height': '10',
#    'left': '865',
#    'rotation': '',
#    'top': '295',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_130': {'shape490': {'element': 'MAV_OS1_018_130',
#    'height': '10',
#    'left': '770',
#    'rotation': '',
#    'top': '355',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_134': {'shape492': {'element': 'MAV_OS1_018_134',
#    'height': '10',
#    'left': '665',
#    'rotation': '',
#    'top': '265',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_136': {'shape473': {'element': 'MAV_OS1_018_136',
#    'height': '10',
#    'left': '1375',
#    'rotation': '',
#    'top': '825',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_141': {'shape491': {'element': 'MAV_OS1_018_141',
#    'height': '10',
#    'left': '735',
#    'rotation': '',
#    'top': '325',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_172': {'shape691': {'element': 'MAV_OS1_018_172',
#    'height': '10',
#    'left': '780',
#    'rotation': '0',
#    'top': '495',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_019_004': {'shape518': {'element': 'MAV_OS1_019_004',
#    'height': '10',
#    'left': '1605',
#    'rotation': '',
#    'top': '450',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_021_047': {'shape660': {'element': 'MAV_OS1_021_047',
#    'height': '10',
#    'left': '440',
#    'rotation': '',
#    'top': '655',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_021_117': {'shape458': {'element': 'MAV_OS1_021_117',
#    'height': '10',
#    'left': '440',
#    'rotation': '',
#    'top': '780',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_021_122': {'shape457': {'element': 'MAV_OS1_021_122',
#    'height': '10',
#    'left': '440',
#    'rotation': '',
#    'top': '840',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_021_140': {'shape459': {'element': 'MAV_OS1_021_140',
#    'height': '10',
#    'left': '440',
#    'rotation': '',
#    'top': '810',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_033': {'shape512': {'element': 'MAV_OS1_022_033',
#    'height': '10',
#    'left': '935',
#    'rotation': '',
#    'top': '495',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_057': {'shape513': {'element': 'MAV_OS1_022_057',
#    'height': '10',
#    'left': '935',
#    'rotation': '',
#    'top': '520',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_059': {'shape516': {'element': 'MAV_OS1_022_059',
#    'height': '10',
#    'left': '1435',
#    'rotation': '',
#    'top': '570',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_060': {'shape514': {'element': 'MAV_OS1_022_060',
#    'height': '10',
#    'left': '1125',
#    'rotation': '',
#    'top': '585',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_061': {'shape510': {'element': 'MAV_OS1_022_061',
#    'height': '10',
#    'left': '975',
#    'rotation': '90',
#    'top': '555',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_062': {'shape506': {'element': 'MAV_OS1_022_062',
#    'height': '10',
#    'left': '1125',
#    'rotation': '',
#    'top': '435',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_063': {'shape650': {'element': 'MAV_OS1_022_063',
#    'height': '10',
#    'left': '920',
#    'rotation': '0',
#    'top': '585',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_064': {'shape649': {'element': 'MAV_OS1_022_064',
#    'height': '10',
#    'left': '860',
#    'rotation': '0',
#    'top': '585',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_065': {'shape694': {'element': 'MAV_OS1_022_065',
#    'height': '10',
#    'left': '920',
#    'rotation': '',
#    'top': '690',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_066': {'shape696': {'element': 'MAV_OS1_022_066',
#    'height': '10',
#    'left': '920',
#    'rotation': '',
#    'top': '655',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_067': {'shape642': {'element': 'MAV_OS1_022_067',
#    'height': '10',
#    'left': '860',
#    'rotation': '',
#    'top': '620',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_068': {'shape640': {'element': 'MAV_OS1_022_068',
#    'height': '10',
#    'left': '860',
#    'rotation': '',
#    'top': '690',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_069': {'shape641': {'element': 'MAV_OS1_022_069',
#    'height': '10',
#    'left': '860',
#    'rotation': '',
#    'top': '655',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_072': {'shape511': {'element': 'MAV_OS1_022_072',
#    'height': '10',
#    'left': '935',
#    'rotation': '',
#    'top': '470',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_073': {'shape508': {'element': 'MAV_OS1_022_073',
#    'height': '10',
#    'left': '1435',
#    'rotation': '',
#    'top': '420',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_074': {'shape509': {'element': 'MAV_OS1_022_074',
#    'height': '10',
#    'left': '1435',
#    'rotation': '',
#    'top': '450',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_162': {'shape517': {'element': 'MAV_OS1_022_162',
#    'height': '10',
#    'left': '1435',
#    'rotation': '',
#    'top': '600',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_024_031': {'shape455': {'element': 'MAV_OS1_024_031',
#    'height': '10',
#    'left': '320',
#    'rotation': '',
#    'top': '655',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_053_027': {'shape418': {'element': 'MAV_OS1_053_027',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '500',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_054_002': {'shape414': {'element': 'MAV_OS1_054_002',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '85',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_054_017': {'shape415': {'element': 'MAV_OS1_054_017',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '175',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_054_021': {'shape416': {'element': 'MAV_OS1_054_021',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '295',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_054_026': {'shape417': {'element': 'MAV_OS1_054_026',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '400',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_059_006': {'shape423': {'element': 'MAV_OS1_059_006',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '840',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_062_004': {'shape421': {'element': 'MAV_OS1_062_004',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '625',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_062_013': {'shape422': {'element': 'MAV_OS1_062_013',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '725',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'OMAVALVE': {'shape469': {'element': 'OMAVALVE',
#    'height': '10',
#    'left': '1195',
#    'rotation': '',
#    'top': '795',
#    'type': 'ValveMan',
#    'width': '30'},
#   'shape471': {'element': 'OMAVALVE',
#    'height': '10',
#    'left': '1195',
#    'rotation': '',
#    'top': '640',
#    'type': 'ValveMan',
#    'width': '30'},
#   'shape507': {'element': 'OMAVALVE',
#    'height': '10',
#    'left': '1195',
#    'rotation': '',
#    'top': '390',
#    'type': 'ValveMan',
#    'width': '30'},
#   'shape515': {'element': 'OMAVALVE',
#    'height': '10',
#    'left': '1195',
#    'rotation': '',
#    'top': '540',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'TK53104': {'shape050': {'element': 'TK53104',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '40',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'TK53105': {'shape051': {'element': 'TK53105',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '145',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'TK53106': {'shape052': {'element': 'TK53106',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '250',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'TK53107': {'shape053': {'element': 'TK53107',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '355',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'TK53109': {'shape054': {'element': 'TK53109',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '465',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'TK53110': {'shape055': {'element': 'TK53110',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '575',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'TK53111': {'shape056': {'element': 'TK53111',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '690',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'TK5397': {'shape057': {'element': 'TK5397',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '790',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'UN20200_WAXY': {'shape794': {'element': 'UN20200_WAXY',
#    'height': '18',
#    'left': '1780',
#    'rotation': '',
#    'top': '820',
#    'type': 'BP',
#    'width': '26'}},
#  'UN2400_WAXY': {'shape792': {'element': 'UN2400_WAXY',
#    'height': '18',
#    'left': '1780',
#    'rotation': '',
#    'top': '70',
#    'type': 'BP',
#    'width': '26'}},
#  'UN2600_WAXY': {'shape793': {'element': 'UN2600_WAXY',
#    'height': '18',
#    'left': '1780',
#    'rotation': '',
#    'top': '415',
#    'type': 'BP',
#    'width': '26'}},
#  '_P53102A': {'shape273': {'element': '_P53102A',
#    'height': '35',
#    'left': '1195',
#    'rotation': '',
#    'top': '75',
#    'type': 'CPump',
#    'width': '35'}},
#  '_P53102AL': {'PseudoValve039': {'element': '_P53102AL',
#    'height': '11',
#    'left': '1175',
#    'rotation': '',
#    'top': '85',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P53102AR': {'PseudoValve040': {'element': '_P53102AR',
#    'height': '11',
#    'left': '1240',
#    'rotation': '',
#    'top': '75',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P53102B': {'shape272': {'element': '_P53102B',
#    'height': '35',
#    'left': '1195',
#    'rotation': '',
#    'top': '280',
#    'type': 'CPump',
#    'width': '35'}},
#  '_P53102BL': {'PseudoValve041': {'element': '_P53102BL',
#    'height': '11',
#    'left': '1175',
#    'rotation': '',
#    'top': '295',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P53102BR': {'PseudoValve042': {'element': '_P53102BR',
#    'height': '11',
#    'left': '1240',
#    'rotation': '',
#    'top': '280',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P53104A': {'shape278': {'element': '_P53104A',
#    'height': '35',
#    'left': '1193',
#    'rotation': '',
#    'top': '420',
#    'type': 'CPump',
#    'width': '35'}},
#  '_P53104AL': {'PseudoValve043': {'element': '_P53104AL',
#    'height': '11',
#    'left': '1175',
#    'rotation': '',
#    'top': '435',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P53104AR': {'PseudoValve044': {'element': '_P53104AR',
#    'height': '11',
#    'left': '1240',
#    'rotation': '',
#    'top': '420',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P53104B': {'shape279': {'element': '_P53104B',
#    'height': '35',
#    'left': '1195',
#    'rotation': '',
#    'top': '570',
#    'type': 'CPump',
#    'width': '35'}},
#  '_P53104BL': {'PseudoValve045': {'element': '_P53104BL',
#    'height': '11',
#    'left': '1175',
#    'rotation': '',
#    'top': '585',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P53104BR': {'PseudoValve046': {'element': '_P53104BR',
#    'height': '11',
#    'left': '1240',
#    'rotation': '',
#    'top': '570',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P5399A': {'shape308': {'element': '_P5399A',
#    'height': '35',
#    'left': '1195',
#    'rotation': '',
#    'top': '670',
#    'type': 'CPump',
#    'width': '35'}},
#  '_P5399AL': {'PseudoValve047': {'element': '_P5399AL',
#    'height': '11',
#    'left': '1175',
#    'rotation': '',
#    'top': '685',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P5399AR': {'PseudoValve048': {'element': '_P5399AR',
#    'height': '11',
#    'left': '1240',
#    'rotation': '',
#    'top': '670',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P5399B': {'shape309': {'element': '_P5399B',
#    'height': '35',
#    'left': '1195',
#    'rotation': '',
#    'top': '825',
#    'type': 'CPump',
#    'width': '35'}},
#  '_P5399BL': {'PseudoValve049': {'element': '_P5399BL',
#    'height': '11',
#    'left': '1175',
#    'rotation': '',
#    'top': '840',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P5399BR': {'PseudoValve050': {'element': '_P5399BR',
#    'height': '11',
#    'left': '1235',
#    'rotation': '',
#    'top': '825',
#    'type': 'ValvePseudo',
#    'width': '11'}}}

# %%
elem['MAL_OS1_202']
# Out:
# {'shape111': {'element': 'MAL_OS1_202',
#   'height': '10',
#   'left': '130',
#   'rotation': '',
#   'top': '505',
#   'type': 'Line',
#   'width': '75'},
#  'shape254': {'element': 'MAL_OS1_202',
#   'height': '10',
#   'left': '225',
#   'rotation': '',
#   'top': '505',
#   'type': 'Line',
#   'width': '275'}}

# %%
for i in elem:
    for j in elem[i]:
        print('{:15} {:15} {:10}'.format(i,j,elem[i][j]['type']))
# Out:
# MAL_OS1_7280    shape385        Line
# MAL_OS1_7280    shape534        Line
# MAL_OS1_7280    shape226        Line
# MAL_OS1_7280    shape536        Line
# MAL_OS1_7280    shape336        Line
# MAL_OS1_7280    shape337        Line
# MAL_OS1_314     shape554        Line
# MAL_OS1_314     shape283        Line
# MAL_OS1_314     shape284        Line
# MAL_OS1_314     shape289        Line
# MAL_OS1_314     shape553        Line
# MAL_OS1_314     shape292        Line
# MAL_OS1_314     shape293        Line
# MAL_OS1_314     shape587        Line
# MAL_OS1_314     shape297        Line
# MAL_OS1_314     shape588        Line
# MAV_OS1_054_002 shape414        ValveMan
# _P53102A        shape273        CPump
# TK53104         shape050        TankNozzle
# TK53105         shape051        TankNozzle
# TK53106         shape052        TankNozzle
# TK53107         shape053        TankNozzle
# TK53109         shape054        TankNozzle
# TK53110         shape055        TankNozzle
# TK53111         shape056        TankNozzle
# TK5397          shape057        TankNozzle
# MAL_OS1_218     shape104        Line
# MAL_OS1_218     shape223        Line
# MAL_OS1_220     shape108        Line
# MAL_OS1_220     shape232        Line
# MAL_OS1_220     shape677        Line
# MAL_OS1_220     shape355        Line
# MAL_OS1_220     shape383        Line
# MAL_OS1_230     shape109        Line
# MAL_OS1_230     shape240        Line
# MAL_OS1_230     shape678        Line
# MAL_OS1_230     shape356        Line
# MAL_OS1_232     shape110        Line
# MAL_OS1_232     shape250        Line
# MAL_OS1_202     shape111        Line
# MAL_OS1_202     shape254        Line
# MAL_OS1_483     shape112        Line
# MAL_OS1_483     shape266        Line
# MAL_OS1_483     shape627        Line
# MAL_OS1_483     shape659        Line
# MAL_OS1_483     shape661        Line
# MAL_OS1_483     shape580        Line
# MAL_OS1_483     shape262        Line
# MAL_OS1_483     shape271        Line
# MAL_OS1_483     shape698        Line
# MAL_OS1_483     shape699        Line
# MAL_OS1_417     shape115        Line
# MAL_OS1_417     shape269        Line
# MAL_OS1_417     shape274        Line
# MAL_OS1_417     shape551        Line
# MAL_OS1_417     shape276        Line
# MAL_OS1_417     shape552        Line
# MAL_OS1_417     shape277        Line
# _P53102B        shape272        CPump
# MAL_OS1_360     shape310        Line
# MAL_OS1_360     shape316        Line
# MAL_OS1_360     shape574        Line
# MAL_OS1_360     shape322        Line
# UN2400_WAXY     shape792        BP
# UN2600_WAXY     shape793        BP
# MAL_OS1_359     shape392        Line
# MAL_OS1_359     shape390        Line
# MAL_OS1_359     shape391        Line
# MAL_OS1_359     shape607        Line
# UN20200_WAXY    shape794        BP
# MAV_OS1_054_017 shape415        ValveMan
# MAV_OS1_054_021 shape416        ValveMan
# MAV_OS1_054_026 shape417        ValveMan
# MAV_OS1_053_027 shape418        ValveMan
# MAV_OS1_062_004 shape421        ValveMan
# MAV_OS1_059_006 shape423        ValveMan
# MAV_OS1_017_024 shape444        ValveMan
# MAL_OS1_312     shape255        Line
# MAL_OS1_312     shape680        Line
# MAL_OS1_312     shape374        Line
# MAL_OS1_312     shape275        Line
# MAV_OS1_018_104 shape447        ValveMan
# MAV_OS1_021_122 shape457        ValveMan
# MAV_OS1_021_117 shape458        ValveMan
# MAV_OS1_021_140 shape459        ValveMan
# _P53104A        shape278        CPump
# _P53104B        shape279        CPump
# MAL_OS1_271     shape281        Line
# MAV_OS1_018_007 shape462        ValveMan
# MAL_OS1_272     shape282        Line
# MAV_OS1_018_008 shape463        ValveMan
# MAL_OS1_2432    shape301        Line
# MAV_OS1_022_062 shape506        ValveMan
# MAL_OS1_2431    shape303        Line
# MAL_OS1_2431    shape563        Line
# MAL_OS1_2431    shape304        Line
# MAL_OS1_2431    shape334        Line
# MAL_OS1_2431    shape566        Line
# MAL_OS1_2431    shape371        Line
# MAL_OS1_2431    shape568        Line
# MAL_OS1_2431    shape393        Line
# MAL_OS1_2431    shape569        Line
# MAL_OS1_2431    shape394        Line
# MAL_OS1_2431    shape570        Line
# OMAVALVE        shape507        ValveMan
# OMAVALVE        shape515        ValveMan
# OMAVALVE        shape469        ValveMan
# OMAVALVE        shape471        ValveMan
# MAL_OS1_2433    shape305        Line
# MAL_OS1_2433    shape564        Line
# MAL_OS1_2433    shape314        Line
# MAL_OS1_2433    shape315        Line
# MAL_OS1_2433    shape329        Line
# MAL_OS1_2433    shape565        Line
# MAL_OS1_2433    shape330        Line
# MAV_OS1_022_073 shape508        ValveMan
# MAV_OS1_022_074 shape509        ValveMan
# MAV_OS1_022_061 shape510        ValveMan
# MAV_OS1_022_072 shape511        ValveMan
# MAV_OS1_022_033 shape512        ValveMan
# MAV_OS1_022_057 shape513        ValveMan
# MAL_OS1_2428    shape395        Line
# MAV_OS1_022_060 shape514        ValveMan
# MAL_OS1_2426    shape396        Line
# MAL_OS1_2426    shape571        Line
# MAL_OS1_2426    shape397        Line
# MAL_OS1_2426    shape399        Line
# MAL_OS1_2426    shape584        Line
# MAL_OS1_2426    shape643        Line
# MAL_OS1_2426    shape644        Line
# MAL_OS1_2426    shape645        Line
# MAL_OS1_2426    shape646        Line
# MAL_OS1_2426    shape647        Line
# MAL_OS1_2426    shape648        Line
# MAL_OS1_2426    shape668        Line
# MAL_OS1_2424    shape398        Line
# MAL_OS1_2424    shape577        Line
# MAL_OS1_2424    shape400        Line
# MAL_OS1_2424    shape401        Line
# MAL_OS1_2424    shape592        Line
# MAL_OS1_2424    shape384        Line
# MAL_OS1_2424    shape402        Line
# MAV_OS1_022_059 shape516        ValveMan
# MAL_OS1_5002    shape404        Line
# MAL_OS1_5002    shape608        Line
# MAL_OS1_5002    shape405        Line
# MAL_OS1_5002    shape406        Line
# MAL_OS1_5002    shape609        Line
# MAL_OS1_5002    shape407        Line
# MAL_OS1_5002    shape408        Line
# MAL_OS1_5002    shape610        Line
# MAL_OS1_5002    shape409        Line
# MAL_OS1_5002    shape410        Line
# MAV_OS1_019_004 shape518        ValveMan
# MAV_OS1_014_003 shape519        ValveMan
# MAL_OS1_246     shape523        Line
# MAL_OS1_246     shape679        Line
# MAL_OS1_246     shape357        Line
# MAL_OS1_325     shape651        Line
# MAL_OS1_325     shape682        Line
# MAL_OS1_325     shape377        Line
# MAL_OS1_325     shape378        Line
# MAL_OS1_325     shape379        Line
# MAL_OS1_325     shape683        Line
# MAL_OS1_325     shape684        Line
# MAL_OS1_325     shape686        Line
# MAL_OS1_325     shape382        Line
# _P5399A         shape308        CPump
# _P5399B         shape309        CPump
# MAL_OS1_289     shape312        Line
# MAL_OS1_289     shape313        Line
# MAL_OS1_289     shape572        Line
# MAL_OS1_289     shape318        Line
# MAV_OS1_018_043 shape468        ValveMan
# MAL_OS1_288     shape319        Line
# MAL_OS1_288     shape573        Line
# MAL_OS1_288     shape320        Line
# MAL_OS1_288     shape321        Line
# MAV_OS1_018_042 shape470        ValveMan
# MAL_OS1_287     shape323        Line
# MAL_OS1_287     shape324        Line
# MAL_OS1_287     shape575        Line
# MAL_OS1_287     shape325        Line
# MAL_OS1_286     shape326        Line
# MAL_OS1_286     shape576        Line
# MAL_OS1_286     shape327        Line
# MAL_OS1_286     shape328        Line
# MAV_OS1_018_038 shape472        ValveMan
# MAV_OS1_018_136 shape473        ValveMan
# MAL_OS1_270     shape286        Line
# MAV_OS1_018_006 shape467        ValveMan
# MAL_OS1_273     shape287        Line
# MAV_OS1_018_009 shape476        ValveMan
# MAL_OS1_313     shape288        Line
# MAL_OS1_313     shape302        Line
# MAL_OS1_313     shape558        Line
# MAL_OS1_313     shape306        Line
# MAL_OS1_313     shape331        Line
# MAL_OS1_313     shape559        Line
# MAL_OS1_313     shape332        Line
# MAL_OS1_313     shape578        Line
# MAV_OS1_018_067 shape477        ValveMan
# MAV_OS1_018_106 shape527        ValveMan
# MAV_OS1_018_107 shape529        ValveMan
# MAL_OS1_376     shape307        Line
# MAL_OS1_376     shape317        Line
# MAL_OS1_376     shape579        Line
# MAL_OS1_376     shape333        Line
# MAV_OS1_014_004 shape479        ValveMan
# MAV_OS1_013_012 shape480        ValveMan
# MAL_OS1_7279    shape335        Line
# MAV_OS1_013_013 shape481        ValveMan
# MAV_OS1_013_014 shape433        ValveMan
# MAV_OS1_013_015 shape442        ValveMan
# MAV_OS1_021_047 shape660        ValveMan
# MAV_OS1_024_031 shape455        ValveMan
# MAL_OS1_491     shape116        Line
# MAL_OS1_491     shape341        Line
# MAL_OS1_491     shape692        Line
# MAL_OS1_491     shape693        Line
# MAV_OS1_062_013 shape422        ValveMan
# MAV_OS1_022_068 shape640        ValveMan
# MAV_OS1_022_069 shape641        ValveMan
# MAV_OS1_022_067 shape642        ValveMan
# MAV_OS1_022_064 shape649        ValveMan
# _P53102AL       PseudoValve039  ValvePseudo
# _P53102AR       PseudoValve040  ValvePseudo
# _P53102BL       PseudoValve041  ValvePseudo
# _P53102BR       PseudoValve042  ValvePseudo
# _P53104AL       PseudoValve043  ValvePseudo
# _P53104AR       PseudoValve044  ValvePseudo
# _P53104BL       PseudoValve045  ValvePseudo
# _P53104BR       PseudoValve046  ValvePseudo
# _P5399AL        PseudoValve047  ValvePseudo
# _P5399AR        PseudoValve048  ValvePseudo
# _P5399BL        PseudoValve049  ValvePseudo
# _P5399BR        PseudoValve050  ValvePseudo
# MAL_OS1_368     shape619        Line
# MAL_OS1_368     shape589        Line
# MAL_OS1_368     shape359        Line
# MAL_OS1_368     shape361        Line
# MAL_OS1_368     shape363        Line
# MAL_OS1_368     shape365        Line
# MAL_OS1_368     shape590        Line
# MAL_OS1_368     shape591        Line
# MAV_OS1_022_063 shape650        ValveMan
# MAV_OS1_018_109 shape438        ValveMan
# MAV_OS1_018_108 shape439        ValveMan
# MAV_OS1_018_110 shape461        ValveMan
# MAV_OS1_018_111 shape464        ValveMan
# MAL_OS1_323     shape311        Line
# MAL_OS1_323     shape617        Line
# MAL_OS1_323     shape622        Line
# MAL_OS1_323     shape637        Line
# MAL_OS1_323     shape350        Line
# MAL_OS1_323     shape638        Line
# MAL_OS1_323     shape364        Line
# MAL_OS1_323     shape369        Line
# MAL_OS1_323     shape370        Line
# MAL_OS1_323     shape372        Line
# MAL_OS1_323     shape376        Line
# MAL_OS1_321     shape347        Line
# MAL_OS1_321     shape655        Line
# MAL_OS1_321     shape352        Line
# MAL_OS1_321     shape672        Line
# MAL_OS1_321     shape673        Line
# MAL_OS1_321     shape362        Line
# MAL_OS1_321     shape367        Line
# MAL_OS1_321     shape368        Line
# MAL_OS1_326     shape348        Line
# MAL_OS1_326     shape674        Line
# MAL_OS1_326     shape675        Line
# MAL_OS1_326     shape353        Line
# MAL_OS1_326     shape360        Line
# MAL_OS1_326     shape366        Line
# MAL_OS1_326     shape375        Line
# MAL_OS1_327     shape349        Line
# MAL_OS1_327     shape676        Line
# MAL_OS1_327     shape354        Line
# MAL_OS1_327     shape358        Line
# MAL_OS1_327     shape373        Line
# MAV_OS1_018_072 shape465        ValveMan
# MAV_OS1_018_071 shape475        ValveMan
# MAV_OS1_018_074 shape483        ValveMan
# MAV_OS1_018_075 shape484        ValveMan
# MAV_OS1_018_114 shape485        ValveMan
# MAV_OS1_018_115 shape486        ValveMan
# MAV_OS1_018_117 shape487        ValveMan
# MAV_OS1_018_116 shape488        ValveMan
# MAV_OS1_018_130 shape490        ValveMan
# MAV_OS1_018_141 shape491        ValveMan
# MAV_OS1_018_134 shape492        ValveMan
# MAV_OS1_018_011 shape681        ValveMan
# MAL_OS1_2427    shape380        Line
# MAV_OS1_018_013 shape689        ValveMan
# MAV_OS1_018_100 shape690        ValveMan
# MAV_OS1_018_172 shape691        ValveMan
# MAV_OS1_018_073 shape493        ValveMan
# MAV_OS1_022_065 shape694        ValveMan
# MAL_OS1_2430    shape695        Line
# MAL_OS1_2430    shape697        Line
# MAV_OS1_022_066 shape696        ValveMan
# MAV_OS1_022_162 shape517        ValveMan
# MAV_OS1_018_065 shape494        ValveMan

# %%
result2 = {}
for i in total:
    temp = {}
    temp['TOP'] = total[i]['TOP']
    temp['LEFT'] = total[i]['LEFT']
    temp['HEIGHT'] = total[i]['HEIGHT']
    temp['LEFWIDTHT'] = total[i]['WIDTH']
    if 'Rotation' in total[i]:
        temp['rotation'] = total[i]['Rotation']
    result2[i] = temp
    
for j in result2:
    if 'rotation' in result2[j]:
        print(j,result2[j]['rotation'])
# Out:
# shape510 90
# shape442 270
# shape649 0
# shape650 0
# shape681 270
# shape689 0
# shape690 0
# shape691 0

# %%
total['shape033']
# Out:
# {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#  'FONT-FAMILY': 'Arial',
#  'FONT-SIZE': '0px',
#  'FONT-STYLE': 'normal',
#  'FONT-WEIGHT': '400',
#  'HEIGHT': '18px',
#  'Height': '18',
#  'LEFT': '1810px',
#  'POSITION': 'absolute',
#  'T?T': 'U-2600',
#  'TEXT-DECORATION': 'none',
#  'TOP': '415px',
#  'WIDTH': '95px',
#  'Width': '95',
#  'fillColorBlink': 'False',
#  'id': 'shape033',
#  'lineColorBlink': 'False',
#  'no': 53}
