# %%
from bs4 import BeautifulSoup
with open('work_test.htm') as file:
    data = file.read()
soup = BeautifulSoup(data,'html.parser')

main = soup.find('div', attrs={'id':'Page'})
main
# Out:
# <div id="Page" pagedescription="MA_CH_OS1_WAXY" style="POSITION: absolute; BACKGROUND-COLOR: transparent; MARGIN: 0px; WIDTH: 1910px; ZOOM: 1; FONT-FAMILY: Arial; HEIGHT: 900px; FONT-SIZE: 12pt; BEHAVIOR: url(#StnEvtReflector) url(#HDXPageBehavior) url(#DisplayDataRepository)">
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Width:30;" id="shape385" linktype="embedded" parameters="Point?element:MAL_OS1_7280;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_013_014~MAV_OS1_013_013;Value?EndPoint2:;" src=".\MA_CH_OS1_WAXY_files\MALineH.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 80px; LEFT: 1685px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="fillColorBlink:False;HDXBINDINGID:207;Height:10;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:2;points:0 0 100 0 ;Width:30;" id="shape385_linPipe" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:40;lineColorBlink:False;Width:10;" id="shape554" linktype="embedded" parameters="Point?element:MAL_OS1_314;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108;Value?EndPoint2:MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110;" src=".\MA_CH_OS1_WAXY_files\MALineU.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 40px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 130px; LEFT: 1070px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="fillColorBlink:False;HDXBINDINGID:266;Height:40;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:2;points:0 0 0 100.4167 ;Width:10;" id="shape554_linPipe" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div>
# <div class="hsc.shape.1" globalscripts="35259920-2E80-4F3B-B242-D1384DFE43F1" hdxproperties="fillColorBlink:False;Height:29;lineColorBlink:False;Width:103;" id="shape001" linktype="embedded" parameters="" src=".\MA_CH_OS1_WAXY_files\General Script Holder_rev0.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 103px; FONT-FAMILY: Arial; HEIGHT: 29px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 0px; LEFT: 5px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.textbox.1" globalscripts="" hdxproperties="FillColor:#696969;fillColorBlink:False;FillStyle:0;Height:29;lineColorBlink:False;LineStyle:1;textColor:#c0c0c0;textColorBlink:False;TotalRotation:0;value:;Width:103;" id="shape001_TxtGSH" style="POSITION: absolute; TEXT-ALIGN: center; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; VISIBILITY: hidden; COLOR: #c0c0c0; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 0%; LEFT: 0%" tabindex="-1">General
# Script Holder</div></div>
# <div class="hsc.image.1" hdxproperties="fillColorBlink:False;Height:24;lineColorBlink:False;Src:.\MA_CH_OS1_WAXY_files\tfgZoomIn.gif;Width:27;" id="picZoomIn" shapesrc=".\MA_CH_OS1_WAXY_files\tfgZoomIn.gif" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 27px; FONT-FAMILY: Arial; HEIGHT: 24px; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#image); TOP: 8px; LEFT: 3px" tabindex="-1"></div>
# <div class="hsc.image.1" hdxproperties="fillColorBlink:False;Height:25;lineColorBlink:False;Src:.\MA_CH_OS1_WAXY_files\tfgZoomOut.gif;Width:26;" id="picZoomOut" shapesrc=".\MA_CH_OS1_WAXY_files\tfgZoomOut.gif" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 26px; FONT-FAMILY: Arial; HEIGHT: 25px; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#image); TOP: 8px; LEFT: 33px" tabindex="-1"></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:14;lineColorBlink:False;Width:92;" id="tfgPlanningData" linktype="embedded" parameters='Point?DestElement:;Point?SrcElement:;Value?IgnoreOnDataChange:"True";' src=".\MA_CH_OS1_WAXY_files\tfgPlanningData.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 92px; FONT-FAMILY: Arial; HEIGHT: 14px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 4px; LEFT: 138px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.textbox.1 HSC.ScriptDataObject.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:0;HDXBINDINGID:1;Height:14;LineColor:#696969;lineColorBlink:False;LineStyle:1;textColor:#ff0000;textColorBlink:False;TotalRotation:0;Width:92;" id="tfgPlanningData_txtDataAcquisition" style="POSITION: absolute; TEXT-ALIGN: left; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; VISIBILITY: hidden; COLOR: #ff0000; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%" tabindex="-1"> Do
# Not Delete This</div></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:16;lineColorBlink:False;Width:60;" id="tfgSelectTimeout" linktype="embedded" parameters='Point?DestElement:;Point?SrcElement:;Value?IgnoreOnDataChange:"True";' src=".\MA_CH_OS1_WAXY_files\tfgSelectTimeout.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 60px; FONT-FAMILY: Arial; HEIGHT: 16px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 4px; LEFT: 77px" styleclass="" tabindex="-1" value="1"><textarea class="hsc.alpha.1" hdxproperties="borderStyle:solid;borderWidth:1px;fillColor:#c0c0c0;fillColorBlink:False;HDXBINDINGID:2;lineColor:#696969;lineColorBlink:False;numericDisplayFormat:%.2f;textColor:#ff0000;textColorBlink:False;" id="tfgSelectTimeout_alpSelectTimeout" style="BORDER-BOTTOM: transparent 1px; POSITION: absolute; TEXT-ALIGN: center; BORDER-LEFT: transparent 1px; PADDING-BOTTOM: 1px; BACKGROUND-COLOR: #c0c0c0; FONT-STYLE: normal; PADDING-LEFT: 1px; WIDTH: 100%; PADDING-RIGHT: 1px; FONT-FAMILY: Arial; WORD-WRAP: normal; HEIGHT: 100%; VISIBILITY: hidden; COLOR: #ff0000; FONT-SIZE: 8pt; OVERFLOW: hidden; BORDER-TOP: transparent 1px; FONT-WEIGHT: normal; BORDER-RIGHT: transparent 1px; TEXT-DECORATION: none; PADDING-TOP: 1px; BEHAVIOR: url(#HDXAlphaBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%; ROWS: 1" tabindex="-1">9999.99</textarea></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:14;lineColorBlink:False;Width:92;" id="tfgOperDataReInit" linktype="embedded" parameters="" src=".\MA_CH_OS1_WAXY_files\tfgOperDataReInit.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 92px; FONT-FAMILY: Arial; HEIGHT: 14px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 4px; LEFT: 230px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.textbox.1 HSC.ScriptDataObject.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:0;HDXBINDINGID:5;Height:14;LineColor:#808080;lineColorBlink:False;LineStyle:1;textColor:#ff0000;textColorBlink:False;TotalRotation:0;Width:92;" id="tfgOperDataReInit_txtDataAcquisition" ondatachange="VBScript:Call HotBuildOnDataChange(me)" style="POSITION: absolute; TEXT-ALIGN: left; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; VISIBILITY: hidden; COLOR: #ff0000; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%" tabindex="-1"> Do Not Delete
# This</div></div>
# <object class="hsc.activexcontrol.1" classid="clsid:14BA344F-0568-473B-9D86-4E98CFFB29AD" id="bmaOpcHelper" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 78px; FONT-FAMILY: Arial; HEIGHT: 16px; FONT-SIZE: 12pt; FONT-WEIGHT: normal; TEXT-DECORATION: none; TOP: 19px; LEFT: 87px" tabindex="-1"><param name="_ExtentX" value="2064"/><param name="_ExtentY" value="423"/></object>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:14;lineColorBlink:False;Width:92;" id="tfgOffDisplayEndPoints" linktype="embedded" parameters="Point?Element1:;Point?Element2:;Point?Element3:;Point?Element4:;Point?Element5:;Point?Element6:;Point?Element7:;Point?Element8:;Point?Element9:;Point?Element10:;Point?Element11:;Point?Element12:;Point?Element13:;Point?Element14:;Point?Element15:;Point?Element16:;Point?Element17:;Point?Element18:;Point?Element19:;Point?Element20:;Point?Element21:;Point?Element22:;Point?Element23:;Point?Element24:;Point?Element25:;Point?Element26:;Point?Element27:;Point?Element28:;Point?Element29:;Point?Element30:;Point?Element31:;Point?Element32:;Point?Element33:;Point?Element34:;Point?Element35:;Point?Element36:;Point?Element37:;Point?Element38:;Point?Element39:;Point?Element40:;" src=".\MA_CH_OS1_WAXY_files\tfgOffDisplayEndPoints.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 92px; FONT-FAMILY: Arial; HEIGHT: 14px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 19px; LEFT: 175px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.textbox.1 HSC.ScriptDataObject.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:0;HDXBINDINGID:6;Height:14;LineColor:#696969;lineColorBlink:False;LineStyle:1;textColor:#ff0000;textColorBlink:False;TotalRotation:0;Width:92;" id="tfgOffDisplayEndPoints_txtDataAcquisition" ondatachange="VBScript:Call OffDisplayEndPointsOnDataChange(me)" style="POSITION: absolute; TEXT-ALIGN: left; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; VISIBILITY: hidden; COLOR: #ff0000; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%" tabindex="-1"> Do Not
# Delete This</div></div>
# <div class="hvg.textbox.1" hdx_lock="-1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:44;lineColorBlink:False;LineStyle:0;textColor:#000000;textColorBlink:False;TotalRotation:0;Width:0;" id="textbox003" style="POSITION: absolute; TEXT-ALIGN: left; FONT-STYLE: normal; WIDTH: 0px; FONT-FAMILY: Arial; HEIGHT: 44px; COLOR: #000000; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 200px; LEFT: 790px" tabindex="-1"></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:36;lineColorBlink:False;Width:1910;" id="shape015" linktype="embedded" parameters="TEXT?ACTIVITY:CH;TEXT?AREA:제품운영1과;TEXT?TANK:-;TEXT?PRODUCT:WAXY;" src=".\MA_CH_OS1_WAXY_files\MA_Toolbar.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 1910px; FONT-FAMILY: Arial; HEIGHT: 36px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 0px; LEFT: 0px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:36;lineColorBlink:False;Width:1910;" id="shape015_group001" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:36;lineColorBlink:False;Width:1910;" id="shape015_group002" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.base.1" hdxproperties="FillColor:#696969;fillColorBlink:False;Height:35;LineColor:#000000;lineColorBlink:False;Width:1910;" id="shape015_rect013" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 97.22%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:35;LineColor:#ffffff;lineColorBlink:False;points:0.000000 100.000000 0.000000 0.000000 100.000000 0.000000 ;Width:1910;" id="shape015_polyline002" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 97.22%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#polyline); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div><input class="hsc.button.1" hdxproperties="fillColor:#00ffff;fillColorBlink:False;HDXBINDINGID:4;lineColorBlink:False;textColor:#000000;textColorBlink:False;" id="shape015_pushbutton001" style="POSITION: absolute; BORDER-BOTTOM-COLOR: #ffffff; TEXT-ALIGN: center; BACKGROUND-COLOR: #00ffff; FONT-STYLE: normal; BORDER-TOP-COLOR: #ffffff; WIDTH: 5.49%; BACKGROUND-REPEAT: no-repeat; FONT-FAMILY: Arial; HEIGHT: 69.44%; COLOR: #000000; BORDER-RIGHT-COLOR: #ffffff; FONT-SIZE: 9pt; BORDER-LEFT-COLOR: #ffffff; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXPushButtonBehavior) url(#BindingBehavior); TOP: 13.88%; LEFT: 37.17%" tabindex="0" type="button" value="MA INDEX"/>
# <div class="hvg.textbox.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;Height:17;LineColor:#ffffff;lineColorBlink:False;LineStyle:1;textColor:#00ff00;textColorBlink:False;TotalRotation:0;Width:105;" id="shape015_textbox001" style="POSITION: absolute; TEXT-ALIGN: center; FONT-STYLE: normal; WIDTH: 5.49%; FONT-FAMILY: Arial; HEIGHT: 47.22%; COLOR: #00ff00; FONT-SIZE: 10pt; OVERFLOW: hidden; FONT-WEIGHT: bold; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 25%; LEFT: 8.63%" tabindex="-1">WAXY</div>
# <div class="hvg.textbox.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;Height:17;LineColor:#ffffff;lineColorBlink:False;LineStyle:1;textColor:#00ff00;textColorBlink:False;TotalRotation:0;Width:65;" id="shape015_textbox002" style="POSITION: absolute; TEXT-ALIGN: center; FONT-STYLE: normal; WIDTH: 3.4%; FONT-FAMILY: Arial; HEIGHT: 47.22%; COLOR: #00ff00; FONT-SIZE: 10pt; OVERFLOW: hidden; FONT-WEIGHT: bold; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 25%; LEFT: 14.65%" tabindex="-1">-</div><input class="hsc.button.1" hdxproperties="fillColor:#00ffff;fillColorBlink:False;HDXBINDINGID:9;lineColorBlink:False;textColor:#000000;textColorBlink:False;" id="shape015_pushbutton005" style="POSITION: absolute; BORDER-BOTTOM-COLOR: #ffffff; BACKGROUND-COLOR: #00ffff; FONT-STYLE: normal; BORDER-TOP-COLOR: #ffffff; WIDTH: 5.49%; BACKGROUND-REPEAT: no-repeat; FONT-FAMILY: Arial; HEIGHT: 69.44%; COLOR: #000000; BORDER-RIGHT-COLOR: #ffffff; FONT-SIZE: 9pt; BORDER-LEFT-COLOR: #ffffff; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXPushButtonBehavior) url(#BindingBehavior); TOP: 13.88%; LEFT: 60%" tabindex="0" type="button" value="TASK SUMMARY"/><input class="hsc.button.1" hdxproperties="fillColor:#00ffff;fillColorBlink:False;HDXBINDINGID:10;lineColorBlink:False;textColor:#000000;textColorBlink:False;" id="shape015_pushbutton006" style="POSITION: absolute; BORDER-BOTTOM-COLOR: #ffffff; BACKGROUND-COLOR: #00ffff; FONT-STYLE: normal; BORDER-TOP-COLOR: #ffffff; WIDTH: 5.49%; BACKGROUND-REPEAT: no-repeat; FONT-FAMILY: Arial; HEIGHT: 69.44%; COLOR: #000000; BORDER-RIGHT-COLOR: #ffffff; FONT-SIZE: 9pt; BORDER-LEFT-COLOR: #ffffff; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXPushButtonBehavior) url(#BindingBehavior); TOP: 13.88%; LEFT: 65.7%" tabindex="0" type="button" value="TRANSFER - OS1"/><input class="hsc.button.1" hdxproperties="fillColor:#00ffff;fillColorBlink:False;HDXBINDINGID:11;lineColorBlink:False;textColor:#000000;textColorBlink:False;" id="shape015_pushbutton007" style="POSITION: absolute; BORDER-BOTTOM-COLOR: #ffffff; BACKGROUND-COLOR: #00ffff; FONT-STYLE: normal; BORDER-TOP-COLOR: #ffffff; WIDTH: 5.49%; BACKGROUND-REPEAT: no-repeat; FONT-FAMILY: Arial; HEIGHT: 69.44%; COLOR: #000000; BORDER-RIGHT-COLOR: #ffffff; FONT-SIZE: 9pt; BORDER-LEFT-COLOR: #ffffff; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXPushButtonBehavior) url(#BindingBehavior); TOP: 13.88%; LEFT: 71.41%" tabindex="0" type="button" value="TRANSFER - OS2"/><input class="hsc.button.1" hdxproperties="fillColor:#00ffff;fillColorBlink:False;HDXBINDINGID:12;lineColorBlink:False;textColor:#000000;textColorBlink:False;" id="shape015_pushbutton008" style="POSITION: absolute; BORDER-BOTTOM-COLOR: #ffffff; BACKGROUND-COLOR: #00ffff; FONT-STYLE: normal; BORDER-TOP-COLOR: #ffffff; WIDTH: 5.49%; BACKGROUND-REPEAT: no-repeat; FONT-FAMILY: Arial; HEIGHT: 69.44%; COLOR: #000000; BORDER-RIGHT-COLOR: #ffffff; FONT-SIZE: 9pt; BORDER-LEFT-COLOR: #ffffff; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXPushButtonBehavior) url(#BindingBehavior); TOP: 13.88%; LEFT: 77.12%" tabindex="0" type="button" value="LOADING"/><input class="hsc.button.1" hdxproperties="fillColor:#00ffff;fillColorBlink:False;HDXBINDINGID:13;lineColorBlink:False;textColor:#000000;textColorBlink:False;" id="shape015_pushbutton009" style="POSITION: absolute; BORDER-BOTTOM-COLOR: #ffffff; BACKGROUND-COLOR: #00ffff; FONT-STYLE: normal; BORDER-TOP-COLOR: #ffffff; WIDTH: 5.49%; BACKGROUND-REPEAT: no-repeat; FONT-FAMILY: Arial; HEIGHT: 69.44%; COLOR: #000000; BORDER-RIGHT-COLOR: #ffffff; FONT-SIZE: 9pt; BORDER-LEFT-COLOR: #ffffff; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXPushButtonBehavior) url(#BindingBehavior); TOP: 13.88%; LEFT: 82.82%" tabindex="0" type="button" value="UNLOADING"/><input class="hsc.button.1" hdxproperties="fillColor:#00ffff;fillColorBlink:False;HDXBINDINGID:14;lineColorBlink:False;textColor:#000000;textColorBlink:Fal ...
# <div class="hvg.textbox.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;Height:17;LineColor:#ffffff;lineColorBlink:False;LineStyle:1;textColor:#00ff00;textColorBlink:False;TotalRotation:0;Width:105;" id="shape015_textbox005" style="POSITION: absolute; TEXT-ALIGN: center; FONT-STYLE: normal; WIDTH: 5.49%; FONT-FAMILY: Arial; HEIGHT: 47.22%; COLOR: #00ff00; FONT-SIZE: 10pt; OVERFLOW: hidden; FONT-WEIGHT: bold; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 25%; LEFT: 2.61%" tabindex="-1">제품운영1과</div>
# <div class="hvg.textbox.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;Height:17;LineColor:#ffffff;lineColorBlink:False;LineStyle:1;textColor:#00ff00;textColorBlink:False;TotalRotation:0;Width:30;" id="shape015_textbox006" style="POSITION: absolute; TEXT-ALIGN: center; FONT-STYLE: normal; WIDTH: 1.57%; FONT-FAMILY: Arial; HEIGHT: 47.22%; COLOR: #00ff00; FONT-SIZE: 10pt; OVERFLOW: hidden; FONT-WEIGHT: bold; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 25%; LEFT: 0.52%" tabindex="-1">CH</div><input class="hsc.button.1" hdxproperties="fillColor:#00ffff;fillColorBlink:False;HDXBINDINGID:16;lineColorBlink:False;textColor:#000000;textColorBlink:False;" id="shape015_pushbutton002" style="POSITION: absolute; BORDER-BOTTOM-COLOR: #ffffff; TEXT-ALIGN: center; BACKGROUND-COLOR: #00ffff; FONT-STYLE: normal; BORDER-TOP-COLOR: #ffffff; WIDTH: 5.49%; BACKGROUND-REPEAT: no-repeat; FONT-FAMILY: Arial; HEIGHT: 69.44%; COLOR: #000000; BORDER-RIGHT-COLOR: #ffffff; FONT-SIZE: 9pt; BORDER-LEFT-COLOR: #ffffff; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXPushButtonBehavior) url(#BindingBehavior); TOP: 13.88%; LEFT: 42.87%" tabindex="0" type="button" value="OS1 OVERVIEW"/><input class="hsc.button.1" hdxproperties="fillColor:#00ffff;fillColorBlink:False;HDXBINDINGID:17;lineColorBlink:False;textColor:#000000;textColorBlink:False;" id="shape015_pushbutton003" style="POSITION: absolute; BORDER-BOTTOM-COLOR: #ffffff; TEXT-ALIGN: center; BACKGROUND-COLOR: #00ffff; FONT-STYLE: normal; BORDER-TOP-COLOR: #ffffff; WIDTH: 5.49%; BACKGROUND-REPEAT: no-repeat; FONT-FAMILY: Arial; HEIGHT: 69.44%; COLOR: #000000; BORDER-RIGHT-COLOR: #ffffff; FONT-SIZE: 9pt; BORDER-LEFT-COLOR: #ffffff; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXPushButtonBehavior) url(#BindingBehavior); TOP: 13.88%; LEFT: 48.58%" tabindex="0" type="button" value="OS2 OVERVIEW"/><input class="hsc.button.1" hdxproperties="fillColor:#00ffff;fillColorBlink:False;HDXBINDINGID:19;lineColorBlink:False;textColor:#000000;textColorBlink:False;" id="shape015_pushbutton004" style="POSITION: absolute; BORDER-BOTTOM-COLOR: #ffffff; TEXT-ALIGN: center; BACKGROUND-COLOR: #00ffff; FONT-STYLE: normal; BORDER-TOP-COLOR: #ffffff; WIDTH: 5.49%; BACKGROUND-REPEAT: no-repeat; FONT-FAMILY: Arial; HEIGHT: 69.44%; COLOR: #000000; BORDER-RIGHT-COLOR: #ffffff; FONT-SIZE: 9pt; BORDER-LEFT-COLOR: #ffffff; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXPushButtonBehavior) url(#BindingBehavior); TOP: 13.88%; LEFT: 54.29%" tabindex="0" type="button" value="ML OVERVIEW"/><input class="hsc.button.1" hdxproperties="fillColor:#00ffff;fillColorBlink:False;HDXBINDINGID:20;lineColorBlink:False;textColor:#000000;textColorBlink:False;" id="shape015_pushbutton011" style="POSITION: absolute; BORDER-BOTTOM-COLOR: #ffffff; TEXT-ALIGN: center; BACKGROUND-COLOR: #00ffff; FONT-STYLE: normal; BORDER-TOP-COLOR: #ffffff; WIDTH: 5.49%; BACKGROUND-REPEAT: no-repeat; FONT-FAMILY: Arial; HEIGHT: 69.44%; COLOR: #000000; BORDER-RIGHT-COLOR: #ffffff; FONT-SIZE: 9pt; BORDER-LEFT-COLOR: #ffffff; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXPushButtonBehavior) url(#BindingBehavior); TOP: 13.88%; LEFT: 30.1%" tabindex="0" type="button" value="ULSD BMA"/><input class="hsc.button.1" hdxproperties="fillColor:#00ffff;fillColorBlink:False;HDXBINDINGID:21;lineColorBlink:False;textColor:#000000;textColorBlink:False;" id="shape015_pushbutton013" style="POSITION: absolute; BORDER-BOTTOM-COLOR: #ffffff; TEXT-ALIGN: center; BACKGROUND-COLOR: #00ffff; FONT-STYLE: normal; BORDER-TOP-COLOR: #ffffff; WIDTH: 5.49%; BACKGROUND-REPEAT: no-repeat; FONT-FAMILY: Arial; HEIGHT: 69.44%; COLOR: #000000; BORDER-RIGHT-COLOR: #ffffff; FONT-SIZE: 9pt; BORDER-LEFT-COLOR: #ffffff; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXPushButtonBehavior) url(#BindingBehavior); TOP: 13.88%; LEFT: 24.34%" tabindex="0" type="button" value="HSBC BMA"/><input class="hsc.button.1" hdxproperties="fillColor:#0 ...
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:18;lineColorBlink:False;Width:95;" id="shape027" linktype="embedded" parameters="T?T:U-2400;" src=".\MA_CH_OS1_WAXY_files\NameTag.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 95px; FONT-FAMILY: Arial; HEIGHT: 18px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 70px; LEFT: 1810px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:18;lineColorBlink:False;Width:95;" id="shape027_group001" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.base.1" hdxproperties="FillColor:#00ffff;fillColorBlink:False;FillStyle:2;GradientFillColor:#008b8b;GradientFillFocus:0;Height:18;LineColor:#c0c0c0;lineColorBlink:False;LineWidth:2;Width:94;" id="shape027_rect001" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 99.1%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0.44%" tabindex="-1"></div>
# <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:15;lineColorBlink:False;LineStyle:0;textColor:#000000;textColorBlink:False;TotalRotation:0;Width:94;" id="shape027_textbox001" style="POSITION: absolute; TEXT-ALIGN: center; FONT-STYLE: normal; WIDTH: 99.1%; FONT-FAMILY: Arial; HEIGHT: 81.81%; COLOR: #000000; FONT-SIZE: 10pt; OVERFLOW: hidden; FONT-WEIGHT: bold; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 4.54%; LEFT: 0%" tabindex="-1">U-2400</div></div></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Width:30;" id="shape414" linktype="embedded" parameters="Point?element:MAV_OS1_054_002;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;" src=".\MA_CH_OS1_WAXY_files\TFGValveMAN_H.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 85px; LEFT: 200px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Width:30;" id="shape414_group001" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="FillColor:#a0a0a0;fillColorBlink:False;HDXBINDINGID:8;Height:10;LineColor:#000000;lineColorBlink:False;ObjectType:10;points:100 0 93.75 0 50 50 100 100 50 50 6.25 0 0 0 0 100 ;PointTypes:m l l lx m l l lx ;Width:20;" id="shape414_plyValve" ondatachange="VBScript:Call OnDataChange(me.parentElement.parentElement, me)" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 66.66%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#polygon) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 16.66%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;GradientFillColor:#808080;Height:10;LineColor:#c0c0c0;lineColorBlink:False;LineStyle:0;LineWidth:2;Width:30;" id="shape414_recSelectBox" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:35;lineColorBlink:False;Width:35;" id="shape273" linktype="embedded" parameters="Point?element:_P53102A;Value?DefElemType:4;Value?ShapeID:CPump;Value?DataBoundObj:plyPump;" src=".\MA_CH_OS1_WAXY_files\CPUMP_R.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 35px; FONT-FAMILY: Arial; HEIGHT: 35px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 75px; LEFT: 1195px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:35;lineColorBlink:False;Width:35;" id="shape273_group001" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:0;GradientFillColor:#c0c0c0;HDXBINDINGID:3;Height:31;LineColor:#000000;lineColorBlink:False;ObjectType:10;Points:87.78318 44.8718 87.78318 20.1282 68.73763 0 45.05276 0 21.48999 0 2.322369 20.1282 2.322369 44.8718 2.322369 69.61539 21.48999 89.74359 45.05276 89.74359 68.73763 89.74359 87.78318 69.61539 87.78318 44.8718 75.57449 76.92308 75.08614 76.92308 72.27813 79.48718 68.9818 82.05128 65.44128 84.35898 61.65658 86.28206 57.74981 87.82051 53.72093 88.84616 49.44789 89.48718 44.93068 89.74359 40.53557 89.48718 36.26251 88.84616 32.23365 87.82051 28.32688 86.28206 24.54218 84.35898 21.00166 82.05128 17.70531 79.48718 15.99609 77.94872 -2.561113 100 95.10838 100 100 0 45.05276 0 49.44789 0.2564063 53.72093 0.897432 57.74981 2.05128 61.65658 3.461535 65.44128 5.384612 68.9818 7.692307 72.27813 10.25641 75.33031 13.07692 78.01624 16.28205 80.45798 19.74359 82.41135 23.07692 100 23.07692 45.05276 0 43.83191 0 43.83191 0.1282032 ;PointTypes:m c c c c c c c c c c c cx m l l l l l l l l l l l l l l l l l l lx m l l l l l l l l l l l l lx m l lx ;Width:27;" id="shape273_plyPump" ondatachange="VBScript:Call OnDataChange(me.parentElement.parentElement, me)" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 76.31%; FONT-FAMILY: Arial; HEIGHT: 87.87%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#oval) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 6.06%; LEFT: 10.52%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:1;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:4;points:107.1429 0 0 0 ;Width:9;" id="shape273_linInlet" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 26.31%; FONT-FAMILY: Arial; HEIGHT: 1.51%; VISIBILITY: hidden; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 46.96%; LEFT: 34.21%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:1;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:4;points:100 0 0 0 ;Width:4;" id="shape273_linOutlet" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 10.52%; FONT-FAMILY: Arial; HEIGHT: 1.51%; VISIBILITY: hidden; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 42.42%; LEFT: 47.36%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:#000000;fillColorBlink:False;FillStyle:0;GradientFillColor:#696969;GradientFillStyle:0;Height:4;LineColor:#000000;lineColorBlink:False;Width:4;" id="shape273_recMotor" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 10.52%; FONT-FAMILY: Arial; HEIGHT: 12.12%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#oval); TOP: 40.9%; LEFT: 39.47%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;Height:35;LineColor:#90ee90;lineColorBlink:False;LineStyle:0;LineWidth:2;Width:35;" id="shape273_recSelectBox" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div></div>
# <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:15;lineColorBlink:False;LineStyle:0;textColor:#ffffff;textColorBlink:False;TotalRotation:0;Width:50;" id="textbox032" style="POSITION: absolute; TEXT-ALIGN: center; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 15px; COLOR: #ffffff; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 110px; LEFT: 1187px" tabindex="-1">P53102A</div>
# <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:15;lineColorBlink:False;LineStyle:0;textColor:#ffffff;textColorBlink:False;TotalRotation:0;Width:50;" id="textbox121" style="POSITION: absolute; TEXT-ALIGN: center; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 15px; COLOR: #ffffff; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 75px; LEFT: 150px" tabindex="-1">6"</div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:80;lineColorBlink:False;Width:125;" id="shape050" linktype="embedded" parameters="Point?element:TK53104;Value?DefElemType:1;Value?ShapeID:TankNozzle;Value?DataBoundObj:shaTank;" src=".\MA_CH_OS1_WAXY_files\IFRT_TANK_ovr.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 125px; FONT-FAMILY: Arial; HEIGHT: 80px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 40px; LEFT: 10px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:80;lineColorBlink:False;Width:125;" id="shape050_grpShape" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hsc.shape.1 HSC.ScriptDataObject.1" globalscripts="" hdxproperties="fillColorBlink:False;HDXBINDINGID:24;Height:62;lineColorBlink:False;Width:113;" id="shape050_shaTank" linktype="embedded" ondatachange="VBScript:Call OnDataChange(me.parentElement.parentElement, me)" parameters="" src=".\MA_CH_OS1_WAXY_files\IFRT_TANK_ovr_files\soilcrtankbox.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 90.76%; FONT-FAMILY: Arial; HEIGHT: 77.5%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 15%; LEFT: 5.38%" styleclass="" tabindex="-1" value="1">
# <div class="hvg.group.1" hdxproperties="FillColor:#ffffff;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillFocus:50;GradientFillStyle:0;Height:62;lineColorBlink:False;Width:113;" id="shape050_shaTank_group001" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.base.1" hdxproperties="FillColor:#ffffff;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:20;LineColor:#000000;lineColorBlink:False;Width:81;" id="shape050_shaTank_oval1" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 71.34%; FONT-FAMILY: Arial; HEIGHT: 32.23%; VISIBILITY: hidden; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#oval); TOP: 37.5%; LEFT: 10.97%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:#ffffff;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:62;LineColor:#c0c0c0;lineColorBlink:False;LineWidth:4;ObjectType:10;Points:93.70629 94.23077 98.6014 94.23077 98.6014 91.34615 98.6014 29.80769 98.6014 25.96154 101.3986 25.96154 49.65035 -0.9615384 -2.097902 25 1.293711 25.09616 0.6993007 25.09616 0.6993007 91.34615 0.6993007 94.23077 5.594406 94.23077 5.594406 100 16.08392 100 16.08392 94.23077 26.57343 91.34615 72.72727 91.34615 83.21678 94.23077 83.21678 100 93.70629 100 ;PointTypes:m l l l l l l l l l l l l l l l l l l l lx ;Rotation:0;textColor:#000000;Width:112;" id="shape050_shaTank_roundrect6" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 99.39%; FONT-FAMILY: Arial; HEIGHT: 99.34%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div></div>
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:6;lineColorBlink:False;Width:110;" id="shape050_grpRoof" style="POSITION: absolute; WIDTH: 87.69%; HEIGHT: 7.5%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 35%; LEFT: 7.69%" tabindex="-1">
# <div class="hvg.base.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:1;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:0.000000 0.000000 100.000000 0.000000 ;textColor:#000000;Width:109;" id="shape050_line009" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 99.35%; FONT-FAMILY: Arial; HEIGHT: 12.5%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 0%; LEFT: 0%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:1;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:0.000000 0.000000 100.000000 0.000000 ;textColor:#000000;Width:90;" id="shape050_line010" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 81.41%; FONT-FAMILY: Arial; HEIGHT: 12.5%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 87.5%; LEFT: 10.25%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:5;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:0.000000 0.000000 0.000000 100.000000 ;textColor:#000000;Width:1;" id="shape050_line011" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 0.64%; FONT-FAMILY: Arial; HEIGHT: 87.5%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 12.5%; LEFT: 91.66%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:5;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:0.000000 0.000000 0.000000 100.000000 ;textColor:#000000;Width:1;" id="shape050_line012" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 0.64%; FONT-FAMILY: Arial; HEIGHT: 87.5%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 12.5%; LEFT: 10.89%" tabindex="-1"></div></div><textarea class="hsc.alpha.1 " hdxproperties="borderWidth:;fillColor:transparent;fillColorBlink:False;HDXBINDINGID:25;indicateScanState:0;lineColor:black;lineColorBlink:False;numberOfChars:4;numericDisplayFormat:%s;styleClass:;textColor:#ff0000;textColorBlink:False;" id="shape050_alpAlarmAbrv" style="POSITION: absolute; BORDER-BOTTOM-STYLE: none; BORDER-BOTTOM-COLOR: transparent; TEXT-ALIGN: center; BACKGROUND-COLOR: transparent; FONT-STYLE: normal; BORDER-TOP-COLOR: transparent; BORDER-LEFT-STYLE: none; WIDTH: 21.53%; FONT-FAMILY: Arial; WORD-WRAP: normal; BORDER-TOP-STYLE: none; HEIGHT: 11.25%; COLOR: #ff0000; BORDER-RIGHT-COLOR: transparent; BORDER-RIGHT-STYLE: none; FONT-SIZE: 5pt; OVERFLOW: hidden; BORDER-LEFT-COLOR: transparent; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXAlphaBehavior) url(#BindingBehavior); TOP: 63.75%; LEFT: 18.46%; ROWS: 1" tabindex="-1">Text</textarea>
# <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:17;lineColorBlink:False;LineStyle:0;textColor:#000000;textColorBlink:False;TotalRotation:0;Width:72;" id="shape050_txtElementName" style="POSITION: absolute; TEXT-ALIGN: center; FONT-STYLE: normal; WIDTH: 57.69%; FONT-FAMILY: Arial; HEIGHT: 21.25%; COLOR: #000000; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: bold; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 17.5%; LEFT: 20%" tabindex="-1">TK53104</div><span class="hsc.indicator.1 " hdxproperties="borderStyle:inset;borderWidth:2px;BreakpointType:1;fillColor:transparent;fillColorBlink:0;HDXBINDINGID:26;indicateAlarmState:0;levelFillColor:deepskyblue;levelFillColorBlink:0;lineColor:#ffffff;lineColorBlink:0;styleClass:;" id="shape050_indLevel" printfillcolor="transparent" printinverse="false" printlevelfillcolor="#008080" printvaluepercent="33" style="BORDER-BOTTOM: transparent 2px; POSITION: absolute; BORDER-LEFT: transparent 2px; FONT-STYLE: normal; WIDTH: 7.69%; FONT-FAMILY: Arial; HEIGHT: 43.75%; COLOR: #000000; FONT-SIZE: 0pt; OVERFLOW: hidden; BORDER-TOP: transparent 2px; FONT-WEIGHT: 400; BORDER-RIGHT: transparent 2px; TEXT-DECORATION: none; BEHAVIOR: url(#HSCIndicatorBehavior) url(#BindingBehavior); TOP: 43.75%; LEFT: 10%" tabindex="-1"></span>
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:6;LineColor:#000000;lineColorBlink:False;Width:7;" id="shape050_group002" style="POSITION: absolute; WIDTH: 5.38%; HEIGHT: 7.5%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 8.75%; LEFT: 50.76%" tabindex="-1">
# <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:6;LineColor:#c0c0c0;lineColorBlink:False;LineWidth:4;points:0 0 0 100 ;Width:1;" id="shape050_line001" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 10%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 0%; LEFT: 10%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:3;LineColor:#c0c0c0;lineColorBlink:False;LineWidth:4;points:-0.7468087 41.59325 33.86841 -81.48369 95.4071 -13.79135 99.25319 100.0548 ;Rotation:345;Width:6;" id="shape050_bezier002" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 90%; FONT-FAMILY: Arial; HEIGHT: 57.14%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#bezier); TOP: 7.14%; LEFT: 0%" tabindex="-1"></div></div>
# <div class="hsc.shape.1 hsc.shapeanimation.1" globalscripts="" hdxproperties="fillColorBlink:False;HDXBINDINGID:27;Height:13;indicateAlarmState:False;indicateScanState:False;lineColorBlink:False;Width:12;" id="shape050_shaTankService" linktype="embedded" numberofshapesanimated="5" parameters="" src=".\MA_CH_OS1_WAXY_files\IFRT_TANK_ovr_files\tfgTankService.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 9.23%; FONT-FAMILY: Arial; HEIGHT: 16.25%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior); TOP: 47.5%; LEFT: 23.07%" styleclass="" tabindex="-1" value="1">
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:13;lineColorBlink:False;Width:12;" id="shape050_shaTankService_grpOOService" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;Height:13;lineColorBlink:False;LineStyle:0;Width:12;" id="shape050_shaTankService_recOOS" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:5;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:100.000000 0.000000 0.000000 100.000000 ;Width:4;" id="shape050_shaTankService_plyOOS1" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 35.71%; FONT-FAMILY: Arial; HEIGHT: 35.71%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#polyline); TOP: 35.71%; LEFT: 35.71%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;Height:8;LineColor:#000000;lineColorBlink:False;LineWidth:2;Width:8;" id="shape050_shaTankService_ovlOOS" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 64.28%; FONT-FAMILY: Arial; HEIGHT: 64.28%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#oval); TOP: 21.42%; LEFT: 21.42%" tabindex="-1"></div></div></div>
# <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:1;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:6;points:0.000000 0.000000 100.000000 0.000000 ;Width:7;" id="shape050_linNozzle" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 5.38%; FONT-FAMILY: Arial; HEIGHT: 1.25%; VISIBILITY: hidden; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 72.5%; LEFT: 66.15%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;Height:80;LineColor:transparent;lineColorBlink:False;LineStyle:0;LineWidth:2;Width:125;" id="shape050_recSelectBox" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div>
# <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:14;lineColorBlink:False;LineStyle:0;textColor:#00004a;textColorBlink:False;TotalRotation:0;Width:24;" id="shape050_textbox001" style="POSITION: absolute; TEXT-ALIGN: left; FONT-STYLE: normal; WIDTH: 19.23%; FONT-FAMILY: Arial; HEIGHT: 17.5%; COLOR: #00004a; FONT-SIZE: 7pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 45%; LEFT: 73.84%" tabindex="-1">DegC</div><textarea class="hsc.alpha.1" hdxproperties="fillColor:transparent;fillColorBlink:False;HDXBINDINGID:28;lineColor:black;numberOfChars:9;numericDisplayFormat:%.1f;textColor:#00004a;textColorBlink:False;" id="shape050_alpha001" style="POSITION: absolute; BORDER-BOTTOM-STYLE: none; TEXT-ALIGN: right; BACKGROUND-COLOR: transparent; FONT-STYLE: normal; BORDER-LEFT-STYLE: none; WIDTH: 45.38%; FONT-FAMILY: Arial; WORD-WRAP: normal; BORDER-TOP-STYLE: none; HEIGHT: 16.25%; COLOR: #00004a; BORDER-RIGHT-STYLE: none; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXAlphaBehavior) url(#BindingBehavior) url(#HoverBehavior); TOP: 42.5%; LEFT: 27.69%; ROWS: 1" tabindex="0">9999.99</textarea><textarea class="hsc.alpha.1" hdxproperties="fillColor:transparent;fillColorBlink:False;HDXBINDINGID:29;lineColor:black;lineColorBlink:False;numberOfChars:9;numericDisplayFormat:%.0f;textColor:#00004a;textColorBlink:False;" id="shape050_alpha003" style="POSITION: absolute; BORDER-BOTTOM-STYLE: none; TEXT-ALIGN: right; BACKGROUND-COLOR: transparent; FONT-STYLE: normal; BORDER-LEFT-STYLE: none; WIDTH: 45.38%; FONT-FAMILY: Arial; WORD-WRAP: normal; BORDER-TOP-STYLE: none; HEIGHT: 16.25%; COLOR: #00004a; BORDER-RIGHT-STYLE: none; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXAlphaBehavior) url(#BindingBehavior) url(#HoverBehavior); TOP: 56.25%; LEFT: 26.92%; ROWS: 1" tabindex="0">9999.99</textarea>
# ...
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Width:30;" id="shape696_group001" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="FillColor:#a0a0a0;fillColorBlink:False;HDXBINDINGID:568;Height:10;LineColor:#000000;lineColorBlink:False;ObjectType:10;points:100 0 93.75 0 50 50 100 100 50 50 6.25 0 0 0 0 100 ;PointTypes:m l l lx m l l lx ;Width:20;" id="shape696_plyValve" ondatachange="VBScript:Call OnDataChange(me.parentElement.parentElement, me)" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 66.66%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#polygon) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 16.66%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;GradientFillColor:#808080;Height:10;LineColor:#c0c0c0;lineColorBlink:False;LineStyle:0;LineWidth:2;Width:30;" id="shape696_recSelectBox" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Width:40;" id="shape697" linktype="embedded" parameters="Point?element:MAL_OS1_2430;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:;Value?EndPoint2:;" src=".\MA_CH_OS1_WAXY_files\MALineH.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 40px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 660px; LEFT: 885px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="fillColorBlink:False;HDXBINDINGID:331;Height:10;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:2;points:0 0 100 0 ;Width:40;" id="shape697_linPipe" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div>
# <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:20;LineColor:#ff0000;lineColorBlink:False;points:0.000000 100.000000 0.000000 0.000000 ;Width:1;" id="line001" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 1px; FONT-FAMILY: Arial; HEIGHT: 20px; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 350px; LEFT: 890px" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:#ff0000;fillColorBlink:False;Height:10;LineColor:#000000;lineColorBlink:False;Width:10;" id="oval001" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#oval); TOP: 345px; LEFT: 885px" tabindex="-1"></div>
# <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:15;lineColorBlink:False;LineStyle:0;textColor:#ffffff;textColorBlink:False;TotalRotation:0;Width:50;" id="textbox136" style="POSITION: absolute; TEXT-ALIGN: center; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 15px; COLOR: #ffffff; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 610px; LEFT: 150px" tabindex="-1">3"</div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:30;lineColorBlink:False;Width:10;" id="shape698" linktype="embedded" parameters="Point?element:MAL_OS1_483;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_069;Value?EndPoint2:;" src=".\MA_CH_OS1_WAXY_files\MALineU.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 630px; LEFT: 760px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="fillColorBlink:False;HDXBINDINGID:280;Height:30;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:2;points:0 0 0 100.4167 ;Width:10;" id="shape698_linPipe" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Width:105;" id="shape699" linktype="embedded" parameters="Point?element:MAL_OS1_483;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_069;Value?EndPoint2:;" src=".\MA_CH_OS1_WAXY_files\MALineH.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 105px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 660px; LEFT: 760px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="fillColorBlink:False;HDXBINDINGID:282;Height:10;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:2;points:0 0 100 0 ;Width:105;" id="shape699_linPipe" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:30;lineColorBlink:False;Width:10;" id="shape592" linktype="embedded" parameters="Point?element:MAL_OS1_2424;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_162;Value?EndPoint2:MAV010;" src=".\MA_CH_OS1_WAXY_files\MALineU.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 575px; LEFT: 1390px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="fillColorBlink:False;HDXBINDINGID:300;Height:30;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:2;points:0 0 0 100.4167 ;Width:10;" id="shape592_linPipe" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Width:30;" id="shape517" linktype="embedded" parameters="Point?element:MAV_OS1_022_162;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;" src=".\MA_CH_OS1_WAXY_files\TFGValveMAN_H.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 600px; LEFT: 1435px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Width:30;" id="shape517_group001" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="FillColor:#a0a0a0;fillColorBlink:False;HDXBINDINGID:390;Height:10;LineColor:#000000;lineColorBlink:False;ObjectType:10;points:100 0 93.75 0 50 50 100 100 50 50 6.25 0 0 0 0 100 ;PointTypes:m l l lx m l l lx ;Width:20;" id="shape517_plyValve" ondatachange="VBScript:Call OnDataChange(me.parentElement.parentElement, me)" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 66.66%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#polygon) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 16.66%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;GradientFillColor:#808080;Height:10;LineColor:#c0c0c0;lineColorBlink:False;LineStyle:0;LineWidth:2;Width:30;" id="shape517_recSelectBox" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Width:50;" id="shape384" linktype="embedded" parameters="Point?element:MAL_OS1_2424;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_162;Value?EndPoint2:;" src=".\MA_CH_OS1_WAXY_files\MALineH.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 605px; LEFT: 1390px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="fillColorBlink:False;HDXBINDINGID:299;Height:10;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:2;points:0 0 100 0 ;Width:50;" id="shape384_linPipe" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Width:50;" id="shape402" linktype="embedded" parameters="Point?element:MAL_OS1_2424;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_059;Value?EndPoint2:;" src=".\MA_CH_OS1_WAXY_files\MALineH.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 575px; LEFT: 1390px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="fillColorBlink:False;HDXBINDINGID:298;Height:10;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:2;points:0 0 100 0 ;Width:50;" id="shape402_linPipe" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Width:30;" id="shape494" linktype="embedded" parameters="Point?element:MAV_OS1_018_065;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;" src=".\MA_CH_OS1_WAXY_files\TFGValveMAN_H.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 500px; LEFT: 495px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Width:30;" id="shape494_group001" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="FillColor:#a0a0a0;fillColorBlink:False;HDXBINDINGID:95;Height:10;LineColor:#000000;lineColorBlink:False;ObjectType:10;points:100 0 93.75 0 50 50 100 100 50 50 6.25 0 0 0 0 100 ;PointTypes:m l l lx m l l lx ;Width:20;" id="shape494_plyValve" ondatachange="VBScript:Call OnDataChange(me.parentElement.parentElement, me)" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 66.66%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#polygon) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 16.66%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;GradientFillColor:#808080;Height:10;LineColor:#c0c0c0;lineColorBlink:False;LineStyle:0;LineWidth:2;Width:30;" id="shape494_recSelectBox" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div></div>
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:15;lineColorBlink:False;Width:70;" id="shape275" linktype="embedded" parameters="Point?element:MAL_OS1_312;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_065;Value?EndPoint2:;" src=".\MA_CH_OS1_WAXY_files\MALineH.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 70px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 505px; LEFT: 520px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="fillColorBlink:False;HDXBINDINGID:253;Height:15;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:2;points:0 0 100 0 ;Width:70;" id="shape275_linPipe" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div>
# <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:15;lineColorBlink:False;LineStyle:0;textColor:#ffffff;textColorBlink:False;TotalRotation:0;Width:75;" id="textbox040" style="POSITION: absolute; TEXT-ALIGN: center; FONT-STYLE: normal; WIDTH: 75px; FONT-FAMILY: Arial; HEIGHT: 15px; COLOR: #ffffff; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 775px; LEFT: 475px" tabindex="-1">P5397
# A/B</div>
# <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:15;lineColorBlink:False;LineStyle:0;textColor:#ffffff;textColorBlink:False;TotalRotation:0;Width:50;" id="textbox137" style="POSITION: absolute; TEXT-ALIGN: center; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 15px; COLOR: #ffffff; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 95px; LEFT: 1620px" tabindex="-1">4"</div></div>

# %%
divpm = main.findAll('div',attrs = {'parameters':True})
len(divpm)
# Out:
# bs4.element.ResultSet

# %%
total = {}
for i,div in enumerate(divpm):
    
    total[div['id']] = {'id':div['id'], 'no':i}
    
    param = {}
    for p in div['parameters'].split(';'):
        param.update(dict(zip(p.split(':')[::2], p.split(':')[1::2])))
    total[div['id']].update(param)
    
    style = {}
    for s in div['style'].split('; '):
        style.update(dict(zip(s.split(':')[::2], s.split(': ')[1::2])))
    total[div['id']].update(style)
    
    properties = {}
    for t in div['hdxproperties'].split(';'):
        properties.update(dict(zip(t.split(':')[::2], t.split(':')[1::2])))
    
    total[div['id']].update(properties)
    
total
# Out:
# {'PseudoValve039': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '85px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve039',
#   'lineColorBlink': 'False',
#   'no': 228},
#  'PseudoValve040': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '75px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve040',
#   'lineColorBlink': 'False',
#   'no': 229},
#  'PseudoValve041': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '295px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve041',
#   'lineColorBlink': 'False',
#   'no': 230},
#  'PseudoValve042': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '280px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve042',
#   'lineColorBlink': 'False',
#   'no': 231},
#  'PseudoValve043': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '435px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve043',
#   'lineColorBlink': 'False',
#   'no': 232},
#  'PseudoValve044': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve044',
#   'lineColorBlink': 'False',
#   'no': 233},
#  'PseudoValve045': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '585px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve045',
#   'lineColorBlink': 'False',
#   'no': 234},
#  'PseudoValve046': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '570px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve046',
#   'lineColorBlink': 'False',
#   'no': 235},
#  'PseudoValve047': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '685px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve047',
#   'lineColorBlink': 'False',
#   'no': 236},
#  'PseudoValve048': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '670px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve048',
#   'lineColorBlink': 'False',
#   'no': 237},
#  'PseudoValve049': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '840px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve049',
#   'lineColorBlink': 'False',
#   'no': 238},
#  'PseudoValve050': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1235px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '825px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve050',
#   'lineColorBlink': 'False',
#   'no': 239},
#  'shape001': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '29px',
#   'Height': '29',
#   'LEFT': '5px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '0px',
#   'WIDTH': '103px',
#   'Width': '103',
#   'fillColorBlink': 'False',
#   'id': 'shape001',
#   'lineColorBlink': 'False',
#   'no': 2},
#  'shape015': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '36px',
#   'Height': '36',
#   'LEFT': '0px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TEXT?ACTIVITY': 'CH',
#   'TEXT?AREA': '제품운영1과',
#   'TEXT?PRODUCT': 'WAXY',
#   'TEXT?TANK': '-',
#   'TOP': '0px',
#   'WIDTH': '1910px',
#   'Width': '1910',
#   'fillColorBlink': 'False',
#   'id': 'shape015',
#   'lineColorBlink': 'False',
#   'no': 7},
#  'shape023': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53104',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31',
#   'TOP': '115px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape023',
#   'lineColorBlink': 'False',
#   'no': 14},
#  'shape024': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53105',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-96S',
#   'TOP': '220px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape024',
#   'lineColorBlink': 'False',
#   'no': 18},
#  'shape025': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53106',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-20',
#   'TOP': '325px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape025',
#   'lineColorBlink': 'False',
#   'no': 22},
#  'shape027': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-2400',
#   'TEXT-DECORATION': 'none',
#   'TOP': '70px',
#   'WIDTH': '95px',
#   'Width': '95',
#   'fillColorBlink': 'False',
#   'id': 'shape027',
#   'lineColorBlink': 'False',
#   'no': 8},
#  'shape028': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53107',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-116',
#   'TOP': '430px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape028',
#   'lineColorBlink': 'False',
#   'no': 26},
#  'shape029': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53109',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-480',
#   'TOP': '540px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape029',
#   'lineColorBlink': 'False',
#   'no': 30},
#  'shape030': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31S',
#   'TOP': '650px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape030',
#   'lineColorBlink': 'False',
#   'no': 34},
#  'shape031': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31S',
#   'TOP': '765px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape031',
#   'lineColorBlink': 'False',
#   'no': 38},
#  'shape032': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK5397',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'Mix-W',
#   'TOP': '865px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape032',
#   'lineColorBlink': 'False',
#   'no': 42},
#  'shape033': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-2600',
#   'TEXT-DECORATION': 'none',
#   'TOP': '415px',
#   'WIDTH': '95px',
#   'Width': '95',
#   'fillColorBlink': 'False',
#   'id': 'shape033',
#   'lineColorBlink': 'False',
#   'no': 53},
#  'shape035': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-20200',
#   'TEXT-DECORATION': 'none',
#   'TOP': '820px',
#   'WIDTH': '95px',
#   'Width': '95',
#   'fillColorBlink': 'False',
#   'id': 'shape035',
#   'lineColorBlink': 'False',
#   'no': 175},
#  'shape050': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53104',
#   'TEXT-DECORATION': 'none',
#   'TOP': '40px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape050',
#   'lineColorBlink': 'False',
#   'no': 11},
#  'shape050_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '24',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape050_shaTank',
#   'lineColorBlink': 'False',
#   'no': 12},
#  'shape050_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '27',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape050_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 13},
#  'shape051': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53105',
#   'TEXT-DECORATION': 'none',
#   'TOP': '145px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape051',
#   'lineColorBlink': 'False',
#   'no': 15},
#  'shape051_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '68',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape051_shaTank',
#   'lineColorBlink': 'False',
#   'no': 16},
#  'shape051_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '71',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape051_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 17},
#  'shape052': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53106',
#   'TEXT-DECORATION': 'none',
#   'TOP': '250px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape052',
#   'lineColorBlink': 'False',
#   'no': 19},
#  'shape052_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '82',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape052_shaTank',
#   'lineColorBlink': 'False',
#   'no': 20},
#  'shape052_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '85',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape052_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 21},
#  'shape053': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53107',
#   'TEXT-DECORATION': 'none',
#   'TOP': '355px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape053',
#   'lineColorBlink': 'False',
#   'no': 23},
#  'shape053_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '96',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape053_shaTank',
#   'lineColorBlink': 'False',
#   'no': 24},
#  'shape053_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '99',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape053_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 25},
#  'shape054': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53109',
#   'TEXT-DECORATION': 'none',
#   'TOP': '465px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape054',
#   'lineColorBlink': 'False',
#   'no': 27},
#  'shape054_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '110',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape054_shaTank',
#   'lineColorBlink': 'False',
#   'no': 28},
#  'shape054_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '113',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape054_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 29},
#  'shape055': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TOP': '575px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape055',
#   'lineColorBlink': 'False',
#   'no': 31},
#  'shape055_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '124',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape055_shaTank',
#   'lineColorBlink': 'False',
#   'no': 32},
#  'shape055_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '127',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape055_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 33},
#  'shape056': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53111',
#   'TEXT-DECORATION': 'none',
#   'TOP': '690px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape056',
#   'lineColorBlink': 'False',
#   'no': 35},
#  'shape056_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '138',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape056_shaTank',
#   'lineColorBlink': 'False',
#   'no': 36},
#  'shape056_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '141',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape056_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 37},
#  'shape057': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK5397',
#   'TEXT-DECORATION': 'none',
#   'TOP': '790px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape057',
#   'lineColorBlink': 'False',
#   'no': 39},
#  'shape057_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '152',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape057_shaTank',
#   'lineColorBlink': 'False',
#   'no': 40},
#  'shape057_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '155',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape057_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 41},
#  'shape104': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_218',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_002',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape104',
#   'lineColorBlink': 'False',
#   'no': 43},
#  'shape108': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_220',
#   'TEXT-DECORATION': 'none',
#   'TOP': '180px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_017',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape108',
#   'lineColorBlink': 'False',
#   'no': 44},
#  'shape109': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_021',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape109',
#   'lineColorBlink': 'False',
#   'no': 45},
#  'shape110': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_232',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_026',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape110',
#   'lineColorBlink': 'False',
#   'no': 46},
#  'shape111': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_202',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_053_027',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape111',
#   'lineColorBlink': 'False',
#   'no': 47},
#  'shape112': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'Width': '80',
#   'fillColorBlink': 'False',
#   'id': 'shape112',
#   'lineColorBlink': 'False',
#   'no': 48},
#  'shape115': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_059_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'Width': '80',
#   'fillColorBlink': 'False',
#   'id': 'shape115',
#   'lineColorBlink': 'False',
#   'no': 49},
#  'shape116': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '730px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_013',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'Width': '80',
#   'fillColorBlink': 'False',
#   'id': 'shape116',
#   'lineColorBlink': 'False',
#   'no': 213},
#  'shape223': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_218',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '435px',
#   'Width': '435',
#   'fillColorBlink': 'False',
#   'id': 'shape223',
#   'lineColorBlink': 'False',
#   'no': 63},
#  'shape226': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '1655px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_7280',
#   'TEXT-DECORATION': 'none',
#   'TOP': '110px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_013_014',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape226',
#   'lineColorBlink': 'False',
#   'no': 200},
#  'shape232': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_220',
#   'TEXT-DECORATION': 'none',
#   'TOP': '180px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '210px',
#   'Width': '210',
#   'fillColorBlink': 'False',
#   'id': 'shape232',
#   'lineColorBlink': 'False',
#   'no': 64},
#  'shape240': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '255px',
#   'Width': '255',
#   'fillColorBlink': 'False',
#   'id': 'shape240',
#   'lineColorBlink': 'False',
#   'no': 65},
#  'shape250': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_232',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '145px',
#   'Width': '145',
#   'fillColorBlink': 'False',
#   'id': 'shape250',
#   'lineColorBlink': 'False',
#   'no': 67},
#  'shape254': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_202',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '275px',
#   'Width': '275',
#   'fillColorBlink': 'False',
#   'id': 'shape254',
#   'lineColorBlink': 'False',
#   'no': 68},
#  'shape255': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '590px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_104',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 'shape255',
#   'lineColorBlink': 'False',
#   'no': 69},
#  'shape262': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '275px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape262',
#   'lineColorBlink': 'False',
#   'no': 210},
#  'shape266': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape266',
#   'lineColorBlink': 'False',
#   'no': 71},
#  'shape269': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_059_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '170px',
#   'Width': '170',
#   'fillColorBlink': 'False',
#   'id': 'shape269',
#   'lineColorBlink': 'False',
#   'no': 72},
#  'shape271': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '275px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004~MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '120px',
#   'Width': '120',
#   'fillColorBlink': 'False',
#   'id': 'shape271',
#   'lineColorBlink': 'False',
#   'no': 212},
#  'shape272': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102B',
#   'TEXT-DECORATION': 'none',
#   'TOP': '280px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 'shape272',
#   'lineColorBlink': 'False',
#   'no': 50},
#  'shape273': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102A',
#   'TEXT-DECORATION': 'none',
#   'TOP': '75px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 'shape273',
#   'lineColorBlink': 'False',
#   'no': 10},
#  'shape274': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_122',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape274',
#   'lineColorBlink': 'False',
#   'no': 73},
#  'shape275': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '520px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_065',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '70px',
#   'Width': '70',
#   'fillColorBlink': 'False',
#   'id': 'shape275',
#   'lineColorBlink': 'False',
#   'no': 336},
#  'shape276': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '785px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_117',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape276',
#   'lineColorBlink': 'False',
#   'no': 76},
#  'shape277': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '815px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_140',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape277',
#   'lineColorBlink': 'False',
#   'no': 79},
#  'shape278': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '1193px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104A',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 'shape278',
#   'lineColorBlink': 'False',
#   'no': 81},
#  'shape279': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104B',
#   'TEXT-DECORATION': 'none',
#   'TOP': '570px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 'shape279',
#   'lineColorBlink': 'False',
#   'no': 82},
#  'shape281': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '1150px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_271',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape281',
#   'lineColorBlink': 'False',
#   'no': 83},
#  'shape282': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '1150px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_272',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape282',
#   'lineColorBlink': 'False',
#   'no': 85},
#  'shape283': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '970px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_109',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape283',
#   'lineColorBlink': 'False',
#   'no': 87},
#  'shape284': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '1070px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_007',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '60px',
#   'Width': '60',
#   'fillColorBlink': 'False',
#   'id': 'shape284',
#   'lineColorBlink': 'False',
#   'no': 88},
#  'shape286': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
# ...
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '195px',
#   'Height': '195',
#   'LEFT': '530px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_246',
#   'TEXT-DECORATION': 'none',
#   'TOP': '210px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape679',
#   'lineColorBlink': 'False',
#   'no': 277},
#  'shape680': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '145px',
#   'Height': '145',
#   'LEFT': '590px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '360px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_130',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape680',
#   'lineColorBlink': 'False',
#   'no': 300},
#  'shape681': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '905px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_011',
#   'Rotation': '270',
#   'TEXT-DECORATION': 'none',
#   'TOP': '390px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape681',
#   'lineColorBlink': 'False',
#   'no': 308},
#  'shape682': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '20px',
#   'Height': '20',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_011',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape682',
#   'lineColorBlink': 'False',
#   'no': 309},
#  'shape683': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '425px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape683',
#   'lineColorBlink': 'False',
#   'no': 313},
#  'shape684': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '45px',
#   'Height': '45',
#   'LEFT': '835px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '455px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape684',
#   'lineColorBlink': 'False',
#   'no': 314},
#  'shape686': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '835px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '590px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_064',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape686',
#   'lineColorBlink': 'False',
#   'no': 316},
#  'shape689': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '865px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_013',
#   'Rotation': '0',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape689',
#   'lineColorBlink': 'False',
#   'no': 317},
#  'shape690': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '780px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_100',
#   'Rotation': '0',
#   'TEXT-DECORATION': 'none',
#   'TOP': '450px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape690',
#   'lineColorBlink': 'False',
#   'no': 318},
#  'shape691': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '780px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_172',
#   'Rotation': '0',
#   'TEXT-DECORATION': 'none',
#   'TOP': '495px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape691',
#   'lineColorBlink': 'False',
#   'no': 319},
#  'shape692': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '105px',
#   'Width': '105',
#   'fillColorBlink': 'False',
#   'id': 'shape692',
#   'lineColorBlink': 'False',
#   'no': 321},
#  'shape693': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape693',
#   'lineColorBlink': 'False',
#   'no': 322},
#  'shape694': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_022_065',
#   'TEXT-DECORATION': 'none',
#   'TOP': '690px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape694',
#   'lineColorBlink': 'False',
#   'no': 325},
#  'shape695': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '885px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2430',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '45px',
#   'Width': '45',
#   'fillColorBlink': 'False',
#   'id': 'shape695',
#   'lineColorBlink': 'False',
#   'no': 326},
#  'shape696': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_022_066',
#   'TEXT-DECORATION': 'none',
#   'TOP': '655px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape696',
#   'lineColorBlink': 'False',
#   'no': 327},
#  'shape697': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '885px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2430',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '40px',
#   'Width': '40',
#   'fillColorBlink': 'False',
#   'id': 'shape697',
#   'lineColorBlink': 'False',
#   'no': 328},
#  'shape698': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape698',
#   'lineColorBlink': 'False',
#   'no': 329},
#  'shape699': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '105px',
#   'Width': '105',
#   'fillColorBlink': 'False',
#   'id': 'shape699',
#   'lineColorBlink': 'False',
#   'no': 330},
#  'shape792': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN2400_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '70px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'Width': '26',
#   'fillColorBlink': 'False',
#   'id': 'shape792',
#   'lineColorBlink': 'False',
#   'no': 52},
#  'shape793': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN2600_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '415px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'Width': '26',
#   'fillColorBlink': 'False',
#   'id': 'shape793',
#   'lineColorBlink': 'False',
#   'no': 54},
#  'shape794': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN20200_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '820px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'Width': '26',
#   'fillColorBlink': 'False',
#   'id': 'shape794',
#   'lineColorBlink': 'False',
#   'no': 56},
#  'tfgOffDisplayEndPoints': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'Height': '14',
#   'LEFT': '175px',
#   'POSITION': 'absolute',
#   'Point?Element1': '',
#   'Point?Element10': '',
#   'Point?Element11': '',
#   'Point?Element12': '',
#   'Point?Element13': '',
#   'Point?Element14': '',
#   'Point?Element15': '',
#   'Point?Element16': '',
#   'Point?Element17': '',
#   'Point?Element18': '',
#   'Point?Element19': '',
#   'Point?Element2': '',
#   'Point?Element20': '',
#   'Point?Element21': '',
#   'Point?Element22': '',
#   'Point?Element23': '',
#   'Point?Element24': '',
#   'Point?Element25': '',
#   'Point?Element26': '',
#   'Point?Element27': '',
#   'Point?Element28': '',
#   'Point?Element29': '',
#   'Point?Element3': '',
#   'Point?Element30': '',
#   'Point?Element31': '',
#   'Point?Element32': '',
#   'Point?Element33': '',
#   'Point?Element34': '',
#   'Point?Element35': '',
#   'Point?Element36': '',
#   'Point?Element37': '',
#   'Point?Element38': '',
#   'Point?Element39': '',
#   'Point?Element4': '',
#   'Point?Element40': '',
#   'Point?Element5': '',
#   'Point?Element6': '',
#   'Point?Element7': '',
#   'Point?Element8': '',
#   'Point?Element9': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '19px',
#   'WIDTH': '92px',
#   'Width': '92',
#   'fillColorBlink': 'False',
#   'id': 'tfgOffDisplayEndPoints',
#   'lineColorBlink': 'False',
#   'no': 6},
#  'tfgOperDataReInit': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'Height': '14',
#   'LEFT': '230px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'WIDTH': '92px',
#   'Width': '92',
#   'fillColorBlink': 'False',
#   'id': 'tfgOperDataReInit',
#   'lineColorBlink': 'False',
#   'no': 5},
#  'tfgPlanningData': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'Height': '14',
#   'LEFT': '138px',
#   'POSITION': 'absolute',
#   'Point?DestElement': '',
#   'Point?SrcElement': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'Value?IgnoreOnDataChange': '"True"',
#   'WIDTH': '92px',
#   'Width': '92',
#   'fillColorBlink': 'False',
#   'id': 'tfgPlanningData',
#   'lineColorBlink': 'False',
#   'no': 3},
#  'tfgSelectTimeout': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '16px',
#   'Height': '16',
#   'LEFT': '77px',
#   'POSITION': 'absolute',
#   'Point?DestElement': '',
#   'Point?SrcElement': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'Value?IgnoreOnDataChange': '"True"',
#   'WIDTH': '60px',
#   'Width': '60',
#   'fillColorBlink': 'False',
#   'id': 'tfgSelectTimeout',
#   'lineColorBlink': 'False',
#   'no': 4}}

# %%
total = {}
for i,div in enumerate(divpm):
    total[div['id']] = {'id':div['id'], 'no':i, 'src':div['src']}
    for p in div['parameters'].split(';'):
        total[div['id']].update(dict(zip(p.split(':')[::2], p.split(':')[1::2])))
    for s in div['style'].split('; '):
        total[div['id']].update(dict(zip(s.split(':')[::2], s.split(': ')[1::2])))
    for t in div['hdxproperties'].split(';'):
        total[div['id']].update(dict(zip(t.split(':')[::2], t.split(':')[1::2])))
total
# Out:
# {'PseudoValve039': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '85px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve039',
#   'lineColorBlink': 'False',
#   'no': 228,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve040': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '75px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve040',
#   'lineColorBlink': 'False',
#   'no': 229,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve041': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '295px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve041',
#   'lineColorBlink': 'False',
#   'no': 230,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve042': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '280px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve042',
#   'lineColorBlink': 'False',
#   'no': 231,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve043': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '435px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve043',
#   'lineColorBlink': 'False',
#   'no': 232,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve044': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve044',
#   'lineColorBlink': 'False',
#   'no': 233,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve045': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '585px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve045',
#   'lineColorBlink': 'False',
#   'no': 234,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve046': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '570px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve046',
#   'lineColorBlink': 'False',
#   'no': 235,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve047': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '685px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve047',
#   'lineColorBlink': 'False',
#   'no': 236,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve048': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '670px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve048',
#   'lineColorBlink': 'False',
#   'no': 237,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve049': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '840px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve049',
#   'lineColorBlink': 'False',
#   'no': 238,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'PseudoValve050': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1235px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '825px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 'PseudoValve050',
#   'lineColorBlink': 'False',
#   'no': 239,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgValvePseudo_S-oil.sha'},
#  'shape001': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '29px',
#   'Height': '29',
#   'LEFT': '5px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '0px',
#   'WIDTH': '103px',
#   'Width': '103',
#   'fillColorBlink': 'False',
#   'id': 'shape001',
#   'lineColorBlink': 'False',
#   'no': 2,
#   'src': '.\\MA_CH_OS1_WAXY_files\\General Script Holder_rev0.sha'},
#  'shape015': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '36px',
#   'Height': '36',
#   'LEFT': '0px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TEXT?ACTIVITY': 'CH',
#   'TEXT?AREA': '제품운영1과',
#   'TEXT?PRODUCT': 'WAXY',
#   'TEXT?TANK': '-',
#   'TOP': '0px',
#   'WIDTH': '1910px',
#   'Width': '1910',
#   'fillColorBlink': 'False',
#   'id': 'shape015',
#   'lineColorBlink': 'False',
#   'no': 7,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MA_Toolbar.sha'},
#  'shape023': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53104',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31',
#   'TOP': '115px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape023',
#   'lineColorBlink': 'False',
#   'no': 14,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape024': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53105',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-96S',
#   'TOP': '220px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape024',
#   'lineColorBlink': 'False',
#   'no': 18,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape025': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53106',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-20',
#   'TOP': '325px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape025',
#   'lineColorBlink': 'False',
#   'no': 22,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape027': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-2400',
#   'TEXT-DECORATION': 'none',
#   'TOP': '70px',
#   'WIDTH': '95px',
#   'Width': '95',
#   'fillColorBlink': 'False',
#   'id': 'shape027',
#   'lineColorBlink': 'False',
#   'no': 8,
#   'src': '.\\MA_CH_OS1_WAXY_files\\NameTag.sha'},
#  'shape028': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53107',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-116',
#   'TOP': '430px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape028',
#   'lineColorBlink': 'False',
#   'no': 26,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape029': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53109',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-480',
#   'TOP': '540px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape029',
#   'lineColorBlink': 'False',
#   'no': 30,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape030': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31S',
#   'TOP': '650px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape030',
#   'lineColorBlink': 'False',
#   'no': 34,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape031': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31S',
#   'TOP': '765px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape031',
#   'lineColorBlink': 'False',
#   'no': 38,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape032': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK5397',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'Mix-W',
#   'TOP': '865px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 'shape032',
#   'lineColorBlink': 'False',
#   'no': 42,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha'},
#  'shape033': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-2600',
#   'TEXT-DECORATION': 'none',
#   'TOP': '415px',
#   'WIDTH': '95px',
#   'Width': '95',
#   'fillColorBlink': 'False',
#   'id': 'shape033',
#   'lineColorBlink': 'False',
#   'no': 53,
#   'src': '.\\MA_CH_OS1_WAXY_files\\NameTag.sha'},
#  'shape035': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-20200',
#   'TEXT-DECORATION': 'none',
#   'TOP': '820px',
#   'WIDTH': '95px',
#   'Width': '95',
#   'fillColorBlink': 'False',
#   'id': 'shape035',
#   'lineColorBlink': 'False',
#   'no': 175,
#   'src': '.\\MA_CH_OS1_WAXY_files\\NameTag.sha'},
#  'shape050': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53104',
#   'TEXT-DECORATION': 'none',
#   'TOP': '40px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape050',
#   'lineColorBlink': 'False',
#   'no': 11,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape050_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '24',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape050_shaTank',
#   'lineColorBlink': 'False',
#   'no': 12,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape050_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '27',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape050_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 13,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape051': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53105',
#   'TEXT-DECORATION': 'none',
#   'TOP': '145px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape051',
#   'lineColorBlink': 'False',
#   'no': 15,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape051_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '68',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape051_shaTank',
#   'lineColorBlink': 'False',
#   'no': 16,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape051_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '71',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape051_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 17,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape052': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53106',
#   'TEXT-DECORATION': 'none',
#   'TOP': '250px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape052',
#   'lineColorBlink': 'False',
#   'no': 19,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape052_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '82',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape052_shaTank',
#   'lineColorBlink': 'False',
#   'no': 20,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape052_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '85',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape052_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 21,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape053': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53107',
#   'TEXT-DECORATION': 'none',
#   'TOP': '355px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape053',
#   'lineColorBlink': 'False',
#   'no': 23,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape053_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '96',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape053_shaTank',
#   'lineColorBlink': 'False',
#   'no': 24,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape053_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '99',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape053_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 25,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape054': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53109',
#   'TEXT-DECORATION': 'none',
#   'TOP': '465px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape054',
#   'lineColorBlink': 'False',
#   'no': 27,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape054_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '110',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape054_shaTank',
#   'lineColorBlink': 'False',
#   'no': 28,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape054_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '113',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape054_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 29,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape055': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TOP': '575px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape055',
#   'lineColorBlink': 'False',
#   'no': 31,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape055_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '124',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape055_shaTank',
#   'lineColorBlink': 'False',
#   'no': 32,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape055_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '127',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape055_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 33,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape056': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53111',
#   'TEXT-DECORATION': 'none',
#   'TOP': '690px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape056',
#   'lineColorBlink': 'False',
#   'no': 35,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape056_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '138',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape056_shaTank',
#   'lineColorBlink': 'False',
#   'no': 36,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape056_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '141',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape056_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 37,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape057': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK5397',
#   'TEXT-DECORATION': 'none',
#   'TOP': '790px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 'shape057',
#   'lineColorBlink': 'False',
#   'no': 39,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr.sha'},
#  'shape057_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '152',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 'shape057_shaTank',
#   'lineColorBlink': 'False',
#   'no': 40,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha'},
#  'shape057_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '155',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 'shape057_shaTankService',
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False',
#   'no': 41,
#   'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha'},
#  'shape104': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_218',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_002',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape104',
#   'lineColorBlink': 'False',
#   'no': 43,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape108': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_220',
#   'TEXT-DECORATION': 'none',
#   'TOP': '180px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_017',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape108',
#   'lineColorBlink': 'False',
#   'no': 44,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape109': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_021',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape109',
#   'lineColorBlink': 'False',
#   'no': 45,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape110': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_232',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_026',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape110',
#   'lineColorBlink': 'False',
#   'no': 46,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape111': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_202',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_053_027',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 'shape111',
#   'lineColorBlink': 'False',
#   'no': 47,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape112': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'Width': '80',
#   'fillColorBlink': 'False',
#   'id': 'shape112',
#   'lineColorBlink': 'False',
#   'no': 48,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape115': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_059_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'Width': '80',
#   'fillColorBlink': 'False',
#   'id': 'shape115',
#   'lineColorBlink': 'False',
#   'no': 49,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape116': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '730px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_013',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'Width': '80',
#   'fillColorBlink': 'False',
#   'id': 'shape116',
#   'lineColorBlink': 'False',
#   'no': 213,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape223': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_218',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '435px',
#   'Width': '435',
#   'fillColorBlink': 'False',
#   'id': 'shape223',
#   'lineColorBlink': 'False',
#   'no': 63,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape226': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '1655px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_7280',
#   'TEXT-DECORATION': 'none',
#   'TOP': '110px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_013_014',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape226',
#   'lineColorBlink': 'False',
#   'no': 200,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape232': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_220',
#   'TEXT-DECORATION': 'none',
#   'TOP': '180px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '210px',
#   'Width': '210',
#   'fillColorBlink': 'False',
#   'id': 'shape232',
#   'lineColorBlink': 'False',
#   'no': 64,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape240': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '255px',
#   'Width': '255',
#   'fillColorBlink': 'False',
#   'id': 'shape240',
#   'lineColorBlink': 'False',
#   'no': 65,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape250': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_232',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '145px',
#   'Width': '145',
#   'fillColorBlink': 'False',
#   'id': 'shape250',
#   'lineColorBlink': 'False',
#   'no': 67,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape254': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_202',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '275px',
#   'Width': '275',
#   'fillColorBlink': 'False',
#   'id': 'shape254',
#   'lineColorBlink': 'False',
#   'no': 68,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape255': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '590px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_104',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 'shape255',
#   'lineColorBlink': 'False',
#   'no': 69,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape262': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '275px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape262',
#   'lineColorBlink': 'False',
#   'no': 210,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape266': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape266',
#   'lineColorBlink': 'False',
#   'no': 71,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape269': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_059_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '170px',
#   'Width': '170',
#   'fillColorBlink': 'False',
#   'id': 'shape269',
#   'lineColorBlink': 'False',
#   'no': 72,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape271': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '275px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004~MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '120px',
#   'Width': '120',
#   'fillColorBlink': 'False',
#   'id': 'shape271',
#   'lineColorBlink': 'False',
#   'no': 212,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape272': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102B',
#   'TEXT-DECORATION': 'none',
#   'TOP': '280px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 'shape272',
#   'lineColorBlink': 'False',
#   'no': 50,
#   'src': '.\\MA_CH_OS1_WAXY_files\\CPUMP_R.sha'},
#  'shape273': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102A',
#   'TEXT-DECORATION': 'none',
#   'TOP': '75px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 'shape273',
#   'lineColorBlink': 'False',
#   'no': 10,
#   'src': '.\\MA_CH_OS1_WAXY_files\\CPUMP_R.sha'},
#  'shape274': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_122',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape274',
#   'lineColorBlink': 'False',
#   'no': 73,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape275': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '520px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_065',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '70px',
#   'Width': '70',
#   'fillColorBlink': 'False',
#   'id': 'shape275',
#   'lineColorBlink': 'False',
#   'no': 336,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape276': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '785px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_117',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 'shape276',
#   'lineColorBlink': 'False',
#   'no': 76,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape277': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
# ...
#  'shape681': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '905px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_011',
#   'Rotation': '270',
#   'TEXT-DECORATION': 'none',
#   'TOP': '390px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape681',
#   'lineColorBlink': 'False',
#   'no': 308,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TFGValveMAN_H.sha'},
#  'shape682': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '20px',
#   'Height': '20',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_011',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape682',
#   'lineColorBlink': 'False',
#   'no': 309,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha'},
#  'shape683': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '425px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape683',
#   'lineColorBlink': 'False',
#   'no': 313,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha'},
#  'shape684': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '45px',
#   'Height': '45',
#   'LEFT': '835px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '455px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape684',
#   'lineColorBlink': 'False',
#   'no': 314,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha'},
#  'shape686': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '835px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '590px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_064',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape686',
#   'lineColorBlink': 'False',
#   'no': 316,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape689': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '865px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_013',
#   'Rotation': '0',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape689',
#   'lineColorBlink': 'False',
#   'no': 317,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TFGValveMAN_H.sha'},
#  'shape690': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '780px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_100',
#   'Rotation': '0',
#   'TEXT-DECORATION': 'none',
#   'TOP': '450px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape690',
#   'lineColorBlink': 'False',
#   'no': 318,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TFGValveMAN_H.sha'},
#  'shape691': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '780px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_172',
#   'Rotation': '0',
#   'TEXT-DECORATION': 'none',
#   'TOP': '495px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape691',
#   'lineColorBlink': 'False',
#   'no': 319,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TFGValveMAN_H.sha'},
#  'shape692': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '105px',
#   'Width': '105',
#   'fillColorBlink': 'False',
#   'id': 'shape692',
#   'lineColorBlink': 'False',
#   'no': 321,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape693': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape693',
#   'lineColorBlink': 'False',
#   'no': 322,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha'},
#  'shape694': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_022_065',
#   'TEXT-DECORATION': 'none',
#   'TOP': '690px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape694',
#   'lineColorBlink': 'False',
#   'no': 325,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TFGValveMAN_H.sha'},
#  'shape695': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '885px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2430',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '45px',
#   'Width': '45',
#   'fillColorBlink': 'False',
#   'id': 'shape695',
#   'lineColorBlink': 'False',
#   'no': 326,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape696': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_022_066',
#   'TEXT-DECORATION': 'none',
#   'TOP': '655px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 'shape696',
#   'lineColorBlink': 'False',
#   'no': 327,
#   'src': '.\\MA_CH_OS1_WAXY_files\\TFGValveMAN_H.sha'},
#  'shape697': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '885px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2430',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '40px',
#   'Width': '40',
#   'fillColorBlink': 'False',
#   'id': 'shape697',
#   'lineColorBlink': 'False',
#   'no': 328,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape698': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 'shape698',
#   'lineColorBlink': 'False',
#   'no': 329,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineU.sha'},
#  'shape699': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '105px',
#   'Width': '105',
#   'fillColorBlink': 'False',
#   'id': 'shape699',
#   'lineColorBlink': 'False',
#   'no': 330,
#   'src': '.\\MA_CH_OS1_WAXY_files\\MALineH.sha'},
#  'shape792': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN2400_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '70px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'Width': '26',
#   'fillColorBlink': 'False',
#   'id': 'shape792',
#   'lineColorBlink': 'False',
#   'no': 52,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgBoundaryPointR.sha'},
#  'shape793': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN2600_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '415px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'Width': '26',
#   'fillColorBlink': 'False',
#   'id': 'shape793',
#   'lineColorBlink': 'False',
#   'no': 54,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgBoundaryPointR.sha'},
#  'shape794': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN20200_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '820px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'Width': '26',
#   'fillColorBlink': 'False',
#   'id': 'shape794',
#   'lineColorBlink': 'False',
#   'no': 56,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgBoundaryPointR.sha'},
#  'tfgOffDisplayEndPoints': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'Height': '14',
#   'LEFT': '175px',
#   'POSITION': 'absolute',
#   'Point?Element1': '',
#   'Point?Element10': '',
#   'Point?Element11': '',
#   'Point?Element12': '',
#   'Point?Element13': '',
#   'Point?Element14': '',
#   'Point?Element15': '',
#   'Point?Element16': '',
#   'Point?Element17': '',
#   'Point?Element18': '',
#   'Point?Element19': '',
#   'Point?Element2': '',
#   'Point?Element20': '',
#   'Point?Element21': '',
#   'Point?Element22': '',
#   'Point?Element23': '',
#   'Point?Element24': '',
#   'Point?Element25': '',
#   'Point?Element26': '',
#   'Point?Element27': '',
#   'Point?Element28': '',
#   'Point?Element29': '',
#   'Point?Element3': '',
#   'Point?Element30': '',
#   'Point?Element31': '',
#   'Point?Element32': '',
#   'Point?Element33': '',
#   'Point?Element34': '',
#   'Point?Element35': '',
#   'Point?Element36': '',
#   'Point?Element37': '',
#   'Point?Element38': '',
#   'Point?Element39': '',
#   'Point?Element4': '',
#   'Point?Element40': '',
#   'Point?Element5': '',
#   'Point?Element6': '',
#   'Point?Element7': '',
#   'Point?Element8': '',
#   'Point?Element9': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '19px',
#   'WIDTH': '92px',
#   'Width': '92',
#   'fillColorBlink': 'False',
#   'id': 'tfgOffDisplayEndPoints',
#   'lineColorBlink': 'False',
#   'no': 6,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgOffDisplayEndPoints.sha'},
#  'tfgOperDataReInit': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'Height': '14',
#   'LEFT': '230px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'WIDTH': '92px',
#   'Width': '92',
#   'fillColorBlink': 'False',
#   'id': 'tfgOperDataReInit',
#   'lineColorBlink': 'False',
#   'no': 5,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgOperDataReInit.sha'},
#  'tfgPlanningData': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'Height': '14',
#   'LEFT': '138px',
#   'POSITION': 'absolute',
#   'Point?DestElement': '',
#   'Point?SrcElement': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'Value?IgnoreOnDataChange': '"True"',
#   'WIDTH': '92px',
#   'Width': '92',
#   'fillColorBlink': 'False',
#   'id': 'tfgPlanningData',
#   'lineColorBlink': 'False',
#   'no': 3,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgPlanningData.sha'},
#  'tfgSelectTimeout': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '16px',
#   'Height': '16',
#   'LEFT': '77px',
#   'POSITION': 'absolute',
#   'Point?DestElement': '',
#   'Point?SrcElement': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'Value?IgnoreOnDataChange': '"True"',
#   'WIDTH': '60px',
#   'Width': '60',
#   'fillColorBlink': 'False',
#   'id': 'tfgSelectTimeout',
#   'lineColorBlink': 'False',
#   'no': 4,
#   'src': '.\\MA_CH_OS1_WAXY_files\\tfgSelectTimeout.sha'}}

# %%
total['shape553']['src']
# Out:
# '.\\MA_CH_OS1_WAXY_files\\MALineU.sha'

# %%
total['shape553']['src'][-11::]
# Out:
# 'MALineU.sha'

# %%
for i,v in total.items():
    if 'Value?ShapeID' in v:
        print(i,v['Value?ShapeID'], v['no'])
    else :
        print('\n',v)
# Out:
# shape385 Line 0
# shape554 Line 1
#
#  {'id': 'shape001', 'no': 2, 'src': '.\\MA_CH_OS1_WAXY_files\\General Script Holder_rev0.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '103px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '29px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '0px', 'LEFT': '5px', 'fillColorBlink': 'False', 'Height': '29', 'lineColorBlink': 'False', 'Width': '103'}
#
#  {'id': 'tfgPlanningData', 'no': 3, 'src': '.\\MA_CH_OS1_WAXY_files\\tfgPlanningData.sha', 'Point?DestElement': '', 'Point?SrcElement': '', 'Value?IgnoreOnDataChange': '"True"', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '92px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '14px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': 'normal', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '4px', 'LEFT': '138px', 'fillColorBlink': 'False', 'Height': '14', 'lineColorBlink': 'False', 'Width': '92'}
#
#  {'id': 'tfgSelectTimeout', 'no': 4, 'src': '.\\MA_CH_OS1_WAXY_files\\tfgSelectTimeout.sha', 'Point?DestElement': '', 'Point?SrcElement': '', 'Value?IgnoreOnDataChange': '"True"', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '60px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '16px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': 'normal', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '4px', 'LEFT': '77px', 'fillColorBlink': 'False', 'Height': '16', 'lineColorBlink': 'False', 'Width': '60'}
#
#  {'id': 'tfgOperDataReInit', 'no': 5, 'src': '.\\MA_CH_OS1_WAXY_files\\tfgOperDataReInit.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '92px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '14px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': 'normal', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '4px', 'LEFT': '230px', 'fillColorBlink': 'False', 'Height': '14', 'lineColorBlink': 'False', 'Width': '92'}
#
#  {'id': 'tfgOffDisplayEndPoints', 'no': 6, 'src': '.\\MA_CH_OS1_WAXY_files\\tfgOffDisplayEndPoints.sha', 'Point?Element1': '', 'Point?Element2': '', 'Point?Element3': '', 'Point?Element4': '', 'Point?Element5': '', 'Point?Element6': '', 'Point?Element7': '', 'Point?Element8': '', 'Point?Element9': '', 'Point?Element10': '', 'Point?Element11': '', 'Point?Element12': '', 'Point?Element13': '', 'Point?Element14': '', 'Point?Element15': '', 'Point?Element16': '', 'Point?Element17': '', 'Point?Element18': '', 'Point?Element19': '', 'Point?Element20': '', 'Point?Element21': '', 'Point?Element22': '', 'Point?Element23': '', 'Point?Element24': '', 'Point?Element25': '', 'Point?Element26': '', 'Point?Element27': '', 'Point?Element28': '', 'Point?Element29': '', 'Point?Element30': '', 'Point?Element31': '', 'Point?Element32': '', 'Point?Element33': '', 'Point?Element34': '', 'Point?Element35': '', 'Point?Element36': '', 'Point?Element37': '', 'Point?Element38': '', 'Point?Element39': '', 'Point?Element40': '', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '92px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '14px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': 'normal', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '19px', 'LEFT': '175px', 'fillColorBlink': 'False', 'Height': '14', 'lineColorBlink': 'False', 'Width': '92'}
#
#  {'id': 'shape015', 'no': 7, 'src': '.\\MA_CH_OS1_WAXY_files\\MA_Toolbar.sha', 'TEXT?ACTIVITY': 'CH', 'TEXT?AREA': '제품운영1과', 'TEXT?TANK': '-', 'TEXT?PRODUCT': 'WAXY', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '1910px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '36px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '0px', 'LEFT': '0px', 'fillColorBlink': 'False', 'Height': '36', 'lineColorBlink': 'False', 'Width': '1910'}
#
#  {'id': 'shape027', 'no': 8, 'src': '.\\MA_CH_OS1_WAXY_files\\NameTag.sha', 'T?T': 'U-2400', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '95px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '18px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '70px', 'LEFT': '1810px', 'fillColorBlink': 'False', 'Height': '18', 'lineColorBlink': 'False', 'Width': '95'}
# shape414 ValveMan 9
# shape273 CPump 10
# shape050 TankNozzle 11
#
#  {'id': 'shape050_shaTank', 'no': 12, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '90.76%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '77.5%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)', 'TOP': '15%', 'LEFT': '5.38%', 'fillColorBlink': 'False', 'HDXBINDINGID': '24', 'Height': '62', 'lineColorBlink': 'False', 'Width': '113'}
#
#  {'id': 'shape050_shaTankService', 'no': 13, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '9.23%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '16.25%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)', 'TOP': '47.5%', 'LEFT': '23.07%', 'fillColorBlink': 'False', 'HDXBINDINGID': '27', 'Height': '13', 'indicateAlarmState': 'False', 'indicateScanState': 'False', 'lineColorBlink': 'False', 'Width': '12'}
#
#  {'id': 'shape023', 'no': 14, 'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha', 'Point?TankName': 'TK53104', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'W-31', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '100px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '115px', 'LEFT': '25px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '100'}
# shape051 TankNozzle 15
#
#  {'id': 'shape051_shaTank', 'no': 16, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '90.76%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '77.5%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)', 'TOP': '15%', 'LEFT': '5.38%', 'fillColorBlink': 'False', 'HDXBINDINGID': '68', 'Height': '62', 'lineColorBlink': 'False', 'Width': '113'}
#
#  {'id': 'shape051_shaTankService', 'no': 17, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '9.23%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '16.25%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)', 'TOP': '47.5%', 'LEFT': '23.07%', 'fillColorBlink': 'False', 'HDXBINDINGID': '71', 'Height': '13', 'indicateAlarmState': 'False', 'indicateScanState': 'False', 'lineColorBlink': 'False', 'Width': '12'}
#
#  {'id': 'shape024', 'no': 18, 'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha', 'Point?TankName': 'TK53105', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'W-96S', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '100px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '220px', 'LEFT': '25px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '100'}
# shape052 TankNozzle 19
#
#  {'id': 'shape052_shaTank', 'no': 20, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '90.76%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '77.5%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)', 'TOP': '15%', 'LEFT': '5.38%', 'fillColorBlink': 'False', 'HDXBINDINGID': '82', 'Height': '62', 'lineColorBlink': 'False', 'Width': '113'}
#
#  {'id': 'shape052_shaTankService', 'no': 21, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '9.23%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '16.25%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)', 'TOP': '47.5%', 'LEFT': '23.07%', 'fillColorBlink': 'False', 'HDXBINDINGID': '85', 'Height': '13', 'indicateAlarmState': 'False', 'indicateScanState': 'False', 'lineColorBlink': 'False', 'Width': '12'}
#
#  {'id': 'shape025', 'no': 22, 'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha', 'Point?TankName': 'TK53106', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'W-20', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '100px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '325px', 'LEFT': '25px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '100'}
# shape053 TankNozzle 23
#
#  {'id': 'shape053_shaTank', 'no': 24, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '90.76%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '77.5%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)', 'TOP': '15%', 'LEFT': '5.38%', 'fillColorBlink': 'False', 'HDXBINDINGID': '96', 'Height': '62', 'lineColorBlink': 'False', 'Width': '113'}
#
#  {'id': 'shape053_shaTankService', 'no': 25, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '9.23%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '16.25%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)', 'TOP': '47.5%', 'LEFT': '23.07%', 'fillColorBlink': 'False', 'HDXBINDINGID': '99', 'Height': '13', 'indicateAlarmState': 'False', 'indicateScanState': 'False', 'lineColorBlink': 'False', 'Width': '12'}
#
#  {'id': 'shape028', 'no': 26, 'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha', 'Point?TankName': 'TK53107', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'W-116', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '100px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '430px', 'LEFT': '25px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '100'}
# shape054 TankNozzle 27
#
#  {'id': 'shape054_shaTank', 'no': 28, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '90.76%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '77.5%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)', 'TOP': '15%', 'LEFT': '5.38%', 'fillColorBlink': 'False', 'HDXBINDINGID': '110', 'Height': '62', 'lineColorBlink': 'False', 'Width': '113'}
#
#  {'id': 'shape054_shaTankService', 'no': 29, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '9.23%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '16.25%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)', 'TOP': '47.5%', 'LEFT': '23.07%', 'fillColorBlink': 'False', 'HDXBINDINGID': '113', 'Height': '13', 'indicateAlarmState': 'False', 'indicateScanState': 'False', 'lineColorBlink': 'False', 'Width': '12'}
#
#  {'id': 'shape029', 'no': 30, 'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha', 'Point?TankName': 'TK53109', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'W-480', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '100px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '540px', 'LEFT': '25px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '100'}
# shape055 TankNozzle 31
#
#  {'id': 'shape055_shaTank', 'no': 32, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '90.76%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '77.5%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)', 'TOP': '15%', 'LEFT': '5.38%', 'fillColorBlink': 'False', 'HDXBINDINGID': '124', 'Height': '62', 'lineColorBlink': 'False', 'Width': '113'}
#
#  {'id': 'shape055_shaTankService', 'no': 33, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '9.23%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '16.25%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)', 'TOP': '47.5%', 'LEFT': '23.07%', 'fillColorBlink': 'False', 'HDXBINDINGID': '127', 'Height': '13', 'indicateAlarmState': 'False', 'indicateScanState': 'False', 'lineColorBlink': 'False', 'Width': '12'}
#
#  {'id': 'shape030', 'no': 34, 'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha', 'Point?TankName': 'TK53110', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'W-31S', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '100px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '650px', 'LEFT': '25px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '100'}
# shape056 TankNozzle 35
#
#  {'id': 'shape056_shaTank', 'no': 36, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '90.76%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '77.5%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)', 'TOP': '15%', 'LEFT': '5.38%', 'fillColorBlink': 'False', 'HDXBINDINGID': '138', 'Height': '62', 'lineColorBlink': 'False', 'Width': '113'}
#
#  {'id': 'shape056_shaTankService', 'no': 37, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '9.23%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '16.25%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)', 'TOP': '47.5%', 'LEFT': '23.07%', 'fillColorBlink': 'False', 'HDXBINDINGID': '141', 'Height': '13', 'indicateAlarmState': 'False', 'indicateScanState': 'False', 'lineColorBlink': 'False', 'Width': '12'}
#
#  {'id': 'shape031', 'no': 38, 'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha', 'Point?TankName': 'TK53110', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'W-31S', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '100px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '765px', 'LEFT': '25px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '100'}
# shape057 TankNozzle 39
#
#  {'id': 'shape057_shaTank', 'no': 40, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\soilcrtankbox.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '90.76%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '77.5%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)', 'TOP': '15%', 'LEFT': '5.38%', 'fillColorBlink': 'False', 'HDXBINDINGID': '152', 'Height': '62', 'lineColorBlink': 'False', 'Width': '113'}
#
#  {'id': 'shape057_shaTankService', 'no': 41, 'src': '.\\MA_CH_OS1_WAXY_files\\IFRT_TANK_ovr_files\\tfgTankService.sha', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '9.23%', 'FONT-FAMILY': 'Arial', 'HEIGHT': '16.25%', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)', 'TOP': '47.5%', 'LEFT': '23.07%', 'fillColorBlink': 'False', 'HDXBINDINGID': '155', 'Height': '13', 'indicateAlarmState': 'False', 'indicateScanState': 'False', 'lineColorBlink': 'False', 'Width': '12'}
#
#  {'id': 'shape032', 'no': 42, 'src': '.\\MA_CH_OS1_WAXY_files\\TK_Activity_NEW.sha', 'Point?TankName': 'TK5397', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'Mix-W', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '100px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '30px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '865px', 'LEFT': '25px', 'fillColorBlink': 'False', 'Height': '30', 'lineColorBlink': 'False', 'Width': '100'}
# shape104 Line 43
# shape108 Line 44
# shape109 Line 45
# shape110 Line 46
# shape111 Line 47
# shape112 Line 48
# shape115 Line 49
# shape272 CPump 50
# shape310 Line 51
# shape792 BP 52
#
#  {'id': 'shape033', 'no': 53, 'src': '.\\MA_CH_OS1_WAXY_files\\NameTag.sha', 'T?T': 'U-2600', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '95px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '18px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '415px', 'LEFT': '1810px', 'fillColorBlink': 'False', 'Height': '18', 'lineColorBlink': 'False', 'Width': '95'}
# shape793 BP 54
# shape392 Line 55
# shape794 BP 56
# shape415 ValveMan 57
# shape416 ValveMan 58
# shape417 ValveMan 59
# shape418 ValveMan 60
# shape421 ValveMan 61
# shape423 ValveMan 62
# shape223 Line 63
# shape232 Line 64
# shape240 Line 65
# shape444 ValveMan 66
# shape250 Line 67
# shape254 Line 68
# shape255 Line 69
# shape447 ValveMan 70
# shape266 Line 71
# shape269 Line 72
# shape274 Line 73
# shape457 ValveMan 74
# shape551 Line 75
# shape276 Line 76
# shape458 ValveMan 77
# shape552 Line 78
# shape277 Line 79
# shape459 ValveMan 80
# shape278 CPump 81
# shape279 CPump 82
# shape281 Line 83
# shape462 ValveMan 84
# shape282 Line 85
# shape463 ValveMan 86
# shape283 Line 87
# shape284 Line 88
# shape289 Line 89
# shape553 Line 90
# shape301 Line 91
# shape506 ValveMan 92
# shape303 Line 93
# shape563 Line 94
# shape304 Line 95
# shape507 ValveMan 96
# shape305 Line 97
# shape564 Line 98
# shape314 Line 99
# shape315 Line 100
# shape508 ValveMan 101
# shape329 Line 102
# shape565 Line 103
# shape509 ValveMan 104
# shape330 Line 105
# shape334 Line 106
# shape566 Line 107
# shape510 ValveMan 108
# shape371 Line 109
# shape511 ValveMan 110
# shape568 Line 111
# shape393 Line 112
# shape512 ValveMan 113
# shape569 Line 114
# shape394 Line 115
# shape513 ValveMan 116
# shape570 Line 117
# shape395 Line 118
# shape514 ValveMan 119
# shape396 Line 120
# shape571 Line 121
# shape397 Line 122
# shape515 ValveMan 123
# shape398 Line 124
# shape577 Line 125
# shape399 Line 126
# shape400 Line 127
# shape401 Line 128
# shape516 ValveMan 129
# shape404 Line 130
# shape608 Line 131
# shape405 Line 132
# shape406 Line 133
# shape609 Line 134
# shape518 ValveMan 135
# shape407 Line 136
# shape408 Line 137
# shape610 Line 138
# shape519 ValveMan 139
# shape409 Line 140
# shape410 Line 141
# shape523 Line 142
# shape627 Line 143
# shape651 Line 144
# shape308 CPump 145
# shape309 CPump 146
# shape312 Line 147
# shape468 ValveMan 148
# shape313 Line 149
# shape316 Line 150
# shape469 ValveMan 151
# shape572 Line 152
# shape318 Line 153
# shape319 Line 154
# shape573 Line 155
# shape320 Line 156
# shape321 Line 157
# shape574 Line 158
# shape470 ValveMan 159
# shape322 Line 160
# shape323 Line 161
# shape324 Line 162
# shape471 ValveMan 163
# shape575 Line 164
# shape325 Line 165
# shape326 Line 166
# shape576 Line 167
# shape327 Line 168
# shape328 Line 169
# shape472 ValveMan 170
# shape473 ValveMan 171
# shape390 Line 172
# shape391 Line 173
# shape607 Line 174
#
#  {'id': 'shape035', 'no': 175, 'src': '.\\MA_CH_OS1_WAXY_files\\NameTag.sha', 'T?T': 'U-20200', 'POSITION': 'absolute', 'FONT-STYLE': 'normal', 'WIDTH': '95px', 'FONT-FAMILY': 'Arial', 'HEIGHT': '18px', 'FONT-SIZE': '0px', 'FONT-WEIGHT': '400', 'TEXT-DECORATION': 'none', 'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', 'TOP': '820px', 'LEFT': '1810px', 'fillColorBlink': 'False', 'Height': '18', 'lineColorBlink': 'False', 'Width': '95'}
# shape286 Line 176
# shape467 ValveMan 177
# shape287 Line 178
# shape476 ValveMan 179
# shape288 Line 180
# shape302 Line 181
# shape558 Line 182
# shape306 Line 183
# shape477 ValveMan 184
# shape527 ValveMan 185
# shape331 Line 186
# shape559 Line 187
# shape529 ValveMan 188
# shape332 Line 189
# shape578 Line 190
# shape307 Line 191
# shape317 Line 192
# shape579 Line 193
# shape333 Line 194
# shape479 ValveMan 195
# shape480 ValveMan 196
# shape335 Line 197
# shape481 ValveMan 198
# shape534 Line 199
# shape226 Line 200
# shape433 ValveMan 201
# shape536 Line 202
# shape442 ValveMan 203
# shape336 Line 204
# shape337 Line 205
# shape659 Line 206
# shape660 ValveMan 207
# shape661 Line 208
# shape580 Line 209
# shape262 Line 210
# shape455 ValveMan 211
# shape271 Line 212
# shape116 Line 213
# shape422 ValveMan 214
# shape341 Line 215
# shape584 Line 216
# shape640 ValveMan 217
# shape641 ValveMan 218
# shape642 ValveMan 219
# shape643 Line 220
# shape644 Line 221
# shape645 Line 222
# shape646 Line 223
# shape647 Line 224
# shape648 Line 225
# shape649 ValveMan 226
# shape668 Line 227
# PseudoValve039 ValvePseudo 228
# PseudoValve040 ValvePseudo 229
# PseudoValve041 ValvePseudo 230
# PseudoValve042 ValvePseudo 231
# PseudoValve043 ValvePseudo 232
# PseudoValve044 ValvePseudo 233
# PseudoValve045 ValvePseudo 234
# PseudoValve046 ValvePseudo 235
# PseudoValve047 ValvePseudo 236
# PseudoValve048 ValvePseudo 237
# PseudoValve049 ValvePseudo 238
# PseudoValve050 ValvePseudo 239
# shape619 Line 240
# shape650 ValveMan 241
# shape438 ValveMan 242
# shape292 Line 243
# shape439 ValveMan 244
# shape293 Line 245
# shape461 ValveMan 246
# shape587 Line 247
# shape297 Line 248
# shape464 ValveMan 249
# shape311 Line 250
# shape347 Line 251
# shape348 Line 252
# shape349 Line 253
# shape588 Line 254
# shape465 ValveMan 255
# shape617 Line 256
# shape622 Line 257
# shape637 Line 258
# shape350 Line 259
# shape475 ValveMan 260
# shape483 ValveMan 261
# shape484 ValveMan 262
# shape638 Line 263
# shape655 Line 264
# shape352 Line 265
# shape672 Line 266
# shape673 Line 267
# shape674 Line 268
# shape675 Line 269
# shape676 Line 270
# shape353 Line 271
# shape354 Line 272
# shape677 Line 273
# shape355 Line 274
# shape678 Line 275
# shape356 Line 276
# shape679 Line 277
# shape357 Line 278
# shape589 Line 279
# shape358 Line 280
# shape485 ValveMan 281
# shape359 Line 282
# shape360 Line 283
# shape486 ValveMan 284
# shape361 Line 285
# shape362 Line 286
# shape487 ValveMan 287
# shape363 Line 288
# shape364 Line 289
# shape488 ValveMan 290
# shape365 Line 291
# shape590 Line 292
# shape591 Line 293
# shape366 Line 294
# shape367 Line 295
# shape368 Line 296
# shape369 Line 297
# shape370 Line 298
# shape372 Line 299
# shape680 Line 300
# shape373 Line 301
# shape490 ValveMan 302
# shape374 Line 303
# shape375 Line 304
# shape491 ValveMan 305
# shape376 Line 306
# shape492 ValveMan 307
# shape681 ValveMan 308
# shape682 Line 309
# shape377 Line 310
# shape378 Line 311
# shape379 Line 312
# shape683 Line 313
# shape684 Line 314
# shape380 Line 315
# shape686 Line 316
# shape689 ValveMan 317
# shape690 ValveMan 318
# shape691 ValveMan 319
# shape382 Line 320
# shape692 Line 321
# shape693 Line 322
# shape383 Line 323
# shape493 ValveMan 324
# shape694 ValveMan 325
# shape695 Line 326
# shape696 ValveMan 327
# shape697 Line 328
# shape698 Line 329
# shape699 Line 330
# shape592 Line 331
# shape517 ValveMan 332
# shape384 Line 333
# shape402 Line 334
# shape494 ValveMan 335
# shape275 Line 336

# %%
for i,v in total.items():
    if 'Value?ShapeID' in v:
        print('{:15} {:15} {:15}'.format(i,v['Value?ShapeID'], v['Point?element']))
# Out:
# shape385        Line            MAL_OS1_7280
# shape554        Line            MAL_OS1_314
# shape414        ValveMan        MAV_OS1_054_002
# shape273        CPump           _P53102A
# shape050        TankNozzle      TK53104
# shape051        TankNozzle      TK53105
# shape052        TankNozzle      TK53106
# shape053        TankNozzle      TK53107
# shape054        TankNozzle      TK53109
# shape055        TankNozzle      TK53110
# shape056        TankNozzle      TK53111
# shape057        TankNozzle      TK5397
# shape104        Line            MAL_OS1_218
# shape108        Line            MAL_OS1_220
# shape109        Line            MAL_OS1_230
# shape110        Line            MAL_OS1_232
# shape111        Line            MAL_OS1_202
# shape112        Line            MAL_OS1_483
# shape115        Line            MAL_OS1_417
# shape272        CPump           _P53102B
# shape310        Line            MAL_OS1_360
# shape792        BP              UN2400_WAXY
# shape793        BP              UN2600_WAXY
# shape392        Line            MAL_OS1_359
# shape794        BP              UN20200_WAXY
# shape415        ValveMan        MAV_OS1_054_017
# shape416        ValveMan        MAV_OS1_054_021
# shape417        ValveMan        MAV_OS1_054_026
# shape418        ValveMan        MAV_OS1_053_027
# shape421        ValveMan        MAV_OS1_062_004
# shape423        ValveMan        MAV_OS1_059_006
# shape223        Line            MAL_OS1_218
# shape232        Line            MAL_OS1_220
# shape240        Line            MAL_OS1_230
# shape444        ValveMan        MAV_OS1_017_024
# shape250        Line            MAL_OS1_232
# shape254        Line            MAL_OS1_202
# shape255        Line            MAL_OS1_312
# shape447        ValveMan        MAV_OS1_018_104
# shape266        Line            MAL_OS1_483
# shape269        Line            MAL_OS1_417
# shape274        Line            MAL_OS1_417
# shape457        ValveMan        MAV_OS1_021_122
# shape551        Line            MAL_OS1_417
# shape276        Line            MAL_OS1_417
# shape458        ValveMan        MAV_OS1_021_117
# shape552        Line            MAL_OS1_417
# shape277        Line            MAL_OS1_417
# shape459        ValveMan        MAV_OS1_021_140
# shape278        CPump           _P53104A
# shape279        CPump           _P53104B
# shape281        Line            MAL_OS1_271
# shape462        ValveMan        MAV_OS1_018_007
# shape282        Line            MAL_OS1_272
# shape463        ValveMan        MAV_OS1_018_008
# shape283        Line            MAL_OS1_314
# shape284        Line            MAL_OS1_314
# shape289        Line            MAL_OS1_314
# shape553        Line            MAL_OS1_314
# shape301        Line            MAL_OS1_2432
# shape506        ValveMan        MAV_OS1_022_062
# shape303        Line            MAL_OS1_2431
# shape563        Line            MAL_OS1_2431
# shape304        Line            MAL_OS1_2431
# shape507        ValveMan        OMAVALVE
# shape305        Line            MAL_OS1_2433
# shape564        Line            MAL_OS1_2433
# shape314        Line            MAL_OS1_2433
# shape315        Line            MAL_OS1_2433
# shape508        ValveMan        MAV_OS1_022_073
# shape329        Line            MAL_OS1_2433
# shape565        Line            MAL_OS1_2433
# shape509        ValveMan        MAV_OS1_022_074
# shape330        Line            MAL_OS1_2433
# shape334        Line            MAL_OS1_2431
# shape566        Line            MAL_OS1_2431
# shape510        ValveMan        MAV_OS1_022_061
# shape371        Line            MAL_OS1_2431
# shape511        ValveMan        MAV_OS1_022_072
# shape568        Line            MAL_OS1_2431
# shape393        Line            MAL_OS1_2431
# shape512        ValveMan        MAV_OS1_022_033
# shape569        Line            MAL_OS1_2431
# shape394        Line            MAL_OS1_2431
# shape513        ValveMan        MAV_OS1_022_057
# shape570        Line            MAL_OS1_2431
# shape395        Line            MAL_OS1_2428
# shape514        ValveMan        MAV_OS1_022_060
# shape396        Line            MAL_OS1_2426
# shape571        Line            MAL_OS1_2426
# shape397        Line            MAL_OS1_2426
# shape515        ValveMan        OMAVALVE
# shape398        Line            MAL_OS1_2424
# shape577        Line            MAL_OS1_2424
# shape399        Line            MAL_OS1_2426
# shape400        Line            MAL_OS1_2424
# shape401        Line            MAL_OS1_2424
# shape516        ValveMan        MAV_OS1_022_059
# shape404        Line            MAL_OS1_5002
# shape608        Line            MAL_OS1_5002
# shape405        Line            MAL_OS1_5002
# shape406        Line            MAL_OS1_5002
# shape609        Line            MAL_OS1_5002
# shape518        ValveMan        MAV_OS1_019_004
# shape407        Line            MAL_OS1_5002
# shape408        Line            MAL_OS1_5002
# shape610        Line            MAL_OS1_5002
# shape519        ValveMan        MAV_OS1_014_003
# shape409        Line            MAL_OS1_5002
# shape410        Line            MAL_OS1_5002
# shape523        Line            MAL_OS1_246
# shape627        Line            MAL_OS1_483
# shape651        Line            MAL_OS1_325
# shape308        CPump           _P5399A
# shape309        CPump           _P5399B
# shape312        Line            MAL_OS1_289
# shape468        ValveMan        MAV_OS1_018_043
# shape313        Line            MAL_OS1_289
# shape316        Line            MAL_OS1_360
# shape469        ValveMan        OMAVALVE
# shape572        Line            MAL_OS1_289
# shape318        Line            MAL_OS1_289
# shape319        Line            MAL_OS1_288
# shape573        Line            MAL_OS1_288
# shape320        Line            MAL_OS1_288
# shape321        Line            MAL_OS1_288
# shape574        Line            MAL_OS1_360
# shape470        ValveMan        MAV_OS1_018_042
# shape322        Line            MAL_OS1_360
# shape323        Line            MAL_OS1_287
# shape324        Line            MAL_OS1_287
# shape471        ValveMan        OMAVALVE
# shape575        Line            MAL_OS1_287
# shape325        Line            MAL_OS1_287
# shape326        Line            MAL_OS1_286
# shape576        Line            MAL_OS1_286
# shape327        Line            MAL_OS1_286
# shape328        Line            MAL_OS1_286
# shape472        ValveMan        MAV_OS1_018_038
# shape473        ValveMan        MAV_OS1_018_136
# shape390        Line            MAL_OS1_359
# shape391        Line            MAL_OS1_359
# shape607        Line            MAL_OS1_359
# shape286        Line            MAL_OS1_270
# shape467        ValveMan        MAV_OS1_018_006
# shape287        Line            MAL_OS1_273
# shape476        ValveMan        MAV_OS1_018_009
# shape288        Line            MAL_OS1_313
# shape302        Line            MAL_OS1_313
# shape558        Line            MAL_OS1_313
# shape306        Line            MAL_OS1_313
# shape477        ValveMan        MAV_OS1_018_067
# shape527        ValveMan        MAV_OS1_018_106
# shape331        Line            MAL_OS1_313
# shape559        Line            MAL_OS1_313
# shape529        ValveMan        MAV_OS1_018_107
# shape332        Line            MAL_OS1_313
# shape578        Line            MAL_OS1_313
# shape307        Line            MAL_OS1_376
# shape317        Line            MAL_OS1_376
# shape579        Line            MAL_OS1_376
# shape333        Line            MAL_OS1_376
# shape479        ValveMan        MAV_OS1_014_004
# shape480        ValveMan        MAV_OS1_013_012
# shape335        Line            MAL_OS1_7279
# shape481        ValveMan        MAV_OS1_013_013
# shape534        Line            MAL_OS1_7280
# shape226        Line            MAL_OS1_7280
# shape433        ValveMan        MAV_OS1_013_014
# shape536        Line            MAL_OS1_7280
# shape442        ValveMan        MAV_OS1_013_015
# shape336        Line            MAL_OS1_7280
# shape337        Line            MAL_OS1_7280
# shape659        Line            MAL_OS1_483
# shape660        ValveMan        MAV_OS1_021_047
# shape661        Line            MAL_OS1_483
# shape580        Line            MAL_OS1_483
# shape262        Line            MAL_OS1_483
# shape455        ValveMan        MAV_OS1_024_031
# shape271        Line            MAL_OS1_483
# shape116        Line            MAL_OS1_491
# shape422        ValveMan        MAV_OS1_062_013
# shape341        Line            MAL_OS1_491
# shape584        Line            MAL_OS1_2426
# shape640        ValveMan        MAV_OS1_022_068
# shape641        ValveMan        MAV_OS1_022_069
# shape642        ValveMan        MAV_OS1_022_067
# shape643        Line            MAL_OS1_2426
# shape644        Line            MAL_OS1_2426
# shape645        Line            MAL_OS1_2426
# shape646        Line            MAL_OS1_2426
# shape647        Line            MAL_OS1_2426
# shape648        Line            MAL_OS1_2426
# shape649        ValveMan        MAV_OS1_022_064
# shape668        Line            MAL_OS1_2426
# PseudoValve039  ValvePseudo     _P53102AL
# PseudoValve040  ValvePseudo     _P53102AR
# PseudoValve041  ValvePseudo     _P53102BL
# PseudoValve042  ValvePseudo     _P53102BR
# PseudoValve043  ValvePseudo     _P53104AL
# PseudoValve044  ValvePseudo     _P53104AR
# PseudoValve045  ValvePseudo     _P53104BL
# PseudoValve046  ValvePseudo     _P53104BR
# PseudoValve047  ValvePseudo     _P5399AL
# PseudoValve048  ValvePseudo     _P5399AR
# PseudoValve049  ValvePseudo     _P5399BL
# PseudoValve050  ValvePseudo     _P5399BR
# shape619        Line            MAL_OS1_368
# shape650        ValveMan        MAV_OS1_022_063
# shape438        ValveMan        MAV_OS1_018_109
# shape292        Line            MAL_OS1_314
# shape439        ValveMan        MAV_OS1_018_108
# shape293        Line            MAL_OS1_314
# shape461        ValveMan        MAV_OS1_018_110
# shape587        Line            MAL_OS1_314
# shape297        Line            MAL_OS1_314
# shape464        ValveMan        MAV_OS1_018_111
# shape311        Line            MAL_OS1_323
# shape347        Line            MAL_OS1_321
# shape348        Line            MAL_OS1_326
# shape349        Line            MAL_OS1_327
# shape588        Line            MAL_OS1_314
# shape465        ValveMan        MAV_OS1_018_072
# shape617        Line            MAL_OS1_323
# shape622        Line            MAL_OS1_323
# shape637        Line            MAL_OS1_323
# shape350        Line            MAL_OS1_323
# shape475        ValveMan        MAV_OS1_018_071
# shape483        ValveMan        MAV_OS1_018_074
# shape484        ValveMan        MAV_OS1_018_075
# shape638        Line            MAL_OS1_323
# shape655        Line            MAL_OS1_321
# shape352        Line            MAL_OS1_321
# shape672        Line            MAL_OS1_321
# shape673        Line            MAL_OS1_321
# shape674        Line            MAL_OS1_326
# shape675        Line            MAL_OS1_326
# shape676        Line            MAL_OS1_327
# shape353        Line            MAL_OS1_326
# shape354        Line            MAL_OS1_327
# shape677        Line            MAL_OS1_220
# shape355        Line            MAL_OS1_220
# shape678        Line            MAL_OS1_230
# shape356        Line            MAL_OS1_230
# shape679        Line            MAL_OS1_246
# shape357        Line            MAL_OS1_246
# shape589        Line            MAL_OS1_368
# shape358        Line            MAL_OS1_327
# shape485        ValveMan        MAV_OS1_018_114
# shape359        Line            MAL_OS1_368
# shape360        Line            MAL_OS1_326
# shape486        ValveMan        MAV_OS1_018_115
# shape361        Line            MAL_OS1_368
# shape362        Line            MAL_OS1_321
# shape487        ValveMan        MAV_OS1_018_117
# shape363        Line            MAL_OS1_368
# shape364        Line            MAL_OS1_323
# shape488        ValveMan        MAV_OS1_018_116
# shape365        Line            MAL_OS1_368
# shape590        Line            MAL_OS1_368
# shape591        Line            MAL_OS1_368
# shape366        Line            MAL_OS1_326
# shape367        Line            MAL_OS1_321
# shape368        Line            MAL_OS1_321
# shape369        Line            MAL_OS1_323
# shape370        Line            MAL_OS1_323
# shape372        Line            MAL_OS1_323
# shape680        Line            MAL_OS1_312
# shape373        Line            MAL_OS1_327
# shape490        ValveMan        MAV_OS1_018_130
# shape374        Line            MAL_OS1_312
# shape375        Line            MAL_OS1_326
# shape491        ValveMan        MAV_OS1_018_141
# shape376        Line            MAL_OS1_323
# shape492        ValveMan        MAV_OS1_018_134
# shape681        ValveMan        MAV_OS1_018_011
# shape682        Line            MAL_OS1_325
# shape377        Line            MAL_OS1_325
# shape378        Line            MAL_OS1_325
# shape379        Line            MAL_OS1_325
# shape683        Line            MAL_OS1_325
# shape684        Line            MAL_OS1_325
# shape380        Line            MAL_OS1_2427
# shape686        Line            MAL_OS1_325
# shape689        ValveMan        MAV_OS1_018_013
# shape690        ValveMan        MAV_OS1_018_100
# shape691        ValveMan        MAV_OS1_018_172
# shape382        Line            MAL_OS1_325
# shape692        Line            MAL_OS1_491
# shape693        Line            MAL_OS1_491
# shape383        Line            MAL_OS1_220
# shape493        ValveMan        MAV_OS1_018_073
# shape694        ValveMan        MAV_OS1_022_065
# shape695        Line            MAL_OS1_2430
# shape696        ValveMan        MAV_OS1_022_066
# shape697        Line            MAL_OS1_2430
# shape698        Line            MAL_OS1_483
# shape699        Line            MAL_OS1_483
# shape592        Line            MAL_OS1_2424
# shape517        ValveMan        MAV_OS1_022_162
# shape384        Line            MAL_OS1_2424
# shape402        Line            MAL_OS1_2424
# shape494        ValveMan        MAV_OS1_018_065
# shape275        Line            MAL_OS1_312

# %%
# all element
result = {}
for i in total:
    temp = {}
    if 'Value?ShapeID' in total[i]:
        temp['type'] = total[i]['Value?ShapeID']
    else :
        temp['type'] = ''
        
    if 'Point?element' in total[i]:
        temp['element'] = total[i]['Point?element']
    else :
        temp['element'] = ''
        
    if 'Rotation' in total[i]:
        temp['rotation'] = total[i]['Rotation']
    else : 
        temp['rotation'] = ''
    
    temp['left'] = total[i]['LEFT'].rstrip('px')
    temp['top'] = total[i]['TOP'].rstrip('px')
    temp['height'] = total[i]['HEIGHT'].rstrip('px')
    temp['width'] = total[i]['WIDTH'].rstrip('px')
    temp['L'] = ''
    temp['T'] = ''
    temp['R'] = ''
    temp['B'] = ''
    temp['x1'] = ''
    temp['y1'] = ''
    temp['x2'] = ''
    temp['y2'] = ''
    if temp['type'] != '':
        temp['left'] = int(temp['left'])
        temp['top'] = int(temp['top'])
        temp['height'] = int(temp['height'])
        temp['width'] = int(temp['width'])
        temp['L'] = temp['left']
        temp['T'] = temp['top']
        temp['R'] = temp['left'] + temp['width']
        temp['B'] = temp['top'] + temp['height']
        temp['x1'] = temp['L']
        temp['y1'] = temp['T'] + temp['height']/2
        temp['x2'] = temp['R']
        temp['y2'] = temp['B'] - temp['height']/2
        if (temp['rotation'] == '90' or temp['rotation'] == '270'):
            temp['L'] = temp['L'] + temp['width']/2 - temp['height']/2
            temp['T'] = temp['T'] - temp['width']/2 + temp['height']/2
            temp['R'] = temp['R']  - temp['width']/2 + temp['height']/2
            temp['B'] = temp['B'] + temp['width']/2 - temp['height']/2
            temp['x1'] = temp['x1'] + temp['width']/2
            temp['y1'] = temp['y1'] - temp['width']/2
            temp['x2'] = temp['x2'] - temp['width']/2
            temp['y2'] = temp['y2'] + temp['width']/2
    result[i] = temp
for r,k in result.items():
    print(r,k)

# %%
# line, valve
result = {}
for i,each in total.items():
    temp = dict(zip(['type','element','rotation'],['','','']))
    if 'Value?ShapeID' in each:
        temp['type'] = each['Value?ShapeID']
    if 'Point?element' in each:
        temp['element'] = each['Point?element']
    if 'Rotation' in each:
        temp['rotation'] = each['Rotation']
    
    temp['left'] = each['LEFT'].rstrip('px')
    temp['top'] = each['TOP'].rstrip('px')
    temp['height'] = each['HEIGHT'].rstrip('px')
    temp['width'] = each['WIDTH'].rstrip('px')
    temp.update(dict(zip(['x1','y1','x2','y2'],['','','',''])))
    if temp['type'] == 'Line':
        if each['src'][-11::] == 'MALineU.sha':
            temp['direction'] = 'V'
        else : 
            temp['direction'] = 'H'
        if temp['direction'] == 'H':
            temp['x1'] = int(temp['left'])
            temp['y1'] = int(temp['top'])
            temp['x2'] = int(temp['left']) + int(temp['width'])
            temp['y2'] = temp['y1']
        elif temp['direction'] == 'V':
            temp['x1'] = int(temp['left'])
            temp['y1'] = int(temp['top'])
            temp['x2'] = temp['x1'] 
            temp['y2'] = int(temp['top']) + int(temp['height'])

    elif temp['type'] == 'ValveMan':
        temp['x1'] = int(temp['left'])
        temp['y1'] = int(temp['top']) + int(temp['height'])/2
        temp['x2'] = temp['x1'] + int(temp['width'])
        temp['y2'] = temp['y1']
        if temp['rotation'] == '90' or temp['rotation'] == '270':
            temp['x1'] = temp['x1'] + int(temp['width'])/2
            temp['y1'] = temp['y1'] - int(temp['width'])/2
            temp['x2'] = temp['x2'] - int(temp['width'])/2
            temp['y2'] = temp['y2'] + int(temp['width'])/2
            
    result[i] = temp
    
for i,v in result.items():
    if v['type'] == 'ValveMan':
        print(i,v)
# Out:
# shape414 {'type': 'ValveMan', 'element': 'MAV_OS1_054_002', 'rotation': '', 'left': '200', 'top': '85', 'height': '10', 'width': '30', 'x1': 200, 'y1': 90.0, 'x2': 230, 'y2': 90.0}
# shape415 {'type': 'ValveMan', 'element': 'MAV_OS1_054_017', 'rotation': '', 'left': '200', 'top': '175', 'height': '10', 'width': '30', 'x1': 200, 'y1': 180.0, 'x2': 230, 'y2': 180.0}
# shape416 {'type': 'ValveMan', 'element': 'MAV_OS1_054_021', 'rotation': '', 'left': '200', 'top': '295', 'height': '10', 'width': '30', 'x1': 200, 'y1': 300.0, 'x2': 230, 'y2': 300.0}
# shape417 {'type': 'ValveMan', 'element': 'MAV_OS1_054_026', 'rotation': '', 'left': '200', 'top': '400', 'height': '10', 'width': '30', 'x1': 200, 'y1': 405.0, 'x2': 230, 'y2': 405.0}
# shape418 {'type': 'ValveMan', 'element': 'MAV_OS1_053_027', 'rotation': '', 'left': '200', 'top': '500', 'height': '10', 'width': '30', 'x1': 200, 'y1': 505.0, 'x2': 230, 'y2': 505.0}
# shape421 {'type': 'ValveMan', 'element': 'MAV_OS1_062_004', 'rotation': '', 'left': '200', 'top': '625', 'height': '10', 'width': '30', 'x1': 200, 'y1': 630.0, 'x2': 230, 'y2': 630.0}
# shape423 {'type': 'ValveMan', 'element': 'MAV_OS1_059_006', 'rotation': '', 'left': '200', 'top': '840', 'height': '10', 'width': '30', 'x1': 200, 'y1': 845.0, 'x2': 230, 'y2': 845.0}
# shape444 {'type': 'ValveMan', 'element': 'MAV_OS1_017_024', 'rotation': '', 'left': '365', 'top': '400', 'height': '10', 'width': '30', 'x1': 365, 'y1': 405.0, 'x2': 395, 'y2': 405.0}
# shape447 {'type': 'ValveMan', 'element': 'MAV_OS1_018_104', 'rotation': '', 'left': '620', 'top': '500', 'height': '10', 'width': '30', 'x1': 620, 'y1': 505.0, 'x2': 650, 'y2': 505.0}
# shape457 {'type': 'ValveMan', 'element': 'MAV_OS1_021_122', 'rotation': '', 'left': '440', 'top': '840', 'height': '10', 'width': '30', 'x1': 440, 'y1': 845.0, 'x2': 470, 'y2': 845.0}
# shape458 {'type': 'ValveMan', 'element': 'MAV_OS1_021_117', 'rotation': '', 'left': '440', 'top': '780', 'height': '10', 'width': '30', 'x1': 440, 'y1': 785.0, 'x2': 470, 'y2': 785.0}
# shape459 {'type': 'ValveMan', 'element': 'MAV_OS1_021_140', 'rotation': '', 'left': '440', 'top': '810', 'height': '10', 'width': '30', 'x1': 440, 'y1': 815.0, 'x2': 470, 'y2': 815.0}
# shape462 {'type': 'ValveMan', 'element': 'MAV_OS1_018_007', 'rotation': '', 'left': '1125', 'top': '85', 'height': '10', 'width': '30', 'x1': 1125, 'y1': 90.0, 'x2': 1155, 'y2': 90.0}
# shape463 {'type': 'ValveMan', 'element': 'MAV_OS1_018_008', 'rotation': '', 'left': '1125', 'top': '295', 'height': '10', 'width': '30', 'x1': 1125, 'y1': 300.0, 'x2': 1155, 'y2': 300.0}
# shape506 {'type': 'ValveMan', 'element': 'MAV_OS1_022_062', 'rotation': '', 'left': '1125', 'top': '435', 'height': '10', 'width': '30', 'x1': 1125, 'y1': 440.0, 'x2': 1155, 'y2': 440.0}
# shape507 {'type': 'ValveMan', 'element': 'OMAVALVE', 'rotation': '', 'left': '1195', 'top': '390', 'height': '10', 'width': '30', 'x1': 1195, 'y1': 395.0, 'x2': 1225, 'y2': 395.0}
# shape508 {'type': 'ValveMan', 'element': 'MAV_OS1_022_073', 'rotation': '', 'left': '1435', 'top': '420', 'height': '10', 'width': '30', 'x1': 1435, 'y1': 425.0, 'x2': 1465, 'y2': 425.0}
# shape509 {'type': 'ValveMan', 'element': 'MAV_OS1_022_074', 'rotation': '', 'left': '1435', 'top': '450', 'height': '10', 'width': '30', 'x1': 1435, 'y1': 455.0, 'x2': 1465, 'y2': 455.0}
# shape510 {'type': 'ValveMan', 'element': 'MAV_OS1_022_061', 'rotation': '90', 'left': '975', 'top': '555', 'height': '10', 'width': '30', 'x1': 990.0, 'y1': 545.0, 'x2': 990.0, 'y2': 575.0}
# shape511 {'type': 'ValveMan', 'element': 'MAV_OS1_022_072', 'rotation': '', 'left': '935', 'top': '470', 'height': '10', 'width': '30', 'x1': 935, 'y1': 475.0, 'x2': 965, 'y2': 475.0}
# shape512 {'type': 'ValveMan', 'element': 'MAV_OS1_022_033', 'rotation': '', 'left': '935', 'top': '495', 'height': '10', 'width': '30', 'x1': 935, 'y1': 500.0, 'x2': 965, 'y2': 500.0}
# shape513 {'type': 'ValveMan', 'element': 'MAV_OS1_022_057', 'rotation': '', 'left': '935', 'top': '520', 'height': '10', 'width': '30', 'x1': 935, 'y1': 525.0, 'x2': 965, 'y2': 525.0}
# shape514 {'type': 'ValveMan', 'element': 'MAV_OS1_022_060', 'rotation': '', 'left': '1125', 'top': '585', 'height': '10', 'width': '30', 'x1': 1125, 'y1': 590.0, 'x2': 1155, 'y2': 590.0}
# shape515 {'type': 'ValveMan', 'element': 'OMAVALVE', 'rotation': '', 'left': '1195', 'top': '540', 'height': '10', 'width': '30', 'x1': 1195, 'y1': 545.0, 'x2': 1225, 'y2': 545.0}
# shape516 {'type': 'ValveMan', 'element': 'MAV_OS1_022_059', 'rotation': '', 'left': '1435', 'top': '570', 'height': '10', 'width': '30', 'x1': 1435, 'y1': 575.0, 'x2': 1465, 'y2': 575.0}
# shape518 {'type': 'ValveMan', 'element': 'MAV_OS1_019_004', 'rotation': '', 'left': '1605', 'top': '450', 'height': '10', 'width': '30', 'x1': 1605, 'y1': 455.0, 'x2': 1635, 'y2': 455.0}
# shape519 {'type': 'ValveMan', 'element': 'MAV_OS1_014_003', 'rotation': '', 'left': '1705', 'top': '450', 'height': '10', 'width': '30', 'x1': 1705, 'y1': 455.0, 'x2': 1735, 'y2': 455.0}
# shape468 {'type': 'ValveMan', 'element': 'MAV_OS1_018_043', 'rotation': '', 'left': '1085', 'top': '840', 'height': '10', 'width': '30', 'x1': 1085, 'y1': 845.0, 'x2': 1115, 'y2': 845.0}
# shape469 {'type': 'ValveMan', 'element': 'OMAVALVE', 'rotation': '', 'left': '1195', 'top': '795', 'height': '10', 'width': '30', 'x1': 1195, 'y1': 800.0, 'x2': 1225, 'y2': 800.0}
# shape470 {'type': 'ValveMan', 'element': 'MAV_OS1_018_042', 'rotation': '', 'left': '1085', 'top': '685', 'height': '10', 'width': '30', 'x1': 1085, 'y1': 690.0, 'x2': 1115, 'y2': 690.0}
# shape471 {'type': 'ValveMan', 'element': 'OMAVALVE', 'rotation': '', 'left': '1195', 'top': '640', 'height': '10', 'width': '30', 'x1': 1195, 'y1': 645.0, 'x2': 1225, 'y2': 645.0}
# shape472 {'type': 'ValveMan', 'element': 'MAV_OS1_018_038', 'rotation': '', 'left': '1375', 'top': '670', 'height': '10', 'width': '30', 'x1': 1375, 'y1': 675.0, 'x2': 1405, 'y2': 675.0}
# shape473 {'type': 'ValveMan', 'element': 'MAV_OS1_018_136', 'rotation': '', 'left': '1375', 'top': '825', 'height': '10', 'width': '30', 'x1': 1375, 'y1': 830.0, 'x2': 1405, 'y2': 830.0}
# shape467 {'type': 'ValveMan', 'element': 'MAV_OS1_018_006', 'rotation': '', 'left': '1270', 'top': '75', 'height': '10', 'width': '30', 'x1': 1270, 'y1': 80.0, 'x2': 1300, 'y2': 80.0}
# shape476 {'type': 'ValveMan', 'element': 'MAV_OS1_018_009', 'rotation': '', 'left': '1270', 'top': '280', 'height': '10', 'width': '30', 'x1': 1270, 'y1': 285.0, 'x2': 1300, 'y2': 285.0}
# shape477 {'type': 'ValveMan', 'element': 'MAV_OS1_018_067', 'rotation': '', 'left': '1390', 'top': '75', 'height': '10', 'width': '30', 'x1': 1390, 'y1': 80.0, 'x2': 1420, 'y2': 80.0}
# shape527 {'type': 'ValveMan', 'element': 'MAV_OS1_018_106', 'rotation': '', 'left': '1390', 'top': '135', 'height': '10', 'width': '30', 'x1': 1390, 'y1': 140.0, 'x2': 1420, 'y2': 140.0}
# shape529 {'type': 'ValveMan', 'element': 'MAV_OS1_018_107', 'rotation': '', 'left': '1390', 'top': '215', 'height': '10', 'width': '30', 'x1': 1390, 'y1': 220.0, 'x2': 1420, 'y2': 220.0}
# shape479 {'type': 'ValveMan', 'element': 'MAV_OS1_014_004', 'rotation': '', 'left': '1485', 'top': '105', 'height': '10', 'width': '30', 'x1': 1485, 'y1': 110.0, 'x2': 1515, 'y2': 110.0}
# shape480 {'type': 'ValveMan', 'element': 'MAV_OS1_013_012', 'rotation': '', 'left': '1580', 'top': '75', 'height': '10', 'width': '30', 'x1': 1580, 'y1': 80.0, 'x2': 1610, 'y2': 80.0}
# shape481 {'type': 'ValveMan', 'element': 'MAV_OS1_013_013', 'rotation': '', 'left': '1630', 'top': '75', 'height': '10', 'width': '30', 'x1': 1630, 'y1': 80.0, 'x2': 1660, 'y2': 80.0}
# shape433 {'type': 'ValveMan', 'element': 'MAV_OS1_013_014', 'rotation': '', 'left': '1630', 'top': '105', 'height': '10', 'width': '30', 'x1': 1630, 'y1': 110.0, 'x2': 1660, 'y2': 110.0}
# shape442 {'type': 'ValveMan', 'element': 'MAV_OS1_013_015', 'rotation': '270', 'left': '1700', 'top': '115', 'height': '10', 'width': '30', 'x1': 1715.0, 'y1': 105.0, 'x2': 1715.0, 'y2': 135.0}
# shape660 {'type': 'ValveMan', 'element': 'MAV_OS1_021_047', 'rotation': '', 'left': '440', 'top': '655', 'height': '10', 'width': '30', 'x1': 440, 'y1': 660.0, 'x2': 470, 'y2': 660.0}
# shape455 {'type': 'ValveMan', 'element': 'MAV_OS1_024_031', 'rotation': '', 'left': '320', 'top': '655', 'height': '10', 'width': '30', 'x1': 320, 'y1': 660.0, 'x2': 350, 'y2': 660.0}
# shape422 {'type': 'ValveMan', 'element': 'MAV_OS1_062_013', 'rotation': '', 'left': '200', 'top': '725', 'height': '10', 'width': '30', 'x1': 200, 'y1': 730.0, 'x2': 230, 'y2': 730.0}
# shape640 {'type': 'ValveMan', 'element': 'MAV_OS1_022_068', 'rotation': '', 'left': '860', 'top': '690', 'height': '10', 'width': '30', 'x1': 860, 'y1': 695.0, 'x2': 890, 'y2': 695.0}
# shape641 {'type': 'ValveMan', 'element': 'MAV_OS1_022_069', 'rotation': '', 'left': '860', 'top': '655', 'height': '10', 'width': '30', 'x1': 860, 'y1': 660.0, 'x2': 890, 'y2': 660.0}
# shape642 {'type': 'ValveMan', 'element': 'MAV_OS1_022_067', 'rotation': '', 'left': '860', 'top': '620', 'height': '10', 'width': '30', 'x1': 860, 'y1': 625.0, 'x2': 890, 'y2': 625.0}
# shape649 {'type': 'ValveMan', 'element': 'MAV_OS1_022_064', 'rotation': '0', 'left': '860', 'top': '585', 'height': '10', 'width': '30', 'x1': 860, 'y1': 590.0, 'x2': 890, 'y2': 590.0}
# shape650 {'type': 'ValveMan', 'element': 'MAV_OS1_022_063', 'rotation': '0', 'left': '920', 'top': '585', 'height': '10', 'width': '30', 'x1': 920, 'y1': 590.0, 'x2': 950, 'y2': 590.0}
# shape438 {'type': 'ValveMan', 'element': 'MAV_OS1_018_109', 'rotation': '', 'left': '945', 'top': '85', 'height': '10', 'width': '30', 'x1': 945, 'y1': 90.0, 'x2': 975, 'y2': 90.0}
# shape439 {'type': 'ValveMan', 'element': 'MAV_OS1_018_108', 'rotation': '', 'left': '945', 'top': '125', 'height': '10', 'width': '30', 'x1': 945, 'y1': 130.0, 'x2': 975, 'y2': 130.0}
# shape461 {'type': 'ValveMan', 'element': 'MAV_OS1_018_110', 'rotation': '', 'left': '945', 'top': '165', 'height': '10', 'width': '30', 'x1': 945, 'y1': 170.0, 'x2': 975, 'y2': 170.0}
# shape464 {'type': 'ValveMan', 'element': 'MAV_OS1_018_111', 'rotation': '', 'left': '945', 'top': '205', 'height': '10', 'width': '30', 'x1': 945, 'y1': 210.0, 'x2': 975, 'y2': 210.0}
# shape465 {'type': 'ValveMan', 'element': 'MAV_OS1_018_072', 'rotation': '', 'left': '655', 'top': '85', 'height': '10', 'width': '30', 'x1': 655, 'y1': 90.0, 'x2': 685, 'y2': 90.0}
# shape475 {'type': 'ValveMan', 'element': 'MAV_OS1_018_071', 'rotation': '', 'left': '655', 'top': '125', 'height': '10', 'width': '30', 'x1': 655, 'y1': 130.0, 'x2': 685, 'y2': 130.0}
# shape483 {'type': 'ValveMan', 'element': 'MAV_OS1_018_074', 'rotation': '', 'left': '655', 'top': '165', 'height': '10', 'width': '30', 'x1': 655, 'y1': 170.0, 'x2': 685, 'y2': 170.0}
# shape484 {'type': 'ValveMan', 'element': 'MAV_OS1_018_075', 'rotation': '', 'left': '655', 'top': '205', 'height': '10', 'width': '30', 'x1': 655, 'y1': 210.0, 'x2': 685, 'y2': 210.0}
# shape485 {'type': 'ValveMan', 'element': 'MAV_OS1_018_114', 'rotation': '', 'left': '865', 'top': '355', 'height': '10', 'width': '30', 'x1': 865, 'y1': 360.0, 'x2': 895, 'y2': 360.0}
# shape486 {'type': 'ValveMan', 'element': 'MAV_OS1_018_115', 'rotation': '', 'left': '865', 'top': '325', 'height': '10', 'width': '30', 'x1': 865, 'y1': 330.0, 'x2': 895, 'y2': 330.0}
# shape487 {'type': 'ValveMan', 'element': 'MAV_OS1_018_117', 'rotation': '', 'left': '865', 'top': '295', 'height': '10', 'width': '30', 'x1': 865, 'y1': 300.0, 'x2': 895, 'y2': 300.0}
# shape488 {'type': 'ValveMan', 'element': 'MAV_OS1_018_116', 'rotation': '', 'left': '865', 'top': '265', 'height': '10', 'width': '30', 'x1': 865, 'y1': 270.0, 'x2': 895, 'y2': 270.0}
# shape490 {'type': 'ValveMan', 'element': 'MAV_OS1_018_130', 'rotation': '', 'left': '770', 'top': '355', 'height': '10', 'width': '30', 'x1': 770, 'y1': 360.0, 'x2': 800, 'y2': 360.0}
# shape491 {'type': 'ValveMan', 'element': 'MAV_OS1_018_141', 'rotation': '', 'left': '735', 'top': '325', 'height': '10', 'width': '30', 'x1': 735, 'y1': 330.0, 'x2': 765, 'y2': 330.0}
# shape492 {'type': 'ValveMan', 'element': 'MAV_OS1_018_134', 'rotation': '', 'left': '665', 'top': '265', 'height': '10', 'width': '30', 'x1': 665, 'y1': 270.0, 'x2': 695, 'y2': 270.0}
# shape681 {'type': 'ValveMan', 'element': 'MAV_OS1_018_011', 'rotation': '270', 'left': '905', 'top': '390', 'height': '10', 'width': '30', 'x1': 920.0, 'y1': 380.0, 'x2': 920.0, 'y2': 410.0}
# shape689 {'type': 'ValveMan', 'element': 'MAV_OS1_018_013', 'rotation': '0', 'left': '865', 'top': '420', 'height': '10', 'width': '30', 'x1': 865, 'y1': 425.0, 'x2': 895, 'y2': 425.0}
# shape690 {'type': 'ValveMan', 'element': 'MAV_OS1_018_100', 'rotation': '0', 'left': '780', 'top': '450', 'height': '10', 'width': '30', 'x1': 780, 'y1': 455.0, 'x2': 810, 'y2': 455.0}
# shape691 {'type': 'ValveMan', 'element': 'MAV_OS1_018_172', 'rotation': '0', 'left': '780', 'top': '495', 'height': '10', 'width': '30', 'x1': 780, 'y1': 500.0, 'x2': 810, 'y2': 500.0}
# shape493 {'type': 'ValveMan', 'element': 'MAV_OS1_018_073', 'rotation': '', 'left': '380', 'top': '125', 'height': '10', 'width': '30', 'x1': 380, 'y1': 130.0, 'x2': 410, 'y2': 130.0}
# shape694 {'type': 'ValveMan', 'element': 'MAV_OS1_022_065', 'rotation': '', 'left': '920', 'top': '690', 'height': '10', 'width': '30', 'x1': 920, 'y1': 695.0, 'x2': 950, 'y2': 695.0}
# shape696 {'type': 'ValveMan', 'element': 'MAV_OS1_022_066', 'rotation': '', 'left': '920', 'top': '655', 'height': '10', 'width': '30', 'x1': 920, 'y1': 660.0, 'x2': 950, 'y2': 660.0}
# shape517 {'type': 'ValveMan', 'element': 'MAV_OS1_022_162', 'rotation': '', 'left': '1435', 'top': '600', 'height': '10', 'width': '30', 'x1': 1435, 'y1': 605.0, 'x2': 1465, 'y2': 605.0}
# shape494 {'type': 'ValveMan', 'element': 'MAV_OS1_018_065', 'rotation': '', 'left': '495', 'top': '500', 'height': '10', 'width': '30', 'x1': 495, 'y1': 505.0, 'x2': 525, 'y2': 505.0}

# %%
elem = {}
for i in result:
    if result[i]['element'] != '':
        if result[i]['element'] not in elem:
            elem[result[i]['element']] = {i:result[i]}
        else:
            elem[result[i]['element']].update({i:result[i]})
elem
# Out:
# {'MAL_OS1_202': {'shape111': {'element': 'MAL_OS1_202',
#    'height': '10',
#    'left': '130',
#    'rotation': '',
#    'top': '505',
#    'type': 'Line',
#    'width': '75'},
#   'shape254': {'element': 'MAL_OS1_202',
#    'height': '10',
#    'left': '225',
#    'rotation': '',
#    'top': '505',
#    'type': 'Line',
#    'width': '275'}},
#  'MAL_OS1_218': {'shape104': {'element': 'MAL_OS1_218',
#    'height': '10',
#    'left': '130',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '75'},
#   'shape223': {'element': 'MAL_OS1_218',
#    'height': '10',
#    'left': '225',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '435'}},
#  'MAL_OS1_220': {'shape108': {'element': 'MAL_OS1_220',
#    'height': '10',
#    'left': '130',
#    'rotation': '',
#    'top': '180',
#    'type': 'Line',
#    'width': '75'},
#   'shape232': {'element': 'MAL_OS1_220',
#    'height': '10',
#    'left': '225',
#    'rotation': '',
#    'top': '180',
#    'type': 'Line',
#    'width': '210'},
#   'shape355': {'element': 'MAL_OS1_220',
#    'height': '15',
#    'left': '435',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '225'},
#   'shape383': {'element': 'MAL_OS1_220',
#    'height': '15',
#    'left': '405',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '30'},
#   'shape677': {'element': 'MAL_OS1_220',
#    'height': '50',
#    'left': '435',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_230': {'shape109': {'element': 'MAL_OS1_230',
#    'height': '10',
#    'left': '130',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '75'},
#   'shape240': {'element': 'MAL_OS1_230',
#    'height': '10',
#    'left': '225',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '255'},
#   'shape356': {'element': 'MAL_OS1_230',
#    'height': '15',
#    'left': '480',
#    'rotation': '',
#    'top': '170',
#    'type': 'Line',
#    'width': '180'},
#   'shape678': {'element': 'MAL_OS1_230',
#    'height': '130',
#    'left': '480',
#    'rotation': '',
#    'top': '170',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_232': {'shape110': {'element': 'MAL_OS1_232',
#    'height': '10',
#    'left': '130',
#    'rotation': '',
#    'top': '405',
#    'type': 'Line',
#    'width': '75'},
#   'shape250': {'element': 'MAL_OS1_232',
#    'height': '15',
#    'left': '225',
#    'rotation': '',
#    'top': '405',
#    'type': 'Line',
#    'width': '145'}},
#  'MAL_OS1_2424': {'shape384': {'element': 'MAL_OS1_2424',
#    'height': '10',
#    'left': '1390',
#    'rotation': '',
#    'top': '605',
#    'type': 'Line',
#    'width': '50'},
#   'shape398': {'element': 'MAL_OS1_2424',
#    'height': '10',
#    'left': '1220',
#    'rotation': '',
#    'top': '545',
#    'type': 'Line',
#    'width': '120'},
#   'shape400': {'element': 'MAL_OS1_2424',
#    'height': '10',
#    'left': '1225',
#    'rotation': '',
#    'top': '575',
#    'type': 'Line',
#    'width': '115'},
#   'shape401': {'element': 'MAL_OS1_2424',
#    'height': '10',
#    'left': '1340',
#    'rotation': '',
#    'top': '575',
#    'type': 'Line',
#    'width': '50'},
#   'shape402': {'element': 'MAL_OS1_2424',
#    'height': '10',
#    'left': '1390',
#    'rotation': '',
#    'top': '575',
#    'type': 'Line',
#    'width': '50'},
#   'shape577': {'element': 'MAL_OS1_2424',
#    'height': '30',
#    'left': '1340',
#    'rotation': '',
#    'top': '545',
#    'type': 'Line',
#    'width': '5'},
#   'shape592': {'element': 'MAL_OS1_2424',
#    'height': '30',
#    'left': '1390',
#    'rotation': '',
#    'top': '575',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_2426': {'shape396': {'element': 'MAL_OS1_2426',
#    'height': '10',
#    'left': '1080',
#    'rotation': '',
#    'top': '590',
#    'type': 'Line',
#    'width': '50'},
#   'shape397': {'element': 'MAL_OS1_2426',
#    'height': '10',
#    'left': '1080',
#    'rotation': '',
#    'top': '545',
#    'type': 'Line',
#    'width': '120'},
#   'shape399': {'element': 'MAL_OS1_2426',
#    'height': '10',
#    'left': '990',
#    'rotation': '',
#    'top': '590',
#    'type': 'Line',
#    'width': '90'},
#   'shape571': {'element': 'MAL_OS1_2426',
#    'height': '45',
#    'left': '1080',
#    'rotation': '',
#    'top': '545',
#    'type': 'Line',
#    'width': '10'},
#   'shape584': {'element': 'MAL_OS1_2426',
#    'height': '20',
#    'left': '990',
#    'rotation': '',
#    'top': '570',
#    'type': 'Line',
#    'width': '15'},
#   'shape643': {'element': 'MAL_OS1_2426',
#    'height': '10',
#    'left': '945',
#    'rotation': '',
#    'top': '695',
#    'type': 'Line',
#    'width': '45'},
#   'shape644': {'element': 'MAL_OS1_2426',
#    'height': '10',
#    'left': '945',
#    'rotation': '',
#    'top': '660',
#    'type': 'Line',
#    'width': '45'},
#   'shape645': {'element': 'MAL_OS1_2426',
#    'height': '10',
#    'left': '885',
#    'rotation': '',
#    'top': '625',
#    'type': 'Line',
#    'width': '105'},
#   'shape646': {'element': 'MAL_OS1_2426',
#    'height': '35',
#    'left': '990',
#    'rotation': '',
#    'top': '590',
#    'type': 'Line',
#    'width': '10'},
#   'shape647': {'element': 'MAL_OS1_2426',
#    'height': '35',
#    'left': '990',
#    'rotation': '',
#    'top': '625',
#    'type': 'Line',
#    'width': '10'},
#   'shape648': {'element': 'MAL_OS1_2426',
#    'height': '35',
#    'left': '990',
#    'rotation': '',
#    'top': '660',
#    'type': 'Line',
#    'width': '10'},
#   'shape668': {'element': 'MAL_OS1_2426',
#    'height': '10',
#    'left': '945',
#    'rotation': '',
#    'top': '590',
#    'type': 'Line',
#    'width': '45'}},
#  'MAL_OS1_2427': {'shape380': {'element': 'MAL_OS1_2427',
#    'height': '15',
#    'left': '885',
#    'rotation': '',
#    'top': '590',
#    'type': 'Line',
#    'width': '40'}},
#  'MAL_OS1_2428': {'shape395': {'element': 'MAL_OS1_2428',
#    'height': '10',
#    'left': '1150',
#    'rotation': '',
#    'top': '590',
#    'type': 'Line',
#    'width': '50'}},
#  'MAL_OS1_2430': {'shape695': {'element': 'MAL_OS1_2430',
#    'height': '10',
#    'left': '885',
#    'rotation': '',
#    'top': '695',
#    'type': 'Line',
#    'width': '45'},
#   'shape697': {'element': 'MAL_OS1_2430',
#    'height': '10',
#    'left': '885',
#    'rotation': '',
#    'top': '660',
#    'type': 'Line',
#    'width': '40'}},
#  'MAL_OS1_2431': {'shape303': {'element': 'MAL_OS1_2431',
#    'height': '10',
#    'left': '1080',
#    'rotation': '',
#    'top': '440',
#    'type': 'Line',
#    'width': '50'},
#   'shape304': {'element': 'MAL_OS1_2431',
#    'height': '10',
#    'left': '1080',
#    'rotation': '',
#    'top': '395',
#    'type': 'Line',
#    'width': '120'},
#   'shape334': {'element': 'MAL_OS1_2431',
#    'height': '10',
#    'left': '990',
#    'rotation': '',
#    'top': '440',
#    'type': 'Line',
#    'width': '90'},
#   'shape371': {'element': 'MAL_OS1_2431',
#    'height': '10',
#    'left': '960',
#    'rotation': '',
#    'top': '475',
#    'type': 'Line',
#    'width': '30'},
#   'shape393': {'element': 'MAL_OS1_2431',
#    'height': '10',
#    'left': '960',
#    'rotation': '',
#    'top': '500',
#    'type': 'Line',
#    'width': '30'},
#   'shape394': {'element': 'MAL_OS1_2431',
#    'height': '10',
#    'left': '960',
#    'rotation': '',
#    'top': '525',
#    'type': 'Line',
#    'width': '30'},
#   'shape563': {'element': 'MAL_OS1_2431',
#    'height': '45',
#    'left': '1080',
#    'rotation': '',
#    'top': '395',
#    'type': 'Line',
#    'width': '10'},
#   'shape566': {'element': 'MAL_OS1_2431',
#    'height': '35',
#    'left': '990',
#    'rotation': '',
#    'top': '440',
#    'type': 'Line',
#    'width': '10'},
#   'shape568': {'element': 'MAL_OS1_2431',
#    'height': '25',
#    'left': '990',
#    'rotation': '',
#    'top': '475',
#    'type': 'Line',
#    'width': '10'},
#   'shape569': {'element': 'MAL_OS1_2431',
#    'height': '25',
#    'left': '990',
#    'rotation': '',
#    'top': '500',
#    'type': 'Line',
#    'width': '10'},
#   'shape570': {'element': 'MAL_OS1_2431',
#    'height': '25',
#    'left': '990',
#    'rotation': '',
#    'top': '525',
#    'type': 'Line',
#    'width': '15'}},
#  'MAL_OS1_2432': {'shape301': {'element': 'MAL_OS1_2432',
#    'height': '10',
#    'left': '1150',
#    'rotation': '',
#    'top': '440',
#    'type': 'Line',
#    'width': '50'}},
#  'MAL_OS1_2433': {'shape305': {'element': 'MAL_OS1_2433',
#    'height': '10',
#    'left': '1220',
#    'rotation': '',
#    'top': '395',
#    'type': 'Line',
#    'width': '120'},
#   'shape314': {'element': 'MAL_OS1_2433',
#    'height': '10',
#    'left': '1220',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '120'},
#   'shape315': {'element': 'MAL_OS1_2433',
#    'height': '10',
#    'left': '1340',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '50'},
#   'shape329': {'element': 'MAL_OS1_2433',
#    'height': '10',
#    'left': '1390',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '50'},
#   'shape330': {'element': 'MAL_OS1_2433',
#    'height': '10',
#    'left': '1390',
#    'rotation': '',
#    'top': '455',
#    'type': 'Line',
#    'width': '50'},
#   'shape564': {'element': 'MAL_OS1_2433',
#    'height': '30',
#    'left': '1340',
#    'rotation': '',
#    'top': '395',
#    'type': 'Line',
#    'width': '5'},
#   'shape565': {'element': 'MAL_OS1_2433',
#    'height': '30',
#    'left': '1390',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_246': {'shape357': {'element': 'MAL_OS1_246',
#    'height': '15',
#    'left': '530',
#    'rotation': '',
#    'top': '210',
#    'type': 'Line',
#    'width': '130'},
#   'shape523': {'element': 'MAL_OS1_246',
#    'height': '10',
#    'left': '390',
#    'rotation': '',
#    'top': '405',
#    'type': 'Line',
#    'width': '140'},
#   'shape679': {'element': 'MAL_OS1_246',
#    'height': '195',
#    'left': '530',
#    'rotation': '',
#    'top': '210',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_270': {'shape286': {'element': 'MAL_OS1_270',
#    'height': '10',
#    'left': '1225',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '50'}},
#  'MAL_OS1_271': {'shape281': {'element': 'MAL_OS1_271',
#    'height': '10',
#    'left': '1150',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '50'}},
#  'MAL_OS1_272': {'shape282': {'element': 'MAL_OS1_272',
#    'height': '10',
#    'left': '1150',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '50'}},
#  'MAL_OS1_273': {'shape287': {'element': 'MAL_OS1_273',
#    'height': '10',
#    'left': '1225',
#    'rotation': '',
#    'top': '285',
#    'type': 'Line',
#    'width': '50'}},
#  'MAL_OS1_286': {'shape326': {'element': 'MAL_OS1_286',
#    'height': '10',
#    'left': '1220',
#    'rotation': '',
#    'top': '645',
#    'type': 'Line',
#    'width': '45'},
#   'shape327': {'element': 'MAL_OS1_286',
#    'height': '10',
#    'left': '1225',
#    'rotation': '',
#    'top': '675',
#    'type': 'Line',
#    'width': '40'},
#   'shape328': {'element': 'MAL_OS1_286',
#    'height': '10',
#    'left': '1270',
#    'rotation': '',
#    'top': '675',
#    'type': 'Line',
#    'width': '110'},
#   'shape576': {'element': 'MAL_OS1_286',
#    'height': '30',
#    'left': '1265',
#    'rotation': '',
#    'top': '645',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_287': {'shape323': {'element': 'MAL_OS1_287',
#    'height': '10',
#    'left': '1155',
#    'rotation': '',
#    'top': '690',
#    'type': 'Line',
#    'width': '45'},
#   'shape324': {'element': 'MAL_OS1_287',
#    'height': '10',
#    'left': '1110',
#    'rotation': '',
#    'top': '690',
#    'type': 'Line',
#    'width': '45'},
#   'shape325': {'element': 'MAL_OS1_287',
#    'height': '10',
#    'left': '1155',
#    'rotation': '',
#    'top': '645',
#    'type': 'Line',
#    'width': '45'},
#   'shape575': {'element': 'MAL_OS1_287',
#    'height': '45',
#    'left': '1155',
#    'rotation': '',
#    'top': '645',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_288': {'shape319': {'element': 'MAL_OS1_288',
#    'height': '10',
#    'left': '1220',
#    'rotation': '',
#    'top': '800',
#    'type': 'Line',
#    'width': '45'},
#   'shape320': {'element': 'MAL_OS1_288',
#    'height': '10',
#    'left': '1225',
#    'rotation': '',
#    'top': '830',
#    'type': 'Line',
#    'width': '40'},
#   'shape321': {'element': 'MAL_OS1_288',
#    'height': '10',
#    'left': '1265',
#    'rotation': '',
#    'top': '830',
#    'type': 'Line',
#    'width': '115'},
#   'shape573': {'element': 'MAL_OS1_288',
#    'height': '30',
#    'left': '1265',
#    'rotation': '',
#    'top': '800',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_289': {'shape312': {'element': 'MAL_OS1_289',
#    'height': '10',
#    'left': '1155',
#    'rotation': '',
#    'top': '845',
#    'type': 'Line',
#    'width': '45'},
#   'shape313': {'element': 'MAL_OS1_289',
#    'height': '10',
#    'left': '1110',
#    'rotation': '',
#    'top': '845',
#    'type': 'Line',
#    'width': '45'},
#   'shape318': {'element': 'MAL_OS1_289',
#    'height': '10',
#    'left': '1155',
#    'rotation': '',
#    'top': '800',
#    'type': 'Line',
#    'width': '45'},
#   'shape572': {'element': 'MAL_OS1_289',
#    'height': '45',
#    'left': '1155',
#    'rotation': '',
#    'top': '800',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_312': {'shape255': {'element': 'MAL_OS1_312',
#    'height': '15',
#    'left': '590',
#    'rotation': '',
#    'top': '505',
#    'type': 'Line',
#    'width': '35'},
#   'shape275': {'element': 'MAL_OS1_312',
#    'height': '15',
#    'left': '520',
#    'rotation': '',
#    'top': '505',
#    'type': 'Line',
#    'width': '70'},
#   'shape374': {'element': 'MAL_OS1_312',
#    'height': '15',
#    'left': '590',
#    'rotation': '',
#    'top': '360',
#    'type': 'Line',
#    'width': '185'},
#   'shape680': {'element': 'MAL_OS1_312',
#    'height': '145',
#    'left': '590',
#    'rotation': '',
#    'top': '360',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_313': {'shape288': {'element': 'MAL_OS1_313',
#    'height': '10',
#    'left': '1295',
#    'rotation': '',
#    'top': '285',
#    'type': 'Line',
#    'width': '50'},
#   'shape302': {'element': 'MAL_OS1_313',
#    'height': '10',
#    'left': '1295',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '50'},
#   'shape306': {'element': 'MAL_OS1_313',
#    'height': '10',
#    'left': '1345',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '50'},
#   'shape331': {'element': 'MAL_OS1_313',
#    'height': '10',
#    'left': '1345',
#    'rotation': '',
#    'top': '140',
#    'type': 'Line',
#    'width': '50'},
#   'shape332': {'element': 'MAL_OS1_313',
#    'height': '10',
#    'left': '1345',
#    'rotation': '',
#    'top': '220',
#    'type': 'Line',
#    'width': '50'},
#   'shape558': {'element': 'MAL_OS1_313',
#    'height': '60',
#    'left': '1345',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '15'},
#   'shape559': {'element': 'MAL_OS1_313',
#    'height': '80',
#    'left': '1345',
#    'rotation': '',
#    'top': '140',
#    'type': 'Line',
#    'width': '15'},
#   'shape578': {'element': 'MAL_OS1_313',
#    'height': '65',
#    'left': '1345',
#    'rotation': '',
#    'top': '220',
#    'type': 'Line',
#    'width': '15'}},
#  'MAL_OS1_314': {'shape283': {'element': 'MAL_OS1_314',
#    'height': '15',
#    'left': '970',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '100'},
#   'shape284': {'element': 'MAL_OS1_314',
#    'height': '15',
#    'left': '1070',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '60'},
#   'shape289': {'element': 'MAL_OS1_314',
#    'height': '10',
#    'left': '1070',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '60'},
#   'shape292': {'element': 'MAL_OS1_314',
#    'height': '15',
#    'left': '970',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '100'},
#   'shape293': {'element': 'MAL_OS1_314',
#    'height': '15',
#    'left': '970',
#    'rotation': '',
#    'top': '170',
#    'type': 'Line',
#    'width': '100'},
#   'shape297': {'element': 'MAL_OS1_314',
#    'height': '15',
#    'left': '970',
#    'rotation': '',
#    'top': '210',
#    'type': 'Line',
#    'width': '100'},
#   'shape553': {'element': 'MAL_OS1_314',
#    'height': '40',
#    'left': '1070',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '10'},
#   'shape554': {'element': 'MAL_OS1_314',
#    'height': '40',
#    'left': '1070',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '10'},
#   'shape587': {'element': 'MAL_OS1_314',
#    'height': '40',
#    'left': '1070',
#    'rotation': '',
#    'top': '170',
#    'type': 'Line',
#    'width': '10'},
#   'shape588': {'element': 'MAL_OS1_314',
#    'height': '90',
#    'left': '1070',
#    'rotation': '',
#    'top': '210',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_321': {'shape347': {'element': 'MAL_OS1_321',
#    'height': '15',
#    'left': '770',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '180'},
#   'shape352': {'element': 'MAL_OS1_321',
#    'height': '15',
#    'left': '680',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '90'},
#   'shape362': {'element': 'MAL_OS1_321',
#    'height': '15',
#    'left': '845',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '25'},
#   'shape367': {'element': 'MAL_OS1_321',
#    'height': '15',
#    'left': '810',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '25'},
#   'shape368': {'element': 'MAL_OS1_321',
#    'height': '15',
#    'left': '770',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '30'},
#   'shape655': {'element': 'MAL_OS1_321',
#    'height': '35',
#    'left': '770',
#    'rotation': '',
#    'top': '130',
#    'type': 'Line',
#    'width': '10'},
#   'shape672': {'element': 'MAL_OS1_321',
#    'height': '30',
#    'left': '770',
#    'rotation': '',
#    'top': '175',
#    'type': 'Line',
#    'width': '10'},
#   'shape673': {'element': 'MAL_OS1_321',
#    'height': '85',
#    'left': '770',
#    'rotation': '',
#    'top': '215',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_323': {'shape311': {'element': 'MAL_OS1_323',
#    'height': '15',
#    'left': '735',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '215'},
#   'shape350': {'element': 'MAL_OS1_323',
#    'height': '15',
#    'left': '680',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '55'},
#   'shape364': {'element': 'MAL_OS1_323',
#    'height': '15',
#    'left': '845',
#    'rotation': '',
#    'top': '270',
#    'type': 'Line',
#    'width': '25'},
#   'shape369': {'element': 'MAL_OS1_323',
#    'height': '15',
#    'left': '810',
#    'rotation': '',
#    'top': '270',
#    'type': 'Line',
#    'width': '25'},
#   'shape370': {'element': 'MAL_OS1_323',
#    'height': '15',
#    'left': '775',
#    'rotation': '',
#    'top': '270',
#    'type': 'Line',
#    'width': '25'},
#   'shape372': {'element': 'MAL_OS1_323',
#    'height': '15',
#    'left': '735',
#    'rotation': '',
#    'top': '270',
#    'type': 'Line',
#    'width': '30'},
#   'shape376': {'element': 'MAL_OS1_323',
#    'height': '15',
#    'left': '690',
#    'rotation': '',
#    'top': '270',
#    'type': 'Line',
#    'width': '45'},
#   'shape617': {'element': 'MAL_OS1_323',
#    'height': '35',
#    'left': '735',
#    'rotation': '',
#    'top': '90',
#    'type': 'Line',
#    'width': '10'},
#   'shape622': {'element': 'MAL_OS1_323',
#    'height': '30',
#    'left': '735',
#    'rotation': '',
#    'top': '135',
#    'type': 'Line',
#    'width': '10'},
#   'shape637': {'element': 'MAL_OS1_323',
#    'height': '30',
#    'left': '735',
#    'rotation': '',
#    'top': '175',
#    'type': 'Line',
#    'width': '10'},
#   'shape638': {'element': 'MAL_OS1_323',
#    'height': '55',
#    'left': '735',
#    'rotation': '',
#    'top': '215',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_325': {'shape377': {'element': 'MAL_OS1_325',
#    'height': '15',
#    'left': '890',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '30'},
#   'shape378': {'element': 'MAL_OS1_325',
#    'height': '10',
#    'left': '805',
#    'rotation': '',
#    'top': '455',
#    'type': 'Line',
#    'width': '30'},
#   'shape379': {'element': 'MAL_OS1_325',
#    'height': '10',
#    'left': '805',
#    'rotation': '',
#    'top': '500',
#    'type': 'Line',
#    'width': '30'},
#   'shape382': {'element': 'MAL_OS1_325',
#    'height': '10',
#    'left': '835',
#    'rotation': '',
#    'top': '455',
#    'type': 'Line',
#    'width': '85'},
#   'shape651': {'element': 'MAL_OS1_325',
#    'height': '90',
#    'left': '835',
#    'rotation': '',
#    'top': '500',
#    'type': 'Line',
#    'width': '10'},
#   'shape682': {'element': 'MAL_OS1_325',
#    'height': '20',
#    'left': '920',
#    'rotation': '',
#    'top': '405',
#    'type': 'Line',
#    'width': '10'},
#   'shape683': {'element': 'MAL_OS1_325',
#    'height': '30',
#    'left': '920',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '10'},
#   'shape684': {'element': 'MAL_OS1_325',
#    'height': '45',
#    'left': '835',
#    'rotation': '',
#    'top': '455',
#    'type': 'Line',
#    'width': '10'},
#   'shape686': {'element': 'MAL_OS1_325',
#    'height': '10',
#    'left': '835',
#    'rotation': '',
#    'top': '590',
#    'type': 'Line',
#    'width': '30'}},
#  'MAL_OS1_326': {'shape348': {'element': 'MAL_OS1_326',
#    'height': '15',
#    'left': '805',
#    'rotation': '',
#    'top': '170',
#    'type': 'Line',
#    'width': '145'},
#   'shape353': {'element': 'MAL_OS1_326',
#    'height': '15',
#    'left': '680',
#    'rotation': '',
#    'top': '170',
#    'type': 'Line',
#    'width': '125'},
#   'shape360': {'element': 'MAL_OS1_326',
#    'height': '15',
#    'left': '845',
#    'rotation': '',
#    'top': '330',
#    'type': 'Line',
#    'width': '25'},
#   'shape366': {'element': 'MAL_OS1_326',
#    'height': '15',
#    'left': '805',
#    'rotation': '',
#    'top': '330',
#    'type': 'Line',
#    'width': '30'},
#   'shape375': {'element': 'MAL_OS1_326',
#    'height': '15',
#    'left': '760',
#    'rotation': '',
#    'top': '330',
#    'type': 'Line',
#    'width': '45'},
#   'shape674': {'element': 'MAL_OS1_326',
#    'height': '35',
#    'left': '805',
#    'rotation': '',
#    'top': '170',
#    'type': 'Line',
#    'width': '10'},
#   'shape675': {'element': 'MAL_OS1_326',
#    'height': '115',
#    'left': '805',
#    'rotation': '',
#    'top': '215',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_327': {'shape349': {'element': 'MAL_OS1_327',
#    'height': '15',
#    'left': '680',
#    'rotation': '',
#    'top': '210',
#    'type': 'Line',
#    'width': '160'},
#   'shape354': {'element': 'MAL_OS1_327',
#    'height': '15',
#    'left': '840',
#    'rotation': '',
#    'top': '210',
#    'type': 'Line',
#    'width': '110'},
#   'shape358': {'element': 'MAL_OS1_327',
#    'height': '15',
#    'left': '840',
#    'rotation': '',
#    'top': '360',
#    'type': 'Line',
#    'width': '30'},
#   'shape373': {'element': 'MAL_OS1_327',
#    'height': '15',
#    'left': '795',
#    'rotation': '',
#    'top': '360',
#    'type': 'Line',
#    'width': '45'},
#   'shape676': {'element': 'MAL_OS1_327',
#    'height': '150',
#    'left': '840',
#    'rotation': '',
#    'top': '210',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_359': {'shape390': {'element': 'MAL_OS1_359',
#    'height': '20',
#    'left': '1400',
#    'rotation': '',
#    'top': '675',
#    'type': 'Line',
#    'width': '110'},
#   'shape391': {'element': 'MAL_OS1_359',
#    'height': '20',
#    'left': '1400',
#    'rotation': '',
#    'top': '830',
#    'type': 'Line',
#    'width': '110'},
#   'shape392': {'element': 'MAL_OS1_359',
#    'height': '10',
#    'left': '1510',
#    'rotation': '',
#    'top': '830',
#    'type': 'Line',
#    'width': '275'},
#   'shape607': {'element': 'MAL_OS1_359',
#    'height': '155',
#    'left': '1510',
#    'rotation': '',
#    'top': '675',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_360': {'shape310': {'element': 'MAL_OS1_360',
#    'height': '10',
#    'left': '465',
#    'rotation': '',
#    'top': '845',
#    'type': 'Line',
#    'width': '585'},
#   'shape316': {'element': 'MAL_OS1_360',
#    'height': '10',
#    'left': '1050',
#    'rotation': '',
#    'top': '845',
#    'type': 'Line',
#    'width': '40'},
#   'shape322': {'element': 'MAL_OS1_360',
#    'height': '20',
#    'left': '1050',
#    'rotation': '',
#    'top': '690',
#    'type': 'Line',
#    'width': '40'},
#   'shape574': {'element': 'MAL_OS1_360',
#    'height': '155',
#    'left': '1050',
#    'rotation': '',
#    'top': '690',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_368': {'shape359': {'element': 'MAL_OS1_368',
#    'height': '15',
#    'left': '890',
#    'rotation': '',
#    'top': '360',
#    'type': 'Line',
#    'width': '30'},
#   'shape361': {'element': 'MAL_OS1_368',
#    'height': '15',
#    'left': '890',
#    'rotation': '',
#    'top': '330',
#    'type': 'Line',
#    'width': '30'},
#   'shape363': {'element': 'MAL_OS1_368',
#    'height': '15',
#    'left': '890',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '30'},
#   'shape365': {'element': 'MAL_OS1_368',
#    'height': '15',
#    'left': '890',
#    'rotation': '',
#    'top': '270',
#    'type': 'Line',
#    'width': '30'},
#   'shape589': {'element': 'MAL_OS1_368',
#    'height': '30',
#    'left': '920',
#    'rotation': '',
#    'top': '330',
#    'type': 'Line',
#    'width': '10'},
#   'shape590': {'element': 'MAL_OS1_368',
#    'height': '30',
#    'left': '920',
#    'rotation': '',
#    'top': '300',
#    'type': 'Line',
#    'width': '10'},
#   'shape591': {'element': 'MAL_OS1_368',
#    'height': '30',
#    'left': '920',
#    'rotation': '',
#    'top': '270',
#    'type': 'Line',
#    'width': '10'},
#   'shape619': {'element': 'MAL_OS1_368',
#    'height': '25',
#    'left': '920',
#    'rotation': '',
#    'top': '360',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_376': {'shape307': {'element': 'MAL_OS1_376',
#    'height': '10',
#    'left': '1415',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '50'},
#   'shape317': {'element': 'MAL_OS1_376',
#    'height': '10',
#    'left': '1465',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '120'},
#   'shape333': {'element': 'MAL_OS1_376',
#    'height': '10',
#    'left': '1465',
#    'rotation': '',
#    'top': '110',
#    'type': 'Line',
#    'width': '30'},
#   'shape579': {'element': 'MAL_OS1_376',
#    'height': '30',
#    'left': '1465',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '15'}},
#  'MAL_OS1_417': {'shape115': {'element': 'MAL_OS1_417',
#    'height': '10',
#    'left': '125',
#    'rotation': '',
#    'top': '845',
#    'type': 'Line',
#    'width': '80'},
#   'shape269': {'element': 'MAL_OS1_417',
#    'height': '15',
#    'left': '225',
#    'rotation': '',
#    'top': '845',
#    'type': 'Line',
#    'width': '170'},
#   'shape274': {'element': 'MAL_OS1_417',
#    'height': '10',
#    'left': '395',
#    'rotation': '',
#    'top': '845',
#    'type': 'Line',
#    'width': '50'},
#   'shape276': {'element': 'MAL_OS1_417',
#    'height': '10',
#    'left': '395',
#    'rotation': '',
#    'top': '785',
#    'type': 'Line',
#    'width': '50'},
#   'shape277': {'element': 'MAL_OS1_417',
#    'height': '10',
#    'left': '395',
#    'rotation': '',
#    'top': '815',
#    'type': 'Line',
#    'width': '50'},
#   'shape551': {'element': 'MAL_OS1_417',
#    'height': '30',
#    'left': '395',
#    'rotation': '',
#    'top': '815',
#    'type': 'Line',
#    'width': '10'},
#   'shape552': {'element': 'MAL_OS1_417',
#    'height': '30',
#    'left': '395',
#    'rotation': '',
#    'top': '785',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_483': {'shape112': {'element': 'MAL_OS1_483',
#    'height': '10',
#    'left': '125',
#    'rotation': '',
#    'top': '630',
#    'type': 'Line',
#    'width': '80'},
#   'shape262': {'element': 'MAL_OS1_483',
#    'height': '10',
#    'left': '275',
#    'rotation': '',
#    'top': '660',
#    'type': 'Line',
#    'width': '50'},
#   'shape266': {'element': 'MAL_OS1_483',
#    'height': '15',
#    'left': '225',
#    'rotation': '',
#    'top': '630',
#    'type': 'Line',
#    'width': '50'},
#   'shape271': {'element': 'MAL_OS1_483',
#    'height': '10',
#    'left': '275',
#    'rotation': '',
#    'top': '630',
#    'type': 'Line',
#    'width': '120'},
#   'shape580': {'element': 'MAL_OS1_483',
#    'height': '30',
#    'left': '275',
#    'rotation': '',
#    'top': '630',
#    'type': 'Line',
#    'width': '10'},
#   'shape627': {'element': 'MAL_OS1_483',
#    'height': '10',
#    'left': '395',
#    'rotation': '',
#    'top': '630',
#    'type': 'Line',
#    'width': '365'},
#   'shape659': {'element': 'MAL_OS1_483',
#    'height': '10',
#    'left': '395',
#    'rotation': '',
#    'top': '660',
#    'type': 'Line',
#    'width': '50'},
#   'shape661': {'element': 'MAL_OS1_483',
#    'height': '30',
#    'left': '395',
#    'rotation': '',
#    'top': '630',
#    'type': 'Line',
#    'width': '10'},
#   'shape698': {'element': 'MAL_OS1_483',
#    'height': '30',
#    'left': '760',
#    'rotation': '',
#    'top': '630',
#    'type': 'Line',
#    'width': '10'},
#   'shape699': {'element': 'MAL_OS1_483',
#    'height': '10',
#    'left': '760',
#    'rotation': '',
#    'top': '660',
#    'type': 'Line',
#    'width': '105'}},
#  'MAL_OS1_491': {'shape116': {'element': 'MAL_OS1_491',
#    'height': '10',
#    'left': '125',
#    'rotation': '',
#    'top': '730',
#    'type': 'Line',
#    'width': '80'},
#   'shape341': {'element': 'MAL_OS1_491',
#    'height': '10',
#    'left': '225',
#    'rotation': '',
#    'top': '730',
#    'type': 'Line',
#    'width': '535'},
#   'shape692': {'element': 'MAL_OS1_491',
#    'height': '10',
#    'left': '760',
#    'rotation': '',
#    'top': '695',
#    'type': 'Line',
#    'width': '105'},
#   'shape693': {'element': 'MAL_OS1_491',
#    'height': '35',
#    'left': '760',
#    'rotation': '',
#    'top': '695',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_5002': {'shape404': {'element': 'MAL_OS1_5002',
#    'height': '10',
#    'left': '1460',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '50'},
#   'shape405': {'element': 'MAL_OS1_5002',
#    'height': '10',
#    'left': '1460',
#    'rotation': '',
#    'top': '575',
#    'type': 'Line',
#    'width': '50'},
#   'shape406': {'element': 'MAL_OS1_5002',
#    'height': '10',
#    'left': '1510',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '50'},
#   'shape407': {'element': 'MAL_OS1_5002',
#    'height': '10',
#    'left': '1560',
#    'rotation': '',
#    'top': '455',
#    'type': 'Line',
#    'width': '50'},
#   'shape408': {'element': 'MAL_OS1_5002',
#    'height': '10',
#    'left': '1560',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '100'},
#   'shape409': {'element': 'MAL_OS1_5002',
#    'height': '10',
#    'left': '1660',
#    'rotation': '',
#    'top': '455',
#    'type': 'Line',
#    'width': '50'},
#   'shape410': {'element': 'MAL_OS1_5002',
#    'height': '15',
#    'left': '1660',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '125'},
#   'shape608': {'element': 'MAL_OS1_5002',
#    'height': '150',
#    'left': '1510',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '10'},
#   'shape609': {'element': 'MAL_OS1_5002',
#    'height': '30',
#    'left': '1560',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '10'},
#   'shape610': {'element': 'MAL_OS1_5002',
#    'height': '30',
#    'left': '1660',
#    'rotation': '',
#    'top': '425',
#    'type': 'Line',
#    'width': '10'}},
#  'MAL_OS1_7279': {'shape335': {'element': 'MAL_OS1_7279',
#    'height': '10',
#    'left': '1605',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '30'}},
#  'MAL_OS1_7280': {'shape226': {'element': 'MAL_OS1_7280',
#    'height': '10',
#    'left': '1655',
#    'rotation': '',
#    'top': '110',
#    'type': 'Line',
#    'width': '30'},
#   'shape336': {'element': 'MAL_OS1_7280',
#    'height': '10',
#    'left': '1655',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '30'},
#   'shape337': {'element': 'MAL_OS1_7280',
#    'height': '10',
#    'left': '1715',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '70'},
#   'shape385': {'element': 'MAL_OS1_7280',
#    'height': '10',
#    'left': '1685',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '30'},
#   'shape534': {'element': 'MAL_OS1_7280',
#    'height': '30',
#    'left': '1685',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '10'},
#   'shape536': {'element': 'MAL_OS1_7280',
#    'height': '30',
#    'left': '1715',
#    'rotation': '',
#    'top': '80',
#    'type': 'Line',
#    'width': '10'}},
#  'MAV_OS1_013_012': {'shape480': {'element': 'MAV_OS1_013_012',
#    'height': '10',
#    'left': '1580',
#    'rotation': '',
#    'top': '75',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_013_013': {'shape481': {'element': 'MAV_OS1_013_013',
#    'height': '10',
#    'left': '1630',
#    'rotation': '',
#    'top': '75',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_013_014': {'shape433': {'element': 'MAV_OS1_013_014',
#    'height': '10',
#    'left': '1630',
#    'rotation': '',
#    'top': '105',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_013_015': {'shape442': {'element': 'MAV_OS1_013_015',
#    'height': '10',
#    'left': '1700',
#    'rotation': '270',
#    'top': '115',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_014_003': {'shape519': {'element': 'MAV_OS1_014_003',
#    'height': '10',
#    'left': '1705',
#    'rotation': '',
#    'top': '450',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_014_004': {'shape479': {'element': 'MAV_OS1_014_004',
#    'height': '10',
#    'left': '1485',
#    'rotation': '',
#    'top': '105',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_017_024': {'shape444': {'element': 'MAV_OS1_017_024',
#    'height': '10',
#    'left': '365',
#    'rotation': '',
#    'top': '400',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_006': {'shape467': {'element': 'MAV_OS1_018_006',
#    'height': '10',
#    'left': '1270',
#    'rotation': '',
#    'top': '75',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_007': {'shape462': {'element': 'MAV_OS1_018_007',
#    'height': '10',
#    'left': '1125',
#    'rotation': '',
#    'top': '85',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_008': {'shape463': {'element': 'MAV_OS1_018_008',
#    'height': '10',
#    'left': '1125',
#    'rotation': '',
#    'top': '295',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_009': {'shape476': {'element': 'MAV_OS1_018_009',
#    'height': '10',
#    'left': '1270',
#    'rotation': '',
#    'top': '280',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_011': {'shape681': {'element': 'MAV_OS1_018_011',
#    'height': '10',
#    'left': '905',
#    'rotation': '270',
#    'top': '390',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_013': {'shape689': {'element': 'MAV_OS1_018_013',
#    'height': '10',
#    'left': '865',
#    'rotation': '0',
#    'top': '420',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_038': {'shape472': {'element': 'MAV_OS1_018_038',
#    'height': '10',
#    'left': '1375',
#    'rotation': '',
#    'top': '670',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_042': {'shape470': {'element': 'MAV_OS1_018_042',
#    'height': '10',
#    'left': '1085',
#    'rotation': '',
#    'top': '685',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_043': {'shape468': {'element': 'MAV_OS1_018_043',
#    'height': '10',
#    'left': '1085',
#    'rotation': '',
#    'top': '840',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_065': {'shape494': {'element': 'MAV_OS1_018_065',
#    'height': '10',
#    'left': '495',
#    'rotation': '',
#    'top': '500',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_067': {'shape477': {'element': 'MAV_OS1_018_067',
#    'height': '10',
#    'left': '1390',
#    'rotation': '',
#    'top': '75',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_071': {'shape475': {'element': 'MAV_OS1_018_071',
#    'height': '10',
#    'left': '655',
#    'rotation': '',
#    'top': '125',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_072': {'shape465': {'element': 'MAV_OS1_018_072',
#    'height': '10',
#    'left': '655',
#    'rotation': '',
#    'top': '85',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_073': {'shape493': {'element': 'MAV_OS1_018_073',
#    'height': '10',
#    'left': '380',
#    'rotation': '',
#    'top': '125',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_074': {'shape483': {'element': 'MAV_OS1_018_074',
#    'height': '10',
#    'left': '655',
#    'rotation': '',
#    'top': '165',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_075': {'shape484': {'element': 'MAV_OS1_018_075',
#    'height': '10',
#    'left': '655',
#    'rotation': '',
#    'top': '205',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_100': {'shape690': {'element': 'MAV_OS1_018_100',
#    'height': '10',
#    'left': '780',
#    'rotation': '0',
#    'top': '450',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_104': {'shape447': {'element': 'MAV_OS1_018_104',
#    'height': '10',
#    'left': '620',
#    'rotation': '',
#    'top': '500',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_106': {'shape527': {'element': 'MAV_OS1_018_106',
#    'height': '10',
#    'left': '1390',
#    'rotation': '',
#    'top': '135',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_107': {'shape529': {'element': 'MAV_OS1_018_107',
#    'height': '10',
#    'left': '1390',
#    'rotation': '',
#    'top': '215',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_108': {'shape439': {'element': 'MAV_OS1_018_108',
#    'height': '10',
#    'left': '945',
#    'rotation': '',
#    'top': '125',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_109': {'shape438': {'element': 'MAV_OS1_018_109',
#    'height': '10',
#    'left': '945',
#    'rotation': '',
#    'top': '85',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_110': {'shape461': {'element': 'MAV_OS1_018_110',
#    'height': '10',
#    'left': '945',
#    'rotation': '',
#    'top': '165',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_111': {'shape464': {'element': 'MAV_OS1_018_111',
#    'height': '10',
#    'left': '945',
#    'rotation': '',
#    'top': '205',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_114': {'shape485': {'element': 'MAV_OS1_018_114',
#    'height': '10',
#    'left': '865',
#    'rotation': '',
#    'top': '355',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_115': {'shape486': {'element': 'MAV_OS1_018_115',
#    'height': '10',
#    'left': '865',
#    'rotation': '',
#    'top': '325',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_116': {'shape488': {'element': 'MAV_OS1_018_116',
#    'height': '10',
#    'left': '865',
#    'rotation': '',
#    'top': '265',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_117': {'shape487': {'element': 'MAV_OS1_018_117',
#    'height': '10',
#    'left': '865',
#    'rotation': '',
#    'top': '295',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_130': {'shape490': {'element': 'MAV_OS1_018_130',
#    'height': '10',
#    'left': '770',
#    'rotation': '',
#    'top': '355',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_134': {'shape492': {'element': 'MAV_OS1_018_134',
#    'height': '10',
#    'left': '665',
#    'rotation': '',
#    'top': '265',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_136': {'shape473': {'element': 'MAV_OS1_018_136',
#    'height': '10',
#    'left': '1375',
#    'rotation': '',
#    'top': '825',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_141': {'shape491': {'element': 'MAV_OS1_018_141',
#    'height': '10',
#    'left': '735',
#    'rotation': '',
#    'top': '325',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_018_172': {'shape691': {'element': 'MAV_OS1_018_172',
#    'height': '10',
#    'left': '780',
#    'rotation': '0',
#    'top': '495',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_019_004': {'shape518': {'element': 'MAV_OS1_019_004',
#    'height': '10',
#    'left': '1605',
#    'rotation': '',
#    'top': '450',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_021_047': {'shape660': {'element': 'MAV_OS1_021_047',
#    'height': '10',
#    'left': '440',
#    'rotation': '',
#    'top': '655',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_021_117': {'shape458': {'element': 'MAV_OS1_021_117',
#    'height': '10',
#    'left': '440',
#    'rotation': '',
#    'top': '780',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_021_122': {'shape457': {'element': 'MAV_OS1_021_122',
#    'height': '10',
#    'left': '440',
#    'rotation': '',
#    'top': '840',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_021_140': {'shape459': {'element': 'MAV_OS1_021_140',
#    'height': '10',
#    'left': '440',
#    'rotation': '',
#    'top': '810',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_033': {'shape512': {'element': 'MAV_OS1_022_033',
#    'height': '10',
#    'left': '935',
#    'rotation': '',
#    'top': '495',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_057': {'shape513': {'element': 'MAV_OS1_022_057',
#    'height': '10',
#    'left': '935',
#    'rotation': '',
#    'top': '520',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_059': {'shape516': {'element': 'MAV_OS1_022_059',
#    'height': '10',
#    'left': '1435',
#    'rotation': '',
#    'top': '570',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_060': {'shape514': {'element': 'MAV_OS1_022_060',
#    'height': '10',
#    'left': '1125',
#    'rotation': '',
#    'top': '585',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_061': {'shape510': {'element': 'MAV_OS1_022_061',
#    'height': '10',
#    'left': '975',
#    'rotation': '90',
#    'top': '555',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_062': {'shape506': {'element': 'MAV_OS1_022_062',
#    'height': '10',
#    'left': '1125',
#    'rotation': '',
#    'top': '435',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_063': {'shape650': {'element': 'MAV_OS1_022_063',
#    'height': '10',
#    'left': '920',
#    'rotation': '0',
#    'top': '585',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_064': {'shape649': {'element': 'MAV_OS1_022_064',
#    'height': '10',
#    'left': '860',
#    'rotation': '0',
#    'top': '585',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_065': {'shape694': {'element': 'MAV_OS1_022_065',
#    'height': '10',
#    'left': '920',
#    'rotation': '',
#    'top': '690',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_066': {'shape696': {'element': 'MAV_OS1_022_066',
#    'height': '10',
#    'left': '920',
#    'rotation': '',
#    'top': '655',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_067': {'shape642': {'element': 'MAV_OS1_022_067',
#    'height': '10',
#    'left': '860',
#    'rotation': '',
#    'top': '620',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_068': {'shape640': {'element': 'MAV_OS1_022_068',
#    'height': '10',
#    'left': '860',
#    'rotation': '',
#    'top': '690',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_069': {'shape641': {'element': 'MAV_OS1_022_069',
#    'height': '10',
#    'left': '860',
#    'rotation': '',
#    'top': '655',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_072': {'shape511': {'element': 'MAV_OS1_022_072',
#    'height': '10',
#    'left': '935',
#    'rotation': '',
#    'top': '470',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_073': {'shape508': {'element': 'MAV_OS1_022_073',
#    'height': '10',
#    'left': '1435',
#    'rotation': '',
#    'top': '420',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_074': {'shape509': {'element': 'MAV_OS1_022_074',
#    'height': '10',
#    'left': '1435',
#    'rotation': '',
#    'top': '450',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_022_162': {'shape517': {'element': 'MAV_OS1_022_162',
#    'height': '10',
#    'left': '1435',
#    'rotation': '',
#    'top': '600',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_024_031': {'shape455': {'element': 'MAV_OS1_024_031',
#    'height': '10',
#    'left': '320',
#    'rotation': '',
#    'top': '655',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_053_027': {'shape418': {'element': 'MAV_OS1_053_027',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '500',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_054_002': {'shape414': {'element': 'MAV_OS1_054_002',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '85',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_054_017': {'shape415': {'element': 'MAV_OS1_054_017',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '175',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_054_021': {'shape416': {'element': 'MAV_OS1_054_021',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '295',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_054_026': {'shape417': {'element': 'MAV_OS1_054_026',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '400',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_059_006': {'shape423': {'element': 'MAV_OS1_059_006',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '840',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_062_004': {'shape421': {'element': 'MAV_OS1_062_004',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '625',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'MAV_OS1_062_013': {'shape422': {'element': 'MAV_OS1_062_013',
#    'height': '10',
#    'left': '200',
#    'rotation': '',
#    'top': '725',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'OMAVALVE': {'shape469': {'element': 'OMAVALVE',
#    'height': '10',
#    'left': '1195',
#    'rotation': '',
#    'top': '795',
#    'type': 'ValveMan',
#    'width': '30'},
#   'shape471': {'element': 'OMAVALVE',
#    'height': '10',
#    'left': '1195',
#    'rotation': '',
#    'top': '640',
#    'type': 'ValveMan',
#    'width': '30'},
#   'shape507': {'element': 'OMAVALVE',
#    'height': '10',
#    'left': '1195',
#    'rotation': '',
#    'top': '390',
#    'type': 'ValveMan',
#    'width': '30'},
#   'shape515': {'element': 'OMAVALVE',
#    'height': '10',
#    'left': '1195',
#    'rotation': '',
#    'top': '540',
#    'type': 'ValveMan',
#    'width': '30'}},
#  'TK53104': {'shape050': {'element': 'TK53104',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '40',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'TK53105': {'shape051': {'element': 'TK53105',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '145',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'TK53106': {'shape052': {'element': 'TK53106',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '250',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'TK53107': {'shape053': {'element': 'TK53107',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '355',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'TK53109': {'shape054': {'element': 'TK53109',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '465',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'TK53110': {'shape055': {'element': 'TK53110',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '575',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'TK53111': {'shape056': {'element': 'TK53111',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '690',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'TK5397': {'shape057': {'element': 'TK5397',
#    'height': '80',
#    'left': '10',
#    'rotation': '',
#    'top': '790',
#    'type': 'TankNozzle',
#    'width': '125'}},
#  'UN20200_WAXY': {'shape794': {'element': 'UN20200_WAXY',
#    'height': '18',
#    'left': '1780',
#    'rotation': '',
#    'top': '820',
#    'type': 'BP',
#    'width': '26'}},
#  'UN2400_WAXY': {'shape792': {'element': 'UN2400_WAXY',
#    'height': '18',
#    'left': '1780',
#    'rotation': '',
#    'top': '70',
#    'type': 'BP',
#    'width': '26'}},
#  'UN2600_WAXY': {'shape793': {'element': 'UN2600_WAXY',
#    'height': '18',
#    'left': '1780',
#    'rotation': '',
#    'top': '415',
#    'type': 'BP',
#    'width': '26'}},
#  '_P53102A': {'shape273': {'element': '_P53102A',
#    'height': '35',
#    'left': '1195',
#    'rotation': '',
#    'top': '75',
#    'type': 'CPump',
#    'width': '35'}},
#  '_P53102AL': {'PseudoValve039': {'element': '_P53102AL',
#    'height': '11',
#    'left': '1175',
#    'rotation': '',
#    'top': '85',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P53102AR': {'PseudoValve040': {'element': '_P53102AR',
#    'height': '11',
#    'left': '1240',
#    'rotation': '',
#    'top': '75',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P53102B': {'shape272': {'element': '_P53102B',
#    'height': '35',
#    'left': '1195',
#    'rotation': '',
#    'top': '280',
#    'type': 'CPump',
#    'width': '35'}},
#  '_P53102BL': {'PseudoValve041': {'element': '_P53102BL',
#    'height': '11',
#    'left': '1175',
#    'rotation': '',
#    'top': '295',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P53102BR': {'PseudoValve042': {'element': '_P53102BR',
#    'height': '11',
#    'left': '1240',
#    'rotation': '',
#    'top': '280',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P53104A': {'shape278': {'element': '_P53104A',
#    'height': '35',
#    'left': '1193',
#    'rotation': '',
#    'top': '420',
#    'type': 'CPump',
#    'width': '35'}},
#  '_P53104AL': {'PseudoValve043': {'element': '_P53104AL',
#    'height': '11',
#    'left': '1175',
#    'rotation': '',
#    'top': '435',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P53104AR': {'PseudoValve044': {'element': '_P53104AR',
#    'height': '11',
#    'left': '1240',
#    'rotation': '',
#    'top': '420',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P53104B': {'shape279': {'element': '_P53104B',
#    'height': '35',
#    'left': '1195',
#    'rotation': '',
#    'top': '570',
#    'type': 'CPump',
#    'width': '35'}},
#  '_P53104BL': {'PseudoValve045': {'element': '_P53104BL',
#    'height': '11',
#    'left': '1175',
#    'rotation': '',
#    'top': '585',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P53104BR': {'PseudoValve046': {'element': '_P53104BR',
#    'height': '11',
#    'left': '1240',
#    'rotation': '',
#    'top': '570',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P5399A': {'shape308': {'element': '_P5399A',
#    'height': '35',
#    'left': '1195',
#    'rotation': '',
#    'top': '670',
#    'type': 'CPump',
#    'width': '35'}},
#  '_P5399AL': {'PseudoValve047': {'element': '_P5399AL',
#    'height': '11',
#    'left': '1175',
#    'rotation': '',
#    'top': '685',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P5399AR': {'PseudoValve048': {'element': '_P5399AR',
#    'height': '11',
#    'left': '1240',
#    'rotation': '',
#    'top': '670',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P5399B': {'shape309': {'element': '_P5399B',
#    'height': '35',
#    'left': '1195',
#    'rotation': '',
#    'top': '825',
#    'type': 'CPump',
#    'width': '35'}},
#  '_P5399BL': {'PseudoValve049': {'element': '_P5399BL',
#    'height': '11',
#    'left': '1175',
#    'rotation': '',
#    'top': '840',
#    'type': 'ValvePseudo',
#    'width': '11'}},
#  '_P5399BR': {'PseudoValve050': {'element': '_P5399BR',
#    'height': '11',
#    'left': '1235',
#    'rotation': '',
#    'top': '825',
#    'type': 'ValvePseudo',
#    'width': '11'}}}

# %%
elem['MAL_OS1_202']
# Out:
# {'shape111': {'element': 'MAL_OS1_202',
#   'height': '10',
#   'left': '130',
#   'rotation': '',
#   'top': '505',
#   'type': 'Line',
#   'width': '75'},
#  'shape254': {'element': 'MAL_OS1_202',
#   'height': '10',
#   'left': '225',
#   'rotation': '',
#   'top': '505',
#   'type': 'Line',
#   'width': '275'}}

# %%
for i in elem:
    for j in elem[i]:
        print('{:15} {:15} {:10}'.format(i,j,elem[i][j]['type']))
# Out:
# MAL_OS1_7280    shape385        Line
# MAL_OS1_7280    shape534        Line
# MAL_OS1_7280    shape226        Line
# MAL_OS1_7280    shape536        Line
# MAL_OS1_7280    shape336        Line
# MAL_OS1_7280    shape337        Line
# MAL_OS1_314     shape554        Line
# MAL_OS1_314     shape283        Line
# MAL_OS1_314     shape284        Line
# MAL_OS1_314     shape289        Line
# MAL_OS1_314     shape553        Line
# MAL_OS1_314     shape292        Line
# MAL_OS1_314     shape293        Line
# MAL_OS1_314     shape587        Line
# MAL_OS1_314     shape297        Line
# MAL_OS1_314     shape588        Line
# MAV_OS1_054_002 shape414        ValveMan
# _P53102A        shape273        CPump
# TK53104         shape050        TankNozzle
# TK53105         shape051        TankNozzle
# TK53106         shape052        TankNozzle
# TK53107         shape053        TankNozzle
# TK53109         shape054        TankNozzle
# TK53110         shape055        TankNozzle
# TK53111         shape056        TankNozzle
# TK5397          shape057        TankNozzle
# MAL_OS1_218     shape104        Line
# MAL_OS1_218     shape223        Line
# MAL_OS1_220     shape108        Line
# MAL_OS1_220     shape232        Line
# MAL_OS1_220     shape677        Line
# MAL_OS1_220     shape355        Line
# MAL_OS1_220     shape383        Line
# MAL_OS1_230     shape109        Line
# MAL_OS1_230     shape240        Line
# MAL_OS1_230     shape678        Line
# MAL_OS1_230     shape356        Line
# MAL_OS1_232     shape110        Line
# MAL_OS1_232     shape250        Line
# MAL_OS1_202     shape111        Line
# MAL_OS1_202     shape254        Line
# MAL_OS1_483     shape112        Line
# MAL_OS1_483     shape266        Line
# MAL_OS1_483     shape627        Line
# MAL_OS1_483     shape659        Line
# MAL_OS1_483     shape661        Line
# MAL_OS1_483     shape580        Line
# MAL_OS1_483     shape262        Line
# MAL_OS1_483     shape271        Line
# MAL_OS1_483     shape698        Line
# MAL_OS1_483     shape699        Line
# MAL_OS1_417     shape115        Line
# MAL_OS1_417     shape269        Line
# MAL_OS1_417     shape274        Line
# MAL_OS1_417     shape551        Line
# MAL_OS1_417     shape276        Line
# MAL_OS1_417     shape552        Line
# MAL_OS1_417     shape277        Line
# _P53102B        shape272        CPump
# MAL_OS1_360     shape310        Line
# MAL_OS1_360     shape316        Line
# MAL_OS1_360     shape574        Line
# MAL_OS1_360     shape322        Line
# UN2400_WAXY     shape792        BP
# UN2600_WAXY     shape793        BP
# MAL_OS1_359     shape392        Line
# MAL_OS1_359     shape390        Line
# MAL_OS1_359     shape391        Line
# MAL_OS1_359     shape607        Line
# UN20200_WAXY    shape794        BP
# MAV_OS1_054_017 shape415        ValveMan
# MAV_OS1_054_021 shape416        ValveMan
# MAV_OS1_054_026 shape417        ValveMan
# MAV_OS1_053_027 shape418        ValveMan
# MAV_OS1_062_004 shape421        ValveMan
# MAV_OS1_059_006 shape423        ValveMan
# MAV_OS1_017_024 shape444        ValveMan
# MAL_OS1_312     shape255        Line
# MAL_OS1_312     shape680        Line
# MAL_OS1_312     shape374        Line
# MAL_OS1_312     shape275        Line
# MAV_OS1_018_104 shape447        ValveMan
# MAV_OS1_021_122 shape457        ValveMan
# MAV_OS1_021_117 shape458        ValveMan
# MAV_OS1_021_140 shape459        ValveMan
# _P53104A        shape278        CPump
# _P53104B        shape279        CPump
# MAL_OS1_271     shape281        Line
# MAV_OS1_018_007 shape462        ValveMan
# MAL_OS1_272     shape282        Line
# MAV_OS1_018_008 shape463        ValveMan
# MAL_OS1_2432    shape301        Line
# MAV_OS1_022_062 shape506        ValveMan
# MAL_OS1_2431    shape303        Line
# MAL_OS1_2431    shape563        Line
# MAL_OS1_2431    shape304        Line
# MAL_OS1_2431    shape334        Line
# MAL_OS1_2431    shape566        Line
# MAL_OS1_2431    shape371        Line
# MAL_OS1_2431    shape568        Line
# MAL_OS1_2431    shape393        Line
# MAL_OS1_2431    shape569        Line
# MAL_OS1_2431    shape394        Line
# MAL_OS1_2431    shape570        Line
# OMAVALVE        shape507        ValveMan
# OMAVALVE        shape515        ValveMan
# OMAVALVE        shape469        ValveMan
# OMAVALVE        shape471        ValveMan
# MAL_OS1_2433    shape305        Line
# MAL_OS1_2433    shape564        Line
# MAL_OS1_2433    shape314        Line
# MAL_OS1_2433    shape315        Line
# MAL_OS1_2433    shape329        Line
# MAL_OS1_2433    shape565        Line
# MAL_OS1_2433    shape330        Line
# MAV_OS1_022_073 shape508        ValveMan
# MAV_OS1_022_074 shape509        ValveMan
# MAV_OS1_022_061 shape510        ValveMan
# MAV_OS1_022_072 shape511        ValveMan
# MAV_OS1_022_033 shape512        ValveMan
# MAV_OS1_022_057 shape513        ValveMan
# MAL_OS1_2428    shape395        Line
# MAV_OS1_022_060 shape514        ValveMan
# MAL_OS1_2426    shape396        Line
# MAL_OS1_2426    shape571        Line
# MAL_OS1_2426    shape397        Line
# MAL_OS1_2426    shape399        Line
# MAL_OS1_2426    shape584        Line
# MAL_OS1_2426    shape643        Line
# MAL_OS1_2426    shape644        Line
# MAL_OS1_2426    shape645        Line
# MAL_OS1_2426    shape646        Line
# MAL_OS1_2426    shape647        Line
# MAL_OS1_2426    shape648        Line
# MAL_OS1_2426    shape668        Line
# MAL_OS1_2424    shape398        Line
# MAL_OS1_2424    shape577        Line
# MAL_OS1_2424    shape400        Line
# MAL_OS1_2424    shape401        Line
# MAL_OS1_2424    shape592        Line
# MAL_OS1_2424    shape384        Line
# MAL_OS1_2424    shape402        Line
# MAV_OS1_022_059 shape516        ValveMan
# MAL_OS1_5002    shape404        Line
# MAL_OS1_5002    shape608        Line
# MAL_OS1_5002    shape405        Line
# MAL_OS1_5002    shape406        Line
# MAL_OS1_5002    shape609        Line
# MAL_OS1_5002    shape407        Line
# MAL_OS1_5002    shape408        Line
# MAL_OS1_5002    shape610        Line
# MAL_OS1_5002    shape409        Line
# MAL_OS1_5002    shape410        Line
# MAV_OS1_019_004 shape518        ValveMan
# MAV_OS1_014_003 shape519        ValveMan
# MAL_OS1_246     shape523        Line
# MAL_OS1_246     shape679        Line
# MAL_OS1_246     shape357        Line
# MAL_OS1_325     shape651        Line
# MAL_OS1_325     shape682        Line
# MAL_OS1_325     shape377        Line
# MAL_OS1_325     shape378        Line
# MAL_OS1_325     shape379        Line
# MAL_OS1_325     shape683        Line
# MAL_OS1_325     shape684        Line
# MAL_OS1_325     shape686        Line
# MAL_OS1_325     shape382        Line
# _P5399A         shape308        CPump
# _P5399B         shape309        CPump
# MAL_OS1_289     shape312        Line
# MAL_OS1_289     shape313        Line
# MAL_OS1_289     shape572        Line
# MAL_OS1_289     shape318        Line
# MAV_OS1_018_043 shape468        ValveMan
# MAL_OS1_288     shape319        Line
# MAL_OS1_288     shape573        Line
# MAL_OS1_288     shape320        Line
# MAL_OS1_288     shape321        Line
# MAV_OS1_018_042 shape470        ValveMan
# MAL_OS1_287     shape323        Line
# MAL_OS1_287     shape324        Line
# MAL_OS1_287     shape575        Line
# MAL_OS1_287     shape325        Line
# MAL_OS1_286     shape326        Line
# MAL_OS1_286     shape576        Line
# MAL_OS1_286     shape327        Line
# MAL_OS1_286     shape328        Line
# MAV_OS1_018_038 shape472        ValveMan
# MAV_OS1_018_136 shape473        ValveMan
# MAL_OS1_270     shape286        Line
# MAV_OS1_018_006 shape467        ValveMan
# MAL_OS1_273     shape287        Line
# MAV_OS1_018_009 shape476        ValveMan
# MAL_OS1_313     shape288        Line
# MAL_OS1_313     shape302        Line
# MAL_OS1_313     shape558        Line
# MAL_OS1_313     shape306        Line
# MAL_OS1_313     shape331        Line
# MAL_OS1_313     shape559        Line
# MAL_OS1_313     shape332        Line
# MAL_OS1_313     shape578        Line
# MAV_OS1_018_067 shape477        ValveMan
# MAV_OS1_018_106 shape527        ValveMan
# MAV_OS1_018_107 shape529        ValveMan
# MAL_OS1_376     shape307        Line
# MAL_OS1_376     shape317        Line
# MAL_OS1_376     shape579        Line
# MAL_OS1_376     shape333        Line
# MAV_OS1_014_004 shape479        ValveMan
# MAV_OS1_013_012 shape480        ValveMan
# MAL_OS1_7279    shape335        Line
# MAV_OS1_013_013 shape481        ValveMan
# MAV_OS1_013_014 shape433        ValveMan
# MAV_OS1_013_015 shape442        ValveMan
# MAV_OS1_021_047 shape660        ValveMan
# MAV_OS1_024_031 shape455        ValveMan
# MAL_OS1_491     shape116        Line
# MAL_OS1_491     shape341        Line
# MAL_OS1_491     shape692        Line
# MAL_OS1_491     shape693        Line
# MAV_OS1_062_013 shape422        ValveMan
# MAV_OS1_022_068 shape640        ValveMan
# MAV_OS1_022_069 shape641        ValveMan
# MAV_OS1_022_067 shape642        ValveMan
# MAV_OS1_022_064 shape649        ValveMan
# _P53102AL       PseudoValve039  ValvePseudo
# _P53102AR       PseudoValve040  ValvePseudo
# _P53102BL       PseudoValve041  ValvePseudo
# _P53102BR       PseudoValve042  ValvePseudo
# _P53104AL       PseudoValve043  ValvePseudo
# _P53104AR       PseudoValve044  ValvePseudo
# _P53104BL       PseudoValve045  ValvePseudo
# _P53104BR       PseudoValve046  ValvePseudo
# _P5399AL        PseudoValve047  ValvePseudo
# _P5399AR        PseudoValve048  ValvePseudo
# _P5399BL        PseudoValve049  ValvePseudo
# _P5399BR        PseudoValve050  ValvePseudo
# MAL_OS1_368     shape619        Line
# MAL_OS1_368     shape589        Line
# MAL_OS1_368     shape359        Line
# MAL_OS1_368     shape361        Line
# MAL_OS1_368     shape363        Line
# MAL_OS1_368     shape365        Line
# MAL_OS1_368     shape590        Line
# MAL_OS1_368     shape591        Line
# MAV_OS1_022_063 shape650        ValveMan
# MAV_OS1_018_109 shape438        ValveMan
# MAV_OS1_018_108 shape439        ValveMan
# MAV_OS1_018_110 shape461        ValveMan
# MAV_OS1_018_111 shape464        ValveMan
# MAL_OS1_323     shape311        Line
# MAL_OS1_323     shape617        Line
# MAL_OS1_323     shape622        Line
# MAL_OS1_323     shape637        Line
# MAL_OS1_323     shape350        Line
# MAL_OS1_323     shape638        Line
# MAL_OS1_323     shape364        Line
# MAL_OS1_323     shape369        Line
# MAL_OS1_323     shape370        Line
# MAL_OS1_323     shape372        Line
# MAL_OS1_323     shape376        Line
# MAL_OS1_321     shape347        Line
# MAL_OS1_321     shape655        Line
# MAL_OS1_321     shape352        Line
# MAL_OS1_321     shape672        Line
# MAL_OS1_321     shape673        Line
# MAL_OS1_321     shape362        Line
# MAL_OS1_321     shape367        Line
# MAL_OS1_321     shape368        Line
# MAL_OS1_326     shape348        Line
# MAL_OS1_326     shape674        Line
# MAL_OS1_326     shape675        Line
# MAL_OS1_326     shape353        Line
# MAL_OS1_326     shape360        Line
# MAL_OS1_326     shape366        Line
# MAL_OS1_326     shape375        Line
# MAL_OS1_327     shape349        Line
# MAL_OS1_327     shape676        Line
# MAL_OS1_327     shape354        Line
# MAL_OS1_327     shape358        Line
# MAL_OS1_327     shape373        Line
# MAV_OS1_018_072 shape465        ValveMan
# MAV_OS1_018_071 shape475        ValveMan
# MAV_OS1_018_074 shape483        ValveMan
# MAV_OS1_018_075 shape484        ValveMan
# MAV_OS1_018_114 shape485        ValveMan
# MAV_OS1_018_115 shape486        ValveMan
# MAV_OS1_018_117 shape487        ValveMan
# MAV_OS1_018_116 shape488        ValveMan
# MAV_OS1_018_130 shape490        ValveMan
# MAV_OS1_018_141 shape491        ValveMan
# MAV_OS1_018_134 shape492        ValveMan
# MAV_OS1_018_011 shape681        ValveMan
# MAL_OS1_2427    shape380        Line
# MAV_OS1_018_013 shape689        ValveMan
# MAV_OS1_018_100 shape690        ValveMan
# MAV_OS1_018_172 shape691        ValveMan
# MAV_OS1_018_073 shape493        ValveMan
# MAV_OS1_022_065 shape694        ValveMan
# MAL_OS1_2430    shape695        Line
# MAL_OS1_2430    shape697        Line
# MAV_OS1_022_066 shape696        ValveMan
# MAV_OS1_022_162 shape517        ValveMan
# MAV_OS1_018_065 shape494        ValveMan

# %%
result2 = {}
for i in total:
    temp = {}
    temp['TOP'] = total[i]['TOP']
    temp['LEFT'] = total[i]['LEFT']
    temp['HEIGHT'] = total[i]['HEIGHT']
    temp['LEFWIDTHT'] = total[i]['WIDTH']
    if 'Rotation' in total[i]:
        temp['rotation'] = total[i]['Rotation']
    result2[i] = temp
    
for j in result2:
    if 'rotation' in result2[j]:
        print(j,result2[j]['rotation'])
# Out:
# shape510 90
# shape442 270
# shape649 0
# shape650 0
# shape681 270
# shape689 0
# shape690 0
# shape691 0

# %%
total['shape033']
# Out:
# {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#  'FONT-FAMILY': 'Arial',
#  'FONT-SIZE': '0px',
#  'FONT-STYLE': 'normal',
#  'FONT-WEIGHT': '400',
#  'HEIGHT': '18px',
#  'Height': '18',
#  'LEFT': '1810px',
#  'POSITION': 'absolute',
#  'T?T': 'U-2600',
#  'TEXT-DECORATION': 'none',
#  'TOP': '415px',
#  'WIDTH': '95px',
#  'Width': '95',
#  'fillColorBlink': 'False',
#  'id': 'shape033',
#  'lineColorBlink': 'False',
#  'no': 53}
