# %%
from bs4 import BeautifulSoup
with open('work_test.htm') as file:
    data = file.read()
soup = BeautifulSoup(data,'html.parser')

main = soup.find('div', attrs={'id':'Page'})
divs = main.find_all('div')

len(divs)

# %%
divs[0]['id']
# Out:
# 'shape385'

# %%
divs[0]['parameters']
# Out:
# 'Point?element:MAL_OS1_7280;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_013_014~MAV_OS1_013_013;Value?EndPoint2:;'

# %%
divs[0].find('parameters')

# %%
len(main)
# Out:
# 786

# %%
divst = main.findAll('div',attrs = {'style':True})
len(divst)
# Out:
# 1183

# %%
divpm = main.findAll('div',attrs = {'parameters':True})
len(divpm)
# Out:
# 337

# %%
divpm = main.findAll('div',attrs = {'parameters':True})
[d['id'] for d in divpm]
# Out:
# ['shape385',
#  'shape554',
#  'shape001',
#  'tfgPlanningData',
#  'tfgSelectTimeout',
#  'tfgOperDataReInit',
#  'tfgOffDisplayEndPoints',
#  'shape015',
#  'shape027',
#  'shape414',
#  'shape273',
#  'shape050',
#  'shape050_shaTank',
#  'shape050_shaTankService',
#  'shape023',
#  'shape051',
#  'shape051_shaTank',
#  'shape051_shaTankService',
#  'shape024',
#  'shape052',
#  'shape052_shaTank',
#  'shape052_shaTankService',
#  'shape025',
#  'shape053',
#  'shape053_shaTank',
#  'shape053_shaTankService',
#  'shape028',
#  'shape054',
#  'shape054_shaTank',
#  'shape054_shaTankService',
#  'shape029',
#  'shape055',
#  'shape055_shaTank',
#  'shape055_shaTankService',
#  'shape030',
#  'shape056',
#  'shape056_shaTank',
#  'shape056_shaTankService',
#  'shape031',
#  'shape057',
#  'shape057_shaTank',
#  'shape057_shaTankService',
#  'shape032',
#  'shape104',
#  'shape108',
#  'shape109',
#  'shape110',
#  'shape111',
#  'shape112',
#  'shape115',
#  'shape272',
#  'shape310',
#  'shape792',
#  'shape033',
#  'shape793',
#  'shape392',
#  'shape794',
#  'shape415',
#  'shape416',
#  'shape417',
#  'shape418',
#  'shape421',
#  'shape423',
#  'shape223',
#  'shape232',
#  'shape240',
#  'shape444',
#  'shape250',
#  'shape254',
#  'shape255',
#  'shape447',
#  'shape266',
#  'shape269',
#  'shape274',
#  'shape457',
#  'shape551',
#  'shape276',
#  'shape458',
#  'shape552',
#  'shape277',
#  'shape459',
#  'shape278',
#  'shape279',
#  'shape281',
#  'shape462',
#  'shape282',
#  'shape463',
#  'shape283',
#  'shape284',
#  'shape289',
#  'shape553',
#  'shape301',
#  'shape506',
#  'shape303',
#  'shape563',
#  'shape304',
#  'shape507',
#  'shape305',
#  'shape564',
#  'shape314',
#  'shape315',
#  'shape508',
#  'shape329',
#  'shape565',
#  'shape509',
#  'shape330',
#  'shape334',
#  'shape566',
#  'shape510',
#  'shape371',
#  'shape511',
#  'shape568',
#  'shape393',
#  'shape512',
#  'shape569',
#  'shape394',
#  'shape513',
#  'shape570',
#  'shape395',
#  'shape514',
#  'shape396',
#  'shape571',
#  'shape397',
#  'shape515',
#  'shape398',
#  'shape577',
#  'shape399',
#  'shape400',
#  'shape401',
#  'shape516',
#  'shape404',
#  'shape608',
#  'shape405',
#  'shape406',
#  'shape609',
#  'shape518',
#  'shape407',
#  'shape408',
#  'shape610',
#  'shape519',
#  'shape409',
#  'shape410',
#  'shape523',
#  'shape627',
#  'shape651',
#  'shape308',
#  'shape309',
#  'shape312',
#  'shape468',
#  'shape313',
#  'shape316',
#  'shape469',
#  'shape572',
#  'shape318',
#  'shape319',
#  'shape573',
#  'shape320',
#  'shape321',
#  'shape574',
#  'shape470',
#  'shape322',
#  'shape323',
#  'shape324',
#  'shape471',
#  'shape575',
#  'shape325',
#  'shape326',
#  'shape576',
#  'shape327',
#  'shape328',
#  'shape472',
#  'shape473',
#  'shape390',
#  'shape391',
#  'shape607',
#  'shape035',
#  'shape286',
#  'shape467',
#  'shape287',
#  'shape476',
#  'shape288',
#  'shape302',
#  'shape558',
#  'shape306',
#  'shape477',
#  'shape527',
#  'shape331',
#  'shape559',
#  'shape529',
#  'shape332',
#  'shape578',
#  'shape307',
#  'shape317',
#  'shape579',
#  'shape333',
#  'shape479',
#  'shape480',
#  'shape335',
#  'shape481',
#  'shape534',
#  'shape226',
#  'shape433',
#  'shape536',
#  'shape442',
#  'shape336',
#  'shape337',
#  'shape659',
#  'shape660',
#  'shape661',
#  'shape580',
#  'shape262',
#  'shape455',
#  'shape271',
#  'shape116',
#  'shape422',
#  'shape341',
#  'shape584',
#  'shape640',
#  'shape641',
#  'shape642',
#  'shape643',
#  'shape644',
#  'shape645',
#  'shape646',
#  'shape647',
#  'shape648',
#  'shape649',
#  'shape668',
#  'PseudoValve039',
#  'PseudoValve040',
#  'PseudoValve041',
#  'PseudoValve042',
#  'PseudoValve043',
#  'PseudoValve044',
#  'PseudoValve045',
#  'PseudoValve046',
#  'PseudoValve047',
#  'PseudoValve048',
#  'PseudoValve049',
#  'PseudoValve050',
#  'shape619',
#  'shape650',
#  'shape438',
#  'shape292',
#  'shape439',
#  'shape293',
#  'shape461',
#  'shape587',
#  'shape297',
#  'shape464',
#  'shape311',
#  'shape347',
#  'shape348',
#  'shape349',
#  'shape588',
#  'shape465',
#  'shape617',
#  'shape622',
#  'shape637',
#  'shape350',
#  'shape475',
#  'shape483',
#  'shape484',
#  'shape638',
#  'shape655',
#  'shape352',
#  'shape672',
#  'shape673',
#  'shape674',
#  'shape675',
#  'shape676',
#  'shape353',
#  'shape354',
#  'shape677',
#  'shape355',
#  'shape678',
#  'shape356',
#  'shape679',
#  'shape357',
#  'shape589',
#  'shape358',
#  'shape485',
#  'shape359',
#  'shape360',
#  'shape486',
#  'shape361',
#  'shape362',
#  'shape487',
#  'shape363',
#  'shape364',
#  'shape488',
#  'shape365',
#  'shape590',
#  'shape591',
#  'shape366',
#  'shape367',
#  'shape368',
#  'shape369',
#  'shape370',
#  'shape372',
#  'shape680',
#  'shape373',
#  'shape490',
#  'shape374',
#  'shape375',
#  'shape491',
#  'shape376',
#  'shape492',
#  'shape681',
#  'shape682',
#  'shape377',
#  'shape378',
#  'shape379',
#  'shape683',
#  'shape684',
#  'shape380',
#  'shape686',
#  'shape689',
#  'shape690',
#  'shape691',
#  'shape382',
#  'shape692',
#  'shape693',
#  'shape383',
#  'shape493',
#  'shape694',
#  'shape695',
#  'shape696',
#  'shape697',
#  'shape698',
#  'shape699',
#  'shape592',
#  'shape517',
#  'shape384',
#  'shape402',
#  'shape494',
#  'shape275']

# %%
# make total dictionary

divpm = main.findAll('div',attrs = {'parameters':True})
total = {}
for i,div in enumerate(divpm):
    total[div['id']] = {'id':i}
    param = {}
    for p in div['parameters'].split(';'):
        param.update(dict(zip(p.split(':')[::2], p.split(':')[1::2])))
    total[div['id']].update(param)
    style = {}
    for s in div['style'].split('; '):
        style.update(dict(zip(s.split(':')[::2], s.split(': ')[1::2])))
    total[div['id']].update(style)
total
# Out:
# {'PseudoValve039': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '85px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 228},
#  'PseudoValve040': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '75px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 229},
#  'PseudoValve041': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '295px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 230},
#  'PseudoValve042': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '280px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 231},
#  'PseudoValve043': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '435px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 232},
#  'PseudoValve044': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 233},
#  'PseudoValve045': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '585px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 234},
#  'PseudoValve046': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '570px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 235},
#  'PseudoValve047': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '685px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 236},
#  'PseudoValve048': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '670px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 237},
#  'PseudoValve049': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '840px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 238},
#  'PseudoValve050': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1235px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '825px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 239},
#  'shape001': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '29px',
#   'LEFT': '5px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '0px',
#   'WIDTH': '103px',
#   'id': 2},
#  'shape015': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '36px',
#   'LEFT': '0px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TEXT?ACTIVITY': 'CH',
#   'TEXT?AREA': '제품운영1과',
#   'TEXT?PRODUCT': 'WAXY',
#   'TEXT?TANK': '-',
#   'TOP': '0px',
#   'WIDTH': '1910px',
#   'id': 7},
#  'shape023': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53104',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31',
#   'TOP': '115px',
#   'WIDTH': '100px',
#   'id': 14},
#  'shape024': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53105',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-96S',
#   'TOP': '220px',
#   'WIDTH': '100px',
#   'id': 18},
#  'shape025': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53106',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-20',
#   'TOP': '325px',
#   'WIDTH': '100px',
#   'id': 22},
#  'shape027': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-2400',
#   'TEXT-DECORATION': 'none',
#   'TOP': '70px',
#   'WIDTH': '95px',
#   'id': 8},
#  'shape028': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53107',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-116',
#   'TOP': '430px',
#   'WIDTH': '100px',
#   'id': 26},
#  'shape029': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53109',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-480',
#   'TOP': '540px',
#   'WIDTH': '100px',
#   'id': 30},
#  'shape030': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31S',
#   'TOP': '650px',
#   'WIDTH': '100px',
#   'id': 34},
#  'shape031': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31S',
#   'TOP': '765px',
#   'WIDTH': '100px',
#   'id': 38},
#  'shape032': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK5397',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'Mix-W',
#   'TOP': '865px',
#   'WIDTH': '100px',
#   'id': 42},
#  'shape033': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-2600',
#   'TEXT-DECORATION': 'none',
#   'TOP': '415px',
#   'WIDTH': '95px',
#   'id': 53},
#  'shape035': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-20200',
#   'TEXT-DECORATION': 'none',
#   'TOP': '820px',
#   'WIDTH': '95px',
#   'id': 175},
#  'shape050': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53104',
#   'TEXT-DECORATION': 'none',
#   'TOP': '40px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 11},
#  'shape050_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 12},
#  'shape050_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 13},
#  'shape051': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53105',
#   'TEXT-DECORATION': 'none',
#   'TOP': '145px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 15},
#  'shape051_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 16},
#  'shape051_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 17},
#  'shape052': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53106',
#   'TEXT-DECORATION': 'none',
#   'TOP': '250px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 19},
#  'shape052_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 20},
#  'shape052_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 21},
#  'shape053': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53107',
#   'TEXT-DECORATION': 'none',
#   'TOP': '355px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 23},
#  'shape053_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 24},
#  'shape053_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 25},
#  'shape054': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53109',
#   'TEXT-DECORATION': 'none',
#   'TOP': '465px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 27},
#  'shape054_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 28},
#  'shape054_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 29},
#  'shape055': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TOP': '575px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 31},
#  'shape055_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 32},
#  'shape055_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 33},
#  'shape056': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53111',
#   'TEXT-DECORATION': 'none',
#   'TOP': '690px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 35},
#  'shape056_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 36},
#  'shape056_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 37},
#  'shape057': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK5397',
#   'TEXT-DECORATION': 'none',
#   'TOP': '790px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 39},
#  'shape057_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 40},
#  'shape057_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 41},
#  'shape104': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_218',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_002',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'id': 43},
#  'shape108': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_220',
#   'TEXT-DECORATION': 'none',
#   'TOP': '180px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_017',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'id': 44},
#  'shape109': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_021',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'id': 45},
#  'shape110': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_232',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_026',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'id': 46},
#  'shape111': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_202',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_053_027',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'id': 47},
#  'shape112': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'id': 48},
#  'shape115': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_059_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'id': 49},
#  'shape116': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '730px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_013',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'id': 213},
#  'shape223': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_218',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '435px',
#   'id': 63},
#  'shape226': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1655px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_7280',
#   'TEXT-DECORATION': 'none',
#   'TOP': '110px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_013_014',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '30px',
#   'id': 200},
#  'shape232': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_220',
#   'TEXT-DECORATION': 'none',
#   'TOP': '180px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '210px',
#   'id': 64},
#  'shape240': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '255px',
#   'id': 65},
#  'shape250': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_232',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '145px',
#   'id': 67},
#  'shape254': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_202',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '275px',
#   'id': 68},
#  'shape255': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '590px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_104',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '35px',
#   'id': 69},
#  'shape262': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '275px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 210},
#  'shape266': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 71},
#  'shape269': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_059_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '170px',
#   'id': 72},
#  'shape271': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '275px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004~MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '120px',
#   'id': 212},
#  'shape272': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102B',
#   'TEXT-DECORATION': 'none',
#   'TOP': '280px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'id': 50},
#  'shape273': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102A',
#   'TEXT-DECORATION': 'none',
#   'TOP': '75px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'id': 10},
#  'shape274': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_122',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 73},
#  'shape275': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '520px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_065',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '70px',
#   'id': 336},
#  'shape276': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '785px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_117',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 76},
#  'shape277': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '815px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_140',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 79},
#  'shape278': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '1193px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104A',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'id': 81},
#  'shape279': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104B',
#   'TEXT-DECORATION': 'none',
#   'TOP': '570px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'id': 82},
#  'shape281': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1150px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_271',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 83},
#  'shape282': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1150px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_272',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 85},
#  'shape283': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '970px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_109',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '100px',
#   'id': 87},
#  'shape284': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '1070px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_007',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '60px',
#   'id': 88},
#  'shape286': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_270',
#   'TEXT-DECORATION': 'none',
#   'TOP': '80px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 176},
#  'shape287': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_273',
#   'TEXT-DECORATION': 'none',
#   'TOP': '285px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 178},
#  'shape288': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1295px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_313',
#   'TEXT-DECORATION': 'none',
#   'TOP': '285px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_009',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 180},
#  'shape289': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1070px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_008',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '60px',
#   'id': 89},
#  'shape292': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '970px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '130px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_108',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '100px',
#   'id': 243},
#  'shape293': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '970px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '170px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_110',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '100px',
#   'id': 245},
#  'shape297': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '970px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '210px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_111',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '100px',
#   'id': 248},
#  'shape301': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1150px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2432',
#   'TEXT-DECORATION': 'none',
#   'TOP': '440px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 91},
#  'shape302': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1295px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_313',
#   'TEXT-DECORATION': 'none',
#   'TOP': '80px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 181},
#  'shape303': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1080px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2431',
#   'TEXT-DECORATION': 'none',
#   'TOP': '440px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 93},
#  'shape304': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1080px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2431',
#   'TEXT-DECORATION': 'none',
#   'TOP': '395px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '120px',
#   'id': 95},
#  'shape305': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1220px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2433',
#   'TEXT-DECORATION': 'none',
#   'TOP': '395px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '120px',
#   'id': 97},
#  'shape306': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1345px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_313',
#   'TEXT-DECORATION': 'none',
#   'TOP': '80px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_067',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 183},
#  'shape307': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1415px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_376',
#   'TEXT-DECORATION': 'none',
#   'TOP': '80px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_067',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 191},
#  'shape308': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399A',
#   'TEXT-DECORATION': 'none',
#   'TOP': '670px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'id': 145},
#  'shape309': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399B',
#   'TEXT-DECORATION': 'none',
#   'TOP': '825px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'id': 146},
#  'shape310': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '465px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_360',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_122',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '585px',
#   'id': 51},
#  'shape311': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '735px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_323',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_109',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '215px',
#   'id': 250},
#  'shape312': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1155px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_289',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '45px',
#   'id': 147},
#  'shape313': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1110px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_289',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_043',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '45px',
#   'id': 149},
#  'shape314': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
# ...
#   'Point?element': 'MAL_OS1_321',
#   'TEXT-DECORATION': 'none',
#   'TOP': '215px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_117',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 267},
#  'shape674': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '805px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_326',
#   'TEXT-DECORATION': 'none',
#   'TOP': '170px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_141~MAV_OS1_018_115',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 268},
#  'shape675': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '115px',
#   'LEFT': '805px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_326',
#   'TEXT-DECORATION': 'none',
#   'TOP': '215px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_141~MAV_OS1_018_115',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 269},
#  'shape676': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '150px',
#   'LEFT': '840px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_327',
#   'TEXT-DECORATION': 'none',
#   'TOP': '210px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 270},
#  'shape677': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '50px',
#   'LEFT': '435px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_220',
#   'TEXT-DECORATION': 'none',
#   'TOP': '130px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 273},
#  'shape678': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '130px',
#   'LEFT': '480px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '170px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 275},
#  'shape679': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '195px',
#   'LEFT': '530px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_246',
#   'TEXT-DECORATION': 'none',
#   'TOP': '210px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 277},
#  'shape680': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '145px',
#   'LEFT': '590px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '360px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_130',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 300},
#  'shape681': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '905px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_011',
#   'TEXT-DECORATION': 'none',
#   'TOP': '390px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'id': 308},
#  'shape682': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '20px',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_011',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 309},
#  'shape683': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '425px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 313},
#  'shape684': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '45px',
#   'LEFT': '835px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '455px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 314},
#  'shape686': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '835px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '590px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_064',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '30px',
#   'id': 316},
#  'shape689': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '865px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_013',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'id': 317},
#  'shape690': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '780px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_100',
#   'TEXT-DECORATION': 'none',
#   'TOP': '450px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'id': 318},
#  'shape691': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '780px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_172',
#   'TEXT-DECORATION': 'none',
#   'TOP': '495px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'id': 319},
#  'shape692': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '105px',
#   'id': 321},
#  'shape693': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 322},
#  'shape694': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_022_065',
#   'TEXT-DECORATION': 'none',
#   'TOP': '690px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'id': 325},
#  'shape695': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '885px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2430',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '45px',
#   'id': 326},
#  'shape696': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_022_066',
#   'TEXT-DECORATION': 'none',
#   'TOP': '655px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'id': 327},
#  'shape697': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '885px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2430',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '40px',
#   'id': 328},
#  'shape698': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 329},
#  'shape699': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '105px',
#   'id': 330},
#  'shape792': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN2400_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '70px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'id': 52},
#  'shape793': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN2600_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '415px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'id': 54},
#  'shape794': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN20200_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '820px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'id': 56},
#  'tfgOffDisplayEndPoints': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'LEFT': '175px',
#   'POSITION': 'absolute',
#   'Point?Element1': '',
#   'Point?Element10': '',
#   'Point?Element11': '',
#   'Point?Element12': '',
#   'Point?Element13': '',
#   'Point?Element14': '',
#   'Point?Element15': '',
#   'Point?Element16': '',
#   'Point?Element17': '',
#   'Point?Element18': '',
#   'Point?Element19': '',
#   'Point?Element2': '',
#   'Point?Element20': '',
#   'Point?Element21': '',
#   'Point?Element22': '',
#   'Point?Element23': '',
#   'Point?Element24': '',
#   'Point?Element25': '',
#   'Point?Element26': '',
#   'Point?Element27': '',
#   'Point?Element28': '',
#   'Point?Element29': '',
#   'Point?Element3': '',
#   'Point?Element30': '',
#   'Point?Element31': '',
#   'Point?Element32': '',
#   'Point?Element33': '',
#   'Point?Element34': '',
#   'Point?Element35': '',
#   'Point?Element36': '',
#   'Point?Element37': '',
#   'Point?Element38': '',
#   'Point?Element39': '',
#   'Point?Element4': '',
#   'Point?Element40': '',
#   'Point?Element5': '',
#   'Point?Element6': '',
#   'Point?Element7': '',
#   'Point?Element8': '',
#   'Point?Element9': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '19px',
#   'WIDTH': '92px',
#   'id': 6},
#  'tfgOperDataReInit': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'LEFT': '230px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'WIDTH': '92px',
#   'id': 5},
#  'tfgPlanningData': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'LEFT': '138px',
#   'POSITION': 'absolute',
#   'Point?DestElement': '',
#   'Point?SrcElement': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'Value?IgnoreOnDataChange': '"True"',
#   'WIDTH': '92px',
#   'id': 3},
#  'tfgSelectTimeout': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '16px',
#   'LEFT': '77px',
#   'POSITION': 'absolute',
#   'Point?DestElement': '',
#   'Point?SrcElement': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'Value?IgnoreOnDataChange': '"True"',
#   'WIDTH': '60px',
#   'id': 4}}

# %%
count={}
for i in total:
    if 'Value?ShapeID' in total[i]:
        print('{:15} {:17} {:15}'.format(i, total[i]['Value?ShapeID'], total[i]['Point?element']))
        if total[i]['Value?ShapeID'] in count:
            count[total[i]['Value?ShapeID']] += 1
        else : 
            count[total[i]['Value?ShapeID']] = 1
print(count)
# Out:
# shape385        Line              MAL_OS1_7280
# shape554        Line              MAL_OS1_314
# shape414        ValveMan          MAV_OS1_054_002
# shape273        CPump             _P53102A
# shape050        TankNozzle        TK53104
# shape051        TankNozzle        TK53105
# shape052        TankNozzle        TK53106
# shape053        TankNozzle        TK53107
# shape054        TankNozzle        TK53109
# shape055        TankNozzle        TK53110
# shape056        TankNozzle        TK53111
# shape057        TankNozzle        TK5397
# shape104        Line              MAL_OS1_218
# shape108        Line              MAL_OS1_220
# shape109        Line              MAL_OS1_230
# shape110        Line              MAL_OS1_232
# shape111        Line              MAL_OS1_202
# shape112        Line              MAL_OS1_483
# shape115        Line              MAL_OS1_417
# shape272        CPump             _P53102B
# shape310        Line              MAL_OS1_360
# shape792        BP                UN2400_WAXY
# shape793        BP                UN2600_WAXY
# shape392        Line              MAL_OS1_359
# shape794        BP                UN20200_WAXY
# shape415        ValveMan          MAV_OS1_054_017
# shape416        ValveMan          MAV_OS1_054_021
# shape417        ValveMan          MAV_OS1_054_026
# shape418        ValveMan          MAV_OS1_053_027
# shape421        ValveMan          MAV_OS1_062_004
# shape423        ValveMan          MAV_OS1_059_006
# shape223        Line              MAL_OS1_218
# shape232        Line              MAL_OS1_220
# shape240        Line              MAL_OS1_230
# shape444        ValveMan          MAV_OS1_017_024
# shape250        Line              MAL_OS1_232
# shape254        Line              MAL_OS1_202
# shape255        Line              MAL_OS1_312
# shape447        ValveMan          MAV_OS1_018_104
# shape266        Line              MAL_OS1_483
# shape269        Line              MAL_OS1_417
# shape274        Line              MAL_OS1_417
# shape457        ValveMan          MAV_OS1_021_122
# shape551        Line              MAL_OS1_417
# shape276        Line              MAL_OS1_417
# shape458        ValveMan          MAV_OS1_021_117
# shape552        Line              MAL_OS1_417
# shape277        Line              MAL_OS1_417
# shape459        ValveMan          MAV_OS1_021_140
# shape278        CPump             _P53104A
# shape279        CPump             _P53104B
# shape281        Line              MAL_OS1_271
# shape462        ValveMan          MAV_OS1_018_007
# shape282        Line              MAL_OS1_272
# shape463        ValveMan          MAV_OS1_018_008
# shape283        Line              MAL_OS1_314
# shape284        Line              MAL_OS1_314
# shape289        Line              MAL_OS1_314
# shape553        Line              MAL_OS1_314
# shape301        Line              MAL_OS1_2432
# shape506        ValveMan          MAV_OS1_022_062
# shape303        Line              MAL_OS1_2431
# shape563        Line              MAL_OS1_2431
# shape304        Line              MAL_OS1_2431
# shape507        ValveMan          OMAVALVE
# shape305        Line              MAL_OS1_2433
# shape564        Line              MAL_OS1_2433
# shape314        Line              MAL_OS1_2433
# shape315        Line              MAL_OS1_2433
# shape508        ValveMan          MAV_OS1_022_073
# shape329        Line              MAL_OS1_2433
# shape565        Line              MAL_OS1_2433
# shape509        ValveMan          MAV_OS1_022_074
# shape330        Line              MAL_OS1_2433
# shape334        Line              MAL_OS1_2431
# shape566        Line              MAL_OS1_2431
# shape510        ValveMan          MAV_OS1_022_061
# shape371        Line              MAL_OS1_2431
# shape511        ValveMan          MAV_OS1_022_072
# shape568        Line              MAL_OS1_2431
# shape393        Line              MAL_OS1_2431
# shape512        ValveMan          MAV_OS1_022_033
# shape569        Line              MAL_OS1_2431
# shape394        Line              MAL_OS1_2431
# shape513        ValveMan          MAV_OS1_022_057
# shape570        Line              MAL_OS1_2431
# shape395        Line              MAL_OS1_2428
# shape514        ValveMan          MAV_OS1_022_060
# shape396        Line              MAL_OS1_2426
# shape571        Line              MAL_OS1_2426
# shape397        Line              MAL_OS1_2426
# shape515        ValveMan          OMAVALVE
# shape398        Line              MAL_OS1_2424
# shape577        Line              MAL_OS1_2424
# shape399        Line              MAL_OS1_2426
# shape400        Line              MAL_OS1_2424
# shape401        Line              MAL_OS1_2424
# shape516        ValveMan          MAV_OS1_022_059
# shape404        Line              MAL_OS1_5002
# shape608        Line              MAL_OS1_5002
# shape405        Line              MAL_OS1_5002
# shape406        Line              MAL_OS1_5002
# shape609        Line              MAL_OS1_5002
# shape518        ValveMan          MAV_OS1_019_004
# shape407        Line              MAL_OS1_5002
# shape408        Line              MAL_OS1_5002
# shape610        Line              MAL_OS1_5002
# shape519        ValveMan          MAV_OS1_014_003
# shape409        Line              MAL_OS1_5002
# shape410        Line              MAL_OS1_5002
# shape523        Line              MAL_OS1_246
# shape627        Line              MAL_OS1_483
# shape651        Line              MAL_OS1_325
# shape308        CPump             _P5399A
# shape309        CPump             _P5399B
# shape312        Line              MAL_OS1_289
# shape468        ValveMan          MAV_OS1_018_043
# shape313        Line              MAL_OS1_289
# shape316        Line              MAL_OS1_360
# shape469        ValveMan          OMAVALVE
# shape572        Line              MAL_OS1_289
# shape318        Line              MAL_OS1_289
# shape319        Line              MAL_OS1_288
# shape573        Line              MAL_OS1_288
# shape320        Line              MAL_OS1_288
# shape321        Line              MAL_OS1_288
# shape574        Line              MAL_OS1_360
# shape470        ValveMan          MAV_OS1_018_042
# shape322        Line              MAL_OS1_360
# shape323        Line              MAL_OS1_287
# shape324        Line              MAL_OS1_287
# shape471        ValveMan          OMAVALVE
# shape575        Line              MAL_OS1_287
# shape325        Line              MAL_OS1_287
# shape326        Line              MAL_OS1_286
# shape576        Line              MAL_OS1_286
# shape327        Line              MAL_OS1_286
# shape328        Line              MAL_OS1_286
# shape472        ValveMan          MAV_OS1_018_038
# shape473        ValveMan          MAV_OS1_018_136
# shape390        Line              MAL_OS1_359
# shape391        Line              MAL_OS1_359
# shape607        Line              MAL_OS1_359
# shape286        Line              MAL_OS1_270
# shape467        ValveMan          MAV_OS1_018_006
# shape287        Line              MAL_OS1_273
# shape476        ValveMan          MAV_OS1_018_009
# shape288        Line              MAL_OS1_313
# shape302        Line              MAL_OS1_313
# shape558        Line              MAL_OS1_313
# shape306        Line              MAL_OS1_313
# shape477        ValveMan          MAV_OS1_018_067
# shape527        ValveMan          MAV_OS1_018_106
# shape331        Line              MAL_OS1_313
# shape559        Line              MAL_OS1_313
# shape529        ValveMan          MAV_OS1_018_107
# shape332        Line              MAL_OS1_313
# shape578        Line              MAL_OS1_313
# shape307        Line              MAL_OS1_376
# shape317        Line              MAL_OS1_376
# shape579        Line              MAL_OS1_376
# shape333        Line              MAL_OS1_376
# shape479        ValveMan          MAV_OS1_014_004
# shape480        ValveMan          MAV_OS1_013_012
# shape335        Line              MAL_OS1_7279
# shape481        ValveMan          MAV_OS1_013_013
# shape534        Line              MAL_OS1_7280
# shape226        Line              MAL_OS1_7280
# shape433        ValveMan          MAV_OS1_013_014
# shape536        Line              MAL_OS1_7280
# shape442        ValveMan          MAV_OS1_013_015
# shape336        Line              MAL_OS1_7280
# shape337        Line              MAL_OS1_7280
# shape659        Line              MAL_OS1_483
# shape660        ValveMan          MAV_OS1_021_047
# shape661        Line              MAL_OS1_483
# shape580        Line              MAL_OS1_483
# shape262        Line              MAL_OS1_483
# shape455        ValveMan          MAV_OS1_024_031
# shape271        Line              MAL_OS1_483
# shape116        Line              MAL_OS1_491
# shape422        ValveMan          MAV_OS1_062_013
# shape341        Line              MAL_OS1_491
# shape584        Line              MAL_OS1_2426
# shape640        ValveMan          MAV_OS1_022_068
# shape641        ValveMan          MAV_OS1_022_069
# shape642        ValveMan          MAV_OS1_022_067
# shape643        Line              MAL_OS1_2426
# shape644        Line              MAL_OS1_2426
# shape645        Line              MAL_OS1_2426
# shape646        Line              MAL_OS1_2426
# shape647        Line              MAL_OS1_2426
# shape648        Line              MAL_OS1_2426
# shape649        ValveMan          MAV_OS1_022_064
# shape668        Line              MAL_OS1_2426
# PseudoValve039  ValvePseudo       _P53102AL
# PseudoValve040  ValvePseudo       _P53102AR
# PseudoValve041  ValvePseudo       _P53102BL
# PseudoValve042  ValvePseudo       _P53102BR
# PseudoValve043  ValvePseudo       _P53104AL
# PseudoValve044  ValvePseudo       _P53104AR
# PseudoValve045  ValvePseudo       _P53104BL
# PseudoValve046  ValvePseudo       _P53104BR
# PseudoValve047  ValvePseudo       _P5399AL
# PseudoValve048  ValvePseudo       _P5399AR
# PseudoValve049  ValvePseudo       _P5399BL
# PseudoValve050  ValvePseudo       _P5399BR
# shape619        Line              MAL_OS1_368
# shape650        ValveMan          MAV_OS1_022_063
# shape438        ValveMan          MAV_OS1_018_109
# shape292        Line              MAL_OS1_314
# shape439        ValveMan          MAV_OS1_018_108
# shape293        Line              MAL_OS1_314
# shape461        ValveMan          MAV_OS1_018_110
# shape587        Line              MAL_OS1_314
# shape297        Line              MAL_OS1_314
# shape464        ValveMan          MAV_OS1_018_111
# shape311        Line              MAL_OS1_323
# shape347        Line              MAL_OS1_321
# shape348        Line              MAL_OS1_326
# shape349        Line              MAL_OS1_327
# shape588        Line              MAL_OS1_314
# shape465        ValveMan          MAV_OS1_018_072
# shape617        Line              MAL_OS1_323
# shape622        Line              MAL_OS1_323
# shape637        Line              MAL_OS1_323
# shape350        Line              MAL_OS1_323
# shape475        ValveMan          MAV_OS1_018_071
# shape483        ValveMan          MAV_OS1_018_074
# shape484        ValveMan          MAV_OS1_018_075
# shape638        Line              MAL_OS1_323
# shape655        Line              MAL_OS1_321
# shape352        Line              MAL_OS1_321
# shape672        Line              MAL_OS1_321
# shape673        Line              MAL_OS1_321
# shape674        Line              MAL_OS1_326
# shape675        Line              MAL_OS1_326
# shape676        Line              MAL_OS1_327
# shape353        Line              MAL_OS1_326
# shape354        Line              MAL_OS1_327
# shape677        Line              MAL_OS1_220
# shape355        Line              MAL_OS1_220
# shape678        Line              MAL_OS1_230
# shape356        Line              MAL_OS1_230
# shape679        Line              MAL_OS1_246
# shape357        Line              MAL_OS1_246
# shape589        Line              MAL_OS1_368
# shape358        Line              MAL_OS1_327
# shape485        ValveMan          MAV_OS1_018_114
# shape359        Line              MAL_OS1_368
# shape360        Line              MAL_OS1_326
# shape486        ValveMan          MAV_OS1_018_115
# shape361        Line              MAL_OS1_368
# shape362        Line              MAL_OS1_321
# shape487        ValveMan          MAV_OS1_018_117
# shape363        Line              MAL_OS1_368
# shape364        Line              MAL_OS1_323
# shape488        ValveMan          MAV_OS1_018_116
# shape365        Line              MAL_OS1_368
# shape590        Line              MAL_OS1_368
# shape591        Line              MAL_OS1_368
# shape366        Line              MAL_OS1_326
# shape367        Line              MAL_OS1_321
# shape368        Line              MAL_OS1_321
# shape369        Line              MAL_OS1_323
# shape370        Line              MAL_OS1_323
# shape372        Line              MAL_OS1_323
# shape680        Line              MAL_OS1_312
# shape373        Line              MAL_OS1_327
# shape490        ValveMan          MAV_OS1_018_130
# shape374        Line              MAL_OS1_312
# shape375        Line              MAL_OS1_326
# shape491        ValveMan          MAV_OS1_018_141
# shape376        Line              MAL_OS1_323
# shape492        ValveMan          MAV_OS1_018_134
# shape681        ValveMan          MAV_OS1_018_011
# shape682        Line              MAL_OS1_325
# shape377        Line              MAL_OS1_325
# shape378        Line              MAL_OS1_325
# shape379        Line              MAL_OS1_325
# shape683        Line              MAL_OS1_325
# shape684        Line              MAL_OS1_325
# shape380        Line              MAL_OS1_2427
# shape686        Line              MAL_OS1_325
# shape689        ValveMan          MAV_OS1_018_013
# shape690        ValveMan          MAV_OS1_018_100
# shape691        ValveMan          MAV_OS1_018_172
# shape382        Line              MAL_OS1_325
# shape692        Line              MAL_OS1_491
# shape693        Line              MAL_OS1_491
# shape383        Line              MAL_OS1_220
# shape493        ValveMan          MAV_OS1_018_073
# shape694        ValveMan          MAV_OS1_022_065
# shape695        Line              MAL_OS1_2430
# shape696        ValveMan          MAV_OS1_022_066
# shape697        Line              MAL_OS1_2430
# shape698        Line              MAL_OS1_483
# shape699        Line              MAL_OS1_483
# shape592        Line              MAL_OS1_2424
# shape517        ValveMan          MAV_OS1_022_162
# shape384        Line              MAL_OS1_2424
# shape402        Line              MAL_OS1_2424
# shape494        ValveMan          MAV_OS1_018_065
# shape275        Line              MAL_OS1_312
# {'Line': 200, 'ValveMan': 75, 'CPump': 6, 'TankNozzle': 8, 'BP': 3, 'ValvePseudo': 12}

# %%
# make total dictionary - 2

divpm = main.findAll('div',attrs = {'parameters':True})
total = {}
for i,div in enumerate(divpm):
    
    total[div['id']] = {'id':i}
    
    param = {}
    for p in div['parameters'].split(';'):
        param.update(dict(zip(p.split(':')[::2], p.split(':')[1::2])))
    total[div['id']].update(param)
    
    style = {}
    for s in div['style'].split('; '):
        style.update(dict(zip(s.split(':')[::2], s.split(': ')[1::2])))
    total[div['id']].update(style)
    
    properties = {}
    for t in div['hdxproperties'].split(';'):
        properties.update(dict(zip(t.split(':')[::2], t.split(':')[1::2])))
    total[div['id']].update(properties)
    
total
# Out:
# {'PseudoValve039': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '85px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 228,
#   'lineColorBlink': 'False'},
#  'PseudoValve040': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '75px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 229,
#   'lineColorBlink': 'False'},
#  'PseudoValve041': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '295px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 230,
#   'lineColorBlink': 'False'},
#  'PseudoValve042': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '280px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 231,
#   'lineColorBlink': 'False'},
#  'PseudoValve043': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '435px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 232,
#   'lineColorBlink': 'False'},
#  'PseudoValve044': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 233,
#   'lineColorBlink': 'False'},
#  'PseudoValve045': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '585px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 234,
#   'lineColorBlink': 'False'},
#  'PseudoValve046': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '570px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 235,
#   'lineColorBlink': 'False'},
#  'PseudoValve047': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '685px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 236,
#   'lineColorBlink': 'False'},
#  'PseudoValve048': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '670px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 237,
#   'lineColorBlink': 'False'},
#  'PseudoValve049': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '840px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 238,
#   'lineColorBlink': 'False'},
#  'PseudoValve050': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'Height': '11',
#   'LEFT': '1235px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '825px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'Width': '11',
#   'fillColorBlink': 'False',
#   'id': 239,
#   'lineColorBlink': 'False'},
#  'shape001': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '29px',
#   'Height': '29',
#   'LEFT': '5px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '0px',
#   'WIDTH': '103px',
#   'Width': '103',
#   'fillColorBlink': 'False',
#   'id': 2,
#   'lineColorBlink': 'False'},
#  'shape015': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '36px',
#   'Height': '36',
#   'LEFT': '0px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TEXT?ACTIVITY': 'CH',
#   'TEXT?AREA': '제품운영1과',
#   'TEXT?PRODUCT': 'WAXY',
#   'TEXT?TANK': '-',
#   'TOP': '0px',
#   'WIDTH': '1910px',
#   'Width': '1910',
#   'fillColorBlink': 'False',
#   'id': 7,
#   'lineColorBlink': 'False'},
#  'shape023': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53104',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31',
#   'TOP': '115px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 14,
#   'lineColorBlink': 'False'},
#  'shape024': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53105',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-96S',
#   'TOP': '220px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 18,
#   'lineColorBlink': 'False'},
#  'shape025': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53106',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-20',
#   'TOP': '325px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 22,
#   'lineColorBlink': 'False'},
#  'shape027': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-2400',
#   'TEXT-DECORATION': 'none',
#   'TOP': '70px',
#   'WIDTH': '95px',
#   'Width': '95',
#   'fillColorBlink': 'False',
#   'id': 8,
#   'lineColorBlink': 'False'},
#  'shape028': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53107',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-116',
#   'TOP': '430px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 26,
#   'lineColorBlink': 'False'},
#  'shape029': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53109',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-480',
#   'TOP': '540px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 30,
#   'lineColorBlink': 'False'},
#  'shape030': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31S',
#   'TOP': '650px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 34,
#   'lineColorBlink': 'False'},
#  'shape031': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31S',
#   'TOP': '765px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 38,
#   'lineColorBlink': 'False'},
#  'shape032': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK5397',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'Mix-W',
#   'TOP': '865px',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 42,
#   'lineColorBlink': 'False'},
#  'shape033': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-2600',
#   'TEXT-DECORATION': 'none',
#   'TOP': '415px',
#   'WIDTH': '95px',
#   'Width': '95',
#   'fillColorBlink': 'False',
#   'id': 53,
#   'lineColorBlink': 'False'},
#  'shape035': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-20200',
#   'TEXT-DECORATION': 'none',
#   'TOP': '820px',
#   'WIDTH': '95px',
#   'Width': '95',
#   'fillColorBlink': 'False',
#   'id': 175,
#   'lineColorBlink': 'False'},
#  'shape050': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53104',
#   'TEXT-DECORATION': 'none',
#   'TOP': '40px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 11,
#   'lineColorBlink': 'False'},
#  'shape050_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '24',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 12,
#   'lineColorBlink': 'False'},
#  'shape050_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '27',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 13,
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False'},
#  'shape051': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53105',
#   'TEXT-DECORATION': 'none',
#   'TOP': '145px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 15,
#   'lineColorBlink': 'False'},
#  'shape051_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '68',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 16,
#   'lineColorBlink': 'False'},
#  'shape051_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '71',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 17,
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False'},
#  'shape052': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53106',
#   'TEXT-DECORATION': 'none',
#   'TOP': '250px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 19,
#   'lineColorBlink': 'False'},
#  'shape052_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '82',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 20,
#   'lineColorBlink': 'False'},
#  'shape052_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '85',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 21,
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False'},
#  'shape053': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53107',
#   'TEXT-DECORATION': 'none',
#   'TOP': '355px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 23,
#   'lineColorBlink': 'False'},
#  'shape053_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '96',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 24,
#   'lineColorBlink': 'False'},
#  'shape053_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '99',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 25,
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False'},
#  'shape054': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53109',
#   'TEXT-DECORATION': 'none',
#   'TOP': '465px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 27,
#   'lineColorBlink': 'False'},
#  'shape054_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '110',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 28,
#   'lineColorBlink': 'False'},
#  'shape054_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '113',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 29,
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False'},
#  'shape055': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TOP': '575px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 31,
#   'lineColorBlink': 'False'},
#  'shape055_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '124',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 32,
#   'lineColorBlink': 'False'},
#  'shape055_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '127',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 33,
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False'},
#  'shape056': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53111',
#   'TEXT-DECORATION': 'none',
#   'TOP': '690px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 35,
#   'lineColorBlink': 'False'},
#  'shape056_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '138',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 36,
#   'lineColorBlink': 'False'},
#  'shape056_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '141',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 37,
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False'},
#  'shape057': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'Height': '80',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK5397',
#   'TEXT-DECORATION': 'none',
#   'TOP': '790px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'Width': '125',
#   'fillColorBlink': 'False',
#   'id': 39,
#   'lineColorBlink': 'False'},
#  'shape057_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '152',
#   'HEIGHT': '77.5%',
#   'Height': '62',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'Width': '113',
#   'fillColorBlink': 'False',
#   'id': 40,
#   'lineColorBlink': 'False'},
#  'shape057_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HDXBINDINGID': '155',
#   'HEIGHT': '16.25%',
#   'Height': '13',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'Width': '12',
#   'fillColorBlink': 'False',
#   'id': 41,
#   'indicateAlarmState': 'False',
#   'indicateScanState': 'False',
#   'lineColorBlink': 'False'},
#  'shape104': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_218',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_002',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 43,
#   'lineColorBlink': 'False'},
#  'shape108': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_220',
#   'TEXT-DECORATION': 'none',
#   'TOP': '180px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_017',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 44,
#   'lineColorBlink': 'False'},
#  'shape109': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_021',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 45,
#   'lineColorBlink': 'False'},
#  'shape110': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_232',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_026',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 46,
#   'lineColorBlink': 'False'},
#  'shape111': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_202',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_053_027',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'Width': '75',
#   'fillColorBlink': 'False',
#   'id': 47,
#   'lineColorBlink': 'False'},
#  'shape112': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'Width': '80',
#   'fillColorBlink': 'False',
#   'id': 48,
#   'lineColorBlink': 'False'},
#  'shape115': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_059_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'Width': '80',
#   'fillColorBlink': 'False',
#   'id': 49,
#   'lineColorBlink': 'False'},
#  'shape116': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '730px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_013',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'Width': '80',
#   'fillColorBlink': 'False',
#   'id': 213,
#   'lineColorBlink': 'False'},
#  'shape223': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_218',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '435px',
#   'Width': '435',
#   'fillColorBlink': 'False',
#   'id': 63,
#   'lineColorBlink': 'False'},
#  'shape226': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '1655px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_7280',
#   'TEXT-DECORATION': 'none',
#   'TOP': '110px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_013_014',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 200,
#   'lineColorBlink': 'False'},
#  'shape232': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_220',
#   'TEXT-DECORATION': 'none',
#   'TOP': '180px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '210px',
#   'Width': '210',
#   'fillColorBlink': 'False',
#   'id': 64,
#   'lineColorBlink': 'False'},
#  'shape240': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '255px',
#   'Width': '255',
#   'fillColorBlink': 'False',
#   'id': 65,
#   'lineColorBlink': 'False'},
#  'shape250': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_232',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '145px',
#   'Width': '145',
#   'fillColorBlink': 'False',
#   'id': 67,
#   'lineColorBlink': 'False'},
#  'shape254': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_202',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '275px',
#   'Width': '275',
#   'fillColorBlink': 'False',
#   'id': 68,
#   'lineColorBlink': 'False'},
#  'shape255': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '590px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_104',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 69,
#   'lineColorBlink': 'False'},
#  'shape262': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '275px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 210,
#   'lineColorBlink': 'False'},
#  'shape266': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 71,
#   'lineColorBlink': 'False'},
#  'shape269': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_059_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '170px',
#   'Width': '170',
#   'fillColorBlink': 'False',
#   'id': 72,
#   'lineColorBlink': 'False'},
#  'shape271': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '275px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004~MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '120px',
#   'Width': '120',
#   'fillColorBlink': 'False',
#   'id': 212,
#   'lineColorBlink': 'False'},
#  'shape272': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102B',
#   'TEXT-DECORATION': 'none',
#   'TOP': '280px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 50,
#   'lineColorBlink': 'False'},
#  'shape273': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102A',
#   'TEXT-DECORATION': 'none',
#   'TOP': '75px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 10,
#   'lineColorBlink': 'False'},
#  'shape274': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_122',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 73,
#   'lineColorBlink': 'False'},
#  'shape275': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '520px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_065',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '70px',
#   'Width': '70',
#   'fillColorBlink': 'False',
#   'id': 336,
#   'lineColorBlink': 'False'},
#  'shape276': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '785px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_117',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 76,
#   'lineColorBlink': 'False'},
#  'shape277': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '815px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_140',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 79,
#   'lineColorBlink': 'False'},
#  'shape278': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '1193px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104A',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 81,
#   'lineColorBlink': 'False'},
#  'shape279': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104B',
#   'TEXT-DECORATION': 'none',
#   'TOP': '570px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'Width': '35',
#   'fillColorBlink': 'False',
#   'id': 82,
#   'lineColorBlink': 'False'},
#  'shape281': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '1150px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_271',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 83,
#   'lineColorBlink': 'False'},
#  'shape282': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '1150px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_272',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 85,
#   'lineColorBlink': 'False'},
#  'shape283': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '970px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_109',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '100px',
#   'Width': '100',
#   'fillColorBlink': 'False',
#   'id': 87,
#   'lineColorBlink': 'False'},
#  'shape284': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'Height': '15',
#   'LEFT': '1070px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_007',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '60px',
#   'Width': '60',
#   'fillColorBlink': 'False',
#   'id': 88,
#   'lineColorBlink': 'False'},
#  'shape286': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '1225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_270',
#   'TEXT-DECORATION': 'none',
#   'TOP': '80px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 176,
#   'lineColorBlink': 'False'},
#  'shape287': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '1225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_273',
#   'TEXT-DECORATION': 'none',
#   'TOP': '285px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 178,
#   'lineColorBlink': 'False'},
#  'shape288': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '1295px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_313',
#   'TEXT-DECORATION': 'none',
#   'TOP': '285px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_009',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'Width': '50',
#   'fillColorBlink': 'False',
#   'id': 180,
#   'lineColorBlink': 'False'},
#  'shape289': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '1070px',
# ...
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '130px',
#   'Height': '130',
#   'LEFT': '480px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '170px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 275,
#   'lineColorBlink': 'False'},
#  'shape679': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '195px',
#   'Height': '195',
#   'LEFT': '530px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_246',
#   'TEXT-DECORATION': 'none',
#   'TOP': '210px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 277,
#   'lineColorBlink': 'False'},
#  'shape680': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '145px',
#   'Height': '145',
#   'LEFT': '590px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '360px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_130',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 300,
#   'lineColorBlink': 'False'},
#  'shape681': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '905px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_011',
#   'Rotation': '270',
#   'TEXT-DECORATION': 'none',
#   'TOP': '390px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 308,
#   'lineColorBlink': 'False'},
#  'shape682': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '20px',
#   'Height': '20',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_011',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 309,
#   'lineColorBlink': 'False'},
#  'shape683': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '425px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 313,
#   'lineColorBlink': 'False'},
#  'shape684': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '45px',
#   'Height': '45',
#   'LEFT': '835px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '455px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 314,
#   'lineColorBlink': 'False'},
#  'shape686': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '835px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '590px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_064',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 316,
#   'lineColorBlink': 'False'},
#  'shape689': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '865px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_013',
#   'Rotation': '0',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 317,
#   'lineColorBlink': 'False'},
#  'shape690': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '780px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_100',
#   'Rotation': '0',
#   'TEXT-DECORATION': 'none',
#   'TOP': '450px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 318,
#   'lineColorBlink': 'False'},
#  'shape691': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '780px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_172',
#   'Rotation': '0',
#   'TEXT-DECORATION': 'none',
#   'TOP': '495px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 319,
#   'lineColorBlink': 'False'},
#  'shape692': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '105px',
#   'Width': '105',
#   'fillColorBlink': 'False',
#   'id': 321,
#   'lineColorBlink': 'False'},
#  'shape693': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'Height': '35',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 322,
#   'lineColorBlink': 'False'},
#  'shape694': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_022_065',
#   'TEXT-DECORATION': 'none',
#   'TOP': '690px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 325,
#   'lineColorBlink': 'False'},
#  'shape695': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '885px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2430',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '45px',
#   'Width': '45',
#   'fillColorBlink': 'False',
#   'id': 326,
#   'lineColorBlink': 'False'},
#  'shape696': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_022_066',
#   'TEXT-DECORATION': 'none',
#   'TOP': '655px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'Width': '30',
#   'fillColorBlink': 'False',
#   'id': 327,
#   'lineColorBlink': 'False'},
#  'shape697': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '885px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2430',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '40px',
#   'Width': '40',
#   'fillColorBlink': 'False',
#   'id': 328,
#   'lineColorBlink': 'False'},
#  'shape698': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'Height': '30',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'Width': '10',
#   'fillColorBlink': 'False',
#   'id': 329,
#   'lineColorBlink': 'False'},
#  'shape699': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'Height': '10',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '105px',
#   'Width': '105',
#   'fillColorBlink': 'False',
#   'id': 330,
#   'lineColorBlink': 'False'},
#  'shape792': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN2400_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '70px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'Width': '26',
#   'fillColorBlink': 'False',
#   'id': 52,
#   'lineColorBlink': 'False'},
#  'shape793': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN2600_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '415px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'Width': '26',
#   'fillColorBlink': 'False',
#   'id': 54,
#   'lineColorBlink': 'False'},
#  'shape794': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'Height': '18',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN20200_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '820px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'Width': '26',
#   'fillColorBlink': 'False',
#   'id': 56,
#   'lineColorBlink': 'False'},
#  'tfgOffDisplayEndPoints': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'Height': '14',
#   'LEFT': '175px',
#   'POSITION': 'absolute',
#   'Point?Element1': '',
#   'Point?Element10': '',
#   'Point?Element11': '',
#   'Point?Element12': '',
#   'Point?Element13': '',
#   'Point?Element14': '',
#   'Point?Element15': '',
#   'Point?Element16': '',
#   'Point?Element17': '',
#   'Point?Element18': '',
#   'Point?Element19': '',
#   'Point?Element2': '',
#   'Point?Element20': '',
#   'Point?Element21': '',
#   'Point?Element22': '',
#   'Point?Element23': '',
#   'Point?Element24': '',
#   'Point?Element25': '',
#   'Point?Element26': '',
#   'Point?Element27': '',
#   'Point?Element28': '',
#   'Point?Element29': '',
#   'Point?Element3': '',
#   'Point?Element30': '',
#   'Point?Element31': '',
#   'Point?Element32': '',
#   'Point?Element33': '',
#   'Point?Element34': '',
#   'Point?Element35': '',
#   'Point?Element36': '',
#   'Point?Element37': '',
#   'Point?Element38': '',
#   'Point?Element39': '',
#   'Point?Element4': '',
#   'Point?Element40': '',
#   'Point?Element5': '',
#   'Point?Element6': '',
#   'Point?Element7': '',
#   'Point?Element8': '',
#   'Point?Element9': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '19px',
#   'WIDTH': '92px',
#   'Width': '92',
#   'fillColorBlink': 'False',
#   'id': 6,
#   'lineColorBlink': 'False'},
#  'tfgOperDataReInit': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'Height': '14',
#   'LEFT': '230px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'WIDTH': '92px',
#   'Width': '92',
#   'fillColorBlink': 'False',
#   'id': 5,
#   'lineColorBlink': 'False'},
#  'tfgPlanningData': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'Height': '14',
#   'LEFT': '138px',
#   'POSITION': 'absolute',
#   'Point?DestElement': '',
#   'Point?SrcElement': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'Value?IgnoreOnDataChange': '"True"',
#   'WIDTH': '92px',
#   'Width': '92',
#   'fillColorBlink': 'False',
#   'id': 3,
#   'lineColorBlink': 'False'},
#  'tfgSelectTimeout': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '16px',
#   'Height': '16',
#   'LEFT': '77px',
#   'POSITION': 'absolute',
#   'Point?DestElement': '',
#   'Point?SrcElement': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'Value?IgnoreOnDataChange': '"True"',
#   'WIDTH': '60px',
#   'Width': '60',
#   'fillColorBlink': 'False',
#   'id': 4,
#   'lineColorBlink': 'False'}}

# %%
total['shape442']
# Out:
# {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#  'FONT-FAMILY': 'Arial',
#  'FONT-SIZE': '0px',
#  'FONT-STYLE': 'normal',
#  'FONT-WEIGHT': '400',
#  'HEIGHT': '10px',
#  'Height': '10',
#  'LEFT': '1700px',
#  'POSITION': 'absolute',
#  'Point?element': 'MAV_OS1_013_015',
#  'Rotation': '270',
#  'TEXT-DECORATION': 'none',
#  'TOP': '115px',
#  'Value?DataBoundObj': 'plyValve',
#  'Value?DefElemType': '5',
#  'Value?ShapeID': 'ValveMan',
#  'WIDTH': '30px',
#  'Width': '30',
#  'fillColorBlink': 'False',
#  'id': 203,
#  'lineColorBlink': 'False'}

# %%
# Line
countline = 0
for i in total:
    if 'Value?ShapeID' in total[i] and total[i]['Value?ShapeID'] == 'Line':
        print('{:10} {:6} {:17} {:40} {:40}'.format(i, total[i]['Value?ShapeID'], total[i]['Point?element'], 
                                                    total[i]['Value?EndPoint1'], total[i]['Value?EndPoint2']))
        countline += 1
print(countline)
# Out:
# shape385   Line   MAL_OS1_7280      MAV_OS1_013_014~MAV_OS1_013_013
# shape554   Line   MAL_OS1_314       MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108 MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110
# shape104   Line   MAL_OS1_218       MAV_OS1_054_002
# shape108   Line   MAL_OS1_220       MAV_OS1_054_017
# shape109   Line   MAL_OS1_230       MAV_OS1_054_021
# shape110   Line   MAL_OS1_232       MAV_OS1_054_026
# shape111   Line   MAL_OS1_202       MAV_OS1_053_027
# shape112   Line   MAL_OS1_483       MAV_OS1_062_004
# shape115   Line   MAL_OS1_417       MAV_OS1_059_006
# shape310   Line   MAL_OS1_360       MAV_OS1_021_122
# shape392   Line   MAL_OS1_359       MAV_OS1_018_136
# shape223   Line   MAL_OS1_218
# shape232   Line   MAL_OS1_220       PSP5383L
# shape240   Line   MAL_OS1_230       PSP5383L
# shape250   Line   MAL_OS1_232       PSP5383L
# shape254   Line   MAL_OS1_202
# shape255   Line   MAL_OS1_312       MAV_OS1_018_104
# shape266   Line   MAL_OS1_483       MAV_OS1_062_004
# shape269   Line   MAL_OS1_417       MAV_OS1_059_006
# shape274   Line   MAL_OS1_417       MAV_OS1_021_122
# shape551   Line   MAL_OS1_417       MAV_OS1_021_140~MAV_OS1_021_117
# shape276   Line   MAL_OS1_417       MAV_OS1_021_117
# shape552   Line   MAL_OS1_417       MAV_OS1_021_117
# shape277   Line   MAL_OS1_417       MAV_OS1_021_140
# shape281   Line   MAL_OS1_271
# shape282   Line   MAL_OS1_272
# shape283   Line   MAL_OS1_314       MAV_OS1_018_109
# shape284   Line   MAL_OS1_314       MAV_OS1_018_007
# shape289   Line   MAL_OS1_314       MAV_OS1_018_008
# shape553   Line   MAL_OS1_314       MAV_OS1_018_007~MAV_OS1_018_109          MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110~MAV_OS1_018_108
# shape301   Line   MAL_OS1_2432      PSP5383L
# shape303   Line   MAL_OS1_2431      PSP5383L
# shape563   Line   MAL_OS1_2431      MAV005~MAV004                            MAV010
# shape304   Line   MAL_OS1_2431      PSP5383L
# shape305   Line   MAL_OS1_2433      PSP5383L
# shape564   Line   MAL_OS1_2433      MAV005~MAV004                            MAV010
# shape314   Line   MAL_OS1_2433      PSP5383L
# shape315   Line   MAL_OS1_2433      PSP5383L
# shape329   Line   MAL_OS1_2433      MAV_OS1_022_073
# shape565   Line   MAL_OS1_2433      MAV_OS1_022_074
# shape330   Line   MAL_OS1_2433      MAV_OS1_022_074
# shape334   Line   MAL_OS1_2431      PSP5383L
# shape566   Line   MAL_OS1_2431      MAV005~MAV004                            MAV010
# shape371   Line   MAL_OS1_2431      MAV_OS1_022_072
# shape568   Line   MAL_OS1_2431      MAV005~MAV004                            MAV010
# shape393   Line   MAL_OS1_2431      MAV_OS1_022_033
# shape569   Line   MAL_OS1_2431      MAV005~MAV004                            MAV010
# shape394   Line   MAL_OS1_2431      MAV_OS1_022_057
# shape570   Line   MAL_OS1_2431      MAV_OS1_022_061
# shape395   Line   MAL_OS1_2428      PSP5383L
# shape396   Line   MAL_OS1_2426      MAV_OS1_022_060
# shape571   Line   MAL_OS1_2426      MAV005~MAV004                            MAV010
# shape397   Line   MAL_OS1_2426      PSP5383L
# shape398   Line   MAL_OS1_2424      PSP5383L
# shape577   Line   MAL_OS1_2424      MAV005~MAV004                            MAV010
# shape399   Line   MAL_OS1_2426      MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067~MAV_OS1_022_063~MAV_OS1_022_061
# shape400   Line   MAL_OS1_2424      PSP5383L
# shape401   Line   MAL_OS1_2424      PSP5383L
# shape404   Line   MAL_OS1_5002      MAV_OS1_022_073
# shape608   Line   MAL_OS1_5002      MAV_OS1_022_059
# shape405   Line   MAL_OS1_5002      MAV_OS1_022_059
# shape406   Line   MAL_OS1_5002      UN2600_WAXY
# shape609   Line   MAL_OS1_5002      MAV_OS1_019_004
# shape407   Line   MAL_OS1_5002      MAV_OS1_019_004
# shape408   Line   MAL_OS1_5002      UN2600_WAXY
# shape610   Line   MAL_OS1_5002      MAV_OS1_014_003
# shape409   Line   MAL_OS1_5002      MAV_OS1_014_003
# shape410   Line   MAL_OS1_5002      UN2600_WAXY
# shape523   Line   MAL_OS1_246       PSP5383L
# shape627   Line   MAL_OS1_483       MAV_OS1_022_069
# shape651   Line   MAL_OS1_325       MAV_OS1_022_064
# shape312   Line   MAL_OS1_289       PSP5383L
# shape313   Line   MAL_OS1_289       MAV_OS1_018_043
# shape316   Line   MAL_OS1_360       MAV_OS1_018_043
# shape572   Line   MAL_OS1_289       OMAVALVE
# shape318   Line   MAL_OS1_289       OMAVALVE
# shape319   Line   MAL_OS1_288       OMAVALVE
# shape573   Line   MAL_OS1_288       OMAVALVE
# shape320   Line   MAL_OS1_288       _P5399BR
# shape321   Line   MAL_OS1_288       MAV_OS1_018_136
# shape574   Line   MAL_OS1_360       MAV_OS1_018_042
# shape322   Line   MAL_OS1_360       MAV_OS1_018_042
# shape323   Line   MAL_OS1_287       _P5399AL
# shape324   Line   MAL_OS1_287       MAV_OS1_018_042
# shape575   Line   MAL_OS1_287       OMAVALVE
# shape325   Line   MAL_OS1_287       OMAVALVE
# shape326   Line   MAL_OS1_286       OMAVALVE
# shape576   Line   MAL_OS1_286       OMAVALVE
# shape327   Line   MAL_OS1_286       PSP5383L
# shape328   Line   MAL_OS1_286       MAV_OS1_018_038
# shape390   Line   MAL_OS1_359       MAV_OS1_018_038
# shape391   Line   MAL_OS1_359       MAV_OS1_018_136
# shape607   Line   MAL_OS1_359       MAV_OS1_018_038
# shape286   Line   MAL_OS1_270
# shape287   Line   MAL_OS1_273
# shape288   Line   MAL_OS1_313       MAV_OS1_018_009
# shape302   Line   MAL_OS1_313       MAV_OS1_018_006
# shape558   Line   MAL_OS1_313       MAV_OS1_018_067~MAV_OS1_018_006
# shape306   Line   MAL_OS1_313       MAV_OS1_018_067
# shape331   Line   MAL_OS1_313       MAV_OS1_018_106
# shape559   Line   MAL_OS1_313       MAV_OS1_018_067~MAV_OS1_018_006~MAV_OS1_018_106 MAV_OS1_018_107~MAV_OS1_018_009
# shape332   Line   MAL_OS1_313       MAV_OS1_018_107
# shape578   Line   MAL_OS1_313       MAV_OS1_018_009
# shape307   Line   MAL_OS1_376       MAV_OS1_018_067
# shape317   Line   MAL_OS1_376       MAV_OS1_013_012
# shape579   Line   MAL_OS1_376       MAV_OS1_014_004
# shape333   Line   MAL_OS1_376       MAV_OS1_014_004
# shape335   Line   MAL_OS1_7279
# shape534   Line   MAL_OS1_7280      MAV_OS1_013_014
# shape226   Line   MAL_OS1_7280      MAV_OS1_013_014
# shape536   Line   MAL_OS1_7280      MAV_OS1_013_015
# shape336   Line   MAL_OS1_7280      MAV_OS1_013_013
# shape337   Line   MAL_OS1_7280      UN2400_WAXY
# shape659   Line   MAL_OS1_483       MAV_OS1_021_047
# shape661   Line   MAL_OS1_483       MAV_OS1_021_047
# shape580   Line   MAL_OS1_483       MAV_OS1_024_031
# shape262   Line   MAL_OS1_483       MAV_OS1_024_031
# shape271   Line   MAL_OS1_483       MAV_OS1_062_004~MAV_OS1_024_031
# shape116   Line   MAL_OS1_491       MAV_OS1_062_013
# shape341   Line   MAL_OS1_491       MAV_OS1_022_068
# shape584   Line   MAL_OS1_2426      MAV_OS1_022_061
# shape643   Line   MAL_OS1_2426      MAV_OS1_022_065
# shape644   Line   MAL_OS1_2426      MAV_OS1_022_066
# shape645   Line   MAL_OS1_2426      MAV_OS1_022_067
# shape646   Line   MAL_OS1_2426      MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067
# shape647   Line   MAL_OS1_2426      MAV_OS1_022_065~MAV_OS1_022_066
# shape648   Line   MAL_OS1_2426      MAV_OS1_022_065
# shape668   Line   MAL_OS1_2426      MAV_OS1_022_063
# shape619   Line   MAL_OS1_368       MAV_OS1_018_011
# shape292   Line   MAL_OS1_314       MAV_OS1_018_108
# shape293   Line   MAL_OS1_314       MAV_OS1_018_110
# shape587   Line   MAL_OS1_314       MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108~MAV_OS1_018_110 MAV_OS1_018_111~MAV_OS1_018_008
# shape297   Line   MAL_OS1_314       MAV_OS1_018_111
# shape311   Line   MAL_OS1_323       MAV_OS1_018_109
# shape347   Line   MAL_OS1_321       MAV_OS1_018_108
# shape348   Line   MAL_OS1_326       MAV_OS1_018_110
# shape349   Line   MAL_OS1_327       PSP5383L
# shape588   Line   MAL_OS1_314       MAV_OS1_018_008
# shape617   Line   MAL_OS1_323       MAV_OS1_018_134~MAV_OS1_018_116          MAV_OS1_018_072~MAV_OS1_018_109
# shape622   Line   MAL_OS1_323       MAV_OS1_018_134~MAV_OS1_018_116          MAV_OS1_018_072~MAV_OS1_018_109
# shape637   Line   MAL_OS1_323       MAV_OS1_018_134~MAV_OS1_018_116          MAV_OS1_018_072~MAV_OS1_018_109
# shape350   Line   MAL_OS1_323       MAV_OS1_018_072
# shape638   Line   MAL_OS1_323       MAV_OS1_018_134~MAV_OS1_018_116          MAV_OS1_018_072~MAV_OS1_018_109
# shape655   Line   MAL_OS1_321       MAV_OS1_018_117                          MAV010
# shape352   Line   MAL_OS1_321       MAV_OS1_018_071
# shape672   Line   MAL_OS1_321       MAV_OS1_018_117                          MAV010
# shape673   Line   MAL_OS1_321       MAV_OS1_018_117                          MAV010
# shape674   Line   MAL_OS1_326       MAV_OS1_018_141~MAV_OS1_018_115
# shape675   Line   MAL_OS1_326       MAV_OS1_018_141~MAV_OS1_018_115
# shape676   Line   MAL_OS1_327       MAV005~MAV004                            MAV010
# shape353   Line   MAL_OS1_326       MAV_OS1_018_074
# shape354   Line   MAL_OS1_327       PSP5383L
# shape677   Line   MAL_OS1_220       MAV005~MAV004                            MAV010
# shape355   Line   MAL_OS1_220       PSP5383L
# shape678   Line   MAL_OS1_230       MAV005~MAV004                            MAV010
# shape356   Line   MAL_OS1_230       PSP5383L
# shape679   Line   MAL_OS1_246       MAV005~MAV004                            MAV010
# shape357   Line   MAL_OS1_246       PSP5383L
# shape589   Line   MAL_OS1_368       MAV005~MAV004                            MAV010
# shape358   Line   MAL_OS1_327       MAV_OS1_018_114
# shape359   Line   MAL_OS1_368       MAV_OS1_018_114
# shape360   Line   MAL_OS1_326       MAV_OS1_018_115
# shape361   Line   MAL_OS1_368       MAV_OS1_018_115
# shape362   Line   MAL_OS1_321       MAV_OS1_018_117
# shape363   Line   MAL_OS1_368       MAV_OS1_018_117
# shape364   Line   MAL_OS1_323       MAV_OS1_018_116
# shape365   Line   MAL_OS1_368       MAV_OS1_018_116
# shape590   Line   MAL_OS1_368       MAV005~MAV004                            MAV010
# shape591   Line   MAL_OS1_368       MAV_OS1_018_116                          MAV010
# shape366   Line   MAL_OS1_326       MAV_OS1_018_115
# shape367   Line   MAL_OS1_321       MAV_OS1_018_117
# shape368   Line   MAL_OS1_321       MAV_OS1_018_117
# shape369   Line   MAL_OS1_323       MAV_OS1_018_116
# shape370   Line   MAL_OS1_323       MAV_OS1_018_116
# shape372   Line   MAL_OS1_323       MAV_OS1_018_116
# shape680   Line   MAL_OS1_312       MAV_OS1_018_130
# shape373   Line   MAL_OS1_327       MAV_OS1_018_130
# shape374   Line   MAL_OS1_312       MAV_OS1_018_130
# shape375   Line   MAL_OS1_326       MAV_OS1_018_141
# shape376   Line   MAL_OS1_323       MAV_OS1_018_134
# shape682   Line   MAL_OS1_325       MAV_OS1_018_011
# shape377   Line   MAL_OS1_325       MAV_OS1_018_013
# shape378   Line   MAL_OS1_325       MAV_OS1_018_100
# shape379   Line   MAL_OS1_325       MAV_OS1_018_172
# shape683   Line   MAL_OS1_325       MAV_OS1_018_013~MAV_OS1_018_011          MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100
# shape684   Line   MAL_OS1_325       MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100 MAV_OS1_022_064~MAV_OS1_018_172
# shape380   Line   MAL_OS1_2427      PSP5383L
# shape686   Line   MAL_OS1_325       MAV_OS1_022_064
# shape382   Line   MAL_OS1_325       MAV_OS1_018_013~MAV_OS1_018_011          MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100
# shape692   Line   MAL_OS1_491       MAV_OS1_022_068
# shape693   Line   MAL_OS1_491       MAV_OS1_022_068                          MAV010
# shape383   Line   MAL_OS1_220       PSP5383L
# shape695   Line   MAL_OS1_2430
# shape697   Line   MAL_OS1_2430
# shape698   Line   MAL_OS1_483       MAV_OS1_022_069
# shape699   Line   MAL_OS1_483       MAV_OS1_022_069
# shape592   Line   MAL_OS1_2424      MAV_OS1_022_162                          MAV010
# shape384   Line   MAL_OS1_2424      MAV_OS1_022_162
# shape402   Line   MAL_OS1_2424      MAV_OS1_022_059
# shape275   Line   MAL_OS1_312       MAV_OS1_018_065
# 200

# %%
# valve
countvalve = 0
for i in total:
    if 'Value?ShapeID' in total[i] and total[i]['Value?ShapeID'] == 'ValveMan':
        print('{:10} {:12} {:17}'.format(i, total[i]['Value?ShapeID'], total[i]['Point?element']))
        countvalve += 1
print(countvalve)
# Out:
# shape414   ValveMan     MAV_OS1_054_002
# shape415   ValveMan     MAV_OS1_054_017
# shape416   ValveMan     MAV_OS1_054_021
# shape417   ValveMan     MAV_OS1_054_026
# shape418   ValveMan     MAV_OS1_053_027
# shape421   ValveMan     MAV_OS1_062_004
# shape423   ValveMan     MAV_OS1_059_006
# shape444   ValveMan     MAV_OS1_017_024
# shape447   ValveMan     MAV_OS1_018_104
# shape457   ValveMan     MAV_OS1_021_122
# shape458   ValveMan     MAV_OS1_021_117
# shape459   ValveMan     MAV_OS1_021_140
# shape462   ValveMan     MAV_OS1_018_007
# shape463   ValveMan     MAV_OS1_018_008
# shape506   ValveMan     MAV_OS1_022_062
# shape507   ValveMan     OMAVALVE
# shape508   ValveMan     MAV_OS1_022_073
# shape509   ValveMan     MAV_OS1_022_074
# shape510   ValveMan     MAV_OS1_022_061
# shape511   ValveMan     MAV_OS1_022_072
# shape512   ValveMan     MAV_OS1_022_033
# shape513   ValveMan     MAV_OS1_022_057
# shape514   ValveMan     MAV_OS1_022_060
# shape515   ValveMan     OMAVALVE
# shape516   ValveMan     MAV_OS1_022_059
# shape518   ValveMan     MAV_OS1_019_004
# shape519   ValveMan     MAV_OS1_014_003
# shape468   ValveMan     MAV_OS1_018_043
# shape469   ValveMan     OMAVALVE
# shape470   ValveMan     MAV_OS1_018_042
# shape471   ValveMan     OMAVALVE
# shape472   ValveMan     MAV_OS1_018_038
# shape473   ValveMan     MAV_OS1_018_136
# shape467   ValveMan     MAV_OS1_018_006
# shape476   ValveMan     MAV_OS1_018_009
# shape477   ValveMan     MAV_OS1_018_067
# shape527   ValveMan     MAV_OS1_018_106
# shape529   ValveMan     MAV_OS1_018_107
# shape479   ValveMan     MAV_OS1_014_004
# shape480   ValveMan     MAV_OS1_013_012
# shape481   ValveMan     MAV_OS1_013_013
# shape433   ValveMan     MAV_OS1_013_014
# shape442   ValveMan     MAV_OS1_013_015
# shape660   ValveMan     MAV_OS1_021_047
# shape455   ValveMan     MAV_OS1_024_031
# shape422   ValveMan     MAV_OS1_062_013
# shape640   ValveMan     MAV_OS1_022_068
# shape641   ValveMan     MAV_OS1_022_069
# shape642   ValveMan     MAV_OS1_022_067
# shape649   ValveMan     MAV_OS1_022_064
# shape650   ValveMan     MAV_OS1_022_063
# shape438   ValveMan     MAV_OS1_018_109
# shape439   ValveMan     MAV_OS1_018_108
# shape461   ValveMan     MAV_OS1_018_110
# shape464   ValveMan     MAV_OS1_018_111
# shape465   ValveMan     MAV_OS1_018_072
# shape475   ValveMan     MAV_OS1_018_071
# shape483   ValveMan     MAV_OS1_018_074
# shape484   ValveMan     MAV_OS1_018_075
# shape485   ValveMan     MAV_OS1_018_114
# shape486   ValveMan     MAV_OS1_018_115
# shape487   ValveMan     MAV_OS1_018_117
# shape488   ValveMan     MAV_OS1_018_116
# shape490   ValveMan     MAV_OS1_018_130
# shape491   ValveMan     MAV_OS1_018_141
# shape492   ValveMan     MAV_OS1_018_134
# shape681   ValveMan     MAV_OS1_018_011
# shape689   ValveMan     MAV_OS1_018_013
# shape690   ValveMan     MAV_OS1_018_100
# shape691   ValveMan     MAV_OS1_018_172
# shape493   ValveMan     MAV_OS1_018_073
# shape694   ValveMan     MAV_OS1_022_065
# shape696   ValveMan     MAV_OS1_022_066
# shape517   ValveMan     MAV_OS1_022_162
# shape494   ValveMan     MAV_OS1_018_065
# 75

# %%
main.find('div', attrs={'id':'shape442'})
# Out:
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Rotation:270;Width:30;" id="shape442" linktype="embedded" parameters="Point?element:MAV_OS1_013_015;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;" src=".\MA_CH_OS1_WAXY_files\TFGValveMAN_H.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 115px; LEFT: 1700px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Width:30;" id="shape442_group001" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="FillColor:#a0a0a0;fillColorBlink:False;HDXBINDINGID:205;Height:10;LineColor:#000000;lineColorBlink:False;ObjectType:10;points:100 0 93.75 0 50 50 100 100 50 50 6.25 0 0 0 0 100 ;PointTypes:m l l lx m l l lx ;Width:20;" id="shape442_plyValve" ondatachange="VBScript:Call OnDataChange(me.parentElement.parentElement, me)" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 66.66%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#polygon) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 16.66%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;GradientFillColor:#808080;Height:10;LineColor:#c0c0c0;lineColorBlink:False;LineStyle:0;LineWidth:2;Width:30;" id="shape442_recSelectBox" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div></div>

# %% [markdown]
# ## =====================================

# %%
print(len(divpm))
for i,div in enumerate(divpm):
    print('{:4} {:2} {:43}'.format(i,len(div), div['id']))
# Out:
# 337
#    0  2 shape385
#    1  2 shape554
#    2  2 shape001
#    3  2 tfgPlanningData
#    4  1 tfgSelectTimeout
#    5  2 tfgOperDataReInit
#    6  2 tfgOffDisplayEndPoints
#    7  2 shape015
#    8  2 shape027
#    9  2 shape414
#   10  2 shape273
#   11  2 shape050
#   12  2 shape050_shaTank
#   13  2 shape050_shaTankService
#   14  2 shape023
#   15  2 shape051
#   16  2 shape051_shaTank
#   17  2 shape051_shaTankService
#   18  2 shape024
#   19  2 shape052
#   20  2 shape052_shaTank
#   21  2 shape052_shaTankService
#   22  2 shape025
#   23  2 shape053
#   24  2 shape053_shaTank
#   25  2 shape053_shaTankService
#   26  2 shape028
#   27  2 shape054
#   28  2 shape054_shaTank
#   29  2 shape054_shaTankService
#   30  2 shape029
#   31  2 shape055
#   32  2 shape055_shaTank
#   33  2 shape055_shaTankService
#   34  2 shape030
#   35  2 shape056
#   36  2 shape056_shaTank
#   37  2 shape056_shaTankService
#   38  2 shape031
#   39  2 shape057
#   40  2 shape057_shaTank
#   41  2 shape057_shaTankService
#   42  2 shape032
#   43  2 shape104
#   44  2 shape108
#   45  2 shape109
#   46  2 shape110
#   47  2 shape111
#   48  2 shape112
#   49  2 shape115
#   50  2 shape272
#   51  2 shape310
#   52  2 shape792
#   53  2 shape033
#   54  2 shape793
#   55  2 shape392
#   56  2 shape794
#   57  2 shape415
#   58  2 shape416
#   59  2 shape417
#   60  2 shape418
#   61  2 shape421
#   62  2 shape423
#   63  2 shape223
#   64  2 shape232
#   65  2 shape240
#   66  2 shape444
#   67  2 shape250
#   68  2 shape254
#   69  2 shape255
#   70  2 shape447
#   71  2 shape266
#   72  2 shape269
#   73  2 shape274
#   74  2 shape457
#   75  2 shape551
#   76  2 shape276
#   77  2 shape458
#   78  2 shape552
#   79  2 shape277
#   80  2 shape459
#   81  2 shape278
#   82  2 shape279
#   83  2 shape281
#   84  2 shape462
#   85  2 shape282
#   86  2 shape463
#   87  2 shape283
#   88  2 shape284
#   89  2 shape289
#   90  2 shape553
#   91  2 shape301
#   92  2 shape506
#   93  2 shape303
#   94  2 shape563
#   95  2 shape304
#   96  2 shape507
#   97  2 shape305
#   98  2 shape564
#   99  2 shape314
#  100  2 shape315
#  101  2 shape508
#  102  2 shape329
#  103  2 shape565
#  104  2 shape509
#  105  2 shape330
#  106  2 shape334
#  107  2 shape566
#  108  2 shape510
#  109  2 shape371
#  110  2 shape511
#  111  2 shape568
#  112  2 shape393
#  113  2 shape512
#  114  2 shape569
#  115  2 shape394
#  116  2 shape513
#  117  2 shape570
#  118  2 shape395
#  119  2 shape514
#  120  2 shape396
#  121  2 shape571
#  122  2 shape397
#  123  2 shape515
#  124  2 shape398
#  125  2 shape577
#  126  2 shape399
#  127  2 shape400
#  128  2 shape401
#  129  2 shape516
#  130  2 shape404
#  131  2 shape608
#  132  2 shape405
#  133  2 shape406
#  134  2 shape609
#  135  2 shape518
#  136  2 shape407
#  137  2 shape408
#  138  2 shape610
#  139  2 shape519
#  140  2 shape409
#  141  2 shape410
#  142  2 shape523
#  143  2 shape627
#  144  2 shape651
#  145  2 shape308
#  146  2 shape309
#  147  2 shape312
#  148  2 shape468
#  149  2 shape313
#  150  2 shape316
#  151  2 shape469
#  152  2 shape572
#  153  2 shape318
#  154  2 shape319
#  155  2 shape573
#  156  2 shape320
#  157  2 shape321
#  158  2 shape574
#  159  2 shape470
#  160  2 shape322
#  161  2 shape323
#  162  2 shape324
#  163  2 shape471
#  164  2 shape575
#  165  2 shape325
#  166  2 shape326
#  167  2 shape576
#  168  2 shape327
#  169  2 shape328
#  170  2 shape472
#  171  2 shape473
#  172  2 shape390
#  173  2 shape391
#  174  2 shape607
#  175  2 shape035
#  176  2 shape286
#  177  2 shape467
#  178  2 shape287
#  179  2 shape476
#  180  2 shape288
#  181  2 shape302
#  182  2 shape558
#  183  2 shape306
#  184  2 shape477
#  185  2 shape527
#  186  2 shape331
#  187  2 shape559
#  188  2 shape529
#  189  2 shape332
#  190  2 shape578
#  191  2 shape307
#  192  2 shape317
#  193  2 shape579
#  194  2 shape333
#  195  2 shape479
#  196  2 shape480
#  197  2 shape335
#  198  2 shape481
#  199  2 shape534
#  200  2 shape226
#  201  2 shape433
#  202  2 shape536
#  203  2 shape442
#  204  2 shape336
#  205  2 shape337
#  206  2 shape659
#  207  2 shape660
#  208  2 shape661
#  209  2 shape580
#  210  2 shape262
#  211  2 shape455
#  212  2 shape271
#  213  2 shape116
#  214  2 shape422
#  215  2 shape341
#  216  2 shape584
#  217  2 shape640
#  218  2 shape641
#  219  2 shape642
#  220  2 shape643
#  221  2 shape644
#  222  2 shape645
#  223  2 shape646
#  224  2 shape647
#  225  2 shape648
#  226  2 shape649
#  227  2 shape668
#  228  2 PseudoValve039
#  229  2 PseudoValve040
#  230  2 PseudoValve041
#  231  2 PseudoValve042
#  232  2 PseudoValve043
#  233  2 PseudoValve044
#  234  2 PseudoValve045
#  235  2 PseudoValve046
#  236  2 PseudoValve047
#  237  2 PseudoValve048
#  238  2 PseudoValve049
#  239  2 PseudoValve050
#  240  2 shape619
#  241  2 shape650
#  242  2 shape438
#  243  2 shape292
#  244  2 shape439
#  245  2 shape293
#  246  2 shape461
#  247  2 shape587
#  248  2 shape297
#  249  2 shape464
#  250  2 shape311
#  251  2 shape347
#  252  2 shape348
#  253  2 shape349
#  254  2 shape588
#  255  2 shape465
#  256  2 shape617
#  257  2 shape622
#  258  2 shape637
#  259  2 shape350
#  260  2 shape475
#  261  2 shape483
#  262  2 shape484
#  263  2 shape638
#  264  2 shape655
#  265  2 shape352
#  266  2 shape672
#  267  2 shape673
#  268  2 shape674
#  269  2 shape675
#  270  2 shape676
#  271  2 shape353
#  272  2 shape354
#  273  2 shape677
#  274  2 shape355
#  275  2 shape678
#  276  2 shape356
#  277  2 shape679
#  278  2 shape357
#  279  2 shape589
#  280  2 shape358
#  281  2 shape485
#  282  2 shape359
#  283  2 shape360
#  284  2 shape486
#  285  2 shape361
#  286  2 shape362
#  287  2 shape487
#  288  2 shape363
#  289  2 shape364
#  290  2 shape488
#  291  2 shape365
#  292  2 shape590
#  293  2 shape591
#  294  2 shape366
#  295  2 shape367
#  296  2 shape368
#  297  2 shape369
#  298  2 shape370
#  299  2 shape372
#  300  2 shape680
#  301  2 shape373
#  302  2 shape490
#  303  2 shape374
#  304  2 shape375
#  305  2 shape491
#  306  2 shape376
#  307  2 shape492
#  308  2 shape681
#  309  2 shape682
#  310  2 shape377
#  311  2 shape378
#  312  2 shape379
#  313  2 shape683
#  314  2 shape684
#  315  2 shape380
#  316  2 shape686
#  317  2 shape689
#  318  2 shape690
#  319  2 shape691
#  320  2 shape382
#  321  2 shape692
#  322  2 shape693
#  323  2 shape383
#  324  2 shape493
#  325  2 shape694
#  326  2 shape695
#  327  2 shape696
#  328  2 shape697
#  329  2 shape698
#  330  2 shape699
#  331  2 shape592
#  332  2 shape517
#  333  2 shape384
#  334  2 shape402
#  335  2 shape494
#  336  2 shape275

# %%
divs[0]
# Out:
# <div class="hsc.shape.1" globalscripts="" hdxproperties="fillColorBlink:False;Height:10;lineColorBlink:False;Width:30;" id="shape385" linktype="embedded" parameters="Point?element:MAL_OS1_7280;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_013_014~MAV_OS1_013_013;Value?EndPoint2:;" src=".\MA_CH_OS1_WAXY_files\MALineH.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 80px; LEFT: 1685px" styleclass="" tabindex="-1" value="1">
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="fillColorBlink:False;HDXBINDINGID:207;Height:10;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:2;points:0 0 100 0 ;Width:30;" id="shape385_linPipe" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div>

# %%
divs[0].div
# Out:
# <div class="hvg.base.1 HSC.ScriptDataObject.1" hdxproperties="fillColorBlink:False;HDXBINDINGID:207;Height:10;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:2;points:0 0 100 0 ;Width:30;" id="shape385_linPipe" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 0%; LEFT: 0%" tabindex="-1"></div>

# %%
divs[0].div['class']
# Out:
# ['hvg.base.1', 'HSC.ScriptDataObject.1']

# %%
divs[0]['class']
# Out:
# ['hsc.shape.1']

# %%
divs[0]['parameters'].split(';')
# Out:
# ['Point?element:MAL_OS1_7280',
#  'Value?DefElemType:3',
#  'Value?ShapeID:Line',
#  'Value?DataBoundObj:linPipe',
#  'Value?EndPoint1:MAV_OS1_013_014~MAV_OS1_013_013',
#  'Value?EndPoint2:',
#  '']

# %%
divs[0]['parameters'].split(';')[0]
# Out:
# 'Point?element:MAL_OS1_7280'

# %%
divs[0]['id']
# Out:
# ['shape385']

# %%
divs[0]['style']
# Out:
# 'POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 80px; LEFT: 1685px'

# %%
count = 0
for i,div in enumerate(divs):
    if len(div) >= 25 :
        print(i,'---------',div['id'])
        #print(div)
        count += 1
print('number of 25:',count)
# Out:
# 43 --------- shape050_grpShape
# 78 --------- shape051_grpShape
# 113 --------- shape052_grpShape
# 148 --------- shape053_grpShape
# 183 --------- shape054_grpShape
# 218 --------- shape055_grpShape
# 253 --------- shape056_grpShape
# 288 --------- shape057_grpShape
# number of 25: 8

# %% [markdown]
# ## total

# %%
for div in divs:
    print(div['id'])
# Out:
# shape385
# shape385_linPipe
# shape554
# shape554_linPipe
# shape001
# shape001_TxtGSH
# picZoomIn
# picZoomOut
# tfgPlanningData
# tfgPlanningData_txtDataAcquisition
# tfgSelectTimeout
# tfgOperDataReInit
# tfgOperDataReInit_txtDataAcquisition
# tfgOffDisplayEndPoints
# tfgOffDisplayEndPoints_txtDataAcquisition
# textbox003
# shape015
# shape015_group001
# shape015_group002
# shape015_rect013
# shape015_polyline002
# shape015_textbox001
# shape015_textbox002
# shape015_textbox005
# shape015_textbox006
# shape027
# shape027_group001
# shape027_rect001
# shape027_textbox001
# shape414
# shape414_group001
# shape414_plyValve
# shape414_recSelectBox
# shape273
# shape273_group001
# shape273_plyPump
# shape273_linInlet
# shape273_linOutlet
# shape273_recMotor
# shape273_recSelectBox
# textbox032
# textbox121
# shape050
# shape050_grpShape
# shape050_shaTank
# shape050_shaTank_group001
# shape050_shaTank_oval1
# shape050_shaTank_roundrect6
# shape050_grpRoof
# shape050_line009
# shape050_line010
# shape050_line011
# shape050_line012
# shape050_txtElementName
# shape050_group002
# shape050_line001
# shape050_bezier002
# shape050_shaTankService
# shape050_shaTankService_grpOOService
# shape050_shaTankService_recOOS
# shape050_shaTankService_plyOOS1
# shape050_shaTankService_ovlOOS
# shape050_linNozzle
# shape050_recSelectBox
# shape050_textbox001
# shape050_textbox003
# shape050_textbox004
# shape023
# shape023_group004
# shape023_textbox001
# shape023_rect001
# shape023_group002
# shape023_TR
# shape023_LD
# shape023_UL
# shape023_RD
# shape023_CH
# shape051
# shape051_grpShape
# shape051_shaTank
# shape051_shaTank_group001
# shape051_shaTank_oval1
# shape051_shaTank_roundrect6
# shape051_grpRoof
# shape051_line009
# shape051_line010
# shape051_line011
# shape051_line012
# shape051_txtElementName
# shape051_group002
# shape051_line001
# shape051_bezier002
# shape051_shaTankService
# shape051_shaTankService_grpOOService
# shape051_shaTankService_recOOS
# shape051_shaTankService_plyOOS1
# shape051_shaTankService_ovlOOS
# shape051_linNozzle
# shape051_recSelectBox
# shape051_textbox001
# shape051_textbox003
# shape051_textbox004
# shape024
# shape024_group004
# shape024_textbox001
# shape024_rect001
# shape024_group002
# shape024_TR
# shape024_LD
# shape024_UL
# shape024_RD
# shape024_CH
# shape052
# shape052_grpShape
# shape052_shaTank
# shape052_shaTank_group001
# shape052_shaTank_oval1
# shape052_shaTank_roundrect6
# shape052_grpRoof
# shape052_line009
# shape052_line010
# shape052_line011
# shape052_line012
# shape052_txtElementName
# shape052_group002
# shape052_line001
# shape052_bezier002
# shape052_shaTankService
# shape052_shaTankService_grpOOService
# shape052_shaTankService_recOOS
# shape052_shaTankService_plyOOS1
# shape052_shaTankService_ovlOOS
# shape052_linNozzle
# shape052_recSelectBox
# shape052_textbox001
# shape052_textbox003
# shape052_textbox004
# shape025
# shape025_group004
# shape025_textbox001
# shape025_rect001
# shape025_group002
# shape025_TR
# shape025_LD
# shape025_UL
# shape025_RD
# shape025_CH
# shape053
# shape053_grpShape
# shape053_shaTank
# shape053_shaTank_group001
# shape053_shaTank_oval1
# shape053_shaTank_roundrect6
# shape053_grpRoof
# shape053_line009
# shape053_line010
# shape053_line011
# shape053_line012
# shape053_txtElementName
# shape053_group002
# shape053_line001
# shape053_bezier002
# shape053_shaTankService
# shape053_shaTankService_grpOOService
# shape053_shaTankService_recOOS
# shape053_shaTankService_plyOOS1
# shape053_shaTankService_ovlOOS
# shape053_linNozzle
# shape053_recSelectBox
# shape053_textbox001
# shape053_textbox003
# shape053_textbox004
# shape028
# shape028_group004
# shape028_textbox001
# shape028_rect001
# shape028_group002
# shape028_TR
# shape028_LD
# shape028_UL
# shape028_RD
# shape028_CH
# shape054
# shape054_grpShape
# shape054_shaTank
# shape054_shaTank_group001
# shape054_shaTank_oval1
# shape054_shaTank_roundrect6
# shape054_grpRoof
# shape054_line009
# shape054_line010
# shape054_line011
# shape054_line012
# shape054_txtElementName
# shape054_group002
# shape054_line001
# shape054_bezier002
# shape054_shaTankService
# shape054_shaTankService_grpOOService
# shape054_shaTankService_recOOS
# shape054_shaTankService_plyOOS1
# shape054_shaTankService_ovlOOS
# shape054_linNozzle
# shape054_recSelectBox
# shape054_textbox001
# shape054_textbox003
# shape054_textbox004
# shape029
# shape029_group004
# shape029_textbox001
# shape029_rect001
# shape029_group002
# shape029_TR
# shape029_LD
# shape029_UL
# shape029_RD
# shape029_CH
# shape055
# shape055_grpShape
# shape055_shaTank
# shape055_shaTank_group001
# shape055_shaTank_oval1
# shape055_shaTank_roundrect6
# shape055_grpRoof
# shape055_line009
# shape055_line010
# shape055_line011
# shape055_line012
# shape055_txtElementName
# shape055_group002
# shape055_line001
# shape055_bezier002
# shape055_shaTankService
# shape055_shaTankService_grpOOService
# shape055_shaTankService_recOOS
# shape055_shaTankService_plyOOS1
# shape055_shaTankService_ovlOOS
# shape055_linNozzle
# shape055_recSelectBox
# shape055_textbox001
# shape055_textbox003
# shape055_textbox004
# shape030
# shape030_group004
# shape030_textbox001
# shape030_rect001
# shape030_group002
# shape030_TR
# shape030_LD
# shape030_UL
# shape030_RD
# shape030_CH
# shape056
# shape056_grpShape
# shape056_shaTank
# shape056_shaTank_group001
# shape056_shaTank_oval1
# shape056_shaTank_roundrect6
# shape056_grpRoof
# shape056_line009
# shape056_line010
# shape056_line011
# shape056_line012
# shape056_txtElementName
# shape056_group002
# shape056_line001
# shape056_bezier002
# shape056_shaTankService
# shape056_shaTankService_grpOOService
# shape056_shaTankService_recOOS
# shape056_shaTankService_plyOOS1
# shape056_shaTankService_ovlOOS
# shape056_linNozzle
# shape056_recSelectBox
# shape056_textbox001
# shape056_textbox003
# shape056_textbox004
# shape031
# shape031_group004
# shape031_textbox001
# shape031_rect001
# shape031_group002
# shape031_TR
# shape031_LD
# shape031_UL
# shape031_RD
# shape031_CH
# shape057
# shape057_grpShape
# shape057_shaTank
# shape057_shaTank_group001
# shape057_shaTank_oval1
# shape057_shaTank_roundrect6
# shape057_grpRoof
# shape057_line009
# shape057_line010
# shape057_line011
# shape057_line012
# shape057_txtElementName
# shape057_group002
# shape057_line001
# shape057_bezier002
# shape057_shaTankService
# shape057_shaTankService_grpOOService
# shape057_shaTankService_recOOS
# shape057_shaTankService_plyOOS1
# shape057_shaTankService_ovlOOS
# shape057_linNozzle
# shape057_recSelectBox
# shape057_textbox001
# shape057_textbox003
# shape057_textbox004
# shape032
# shape032_group004
# shape032_textbox001
# shape032_rect001
# shape032_group002
# shape032_TR
# shape032_LD
# shape032_UL
# shape032_RD
# shape032_CH
# shape104
# shape104_linPipe
# shape108
# shape108_linPipe
# shape109
# shape109_linPipe
# shape110
# shape110_linPipe
# shape111
# shape111_linPipe
# shape112
# shape112_linPipe
# shape115
# shape115_linPipe
# shape272
# shape272_group001
# shape272_plyPump
# shape272_linInlet
# shape272_linOutlet
# shape272_recMotor
# shape272_recSelectBox
# textbox031
# shape310
# shape310_linPipe
# shape792
# shape792_grpShape
# shape792_plyBPArrow
# shape792_recSelectBox
# shape033
# shape033_group001
# shape033_rect001
# shape033_textbox001
# shape793
# shape793_grpShape
# shape793_plyBPArrow
# shape793_recSelectBox
# shape392
# shape392_linPipe
# shape794
# shape794_grpShape
# shape794_plyBPArrow
# shape794_recSelectBox
# shape415
# shape415_group001
# shape415_plyValve
# shape415_recSelectBox
# textbox122
# shape416
# shape416_group001
# shape416_plyValve
# shape416_recSelectBox
# shape417
# shape417_group001
# shape417_plyValve
# shape417_recSelectBox
# shape418
# shape418_group001
# shape418_plyValve
# shape418_recSelectBox
# shape421
# shape421_group001
# shape421_plyValve
# shape421_recSelectBox
# shape423
# shape423_group001
# shape423_plyValve
# shape423_recSelectBox
# shape223
# shape223_linPipe
# shape232
# shape232_linPipe
# shape240
# shape240_linPipe
# shape444
# shape444_group001
# shape444_plyValve
# shape444_recSelectBox
# shape250
# shape250_linPipe
# shape254
# shape254_linPipe
# shape255
# shape255_linPipe
# shape447
# shape447_group001
# shape447_plyValve
# shape447_recSelectBox
# shape266
# shape266_linPipe
# shape269
# shape269_linPipe
# shape274
# shape274_linPipe
# shape457
# shape457_group001
# shape457_plyValve
# shape457_recSelectBox
# shape551
# shape551_linPipe
# shape276
# shape276_linPipe
# shape458
# shape458_group001
# shape458_plyValve
# shape458_recSelectBox
# shape552
# shape552_linPipe
# shape277
# shape277_linPipe
# shape459
# shape459_group001
# shape459_plyValve
# shape459_recSelectBox
# shape278
# shape278_group001
# shape278_plyPump
# shape278_linInlet
# shape278_linOutlet
# shape278_recMotor
# shape278_recSelectBox
# textbox037
# shape279
# shape279_group001
# shape279_plyPump
# shape279_linInlet
# shape279_linOutlet
# shape279_recMotor
# shape279_recSelectBox
# textbox038
# shape281
# shape281_linPipe
# shape462
# shape462_group001
# shape462_plyValve
# shape462_recSelectBox
# shape282
# shape282_linPipe
# shape463
# shape463_group001
# shape463_plyValve
# shape463_recSelectBox
# shape283
# shape283_linPipe
# shape284
# shape284_linPipe
# shape289
# shape289_linPipe
# shape553
# shape553_linPipe
# shape301
# shape301_linPipe
# shape506
# shape506_group001
# shape506_plyValve
# shape506_recSelectBox
# shape303
# shape303_linPipe
# shape563
# shape563_linPipe
# shape304
# shape304_linPipe
# shape507
# shape507_group001
# shape507_plyValve
# shape507_recSelectBox
# shape305
# shape305_linPipe
# shape564
# shape564_linPipe
# shape314
# shape314_linPipe
# shape315
# shape315_linPipe
# shape508
# shape508_group001
# shape508_plyValve
# shape508_recSelectBox
# shape329
# shape329_linPipe
# shape565
# shape565_linPipe
# shape509
# shape509_group001
# shape509_plyValve
# shape509_recSelectBox
# shape330
# shape330_linPipe
# shape334
# shape334_linPipe
# shape566
# shape566_linPipe
# shape510
# shape510_group001
# shape510_plyValve
# shape510_recSelectBox
# shape371
# shape371_linPipe
# shape511
# shape511_group001
# shape511_plyValve
# shape511_recSelectBox
# shape568
# shape568_linPipe
# shape393
# shape393_linPipe
# shape512
# shape512_group001
# shape512_plyValve
# shape512_recSelectBox
# shape569
# shape569_linPipe
# shape394
# shape394_linPipe
# shape513
# shape513_group001
# shape513_plyValve
# shape513_recSelectBox
# shape570
# shape570_linPipe
# shape395
# shape395_linPipe
# shape514
# shape514_group001
# shape514_plyValve
# shape514_recSelectBox
# shape396
# shape396_linPipe
# shape571
# shape571_linPipe
# shape397
# shape397_linPipe
# shape515
# shape515_group001
# shape515_plyValve
# shape515_recSelectBox
# shape398
# shape398_linPipe
# shape577
# shape577_linPipe
# shape399
# shape399_linPipe
# shape400
# shape400_linPipe
# shape401
# shape401_linPipe
# shape516
# shape516_group001
# shape516_plyValve
# shape516_recSelectBox
# shape404
# shape404_linPipe
# shape608
# shape608_linPipe
# shape405
# shape405_linPipe
# shape406
# shape406_linPipe
# shape609
# shape609_linPipe
# shape518
# shape518_group001
# shape518_plyValve
# shape518_recSelectBox
# shape407
# shape407_linPipe
# shape408
# shape408_linPipe
# shape610
# shape610_linPipe
# shape519
# shape519_group001
# shape519_plyValve
# shape519_recSelectBox
# shape409
# shape409_linPipe
# shape410
# shape410_linPipe
# shape523
# shape523_linPipe
# shape627
# shape627_linPipe
# shape651
# shape651_linPipe
# shape308
# shape308_group001
# shape308_plyPump
# shape308_linInlet
# shape308_linOutlet
# shape308_recMotor
# shape308_recSelectBox
# textbox035
# shape309
# shape309_group001
# shape309_plyPump
# shape309_linInlet
# shape309_linOutlet
# shape309_recMotor
# shape309_recSelectBox
# textbox036
# shape312
# shape312_linPipe
# shape468
# shape468_group001
# shape468_plyValve
# shape468_recSelectBox
# shape313
# shape313_linPipe
# shape316
# shape316_linPipe
# shape469
# shape469_group001
# shape469_plyValve
# shape469_recSelectBox
# shape572
# shape572_linPipe
# shape318
# shape318_linPipe
# shape319
# shape319_linPipe
# shape573
# shape573_linPipe
# shape320
# shape320_linPipe
# shape321
# shape321_linPipe
# shape574
# shape574_linPipe
# shape470
# shape470_group001
# shape470_plyValve
# shape470_recSelectBox
# shape322
# shape322_linPipe
# shape323
# shape323_linPipe
# shape324
# shape324_linPipe
# shape471
# shape471_group001
# shape471_plyValve
# shape471_recSelectBox
# shape575
# shape575_linPipe
# shape325
# shape325_linPipe
# shape326
# shape326_linPipe
# shape576
# shape576_linPipe
# shape327
# shape327_linPipe
# shape328
# shape328_linPipe
# shape472
# shape472_group001
# shape472_plyValve
# shape472_recSelectBox
# textbox154
# shape473
# shape473_group001
# shape473_plyValve
# shape473_recSelectBox
# textbox155
# shape390
# shape390_linPipe
# shape391
# shape391_linPipe
# shape607
# shape607_linPipe
# textbox156
# shape035
# shape035_group001
# shape035_rect001
# shape035_textbox001
# shape286
# shape286_linPipe
# shape467
# shape467_group001
# shape467_plyValve
# shape467_recSelectBox
# shape287
# shape287_linPipe
# shape476
# shape476_group001
# shape476_plyValve
# shape476_recSelectBox
# shape288
# shape288_linPipe
# shape302
# shape302_linPipe
# shape558
# shape558_linPipe
# shape306
# shape306_linPipe
# shape477
# shape477_group001
# shape477_plyValve
# shape477_recSelectBox
# shape527
# shape527_group001
# shape527_plyValve
# shape527_recSelectBox
# shape331
# shape331_linPipe
# shape559
# shape559_linPipe
# shape529
# shape529_group001
# shape529_plyValve
# shape529_recSelectBox
# shape332
# shape332_linPipe
# shape578
# shape578_linPipe
# shape307
# shape307_linPipe
# shape317
# shape317_linPipe
# shape579
# shape579_linPipe
# shape333
# shape333_linPipe
# shape479
# shape479_group001
# shape479_plyValve
# shape479_recSelectBox
# shape480
# shape480_group001
# shape480_plyValve
# shape480_recSelectBox
# shape335
# shape335_linPipe
# shape481
# shape481_group001
# shape481_plyValve
# shape481_recSelectBox
# shape534
# shape534_linPipe
# shape226
# shape226_linPipe
# shape433
# shape433_group001
# shape433_plyValve
# shape433_recSelectBox
# shape536
# shape536_linPipe
# shape442
# shape442_group001
# shape442_plyValve
# shape442_recSelectBox
# textbox126
# textbox127
# shape336
# shape336_linPipe
# shape337
# shape337_linPipe
# textbox039
# shape659
# shape659_linPipe
# shape660
# shape660_group001
# shape660_plyValve
# shape660_recSelectBox
# shape661
# shape661_linPipe
# shape580
# shape580_linPipe
# shape262
# shape262_linPipe
# shape455
# shape455_group001
# shape455_plyValve
# shape455_recSelectBox
# shape271
# shape271_linPipe
# shape116
# shape116_linPipe
# shape422
# shape422_group001
# shape422_plyValve
# shape422_recSelectBox
# shape341
# shape341_linPipe
# rect146
# rect148
# rect149
# rect159
# rect160
# rect161
# rect162
# rect168
# rect183
# rect195
# rect196
# rect198
# rect199
# rect200
# rect163
# rect164
# rect165
# rect166
# rect167
# rect194
# rect155
# rect169
# rect170
# rect171
# rect132
# rect133
# rect206
# rect147
# shape584
# shape584_linPipe
# shape640
# shape640_group001
# shape640_plyValve
# shape640_recSelectBox
# shape641
# shape641_group001
# shape641_plyValve
# shape641_recSelectBox
# shape642
# shape642_group001
# shape642_plyValve
# shape642_recSelectBox
# shape643
# shape643_linPipe
# shape644
# shape644_linPipe
# shape645
# shape645_linPipe
# shape646
# shape646_linPipe
# shape647
# shape647_linPipe
# shape648
# shape648_linPipe
# shape649
# shape649_group001
# shape649_plyValve
# shape649_recSelectBox
# shape668
# shape668_linPipe
# rect209
# rect210
# rect211
# PseudoValve039
# PseudoValve039_grpShape
# PseudoValve039_ovlValve
# PseudoValve039_recSelectBox
# PseudoValve040
# PseudoValve040_grpShape
# PseudoValve040_ovlValve
# PseudoValve040_recSelectBox
# PseudoValve041
# PseudoValve041_grpShape
# PseudoValve041_ovlValve
# PseudoValve041_recSelectBox
# PseudoValve042
# PseudoValve042_grpShape
# PseudoValve042_ovlValve
# PseudoValve042_recSelectBox
# PseudoValve043
# PseudoValve043_grpShape
# PseudoValve043_ovlValve
# PseudoValve043_recSelectBox
# PseudoValve044
# PseudoValve044_grpShape
# PseudoValve044_ovlValve
# PseudoValve044_recSelectBox
# PseudoValve045
# PseudoValve045_grpShape
# PseudoValve045_ovlValve
# PseudoValve045_recSelectBox
# PseudoValve046
# PseudoValve046_grpShape
# PseudoValve046_ovlValve
# PseudoValve046_recSelectBox
# PseudoValve047
# PseudoValve047_grpShape
# PseudoValve047_ovlValve
# PseudoValve047_recSelectBox
# PseudoValve048
# PseudoValve048_grpShape
# PseudoValve048_ovlValve
# PseudoValve048_recSelectBox
# PseudoValve049
# PseudoValve049_grpShape
# PseudoValve049_ovlValve
# PseudoValve049_recSelectBox
# PseudoValve050
# PseudoValve050_grpShape
# PseudoValve050_ovlValve
# PseudoValve050_recSelectBox
# shape619
# shape619_linPipe
# shape650
# shape650_group001
# shape650_plyValve
# shape650_recSelectBox
# shape438
# shape438_group001
# shape438_plyValve
# shape438_recSelectBox
# shape292
# shape292_linPipe
# rect153
# shape439
# shape439_group001
# shape439_plyValve
# shape439_recSelectBox
# shape293
# shape293_linPipe
# shape461
# shape461_group001
# shape461_plyValve
# shape461_recSelectBox
# shape587
# shape587_linPipe
# shape297
# shape297_linPipe
# shape464
# shape464_group001
# shape464_plyValve
# shape464_recSelectBox
# shape311
# shape311_linPipe
# shape347
# shape347_linPipe
# shape348
# shape348_linPipe
# shape349
# shape349_linPipe
# shape588
# shape588_linPipe
# shape465
# shape465_group001
# shape465_plyValve
# shape465_recSelectBox
# shape617
# shape617_linPipe
# shape622
# shape622_linPipe
# shape637
# shape637_linPipe
# shape350
# shape350_linPipe
# shape475
# shape475_group001
# shape475_plyValve
# shape475_recSelectBox
# shape483
# shape483_group001
# shape483_plyValve
# shape483_recSelectBox
# shape484
# shape484_group001
# shape484_plyValve
# shape484_recSelectBox
# shape638
# shape638_linPipe
# shape655
# shape655_linPipe
# shape352
# shape352_linPipe
# shape672
# shape672_linPipe
# shape673
# shape673_linPipe
# shape674
# shape674_linPipe
# shape675
# shape675_linPipe
# shape676
# shape676_linPipe
# shape353
# shape353_linPipe
# shape354
# shape354_linPipe
# shape677
# shape677_linPipe
# shape355
# shape355_linPipe
# shape678
# shape678_linPipe
# shape356
# shape356_linPipe
# shape679
# shape679_linPipe
# shape357
# shape357_linPipe
# rect156
# shape589
# shape589_linPipe
# shape358
# shape358_linPipe
# shape485
# shape485_group001
# shape485_plyValve
# shape485_recSelectBox
# shape359
# shape359_linPipe
# shape360
# shape360_linPipe
# shape486
# shape486_group001
# shape486_plyValve
# shape486_recSelectBox
# shape361
# shape361_linPipe
# shape362
# shape362_linPipe
# shape487
# shape487_group001
# shape487_plyValve
# shape487_recSelectBox
# shape363
# shape363_linPipe
# shape364
# shape364_linPipe
# shape488
# shape488_group001
# shape488_plyValve
# shape488_recSelectBox
# shape365
# shape365_linPipe
# shape590
# shape590_linPipe
# shape591
# shape591_linPipe
# shape366
# shape366_linPipe
# shape367
# shape367_linPipe
# shape368
# shape368_linPipe
# shape369
# shape369_linPipe
# shape370
# shape370_linPipe
# shape372
# shape372_linPipe
# shape680
# shape680_linPipe
# shape373
# shape373_linPipe
# shape490
# shape490_group001
# shape490_plyValve
# shape490_recSelectBox
# shape374
# shape374_linPipe
# shape375
# shape375_linPipe
# shape491
# shape491_group001
# shape491_plyValve
# shape491_recSelectBox
# shape376
# shape376_linPipe
# shape492
# shape492_group001
# shape492_plyValve
# shape492_recSelectBox
# shape681
# shape681_group001
# shape681_plyValve
# shape681_recSelectBox
# shape682
# shape682_linPipe
# shape377
# shape377_linPipe
# shape378
# shape378_linPipe
# shape379
# shape379_linPipe
# shape683
# shape683_linPipe
# shape684
# shape684_linPipe
# shape380
# shape380_linPipe
# shape686
# shape686_linPipe
# shape689
# shape689_group001
# shape689_plyValve
# shape689_recSelectBox
# shape690
# shape690_group001
# shape690_plyValve
# shape690_recSelectBox
# shape691
# shape691_group001
# shape691_plyValve
# shape691_recSelectBox
# rect175
# rect176
# rect177
# rect178
# rect179
# rect180
# rect181
# rect182
# rect184
# rect186
# shape382
# shape382_linPipe
# shape692
# shape692_linPipe
# shape693
# shape693_linPipe
# rect185
# textbox130
# textbox131
# textbox135
# shape383
# shape383_linPipe
# shape493
# shape493_group001
# shape493_plyValve
# shape493_recSelectBox
# textbox033
# textbox034
# shape694
# shape694_group001
# shape694_plyValve
# shape694_recSelectBox
# shape695
# shape695_linPipe
# shape696
# shape696_group001
# shape696_plyValve
# shape696_recSelectBox
# shape697
# shape697_linPipe
# line001
# oval001
# textbox136
# shape698
# shape698_linPipe
# shape699
# shape699_linPipe
# shape592
# shape592_linPipe
# shape517
# shape517_group001
# shape517_plyValve
# shape517_recSelectBox
# shape384
# shape384_linPipe
# shape402
# shape402_linPipe
# shape494
# shape494_group001
# shape494_plyValve
# shape494_recSelectBox
# shape275
# shape275_linPipe
# textbox040
# textbox137

# %%
for i,div in enumerate(divs):
    print(i,div['id'], div['class'], len(div))
# Out:
# 0 shape385 ['hsc.shape.1'] 2
# 1 shape385_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 2 shape554 ['hsc.shape.1'] 2
# 3 shape554_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 4 shape001 ['hsc.shape.1'] 2
# 5 shape001_TxtGSH ['hvg.textbox.1'] 1
# 6 picZoomIn ['hsc.image.1'] 0
# 7 picZoomOut ['hsc.image.1'] 0
# 8 tfgPlanningData ['hsc.shape.1'] 2
# 9 tfgPlanningData_txtDataAcquisition ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 10 tfgSelectTimeout ['hsc.shape.1'] 1
# 11 tfgOperDataReInit ['hsc.shape.1'] 2
# 12 tfgOperDataReInit_txtDataAcquisition ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 13 tfgOffDisplayEndPoints ['hsc.shape.1'] 2
# 14 tfgOffDisplayEndPoints_txtDataAcquisition ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 15 textbox003 ['hvg.textbox.1'] 0
# 16 shape015 ['hsc.shape.1'] 2
# 17 shape015_group001 ['hvg.group.1'] 24
# 18 shape015_group002 ['hvg.group.1'] 4
# 19 shape015_rect013 ['hvg.base.1'] 0
# 20 shape015_polyline002 ['hvg.base.1'] 0
# 21 shape015_textbox001 ['hvg.textbox.1'] 1
# 22 shape015_textbox002 ['hvg.textbox.1'] 1
# 23 shape015_textbox005 ['hvg.textbox.1'] 1
# 24 shape015_textbox006 ['hvg.textbox.1'] 1
# 25 shape027 ['hsc.shape.1'] 2
# 26 shape027_group001 ['hvg.group.1'] 4
# 27 shape027_rect001 ['hvg.base.1'] 0
# 28 shape027_textbox001 ['hvg.textbox.1'] 1
# 29 shape414 ['hsc.shape.1'] 2
# 30 shape414_group001 ['hvg.group.1'] 4
# 31 shape414_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 32 shape414_recSelectBox ['hvg.base.1'] 0
# 33 shape273 ['hsc.shape.1'] 2
# 34 shape273_group001 ['hvg.group.1'] 10
# 35 shape273_plyPump ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 36 shape273_linInlet ['hvg.base.1'] 0
# 37 shape273_linOutlet ['hvg.base.1'] 0
# 38 shape273_recMotor ['hvg.base.1'] 0
# 39 shape273_recSelectBox ['hvg.base.1'] 0
# 40 textbox032 ['hvg.textbox.1'] 1
# 41 textbox121 ['hvg.textbox.1'] 1
# 42 shape050 ['hsc.shape.1'] 2
# 43 shape050_grpShape ['hvg.group.1'] 25
# 44 shape050_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] 2
# 45 shape050_shaTank_group001 ['hvg.group.1'] 4
# 46 shape050_shaTank_oval1 ['hvg.base.1'] 0
# 47 shape050_shaTank_roundrect6 ['hvg.base.1'] 0
# 48 shape050_grpRoof ['hvg.group.1'] 8
# 49 shape050_line009 ['hvg.base.1'] 0
# 50 shape050_line010 ['hvg.base.1'] 0
# 51 shape050_line011 ['hvg.base.1'] 0
# 52 shape050_line012 ['hvg.base.1'] 0
# 53 shape050_txtElementName ['hvg.textbox.1'] 1
# 54 shape050_group002 ['hvg.group.1'] 4
# 55 shape050_line001 ['hvg.base.1'] 0
# 56 shape050_bezier002 ['hvg.base.1'] 0
# 57 shape050_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] 2
# 58 shape050_shaTankService_grpOOService ['hvg.group.1'] 6
# 59 shape050_shaTankService_recOOS ['hvg.base.1'] 0
# 60 shape050_shaTankService_plyOOS1 ['hvg.base.1'] 0
# 61 shape050_shaTankService_ovlOOS ['hvg.base.1'] 0
# 62 shape050_linNozzle ['hvg.base.1'] 0
# 63 shape050_recSelectBox ['hvg.base.1'] 0
# 64 shape050_textbox001 ['hvg.textbox.1'] 1
# 65 shape050_textbox003 ['hvg.textbox.1'] 1
# 66 shape050_textbox004 ['hvg.textbox.1'] 1
# 67 shape023 ['hsc.shape.1'] 2
# 68 shape023_group004 ['hvg.group.1'] 6
# 69 shape023_textbox001 ['hvg.textbox.1'] 1
# 70 shape023_rect001 ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 71 shape023_group002 ['hvg.group.1'] 10
# 72 shape023_TR ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 73 shape023_LD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 74 shape023_UL ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 75 shape023_RD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 76 shape023_CH ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 77 shape051 ['hsc.shape.1'] 2
# 78 shape051_grpShape ['hvg.group.1'] 25
# 79 shape051_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] 2
# 80 shape051_shaTank_group001 ['hvg.group.1'] 4
# 81 shape051_shaTank_oval1 ['hvg.base.1'] 0
# 82 shape051_shaTank_roundrect6 ['hvg.base.1'] 0
# 83 shape051_grpRoof ['hvg.group.1'] 8
# 84 shape051_line009 ['hvg.base.1'] 0
# 85 shape051_line010 ['hvg.base.1'] 0
# 86 shape051_line011 ['hvg.base.1'] 0
# 87 shape051_line012 ['hvg.base.1'] 0
# 88 shape051_txtElementName ['hvg.textbox.1'] 1
# 89 shape051_group002 ['hvg.group.1'] 4
# 90 shape051_line001 ['hvg.base.1'] 0
# 91 shape051_bezier002 ['hvg.base.1'] 0
# 92 shape051_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] 2
# 93 shape051_shaTankService_grpOOService ['hvg.group.1'] 6
# 94 shape051_shaTankService_recOOS ['hvg.base.1'] 0
# 95 shape051_shaTankService_plyOOS1 ['hvg.base.1'] 0
# 96 shape051_shaTankService_ovlOOS ['hvg.base.1'] 0
# 97 shape051_linNozzle ['hvg.base.1'] 0
# 98 shape051_recSelectBox ['hvg.base.1'] 0
# 99 shape051_textbox001 ['hvg.textbox.1'] 1
# 100 shape051_textbox003 ['hvg.textbox.1'] 1
# 101 shape051_textbox004 ['hvg.textbox.1'] 1
# 102 shape024 ['hsc.shape.1'] 2
# 103 shape024_group004 ['hvg.group.1'] 6
# 104 shape024_textbox001 ['hvg.textbox.1'] 1
# 105 shape024_rect001 ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 106 shape024_group002 ['hvg.group.1'] 10
# 107 shape024_TR ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 108 shape024_LD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 109 shape024_UL ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 110 shape024_RD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 111 shape024_CH ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 112 shape052 ['hsc.shape.1'] 2
# 113 shape052_grpShape ['hvg.group.1'] 25
# 114 shape052_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] 2
# 115 shape052_shaTank_group001 ['hvg.group.1'] 4
# 116 shape052_shaTank_oval1 ['hvg.base.1'] 0
# 117 shape052_shaTank_roundrect6 ['hvg.base.1'] 0
# 118 shape052_grpRoof ['hvg.group.1'] 8
# 119 shape052_line009 ['hvg.base.1'] 0
# 120 shape052_line010 ['hvg.base.1'] 0
# 121 shape052_line011 ['hvg.base.1'] 0
# 122 shape052_line012 ['hvg.base.1'] 0
# 123 shape052_txtElementName ['hvg.textbox.1'] 1
# 124 shape052_group002 ['hvg.group.1'] 4
# 125 shape052_line001 ['hvg.base.1'] 0
# 126 shape052_bezier002 ['hvg.base.1'] 0
# 127 shape052_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] 2
# 128 shape052_shaTankService_grpOOService ['hvg.group.1'] 6
# 129 shape052_shaTankService_recOOS ['hvg.base.1'] 0
# 130 shape052_shaTankService_plyOOS1 ['hvg.base.1'] 0
# 131 shape052_shaTankService_ovlOOS ['hvg.base.1'] 0
# 132 shape052_linNozzle ['hvg.base.1'] 0
# 133 shape052_recSelectBox ['hvg.base.1'] 0
# 134 shape052_textbox001 ['hvg.textbox.1'] 1
# 135 shape052_textbox003 ['hvg.textbox.1'] 1
# 136 shape052_textbox004 ['hvg.textbox.1'] 1
# 137 shape025 ['hsc.shape.1'] 2
# 138 shape025_group004 ['hvg.group.1'] 6
# 139 shape025_textbox001 ['hvg.textbox.1'] 1
# 140 shape025_rect001 ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 141 shape025_group002 ['hvg.group.1'] 10
# 142 shape025_TR ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 143 shape025_LD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 144 shape025_UL ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 145 shape025_RD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 146 shape025_CH ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 147 shape053 ['hsc.shape.1'] 2
# 148 shape053_grpShape ['hvg.group.1'] 25
# 149 shape053_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] 2
# 150 shape053_shaTank_group001 ['hvg.group.1'] 4
# 151 shape053_shaTank_oval1 ['hvg.base.1'] 0
# 152 shape053_shaTank_roundrect6 ['hvg.base.1'] 0
# 153 shape053_grpRoof ['hvg.group.1'] 8
# 154 shape053_line009 ['hvg.base.1'] 0
# 155 shape053_line010 ['hvg.base.1'] 0
# 156 shape053_line011 ['hvg.base.1'] 0
# 157 shape053_line012 ['hvg.base.1'] 0
# 158 shape053_txtElementName ['hvg.textbox.1'] 1
# 159 shape053_group002 ['hvg.group.1'] 4
# 160 shape053_line001 ['hvg.base.1'] 0
# 161 shape053_bezier002 ['hvg.base.1'] 0
# 162 shape053_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] 2
# 163 shape053_shaTankService_grpOOService ['hvg.group.1'] 6
# 164 shape053_shaTankService_recOOS ['hvg.base.1'] 0
# 165 shape053_shaTankService_plyOOS1 ['hvg.base.1'] 0
# 166 shape053_shaTankService_ovlOOS ['hvg.base.1'] 0
# 167 shape053_linNozzle ['hvg.base.1'] 0
# 168 shape053_recSelectBox ['hvg.base.1'] 0
# 169 shape053_textbox001 ['hvg.textbox.1'] 1
# 170 shape053_textbox003 ['hvg.textbox.1'] 1
# 171 shape053_textbox004 ['hvg.textbox.1'] 1
# 172 shape028 ['hsc.shape.1'] 2
# 173 shape028_group004 ['hvg.group.1'] 6
# 174 shape028_textbox001 ['hvg.textbox.1'] 1
# 175 shape028_rect001 ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 176 shape028_group002 ['hvg.group.1'] 10
# 177 shape028_TR ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 178 shape028_LD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 179 shape028_UL ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 180 shape028_RD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 181 shape028_CH ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 182 shape054 ['hsc.shape.1'] 2
# 183 shape054_grpShape ['hvg.group.1'] 25
# 184 shape054_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] 2
# 185 shape054_shaTank_group001 ['hvg.group.1'] 4
# 186 shape054_shaTank_oval1 ['hvg.base.1'] 0
# 187 shape054_shaTank_roundrect6 ['hvg.base.1'] 0
# 188 shape054_grpRoof ['hvg.group.1'] 8
# 189 shape054_line009 ['hvg.base.1'] 0
# 190 shape054_line010 ['hvg.base.1'] 0
# 191 shape054_line011 ['hvg.base.1'] 0
# 192 shape054_line012 ['hvg.base.1'] 0
# 193 shape054_txtElementName ['hvg.textbox.1'] 1
# 194 shape054_group002 ['hvg.group.1'] 4
# 195 shape054_line001 ['hvg.base.1'] 0
# 196 shape054_bezier002 ['hvg.base.1'] 0
# 197 shape054_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] 2
# 198 shape054_shaTankService_grpOOService ['hvg.group.1'] 6
# 199 shape054_shaTankService_recOOS ['hvg.base.1'] 0
# 200 shape054_shaTankService_plyOOS1 ['hvg.base.1'] 0
# 201 shape054_shaTankService_ovlOOS ['hvg.base.1'] 0
# 202 shape054_linNozzle ['hvg.base.1'] 0
# 203 shape054_recSelectBox ['hvg.base.1'] 0
# 204 shape054_textbox001 ['hvg.textbox.1'] 1
# 205 shape054_textbox003 ['hvg.textbox.1'] 1
# 206 shape054_textbox004 ['hvg.textbox.1'] 1
# 207 shape029 ['hsc.shape.1'] 2
# 208 shape029_group004 ['hvg.group.1'] 6
# 209 shape029_textbox001 ['hvg.textbox.1'] 1
# 210 shape029_rect001 ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 211 shape029_group002 ['hvg.group.1'] 10
# 212 shape029_TR ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 213 shape029_LD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 214 shape029_UL ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 215 shape029_RD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 216 shape029_CH ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 217 shape055 ['hsc.shape.1'] 2
# 218 shape055_grpShape ['hvg.group.1'] 25
# 219 shape055_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] 2
# 220 shape055_shaTank_group001 ['hvg.group.1'] 4
# 221 shape055_shaTank_oval1 ['hvg.base.1'] 0
# 222 shape055_shaTank_roundrect6 ['hvg.base.1'] 0
# 223 shape055_grpRoof ['hvg.group.1'] 8
# 224 shape055_line009 ['hvg.base.1'] 0
# 225 shape055_line010 ['hvg.base.1'] 0
# 226 shape055_line011 ['hvg.base.1'] 0
# 227 shape055_line012 ['hvg.base.1'] 0
# 228 shape055_txtElementName ['hvg.textbox.1'] 1
# 229 shape055_group002 ['hvg.group.1'] 4
# 230 shape055_line001 ['hvg.base.1'] 0
# 231 shape055_bezier002 ['hvg.base.1'] 0
# 232 shape055_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] 2
# 233 shape055_shaTankService_grpOOService ['hvg.group.1'] 6
# 234 shape055_shaTankService_recOOS ['hvg.base.1'] 0
# 235 shape055_shaTankService_plyOOS1 ['hvg.base.1'] 0
# 236 shape055_shaTankService_ovlOOS ['hvg.base.1'] 0
# 237 shape055_linNozzle ['hvg.base.1'] 0
# 238 shape055_recSelectBox ['hvg.base.1'] 0
# 239 shape055_textbox001 ['hvg.textbox.1'] 1
# 240 shape055_textbox003 ['hvg.textbox.1'] 1
# 241 shape055_textbox004 ['hvg.textbox.1'] 1
# 242 shape030 ['hsc.shape.1'] 2
# 243 shape030_group004 ['hvg.group.1'] 6
# 244 shape030_textbox001 ['hvg.textbox.1'] 1
# 245 shape030_rect001 ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 246 shape030_group002 ['hvg.group.1'] 10
# 247 shape030_TR ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 248 shape030_LD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 249 shape030_UL ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 250 shape030_RD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 251 shape030_CH ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 252 shape056 ['hsc.shape.1'] 2
# 253 shape056_grpShape ['hvg.group.1'] 25
# 254 shape056_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] 2
# 255 shape056_shaTank_group001 ['hvg.group.1'] 4
# 256 shape056_shaTank_oval1 ['hvg.base.1'] 0
# 257 shape056_shaTank_roundrect6 ['hvg.base.1'] 0
# 258 shape056_grpRoof ['hvg.group.1'] 8
# 259 shape056_line009 ['hvg.base.1'] 0
# 260 shape056_line010 ['hvg.base.1'] 0
# 261 shape056_line011 ['hvg.base.1'] 0
# 262 shape056_line012 ['hvg.base.1'] 0
# 263 shape056_txtElementName ['hvg.textbox.1'] 1
# 264 shape056_group002 ['hvg.group.1'] 4
# 265 shape056_line001 ['hvg.base.1'] 0
# 266 shape056_bezier002 ['hvg.base.1'] 0
# 267 shape056_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] 2
# 268 shape056_shaTankService_grpOOService ['hvg.group.1'] 6
# 269 shape056_shaTankService_recOOS ['hvg.base.1'] 0
# 270 shape056_shaTankService_plyOOS1 ['hvg.base.1'] 0
# 271 shape056_shaTankService_ovlOOS ['hvg.base.1'] 0
# 272 shape056_linNozzle ['hvg.base.1'] 0
# 273 shape056_recSelectBox ['hvg.base.1'] 0
# 274 shape056_textbox001 ['hvg.textbox.1'] 1
# 275 shape056_textbox003 ['hvg.textbox.1'] 1
# 276 shape056_textbox004 ['hvg.textbox.1'] 1
# 277 shape031 ['hsc.shape.1'] 2
# 278 shape031_group004 ['hvg.group.1'] 6
# 279 shape031_textbox001 ['hvg.textbox.1'] 1
# 280 shape031_rect001 ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 281 shape031_group002 ['hvg.group.1'] 10
# 282 shape031_TR ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 283 shape031_LD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 284 shape031_UL ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 285 shape031_RD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 286 shape031_CH ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 287 shape057 ['hsc.shape.1'] 2
# 288 shape057_grpShape ['hvg.group.1'] 25
# 289 shape057_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] 2
# 290 shape057_shaTank_group001 ['hvg.group.1'] 4
# 291 shape057_shaTank_oval1 ['hvg.base.1'] 0
# 292 shape057_shaTank_roundrect6 ['hvg.base.1'] 0
# 293 shape057_grpRoof ['hvg.group.1'] 8
# 294 shape057_line009 ['hvg.base.1'] 0
# 295 shape057_line010 ['hvg.base.1'] 0
# 296 shape057_line011 ['hvg.base.1'] 0
# 297 shape057_line012 ['hvg.base.1'] 0
# 298 shape057_txtElementName ['hvg.textbox.1'] 1
# 299 shape057_group002 ['hvg.group.1'] 4
# 300 shape057_line001 ['hvg.base.1'] 0
# 301 shape057_bezier002 ['hvg.base.1'] 0
# 302 shape057_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] 2
# 303 shape057_shaTankService_grpOOService ['hvg.group.1'] 6
# 304 shape057_shaTankService_recOOS ['hvg.base.1'] 0
# 305 shape057_shaTankService_plyOOS1 ['hvg.base.1'] 0
# 306 shape057_shaTankService_ovlOOS ['hvg.base.1'] 0
# 307 shape057_linNozzle ['hvg.base.1'] 0
# 308 shape057_recSelectBox ['hvg.base.1'] 0
# 309 shape057_textbox001 ['hvg.textbox.1'] 1
# 310 shape057_textbox003 ['hvg.textbox.1'] 1
# 311 shape057_textbox004 ['hvg.textbox.1'] 1
# 312 shape032 ['hsc.shape.1'] 2
# 313 shape032_group004 ['hvg.group.1'] 6
# 314 shape032_textbox001 ['hvg.textbox.1'] 1
# 315 shape032_rect001 ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 316 shape032_group002 ['hvg.group.1'] 10
# 317 shape032_TR ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 318 shape032_LD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 319 shape032_UL ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 320 shape032_RD ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 321 shape032_CH ['hvg.textbox.1', 'HSC.ScriptDataObject.1'] 1
# 322 shape104 ['hsc.shape.1'] 2
# 323 shape104_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 324 shape108 ['hsc.shape.1'] 2
# 325 shape108_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 326 shape109 ['hsc.shape.1'] 2
# 327 shape109_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 328 shape110 ['hsc.shape.1'] 2
# 329 shape110_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 330 shape111 ['hsc.shape.1'] 2
# 331 shape111_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 332 shape112 ['hsc.shape.1'] 2
# 333 shape112_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 334 shape115 ['hsc.shape.1'] 2
# 335 shape115_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 336 shape272 ['hsc.shape.1'] 2
# 337 shape272_group001 ['hvg.group.1'] 10
# 338 shape272_plyPump ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 339 shape272_linInlet ['hvg.base.1'] 0
# 340 shape272_linOutlet ['hvg.base.1'] 0
# 341 shape272_recMotor ['hvg.base.1'] 0
# 342 shape272_recSelectBox ['hvg.base.1'] 0
# 343 textbox031 ['hvg.textbox.1'] 1
# 344 shape310 ['hsc.shape.1'] 2
# 345 shape310_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 346 shape792 ['hsc.shape.1'] 2
# 347 shape792_grpShape ['hvg.group.1'] 4
# 348 shape792_plyBPArrow ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 349 shape792_recSelectBox ['hvg.base.1'] 0
# 350 shape033 ['hsc.shape.1'] 2
# 351 shape033_group001 ['hvg.group.1'] 4
# 352 shape033_rect001 ['hvg.base.1'] 0
# 353 shape033_textbox001 ['hvg.textbox.1'] 1
# 354 shape793 ['hsc.shape.1'] 2
# 355 shape793_grpShape ['hvg.group.1'] 4
# 356 shape793_plyBPArrow ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 357 shape793_recSelectBox ['hvg.base.1'] 0
# 358 shape392 ['hsc.shape.1'] 2
# 359 shape392_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 360 shape794 ['hsc.shape.1'] 2
# 361 shape794_grpShape ['hvg.group.1'] 4
# 362 shape794_plyBPArrow ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 363 shape794_recSelectBox ['hvg.base.1'] 0
# 364 shape415 ['hsc.shape.1'] 2
# 365 shape415_group001 ['hvg.group.1'] 4
# 366 shape415_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 367 shape415_recSelectBox ['hvg.base.1'] 0
# 368 textbox122 ['hvg.textbox.1'] 1
# 369 shape416 ['hsc.shape.1'] 2
# 370 shape416_group001 ['hvg.group.1'] 4
# 371 shape416_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 372 shape416_recSelectBox ['hvg.base.1'] 0
# 373 shape417 ['hsc.shape.1'] 2
# 374 shape417_group001 ['hvg.group.1'] 4
# 375 shape417_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 376 shape417_recSelectBox ['hvg.base.1'] 0
# 377 shape418 ['hsc.shape.1'] 2
# 378 shape418_group001 ['hvg.group.1'] 4
# 379 shape418_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 380 shape418_recSelectBox ['hvg.base.1'] 0
# 381 shape421 ['hsc.shape.1'] 2
# 382 shape421_group001 ['hvg.group.1'] 4
# 383 shape421_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 384 shape421_recSelectBox ['hvg.base.1'] 0
# 385 shape423 ['hsc.shape.1'] 2
# 386 shape423_group001 ['hvg.group.1'] 4
# 387 shape423_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 388 shape423_recSelectBox ['hvg.base.1'] 0
# 389 shape223 ['hsc.shape.1'] 2
# 390 shape223_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 391 shape232 ['hsc.shape.1'] 2
# 392 shape232_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 393 shape240 ['hsc.shape.1'] 2
# 394 shape240_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 395 shape444 ['hsc.shape.1'] 2
# 396 shape444_group001 ['hvg.group.1'] 4
# 397 shape444_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 398 shape444_recSelectBox ['hvg.base.1'] 0
# 399 shape250 ['hsc.shape.1'] 2
# 400 shape250_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 401 shape254 ['hsc.shape.1'] 2
# 402 shape254_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 403 shape255 ['hsc.shape.1'] 2
# 404 shape255_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 405 shape447 ['hsc.shape.1'] 2
# 406 shape447_group001 ['hvg.group.1'] 4
# 407 shape447_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 408 shape447_recSelectBox ['hvg.base.1'] 0
# 409 shape266 ['hsc.shape.1'] 2
# 410 shape266_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 411 shape269 ['hsc.shape.1'] 2
# 412 shape269_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 413 shape274 ['hsc.shape.1'] 2
# 414 shape274_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 415 shape457 ['hsc.shape.1'] 2
# 416 shape457_group001 ['hvg.group.1'] 4
# 417 shape457_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 418 shape457_recSelectBox ['hvg.base.1'] 0
# 419 shape551 ['hsc.shape.1'] 2
# 420 shape551_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 421 shape276 ['hsc.shape.1'] 2
# 422 shape276_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 423 shape458 ['hsc.shape.1'] 2
# 424 shape458_group001 ['hvg.group.1'] 4
# 425 shape458_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 426 shape458_recSelectBox ['hvg.base.1'] 0
# 427 shape552 ['hsc.shape.1'] 2
# 428 shape552_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 429 shape277 ['hsc.shape.1'] 2
# 430 shape277_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 431 shape459 ['hsc.shape.1'] 2
# 432 shape459_group001 ['hvg.group.1'] 4
# 433 shape459_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 434 shape459_recSelectBox ['hvg.base.1'] 0
# 435 shape278 ['hsc.shape.1'] 2
# 436 shape278_group001 ['hvg.group.1'] 10
# 437 shape278_plyPump ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 438 shape278_linInlet ['hvg.base.1'] 0
# 439 shape278_linOutlet ['hvg.base.1'] 0
# 440 shape278_recMotor ['hvg.base.1'] 0
# 441 shape278_recSelectBox ['hvg.base.1'] 0
# 442 textbox037 ['hvg.textbox.1'] 1
# 443 shape279 ['hsc.shape.1'] 2
# 444 shape279_group001 ['hvg.group.1'] 10
# 445 shape279_plyPump ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 446 shape279_linInlet ['hvg.base.1'] 0
# 447 shape279_linOutlet ['hvg.base.1'] 0
# 448 shape279_recMotor ['hvg.base.1'] 0
# 449 shape279_recSelectBox ['hvg.base.1'] 0
# 450 textbox038 ['hvg.textbox.1'] 1
# 451 shape281 ['hsc.shape.1'] 2
# 452 shape281_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 453 shape462 ['hsc.shape.1'] 2
# 454 shape462_group001 ['hvg.group.1'] 4
# 455 shape462_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 456 shape462_recSelectBox ['hvg.base.1'] 0
# 457 shape282 ['hsc.shape.1'] 2
# 458 shape282_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 459 shape463 ['hsc.shape.1'] 2
# 460 shape463_group001 ['hvg.group.1'] 4
# 461 shape463_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 462 shape463_recSelectBox ['hvg.base.1'] 0
# 463 shape283 ['hsc.shape.1'] 2
# 464 shape283_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 465 shape284 ['hsc.shape.1'] 2
# 466 shape284_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 467 shape289 ['hsc.shape.1'] 2
# 468 shape289_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 469 shape553 ['hsc.shape.1'] 2
# 470 shape553_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 471 shape301 ['hsc.shape.1'] 2
# 472 shape301_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 473 shape506 ['hsc.shape.1'] 2
# 474 shape506_group001 ['hvg.group.1'] 4
# 475 shape506_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 476 shape506_recSelectBox ['hvg.base.1'] 0
# 477 shape303 ['hsc.shape.1'] 2
# 478 shape303_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 479 shape563 ['hsc.shape.1'] 2
# 480 shape563_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 481 shape304 ['hsc.shape.1'] 2
# 482 shape304_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 483 shape507 ['hsc.shape.1'] 2
# 484 shape507_group001 ['hvg.group.1'] 4
# 485 shape507_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 486 shape507_recSelectBox ['hvg.base.1'] 0
# 487 shape305 ['hsc.shape.1'] 2
# 488 shape305_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 489 shape564 ['hsc.shape.1'] 2
# 490 shape564_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 491 shape314 ['hsc.shape.1'] 2
# 492 shape314_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 493 shape315 ['hsc.shape.1'] 2
# 494 shape315_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 495 shape508 ['hsc.shape.1'] 2
# 496 shape508_group001 ['hvg.group.1'] 4
# 497 shape508_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 498 shape508_recSelectBox ['hvg.base.1'] 0
# 499 shape329 ['hsc.shape.1'] 2
# 500 shape329_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 501 shape565 ['hsc.shape.1'] 2
# 502 shape565_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 503 shape509 ['hsc.shape.1'] 2
# 504 shape509_group001 ['hvg.group.1'] 4
# 505 shape509_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 506 shape509_recSelectBox ['hvg.base.1'] 0
# 507 shape330 ['hsc.shape.1'] 2
# 508 shape330_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 509 shape334 ['hsc.shape.1'] 2
# 510 shape334_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 511 shape566 ['hsc.shape.1'] 2
# 512 shape566_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 513 shape510 ['hsc.shape.1'] 2
# 514 shape510_group001 ['hvg.group.1'] 4
# 515 shape510_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 516 shape510_recSelectBox ['hvg.base.1'] 0
# 517 shape371 ['hsc.shape.1'] 2
# 518 shape371_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 519 shape511 ['hsc.shape.1'] 2
# 520 shape511_group001 ['hvg.group.1'] 4
# 521 shape511_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 522 shape511_recSelectBox ['hvg.base.1'] 0
# 523 shape568 ['hsc.shape.1'] 2
# 524 shape568_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 525 shape393 ['hsc.shape.1'] 2
# 526 shape393_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 527 shape512 ['hsc.shape.1'] 2
# 528 shape512_group001 ['hvg.group.1'] 4
# 529 shape512_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 530 shape512_recSelectBox ['hvg.base.1'] 0
# 531 shape569 ['hsc.shape.1'] 2
# 532 shape569_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 533 shape394 ['hsc.shape.1'] 2
# 534 shape394_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 535 shape513 ['hsc.shape.1'] 2
# 536 shape513_group001 ['hvg.group.1'] 4
# 537 shape513_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 538 shape513_recSelectBox ['hvg.base.1'] 0
# 539 shape570 ['hsc.shape.1'] 2
# 540 shape570_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 541 shape395 ['hsc.shape.1'] 2
# 542 shape395_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 543 shape514 ['hsc.shape.1'] 2
# 544 shape514_group001 ['hvg.group.1'] 4
# 545 shape514_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 546 shape514_recSelectBox ['hvg.base.1'] 0
# 547 shape396 ['hsc.shape.1'] 2
# 548 shape396_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 549 shape571 ['hsc.shape.1'] 2
# 550 shape571_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 551 shape397 ['hsc.shape.1'] 2
# 552 shape397_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 553 shape515 ['hsc.shape.1'] 2
# 554 shape515_group001 ['hvg.group.1'] 4
# 555 shape515_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 556 shape515_recSelectBox ['hvg.base.1'] 0
# 557 shape398 ['hsc.shape.1'] 2
# 558 shape398_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 559 shape577 ['hsc.shape.1'] 2
# 560 shape577_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 561 shape399 ['hsc.shape.1'] 2
# 562 shape399_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 563 shape400 ['hsc.shape.1'] 2
# 564 shape400_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 565 shape401 ['hsc.shape.1'] 2
# 566 shape401_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 567 shape516 ['hsc.shape.1'] 2
# 568 shape516_group001 ['hvg.group.1'] 4
# 569 shape516_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 570 shape516_recSelectBox ['hvg.base.1'] 0
# 571 shape404 ['hsc.shape.1'] 2
# 572 shape404_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 573 shape608 ['hsc.shape.1'] 2
# 574 shape608_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 575 shape405 ['hsc.shape.1'] 2
# 576 shape405_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 577 shape406 ['hsc.shape.1'] 2
# 578 shape406_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 579 shape609 ['hsc.shape.1'] 2
# 580 shape609_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 581 shape518 ['hsc.shape.1'] 2
# 582 shape518_group001 ['hvg.group.1'] 4
# 583 shape518_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 584 shape518_recSelectBox ['hvg.base.1'] 0
# 585 shape407 ['hsc.shape.1'] 2
# 586 shape407_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 587 shape408 ['hsc.shape.1'] 2
# 588 shape408_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 589 shape610 ['hsc.shape.1'] 2
# 590 shape610_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 591 shape519 ['hsc.shape.1'] 2
# 592 shape519_group001 ['hvg.group.1'] 4
# 593 shape519_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 594 shape519_recSelectBox ['hvg.base.1'] 0
# 595 shape409 ['hsc.shape.1'] 2
# 596 shape409_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 597 shape410 ['hsc.shape.1'] 2
# 598 shape410_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 599 shape523 ['hsc.shape.1'] 2
# 600 shape523_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 601 shape627 ['hsc.shape.1'] 2
# 602 shape627_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 603 shape651 ['hsc.shape.1'] 2
# 604 shape651_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 605 shape308 ['hsc.shape.1'] 2
# 606 shape308_group001 ['hvg.group.1'] 10
# 607 shape308_plyPump ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 608 shape308_linInlet ['hvg.base.1'] 0
# 609 shape308_linOutlet ['hvg.base.1'] 0
# 610 shape308_recMotor ['hvg.base.1'] 0
# 611 shape308_recSelectBox ['hvg.base.1'] 0
# 612 textbox035 ['hvg.textbox.1'] 1
# 613 shape309 ['hsc.shape.1'] 2
# 614 shape309_group001 ['hvg.group.1'] 10
# 615 shape309_plyPump ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 616 shape309_linInlet ['hvg.base.1'] 0
# 617 shape309_linOutlet ['hvg.base.1'] 0
# 618 shape309_recMotor ['hvg.base.1'] 0
# 619 shape309_recSelectBox ['hvg.base.1'] 0
# 620 textbox036 ['hvg.textbox.1'] 1
# 621 shape312 ['hsc.shape.1'] 2
# 622 shape312_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 623 shape468 ['hsc.shape.1'] 2
# 624 shape468_group001 ['hvg.group.1'] 4
# 625 shape468_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 626 shape468_recSelectBox ['hvg.base.1'] 0
# 627 shape313 ['hsc.shape.1'] 2
# 628 shape313_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 629 shape316 ['hsc.shape.1'] 2
# 630 shape316_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 631 shape469 ['hsc.shape.1'] 2
# 632 shape469_group001 ['hvg.group.1'] 4
# 633 shape469_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 634 shape469_recSelectBox ['hvg.base.1'] 0
# 635 shape572 ['hsc.shape.1'] 2
# 636 shape572_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 637 shape318 ['hsc.shape.1'] 2
# 638 shape318_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 639 shape319 ['hsc.shape.1'] 2
# 640 shape319_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 641 shape573 ['hsc.shape.1'] 2
# 642 shape573_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 643 shape320 ['hsc.shape.1'] 2
# 644 shape320_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 645 shape321 ['hsc.shape.1'] 2
# 646 shape321_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 647 shape574 ['hsc.shape.1'] 2
# 648 shape574_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 649 shape470 ['hsc.shape.1'] 2
# 650 shape470_group001 ['hvg.group.1'] 4
# 651 shape470_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 652 shape470_recSelectBox ['hvg.base.1'] 0
# 653 shape322 ['hsc.shape.1'] 2
# 654 shape322_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 655 shape323 ['hsc.shape.1'] 2
# 656 shape323_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 657 shape324 ['hsc.shape.1'] 2
# 658 shape324_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 659 shape471 ['hsc.shape.1'] 2
# 660 shape471_group001 ['hvg.group.1'] 4
# 661 shape471_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 662 shape471_recSelectBox ['hvg.base.1'] 0
# 663 shape575 ['hsc.shape.1'] 2
# 664 shape575_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 665 shape325 ['hsc.shape.1'] 2
# 666 shape325_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 667 shape326 ['hsc.shape.1'] 2
# 668 shape326_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 669 shape576 ['hsc.shape.1'] 2
# 670 shape576_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 671 shape327 ['hsc.shape.1'] 2
# 672 shape327_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 673 shape328 ['hsc.shape.1'] 2
# 674 shape328_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 675 shape472 ['hsc.shape.1'] 2
# 676 shape472_group001 ['hvg.group.1'] 4
# 677 shape472_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 678 shape472_recSelectBox ['hvg.base.1'] 0
# 679 textbox154 ['hvg.textbox.1'] 1
# 680 shape473 ['hsc.shape.1'] 2
# 681 shape473_group001 ['hvg.group.1'] 4
# 682 shape473_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 683 shape473_recSelectBox ['hvg.base.1'] 0
# 684 textbox155 ['hvg.textbox.1'] 1
# 685 shape390 ['hsc.shape.1'] 2
# 686 shape390_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 687 shape391 ['hsc.shape.1'] 2
# 688 shape391_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 689 shape607 ['hsc.shape.1'] 2
# 690 shape607_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 691 textbox156 ['hvg.textbox.1'] 1
# 692 shape035 ['hsc.shape.1'] 2
# 693 shape035_group001 ['hvg.group.1'] 4
# 694 shape035_rect001 ['hvg.base.1'] 0
# 695 shape035_textbox001 ['hvg.textbox.1'] 1
# 696 shape286 ['hsc.shape.1'] 2
# 697 shape286_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 698 shape467 ['hsc.shape.1'] 2
# 699 shape467_group001 ['hvg.group.1'] 4
# 700 shape467_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 701 shape467_recSelectBox ['hvg.base.1'] 0
# 702 shape287 ['hsc.shape.1'] 2
# 703 shape287_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 704 shape476 ['hsc.shape.1'] 2
# 705 shape476_group001 ['hvg.group.1'] 4
# 706 shape476_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 707 shape476_recSelectBox ['hvg.base.1'] 0
# 708 shape288 ['hsc.shape.1'] 2
# 709 shape288_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 710 shape302 ['hsc.shape.1'] 2
# 711 shape302_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 712 shape558 ['hsc.shape.1'] 2
# 713 shape558_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 714 shape306 ['hsc.shape.1'] 2
# 715 shape306_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 716 shape477 ['hsc.shape.1'] 2
# 717 shape477_group001 ['hvg.group.1'] 4
# 718 shape477_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 719 shape477_recSelectBox ['hvg.base.1'] 0
# 720 shape527 ['hsc.shape.1'] 2
# 721 shape527_group001 ['hvg.group.1'] 4
# 722 shape527_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 723 shape527_recSelectBox ['hvg.base.1'] 0
# 724 shape331 ['hsc.shape.1'] 2
# 725 shape331_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 726 shape559 ['hsc.shape.1'] 2
# 727 shape559_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 728 shape529 ['hsc.shape.1'] 2
# 729 shape529_group001 ['hvg.group.1'] 4
# 730 shape529_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 731 shape529_recSelectBox ['hvg.base.1'] 0
# 732 shape332 ['hsc.shape.1'] 2
# 733 shape332_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 734 shape578 ['hsc.shape.1'] 2
# 735 shape578_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 736 shape307 ['hsc.shape.1'] 2
# 737 shape307_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 738 shape317 ['hsc.shape.1'] 2
# 739 shape317_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 740 shape579 ['hsc.shape.1'] 2
# 741 shape579_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 742 shape333 ['hsc.shape.1'] 2
# 743 shape333_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 744 shape479 ['hsc.shape.1'] 2
# 745 shape479_group001 ['hvg.group.1'] 4
# 746 shape479_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 747 shape479_recSelectBox ['hvg.base.1'] 0
# 748 shape480 ['hsc.shape.1'] 2
# 749 shape480_group001 ['hvg.group.1'] 4
# 750 shape480_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 751 shape480_recSelectBox ['hvg.base.1'] 0
# 752 shape335 ['hsc.shape.1'] 2
# 753 shape335_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 754 shape481 ['hsc.shape.1'] 2
# 755 shape481_group001 ['hvg.group.1'] 4
# 756 shape481_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 757 shape481_recSelectBox ['hvg.base.1'] 0
# 758 shape534 ['hsc.shape.1'] 2
# 759 shape534_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 760 shape226 ['hsc.shape.1'] 2
# 761 shape226_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 762 shape433 ['hsc.shape.1'] 2
# 763 shape433_group001 ['hvg.group.1'] 4
# 764 shape433_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 765 shape433_recSelectBox ['hvg.base.1'] 0
# 766 shape536 ['hsc.shape.1'] 2
# 767 shape536_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 768 shape442 ['hsc.shape.1'] 2
# 769 shape442_group001 ['hvg.group.1'] 4
# 770 shape442_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 771 shape442_recSelectBox ['hvg.base.1'] 0
# 772 textbox126 ['hvg.textbox.1'] 1
# 773 textbox127 ['hvg.textbox.1'] 1
# 774 shape336 ['hsc.shape.1'] 2
# 775 shape336_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 776 shape337 ['hsc.shape.1'] 2
# 777 shape337_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 778 textbox039 ['hvg.textbox.1'] 1
# 779 shape659 ['hsc.shape.1'] 2
# 780 shape659_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 781 shape660 ['hsc.shape.1'] 2
# 782 shape660_group001 ['hvg.group.1'] 4
# 783 shape660_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 784 shape660_recSelectBox ['hvg.base.1'] 0
# 785 shape661 ['hsc.shape.1'] 2
# 786 shape661_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 787 shape580 ['hsc.shape.1'] 2
# 788 shape580_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 789 shape262 ['hsc.shape.1'] 2
# 790 shape262_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 791 shape455 ['hsc.shape.1'] 2
# 792 shape455_group001 ['hvg.group.1'] 4
# 793 shape455_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 794 shape455_recSelectBox ['hvg.base.1'] 0
# 795 shape271 ['hsc.shape.1'] 2
# 796 shape271_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 797 shape116 ['hsc.shape.1'] 2
# 798 shape116_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 799 shape422 ['hsc.shape.1'] 2
# 800 shape422_group001 ['hvg.group.1'] 4
# 801 shape422_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 802 shape422_recSelectBox ['hvg.base.1'] 0
# 803 shape341 ['hsc.shape.1'] 2
# 804 shape341_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 805 rect146 ['hvg.base.1'] 0
# 806 rect148 ['hvg.base.1'] 0
# 807 rect149 ['hvg.base.1'] 0
# 808 rect159 ['hvg.base.1'] 0
# 809 rect160 ['hvg.base.1'] 0
# 810 rect161 ['hvg.base.1'] 0
# 811 rect162 ['hvg.base.1'] 0
# 812 rect168 ['hvg.base.1'] 0
# 813 rect183 ['hvg.base.1'] 0
# 814 rect195 ['hvg.base.1'] 0
# 815 rect196 ['hvg.base.1'] 0
# 816 rect198 ['hvg.base.1'] 0
# 817 rect199 ['hvg.base.1'] 0
# 818 rect200 ['hvg.base.1'] 0
# 819 rect163 ['hvg.base.1'] 0
# 820 rect164 ['hvg.base.1'] 0
# 821 rect165 ['hvg.base.1'] 0
# 822 rect166 ['hvg.base.1'] 0
# 823 rect167 ['hvg.base.1'] 0
# 824 rect194 ['hvg.base.1'] 0
# 825 rect155 ['hvg.base.1'] 0
# 826 rect169 ['hvg.base.1'] 0
# 827 rect170 ['hvg.base.1'] 0
# 828 rect171 ['hvg.base.1'] 0
# 829 rect132 ['hvg.base.1'] 0
# 830 rect133 ['hvg.base.1'] 0
# 831 rect206 ['hvg.base.1'] 0
# 832 rect147 ['hvg.base.1'] 0
# 833 shape584 ['hsc.shape.1'] 2
# 834 shape584_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 835 shape640 ['hsc.shape.1'] 2
# 836 shape640_group001 ['hvg.group.1'] 4
# 837 shape640_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 838 shape640_recSelectBox ['hvg.base.1'] 0
# 839 shape641 ['hsc.shape.1'] 2
# 840 shape641_group001 ['hvg.group.1'] 4
# 841 shape641_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 842 shape641_recSelectBox ['hvg.base.1'] 0
# 843 shape642 ['hsc.shape.1'] 2
# 844 shape642_group001 ['hvg.group.1'] 4
# 845 shape642_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 846 shape642_recSelectBox ['hvg.base.1'] 0
# 847 shape643 ['hsc.shape.1'] 2
# 848 shape643_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 849 shape644 ['hsc.shape.1'] 2
# 850 shape644_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 851 shape645 ['hsc.shape.1'] 2
# 852 shape645_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 853 shape646 ['hsc.shape.1'] 2
# 854 shape646_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 855 shape647 ['hsc.shape.1'] 2
# 856 shape647_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 857 shape648 ['hsc.shape.1'] 2
# 858 shape648_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 859 shape649 ['hsc.shape.1'] 2
# 860 shape649_group001 ['hvg.group.1'] 4
# 861 shape649_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 862 shape649_recSelectBox ['hvg.base.1'] 0
# 863 shape668 ['hsc.shape.1'] 2
# 864 shape668_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 865 rect209 ['hvg.base.1'] 0
# 866 rect210 ['hvg.base.1'] 0
# 867 rect211 ['hvg.base.1'] 0
# 868 PseudoValve039 ['hsc.shape.1'] 2
# 869 PseudoValve039_grpShape ['hvg.group.1'] 4
# 870 PseudoValve039_ovlValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 871 PseudoValve039_recSelectBox ['hvg.base.1'] 0
# 872 PseudoValve040 ['hsc.shape.1'] 2
# 873 PseudoValve040_grpShape ['hvg.group.1'] 4
# 874 PseudoValve040_ovlValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 875 PseudoValve040_recSelectBox ['hvg.base.1'] 0
# 876 PseudoValve041 ['hsc.shape.1'] 2
# 877 PseudoValve041_grpShape ['hvg.group.1'] 4
# 878 PseudoValve041_ovlValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 879 PseudoValve041_recSelectBox ['hvg.base.1'] 0
# 880 PseudoValve042 ['hsc.shape.1'] 2
# 881 PseudoValve042_grpShape ['hvg.group.1'] 4
# 882 PseudoValve042_ovlValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 883 PseudoValve042_recSelectBox ['hvg.base.1'] 0
# 884 PseudoValve043 ['hsc.shape.1'] 2
# 885 PseudoValve043_grpShape ['hvg.group.1'] 4
# 886 PseudoValve043_ovlValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 887 PseudoValve043_recSelectBox ['hvg.base.1'] 0
# 888 PseudoValve044 ['hsc.shape.1'] 2
# 889 PseudoValve044_grpShape ['hvg.group.1'] 4
# 890 PseudoValve044_ovlValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 891 PseudoValve044_recSelectBox ['hvg.base.1'] 0
# 892 PseudoValve045 ['hsc.shape.1'] 2
# 893 PseudoValve045_grpShape ['hvg.group.1'] 4
# 894 PseudoValve045_ovlValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 895 PseudoValve045_recSelectBox ['hvg.base.1'] 0
# 896 PseudoValve046 ['hsc.shape.1'] 2
# 897 PseudoValve046_grpShape ['hvg.group.1'] 4
# 898 PseudoValve046_ovlValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 899 PseudoValve046_recSelectBox ['hvg.base.1'] 0
# 900 PseudoValve047 ['hsc.shape.1'] 2
# 901 PseudoValve047_grpShape ['hvg.group.1'] 4
# 902 PseudoValve047_ovlValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 903 PseudoValve047_recSelectBox ['hvg.base.1'] 0
# 904 PseudoValve048 ['hsc.shape.1'] 2
# 905 PseudoValve048_grpShape ['hvg.group.1'] 4
# 906 PseudoValve048_ovlValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 907 PseudoValve048_recSelectBox ['hvg.base.1'] 0
# 908 PseudoValve049 ['hsc.shape.1'] 2
# 909 PseudoValve049_grpShape ['hvg.group.1'] 4
# 910 PseudoValve049_ovlValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 911 PseudoValve049_recSelectBox ['hvg.base.1'] 0
# 912 PseudoValve050 ['hsc.shape.1'] 2
# 913 PseudoValve050_grpShape ['hvg.group.1'] 4
# 914 PseudoValve050_ovlValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 915 PseudoValve050_recSelectBox ['hvg.base.1'] 0
# 916 shape619 ['hsc.shape.1'] 2
# 917 shape619_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 918 shape650 ['hsc.shape.1'] 2
# 919 shape650_group001 ['hvg.group.1'] 4
# 920 shape650_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 921 shape650_recSelectBox ['hvg.base.1'] 0
# 922 shape438 ['hsc.shape.1'] 2
# 923 shape438_group001 ['hvg.group.1'] 4
# 924 shape438_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 925 shape438_recSelectBox ['hvg.base.1'] 0
# 926 shape292 ['hsc.shape.1'] 2
# 927 shape292_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 928 rect153 ['hvg.base.1'] 0
# 929 shape439 ['hsc.shape.1'] 2
# 930 shape439_group001 ['hvg.group.1'] 4
# 931 shape439_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 932 shape439_recSelectBox ['hvg.base.1'] 0
# 933 shape293 ['hsc.shape.1'] 2
# 934 shape293_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 935 shape461 ['hsc.shape.1'] 2
# 936 shape461_group001 ['hvg.group.1'] 4
# 937 shape461_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 938 shape461_recSelectBox ['hvg.base.1'] 0
# 939 shape587 ['hsc.shape.1'] 2
# 940 shape587_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 941 shape297 ['hsc.shape.1'] 2
# 942 shape297_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 943 shape464 ['hsc.shape.1'] 2
# 944 shape464_group001 ['hvg.group.1'] 4
# 945 shape464_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 946 shape464_recSelectBox ['hvg.base.1'] 0
# 947 shape311 ['hsc.shape.1'] 2
# 948 shape311_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 949 shape347 ['hsc.shape.1'] 2
# 950 shape347_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 951 shape348 ['hsc.shape.1'] 2
# 952 shape348_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 953 shape349 ['hsc.shape.1'] 2
# 954 shape349_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 955 shape588 ['hsc.shape.1'] 2
# 956 shape588_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 957 shape465 ['hsc.shape.1'] 2
# 958 shape465_group001 ['hvg.group.1'] 4
# 959 shape465_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 960 shape465_recSelectBox ['hvg.base.1'] 0
# 961 shape617 ['hsc.shape.1'] 2
# 962 shape617_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 963 shape622 ['hsc.shape.1'] 2
# 964 shape622_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 965 shape637 ['hsc.shape.1'] 2
# 966 shape637_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 967 shape350 ['hsc.shape.1'] 2
# 968 shape350_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 969 shape475 ['hsc.shape.1'] 2
# 970 shape475_group001 ['hvg.group.1'] 4
# 971 shape475_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 972 shape475_recSelectBox ['hvg.base.1'] 0
# 973 shape483 ['hsc.shape.1'] 2
# 974 shape483_group001 ['hvg.group.1'] 4
# 975 shape483_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 976 shape483_recSelectBox ['hvg.base.1'] 0
# 977 shape484 ['hsc.shape.1'] 2
# 978 shape484_group001 ['hvg.group.1'] 4
# 979 shape484_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 980 shape484_recSelectBox ['hvg.base.1'] 0
# 981 shape638 ['hsc.shape.1'] 2
# 982 shape638_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 983 shape655 ['hsc.shape.1'] 2
# 984 shape655_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 985 shape352 ['hsc.shape.1'] 2
# 986 shape352_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 987 shape672 ['hsc.shape.1'] 2
# 988 shape672_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 989 shape673 ['hsc.shape.1'] 2
# 990 shape673_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 991 shape674 ['hsc.shape.1'] 2
# 992 shape674_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 993 shape675 ['hsc.shape.1'] 2
# 994 shape675_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 995 shape676 ['hsc.shape.1'] 2
# 996 shape676_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 997 shape353 ['hsc.shape.1'] 2
# 998 shape353_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 999 shape354 ['hsc.shape.1'] 2
# 1000 shape354_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1001 shape677 ['hsc.shape.1'] 2
# 1002 shape677_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1003 shape355 ['hsc.shape.1'] 2
# 1004 shape355_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1005 shape678 ['hsc.shape.1'] 2
# 1006 shape678_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1007 shape356 ['hsc.shape.1'] 2
# 1008 shape356_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1009 shape679 ['hsc.shape.1'] 2
# 1010 shape679_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1011 shape357 ['hsc.shape.1'] 2
# 1012 shape357_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1013 rect156 ['hvg.base.1'] 0
# 1014 shape589 ['hsc.shape.1'] 2
# 1015 shape589_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1016 shape358 ['hsc.shape.1'] 2
# 1017 shape358_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1018 shape485 ['hsc.shape.1'] 2
# 1019 shape485_group001 ['hvg.group.1'] 4
# 1020 shape485_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1021 shape485_recSelectBox ['hvg.base.1'] 0
# 1022 shape359 ['hsc.shape.1'] 2
# 1023 shape359_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1024 shape360 ['hsc.shape.1'] 2
# 1025 shape360_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1026 shape486 ['hsc.shape.1'] 2
# 1027 shape486_group001 ['hvg.group.1'] 4
# 1028 shape486_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1029 shape486_recSelectBox ['hvg.base.1'] 0
# 1030 shape361 ['hsc.shape.1'] 2
# 1031 shape361_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1032 shape362 ['hsc.shape.1'] 2
# 1033 shape362_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1034 shape487 ['hsc.shape.1'] 2
# 1035 shape487_group001 ['hvg.group.1'] 4
# 1036 shape487_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1037 shape487_recSelectBox ['hvg.base.1'] 0
# 1038 shape363 ['hsc.shape.1'] 2
# 1039 shape363_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1040 shape364 ['hsc.shape.1'] 2
# 1041 shape364_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1042 shape488 ['hsc.shape.1'] 2
# 1043 shape488_group001 ['hvg.group.1'] 4
# 1044 shape488_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1045 shape488_recSelectBox ['hvg.base.1'] 0
# 1046 shape365 ['hsc.shape.1'] 2
# 1047 shape365_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1048 shape590 ['hsc.shape.1'] 2
# 1049 shape590_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1050 shape591 ['hsc.shape.1'] 2
# 1051 shape591_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1052 shape366 ['hsc.shape.1'] 2
# 1053 shape366_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1054 shape367 ['hsc.shape.1'] 2
# 1055 shape367_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1056 shape368 ['hsc.shape.1'] 2
# 1057 shape368_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1058 shape369 ['hsc.shape.1'] 2
# 1059 shape369_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1060 shape370 ['hsc.shape.1'] 2
# 1061 shape370_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1062 shape372 ['hsc.shape.1'] 2
# 1063 shape372_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1064 shape680 ['hsc.shape.1'] 2
# 1065 shape680_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1066 shape373 ['hsc.shape.1'] 2
# 1067 shape373_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1068 shape490 ['hsc.shape.1'] 2
# 1069 shape490_group001 ['hvg.group.1'] 4
# 1070 shape490_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1071 shape490_recSelectBox ['hvg.base.1'] 0
# 1072 shape374 ['hsc.shape.1'] 2
# 1073 shape374_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1074 shape375 ['hsc.shape.1'] 2
# 1075 shape375_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1076 shape491 ['hsc.shape.1'] 2
# 1077 shape491_group001 ['hvg.group.1'] 4
# 1078 shape491_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1079 shape491_recSelectBox ['hvg.base.1'] 0
# 1080 shape376 ['hsc.shape.1'] 2
# 1081 shape376_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1082 shape492 ['hsc.shape.1'] 2
# 1083 shape492_group001 ['hvg.group.1'] 4
# 1084 shape492_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1085 shape492_recSelectBox ['hvg.base.1'] 0
# 1086 shape681 ['hsc.shape.1'] 2
# 1087 shape681_group001 ['hvg.group.1'] 4
# 1088 shape681_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1089 shape681_recSelectBox ['hvg.base.1'] 0
# 1090 shape682 ['hsc.shape.1'] 2
# 1091 shape682_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1092 shape377 ['hsc.shape.1'] 2
# 1093 shape377_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1094 shape378 ['hsc.shape.1'] 2
# 1095 shape378_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1096 shape379 ['hsc.shape.1'] 2
# 1097 shape379_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1098 shape683 ['hsc.shape.1'] 2
# 1099 shape683_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1100 shape684 ['hsc.shape.1'] 2
# 1101 shape684_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1102 shape380 ['hsc.shape.1'] 2
# 1103 shape380_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1104 shape686 ['hsc.shape.1'] 2
# 1105 shape686_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1106 shape689 ['hsc.shape.1'] 2
# 1107 shape689_group001 ['hvg.group.1'] 4
# 1108 shape689_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1109 shape689_recSelectBox ['hvg.base.1'] 0
# 1110 shape690 ['hsc.shape.1'] 2
# 1111 shape690_group001 ['hvg.group.1'] 4
# 1112 shape690_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1113 shape690_recSelectBox ['hvg.base.1'] 0
# 1114 shape691 ['hsc.shape.1'] 2
# 1115 shape691_group001 ['hvg.group.1'] 4
# 1116 shape691_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1117 shape691_recSelectBox ['hvg.base.1'] 0
# 1118 rect175 ['hvg.base.1'] 0
# 1119 rect176 ['hvg.base.1'] 0
# 1120 rect177 ['hvg.base.1'] 0
# 1121 rect178 ['hvg.base.1'] 0
# 1122 rect179 ['hvg.base.1'] 0
# 1123 rect180 ['hvg.base.1'] 0
# 1124 rect181 ['hvg.base.1'] 0
# 1125 rect182 ['hvg.base.1'] 0
# 1126 rect184 ['hvg.base.1'] 0
# 1127 rect186 ['hvg.base.1'] 0
# 1128 shape382 ['hsc.shape.1'] 2
# 1129 shape382_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1130 shape692 ['hsc.shape.1'] 2
# 1131 shape692_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1132 shape693 ['hsc.shape.1'] 2
# 1133 shape693_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1134 rect185 ['hvg.base.1'] 0
# 1135 textbox130 ['hvg.textbox.1'] 1
# 1136 textbox131 ['hvg.textbox.1'] 1
# 1137 textbox135 ['hvg.textbox.1'] 1
# 1138 shape383 ['hsc.shape.1'] 2
# 1139 shape383_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1140 shape493 ['hsc.shape.1'] 2
# 1141 shape493_group001 ['hvg.group.1'] 4
# 1142 shape493_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1143 shape493_recSelectBox ['hvg.base.1'] 0
# 1144 textbox033 ['hvg.textbox.1'] 1
# 1145 textbox034 ['hvg.textbox.1'] 1
# 1146 shape694 ['hsc.shape.1'] 2
# 1147 shape694_group001 ['hvg.group.1'] 4
# 1148 shape694_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1149 shape694_recSelectBox ['hvg.base.1'] 0
# 1150 shape695 ['hsc.shape.1'] 2
# 1151 shape695_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1152 shape696 ['hsc.shape.1'] 2
# 1153 shape696_group001 ['hvg.group.1'] 4
# 1154 shape696_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1155 shape696_recSelectBox ['hvg.base.1'] 0
# 1156 shape697 ['hsc.shape.1'] 2
# 1157 shape697_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1158 line001 ['hvg.base.1'] 0
# 1159 oval001 ['hvg.base.1'] 0
# 1160 textbox136 ['hvg.textbox.1'] 1
# 1161 shape698 ['hsc.shape.1'] 2
# 1162 shape698_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1163 shape699 ['hsc.shape.1'] 2
# 1164 shape699_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1165 shape592 ['hsc.shape.1'] 2
# 1166 shape592_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1167 shape517 ['hsc.shape.1'] 2
# 1168 shape517_group001 ['hvg.group.1'] 4
# 1169 shape517_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1170 shape517_recSelectBox ['hvg.base.1'] 0
# 1171 shape384 ['hsc.shape.1'] 2
# 1172 shape384_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1173 shape402 ['hsc.shape.1'] 2
# 1174 shape402_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1175 shape494 ['hsc.shape.1'] 2
# 1176 shape494_group001 ['hvg.group.1'] 4
# 1177 shape494_plyValve ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1178 shape494_recSelectBox ['hvg.base.1'] 0
# 1179 shape275 ['hsc.shape.1'] 2
# 1180 shape275_linPipe ['hvg.base.1', 'HSC.ScriptDataObject.1'] 0
# 1181 textbox040 ['hvg.textbox.1'] 1
# 1182 textbox137 ['hvg.textbox.1'] 1

# %%
for i,div in enumerate(divs):
    if 'hsc.shape.1' in div['class']:
        print(i, div['id'], div['parameters'])
# Out:
# 0 shape385 Point?element:MAL_OS1_7280;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_013_014~MAV_OS1_013_013;Value?EndPoint2:;
# 2 shape554 Point?element:MAL_OS1_314;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108;Value?EndPoint2:MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110;
# 4 shape001
# 8 tfgPlanningData Point?DestElement:;Point?SrcElement:;Value?IgnoreOnDataChange:"True";
# 10 tfgSelectTimeout Point?DestElement:;Point?SrcElement:;Value?IgnoreOnDataChange:"True";
# 11 tfgOperDataReInit
# 13 tfgOffDisplayEndPoints Point?Element1:;Point?Element2:;Point?Element3:;Point?Element4:;Point?Element5:;Point?Element6:;Point?Element7:;Point?Element8:;Point?Element9:;Point?Element10:;Point?Element11:;Point?Element12:;Point?Element13:;Point?Element14:;Point?Element15:;Point?Element16:;Point?Element17:;Point?Element18:;Point?Element19:;Point?Element20:;Point?Element21:;Point?Element22:;Point?Element23:;Point?Element24:;Point?Element25:;Point?Element26:;Point?Element27:;Point?Element28:;Point?Element29:;Point?Element30:;Point?Element31:;Point?Element32:;Point?Element33:;Point?Element34:;Point?Element35:;Point?Element36:;Point?Element37:;Point?Element38:;Point?Element39:;Point?Element40:;
# 16 shape015 TEXT?ACTIVITY:CH;TEXT?AREA:제품운영1과;TEXT?TANK:-;TEXT?PRODUCT:WAXY;
# 25 shape027 T?T:U-2400;
# 29 shape414 Point?element:MAV_OS1_054_002;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 33 shape273 Point?element:_P53102A;Value?DefElemType:4;Value?ShapeID:CPump;Value?DataBoundObj:plyPump;
# 42 shape050 Point?element:TK53104;Value?DefElemType:1;Value?ShapeID:TankNozzle;Value?DataBoundObj:shaTank;
# 44 shape050_shaTank
# 57 shape050_shaTankService
# 67 shape023 Point?TankName:TK53104;Parameter?TaskID:TaskID;Parameter?Material:Matlcode;TEXT?MATERIAL:W-31;
# 77 shape051 Point?element:TK53105;Value?DefElemType:1;Value?ShapeID:TankNozzle;Value?DataBoundObj:shaTank;
# 79 shape051_shaTank
# 92 shape051_shaTankService
# 102 shape024 Point?TankName:TK53105;Parameter?TaskID:TaskID;Parameter?Material:Matlcode;TEXT?MATERIAL:W-96S;
# 112 shape052 Point?element:TK53106;Value?DefElemType:1;Value?ShapeID:TankNozzle;Value?DataBoundObj:shaTank;
# 114 shape052_shaTank
# 127 shape052_shaTankService
# 137 shape025 Point?TankName:TK53106;Parameter?TaskID:TaskID;Parameter?Material:Matlcode;TEXT?MATERIAL:W-20;
# 147 shape053 Point?element:TK53107;Value?DefElemType:1;Value?ShapeID:TankNozzle;Value?DataBoundObj:shaTank;
# 149 shape053_shaTank
# 162 shape053_shaTankService
# 172 shape028 Point?TankName:TK53107;Parameter?TaskID:TaskID;Parameter?Material:Matlcode;TEXT?MATERIAL:W-116;
# 182 shape054 Point?element:TK53109;Value?DefElemType:1;Value?ShapeID:TankNozzle;Value?DataBoundObj:shaTank;
# 184 shape054_shaTank
# 197 shape054_shaTankService
# 207 shape029 Point?TankName:TK53109;Parameter?TaskID:TaskID;Parameter?Material:Matlcode;TEXT?MATERIAL:W-480;
# 217 shape055 Point?element:TK53110;Value?DefElemType:1;Value?ShapeID:TankNozzle;Value?DataBoundObj:shaTank;
# 219 shape055_shaTank
# 232 shape055_shaTankService
# 242 shape030 Point?TankName:TK53110;Parameter?TaskID:TaskID;Parameter?Material:Matlcode;TEXT?MATERIAL:W-31S;
# 252 shape056 Point?element:TK53111;Value?DefElemType:1;Value?ShapeID:TankNozzle;Value?DataBoundObj:shaTank;
# 254 shape056_shaTank
# 267 shape056_shaTankService
# 277 shape031 Point?TankName:TK53110;Parameter?TaskID:TaskID;Parameter?Material:Matlcode;TEXT?MATERIAL:W-31S;
# 287 shape057 Point?element:TK5397;Value?DefElemType:1;Value?ShapeID:TankNozzle;Value?DataBoundObj:shaTank;
# 289 shape057_shaTank
# 302 shape057_shaTankService
# 312 shape032 Point?TankName:TK5397;Parameter?TaskID:TaskID;Parameter?Material:Matlcode;TEXT?MATERIAL:Mix-W;
# 322 shape104 Point?element:MAL_OS1_218;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_054_002;Value?EndPoint2:;
# 324 shape108 Point?element:MAL_OS1_220;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_054_017;Value?EndPoint2:;
# 326 shape109 Point?element:MAL_OS1_230;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_054_021;Value?EndPoint2:;
# 328 shape110 Point?element:MAL_OS1_232;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_054_026;Value?EndPoint2:;
# 330 shape111 Point?element:MAL_OS1_202;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_053_027;Value?EndPoint2:;
# 332 shape112 Point?element:MAL_OS1_483;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_062_004;Value?EndPoint2:;
# 334 shape115 Point?element:MAL_OS1_417;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_059_006;Value?EndPoint2:;
# 336 shape272 Point?element:_P53102B;Value?DefElemType:4;Value?ShapeID:CPump;Value?DataBoundObj:plyPump;
# 344 shape310 Point?element:MAL_OS1_360;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_021_122;Value?EndPoint2:;
# 346 shape792 Point?element:UN2400_WAXY;Value?DefElemType:2;Value?ShapeID:BP;Value?DataBoundObj:plyBPArrow;
# 350 shape033 T?T:U-2600;
# 354 shape793 Point?element:UN2600_WAXY;Value?DefElemType:2;Value?ShapeID:BP;Value?DataBoundObj:plyBPArrow;
# 358 shape392 Point?element:MAL_OS1_359;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_136;Value?EndPoint2:;
# 360 shape794 Point?element:UN20200_WAXY;Value?DefElemType:2;Value?ShapeID:BP;Value?DataBoundObj:plyBPArrow;
# 364 shape415 Point?element:MAV_OS1_054_017;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 369 shape416 Point?element:MAV_OS1_054_021;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 373 shape417 Point?element:MAV_OS1_054_026;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 377 shape418 Point?element:MAV_OS1_053_027;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 381 shape421 Point?element:MAV_OS1_062_004;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 385 shape423 Point?element:MAV_OS1_059_006;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 389 shape223 Point?element:MAL_OS1_218;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:;Value?EndPoint2:;
# 391 shape232 Point?element:MAL_OS1_220;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 393 shape240 Point?element:MAL_OS1_230;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 395 shape444 Point?element:MAV_OS1_017_024;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 399 shape250 Point?element:MAL_OS1_232;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 401 shape254 Point?element:MAL_OS1_202;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:;Value?EndPoint2:;
# 403 shape255 Point?element:MAL_OS1_312;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_104;Value?EndPoint2:;
# 405 shape447 Point?element:MAV_OS1_018_104;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 409 shape266 Point?element:MAL_OS1_483;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_062_004;Value?EndPoint2:;
# 411 shape269 Point?element:MAL_OS1_417;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_059_006;Value?EndPoint2:;
# 413 shape274 Point?element:MAL_OS1_417;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_021_122;Value?EndPoint2:;
# 415 shape457 Point?element:MAV_OS1_021_122;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 419 shape551 Point?element:MAL_OS1_417;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_021_140~MAV_OS1_021_117;Value?EndPoint2:;
# 421 shape276 Point?element:MAL_OS1_417;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_021_117;Value?EndPoint2:;
# 423 shape458 Point?element:MAV_OS1_021_117;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 427 shape552 Point?element:MAL_OS1_417;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_021_117;Value?EndPoint2:;
# 429 shape277 Point?element:MAL_OS1_417;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_021_140;Value?EndPoint2:;
# 431 shape459 Point?element:MAV_OS1_021_140;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 435 shape278 Point?element:_P53104A;Value?DefElemType:4;Value?ShapeID:CPump;Value?DataBoundObj:plyPump;
# 443 shape279 Point?element:_P53104B;Value?DefElemType:4;Value?ShapeID:CPump;Value?DataBoundObj:plyPump;
# 451 shape281 Point?element:MAL_OS1_271;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:;Value?EndPoint2:;
# 453 shape462 Point?element:MAV_OS1_018_007;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 457 shape282 Point?element:MAL_OS1_272;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:;Value?EndPoint2:;
# 459 shape463 Point?element:MAV_OS1_018_008;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 463 shape283 Point?element:MAL_OS1_314;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_109;Value?EndPoint2:;
# 465 shape284 Point?element:MAL_OS1_314;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_007;Value?EndPoint2:;
# 467 shape289 Point?element:MAL_OS1_314;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_008;Value?EndPoint2:;
# 469 shape553 Point?element:MAL_OS1_314;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_007~MAV_OS1_018_109;Value?EndPoint2:MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110~MAV_OS1_018_108;
# 471 shape301 Point?element:MAL_OS1_2432;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 473 shape506 Point?element:MAV_OS1_022_062;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 477 shape303 Point?element:MAL_OS1_2431;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 479 shape563 Point?element:MAL_OS1_2431;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV005~MAV004;Value?EndPoint2:MAV010;
# 481 shape304 Point?element:MAL_OS1_2431;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 483 shape507 Point?element:OMAVALVE;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 487 shape305 Point?element:MAL_OS1_2433;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 489 shape564 Point?element:MAL_OS1_2433;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV005~MAV004;Value?EndPoint2:MAV010;
# 491 shape314 Point?element:MAL_OS1_2433;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 493 shape315 Point?element:MAL_OS1_2433;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 495 shape508 Point?element:MAV_OS1_022_073;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 499 shape329 Point?element:MAL_OS1_2433;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_073;Value?EndPoint2:;
# 501 shape565 Point?element:MAL_OS1_2433;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_074;Value?EndPoint2:;
# 503 shape509 Point?element:MAV_OS1_022_074;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 507 shape330 Point?element:MAL_OS1_2433;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_074;Value?EndPoint2:;
# 509 shape334 Point?element:MAL_OS1_2431;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 511 shape566 Point?element:MAL_OS1_2431;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV005~MAV004;Value?EndPoint2:MAV010;
# 513 shape510 Point?element:MAV_OS1_022_061;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 517 shape371 Point?element:MAL_OS1_2431;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_072;Value?EndPoint2:;
# 519 shape511 Point?element:MAV_OS1_022_072;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 523 shape568 Point?element:MAL_OS1_2431;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV005~MAV004;Value?EndPoint2:MAV010;
# 525 shape393 Point?element:MAL_OS1_2431;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_033;Value?EndPoint2:;
# 527 shape512 Point?element:MAV_OS1_022_033;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 531 shape569 Point?element:MAL_OS1_2431;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV005~MAV004;Value?EndPoint2:MAV010;
# 533 shape394 Point?element:MAL_OS1_2431;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_057;Value?EndPoint2:;
# 535 shape513 Point?element:MAV_OS1_022_057;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 539 shape570 Point?element:MAL_OS1_2431;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_061;Value?EndPoint2:;
# 541 shape395 Point?element:MAL_OS1_2428;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 543 shape514 Point?element:MAV_OS1_022_060;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 547 shape396 Point?element:MAL_OS1_2426;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_060;Value?EndPoint2:;
# 549 shape571 Point?element:MAL_OS1_2426;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV005~MAV004;Value?EndPoint2:MAV010;
# 551 shape397 Point?element:MAL_OS1_2426;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 553 shape515 Point?element:OMAVALVE;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 557 shape398 Point?element:MAL_OS1_2424;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 559 shape577 Point?element:MAL_OS1_2424;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV005~MAV004;Value?EndPoint2:MAV010;
# 561 shape399 Point?element:MAL_OS1_2426;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067~MAV_OS1_022_063~MAV_OS1_022_061;Value?EndPoint2:;
# 563 shape400 Point?element:MAL_OS1_2424;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 565 shape401 Point?element:MAL_OS1_2424;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 567 shape516 Point?element:MAV_OS1_022_059;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 571 shape404 Point?element:MAL_OS1_5002;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_073;Value?EndPoint2:;
# 573 shape608 Point?element:MAL_OS1_5002;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_059;Value?EndPoint2:;
# 575 shape405 Point?element:MAL_OS1_5002;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_059;Value?EndPoint2:;
# 577 shape406 Point?element:MAL_OS1_5002;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:UN2600_WAXY;Value?EndPoint2:;
# 579 shape609 Point?element:MAL_OS1_5002;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_019_004;Value?EndPoint2:;
# 581 shape518 Point?element:MAV_OS1_019_004;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 585 shape407 Point?element:MAL_OS1_5002;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_019_004;Value?EndPoint2:;
# 587 shape408 Point?element:MAL_OS1_5002;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:UN2600_WAXY;Value?EndPoint2:;
# 589 shape610 Point?element:MAL_OS1_5002;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_014_003;Value?EndPoint2:;
# 591 shape519 Point?element:MAV_OS1_014_003;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 595 shape409 Point?element:MAL_OS1_5002;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_014_003;Value?EndPoint2:;
# 597 shape410 Point?element:MAL_OS1_5002;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:UN2600_WAXY;Value?EndPoint2:;
# 599 shape523 Point?element:MAL_OS1_246;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 601 shape627 Point?element:MAL_OS1_483;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_069;Value?EndPoint2:;
# 603 shape651 Point?element:MAL_OS1_325;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_064;Value?EndPoint2:;
# 605 shape308 Point?element:_P5399A;Value?DefElemType:4;Value?ShapeID:CPump;Value?DataBoundObj:plyPump;
# 613 shape309 Point?element:_P5399B;Value?DefElemType:4;Value?ShapeID:CPump;Value?DataBoundObj:plyPump;
# 621 shape312 Point?element:MAL_OS1_289;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 623 shape468 Point?element:MAV_OS1_018_043;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 627 shape313 Point?element:MAL_OS1_289;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_043;Value?EndPoint2:;
# 629 shape316 Point?element:MAL_OS1_360;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_043;Value?EndPoint2:;
# 631 shape469 Point?element:OMAVALVE;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 635 shape572 Point?element:MAL_OS1_289;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:OMAVALVE;Value?EndPoint2:;
# 637 shape318 Point?element:MAL_OS1_289;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:OMAVALVE;Value?EndPoint2:;
# 639 shape319 Point?element:MAL_OS1_288;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:OMAVALVE;Value?EndPoint2:;
# 641 shape573 Point?element:MAL_OS1_288;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:OMAVALVE;Value?EndPoint2:;
# 643 shape320 Point?element:MAL_OS1_288;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:_P5399BR;Value?EndPoint2:;
# 645 shape321 Point?element:MAL_OS1_288;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_136;Value?EndPoint2:;
# 647 shape574 Point?element:MAL_OS1_360;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_042;Value?EndPoint2:;
# 649 shape470 Point?element:MAV_OS1_018_042;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 653 shape322 Point?element:MAL_OS1_360;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_042;Value?EndPoint2:;
# 655 shape323 Point?element:MAL_OS1_287;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:_P5399AL;Value?EndPoint2:;
# 657 shape324 Point?element:MAL_OS1_287;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_042;Value?EndPoint2:;
# 659 shape471 Point?element:OMAVALVE;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 663 shape575 Point?element:MAL_OS1_287;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:OMAVALVE;Value?EndPoint2:;
# 665 shape325 Point?element:MAL_OS1_287;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:OMAVALVE;Value?EndPoint2:;
# 667 shape326 Point?element:MAL_OS1_286;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:OMAVALVE;Value?EndPoint2:;
# 669 shape576 Point?element:MAL_OS1_286;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:OMAVALVE;Value?EndPoint2:;
# 671 shape327 Point?element:MAL_OS1_286;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 673 shape328 Point?element:MAL_OS1_286;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_038;Value?EndPoint2:;
# 675 shape472 Point?element:MAV_OS1_018_038;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 680 shape473 Point?element:MAV_OS1_018_136;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 685 shape390 Point?element:MAL_OS1_359;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_038;Value?EndPoint2:;
# 687 shape391 Point?element:MAL_OS1_359;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_136;Value?EndPoint2:;
# 689 shape607 Point?element:MAL_OS1_359;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_038;Value?EndPoint2:;
# 692 shape035 T?T:U-20200;
# 696 shape286 Point?element:MAL_OS1_270;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:;Value?EndPoint2:;
# 698 shape467 Point?element:MAV_OS1_018_006;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 702 shape287 Point?element:MAL_OS1_273;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:;Value?EndPoint2:;
# 704 shape476 Point?element:MAV_OS1_018_009;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 708 shape288 Point?element:MAL_OS1_313;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_009;Value?EndPoint2:;
# 710 shape302 Point?element:MAL_OS1_313;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_006;Value?EndPoint2:;
# 712 shape558 Point?element:MAL_OS1_313;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_067~MAV_OS1_018_006;Value?EndPoint2:;
# 714 shape306 Point?element:MAL_OS1_313;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_067;Value?EndPoint2:;
# 716 shape477 Point?element:MAV_OS1_018_067;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 720 shape527 Point?element:MAV_OS1_018_106;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 724 shape331 Point?element:MAL_OS1_313;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_106;Value?EndPoint2:;
# 726 shape559 Point?element:MAL_OS1_313;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_067~MAV_OS1_018_006~MAV_OS1_018_106;Value?EndPoint2:MAV_OS1_018_107~MAV_OS1_018_009;
# 728 shape529 Point?element:MAV_OS1_018_107;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 732 shape332 Point?element:MAL_OS1_313;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_107;Value?EndPoint2:;
# 734 shape578 Point?element:MAL_OS1_313;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_009;Value?EndPoint2:;
# 736 shape307 Point?element:MAL_OS1_376;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_067;Value?EndPoint2:;
# 738 shape317 Point?element:MAL_OS1_376;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_013_012;Value?EndPoint2:;
# 740 shape579 Point?element:MAL_OS1_376;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_014_004;Value?EndPoint2:;
# 742 shape333 Point?element:MAL_OS1_376;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_014_004;Value?EndPoint2:;
# 744 shape479 Point?element:MAV_OS1_014_004;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 748 shape480 Point?element:MAV_OS1_013_012;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 752 shape335 Point?element:MAL_OS1_7279;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:;Value?EndPoint2:;
# 754 shape481 Point?element:MAV_OS1_013_013;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 758 shape534 Point?element:MAL_OS1_7280;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_013_014;Value?EndPoint2:;
# 760 shape226 Point?element:MAL_OS1_7280;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_013_014;Value?EndPoint2:;
# 762 shape433 Point?element:MAV_OS1_013_014;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 766 shape536 Point?element:MAL_OS1_7280;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_013_015;Value?EndPoint2:;
# 768 shape442 Point?element:MAV_OS1_013_015;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 774 shape336 Point?element:MAL_OS1_7280;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_013_013;Value?EndPoint2:;
# 776 shape337 Point?element:MAL_OS1_7280;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:UN2400_WAXY;Value?EndPoint2:;
# 779 shape659 Point?element:MAL_OS1_483;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_021_047;Value?EndPoint2:;
# 781 shape660 Point?element:MAV_OS1_021_047;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 785 shape661 Point?element:MAL_OS1_483;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_021_047;Value?EndPoint2:;
# 787 shape580 Point?element:MAL_OS1_483;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_024_031;Value?EndPoint2:;
# 789 shape262 Point?element:MAL_OS1_483;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_024_031;Value?EndPoint2:;
# 791 shape455 Point?element:MAV_OS1_024_031;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 795 shape271 Point?element:MAL_OS1_483;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_062_004~MAV_OS1_024_031;Value?EndPoint2:;
# 797 shape116 Point?element:MAL_OS1_491;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_062_013;Value?EndPoint2:;
# 799 shape422 Point?element:MAV_OS1_062_013;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 803 shape341 Point?element:MAL_OS1_491;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_068;Value?EndPoint2:;
# 833 shape584 Point?element:MAL_OS1_2426;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_061;Value?EndPoint2:;
# 835 shape640 Point?element:MAV_OS1_022_068;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 839 shape641 Point?element:MAV_OS1_022_069;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 843 shape642 Point?element:MAV_OS1_022_067;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 847 shape643 Point?element:MAL_OS1_2426;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_065;Value?EndPoint2:;
# 849 shape644 Point?element:MAL_OS1_2426;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_066;Value?EndPoint2:;
# 851 shape645 Point?element:MAL_OS1_2426;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_067;Value?EndPoint2:;
# 853 shape646 Point?element:MAL_OS1_2426;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067;Value?EndPoint2:;
# 855 shape647 Point?element:MAL_OS1_2426;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_065~MAV_OS1_022_066;Value?EndPoint2:;
# 857 shape648 Point?element:MAL_OS1_2426;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_065;Value?EndPoint2:;
# 859 shape649 Point?element:MAV_OS1_022_064;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 863 shape668 Point?element:MAL_OS1_2426;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_063;Value?EndPoint2:;
# 868 PseudoValve039 Point?element:_P53102AL;Value?DefElemType:5;Value?ShapeID:ValvePseudo;Value?DataBoundObj:ovlValve;
# 872 PseudoValve040 Point?element:_P53102AR;Value?DefElemType:5;Value?ShapeID:ValvePseudo;Value?DataBoundObj:ovlValve;
# 876 PseudoValve041 Point?element:_P53102BL;Value?DefElemType:5;Value?ShapeID:ValvePseudo;Value?DataBoundObj:ovlValve;
# 880 PseudoValve042 Point?element:_P53102BR;Value?DefElemType:5;Value?ShapeID:ValvePseudo;Value?DataBoundObj:ovlValve;
# 884 PseudoValve043 Point?element:_P53104AL;Value?DefElemType:5;Value?ShapeID:ValvePseudo;Value?DataBoundObj:ovlValve;
# 888 PseudoValve044 Point?element:_P53104AR;Value?DefElemType:5;Value?ShapeID:ValvePseudo;Value?DataBoundObj:ovlValve;
# 892 PseudoValve045 Point?element:_P53104BL;Value?DefElemType:5;Value?ShapeID:ValvePseudo;Value?DataBoundObj:ovlValve;
# 896 PseudoValve046 Point?element:_P53104BR;Value?DefElemType:5;Value?ShapeID:ValvePseudo;Value?DataBoundObj:ovlValve;
# 900 PseudoValve047 Point?element:_P5399AL;Value?DefElemType:5;Value?ShapeID:ValvePseudo;Value?DataBoundObj:ovlValve;
# 904 PseudoValve048 Point?element:_P5399AR;Value?DefElemType:5;Value?ShapeID:ValvePseudo;Value?DataBoundObj:ovlValve;
# 908 PseudoValve049 Point?element:_P5399BL;Value?DefElemType:5;Value?ShapeID:ValvePseudo;Value?DataBoundObj:ovlValve;
# 912 PseudoValve050 Point?element:_P5399BR;Value?DefElemType:5;Value?ShapeID:ValvePseudo;Value?DataBoundObj:ovlValve;
# 916 shape619 Point?element:MAL_OS1_368;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_011;Value?EndPoint2:;
# 918 shape650 Point?element:MAV_OS1_022_063;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 922 shape438 Point?element:MAV_OS1_018_109;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 926 shape292 Point?element:MAL_OS1_314;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_108;Value?EndPoint2:;
# 929 shape439 Point?element:MAV_OS1_018_108;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 933 shape293 Point?element:MAL_OS1_314;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_110;Value?EndPoint2:;
# 935 shape461 Point?element:MAV_OS1_018_110;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 939 shape587 Point?element:MAL_OS1_314;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108~MAV_OS1_018_110;Value?EndPoint2:MAV_OS1_018_111~MAV_OS1_018_008;
# 941 shape297 Point?element:MAL_OS1_314;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_111;Value?EndPoint2:;
# 943 shape464 Point?element:MAV_OS1_018_111;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 947 shape311 Point?element:MAL_OS1_323;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_109;Value?EndPoint2:;
# 949 shape347 Point?element:MAL_OS1_321;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_108;Value?EndPoint2:;
# 951 shape348 Point?element:MAL_OS1_326;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_110;Value?EndPoint2:;
# 953 shape349 Point?element:MAL_OS1_327;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 955 shape588 Point?element:MAL_OS1_314;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_008;Value?EndPoint2:;
# 957 shape465 Point?element:MAV_OS1_018_072;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 961 shape617 Point?element:MAL_OS1_323;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_134~MAV_OS1_018_116;Value?EndPoint2:MAV_OS1_018_072~MAV_OS1_018_109;
# 963 shape622 Point?element:MAL_OS1_323;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_134~MAV_OS1_018_116;Value?EndPoint2:MAV_OS1_018_072~MAV_OS1_018_109;
# 965 shape637 Point?element:MAL_OS1_323;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_134~MAV_OS1_018_116;Value?EndPoint2:MAV_OS1_018_072~MAV_OS1_018_109;
# 967 shape350 Point?element:MAL_OS1_323;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_072;Value?EndPoint2:;
# 969 shape475 Point?element:MAV_OS1_018_071;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 973 shape483 Point?element:MAV_OS1_018_074;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 977 shape484 Point?element:MAV_OS1_018_075;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 981 shape638 Point?element:MAL_OS1_323;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_134~MAV_OS1_018_116;Value?EndPoint2:MAV_OS1_018_072~MAV_OS1_018_109;
# 983 shape655 Point?element:MAL_OS1_321;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_117;Value?EndPoint2:MAV010;
# 985 shape352 Point?element:MAL_OS1_321;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_071;Value?EndPoint2:;
# 987 shape672 Point?element:MAL_OS1_321;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_117;Value?EndPoint2:MAV010;
# 989 shape673 Point?element:MAL_OS1_321;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_117;Value?EndPoint2:MAV010;
# 991 shape674 Point?element:MAL_OS1_326;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_141~MAV_OS1_018_115;Value?EndPoint2:;
# 993 shape675 Point?element:MAL_OS1_326;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_141~MAV_OS1_018_115;Value?EndPoint2:;
# 995 shape676 Point?element:MAL_OS1_327;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV005~MAV004;Value?EndPoint2:MAV010;
# 997 shape353 Point?element:MAL_OS1_326;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_074;Value?EndPoint2:;
# 999 shape354 Point?element:MAL_OS1_327;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 1001 shape677 Point?element:MAL_OS1_220;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV005~MAV004;Value?EndPoint2:MAV010;
# 1003 shape355 Point?element:MAL_OS1_220;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 1005 shape678 Point?element:MAL_OS1_230;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV005~MAV004;Value?EndPoint2:MAV010;
# 1007 shape356 Point?element:MAL_OS1_230;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 1009 shape679 Point?element:MAL_OS1_246;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV005~MAV004;Value?EndPoint2:MAV010;
# 1011 shape357 Point?element:MAL_OS1_246;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 1014 shape589 Point?element:MAL_OS1_368;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV005~MAV004;Value?EndPoint2:MAV010;
# 1016 shape358 Point?element:MAL_OS1_327;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_114;Value?EndPoint2:;
# 1018 shape485 Point?element:MAV_OS1_018_114;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1022 shape359 Point?element:MAL_OS1_368;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_114;Value?EndPoint2:;
# 1024 shape360 Point?element:MAL_OS1_326;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_115;Value?EndPoint2:;
# 1026 shape486 Point?element:MAV_OS1_018_115;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1030 shape361 Point?element:MAL_OS1_368;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_115;Value?EndPoint2:;
# 1032 shape362 Point?element:MAL_OS1_321;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_117;Value?EndPoint2:;
# 1034 shape487 Point?element:MAV_OS1_018_117;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1038 shape363 Point?element:MAL_OS1_368;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_117;Value?EndPoint2:;
# 1040 shape364 Point?element:MAL_OS1_323;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_116;Value?EndPoint2:;
# 1042 shape488 Point?element:MAV_OS1_018_116;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1046 shape365 Point?element:MAL_OS1_368;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_116;Value?EndPoint2:;
# 1048 shape590 Point?element:MAL_OS1_368;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV005~MAV004;Value?EndPoint2:MAV010;
# 1050 shape591 Point?element:MAL_OS1_368;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_116;Value?EndPoint2:MAV010;
# 1052 shape366 Point?element:MAL_OS1_326;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_115;Value?EndPoint2:;
# 1054 shape367 Point?element:MAL_OS1_321;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_117;Value?EndPoint2:;
# 1056 shape368 Point?element:MAL_OS1_321;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_117;Value?EndPoint2:;
# 1058 shape369 Point?element:MAL_OS1_323;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_116;Value?EndPoint2:;
# 1060 shape370 Point?element:MAL_OS1_323;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_116;Value?EndPoint2:;
# 1062 shape372 Point?element:MAL_OS1_323;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_116;Value?EndPoint2:;
# 1064 shape680 Point?element:MAL_OS1_312;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_130;Value?EndPoint2:;
# 1066 shape373 Point?element:MAL_OS1_327;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_130;Value?EndPoint2:;
# 1068 shape490 Point?element:MAV_OS1_018_130;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1072 shape374 Point?element:MAL_OS1_312;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_130;Value?EndPoint2:;
# 1074 shape375 Point?element:MAL_OS1_326;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_141;Value?EndPoint2:;
# 1076 shape491 Point?element:MAV_OS1_018_141;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1080 shape376 Point?element:MAL_OS1_323;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_134;Value?EndPoint2:;
# 1082 shape492 Point?element:MAV_OS1_018_134;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1086 shape681 Point?element:MAV_OS1_018_011;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1090 shape682 Point?element:MAL_OS1_325;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_011;Value?EndPoint2:;
# 1092 shape377 Point?element:MAL_OS1_325;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_013;Value?EndPoint2:;
# 1094 shape378 Point?element:MAL_OS1_325;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_100;Value?EndPoint2:;
# 1096 shape379 Point?element:MAL_OS1_325;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_172;Value?EndPoint2:;
# 1098 shape683 Point?element:MAL_OS1_325;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_013~MAV_OS1_018_011;Value?EndPoint2:MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100;
# 1100 shape684 Point?element:MAL_OS1_325;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100;Value?EndPoint2:MAV_OS1_022_064~MAV_OS1_018_172;
# 1102 shape380 Point?element:MAL_OS1_2427;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 1104 shape686 Point?element:MAL_OS1_325;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_064;Value?EndPoint2:;
# 1106 shape689 Point?element:MAV_OS1_018_013;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1110 shape690 Point?element:MAV_OS1_018_100;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1114 shape691 Point?element:MAV_OS1_018_172;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1128 shape382 Point?element:MAL_OS1_325;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_013~MAV_OS1_018_011;Value?EndPoint2:MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100;
# 1130 shape692 Point?element:MAL_OS1_491;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_068;Value?EndPoint2:;
# 1132 shape693 Point?element:MAL_OS1_491;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_068;Value?EndPoint2:MAV010;
# 1138 shape383 Point?element:MAL_OS1_220;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:PSP5383L;Value?EndPoint2:;
# 1140 shape493 Point?element:MAV_OS1_018_073;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1146 shape694 Point?element:MAV_OS1_022_065;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1150 shape695 Point?element:MAL_OS1_2430;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:;Value?EndPoint2:;
# 1152 shape696 Point?element:MAV_OS1_022_066;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1156 shape697 Point?element:MAL_OS1_2430;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:;Value?EndPoint2:;
# 1161 shape698 Point?element:MAL_OS1_483;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_069;Value?EndPoint2:;
# 1163 shape699 Point?element:MAL_OS1_483;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_069;Value?EndPoint2:;
# 1165 shape592 Point?element:MAL_OS1_2424;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_162;Value?EndPoint2:MAV010;
# 1167 shape517 Point?element:MAV_OS1_022_162;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1171 shape384 Point?element:MAL_OS1_2424;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_162;Value?EndPoint2:;
# 1173 shape402 Point?element:MAL_OS1_2424;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_022_059;Value?EndPoint2:;
# 1175 shape494 Point?element:MAV_OS1_018_065;Value?DefElemType:5;Value?ShapeID:ValveMan;Value?DataBoundObj:plyValve;
# 1179 shape275 Point?element:MAL_OS1_312;Value?DefElemType:3;Value?ShapeID:Line;Value?DataBoundObj:linPipe;Value?EndPoint1:MAV_OS1_018_065;Value?EndPoint2:;

# %%
for i,div in enumerate(divs):
    if 'hsc.shape.1' in div['class']:
        print(i, div['id'], div['style'])
# Out:
# 0 shape385 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 80px; LEFT: 1685px
# 2 shape554 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 40px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 130px; LEFT: 1070px
# 4 shape001 POSITION: absolute; FONT-STYLE: normal; WIDTH: 103px; FONT-FAMILY: Arial; HEIGHT: 29px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 0px; LEFT: 5px
# 8 tfgPlanningData POSITION: absolute; FONT-STYLE: normal; WIDTH: 92px; FONT-FAMILY: Arial; HEIGHT: 14px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 4px; LEFT: 138px
# 10 tfgSelectTimeout POSITION: absolute; FONT-STYLE: normal; WIDTH: 60px; FONT-FAMILY: Arial; HEIGHT: 16px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 4px; LEFT: 77px
# 11 tfgOperDataReInit POSITION: absolute; FONT-STYLE: normal; WIDTH: 92px; FONT-FAMILY: Arial; HEIGHT: 14px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 4px; LEFT: 230px
# 13 tfgOffDisplayEndPoints POSITION: absolute; FONT-STYLE: normal; WIDTH: 92px; FONT-FAMILY: Arial; HEIGHT: 14px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 19px; LEFT: 175px
# 16 shape015 POSITION: absolute; FONT-STYLE: normal; WIDTH: 1910px; FONT-FAMILY: Arial; HEIGHT: 36px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 0px; LEFT: 0px
# 25 shape027 POSITION: absolute; FONT-STYLE: normal; WIDTH: 95px; FONT-FAMILY: Arial; HEIGHT: 18px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 70px; LEFT: 1810px
# 29 shape414 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 85px; LEFT: 200px
# 33 shape273 POSITION: absolute; FONT-STYLE: normal; WIDTH: 35px; FONT-FAMILY: Arial; HEIGHT: 35px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 75px; LEFT: 1195px
# 42 shape050 POSITION: absolute; FONT-STYLE: normal; WIDTH: 125px; FONT-FAMILY: Arial; HEIGHT: 80px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 40px; LEFT: 10px
# 44 shape050_shaTank POSITION: absolute; FONT-STYLE: normal; WIDTH: 90.76%; FONT-FAMILY: Arial; HEIGHT: 77.5%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 15%; LEFT: 5.38%
# 57 shape050_shaTankService POSITION: absolute; FONT-STYLE: normal; WIDTH: 9.23%; FONT-FAMILY: Arial; HEIGHT: 16.25%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior); TOP: 47.5%; LEFT: 23.07%
# 67 shape023 POSITION: absolute; FONT-STYLE: normal; WIDTH: 100px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 115px; LEFT: 25px
# 77 shape051 POSITION: absolute; FONT-STYLE: normal; WIDTH: 125px; FONT-FAMILY: Arial; HEIGHT: 80px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 145px; LEFT: 10px
# 79 shape051_shaTank POSITION: absolute; FONT-STYLE: normal; WIDTH: 90.76%; FONT-FAMILY: Arial; HEIGHT: 77.5%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 15%; LEFT: 5.38%
# 92 shape051_shaTankService POSITION: absolute; FONT-STYLE: normal; WIDTH: 9.23%; FONT-FAMILY: Arial; HEIGHT: 16.25%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior); TOP: 47.5%; LEFT: 23.07%
# 102 shape024 POSITION: absolute; FONT-STYLE: normal; WIDTH: 100px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 220px; LEFT: 25px
# 112 shape052 POSITION: absolute; FONT-STYLE: normal; WIDTH: 125px; FONT-FAMILY: Arial; HEIGHT: 80px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 250px; LEFT: 10px
# 114 shape052_shaTank POSITION: absolute; FONT-STYLE: normal; WIDTH: 90.76%; FONT-FAMILY: Arial; HEIGHT: 77.5%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 15%; LEFT: 5.38%
# 127 shape052_shaTankService POSITION: absolute; FONT-STYLE: normal; WIDTH: 9.23%; FONT-FAMILY: Arial; HEIGHT: 16.25%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior); TOP: 47.5%; LEFT: 23.07%
# 137 shape025 POSITION: absolute; FONT-STYLE: normal; WIDTH: 100px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 325px; LEFT: 25px
# 147 shape053 POSITION: absolute; FONT-STYLE: normal; WIDTH: 125px; FONT-FAMILY: Arial; HEIGHT: 80px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 355px; LEFT: 10px
# 149 shape053_shaTank POSITION: absolute; FONT-STYLE: normal; WIDTH: 90.76%; FONT-FAMILY: Arial; HEIGHT: 77.5%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 15%; LEFT: 5.38%
# 162 shape053_shaTankService POSITION: absolute; FONT-STYLE: normal; WIDTH: 9.23%; FONT-FAMILY: Arial; HEIGHT: 16.25%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior); TOP: 47.5%; LEFT: 23.07%
# 172 shape028 POSITION: absolute; FONT-STYLE: normal; WIDTH: 100px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 430px; LEFT: 25px
# 182 shape054 POSITION: absolute; FONT-STYLE: normal; WIDTH: 125px; FONT-FAMILY: Arial; HEIGHT: 80px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 465px; LEFT: 10px
# 184 shape054_shaTank POSITION: absolute; FONT-STYLE: normal; WIDTH: 90.76%; FONT-FAMILY: Arial; HEIGHT: 77.5%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 15%; LEFT: 5.38%
# 197 shape054_shaTankService POSITION: absolute; FONT-STYLE: normal; WIDTH: 9.23%; FONT-FAMILY: Arial; HEIGHT: 16.25%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior); TOP: 47.5%; LEFT: 23.07%
# 207 shape029 POSITION: absolute; FONT-STYLE: normal; WIDTH: 100px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 540px; LEFT: 25px
# 217 shape055 POSITION: absolute; FONT-STYLE: normal; WIDTH: 125px; FONT-FAMILY: Arial; HEIGHT: 80px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 575px; LEFT: 10px
# 219 shape055_shaTank POSITION: absolute; FONT-STYLE: normal; WIDTH: 90.76%; FONT-FAMILY: Arial; HEIGHT: 77.5%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 15%; LEFT: 5.38%
# 232 shape055_shaTankService POSITION: absolute; FONT-STYLE: normal; WIDTH: 9.23%; FONT-FAMILY: Arial; HEIGHT: 16.25%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior); TOP: 47.5%; LEFT: 23.07%
# 242 shape030 POSITION: absolute; FONT-STYLE: normal; WIDTH: 100px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 650px; LEFT: 25px
# 252 shape056 POSITION: absolute; FONT-STYLE: normal; WIDTH: 125px; FONT-FAMILY: Arial; HEIGHT: 80px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 690px; LEFT: 10px
# 254 shape056_shaTank POSITION: absolute; FONT-STYLE: normal; WIDTH: 90.76%; FONT-FAMILY: Arial; HEIGHT: 77.5%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 15%; LEFT: 5.38%
# 267 shape056_shaTankService POSITION: absolute; FONT-STYLE: normal; WIDTH: 9.23%; FONT-FAMILY: Arial; HEIGHT: 16.25%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior); TOP: 47.5%; LEFT: 23.07%
# 277 shape031 POSITION: absolute; FONT-STYLE: normal; WIDTH: 100px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 765px; LEFT: 25px
# 287 shape057 POSITION: absolute; FONT-STYLE: normal; WIDTH: 125px; FONT-FAMILY: Arial; HEIGHT: 80px; FONT-SIZE: 0px; FONT-WEIGHT: normal; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 790px; LEFT: 10px
# 289 shape057_shaTank POSITION: absolute; FONT-STYLE: normal; WIDTH: 90.76%; FONT-FAMILY: Arial; HEIGHT: 77.5%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 15%; LEFT: 5.38%
# 302 shape057_shaTankService POSITION: absolute; FONT-STYLE: normal; WIDTH: 9.23%; FONT-FAMILY: Arial; HEIGHT: 16.25%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior); TOP: 47.5%; LEFT: 23.07%
# 312 shape032 POSITION: absolute; FONT-STYLE: normal; WIDTH: 100px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 865px; LEFT: 25px
# 322 shape104 POSITION: absolute; FONT-STYLE: normal; WIDTH: 75px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 90px; LEFT: 130px
# 324 shape108 POSITION: absolute; FONT-STYLE: normal; WIDTH: 75px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 180px; LEFT: 130px
# 326 shape109 POSITION: absolute; FONT-STYLE: normal; WIDTH: 75px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 300px; LEFT: 130px
# 328 shape110 POSITION: absolute; FONT-STYLE: normal; WIDTH: 75px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 405px; LEFT: 130px
# 330 shape111 POSITION: absolute; FONT-STYLE: normal; WIDTH: 75px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 505px; LEFT: 130px
# 332 shape112 POSITION: absolute; FONT-STYLE: normal; WIDTH: 80px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 630px; LEFT: 125px
# 334 shape115 POSITION: absolute; FONT-STYLE: normal; WIDTH: 80px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 845px; LEFT: 125px
# 336 shape272 POSITION: absolute; FONT-STYLE: normal; WIDTH: 35px; FONT-FAMILY: Arial; HEIGHT: 35px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 280px; LEFT: 1195px
# 344 shape310 POSITION: absolute; FONT-STYLE: normal; WIDTH: 585px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 845px; LEFT: 465px
# 346 shape792 POSITION: absolute; FONT-STYLE: normal; WIDTH: 26px; FONT-FAMILY: Arial; HEIGHT: 18px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 70px; LEFT: 1780px
# 350 shape033 POSITION: absolute; FONT-STYLE: normal; WIDTH: 95px; FONT-FAMILY: Arial; HEIGHT: 18px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 415px; LEFT: 1810px
# 354 shape793 POSITION: absolute; FONT-STYLE: normal; WIDTH: 26px; FONT-FAMILY: Arial; HEIGHT: 18px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 415px; LEFT: 1780px
# 358 shape392 POSITION: absolute; FONT-STYLE: normal; WIDTH: 275px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 830px; LEFT: 1510px
# 360 shape794 POSITION: absolute; FONT-STYLE: normal; WIDTH: 26px; FONT-FAMILY: Arial; HEIGHT: 18px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 820px; LEFT: 1780px
# 364 shape415 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 175px; LEFT: 200px
# 369 shape416 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 295px; LEFT: 200px
# 373 shape417 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 400px; LEFT: 200px
# 377 shape418 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 500px; LEFT: 200px
# 381 shape421 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 625px; LEFT: 200px
# 385 shape423 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 840px; LEFT: 200px
# 389 shape223 POSITION: absolute; FONT-STYLE: normal; WIDTH: 435px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 90px; LEFT: 225px
# 391 shape232 POSITION: absolute; FONT-STYLE: normal; WIDTH: 210px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 180px; LEFT: 225px
# 393 shape240 POSITION: absolute; FONT-STYLE: normal; WIDTH: 255px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 300px; LEFT: 225px
# 395 shape444 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 400px; LEFT: 365px
# 399 shape250 POSITION: absolute; FONT-STYLE: normal; WIDTH: 145px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 405px; LEFT: 225px
# 401 shape254 POSITION: absolute; FONT-STYLE: normal; WIDTH: 275px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 505px; LEFT: 225px
# 403 shape255 POSITION: absolute; FONT-STYLE: normal; WIDTH: 35px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 505px; LEFT: 590px
# 405 shape447 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 500px; LEFT: 620px
# 409 shape266 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 630px; LEFT: 225px
# 411 shape269 POSITION: absolute; FONT-STYLE: normal; WIDTH: 170px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 845px; LEFT: 225px
# 413 shape274 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 845px; LEFT: 395px
# 415 shape457 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 840px; LEFT: 440px
# 419 shape551 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 815px; LEFT: 395px
# 421 shape276 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 785px; LEFT: 395px
# 423 shape458 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 780px; LEFT: 440px
# 427 shape552 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 785px; LEFT: 395px
# 429 shape277 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 815px; LEFT: 395px
# 431 shape459 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 810px; LEFT: 440px
# 435 shape278 POSITION: absolute; FONT-STYLE: normal; WIDTH: 35px; FONT-FAMILY: Arial; HEIGHT: 35px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 420px; LEFT: 1193px
# 443 shape279 POSITION: absolute; FONT-STYLE: normal; WIDTH: 35px; FONT-FAMILY: Arial; HEIGHT: 35px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 570px; LEFT: 1195px
# 451 shape281 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 90px; LEFT: 1150px
# 453 shape462 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 85px; LEFT: 1125px
# 457 shape282 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 300px; LEFT: 1150px
# 459 shape463 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 295px; LEFT: 1125px
# 463 shape283 POSITION: absolute; FONT-STYLE: normal; WIDTH: 100px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 90px; LEFT: 970px
# 465 shape284 POSITION: absolute; FONT-STYLE: normal; WIDTH: 60px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 90px; LEFT: 1070px
# 467 shape289 POSITION: absolute; FONT-STYLE: normal; WIDTH: 60px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 300px; LEFT: 1070px
# 469 shape553 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 40px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 90px; LEFT: 1070px
# 471 shape301 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 440px; LEFT: 1150px
# 473 shape506 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 435px; LEFT: 1125px
# 477 shape303 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 440px; LEFT: 1080px
# 479 shape563 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 45px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 395px; LEFT: 1080px
# 481 shape304 POSITION: absolute; FONT-STYLE: normal; WIDTH: 120px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 395px; LEFT: 1080px
# 483 shape507 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 390px; LEFT: 1195px
# 487 shape305 POSITION: absolute; FONT-STYLE: normal; WIDTH: 120px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 395px; LEFT: 1220px
# 489 shape564 POSITION: absolute; FONT-STYLE: normal; WIDTH: 5px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 395px; LEFT: 1340px
# 491 shape314 POSITION: absolute; FONT-STYLE: normal; WIDTH: 120px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 425px; LEFT: 1220px
# 493 shape315 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 425px; LEFT: 1340px
# 495 shape508 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 420px; LEFT: 1435px
# 499 shape329 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 425px; LEFT: 1390px
# 501 shape565 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 425px; LEFT: 1390px
# 503 shape509 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 450px; LEFT: 1435px
# 507 shape330 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 455px; LEFT: 1390px
# 509 shape334 POSITION: absolute; FONT-STYLE: normal; WIDTH: 90px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 440px; LEFT: 990px
# 511 shape566 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 35px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 440px; LEFT: 990px
# 513 shape510 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 555px; LEFT: 975px
# 517 shape371 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 475px; LEFT: 960px
# 519 shape511 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 470px; LEFT: 935px
# 523 shape568 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 25px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 475px; LEFT: 990px
# 525 shape393 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 500px; LEFT: 960px
# 527 shape512 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 495px; LEFT: 935px
# 531 shape569 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 25px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 500px; LEFT: 990px
# 533 shape394 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 525px; LEFT: 960px
# 535 shape513 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 520px; LEFT: 935px
# 539 shape570 POSITION: absolute; FONT-STYLE: normal; WIDTH: 15px; FONT-FAMILY: Arial; HEIGHT: 25px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 525px; LEFT: 990px
# 541 shape395 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 590px; LEFT: 1150px
# 543 shape514 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 585px; LEFT: 1125px
# 547 shape396 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 590px; LEFT: 1080px
# 549 shape571 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 45px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 545px; LEFT: 1080px
# 551 shape397 POSITION: absolute; FONT-STYLE: normal; WIDTH: 120px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 545px; LEFT: 1080px
# 553 shape515 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 540px; LEFT: 1195px
# 557 shape398 POSITION: absolute; FONT-STYLE: normal; WIDTH: 120px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 545px; LEFT: 1220px
# 559 shape577 POSITION: absolute; FONT-STYLE: normal; WIDTH: 5px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 545px; LEFT: 1340px
# 561 shape399 POSITION: absolute; FONT-STYLE: normal; WIDTH: 90px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 590px; LEFT: 990px
# 563 shape400 POSITION: absolute; FONT-STYLE: normal; WIDTH: 115px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 575px; LEFT: 1225px
# 565 shape401 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 575px; LEFT: 1340px
# 567 shape516 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 570px; LEFT: 1435px
# 571 shape404 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 425px; LEFT: 1460px
# 573 shape608 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 150px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 425px; LEFT: 1510px
# 575 shape405 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 575px; LEFT: 1460px
# 577 shape406 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 425px; LEFT: 1510px
# 579 shape609 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 425px; LEFT: 1560px
# 581 shape518 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 450px; LEFT: 1605px
# 585 shape407 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 455px; LEFT: 1560px
# 587 shape408 POSITION: absolute; FONT-STYLE: normal; WIDTH: 100px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 425px; LEFT: 1560px
# 589 shape610 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 425px; LEFT: 1660px
# 591 shape519 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 450px; LEFT: 1705px
# 595 shape409 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 455px; LEFT: 1660px
# 597 shape410 POSITION: absolute; FONT-STYLE: normal; WIDTH: 125px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 425px; LEFT: 1660px
# 599 shape523 POSITION: absolute; FONT-STYLE: normal; WIDTH: 140px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 405px; LEFT: 390px
# 601 shape627 POSITION: absolute; FONT-STYLE: normal; WIDTH: 365px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 630px; LEFT: 395px
# 603 shape651 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 90px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 500px; LEFT: 835px
# 605 shape308 POSITION: absolute; FONT-STYLE: normal; WIDTH: 35px; FONT-FAMILY: Arial; HEIGHT: 35px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 670px; LEFT: 1195px
# 613 shape309 POSITION: absolute; FONT-STYLE: normal; WIDTH: 35px; FONT-FAMILY: Arial; HEIGHT: 35px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 825px; LEFT: 1195px
# 621 shape312 POSITION: absolute; FONT-STYLE: normal; WIDTH: 45px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 845px; LEFT: 1155px
# 623 shape468 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 840px; LEFT: 1085px
# 627 shape313 POSITION: absolute; FONT-STYLE: normal; WIDTH: 45px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 845px; LEFT: 1110px
# 629 shape316 POSITION: absolute; FONT-STYLE: normal; WIDTH: 40px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 845px; LEFT: 1050px
# 631 shape469 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 795px; LEFT: 1195px
# 635 shape572 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 45px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 800px; LEFT: 1155px
# 637 shape318 POSITION: absolute; FONT-STYLE: normal; WIDTH: 45px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 800px; LEFT: 1155px
# 639 shape319 POSITION: absolute; FONT-STYLE: normal; WIDTH: 45px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 800px; LEFT: 1220px
# 641 shape573 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 800px; LEFT: 1265px
# 643 shape320 POSITION: absolute; FONT-STYLE: normal; WIDTH: 40px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 830px; LEFT: 1225px
# 645 shape321 POSITION: absolute; FONT-STYLE: normal; WIDTH: 115px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 830px; LEFT: 1265px
# 647 shape574 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 155px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 690px; LEFT: 1050px
# 649 shape470 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 685px; LEFT: 1085px
# 653 shape322 POSITION: absolute; FONT-STYLE: normal; WIDTH: 40px; FONT-FAMILY: Arial; HEIGHT: 20px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 690px; LEFT: 1050px
# 655 shape323 POSITION: absolute; FONT-STYLE: normal; WIDTH: 45px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 690px; LEFT: 1155px
# 657 shape324 POSITION: absolute; FONT-STYLE: normal; WIDTH: 45px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 690px; LEFT: 1110px
# 659 shape471 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 640px; LEFT: 1195px
# 663 shape575 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 45px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 645px; LEFT: 1155px
# 665 shape325 POSITION: absolute; FONT-STYLE: normal; WIDTH: 45px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 645px; LEFT: 1155px
# 667 shape326 POSITION: absolute; FONT-STYLE: normal; WIDTH: 45px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 645px; LEFT: 1220px
# 669 shape576 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 645px; LEFT: 1265px
# 671 shape327 POSITION: absolute; FONT-STYLE: normal; WIDTH: 40px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 675px; LEFT: 1225px
# 673 shape328 POSITION: absolute; FONT-STYLE: normal; WIDTH: 110px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 675px; LEFT: 1270px
# 675 shape472 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 670px; LEFT: 1375px
# 680 shape473 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 825px; LEFT: 1375px
# 685 shape390 POSITION: absolute; FONT-STYLE: normal; WIDTH: 110px; FONT-FAMILY: Arial; HEIGHT: 20px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 675px; LEFT: 1400px
# 687 shape391 POSITION: absolute; FONT-STYLE: normal; WIDTH: 110px; FONT-FAMILY: Arial; HEIGHT: 20px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 830px; LEFT: 1400px
# 689 shape607 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 155px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 675px; LEFT: 1510px
# 692 shape035 POSITION: absolute; FONT-STYLE: normal; WIDTH: 95px; FONT-FAMILY: Arial; HEIGHT: 18px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 820px; LEFT: 1810px
# 696 shape286 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 80px; LEFT: 1225px
# 698 shape467 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 75px; LEFT: 1270px
# 702 shape287 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 285px; LEFT: 1225px
# 704 shape476 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 280px; LEFT: 1270px
# 708 shape288 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 285px; LEFT: 1295px
# 710 shape302 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 80px; LEFT: 1295px
# 712 shape558 POSITION: absolute; FONT-STYLE: normal; WIDTH: 15px; FONT-FAMILY: Arial; HEIGHT: 60px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 80px; LEFT: 1345px
# 714 shape306 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 80px; LEFT: 1345px
# ...
# 1003 shape355 POSITION: absolute; FONT-STYLE: normal; WIDTH: 225px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 130px; LEFT: 435px
# 1005 shape678 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 130px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 170px; LEFT: 480px
# 1007 shape356 POSITION: absolute; FONT-STYLE: normal; WIDTH: 180px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 170px; LEFT: 480px
# 1009 shape679 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 195px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 210px; LEFT: 530px
# 1011 shape357 POSITION: absolute; FONT-STYLE: normal; WIDTH: 130px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 210px; LEFT: 530px
# 1014 shape589 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 330px; LEFT: 920px
# 1016 shape358 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 360px; LEFT: 840px
# 1018 shape485 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 355px; LEFT: 865px
# 1022 shape359 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 360px; LEFT: 890px
# 1024 shape360 POSITION: absolute; FONT-STYLE: normal; WIDTH: 25px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 330px; LEFT: 845px
# 1026 shape486 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 325px; LEFT: 865px
# 1030 shape361 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 330px; LEFT: 890px
# 1032 shape362 POSITION: absolute; FONT-STYLE: normal; WIDTH: 25px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 300px; LEFT: 845px
# 1034 shape487 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 295px; LEFT: 865px
# 1038 shape363 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 300px; LEFT: 890px
# 1040 shape364 POSITION: absolute; FONT-STYLE: normal; WIDTH: 25px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 270px; LEFT: 845px
# 1042 shape488 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 265px; LEFT: 865px
# 1046 shape365 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 270px; LEFT: 890px
# 1048 shape590 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 300px; LEFT: 920px
# 1050 shape591 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 270px; LEFT: 920px
# 1052 shape366 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 330px; LEFT: 805px
# 1054 shape367 POSITION: absolute; FONT-STYLE: normal; WIDTH: 25px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 300px; LEFT: 810px
# 1056 shape368 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 300px; LEFT: 770px
# 1058 shape369 POSITION: absolute; FONT-STYLE: normal; WIDTH: 25px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 270px; LEFT: 810px
# 1060 shape370 POSITION: absolute; FONT-STYLE: normal; WIDTH: 25px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 270px; LEFT: 775px
# 1062 shape372 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 270px; LEFT: 735px
# 1064 shape680 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 145px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 360px; LEFT: 590px
# 1066 shape373 POSITION: absolute; FONT-STYLE: normal; WIDTH: 45px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 360px; LEFT: 795px
# 1068 shape490 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 355px; LEFT: 770px
# 1072 shape374 POSITION: absolute; FONT-STYLE: normal; WIDTH: 185px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 360px; LEFT: 590px
# 1074 shape375 POSITION: absolute; FONT-STYLE: normal; WIDTH: 45px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 330px; LEFT: 760px
# 1076 shape491 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 325px; LEFT: 735px
# 1080 shape376 POSITION: absolute; FONT-STYLE: normal; WIDTH: 45px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 270px; LEFT: 690px
# 1082 shape492 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 265px; LEFT: 665px
# 1086 shape681 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 390px; LEFT: 905px
# 1090 shape682 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 20px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 405px; LEFT: 920px
# 1092 shape377 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 425px; LEFT: 890px
# 1094 shape378 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 455px; LEFT: 805px
# 1096 shape379 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 500px; LEFT: 805px
# 1098 shape683 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 425px; LEFT: 920px
# 1100 shape684 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 45px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 455px; LEFT: 835px
# 1102 shape380 POSITION: absolute; FONT-STYLE: normal; WIDTH: 40px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 590px; LEFT: 885px
# 1104 shape686 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 590px; LEFT: 835px
# 1106 shape689 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 420px; LEFT: 865px
# 1110 shape690 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 450px; LEFT: 780px
# 1114 shape691 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 495px; LEFT: 780px
# 1128 shape382 POSITION: absolute; FONT-STYLE: normal; WIDTH: 85px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 455px; LEFT: 835px
# 1130 shape692 POSITION: absolute; FONT-STYLE: normal; WIDTH: 105px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 695px; LEFT: 760px
# 1132 shape693 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 35px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 695px; LEFT: 760px
# 1138 shape383 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 130px; LEFT: 405px
# 1140 shape493 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 125px; LEFT: 380px
# 1146 shape694 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 690px; LEFT: 920px
# 1150 shape695 POSITION: absolute; FONT-STYLE: normal; WIDTH: 45px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 695px; LEFT: 885px
# 1152 shape696 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 655px; LEFT: 920px
# 1156 shape697 POSITION: absolute; FONT-STYLE: normal; WIDTH: 40px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 660px; LEFT: 885px
# 1161 shape698 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 630px; LEFT: 760px
# 1163 shape699 POSITION: absolute; FONT-STYLE: normal; WIDTH: 105px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 660px; LEFT: 760px
# 1165 shape592 POSITION: absolute; FONT-STYLE: normal; WIDTH: 10px; FONT-FAMILY: Arial; HEIGHT: 30px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 575px; LEFT: 1390px
# 1167 shape517 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 600px; LEFT: 1435px
# 1171 shape384 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 605px; LEFT: 1390px
# 1173 shape402 POSITION: absolute; FONT-STYLE: normal; WIDTH: 50px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 575px; LEFT: 1390px
# 1175 shape494 POSITION: absolute; FONT-STYLE: normal; WIDTH: 30px; FONT-FAMILY: Arial; HEIGHT: 10px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 500px; LEFT: 495px
# 1179 shape275 POSITION: absolute; FONT-STYLE: normal; WIDTH: 70px; FONT-FAMILY: Arial; HEIGHT: 15px; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink); TOP: 505px; LEFT: 520px

# %%
for idx,div in enumerate(divs[43]):
    print(idx,div)
# Out:
# 0
#
# 1 <div class="hsc.shape.1 HSC.ScriptDataObject.1" globalscripts="" hdxproperties="fillColorBlink:False;HDXBINDINGID:24;Height:62;lineColorBlink:False;Width:113;" id="shape050_shaTank" linktype="embedded" ondatachange="VBScript:Call OnDataChange(me.parentElement.parentElement, me)" parameters="" src=".\MA_CH_OS1_WAXY_files\IFRT_TANK_ovr_files\soilcrtankbox.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 90.76%; FONT-FAMILY: Arial; HEIGHT: 77.5%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 15%; LEFT: 5.38%" styleclass="" tabindex="-1" value="1">
# <div class="hvg.group.1" hdxproperties="FillColor:#ffffff;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillFocus:50;GradientFillStyle:0;Height:62;lineColorBlink:False;Width:113;" id="shape050_shaTank_group001" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.base.1" hdxproperties="FillColor:#ffffff;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:20;LineColor:#000000;lineColorBlink:False;Width:81;" id="shape050_shaTank_oval1" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 71.34%; FONT-FAMILY: Arial; HEIGHT: 32.23%; VISIBILITY: hidden; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#oval); TOP: 37.5%; LEFT: 10.97%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:#ffffff;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:62;LineColor:#c0c0c0;lineColorBlink:False;LineWidth:4;ObjectType:10;Points:93.70629 94.23077 98.6014 94.23077 98.6014 91.34615 98.6014 29.80769 98.6014 25.96154 101.3986 25.96154 49.65035 -0.9615384 -2.097902 25 1.293711 25.09616 0.6993007 25.09616 0.6993007 91.34615 0.6993007 94.23077 5.594406 94.23077 5.594406 100 16.08392 100 16.08392 94.23077 26.57343 91.34615 72.72727 91.34615 83.21678 94.23077 83.21678 100 93.70629 100 ;PointTypes:m l l l l l l l l l l l l l l l l l l l lx ;Rotation:0;textColor:#000000;Width:112;" id="shape050_shaTank_roundrect6" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 99.39%; FONT-FAMILY: Arial; HEIGHT: 99.34%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div></div>
# 2
#
# 3 <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:6;lineColorBlink:False;Width:110;" id="shape050_grpRoof" style="POSITION: absolute; WIDTH: 87.69%; HEIGHT: 7.5%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 35%; LEFT: 7.69%" tabindex="-1">
# <div class="hvg.base.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:1;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:0.000000 0.000000 100.000000 0.000000 ;textColor:#000000;Width:109;" id="shape050_line009" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 99.35%; FONT-FAMILY: Arial; HEIGHT: 12.5%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 0%; LEFT: 0%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:1;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:0.000000 0.000000 100.000000 0.000000 ;textColor:#000000;Width:90;" id="shape050_line010" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 81.41%; FONT-FAMILY: Arial; HEIGHT: 12.5%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 87.5%; LEFT: 10.25%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:5;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:0.000000 0.000000 0.000000 100.000000 ;textColor:#000000;Width:1;" id="shape050_line011" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 0.64%; FONT-FAMILY: Arial; HEIGHT: 87.5%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 12.5%; LEFT: 91.66%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:5;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:0.000000 0.000000 0.000000 100.000000 ;textColor:#000000;Width:1;" id="shape050_line012" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 0.64%; FONT-FAMILY: Arial; HEIGHT: 87.5%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 12.5%; LEFT: 10.89%" tabindex="-1"></div></div>
# 4 <textarea class="hsc.alpha.1 " hdxproperties="borderWidth:;fillColor:transparent;fillColorBlink:False;HDXBINDINGID:25;indicateScanState:0;lineColor:black;lineColorBlink:False;numberOfChars:4;numericDisplayFormat:%s;styleClass:;textColor:#ff0000;textColorBlink:False;" id="shape050_alpAlarmAbrv" style="POSITION: absolute; BORDER-BOTTOM-STYLE: none; BORDER-BOTTOM-COLOR: transparent; TEXT-ALIGN: center; BACKGROUND-COLOR: transparent; FONT-STYLE: normal; BORDER-TOP-COLOR: transparent; BORDER-LEFT-STYLE: none; WIDTH: 21.53%; FONT-FAMILY: Arial; WORD-WRAP: normal; BORDER-TOP-STYLE: none; HEIGHT: 11.25%; COLOR: #ff0000; BORDER-RIGHT-COLOR: transparent; BORDER-RIGHT-STYLE: none; FONT-SIZE: 5pt; OVERFLOW: hidden; BORDER-LEFT-COLOR: transparent; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXAlphaBehavior) url(#BindingBehavior); TOP: 63.75%; LEFT: 18.46%; ROWS: 1" tabindex="-1">Text</textarea>
# 5
#
# 6 <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:17;lineColorBlink:False;LineStyle:0;textColor:#000000;textColorBlink:False;TotalRotation:0;Width:72;" id="shape050_txtElementName" style="POSITION: absolute; TEXT-ALIGN: center; FONT-STYLE: normal; WIDTH: 57.69%; FONT-FAMILY: Arial; HEIGHT: 21.25%; COLOR: #000000; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: bold; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 17.5%; LEFT: 20%" tabindex="-1">TK53104</div>
# 7 <span class="hsc.indicator.1 " hdxproperties="borderStyle:inset;borderWidth:2px;BreakpointType:1;fillColor:transparent;fillColorBlink:0;HDXBINDINGID:26;indicateAlarmState:0;levelFillColor:deepskyblue;levelFillColorBlink:0;lineColor:#ffffff;lineColorBlink:0;styleClass:;" id="shape050_indLevel" printfillcolor="transparent" printinverse="false" printlevelfillcolor="#008080" printvaluepercent="33" style="BORDER-BOTTOM: transparent 2px; POSITION: absolute; BORDER-LEFT: transparent 2px; FONT-STYLE: normal; WIDTH: 7.69%; FONT-FAMILY: Arial; HEIGHT: 43.75%; COLOR: #000000; FONT-SIZE: 0pt; OVERFLOW: hidden; BORDER-TOP: transparent 2px; FONT-WEIGHT: 400; BORDER-RIGHT: transparent 2px; TEXT-DECORATION: none; BEHAVIOR: url(#HSCIndicatorBehavior) url(#BindingBehavior); TOP: 43.75%; LEFT: 10%" tabindex="-1"></span>
# 8
#
# 9 <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:6;LineColor:#000000;lineColorBlink:False;Width:7;" id="shape050_group002" style="POSITION: absolute; WIDTH: 5.38%; HEIGHT: 7.5%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 8.75%; LEFT: 50.76%" tabindex="-1">
# <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:6;LineColor:#c0c0c0;lineColorBlink:False;LineWidth:4;points:0 0 0 100 ;Width:1;" id="shape050_line001" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 10%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 0%; LEFT: 10%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:3;LineColor:#c0c0c0;lineColorBlink:False;LineWidth:4;points:-0.7468087 41.59325 33.86841 -81.48369 95.4071 -13.79135 99.25319 100.0548 ;Rotation:345;Width:6;" id="shape050_bezier002" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 90%; FONT-FAMILY: Arial; HEIGHT: 57.14%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#bezier); TOP: 7.14%; LEFT: 0%" tabindex="-1"></div></div>
# 10
#
# 11 <div class="hsc.shape.1 hsc.shapeanimation.1" globalscripts="" hdxproperties="fillColorBlink:False;HDXBINDINGID:27;Height:13;indicateAlarmState:False;indicateScanState:False;lineColorBlink:False;Width:12;" id="shape050_shaTankService" linktype="embedded" numberofshapesanimated="5" parameters="" src=".\MA_CH_OS1_WAXY_files\IFRT_TANK_ovr_files\tfgTankService.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 9.23%; FONT-FAMILY: Arial; HEIGHT: 16.25%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior); TOP: 47.5%; LEFT: 23.07%" styleclass="" tabindex="-1" value="1">
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:13;lineColorBlink:False;Width:12;" id="shape050_shaTankService_grpOOService" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;Height:13;lineColorBlink:False;LineStyle:0;Width:12;" id="shape050_shaTankService_recOOS" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:5;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:100.000000 0.000000 0.000000 100.000000 ;Width:4;" id="shape050_shaTankService_plyOOS1" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 35.71%; FONT-FAMILY: Arial; HEIGHT: 35.71%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#polyline); TOP: 35.71%; LEFT: 35.71%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;Height:8;LineColor:#000000;lineColorBlink:False;LineWidth:2;Width:8;" id="shape050_shaTankService_ovlOOS" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 64.28%; FONT-FAMILY: Arial; HEIGHT: 64.28%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#oval); TOP: 21.42%; LEFT: 21.42%" tabindex="-1"></div></div></div>
# 12
#
# 13 <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:1;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:6;points:0.000000 0.000000 100.000000 0.000000 ;Width:7;" id="shape050_linNozzle" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 5.38%; FONT-FAMILY: Arial; HEIGHT: 1.25%; VISIBILITY: hidden; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 72.5%; LEFT: 66.15%" tabindex="-1"></div>
# 14
#
# 15 <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;Height:80;LineColor:transparent;lineColorBlink:False;LineStyle:0;LineWidth:2;Width:125;" id="shape050_recSelectBox" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div>
# 16
#
# 17 <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:14;lineColorBlink:False;LineStyle:0;textColor:#00004a;textColorBlink:False;TotalRotation:0;Width:24;" id="shape050_textbox001" style="POSITION: absolute; TEXT-ALIGN: left; FONT-STYLE: normal; WIDTH: 19.23%; FONT-FAMILY: Arial; HEIGHT: 17.5%; COLOR: #00004a; FONT-SIZE: 7pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 45%; LEFT: 73.84%" tabindex="-1">DegC</div>
# 18 <textarea class="hsc.alpha.1" hdxproperties="fillColor:transparent;fillColorBlink:False;HDXBINDINGID:28;lineColor:black;numberOfChars:9;numericDisplayFormat:%.1f;textColor:#00004a;textColorBlink:False;" id="shape050_alpha001" style="POSITION: absolute; BORDER-BOTTOM-STYLE: none; TEXT-ALIGN: right; BACKGROUND-COLOR: transparent; FONT-STYLE: normal; BORDER-LEFT-STYLE: none; WIDTH: 45.38%; FONT-FAMILY: Arial; WORD-WRAP: normal; BORDER-TOP-STYLE: none; HEIGHT: 16.25%; COLOR: #00004a; BORDER-RIGHT-STYLE: none; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXAlphaBehavior) url(#BindingBehavior) url(#HoverBehavior); TOP: 42.5%; LEFT: 27.69%; ROWS: 1" tabindex="0">9999.99</textarea>
# 19 <textarea class="hsc.alpha.1" hdxproperties="fillColor:transparent;fillColorBlink:False;HDXBINDINGID:29;lineColor:black;lineColorBlink:False;numberOfChars:9;numericDisplayFormat:%.0f;textColor:#00004a;textColorBlink:False;" id="shape050_alpha003" style="POSITION: absolute; BORDER-BOTTOM-STYLE: none; TEXT-ALIGN: right; BACKGROUND-COLOR: transparent; FONT-STYLE: normal; BORDER-LEFT-STYLE: none; WIDTH: 45.38%; FONT-FAMILY: Arial; WORD-WRAP: normal; BORDER-TOP-STYLE: none; HEIGHT: 16.25%; COLOR: #00004a; BORDER-RIGHT-STYLE: none; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXAlphaBehavior) url(#BindingBehavior) url(#HoverBehavior); TOP: 56.25%; LEFT: 26.92%; ROWS: 1" tabindex="0">9999.99</textarea>
# 20
#
# 21 <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:14;lineColorBlink:False;LineStyle:0;textColor:#00004a;textColorBlink:False;TotalRotation:0;Width:24;" id="shape050_textbox003" style="POSITION: absolute; TEXT-ALIGN: left; FONT-STYLE: normal; WIDTH: 19.23%; FONT-FAMILY: Arial; HEIGHT: 17.5%; COLOR: #00004a; FONT-SIZE: 7pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 58.75%; LEFT: 75.38%" tabindex="-1">mm</div>
# 22 <textarea class="hsc.alpha.1" hdxproperties="fillColor:transparent;fillColorBlink:False;HDXBINDINGID:30;indicateAlarmState:0;lineColor:black;numberOfChars:9;numericDisplayFormat:%.2f;textColor:#00004a;textColorBlink:False;" id="shape050_alpha004" style="POSITION: absolute; BORDER-BOTTOM-STYLE: none; TEXT-ALIGN: right; BACKGROUND-COLOR: transparent; FONT-STYLE: normal; BORDER-LEFT-STYLE: none; WIDTH: 45.38%; FONT-FAMILY: Arial; WORD-WRAP: normal; BORDER-TOP-STYLE: none; HEIGHT: 16.25%; COLOR: #00004a; BORDER-RIGHT-STYLE: none; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXAlphaBehavior) url(#BindingBehavior) url(#HoverBehavior); TOP: 70%; LEFT: 26.15%; ROWS: 1" tabindex="0">9999.99</textarea>
# 23
#
# 24 <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:14;lineColorBlink:False;LineStyle:0;textColor:#00004a;textColorBlink:False;TotalRotation:0;Width:24;" id="shape050_textbox004" style="POSITION: absolute; TEXT-ALIGN: left; FONT-STYLE: normal; WIDTH: 19.23%; FONT-FAMILY: Arial; HEIGHT: 17.5%; COLOR: #00004a; FONT-SIZE: 7pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 72.5%; LEFT: 73.84%" tabindex="-1">BBL</div>

# %%
for i,div in enumerate(divs):
    if 'hsc.shape.1' in div['class']:
        parameters = div['parameters'].split(';')
        if len(parameters) == 2:
            print(parameters, len(parameters))
# Out:
# ['T?T:U-2400', ''] 2
# ['T?T:U-2600', ''] 2
# ['T?T:U-20200', ''] 2

# %%
for idx,div in enumerate(divs[78]):
    print(idx,div)
# Out:
# 0
#
# 1 <div class="hsc.shape.1 HSC.ScriptDataObject.1" globalscripts="" hdxproperties="fillColorBlink:False;HDXBINDINGID:68;Height:62;lineColorBlink:False;Width:113;" id="shape051_shaTank" linktype="embedded" ondatachange="VBScript:Call OnDataChange(me.parentElement.parentElement, me)" parameters="" src=".\MA_CH_OS1_WAXY_files\IFRT_TANK_ovr_files\soilcrtankbox.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 90.76%; FONT-FAMILY: Arial; HEIGHT: 77.5%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior); TOP: 15%; LEFT: 5.38%" styleclass="" tabindex="-1" value="1">
# <div class="hvg.group.1" hdxproperties="FillColor:#ffffff;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillFocus:50;GradientFillStyle:0;Height:62;lineColorBlink:False;Width:113;" id="shape051_shaTank_group001" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.base.1" hdxproperties="FillColor:#ffffff;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:20;LineColor:#000000;lineColorBlink:False;Width:81;" id="shape051_shaTank_oval1" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 71.34%; FONT-FAMILY: Arial; HEIGHT: 32.23%; VISIBILITY: hidden; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#oval); TOP: 37.5%; LEFT: 10.97%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:#ffffff;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:62;LineColor:#c0c0c0;lineColorBlink:False;LineWidth:4;ObjectType:10;Points:93.70629 94.23077 98.6014 94.23077 98.6014 91.34615 98.6014 29.80769 98.6014 25.96154 101.3986 25.96154 49.65035 -0.9615384 -2.097902 25 1.293711 25.09616 0.6993007 25.09616 0.6993007 91.34615 0.6993007 94.23077 5.594406 94.23077 5.594406 100 16.08392 100 16.08392 94.23077 26.57343 91.34615 72.72727 91.34615 83.21678 94.23077 83.21678 100 93.70629 100 ;PointTypes:m l l l l l l l l l l l l l l l l l l l lx ;Rotation:0;textColor:#000000;Width:112;" id="shape051_shaTank_roundrect6" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 99.39%; FONT-FAMILY: Arial; HEIGHT: 99.34%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div></div></div>
# 2
#
# 3 <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:6;lineColorBlink:False;Width:110;" id="shape051_grpRoof" style="POSITION: absolute; WIDTH: 87.69%; HEIGHT: 7.5%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 35%; LEFT: 7.69%" tabindex="-1">
# <div class="hvg.base.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:1;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:0.000000 0.000000 100.000000 0.000000 ;textColor:#000000;Width:109;" id="shape051_line009" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 99.35%; FONT-FAMILY: Arial; HEIGHT: 12.5%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 0%; LEFT: 0%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:1;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:0.000000 0.000000 100.000000 0.000000 ;textColor:#000000;Width:90;" id="shape051_line010" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 81.41%; FONT-FAMILY: Arial; HEIGHT: 12.5%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 87.5%; LEFT: 10.25%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:5;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:0.000000 0.000000 0.000000 100.000000 ;textColor:#000000;Width:1;" id="shape051_line011" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 0.64%; FONT-FAMILY: Arial; HEIGHT: 87.5%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 12.5%; LEFT: 91.66%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:#c0c0c0;fillColorBlink:False;FillStyle:2;GradientFillColor:#808080;GradientFillStyle:0;Height:5;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:0.000000 0.000000 0.000000 100.000000 ;textColor:#000000;Width:1;" id="shape051_line012" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 0.64%; FONT-FAMILY: Arial; HEIGHT: 87.5%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 12.5%; LEFT: 10.89%" tabindex="-1"></div></div>
# 4 <textarea class="hsc.alpha.1 " hdxproperties="borderWidth:;fillColor:transparent;fillColorBlink:False;HDXBINDINGID:69;indicateScanState:0;lineColor:black;lineColorBlink:False;numberOfChars:4;numericDisplayFormat:%s;styleClass:;textColor:#ff0000;textColorBlink:False;" id="shape051_alpAlarmAbrv" style="POSITION: absolute; BORDER-BOTTOM-STYLE: none; BORDER-BOTTOM-COLOR: transparent; TEXT-ALIGN: center; BACKGROUND-COLOR: transparent; FONT-STYLE: normal; BORDER-TOP-COLOR: transparent; BORDER-LEFT-STYLE: none; WIDTH: 21.53%; FONT-FAMILY: Arial; WORD-WRAP: normal; BORDER-TOP-STYLE: none; HEIGHT: 11.25%; COLOR: #ff0000; BORDER-RIGHT-COLOR: transparent; BORDER-RIGHT-STYLE: none; FONT-SIZE: 5pt; OVERFLOW: hidden; BORDER-LEFT-COLOR: transparent; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXAlphaBehavior) url(#BindingBehavior); TOP: 63.75%; LEFT: 18.46%; ROWS: 1" tabindex="-1">Text</textarea>
# 5
#
# 6 <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:17;lineColorBlink:False;LineStyle:0;textColor:#000000;textColorBlink:False;TotalRotation:0;Width:72;" id="shape051_txtElementName" style="POSITION: absolute; TEXT-ALIGN: center; FONT-STYLE: normal; WIDTH: 57.69%; FONT-FAMILY: Arial; HEIGHT: 21.25%; COLOR: #000000; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: bold; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 17.5%; LEFT: 20%" tabindex="-1">TK53105</div>
# 7 <span class="hsc.indicator.1 " hdxproperties="borderStyle:inset;borderWidth:2px;BreakpointType:1;fillColor:transparent;fillColorBlink:0;HDXBINDINGID:70;indicateAlarmState:0;levelFillColor:deepskyblue;levelFillColorBlink:0;lineColor:#ffffff;lineColorBlink:0;styleClass:;" id="shape051_indLevel" printfillcolor="transparent" printinverse="false" printlevelfillcolor="#008080" printvaluepercent="33" style="BORDER-BOTTOM: transparent 2px; POSITION: absolute; BORDER-LEFT: transparent 2px; FONT-STYLE: normal; WIDTH: 7.69%; FONT-FAMILY: Arial; HEIGHT: 43.75%; COLOR: #000000; FONT-SIZE: 0pt; OVERFLOW: hidden; BORDER-TOP: transparent 2px; FONT-WEIGHT: 400; BORDER-RIGHT: transparent 2px; TEXT-DECORATION: none; BEHAVIOR: url(#HSCIndicatorBehavior) url(#BindingBehavior); TOP: 43.75%; LEFT: 10%" tabindex="-1"></span>
# 8
#
# 9 <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:6;LineColor:#000000;lineColorBlink:False;Width:7;" id="shape051_group002" style="POSITION: absolute; WIDTH: 5.38%; HEIGHT: 7.5%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 8.75%; LEFT: 50.76%" tabindex="-1">
# <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:6;LineColor:#c0c0c0;lineColorBlink:False;LineWidth:4;points:0 0 0 100 ;Width:1;" id="shape051_line001" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 10%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 0%; LEFT: 10%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:3;LineColor:#c0c0c0;lineColorBlink:False;LineWidth:4;points:-0.7468087 41.59325 33.86841 -81.48369 95.4071 -13.79135 99.25319 100.0548 ;Rotation:345;Width:6;" id="shape051_bezier002" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 90%; FONT-FAMILY: Arial; HEIGHT: 57.14%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#bezier); TOP: 7.14%; LEFT: 0%" tabindex="-1"></div></div>
# 10
#
# 11 <div class="hsc.shape.1 hsc.shapeanimation.1" globalscripts="" hdxproperties="fillColorBlink:False;HDXBINDINGID:71;Height:13;indicateAlarmState:False;indicateScanState:False;lineColorBlink:False;Width:12;" id="shape051_shaTankService" linktype="embedded" numberofshapesanimated="5" parameters="" src=".\MA_CH_OS1_WAXY_files\IFRT_TANK_ovr_files\tfgTankService.sha" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 9.23%; FONT-FAMILY: Arial; HEIGHT: 16.25%; FONT-SIZE: 0px; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior); TOP: 47.5%; LEFT: 23.07%" styleclass="" tabindex="-1" value="1">
# <div class="hvg.group.1" hdxproperties="fillColorBlink:False;Height:13;lineColorBlink:False;Width:12;" id="shape051_shaTankService_grpOOService" style="POSITION: absolute; WIDTH: 100%; HEIGHT: 100%; FONT-SIZE: 0pt; BEHAVIOR: url(#HDXVectorFactory#group); TOP: 0%; LEFT: 0%" tabindex="-1">
# <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;Height:13;lineColorBlink:False;LineStyle:0;Width:12;" id="shape051_shaTankService_recOOS" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:5;LineColor:#000000;lineColorBlink:False;LineWidth:2;points:100.000000 0.000000 0.000000 100.000000 ;Width:4;" id="shape051_shaTankService_plyOOS1" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 35.71%; FONT-FAMILY: Arial; HEIGHT: 35.71%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#polyline); TOP: 35.71%; LEFT: 35.71%" tabindex="-1"></div>
# <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;Height:8;LineColor:#000000;lineColorBlink:False;LineWidth:2;Width:8;" id="shape051_shaTankService_ovlOOS" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 64.28%; FONT-FAMILY: Arial; HEIGHT: 64.28%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#oval); TOP: 21.42%; LEFT: 21.42%" tabindex="-1"></div></div></div>
# 12
#
# 13 <div class="hvg.base.1" hdxproperties="fillColorBlink:False;Height:1;LineColor:#a0a0a0;lineColorBlink:False;LineWidth:6;points:0.000000 0.000000 100.000000 0.000000 ;Width:7;" id="shape051_linNozzle" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 5.38%; FONT-FAMILY: Arial; HEIGHT: 1.25%; VISIBILITY: hidden; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#line); TOP: 72.5%; LEFT: 66.15%" tabindex="-1"></div>
# 14
#
# 15 <div class="hvg.base.1" hdxproperties="FillColor:transparent;fillColorBlink:False;FillStyle:1;Height:80;LineColor:transparent;lineColorBlink:False;LineStyle:0;LineWidth:2;Width:125;" id="shape051_recSelectBox" style="POSITION: absolute; FONT-STYLE: normal; WIDTH: 100%; FONT-FAMILY: Arial; HEIGHT: 100%; FONT-SIZE: 12pt; OVERFLOW: hidden; FONT-WEIGHT: 400; TEXT-DECORATION: none; BEHAVIOR: url(#HDXVectorFactory#rect); TOP: 0%; LEFT: 0%" tabindex="-1"></div>
# 16
#
# 17 <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:14;lineColorBlink:False;LineStyle:0;textColor:#00004a;textColorBlink:False;TotalRotation:0;Width:24;" id="shape051_textbox001" style="POSITION: absolute; TEXT-ALIGN: left; FONT-STYLE: normal; WIDTH: 19.23%; FONT-FAMILY: Arial; HEIGHT: 17.5%; COLOR: #00004a; FONT-SIZE: 7pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 45%; LEFT: 73.84%" tabindex="-1">DegC</div>
# 18 <textarea class="hsc.alpha.1" hdxproperties="fillColor:transparent;fillColorBlink:False;HDXBINDINGID:72;lineColor:black;numberOfChars:9;numericDisplayFormat:%.1f;textColor:#00004a;textColorBlink:False;" id="shape051_alpha001" style="POSITION: absolute; BORDER-BOTTOM-STYLE: none; TEXT-ALIGN: right; BACKGROUND-COLOR: transparent; FONT-STYLE: normal; BORDER-LEFT-STYLE: none; WIDTH: 45.38%; FONT-FAMILY: Arial; WORD-WRAP: normal; BORDER-TOP-STYLE: none; HEIGHT: 16.25%; COLOR: #00004a; BORDER-RIGHT-STYLE: none; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXAlphaBehavior) url(#BindingBehavior) url(#HoverBehavior); TOP: 42.5%; LEFT: 27.69%; ROWS: 1" tabindex="0">9999.99</textarea>
# 19 <textarea class="hsc.alpha.1" hdxproperties="fillColor:transparent;fillColorBlink:False;HDXBINDINGID:73;lineColor:black;lineColorBlink:False;numberOfChars:9;numericDisplayFormat:%.0f;textColor:#00004a;textColorBlink:False;" id="shape051_alpha003" style="POSITION: absolute; BORDER-BOTTOM-STYLE: none; TEXT-ALIGN: right; BACKGROUND-COLOR: transparent; FONT-STYLE: normal; BORDER-LEFT-STYLE: none; WIDTH: 45.38%; FONT-FAMILY: Arial; WORD-WRAP: normal; BORDER-TOP-STYLE: none; HEIGHT: 16.25%; COLOR: #00004a; BORDER-RIGHT-STYLE: none; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXAlphaBehavior) url(#BindingBehavior) url(#HoverBehavior); TOP: 56.25%; LEFT: 26.92%; ROWS: 1" tabindex="0">9999.99</textarea>
# 20
#
# 21 <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:14;lineColorBlink:False;LineStyle:0;textColor:#00004a;textColorBlink:False;TotalRotation:0;Width:24;" id="shape051_textbox003" style="POSITION: absolute; TEXT-ALIGN: left; FONT-STYLE: normal; WIDTH: 19.23%; FONT-FAMILY: Arial; HEIGHT: 17.5%; COLOR: #00004a; FONT-SIZE: 7pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 58.75%; LEFT: 75.38%" tabindex="-1">mm</div>
# 22 <textarea class="hsc.alpha.1" hdxproperties="fillColor:transparent;fillColorBlink:False;HDXBINDINGID:74;indicateAlarmState:0;lineColor:black;numberOfChars:9;numericDisplayFormat:%.2f;textColor:#00004a;textColorBlink:False;" id="shape051_alpha004" style="POSITION: absolute; BORDER-BOTTOM-STYLE: none; TEXT-ALIGN: right; BACKGROUND-COLOR: transparent; FONT-STYLE: normal; BORDER-LEFT-STYLE: none; WIDTH: 45.38%; FONT-FAMILY: Arial; WORD-WRAP: normal; BORDER-TOP-STYLE: none; HEIGHT: 16.25%; COLOR: #00004a; BORDER-RIGHT-STYLE: none; FONT-SIZE: 8pt; OVERFLOW: hidden; FONT-WEIGHT: bold; TEXT-DECORATION: none; BEHAVIOR: url(#HDXAlphaBehavior) url(#BindingBehavior) url(#HoverBehavior); TOP: 70%; LEFT: 26.15%; ROWS: 1" tabindex="0">9999.99</textarea>
# 23
#
# 24 <div class="hvg.textbox.1" hdxproperties="fillColorBlink:False;FillStyle:1;Height:14;lineColorBlink:False;LineStyle:0;textColor:#00004a;textColorBlink:False;TotalRotation:0;Width:24;" id="shape051_textbox004" style="POSITION: absolute; TEXT-ALIGN: left; FONT-STYLE: normal; WIDTH: 19.23%; FONT-FAMILY: Arial; HEIGHT: 17.5%; COLOR: #00004a; FONT-SIZE: 7pt; OVERFLOW: hidden; FONT-WEIGHT: normal; BEHAVIOR: url(#HDXVectorFactory#text); TOP: 72.5%; LEFT: 73.84%" tabindex="-1">BBL</div>

# %%
[div['parameters'].split(';') for div in divs if 'hsc.shape.1' in div['class']]
# Out:
# [['Point?element:MAL_OS1_7280',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_013_014~MAV_OS1_013_013',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_314',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108',
#   'Value?EndPoint2:MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110',
#   ''],
#  [''],
#  ['Point?DestElement:',
#   'Point?SrcElement:',
#   'Value?IgnoreOnDataChange:"True"',
#   ''],
#  ['Point?DestElement:',
#   'Point?SrcElement:',
#   'Value?IgnoreOnDataChange:"True"',
#   ''],
#  [''],
#  ['Point?Element1:',
#   'Point?Element2:',
#   'Point?Element3:',
#   'Point?Element4:',
#   'Point?Element5:',
#   'Point?Element6:',
#   'Point?Element7:',
#   'Point?Element8:',
#   'Point?Element9:',
#   'Point?Element10:',
#   'Point?Element11:',
#   'Point?Element12:',
#   'Point?Element13:',
#   'Point?Element14:',
#   'Point?Element15:',
#   'Point?Element16:',
#   'Point?Element17:',
#   'Point?Element18:',
#   'Point?Element19:',
#   'Point?Element20:',
#   'Point?Element21:',
#   'Point?Element22:',
#   'Point?Element23:',
#   'Point?Element24:',
#   'Point?Element25:',
#   'Point?Element26:',
#   'Point?Element27:',
#   'Point?Element28:',
#   'Point?Element29:',
#   'Point?Element30:',
#   'Point?Element31:',
#   'Point?Element32:',
#   'Point?Element33:',
#   'Point?Element34:',
#   'Point?Element35:',
#   'Point?Element36:',
#   'Point?Element37:',
#   'Point?Element38:',
#   'Point?Element39:',
#   'Point?Element40:',
#   ''],
#  ['TEXT?ACTIVITY:CH',
#   'TEXT?AREA:제품운영1과',
#   'TEXT?TANK:-',
#   'TEXT?PRODUCT:WAXY',
#   ''],
#  ['T?T:U-2400', ''],
#  ['Point?element:MAV_OS1_054_002',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:_P53102A',
#   'Value?DefElemType:4',
#   'Value?ShapeID:CPump',
#   'Value?DataBoundObj:plyPump',
#   ''],
#  ['Point?element:TK53104',
#   'Value?DefElemType:1',
#   'Value?ShapeID:TankNozzle',
#   'Value?DataBoundObj:shaTank',
#   ''],
#  [''],
#  [''],
#  ['Point?TankName:TK53104',
#   'Parameter?TaskID:TaskID',
#   'Parameter?Material:Matlcode',
#   'TEXT?MATERIAL:W-31',
#   ''],
#  ['Point?element:TK53105',
#   'Value?DefElemType:1',
#   'Value?ShapeID:TankNozzle',
#   'Value?DataBoundObj:shaTank',
#   ''],
#  [''],
#  [''],
#  ['Point?TankName:TK53105',
#   'Parameter?TaskID:TaskID',
#   'Parameter?Material:Matlcode',
#   'TEXT?MATERIAL:W-96S',
#   ''],
#  ['Point?element:TK53106',
#   'Value?DefElemType:1',
#   'Value?ShapeID:TankNozzle',
#   'Value?DataBoundObj:shaTank',
#   ''],
#  [''],
#  [''],
#  ['Point?TankName:TK53106',
#   'Parameter?TaskID:TaskID',
#   'Parameter?Material:Matlcode',
#   'TEXT?MATERIAL:W-20',
#   ''],
#  ['Point?element:TK53107',
#   'Value?DefElemType:1',
#   'Value?ShapeID:TankNozzle',
#   'Value?DataBoundObj:shaTank',
#   ''],
#  [''],
#  [''],
#  ['Point?TankName:TK53107',
#   'Parameter?TaskID:TaskID',
#   'Parameter?Material:Matlcode',
#   'TEXT?MATERIAL:W-116',
#   ''],
#  ['Point?element:TK53109',
#   'Value?DefElemType:1',
#   'Value?ShapeID:TankNozzle',
#   'Value?DataBoundObj:shaTank',
#   ''],
#  [''],
#  [''],
#  ['Point?TankName:TK53109',
#   'Parameter?TaskID:TaskID',
#   'Parameter?Material:Matlcode',
#   'TEXT?MATERIAL:W-480',
#   ''],
#  ['Point?element:TK53110',
#   'Value?DefElemType:1',
#   'Value?ShapeID:TankNozzle',
#   'Value?DataBoundObj:shaTank',
#   ''],
#  [''],
#  [''],
#  ['Point?TankName:TK53110',
#   'Parameter?TaskID:TaskID',
#   'Parameter?Material:Matlcode',
#   'TEXT?MATERIAL:W-31S',
#   ''],
#  ['Point?element:TK53111',
#   'Value?DefElemType:1',
#   'Value?ShapeID:TankNozzle',
#   'Value?DataBoundObj:shaTank',
#   ''],
#  [''],
#  [''],
#  ['Point?TankName:TK53110',
#   'Parameter?TaskID:TaskID',
#   'Parameter?Material:Matlcode',
#   'TEXT?MATERIAL:W-31S',
#   ''],
#  ['Point?element:TK5397',
#   'Value?DefElemType:1',
#   'Value?ShapeID:TankNozzle',
#   'Value?DataBoundObj:shaTank',
#   ''],
#  [''],
#  [''],
#  ['Point?TankName:TK5397',
#   'Parameter?TaskID:TaskID',
#   'Parameter?Material:Matlcode',
#   'TEXT?MATERIAL:Mix-W',
#   ''],
#  ['Point?element:MAL_OS1_218',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_054_002',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_220',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_054_017',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_230',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_054_021',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_232',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_054_026',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_202',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_053_027',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_483',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_062_004',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_417',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_059_006',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:_P53102B',
#   'Value?DefElemType:4',
#   'Value?ShapeID:CPump',
#   'Value?DataBoundObj:plyPump',
#   ''],
#  ['Point?element:MAL_OS1_360',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_021_122',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:UN2400_WAXY',
#   'Value?DefElemType:2',
#   'Value?ShapeID:BP',
#   'Value?DataBoundObj:plyBPArrow',
#   ''],
#  ['T?T:U-2600', ''],
#  ['Point?element:UN2600_WAXY',
#   'Value?DefElemType:2',
#   'Value?ShapeID:BP',
#   'Value?DataBoundObj:plyBPArrow',
#   ''],
#  ['Point?element:MAL_OS1_359',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_136',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:UN20200_WAXY',
#   'Value?DefElemType:2',
#   'Value?ShapeID:BP',
#   'Value?DataBoundObj:plyBPArrow',
#   ''],
#  ['Point?element:MAV_OS1_054_017',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_054_021',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_054_026',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_053_027',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_062_004',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_059_006',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_218',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_220',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_230',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_017_024',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_232',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_202',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_312',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_104',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_104',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_483',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_062_004',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_417',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_059_006',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_417',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_021_122',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_021_122',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_417',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_021_140~MAV_OS1_021_117',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_417',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_021_117',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_021_117',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_417',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_021_117',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_417',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_021_140',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_021_140',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:_P53104A',
#   'Value?DefElemType:4',
#   'Value?ShapeID:CPump',
#   'Value?DataBoundObj:plyPump',
#   ''],
#  ['Point?element:_P53104B',
#   'Value?DefElemType:4',
#   'Value?ShapeID:CPump',
#   'Value?DataBoundObj:plyPump',
#   ''],
#  ['Point?element:MAL_OS1_271',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_007',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_272',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_008',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_314',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_109',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_314',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_007',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_314',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_008',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_314',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_007~MAV_OS1_018_109',
#   'Value?EndPoint2:MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110~MAV_OS1_018_108',
#   ''],
#  ['Point?element:MAL_OS1_2432',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_022_062',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2431',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2431',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV005~MAV004',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_2431',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:OMAVALVE',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2433',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2433',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV005~MAV004',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_2433',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2433',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_022_073',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2433',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_073',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2433',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_074',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_022_074',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2433',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_074',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2431',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2431',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV005~MAV004',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAV_OS1_022_061',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2431',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_072',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_022_072',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2431',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV005~MAV004',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_2431',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_033',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_022_033',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2431',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV005~MAV004',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_2431',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_057',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_022_057',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2431',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_061',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2428',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_022_060',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2426',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_060',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2426',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV005~MAV004',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_2426',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:OMAVALVE',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2424',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2424',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV005~MAV004',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_2426',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067~MAV_OS1_022_063~MAV_OS1_022_061',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2424',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2424',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_022_059',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_5002',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_073',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_5002',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_059',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_5002',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_059',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_5002',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:UN2600_WAXY',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_5002',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_019_004',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_019_004',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_5002',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_019_004',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_5002',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:UN2600_WAXY',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_5002',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_014_003',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_014_003',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_5002',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_014_003',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_5002',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:UN2600_WAXY',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_246',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_483',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_069',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_325',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_064',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:_P5399A',
#   'Value?DefElemType:4',
#   'Value?ShapeID:CPump',
#   'Value?DataBoundObj:plyPump',
#   ''],
#  ['Point?element:_P5399B',
#   'Value?DefElemType:4',
#   'Value?ShapeID:CPump',
#   'Value?DataBoundObj:plyPump',
#   ''],
#  ['Point?element:MAL_OS1_289',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_043',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_289',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_043',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_360',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_043',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:OMAVALVE',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_289',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:OMAVALVE',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_289',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:OMAVALVE',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_288',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:OMAVALVE',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_288',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:OMAVALVE',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_288',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:_P5399BR',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_288',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_136',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_360',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_042',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_042',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_360',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_042',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_287',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:_P5399AL',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_287',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_042',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:OMAVALVE',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_287',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:OMAVALVE',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_287',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:OMAVALVE',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_286',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:OMAVALVE',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_286',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:OMAVALVE',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_286',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_286',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_038',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_038',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_018_136',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_359',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_038',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_359',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_136',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_359',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_038',
#   'Value?EndPoint2:',
#   ''],
#  ['T?T:U-20200', ''],
#  ['Point?element:MAL_OS1_270',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_006',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_273',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_009',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_313',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_009',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_313',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_006',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_313',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_067~MAV_OS1_018_006',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_313',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_067',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_067',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_018_106',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_313',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_106',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_313',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_067~MAV_OS1_018_006~MAV_OS1_018_106',
#   'Value?EndPoint2:MAV_OS1_018_107~MAV_OS1_018_009',
#   ''],
#  ['Point?element:MAV_OS1_018_107',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_313',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_107',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_313',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_009',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_376',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_067',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_376',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_013_012',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_376',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_014_004',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_376',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_014_004',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_014_004',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_013_012',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_7279',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_013_013',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_7280',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_013_014',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_7280',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_013_014',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_013_014',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_7280',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_013_015',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_013_015',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_7280',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_013_013',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_7280',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:UN2400_WAXY',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_483',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_021_047',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_021_047',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_483',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_021_047',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_483',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_024_031',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_483',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_024_031',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_024_031',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_483',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_062_004~MAV_OS1_024_031',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_491',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_062_013',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_062_013',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_491',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_068',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2426',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_061',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_022_068',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_022_069',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_022_067',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2426',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_065',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2426',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_066',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2426',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_067',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2426',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2426',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_065~MAV_OS1_022_066',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2426',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_065',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_022_064',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2426',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_063',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:_P53102AL',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValvePseudo',
#   'Value?DataBoundObj:ovlValve',
#   ''],
#  ['Point?element:_P53102AR',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValvePseudo',
#   'Value?DataBoundObj:ovlValve',
#   ''],
#  ['Point?element:_P53102BL',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValvePseudo',
#   'Value?DataBoundObj:ovlValve',
#   ''],
#  ['Point?element:_P53102BR',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValvePseudo',
#   'Value?DataBoundObj:ovlValve',
#   ''],
#  ['Point?element:_P53104AL',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValvePseudo',
#   'Value?DataBoundObj:ovlValve',
#   ''],
#  ['Point?element:_P53104AR',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValvePseudo',
#   'Value?DataBoundObj:ovlValve',
#   ''],
#  ['Point?element:_P53104BL',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValvePseudo',
#   'Value?DataBoundObj:ovlValve',
#   ''],
#  ['Point?element:_P53104BR',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValvePseudo',
#   'Value?DataBoundObj:ovlValve',
#   ''],
#  ['Point?element:_P5399AL',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValvePseudo',
#   'Value?DataBoundObj:ovlValve',
#   ''],
#  ['Point?element:_P5399AR',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValvePseudo',
#   'Value?DataBoundObj:ovlValve',
#   ''],
#  ['Point?element:_P5399BL',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValvePseudo',
#   'Value?DataBoundObj:ovlValve',
#   ''],
#  ['Point?element:_P5399BR',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValvePseudo',
#   'Value?DataBoundObj:ovlValve',
#   ''],
#  ['Point?element:MAL_OS1_368',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_011',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_022_063',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_018_109',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_314',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_108',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_108',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_314',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_110',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_110',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_314',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108~MAV_OS1_018_110',
#   'Value?EndPoint2:MAV_OS1_018_111~MAV_OS1_018_008',
#   ''],
#  ['Point?element:MAL_OS1_314',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_111',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_111',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_323',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_109',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_321',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_108',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_326',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_110',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_327',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_314',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_008',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_072',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_323',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_134~MAV_OS1_018_116',
#   'Value?EndPoint2:MAV_OS1_018_072~MAV_OS1_018_109',
#   ''],
#  ['Point?element:MAL_OS1_323',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_134~MAV_OS1_018_116',
#   'Value?EndPoint2:MAV_OS1_018_072~MAV_OS1_018_109',
#   ''],
#  ['Point?element:MAL_OS1_323',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_134~MAV_OS1_018_116',
#   'Value?EndPoint2:MAV_OS1_018_072~MAV_OS1_018_109',
#   ''],
#  ['Point?element:MAL_OS1_323',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_072',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_071',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_018_074',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_018_075',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_323',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_134~MAV_OS1_018_116',
#   'Value?EndPoint2:MAV_OS1_018_072~MAV_OS1_018_109',
#   ''],
#  ['Point?element:MAL_OS1_321',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_117',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_321',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_071',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_321',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_117',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_321',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_117',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_326',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_141~MAV_OS1_018_115',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_326',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_141~MAV_OS1_018_115',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_327',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV005~MAV004',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_326',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_074',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_327',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_220',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV005~MAV004',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_220',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_230',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV005~MAV004',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_230',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_246',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV005~MAV004',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_246',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_368',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV005~MAV004',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_327',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_114',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_114',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_368',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_114',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_326',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_115',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_115',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_368',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_115',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_321',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_117',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_117',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_368',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_117',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_323',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_116',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_116',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_368',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_116',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_368',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV005~MAV004',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_368',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_116',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_326',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_115',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_321',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_117',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_321',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_117',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_323',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_116',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_323',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_116',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_323',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_116',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_312',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_130',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_327',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_130',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_130',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_312',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_130',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_326',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_141',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_141',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_323',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_134',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_134',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_018_011',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_325',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_011',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_325',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_013',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_325',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_100',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_325',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_172',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_325',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_013~MAV_OS1_018_011',
#   'Value?EndPoint2:MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100',
#   ''],
#  ['Point?element:MAL_OS1_325',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100',
#   'Value?EndPoint2:MAV_OS1_022_064~MAV_OS1_018_172',
#   ''],
#  ['Point?element:MAL_OS1_2427',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_325',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_064',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_013',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_018_100',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_018_172',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_325',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_013~MAV_OS1_018_011',
#   'Value?EndPoint2:MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100',
#   ''],
#  ['Point?element:MAL_OS1_491',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_068',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_491',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_068',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAL_OS1_220',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:PSP5383L',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_073',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAV_OS1_022_065',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2430',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_022_066',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2430',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_483',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_069',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_483',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_069',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2424',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_162',
#   'Value?EndPoint2:MAV010',
#   ''],
#  ['Point?element:MAV_OS1_022_162',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_2424',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_162',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAL_OS1_2424',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_022_059',
#   'Value?EndPoint2:',
#   ''],
#  ['Point?element:MAV_OS1_018_065',
#   'Value?DefElemType:5',
#   'Value?ShapeID:ValveMan',
#   'Value?DataBoundObj:plyValve',
#   ''],
#  ['Point?element:MAL_OS1_312',
#   'Value?DefElemType:3',
#   'Value?ShapeID:Line',
#   'Value?DataBoundObj:linPipe',
#   'Value?EndPoint1:MAV_OS1_018_065',
#   'Value?EndPoint2:',
#   '']]

# %%
[[p.split(':') for p in div['parameters'].split(';')] for div in divs if 'hsc.shape.1' in div['class']]
# Out:
# [[['Point?element', 'MAL_OS1_7280'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_013_014~MAV_OS1_013_013'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_314'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108'],
#   ['Value?EndPoint2', 'MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110'],
#   ['']],
#  [['']],
#  [['Point?DestElement', ''],
#   ['Point?SrcElement', ''],
#   ['Value?IgnoreOnDataChange', '"True"'],
#   ['']],
#  [['Point?DestElement', ''],
#   ['Point?SrcElement', ''],
#   ['Value?IgnoreOnDataChange', '"True"'],
#   ['']],
#  [['']],
#  [['Point?Element1', ''],
#   ['Point?Element2', ''],
#   ['Point?Element3', ''],
#   ['Point?Element4', ''],
#   ['Point?Element5', ''],
#   ['Point?Element6', ''],
#   ['Point?Element7', ''],
#   ['Point?Element8', ''],
#   ['Point?Element9', ''],
#   ['Point?Element10', ''],
#   ['Point?Element11', ''],
#   ['Point?Element12', ''],
#   ['Point?Element13', ''],
#   ['Point?Element14', ''],
#   ['Point?Element15', ''],
#   ['Point?Element16', ''],
#   ['Point?Element17', ''],
#   ['Point?Element18', ''],
#   ['Point?Element19', ''],
#   ['Point?Element20', ''],
#   ['Point?Element21', ''],
#   ['Point?Element22', ''],
#   ['Point?Element23', ''],
#   ['Point?Element24', ''],
#   ['Point?Element25', ''],
#   ['Point?Element26', ''],
#   ['Point?Element27', ''],
#   ['Point?Element28', ''],
#   ['Point?Element29', ''],
#   ['Point?Element30', ''],
#   ['Point?Element31', ''],
#   ['Point?Element32', ''],
#   ['Point?Element33', ''],
#   ['Point?Element34', ''],
#   ['Point?Element35', ''],
#   ['Point?Element36', ''],
#   ['Point?Element37', ''],
#   ['Point?Element38', ''],
#   ['Point?Element39', ''],
#   ['Point?Element40', ''],
#   ['']],
#  [['TEXT?ACTIVITY', 'CH'],
#   ['TEXT?AREA', '제품운영1과'],
#   ['TEXT?TANK', '-'],
#   ['TEXT?PRODUCT', 'WAXY'],
#   ['']],
#  [['T?T', 'U-2400'], ['']],
#  [['Point?element', 'MAV_OS1_054_002'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', '_P53102A'],
#   ['Value?DefElemType', '4'],
#   ['Value?ShapeID', 'CPump'],
#   ['Value?DataBoundObj', 'plyPump'],
#   ['']],
#  [['Point?element', 'TK53104'],
#   ['Value?DefElemType', '1'],
#   ['Value?ShapeID', 'TankNozzle'],
#   ['Value?DataBoundObj', 'shaTank'],
#   ['']],
#  [['']],
#  [['']],
#  [['Point?TankName', 'TK53104'],
#   ['Parameter?TaskID', 'TaskID'],
#   ['Parameter?Material', 'Matlcode'],
#   ['TEXT?MATERIAL', 'W-31'],
#   ['']],
#  [['Point?element', 'TK53105'],
#   ['Value?DefElemType', '1'],
#   ['Value?ShapeID', 'TankNozzle'],
#   ['Value?DataBoundObj', 'shaTank'],
#   ['']],
#  [['']],
#  [['']],
#  [['Point?TankName', 'TK53105'],
#   ['Parameter?TaskID', 'TaskID'],
#   ['Parameter?Material', 'Matlcode'],
#   ['TEXT?MATERIAL', 'W-96S'],
#   ['']],
#  [['Point?element', 'TK53106'],
#   ['Value?DefElemType', '1'],
#   ['Value?ShapeID', 'TankNozzle'],
#   ['Value?DataBoundObj', 'shaTank'],
#   ['']],
#  [['']],
#  [['']],
#  [['Point?TankName', 'TK53106'],
#   ['Parameter?TaskID', 'TaskID'],
#   ['Parameter?Material', 'Matlcode'],
#   ['TEXT?MATERIAL', 'W-20'],
#   ['']],
#  [['Point?element', 'TK53107'],
#   ['Value?DefElemType', '1'],
#   ['Value?ShapeID', 'TankNozzle'],
#   ['Value?DataBoundObj', 'shaTank'],
#   ['']],
#  [['']],
#  [['']],
#  [['Point?TankName', 'TK53107'],
#   ['Parameter?TaskID', 'TaskID'],
#   ['Parameter?Material', 'Matlcode'],
#   ['TEXT?MATERIAL', 'W-116'],
#   ['']],
#  [['Point?element', 'TK53109'],
#   ['Value?DefElemType', '1'],
#   ['Value?ShapeID', 'TankNozzle'],
#   ['Value?DataBoundObj', 'shaTank'],
#   ['']],
#  [['']],
#  [['']],
#  [['Point?TankName', 'TK53109'],
#   ['Parameter?TaskID', 'TaskID'],
#   ['Parameter?Material', 'Matlcode'],
#   ['TEXT?MATERIAL', 'W-480'],
#   ['']],
#  [['Point?element', 'TK53110'],
#   ['Value?DefElemType', '1'],
#   ['Value?ShapeID', 'TankNozzle'],
#   ['Value?DataBoundObj', 'shaTank'],
#   ['']],
#  [['']],
#  [['']],
#  [['Point?TankName', 'TK53110'],
#   ['Parameter?TaskID', 'TaskID'],
#   ['Parameter?Material', 'Matlcode'],
#   ['TEXT?MATERIAL', 'W-31S'],
#   ['']],
#  [['Point?element', 'TK53111'],
#   ['Value?DefElemType', '1'],
#   ['Value?ShapeID', 'TankNozzle'],
#   ['Value?DataBoundObj', 'shaTank'],
#   ['']],
#  [['']],
#  [['']],
#  [['Point?TankName', 'TK53110'],
#   ['Parameter?TaskID', 'TaskID'],
#   ['Parameter?Material', 'Matlcode'],
#   ['TEXT?MATERIAL', 'W-31S'],
#   ['']],
#  [['Point?element', 'TK5397'],
#   ['Value?DefElemType', '1'],
#   ['Value?ShapeID', 'TankNozzle'],
#   ['Value?DataBoundObj', 'shaTank'],
#   ['']],
#  [['']],
#  [['']],
#  [['Point?TankName', 'TK5397'],
#   ['Parameter?TaskID', 'TaskID'],
#   ['Parameter?Material', 'Matlcode'],
#   ['TEXT?MATERIAL', 'Mix-W'],
#   ['']],
#  [['Point?element', 'MAL_OS1_218'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_054_002'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_220'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_054_017'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_230'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_054_021'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_232'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_054_026'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_202'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_053_027'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_483'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_062_004'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_417'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_059_006'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', '_P53102B'],
#   ['Value?DefElemType', '4'],
#   ['Value?ShapeID', 'CPump'],
#   ['Value?DataBoundObj', 'plyPump'],
#   ['']],
#  [['Point?element', 'MAL_OS1_360'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_021_122'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'UN2400_WAXY'],
#   ['Value?DefElemType', '2'],
#   ['Value?ShapeID', 'BP'],
#   ['Value?DataBoundObj', 'plyBPArrow'],
#   ['']],
#  [['T?T', 'U-2600'], ['']],
#  [['Point?element', 'UN2600_WAXY'],
#   ['Value?DefElemType', '2'],
#   ['Value?ShapeID', 'BP'],
#   ['Value?DataBoundObj', 'plyBPArrow'],
#   ['']],
#  [['Point?element', 'MAL_OS1_359'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_136'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'UN20200_WAXY'],
#   ['Value?DefElemType', '2'],
#   ['Value?ShapeID', 'BP'],
#   ['Value?DataBoundObj', 'plyBPArrow'],
#   ['']],
#  [['Point?element', 'MAV_OS1_054_017'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_054_021'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_054_026'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_053_027'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_062_004'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_059_006'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_218'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', ''],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_220'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_230'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_017_024'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_232'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_202'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', ''],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_312'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_104'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_104'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_483'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_062_004'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_417'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_059_006'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_417'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_021_122'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_021_122'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_417'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_021_140~MAV_OS1_021_117'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_417'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_021_117'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_021_117'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_417'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_021_117'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_417'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_021_140'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_021_140'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', '_P53104A'],
#   ['Value?DefElemType', '4'],
#   ['Value?ShapeID', 'CPump'],
#   ['Value?DataBoundObj', 'plyPump'],
#   ['']],
#  [['Point?element', '_P53104B'],
#   ['Value?DefElemType', '4'],
#   ['Value?ShapeID', 'CPump'],
#   ['Value?DataBoundObj', 'plyPump'],
#   ['']],
#  [['Point?element', 'MAL_OS1_271'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', ''],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_007'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_272'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', ''],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_008'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_314'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_109'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_314'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_007'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_314'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_008'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_314'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_007~MAV_OS1_018_109'],
#   ['Value?EndPoint2',
#    'MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110~MAV_OS1_018_108'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2432'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_062'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2431'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2431'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV005~MAV004'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2431'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'OMAVALVE'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2433'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2433'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV005~MAV004'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2433'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2433'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_073'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2433'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_073'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2433'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_074'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_074'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2433'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_074'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2431'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2431'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV005~MAV004'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_061'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2431'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_072'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_072'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2431'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV005~MAV004'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2431'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_033'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_033'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2431'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV005~MAV004'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2431'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_057'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_057'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2431'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_061'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2428'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_060'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2426'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_060'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2426'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV005~MAV004'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2426'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'OMAVALVE'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2424'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2424'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV005~MAV004'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2426'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1',
#    'MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067~MAV_OS1_022_063~MAV_OS1_022_061'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2424'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2424'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_059'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_5002'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_073'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_5002'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_059'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_5002'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_059'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_5002'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'UN2600_WAXY'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_5002'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_019_004'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_019_004'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_5002'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_019_004'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_5002'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'UN2600_WAXY'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_5002'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_014_003'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_014_003'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_5002'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_014_003'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_5002'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'UN2600_WAXY'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_246'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_483'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_069'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_325'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_064'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', '_P5399A'],
#   ['Value?DefElemType', '4'],
#   ['Value?ShapeID', 'CPump'],
#   ['Value?DataBoundObj', 'plyPump'],
#   ['']],
#  [['Point?element', '_P5399B'],
#   ['Value?DefElemType', '4'],
#   ['Value?ShapeID', 'CPump'],
#   ['Value?DataBoundObj', 'plyPump'],
#   ['']],
#  [['Point?element', 'MAL_OS1_289'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_043'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_289'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_043'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_360'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_043'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'OMAVALVE'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_289'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'OMAVALVE'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_289'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'OMAVALVE'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_288'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'OMAVALVE'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_288'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'OMAVALVE'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_288'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', '_P5399BR'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_288'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_136'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_360'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_042'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_042'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_360'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_042'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_287'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', '_P5399AL'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_287'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_042'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'OMAVALVE'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_287'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'OMAVALVE'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_287'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'OMAVALVE'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_286'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'OMAVALVE'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_286'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'OMAVALVE'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_286'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_286'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_038'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_038'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_136'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_359'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_038'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_359'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_136'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_359'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_038'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['T?T', 'U-20200'], ['']],
#  [['Point?element', 'MAL_OS1_270'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', ''],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_006'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_273'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', ''],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_009'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_313'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_009'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_313'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_006'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_313'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_067~MAV_OS1_018_006'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_313'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_067'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_067'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_106'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_313'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_106'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_313'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_067~MAV_OS1_018_006~MAV_OS1_018_106'],
#   ['Value?EndPoint2', 'MAV_OS1_018_107~MAV_OS1_018_009'],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_107'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_313'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_107'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_313'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_009'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_376'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_067'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_376'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_013_012'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_376'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_014_004'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_376'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_014_004'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_014_004'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_013_012'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_7279'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', ''],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_013_013'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_7280'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_013_014'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_7280'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_013_014'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_013_014'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_7280'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_013_015'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_013_015'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_7280'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_013_013'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_7280'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'UN2400_WAXY'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_483'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_021_047'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_021_047'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_483'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_021_047'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_483'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_024_031'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_483'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_024_031'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_024_031'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_483'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_062_004~MAV_OS1_024_031'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_491'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_062_013'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_062_013'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_491'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_068'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2426'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_061'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_068'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_069'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_067'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2426'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_065'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2426'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_066'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2426'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_067'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2426'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2426'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_065~MAV_OS1_022_066'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2426'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_065'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_064'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2426'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_063'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', '_P53102AL'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValvePseudo'],
#   ['Value?DataBoundObj', 'ovlValve'],
#   ['']],
#  [['Point?element', '_P53102AR'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValvePseudo'],
#   ['Value?DataBoundObj', 'ovlValve'],
#   ['']],
#  [['Point?element', '_P53102BL'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValvePseudo'],
#   ['Value?DataBoundObj', 'ovlValve'],
#   ['']],
#  [['Point?element', '_P53102BR'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValvePseudo'],
#   ['Value?DataBoundObj', 'ovlValve'],
#   ['']],
#  [['Point?element', '_P53104AL'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValvePseudo'],
#   ['Value?DataBoundObj', 'ovlValve'],
#   ['']],
#  [['Point?element', '_P53104AR'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValvePseudo'],
#   ['Value?DataBoundObj', 'ovlValve'],
#   ['']],
#  [['Point?element', '_P53104BL'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValvePseudo'],
#   ['Value?DataBoundObj', 'ovlValve'],
#   ['']],
#  [['Point?element', '_P53104BR'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValvePseudo'],
#   ['Value?DataBoundObj', 'ovlValve'],
#   ['']],
#  [['Point?element', '_P5399AL'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValvePseudo'],
#   ['Value?DataBoundObj', 'ovlValve'],
#   ['']],
#  [['Point?element', '_P5399AR'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValvePseudo'],
#   ['Value?DataBoundObj', 'ovlValve'],
#   ['']],
#  [['Point?element', '_P5399BL'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValvePseudo'],
#   ['Value?DataBoundObj', 'ovlValve'],
#   ['']],
#  [['Point?element', '_P5399BR'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValvePseudo'],
#   ['Value?DataBoundObj', 'ovlValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_368'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_011'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_063'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_109'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_314'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_108'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_108'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_314'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_110'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_110'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_314'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1',
#    'MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108~MAV_OS1_018_110'],
#   ['Value?EndPoint2', 'MAV_OS1_018_111~MAV_OS1_018_008'],
#   ['']],
#  [['Point?element', 'MAL_OS1_314'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_111'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_111'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_323'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_109'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_321'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_108'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_326'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_110'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_327'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_314'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_008'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_072'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_323'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_134~MAV_OS1_018_116'],
#   ['Value?EndPoint2', 'MAV_OS1_018_072~MAV_OS1_018_109'],
#   ['']],
#  [['Point?element', 'MAL_OS1_323'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_134~MAV_OS1_018_116'],
#   ['Value?EndPoint2', 'MAV_OS1_018_072~MAV_OS1_018_109'],
#   ['']],
#  [['Point?element', 'MAL_OS1_323'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_134~MAV_OS1_018_116'],
#   ['Value?EndPoint2', 'MAV_OS1_018_072~MAV_OS1_018_109'],
#   ['']],
#  [['Point?element', 'MAL_OS1_323'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_072'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_071'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_074'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_075'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_323'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_134~MAV_OS1_018_116'],
#   ['Value?EndPoint2', 'MAV_OS1_018_072~MAV_OS1_018_109'],
#   ['']],
#  [['Point?element', 'MAL_OS1_321'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_117'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_321'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_071'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_321'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_117'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_321'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_117'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_326'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_141~MAV_OS1_018_115'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_326'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_141~MAV_OS1_018_115'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_327'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV005~MAV004'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_326'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_074'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_327'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_220'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV005~MAV004'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_220'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_230'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV005~MAV004'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_230'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_246'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV005~MAV004'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_246'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_368'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV005~MAV004'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_327'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_114'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_114'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_368'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_114'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_326'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_115'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_115'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_368'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_115'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_321'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_117'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_117'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_368'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_117'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_323'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_116'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_116'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_368'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_116'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_368'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV005~MAV004'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_368'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_116'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_326'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_115'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_321'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_117'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_321'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_117'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_323'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_116'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_323'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_116'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_323'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_116'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_312'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_130'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_327'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_130'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_130'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_312'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_130'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_326'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_141'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_141'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_323'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_134'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_134'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_011'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_325'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_011'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_325'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_013'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_325'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_100'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_325'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_172'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_325'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_013~MAV_OS1_018_011'],
#   ['Value?EndPoint2', 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100'],
#   ['']],
#  [['Point?element', 'MAL_OS1_325'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100'],
#   ['Value?EndPoint2', 'MAV_OS1_022_064~MAV_OS1_018_172'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2427'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_325'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_064'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_013'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_100'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_172'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_325'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_013~MAV_OS1_018_011'],
#   ['Value?EndPoint2', 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100'],
#   ['']],
#  [['Point?element', 'MAL_OS1_491'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_068'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_491'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_068'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAL_OS1_220'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'PSP5383L'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_073'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_065'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2430'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', ''],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_066'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2430'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', ''],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_483'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_069'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_483'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_069'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2424'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_162'],
#   ['Value?EndPoint2', 'MAV010'],
#   ['']],
#  [['Point?element', 'MAV_OS1_022_162'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_2424'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_162'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAL_OS1_2424'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_022_059'],
#   ['Value?EndPoint2', ''],
#   ['']],
#  [['Point?element', 'MAV_OS1_018_065'],
#   ['Value?DefElemType', '5'],
#   ['Value?ShapeID', 'ValveMan'],
#   ['Value?DataBoundObj', 'plyValve'],
#   ['']],
#  [['Point?element', 'MAL_OS1_312'],
#   ['Value?DefElemType', '3'],
#   ['Value?ShapeID', 'Line'],
#   ['Value?DataBoundObj', 'linPipe'],
#   ['Value?EndPoint1', 'MAV_OS1_018_065'],
#   ['Value?EndPoint2', ''],
#   ['']]]

# %%
[[dict(zip(p.split(':')[::2],p.split(':')[1::2])) for p in div['parameters'].split(';')] for div in divs if 'hsc.shape.1' in div['class']]
# Out:
# [[{'Point?element': 'MAL_OS1_7280'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_013_014~MAV_OS1_013_013'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_314'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108'},
#   {'Value?EndPoint2': 'MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110'},
#   {}],
#  [{}],
#  [{'Point?DestElement': ''},
#   {'Point?SrcElement': ''},
#   {'Value?IgnoreOnDataChange': '"True"'},
#   {}],
#  [{'Point?DestElement': ''},
#   {'Point?SrcElement': ''},
#   {'Value?IgnoreOnDataChange': '"True"'},
#   {}],
#  [{}],
#  [{'Point?Element1': ''},
#   {'Point?Element2': ''},
#   {'Point?Element3': ''},
#   {'Point?Element4': ''},
#   {'Point?Element5': ''},
#   {'Point?Element6': ''},
#   {'Point?Element7': ''},
#   {'Point?Element8': ''},
#   {'Point?Element9': ''},
#   {'Point?Element10': ''},
#   {'Point?Element11': ''},
#   {'Point?Element12': ''},
#   {'Point?Element13': ''},
#   {'Point?Element14': ''},
#   {'Point?Element15': ''},
#   {'Point?Element16': ''},
#   {'Point?Element17': ''},
#   {'Point?Element18': ''},
#   {'Point?Element19': ''},
#   {'Point?Element20': ''},
#   {'Point?Element21': ''},
#   {'Point?Element22': ''},
#   {'Point?Element23': ''},
#   {'Point?Element24': ''},
#   {'Point?Element25': ''},
#   {'Point?Element26': ''},
#   {'Point?Element27': ''},
#   {'Point?Element28': ''},
#   {'Point?Element29': ''},
#   {'Point?Element30': ''},
#   {'Point?Element31': ''},
#   {'Point?Element32': ''},
#   {'Point?Element33': ''},
#   {'Point?Element34': ''},
#   {'Point?Element35': ''},
#   {'Point?Element36': ''},
#   {'Point?Element37': ''},
#   {'Point?Element38': ''},
#   {'Point?Element39': ''},
#   {'Point?Element40': ''},
#   {}],
#  [{'TEXT?ACTIVITY': 'CH'},
#   {'TEXT?AREA': '제품운영1과'},
#   {'TEXT?TANK': '-'},
#   {'TEXT?PRODUCT': 'WAXY'},
#   {}],
#  [{'T?T': 'U-2400'}, {}],
#  [{'Point?element': 'MAV_OS1_054_002'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': '_P53102A'},
#   {'Value?DefElemType': '4'},
#   {'Value?ShapeID': 'CPump'},
#   {'Value?DataBoundObj': 'plyPump'},
#   {}],
#  [{'Point?element': 'TK53104'},
#   {'Value?DefElemType': '1'},
#   {'Value?ShapeID': 'TankNozzle'},
#   {'Value?DataBoundObj': 'shaTank'},
#   {}],
#  [{}],
#  [{}],
#  [{'Point?TankName': 'TK53104'},
#   {'Parameter?TaskID': 'TaskID'},
#   {'Parameter?Material': 'Matlcode'},
#   {'TEXT?MATERIAL': 'W-31'},
#   {}],
#  [{'Point?element': 'TK53105'},
#   {'Value?DefElemType': '1'},
#   {'Value?ShapeID': 'TankNozzle'},
#   {'Value?DataBoundObj': 'shaTank'},
#   {}],
#  [{}],
#  [{}],
#  [{'Point?TankName': 'TK53105'},
#   {'Parameter?TaskID': 'TaskID'},
#   {'Parameter?Material': 'Matlcode'},
#   {'TEXT?MATERIAL': 'W-96S'},
#   {}],
#  [{'Point?element': 'TK53106'},
#   {'Value?DefElemType': '1'},
#   {'Value?ShapeID': 'TankNozzle'},
#   {'Value?DataBoundObj': 'shaTank'},
#   {}],
#  [{}],
#  [{}],
#  [{'Point?TankName': 'TK53106'},
#   {'Parameter?TaskID': 'TaskID'},
#   {'Parameter?Material': 'Matlcode'},
#   {'TEXT?MATERIAL': 'W-20'},
#   {}],
#  [{'Point?element': 'TK53107'},
#   {'Value?DefElemType': '1'},
#   {'Value?ShapeID': 'TankNozzle'},
#   {'Value?DataBoundObj': 'shaTank'},
#   {}],
#  [{}],
#  [{}],
#  [{'Point?TankName': 'TK53107'},
#   {'Parameter?TaskID': 'TaskID'},
#   {'Parameter?Material': 'Matlcode'},
#   {'TEXT?MATERIAL': 'W-116'},
#   {}],
#  [{'Point?element': 'TK53109'},
#   {'Value?DefElemType': '1'},
#   {'Value?ShapeID': 'TankNozzle'},
#   {'Value?DataBoundObj': 'shaTank'},
#   {}],
#  [{}],
#  [{}],
#  [{'Point?TankName': 'TK53109'},
#   {'Parameter?TaskID': 'TaskID'},
#   {'Parameter?Material': 'Matlcode'},
#   {'TEXT?MATERIAL': 'W-480'},
#   {}],
#  [{'Point?element': 'TK53110'},
#   {'Value?DefElemType': '1'},
#   {'Value?ShapeID': 'TankNozzle'},
#   {'Value?DataBoundObj': 'shaTank'},
#   {}],
#  [{}],
#  [{}],
#  [{'Point?TankName': 'TK53110'},
#   {'Parameter?TaskID': 'TaskID'},
#   {'Parameter?Material': 'Matlcode'},
#   {'TEXT?MATERIAL': 'W-31S'},
#   {}],
#  [{'Point?element': 'TK53111'},
#   {'Value?DefElemType': '1'},
#   {'Value?ShapeID': 'TankNozzle'},
#   {'Value?DataBoundObj': 'shaTank'},
#   {}],
#  [{}],
#  [{}],
#  [{'Point?TankName': 'TK53110'},
#   {'Parameter?TaskID': 'TaskID'},
#   {'Parameter?Material': 'Matlcode'},
#   {'TEXT?MATERIAL': 'W-31S'},
#   {}],
#  [{'Point?element': 'TK5397'},
#   {'Value?DefElemType': '1'},
#   {'Value?ShapeID': 'TankNozzle'},
#   {'Value?DataBoundObj': 'shaTank'},
#   {}],
#  [{}],
#  [{}],
#  [{'Point?TankName': 'TK5397'},
#   {'Parameter?TaskID': 'TaskID'},
#   {'Parameter?Material': 'Matlcode'},
#   {'TEXT?MATERIAL': 'Mix-W'},
#   {}],
#  [{'Point?element': 'MAL_OS1_218'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_054_002'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_220'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_054_017'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_230'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_054_021'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_232'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_054_026'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_202'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_053_027'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_483'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_062_004'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_417'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_059_006'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': '_P53102B'},
#   {'Value?DefElemType': '4'},
#   {'Value?ShapeID': 'CPump'},
#   {'Value?DataBoundObj': 'plyPump'},
#   {}],
#  [{'Point?element': 'MAL_OS1_360'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_021_122'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'UN2400_WAXY'},
#   {'Value?DefElemType': '2'},
#   {'Value?ShapeID': 'BP'},
#   {'Value?DataBoundObj': 'plyBPArrow'},
#   {}],
#  [{'T?T': 'U-2600'}, {}],
#  [{'Point?element': 'UN2600_WAXY'},
#   {'Value?DefElemType': '2'},
#   {'Value?ShapeID': 'BP'},
#   {'Value?DataBoundObj': 'plyBPArrow'},
#   {}],
#  [{'Point?element': 'MAL_OS1_359'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_136'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'UN20200_WAXY'},
#   {'Value?DefElemType': '2'},
#   {'Value?ShapeID': 'BP'},
#   {'Value?DataBoundObj': 'plyBPArrow'},
#   {}],
#  [{'Point?element': 'MAV_OS1_054_017'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_054_021'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_054_026'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_053_027'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_062_004'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_059_006'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_218'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': ''},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_220'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_230'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_017_024'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_232'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_202'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': ''},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_312'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_104'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_104'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_483'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_062_004'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_417'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_059_006'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_417'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_021_122'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_021_122'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_417'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_021_140~MAV_OS1_021_117'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_417'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_021_117'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_021_117'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_417'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_021_117'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_417'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_021_140'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_021_140'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': '_P53104A'},
#   {'Value?DefElemType': '4'},
#   {'Value?ShapeID': 'CPump'},
#   {'Value?DataBoundObj': 'plyPump'},
#   {}],
#  [{'Point?element': '_P53104B'},
#   {'Value?DefElemType': '4'},
#   {'Value?ShapeID': 'CPump'},
#   {'Value?DataBoundObj': 'plyPump'},
#   {}],
#  [{'Point?element': 'MAL_OS1_271'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': ''},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_007'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_272'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': ''},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_008'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_314'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_109'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_314'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_007'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_314'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_008'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_314'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_007~MAV_OS1_018_109'},
#   {'Value?EndPoint2': 'MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110~MAV_OS1_018_108'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2432'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_062'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2431'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2431'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV005~MAV004'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2431'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'OMAVALVE'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2433'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2433'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV005~MAV004'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2433'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2433'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_073'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2433'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_073'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2433'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_074'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_074'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2433'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_074'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2431'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2431'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV005~MAV004'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_061'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2431'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_072'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_072'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2431'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV005~MAV004'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2431'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_033'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_033'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2431'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV005~MAV004'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2431'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_057'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_057'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2431'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_061'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2428'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_060'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2426'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_060'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2426'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV005~MAV004'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2426'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'OMAVALVE'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2424'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2424'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV005~MAV004'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2426'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067~MAV_OS1_022_063~MAV_OS1_022_061'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2424'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2424'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_059'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_5002'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_073'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_5002'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_059'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_5002'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_059'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_5002'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'UN2600_WAXY'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_5002'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_019_004'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_019_004'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_5002'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_019_004'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_5002'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'UN2600_WAXY'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_5002'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_014_003'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_014_003'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_5002'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_014_003'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_5002'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'UN2600_WAXY'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_246'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_483'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_069'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_325'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_064'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': '_P5399A'},
#   {'Value?DefElemType': '4'},
#   {'Value?ShapeID': 'CPump'},
#   {'Value?DataBoundObj': 'plyPump'},
#   {}],
#  [{'Point?element': '_P5399B'},
#   {'Value?DefElemType': '4'},
#   {'Value?ShapeID': 'CPump'},
#   {'Value?DataBoundObj': 'plyPump'},
#   {}],
#  [{'Point?element': 'MAL_OS1_289'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_043'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_289'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_043'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_360'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_043'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'OMAVALVE'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_289'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'OMAVALVE'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_289'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'OMAVALVE'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_288'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'OMAVALVE'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_288'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'OMAVALVE'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_288'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': '_P5399BR'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_288'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_136'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_360'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_042'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_042'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_360'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_042'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_287'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': '_P5399AL'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_287'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_042'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'OMAVALVE'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_287'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'OMAVALVE'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_287'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'OMAVALVE'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_286'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'OMAVALVE'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_286'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'OMAVALVE'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_286'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_286'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_038'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_038'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_136'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_359'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_038'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_359'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_136'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_359'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_038'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'T?T': 'U-20200'}, {}],
#  [{'Point?element': 'MAL_OS1_270'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': ''},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_006'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_273'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': ''},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_009'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_313'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_009'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_313'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_006'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_313'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_067~MAV_OS1_018_006'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_313'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_067'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_067'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_106'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_313'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_106'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_313'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_067~MAV_OS1_018_006~MAV_OS1_018_106'},
#   {'Value?EndPoint2': 'MAV_OS1_018_107~MAV_OS1_018_009'},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_107'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_313'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_107'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_313'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_009'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_376'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_067'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_376'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_013_012'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_376'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_014_004'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_376'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_014_004'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_014_004'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_013_012'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_7279'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': ''},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_013_013'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_7280'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_013_014'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_7280'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_013_014'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_013_014'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_7280'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_013_015'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_013_015'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_7280'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_013_013'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_7280'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'UN2400_WAXY'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_483'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_021_047'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_021_047'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_483'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_021_047'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_483'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_024_031'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_483'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_024_031'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_024_031'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_483'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_062_004~MAV_OS1_024_031'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_491'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_062_013'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_062_013'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_491'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_068'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2426'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_061'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_068'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_069'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_067'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2426'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_065'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2426'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_066'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2426'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_067'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2426'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2426'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_065~MAV_OS1_022_066'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2426'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_065'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_064'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2426'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_063'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': '_P53102AL'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValvePseudo'},
#   {'Value?DataBoundObj': 'ovlValve'},
#   {}],
#  [{'Point?element': '_P53102AR'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValvePseudo'},
#   {'Value?DataBoundObj': 'ovlValve'},
#   {}],
#  [{'Point?element': '_P53102BL'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValvePseudo'},
#   {'Value?DataBoundObj': 'ovlValve'},
#   {}],
#  [{'Point?element': '_P53102BR'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValvePseudo'},
#   {'Value?DataBoundObj': 'ovlValve'},
#   {}],
#  [{'Point?element': '_P53104AL'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValvePseudo'},
#   {'Value?DataBoundObj': 'ovlValve'},
#   {}],
#  [{'Point?element': '_P53104AR'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValvePseudo'},
#   {'Value?DataBoundObj': 'ovlValve'},
#   {}],
#  [{'Point?element': '_P53104BL'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValvePseudo'},
#   {'Value?DataBoundObj': 'ovlValve'},
#   {}],
#  [{'Point?element': '_P53104BR'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValvePseudo'},
#   {'Value?DataBoundObj': 'ovlValve'},
#   {}],
#  [{'Point?element': '_P5399AL'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValvePseudo'},
#   {'Value?DataBoundObj': 'ovlValve'},
#   {}],
#  [{'Point?element': '_P5399AR'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValvePseudo'},
#   {'Value?DataBoundObj': 'ovlValve'},
#   {}],
#  [{'Point?element': '_P5399BL'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValvePseudo'},
#   {'Value?DataBoundObj': 'ovlValve'},
#   {}],
#  [{'Point?element': '_P5399BR'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValvePseudo'},
#   {'Value?DataBoundObj': 'ovlValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_368'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_011'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_063'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_109'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_314'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_108'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_108'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_314'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_110'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_110'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_314'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108~MAV_OS1_018_110'},
#   {'Value?EndPoint2': 'MAV_OS1_018_111~MAV_OS1_018_008'},
#   {}],
#  [{'Point?element': 'MAL_OS1_314'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_111'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_111'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_323'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_109'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_321'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_108'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_326'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_110'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_327'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_314'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_008'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_072'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_323'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_134~MAV_OS1_018_116'},
#   {'Value?EndPoint2': 'MAV_OS1_018_072~MAV_OS1_018_109'},
#   {}],
#  [{'Point?element': 'MAL_OS1_323'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_134~MAV_OS1_018_116'},
#   {'Value?EndPoint2': 'MAV_OS1_018_072~MAV_OS1_018_109'},
#   {}],
#  [{'Point?element': 'MAL_OS1_323'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_134~MAV_OS1_018_116'},
#   {'Value?EndPoint2': 'MAV_OS1_018_072~MAV_OS1_018_109'},
#   {}],
#  [{'Point?element': 'MAL_OS1_323'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_072'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_071'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_074'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_075'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_323'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_134~MAV_OS1_018_116'},
#   {'Value?EndPoint2': 'MAV_OS1_018_072~MAV_OS1_018_109'},
#   {}],
#  [{'Point?element': 'MAL_OS1_321'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_117'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_321'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_071'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_321'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_117'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_321'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_117'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_326'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_141~MAV_OS1_018_115'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_326'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_141~MAV_OS1_018_115'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_327'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV005~MAV004'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_326'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_074'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_327'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_220'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV005~MAV004'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_220'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_230'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV005~MAV004'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_230'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_246'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV005~MAV004'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_246'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_368'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV005~MAV004'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_327'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_114'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_114'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_368'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_114'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_326'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_115'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_115'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_368'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_115'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_321'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_117'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_117'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_368'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_117'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_323'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_116'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_116'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_368'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_116'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_368'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV005~MAV004'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_368'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_116'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_326'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_115'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_321'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_117'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_321'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_117'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_323'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_116'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_323'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_116'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_323'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_116'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_312'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_130'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_327'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_130'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_130'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_312'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_130'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_326'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_141'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_141'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_323'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_134'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_134'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_011'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_325'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_011'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_325'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_013'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_325'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_100'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_325'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_172'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_325'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011'},
#   {'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100'},
#   {}],
#  [{'Point?element': 'MAL_OS1_325'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100'},
#   {'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2427'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_325'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_064'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_013'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_100'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_172'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_325'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011'},
#   {'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100'},
#   {}],
#  [{'Point?element': 'MAL_OS1_491'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_068'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_491'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_068'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAL_OS1_220'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'PSP5383L'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_073'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_065'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2430'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': ''},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_066'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2430'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': ''},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_483'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_069'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_483'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_069'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2424'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_162'},
#   {'Value?EndPoint2': 'MAV010'},
#   {}],
#  [{'Point?element': 'MAV_OS1_022_162'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_2424'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_162'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAL_OS1_2424'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_022_059'},
#   {'Value?EndPoint2': ''},
#   {}],
#  [{'Point?element': 'MAV_OS1_018_065'},
#   {'Value?DefElemType': '5'},
#   {'Value?ShapeID': 'ValveMan'},
#   {'Value?DataBoundObj': 'plyValve'},
#   {}],
#  [{'Point?element': 'MAL_OS1_312'},
#   {'Value?DefElemType': '3'},
#   {'Value?ShapeID': 'Line'},
#   {'Value?DataBoundObj': 'linPipe'},
#   {'Value?EndPoint1': 'MAV_OS1_018_065'},
#   {'Value?EndPoint2': ''},
#   {}]]

# %%
[[p.split(': ') for p in div['style'].split('; ')] for div in divs if 'hsc.shape.1' in div['class']]
# Out:
# [[['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '80px'],
#   ['LEFT', '1685px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '40px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '130px'],
#   ['LEFT', '1070px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '103px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '29px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '0px'],
#   ['LEFT', '5px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '92px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '14px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', 'normal'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '4px'],
#   ['LEFT', '138px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '60px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '16px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', 'normal'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '4px'],
#   ['LEFT', '77px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '92px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '14px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', 'normal'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '4px'],
#   ['LEFT', '230px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '92px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '14px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', 'normal'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '19px'],
#   ['LEFT', '175px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '1910px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '36px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '0px'],
#   ['LEFT', '0px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '95px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '18px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '70px'],
#   ['LEFT', '1810px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '85px'],
#   ['LEFT', '200px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '35px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '35px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '75px'],
#   ['LEFT', '1195px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '125px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '80px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', 'normal'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '40px'],
#   ['LEFT', '10px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '90.76%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '77.5%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)'],
#   ['TOP', '15%'],
#   ['LEFT', '5.38%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '9.23%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '16.25%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)'],
#   ['TOP', '47.5%'],
#   ['LEFT', '23.07%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '100px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '115px'],
#   ['LEFT', '25px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '125px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '80px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', 'normal'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '145px'],
#   ['LEFT', '10px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '90.76%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '77.5%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)'],
#   ['TOP', '15%'],
#   ['LEFT', '5.38%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '9.23%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '16.25%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)'],
#   ['TOP', '47.5%'],
#   ['LEFT', '23.07%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '100px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '220px'],
#   ['LEFT', '25px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '125px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '80px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', 'normal'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '250px'],
#   ['LEFT', '10px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '90.76%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '77.5%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)'],
#   ['TOP', '15%'],
#   ['LEFT', '5.38%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '9.23%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '16.25%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)'],
#   ['TOP', '47.5%'],
#   ['LEFT', '23.07%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '100px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '325px'],
#   ['LEFT', '25px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '125px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '80px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', 'normal'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '355px'],
#   ['LEFT', '10px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '90.76%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '77.5%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)'],
#   ['TOP', '15%'],
#   ['LEFT', '5.38%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '9.23%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '16.25%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)'],
#   ['TOP', '47.5%'],
#   ['LEFT', '23.07%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '100px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '430px'],
#   ['LEFT', '25px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '125px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '80px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', 'normal'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '465px'],
#   ['LEFT', '10px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '90.76%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '77.5%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)'],
#   ['TOP', '15%'],
#   ['LEFT', '5.38%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '9.23%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '16.25%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)'],
#   ['TOP', '47.5%'],
#   ['LEFT', '23.07%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '100px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '540px'],
#   ['LEFT', '25px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '125px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '80px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', 'normal'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '575px'],
#   ['LEFT', '10px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '90.76%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '77.5%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)'],
#   ['TOP', '15%'],
#   ['LEFT', '5.38%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '9.23%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '16.25%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)'],
#   ['TOP', '47.5%'],
#   ['LEFT', '23.07%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '100px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '650px'],
#   ['LEFT', '25px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '125px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '80px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', 'normal'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '690px'],
#   ['LEFT', '10px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '90.76%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '77.5%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)'],
#   ['TOP', '15%'],
#   ['LEFT', '5.38%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '9.23%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '16.25%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)'],
#   ['TOP', '47.5%'],
#   ['LEFT', '23.07%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '100px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '765px'],
#   ['LEFT', '25px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '125px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '80px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', 'normal'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '790px'],
#   ['LEFT', '10px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '90.76%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '77.5%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)'],
#   ['TOP', '15%'],
#   ['LEFT', '5.38%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '9.23%'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '16.25%'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR',
#    'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)'],
#   ['TOP', '47.5%'],
#   ['LEFT', '23.07%']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '100px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '865px'],
#   ['LEFT', '25px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '75px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '90px'],
#   ['LEFT', '130px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '75px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '180px'],
#   ['LEFT', '130px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '75px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '300px'],
#   ['LEFT', '130px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '75px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '405px'],
#   ['LEFT', '130px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '75px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '505px'],
#   ['LEFT', '130px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '80px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '630px'],
#   ['LEFT', '125px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '80px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '845px'],
#   ['LEFT', '125px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '35px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '35px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '280px'],
#   ['LEFT', '1195px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '585px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '845px'],
#   ['LEFT', '465px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '26px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '18px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '70px'],
#   ['LEFT', '1780px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '95px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '18px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '415px'],
#   ['LEFT', '1810px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '26px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '18px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '415px'],
#   ['LEFT', '1780px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '275px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '830px'],
#   ['LEFT', '1510px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '26px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '18px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '820px'],
#   ['LEFT', '1780px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '175px'],
#   ['LEFT', '200px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '295px'],
#   ['LEFT', '200px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '400px'],
#   ['LEFT', '200px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '500px'],
#   ['LEFT', '200px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '625px'],
#   ['LEFT', '200px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '840px'],
#   ['LEFT', '200px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '435px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '90px'],
#   ['LEFT', '225px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '210px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '180px'],
#   ['LEFT', '225px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '255px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '300px'],
#   ['LEFT', '225px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '400px'],
#   ['LEFT', '365px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '145px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '405px'],
#   ['LEFT', '225px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '275px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '505px'],
#   ['LEFT', '225px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '35px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '505px'],
#   ['LEFT', '590px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '500px'],
#   ['LEFT', '620px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '630px'],
#   ['LEFT', '225px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '170px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '845px'],
#   ['LEFT', '225px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '845px'],
#   ['LEFT', '395px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '840px'],
#   ['LEFT', '440px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '815px'],
#   ['LEFT', '395px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '785px'],
#   ['LEFT', '395px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '780px'],
#   ['LEFT', '440px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '785px'],
#   ['LEFT', '395px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '815px'],
#   ['LEFT', '395px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '810px'],
#   ['LEFT', '440px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '35px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '35px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '420px'],
#   ['LEFT', '1193px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '35px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '35px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '570px'],
#   ['LEFT', '1195px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '90px'],
#   ['LEFT', '1150px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '85px'],
#   ['LEFT', '1125px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '300px'],
#   ['LEFT', '1150px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '295px'],
#   ['LEFT', '1125px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '100px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '90px'],
#   ['LEFT', '970px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '60px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '90px'],
#   ['LEFT', '1070px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '60px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '300px'],
#   ['LEFT', '1070px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '40px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '90px'],
#   ['LEFT', '1070px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '440px'],
#   ['LEFT', '1150px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '435px'],
#   ['LEFT', '1125px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '440px'],
#   ['LEFT', '1080px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '45px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '395px'],
#   ['LEFT', '1080px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '120px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '395px'],
#   ['LEFT', '1080px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '390px'],
#   ['LEFT', '1195px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '120px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '395px'],
#   ['LEFT', '1220px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '5px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '395px'],
#   ['LEFT', '1340px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '120px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '425px'],
#   ['LEFT', '1220px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '425px'],
#   ['LEFT', '1340px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '420px'],
#   ['LEFT', '1435px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '425px'],
#   ['LEFT', '1390px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '425px'],
#   ['LEFT', '1390px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '450px'],
#   ['LEFT', '1435px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '455px'],
#   ['LEFT', '1390px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '90px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '440px'],
#   ['LEFT', '990px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '35px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '440px'],
#   ['LEFT', '990px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '555px'],
#   ['LEFT', '975px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '475px'],
#   ['LEFT', '960px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '470px'],
#   ['LEFT', '935px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '25px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '475px'],
#   ['LEFT', '990px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '500px'],
#   ['LEFT', '960px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '495px'],
#   ['LEFT', '935px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '25px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '500px'],
#   ['LEFT', '990px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '525px'],
#   ['LEFT', '960px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '520px'],
#   ['LEFT', '935px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '15px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '25px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '525px'],
#   ['LEFT', '990px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '590px'],
#   ['LEFT', '1150px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '585px'],
#   ['LEFT', '1125px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '590px'],
#   ['LEFT', '1080px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '45px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '545px'],
#   ['LEFT', '1080px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '120px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '545px'],
#   ['LEFT', '1080px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '540px'],
#   ['LEFT', '1195px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '120px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '545px'],
#   ['LEFT', '1220px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '5px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '545px'],
#   ['LEFT', '1340px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '90px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '590px'],
#   ['LEFT', '990px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '115px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '575px'],
#   ['LEFT', '1225px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '575px'],
#   ['LEFT', '1340px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '570px'],
#   ['LEFT', '1435px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '425px'],
#   ['LEFT', '1460px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '150px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '425px'],
#   ['LEFT', '1510px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '575px'],
#   ['LEFT', '1460px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '425px'],
#   ['LEFT', '1510px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '425px'],
#   ['LEFT', '1560px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '450px'],
#   ['LEFT', '1605px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '455px'],
#   ['LEFT', '1560px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '100px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '425px'],
#   ['LEFT', '1560px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '425px'],
#   ['LEFT', '1660px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '450px'],
#   ['LEFT', '1705px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '455px'],
#   ['LEFT', '1660px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '125px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
# ...
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '300px'],
#   ['LEFT', '890px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '25px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '270px'],
#   ['LEFT', '845px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '265px'],
#   ['LEFT', '865px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '270px'],
#   ['LEFT', '890px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '300px'],
#   ['LEFT', '920px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '270px'],
#   ['LEFT', '920px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '330px'],
#   ['LEFT', '805px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '25px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '300px'],
#   ['LEFT', '810px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '300px'],
#   ['LEFT', '770px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '25px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '270px'],
#   ['LEFT', '810px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '25px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '270px'],
#   ['LEFT', '775px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '270px'],
#   ['LEFT', '735px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '145px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '360px'],
#   ['LEFT', '590px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '45px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '360px'],
#   ['LEFT', '795px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '355px'],
#   ['LEFT', '770px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '185px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '360px'],
#   ['LEFT', '590px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '45px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '330px'],
#   ['LEFT', '760px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '325px'],
#   ['LEFT', '735px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '45px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '270px'],
#   ['LEFT', '690px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '265px'],
#   ['LEFT', '665px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '390px'],
#   ['LEFT', '905px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '20px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '405px'],
#   ['LEFT', '920px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '425px'],
#   ['LEFT', '890px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '455px'],
#   ['LEFT', '805px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '500px'],
#   ['LEFT', '805px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '425px'],
#   ['LEFT', '920px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '45px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '455px'],
#   ['LEFT', '835px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '40px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '590px'],
#   ['LEFT', '885px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '590px'],
#   ['LEFT', '835px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '420px'],
#   ['LEFT', '865px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '450px'],
#   ['LEFT', '780px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '495px'],
#   ['LEFT', '780px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '85px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '455px'],
#   ['LEFT', '835px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '105px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '695px'],
#   ['LEFT', '760px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '35px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '695px'],
#   ['LEFT', '760px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '130px'],
#   ['LEFT', '405px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '125px'],
#   ['LEFT', '380px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '690px'],
#   ['LEFT', '920px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '45px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '695px'],
#   ['LEFT', '885px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '655px'],
#   ['LEFT', '920px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '40px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '660px'],
#   ['LEFT', '885px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '630px'],
#   ['LEFT', '760px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '105px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '660px'],
#   ['LEFT', '760px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '10px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '30px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '575px'],
#   ['LEFT', '1390px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '600px'],
#   ['LEFT', '1435px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '605px'],
#   ['LEFT', '1390px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '50px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '575px'],
#   ['LEFT', '1390px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '30px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '10px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '500px'],
#   ['LEFT', '495px']],
#  [['POSITION', 'absolute'],
#   ['FONT-STYLE', 'normal'],
#   ['WIDTH', '70px'],
#   ['FONT-FAMILY', 'Arial'],
#   ['HEIGHT', '15px'],
#   ['FONT-SIZE', '0px'],
#   ['FONT-WEIGHT', '400'],
#   ['TEXT-DECORATION', 'none'],
#   ['BEHAVIOR', 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)'],
#   ['TOP', '505px'],
#   ['LEFT', '520px']]]

# %%
for i,div in enumerate(divs):
    if 'hsc.shape.1' in div['class']:
        for p in div['parameters'].split(';'):
            print(p.split(':')[0], p.split(':')[1])
# Out:
# Point?element MAL_OS1_7280
# Value?DefElemType 3
# Value?ShapeID Line
# Value?DataBoundObj linPipe
# Value?EndPoint1 MAV_OS1_013_014~MAV_OS1_013_013
# Value?EndPoint2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-190-df19b26ff7bc> in <module>()
#       2     if 'hsc.shape.1' in div['class']:
#       3         for p in div['parameters'].split(';'):
# ----> 4             print(p.split(':')[0], p.split(':')[1])
#
# IndexError: list index out of range

# %%
for i,div in enumerate(divs):
    if 'hsc.shape.1' in div['class']:
        param = {}
        for p in div['parameters'].split(';'):
            param.update(dict(zip(p.split(':')[::2], p.split(':')[1::2])))
        print(i,div['id'], div['class'], param)
# Out:
# 0 shape385 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_7280', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_013_014~MAV_OS1_013_013', 'Value?EndPoint2': ''}
# 2 shape554 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108', 'Value?EndPoint2': 'MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110'}
# 4 shape001 ['hsc.shape.1'] {}
# 8 tfgPlanningData ['hsc.shape.1'] {'Point?DestElement': '', 'Point?SrcElement': '', 'Value?IgnoreOnDataChange': '"True"'}
# 10 tfgSelectTimeout ['hsc.shape.1'] {'Point?DestElement': '', 'Point?SrcElement': '', 'Value?IgnoreOnDataChange': '"True"'}
# 11 tfgOperDataReInit ['hsc.shape.1'] {}
# 13 tfgOffDisplayEndPoints ['hsc.shape.1'] {'Point?Element1': '', 'Point?Element2': '', 'Point?Element3': '', 'Point?Element4': '', 'Point?Element5': '', 'Point?Element6': '', 'Point?Element7': '', 'Point?Element8': '', 'Point?Element9': '', 'Point?Element10': '', 'Point?Element11': '', 'Point?Element12': '', 'Point?Element13': '', 'Point?Element14': '', 'Point?Element15': '', 'Point?Element16': '', 'Point?Element17': '', 'Point?Element18': '', 'Point?Element19': '', 'Point?Element20': '', 'Point?Element21': '', 'Point?Element22': '', 'Point?Element23': '', 'Point?Element24': '', 'Point?Element25': '', 'Point?Element26': '', 'Point?Element27': '', 'Point?Element28': '', 'Point?Element29': '', 'Point?Element30': '', 'Point?Element31': '', 'Point?Element32': '', 'Point?Element33': '', 'Point?Element34': '', 'Point?Element35': '', 'Point?Element36': '', 'Point?Element37': '', 'Point?Element38': '', 'Point?Element39': '', 'Point?Element40': ''}
# 16 shape015 ['hsc.shape.1'] {'TEXT?ACTIVITY': 'CH', 'TEXT?AREA': '제품운영1과', 'TEXT?TANK': '-', 'TEXT?PRODUCT': 'WAXY'}
# 25 shape027 ['hsc.shape.1'] {'T?T': 'U-2400'}
# 29 shape414 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_054_002', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 33 shape273 ['hsc.shape.1'] {'Point?element': '_P53102A', 'Value?DefElemType': '4', 'Value?ShapeID': 'CPump', 'Value?DataBoundObj': 'plyPump'}
# 42 shape050 ['hsc.shape.1'] {'Point?element': 'TK53104', 'Value?DefElemType': '1', 'Value?ShapeID': 'TankNozzle', 'Value?DataBoundObj': 'shaTank'}
# 44 shape050_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] {}
# 57 shape050_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] {}
# 67 shape023 ['hsc.shape.1'] {'Point?TankName': 'TK53104', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'W-31'}
# 77 shape051 ['hsc.shape.1'] {'Point?element': 'TK53105', 'Value?DefElemType': '1', 'Value?ShapeID': 'TankNozzle', 'Value?DataBoundObj': 'shaTank'}
# 79 shape051_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] {}
# 92 shape051_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] {}
# 102 shape024 ['hsc.shape.1'] {'Point?TankName': 'TK53105', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'W-96S'}
# 112 shape052 ['hsc.shape.1'] {'Point?element': 'TK53106', 'Value?DefElemType': '1', 'Value?ShapeID': 'TankNozzle', 'Value?DataBoundObj': 'shaTank'}
# 114 shape052_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] {}
# 127 shape052_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] {}
# 137 shape025 ['hsc.shape.1'] {'Point?TankName': 'TK53106', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'W-20'}
# 147 shape053 ['hsc.shape.1'] {'Point?element': 'TK53107', 'Value?DefElemType': '1', 'Value?ShapeID': 'TankNozzle', 'Value?DataBoundObj': 'shaTank'}
# 149 shape053_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] {}
# 162 shape053_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] {}
# 172 shape028 ['hsc.shape.1'] {'Point?TankName': 'TK53107', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'W-116'}
# 182 shape054 ['hsc.shape.1'] {'Point?element': 'TK53109', 'Value?DefElemType': '1', 'Value?ShapeID': 'TankNozzle', 'Value?DataBoundObj': 'shaTank'}
# 184 shape054_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] {}
# 197 shape054_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] {}
# 207 shape029 ['hsc.shape.1'] {'Point?TankName': 'TK53109', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'W-480'}
# 217 shape055 ['hsc.shape.1'] {'Point?element': 'TK53110', 'Value?DefElemType': '1', 'Value?ShapeID': 'TankNozzle', 'Value?DataBoundObj': 'shaTank'}
# 219 shape055_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] {}
# 232 shape055_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] {}
# 242 shape030 ['hsc.shape.1'] {'Point?TankName': 'TK53110', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'W-31S'}
# 252 shape056 ['hsc.shape.1'] {'Point?element': 'TK53111', 'Value?DefElemType': '1', 'Value?ShapeID': 'TankNozzle', 'Value?DataBoundObj': 'shaTank'}
# 254 shape056_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] {}
# 267 shape056_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] {}
# 277 shape031 ['hsc.shape.1'] {'Point?TankName': 'TK53110', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'W-31S'}
# 287 shape057 ['hsc.shape.1'] {'Point?element': 'TK5397', 'Value?DefElemType': '1', 'Value?ShapeID': 'TankNozzle', 'Value?DataBoundObj': 'shaTank'}
# 289 shape057_shaTank ['hsc.shape.1', 'HSC.ScriptDataObject.1'] {}
# 302 shape057_shaTankService ['hsc.shape.1', 'hsc.shapeanimation.1'] {}
# 312 shape032 ['hsc.shape.1'] {'Point?TankName': 'TK5397', 'Parameter?TaskID': 'TaskID', 'Parameter?Material': 'Matlcode', 'TEXT?MATERIAL': 'Mix-W'}
# 322 shape104 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_218', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_054_002', 'Value?EndPoint2': ''}
# 324 shape108 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_220', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_054_017', 'Value?EndPoint2': ''}
# 326 shape109 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_230', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_054_021', 'Value?EndPoint2': ''}
# 328 shape110 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_232', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_054_026', 'Value?EndPoint2': ''}
# 330 shape111 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_202', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_053_027', 'Value?EndPoint2': ''}
# 332 shape112 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_062_004', 'Value?EndPoint2': ''}
# 334 shape115 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_417', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_059_006', 'Value?EndPoint2': ''}
# 336 shape272 ['hsc.shape.1'] {'Point?element': '_P53102B', 'Value?DefElemType': '4', 'Value?ShapeID': 'CPump', 'Value?DataBoundObj': 'plyPump'}
# 344 shape310 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_360', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_021_122', 'Value?EndPoint2': ''}
# 346 shape792 ['hsc.shape.1'] {'Point?element': 'UN2400_WAXY', 'Value?DefElemType': '2', 'Value?ShapeID': 'BP', 'Value?DataBoundObj': 'plyBPArrow'}
# 350 shape033 ['hsc.shape.1'] {'T?T': 'U-2600'}
# 354 shape793 ['hsc.shape.1'] {'Point?element': 'UN2600_WAXY', 'Value?DefElemType': '2', 'Value?ShapeID': 'BP', 'Value?DataBoundObj': 'plyBPArrow'}
# 358 shape392 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_359', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_136', 'Value?EndPoint2': ''}
# 360 shape794 ['hsc.shape.1'] {'Point?element': 'UN20200_WAXY', 'Value?DefElemType': '2', 'Value?ShapeID': 'BP', 'Value?DataBoundObj': 'plyBPArrow'}
# 364 shape415 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_054_017', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 369 shape416 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_054_021', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 373 shape417 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_054_026', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 377 shape418 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_053_027', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 381 shape421 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_062_004', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 385 shape423 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_059_006', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 389 shape223 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_218', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': ''}
# 391 shape232 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_220', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 393 shape240 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_230', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 395 shape444 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_017_024', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 399 shape250 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_232', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 401 shape254 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_202', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': ''}
# 403 shape255 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_312', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_104', 'Value?EndPoint2': ''}
# 405 shape447 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_104', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 409 shape266 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_062_004', 'Value?EndPoint2': ''}
# 411 shape269 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_417', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_059_006', 'Value?EndPoint2': ''}
# 413 shape274 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_417', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_021_122', 'Value?EndPoint2': ''}
# 415 shape457 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_021_122', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 419 shape551 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_417', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_021_140~MAV_OS1_021_117', 'Value?EndPoint2': ''}
# 421 shape276 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_417', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_021_117', 'Value?EndPoint2': ''}
# 423 shape458 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_021_117', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 427 shape552 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_417', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_021_117', 'Value?EndPoint2': ''}
# 429 shape277 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_417', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_021_140', 'Value?EndPoint2': ''}
# 431 shape459 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_021_140', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 435 shape278 ['hsc.shape.1'] {'Point?element': '_P53104A', 'Value?DefElemType': '4', 'Value?ShapeID': 'CPump', 'Value?DataBoundObj': 'plyPump'}
# 443 shape279 ['hsc.shape.1'] {'Point?element': '_P53104B', 'Value?DefElemType': '4', 'Value?ShapeID': 'CPump', 'Value?DataBoundObj': 'plyPump'}
# 451 shape281 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_271', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': ''}
# 453 shape462 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_007', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 457 shape282 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_272', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': ''}
# 459 shape463 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_008', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 463 shape283 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_109', 'Value?EndPoint2': ''}
# 465 shape284 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_007', 'Value?EndPoint2': ''}
# 467 shape289 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_008', 'Value?EndPoint2': ''}
# 469 shape553 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_007~MAV_OS1_018_109', 'Value?EndPoint2': 'MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110~MAV_OS1_018_108'}
# 471 shape301 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2432', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 473 shape506 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_062', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 477 shape303 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 479 shape563 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010'}
# 481 shape304 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 483 shape507 ['hsc.shape.1'] {'Point?element': 'OMAVALVE', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 487 shape305 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2433', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 489 shape564 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2433', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010'}
# 491 shape314 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2433', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 493 shape315 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2433', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 495 shape508 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_073', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 499 shape329 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2433', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_073', 'Value?EndPoint2': ''}
# 501 shape565 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2433', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_074', 'Value?EndPoint2': ''}
# 503 shape509 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_074', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 507 shape330 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2433', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_074', 'Value?EndPoint2': ''}
# 509 shape334 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 511 shape566 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010'}
# 513 shape510 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_061', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 517 shape371 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_072', 'Value?EndPoint2': ''}
# 519 shape511 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_072', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 523 shape568 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010'}
# 525 shape393 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_033', 'Value?EndPoint2': ''}
# 527 shape512 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_033', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 531 shape569 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010'}
# 533 shape394 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_057', 'Value?EndPoint2': ''}
# 535 shape513 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_057', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 539 shape570 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2431', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_061', 'Value?EndPoint2': ''}
# 541 shape395 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2428', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 543 shape514 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_060', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 547 shape396 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_060', 'Value?EndPoint2': ''}
# 549 shape571 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010'}
# 551 shape397 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 553 shape515 ['hsc.shape.1'] {'Point?element': 'OMAVALVE', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 557 shape398 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2424', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 559 shape577 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2424', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010'}
# 561 shape399 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067~MAV_OS1_022_063~MAV_OS1_022_061', 'Value?EndPoint2': ''}
# 563 shape400 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2424', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 565 shape401 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2424', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 567 shape516 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_059', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 571 shape404 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_073', 'Value?EndPoint2': ''}
# 573 shape608 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_059', 'Value?EndPoint2': ''}
# 575 shape405 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_059', 'Value?EndPoint2': ''}
# 577 shape406 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'UN2600_WAXY', 'Value?EndPoint2': ''}
# 579 shape609 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_019_004', 'Value?EndPoint2': ''}
# 581 shape518 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_019_004', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 585 shape407 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_019_004', 'Value?EndPoint2': ''}
# 587 shape408 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'UN2600_WAXY', 'Value?EndPoint2': ''}
# 589 shape610 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_014_003', 'Value?EndPoint2': ''}
# 591 shape519 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_014_003', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 595 shape409 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_014_003', 'Value?EndPoint2': ''}
# 597 shape410 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_5002', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'UN2600_WAXY', 'Value?EndPoint2': ''}
# 599 shape523 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_246', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 601 shape627 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_069', 'Value?EndPoint2': ''}
# 603 shape651 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_064', 'Value?EndPoint2': ''}
# 605 shape308 ['hsc.shape.1'] {'Point?element': '_P5399A', 'Value?DefElemType': '4', 'Value?ShapeID': 'CPump', 'Value?DataBoundObj': 'plyPump'}
# 613 shape309 ['hsc.shape.1'] {'Point?element': '_P5399B', 'Value?DefElemType': '4', 'Value?ShapeID': 'CPump', 'Value?DataBoundObj': 'plyPump'}
# 621 shape312 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_289', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 623 shape468 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_043', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 627 shape313 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_289', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_043', 'Value?EndPoint2': ''}
# 629 shape316 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_360', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_043', 'Value?EndPoint2': ''}
# 631 shape469 ['hsc.shape.1'] {'Point?element': 'OMAVALVE', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 635 shape572 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_289', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'OMAVALVE', 'Value?EndPoint2': ''}
# 637 shape318 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_289', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'OMAVALVE', 'Value?EndPoint2': ''}
# 639 shape319 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_288', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'OMAVALVE', 'Value?EndPoint2': ''}
# 641 shape573 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_288', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'OMAVALVE', 'Value?EndPoint2': ''}
# 643 shape320 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_288', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '_P5399BR', 'Value?EndPoint2': ''}
# 645 shape321 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_288', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_136', 'Value?EndPoint2': ''}
# 647 shape574 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_360', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_042', 'Value?EndPoint2': ''}
# 649 shape470 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_042', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 653 shape322 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_360', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_042', 'Value?EndPoint2': ''}
# 655 shape323 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_287', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '_P5399AL', 'Value?EndPoint2': ''}
# 657 shape324 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_287', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_042', 'Value?EndPoint2': ''}
# 659 shape471 ['hsc.shape.1'] {'Point?element': 'OMAVALVE', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 663 shape575 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_287', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'OMAVALVE', 'Value?EndPoint2': ''}
# 665 shape325 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_287', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'OMAVALVE', 'Value?EndPoint2': ''}
# 667 shape326 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_286', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'OMAVALVE', 'Value?EndPoint2': ''}
# 669 shape576 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_286', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'OMAVALVE', 'Value?EndPoint2': ''}
# 671 shape327 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_286', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 673 shape328 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_286', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_038', 'Value?EndPoint2': ''}
# 675 shape472 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_038', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 680 shape473 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_136', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 685 shape390 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_359', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_038', 'Value?EndPoint2': ''}
# 687 shape391 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_359', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_136', 'Value?EndPoint2': ''}
# 689 shape607 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_359', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_038', 'Value?EndPoint2': ''}
# 692 shape035 ['hsc.shape.1'] {'T?T': 'U-20200'}
# 696 shape286 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_270', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': ''}
# 698 shape467 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_006', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 702 shape287 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_273', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': ''}
# 704 shape476 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_009', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 708 shape288 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_313', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_009', 'Value?EndPoint2': ''}
# 710 shape302 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_313', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_006', 'Value?EndPoint2': ''}
# 712 shape558 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_313', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_067~MAV_OS1_018_006', 'Value?EndPoint2': ''}
# 714 shape306 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_313', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_067', 'Value?EndPoint2': ''}
# 716 shape477 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_067', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 720 shape527 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_106', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 724 shape331 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_313', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_106', 'Value?EndPoint2': ''}
# 726 shape559 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_313', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_067~MAV_OS1_018_006~MAV_OS1_018_106', 'Value?EndPoint2': 'MAV_OS1_018_107~MAV_OS1_018_009'}
# 728 shape529 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_107', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 732 shape332 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_313', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_107', 'Value?EndPoint2': ''}
# 734 shape578 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_313', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_009', 'Value?EndPoint2': ''}
# 736 shape307 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_376', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_067', 'Value?EndPoint2': ''}
# 738 shape317 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_376', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_013_012', 'Value?EndPoint2': ''}
# 740 shape579 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_376', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_014_004', 'Value?EndPoint2': ''}
# 742 shape333 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_376', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_014_004', 'Value?EndPoint2': ''}
# 744 shape479 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_014_004', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 748 shape480 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_013_012', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 752 shape335 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_7279', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': ''}
# 754 shape481 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_013_013', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 758 shape534 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_7280', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_013_014', 'Value?EndPoint2': ''}
# 760 shape226 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_7280', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_013_014', 'Value?EndPoint2': ''}
# 762 shape433 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_013_014', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 766 shape536 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_7280', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_013_015', 'Value?EndPoint2': ''}
# 768 shape442 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_013_015', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 774 shape336 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_7280', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_013_013', 'Value?EndPoint2': ''}
# 776 shape337 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_7280', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'UN2400_WAXY', 'Value?EndPoint2': ''}
# 779 shape659 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_021_047', 'Value?EndPoint2': ''}
# 781 shape660 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_021_047', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 785 shape661 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_021_047', 'Value?EndPoint2': ''}
# 787 shape580 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_024_031', 'Value?EndPoint2': ''}
# 789 shape262 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_024_031', 'Value?EndPoint2': ''}
# 791 shape455 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_024_031', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 795 shape271 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_062_004~MAV_OS1_024_031', 'Value?EndPoint2': ''}
# 797 shape116 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_491', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_062_013', 'Value?EndPoint2': ''}
# 799 shape422 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_062_013', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 803 shape341 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_491', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_068', 'Value?EndPoint2': ''}
# 833 shape584 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_061', 'Value?EndPoint2': ''}
# 835 shape640 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_068', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 839 shape641 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_069', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 843 shape642 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_067', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 847 shape643 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_065', 'Value?EndPoint2': ''}
# 849 shape644 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_066', 'Value?EndPoint2': ''}
# 851 shape645 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_067', 'Value?EndPoint2': ''}
# 853 shape646 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067', 'Value?EndPoint2': ''}
# 855 shape647 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_065~MAV_OS1_022_066', 'Value?EndPoint2': ''}
# 857 shape648 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_065', 'Value?EndPoint2': ''}
# 859 shape649 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_064', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 863 shape668 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2426', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_063', 'Value?EndPoint2': ''}
# 868 PseudoValve039 ['hsc.shape.1'] {'Point?element': '_P53102AL', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValvePseudo', 'Value?DataBoundObj': 'ovlValve'}
# 872 PseudoValve040 ['hsc.shape.1'] {'Point?element': '_P53102AR', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValvePseudo', 'Value?DataBoundObj': 'ovlValve'}
# 876 PseudoValve041 ['hsc.shape.1'] {'Point?element': '_P53102BL', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValvePseudo', 'Value?DataBoundObj': 'ovlValve'}
# 880 PseudoValve042 ['hsc.shape.1'] {'Point?element': '_P53102BR', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValvePseudo', 'Value?DataBoundObj': 'ovlValve'}
# 884 PseudoValve043 ['hsc.shape.1'] {'Point?element': '_P53104AL', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValvePseudo', 'Value?DataBoundObj': 'ovlValve'}
# 888 PseudoValve044 ['hsc.shape.1'] {'Point?element': '_P53104AR', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValvePseudo', 'Value?DataBoundObj': 'ovlValve'}
# 892 PseudoValve045 ['hsc.shape.1'] {'Point?element': '_P53104BL', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValvePseudo', 'Value?DataBoundObj': 'ovlValve'}
# 896 PseudoValve046 ['hsc.shape.1'] {'Point?element': '_P53104BR', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValvePseudo', 'Value?DataBoundObj': 'ovlValve'}
# 900 PseudoValve047 ['hsc.shape.1'] {'Point?element': '_P5399AL', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValvePseudo', 'Value?DataBoundObj': 'ovlValve'}
# 904 PseudoValve048 ['hsc.shape.1'] {'Point?element': '_P5399AR', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValvePseudo', 'Value?DataBoundObj': 'ovlValve'}
# 908 PseudoValve049 ['hsc.shape.1'] {'Point?element': '_P5399BL', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValvePseudo', 'Value?DataBoundObj': 'ovlValve'}
# 912 PseudoValve050 ['hsc.shape.1'] {'Point?element': '_P5399BR', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValvePseudo', 'Value?DataBoundObj': 'ovlValve'}
# 916 shape619 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_368', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_011', 'Value?EndPoint2': ''}
# 918 shape650 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_063', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 922 shape438 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_109', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 926 shape292 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_108', 'Value?EndPoint2': ''}
# 929 shape439 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_108', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 933 shape293 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_110', 'Value?EndPoint2': ''}
# 935 shape461 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_110', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 939 shape587 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108~MAV_OS1_018_110', 'Value?EndPoint2': 'MAV_OS1_018_111~MAV_OS1_018_008'}
# 941 shape297 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_111', 'Value?EndPoint2': ''}
# 943 shape464 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_111', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 947 shape311 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_323', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_109', 'Value?EndPoint2': ''}
# 949 shape347 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_321', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_108', 'Value?EndPoint2': ''}
# 951 shape348 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_326', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_110', 'Value?EndPoint2': ''}
# 953 shape349 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_327', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 955 shape588 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_314', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_008', 'Value?EndPoint2': ''}
# 957 shape465 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_072', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 961 shape617 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_323', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_134~MAV_OS1_018_116', 'Value?EndPoint2': 'MAV_OS1_018_072~MAV_OS1_018_109'}
# 963 shape622 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_323', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_134~MAV_OS1_018_116', 'Value?EndPoint2': 'MAV_OS1_018_072~MAV_OS1_018_109'}
# 965 shape637 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_323', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_134~MAV_OS1_018_116', 'Value?EndPoint2': 'MAV_OS1_018_072~MAV_OS1_018_109'}
# 967 shape350 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_323', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_072', 'Value?EndPoint2': ''}
# 969 shape475 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_071', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 973 shape483 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_074', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 977 shape484 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_075', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 981 shape638 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_323', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_134~MAV_OS1_018_116', 'Value?EndPoint2': 'MAV_OS1_018_072~MAV_OS1_018_109'}
# 983 shape655 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_321', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_117', 'Value?EndPoint2': 'MAV010'}
# 985 shape352 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_321', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_071', 'Value?EndPoint2': ''}
# 987 shape672 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_321', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_117', 'Value?EndPoint2': 'MAV010'}
# 989 shape673 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_321', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_117', 'Value?EndPoint2': 'MAV010'}
# 991 shape674 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_326', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_141~MAV_OS1_018_115', 'Value?EndPoint2': ''}
# 993 shape675 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_326', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_141~MAV_OS1_018_115', 'Value?EndPoint2': ''}
# 995 shape676 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_327', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010'}
# 997 shape353 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_326', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_074', 'Value?EndPoint2': ''}
# 999 shape354 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_327', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 1001 shape677 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_220', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010'}
# 1003 shape355 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_220', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 1005 shape678 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_230', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010'}
# 1007 shape356 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_230', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 1009 shape679 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_246', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010'}
# 1011 shape357 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_246', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 1014 shape589 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_368', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010'}
# 1016 shape358 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_327', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_114', 'Value?EndPoint2': ''}
# 1018 shape485 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_114', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1022 shape359 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_368', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_114', 'Value?EndPoint2': ''}
# 1024 shape360 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_326', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_115', 'Value?EndPoint2': ''}
# 1026 shape486 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_115', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1030 shape361 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_368', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_115', 'Value?EndPoint2': ''}
# 1032 shape362 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_321', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_117', 'Value?EndPoint2': ''}
# 1034 shape487 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_117', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1038 shape363 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_368', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_117', 'Value?EndPoint2': ''}
# 1040 shape364 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_323', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_116', 'Value?EndPoint2': ''}
# 1042 shape488 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_116', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1046 shape365 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_368', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_116', 'Value?EndPoint2': ''}
# 1048 shape590 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_368', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV005~MAV004', 'Value?EndPoint2': 'MAV010'}
# 1050 shape591 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_368', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_116', 'Value?EndPoint2': 'MAV010'}
# 1052 shape366 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_326', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_115', 'Value?EndPoint2': ''}
# 1054 shape367 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_321', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_117', 'Value?EndPoint2': ''}
# 1056 shape368 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_321', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_117', 'Value?EndPoint2': ''}
# 1058 shape369 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_323', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_116', 'Value?EndPoint2': ''}
# 1060 shape370 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_323', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_116', 'Value?EndPoint2': ''}
# 1062 shape372 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_323', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_116', 'Value?EndPoint2': ''}
# 1064 shape680 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_312', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_130', 'Value?EndPoint2': ''}
# 1066 shape373 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_327', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_130', 'Value?EndPoint2': ''}
# 1068 shape490 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_130', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1072 shape374 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_312', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_130', 'Value?EndPoint2': ''}
# 1074 shape375 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_326', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_141', 'Value?EndPoint2': ''}
# 1076 shape491 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_141', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1080 shape376 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_323', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_134', 'Value?EndPoint2': ''}
# 1082 shape492 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_134', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1086 shape681 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_011', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1090 shape682 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_011', 'Value?EndPoint2': ''}
# 1092 shape377 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_013', 'Value?EndPoint2': ''}
# 1094 shape378 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_100', 'Value?EndPoint2': ''}
# 1096 shape379 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_172', 'Value?EndPoint2': ''}
# 1098 shape683 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011', 'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100'}
# 1100 shape684 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100', 'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172'}
# 1102 shape380 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2427', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 1104 shape686 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_064', 'Value?EndPoint2': ''}
# 1106 shape689 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_013', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1110 shape690 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_100', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1114 shape691 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_172', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1128 shape382 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_325', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011', 'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100'}
# 1130 shape692 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_491', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_068', 'Value?EndPoint2': ''}
# 1132 shape693 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_491', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_068', 'Value?EndPoint2': 'MAV010'}
# 1138 shape383 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_220', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'PSP5383L', 'Value?EndPoint2': ''}
# 1140 shape493 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_073', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1146 shape694 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_065', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1150 shape695 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2430', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': ''}
# 1152 shape696 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_066', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1156 shape697 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2430', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': '', 'Value?EndPoint2': ''}
# 1161 shape698 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_069', 'Value?EndPoint2': ''}
# 1163 shape699 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_483', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_069', 'Value?EndPoint2': ''}
# 1165 shape592 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2424', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_162', 'Value?EndPoint2': 'MAV010'}
# 1167 shape517 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_022_162', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1171 shape384 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2424', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_162', 'Value?EndPoint2': ''}
# 1173 shape402 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_2424', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_022_059', 'Value?EndPoint2': ''}
# 1175 shape494 ['hsc.shape.1'] {'Point?element': 'MAV_OS1_018_065', 'Value?DefElemType': '5', 'Value?ShapeID': 'ValveMan', 'Value?DataBoundObj': 'plyValve'}
# 1179 shape275 ['hsc.shape.1'] {'Point?element': 'MAL_OS1_312', 'Value?DefElemType': '3', 'Value?ShapeID': 'Line', 'Value?DataBoundObj': 'linPipe', 'Value?EndPoint1': 'MAV_OS1_018_065', 'Value?EndPoint2': ''}

# %%
# make dictionary
total = {}
for i,div in enumerate(divs):
    if 'hsc.shape.1' in div['class']:
        param = {}
        for p in div['parameters'].split(';'):
            param.update(dict(zip(p.split(':')[::2], p.split(':')[1::2])))
        #print(i,div['id'], div['class'], param)
        total[div['id']] = param
total
# Out:
# {'PseudoValve039': {'Point?element': '_P53102AL',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo'},
#  'PseudoValve040': {'Point?element': '_P53102AR',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo'},
#  'PseudoValve041': {'Point?element': '_P53102BL',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo'},
#  'PseudoValve042': {'Point?element': '_P53102BR',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo'},
#  'PseudoValve043': {'Point?element': '_P53104AL',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo'},
#  'PseudoValve044': {'Point?element': '_P53104AR',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo'},
#  'PseudoValve045': {'Point?element': '_P53104BL',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo'},
#  'PseudoValve046': {'Point?element': '_P53104BR',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo'},
#  'PseudoValve047': {'Point?element': '_P5399AL',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo'},
#  'PseudoValve048': {'Point?element': '_P5399AR',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo'},
#  'PseudoValve049': {'Point?element': '_P5399BL',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo'},
#  'PseudoValve050': {'Point?element': '_P5399BR',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo'},
#  'shape001': {},
#  'shape015': {'TEXT?ACTIVITY': 'CH',
#   'TEXT?AREA': '제품운영1과',
#   'TEXT?PRODUCT': 'WAXY',
#   'TEXT?TANK': '-'},
#  'shape023': {'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53104',
#   'TEXT?MATERIAL': 'W-31'},
#  'shape024': {'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53105',
#   'TEXT?MATERIAL': 'W-96S'},
#  'shape025': {'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53106',
#   'TEXT?MATERIAL': 'W-20'},
#  'shape027': {'T?T': 'U-2400'},
#  'shape028': {'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53107',
#   'TEXT?MATERIAL': 'W-116'},
#  'shape029': {'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53109',
#   'TEXT?MATERIAL': 'W-480'},
#  'shape030': {'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53110',
#   'TEXT?MATERIAL': 'W-31S'},
#  'shape031': {'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53110',
#   'TEXT?MATERIAL': 'W-31S'},
#  'shape032': {'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK5397',
#   'TEXT?MATERIAL': 'Mix-W'},
#  'shape033': {'T?T': 'U-2600'},
#  'shape035': {'T?T': 'U-20200'},
#  'shape050': {'Point?element': 'TK53104',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle'},
#  'shape050_shaTank': {},
#  'shape050_shaTankService': {},
#  'shape051': {'Point?element': 'TK53105',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle'},
#  'shape051_shaTank': {},
#  'shape051_shaTankService': {},
#  'shape052': {'Point?element': 'TK53106',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle'},
#  'shape052_shaTank': {},
#  'shape052_shaTankService': {},
#  'shape053': {'Point?element': 'TK53107',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle'},
#  'shape053_shaTank': {},
#  'shape053_shaTankService': {},
#  'shape054': {'Point?element': 'TK53109',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle'},
#  'shape054_shaTank': {},
#  'shape054_shaTankService': {},
#  'shape055': {'Point?element': 'TK53110',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle'},
#  'shape055_shaTank': {},
#  'shape055_shaTankService': {},
#  'shape056': {'Point?element': 'TK53111',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle'},
#  'shape056_shaTank': {},
#  'shape056_shaTankService': {},
#  'shape057': {'Point?element': 'TK5397',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle'},
#  'shape057_shaTank': {},
#  'shape057_shaTankService': {},
#  'shape104': {'Point?element': 'MAL_OS1_218',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_002',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape108': {'Point?element': 'MAL_OS1_220',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_017',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape109': {'Point?element': 'MAL_OS1_230',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_021',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape110': {'Point?element': 'MAL_OS1_232',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_026',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape111': {'Point?element': 'MAL_OS1_202',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_053_027',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape112': {'Point?element': 'MAL_OS1_483',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape115': {'Point?element': 'MAL_OS1_417',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_059_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape116': {'Point?element': 'MAL_OS1_491',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_013',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape223': {'Point?element': 'MAL_OS1_218',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape226': {'Point?element': 'MAL_OS1_7280',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_013_014',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape232': {'Point?element': 'MAL_OS1_220',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape240': {'Point?element': 'MAL_OS1_230',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape250': {'Point?element': 'MAL_OS1_232',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape254': {'Point?element': 'MAL_OS1_202',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape255': {'Point?element': 'MAL_OS1_312',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_104',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape262': {'Point?element': 'MAL_OS1_483',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape266': {'Point?element': 'MAL_OS1_483',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape269': {'Point?element': 'MAL_OS1_417',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_059_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape271': {'Point?element': 'MAL_OS1_483',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004~MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape272': {'Point?element': '_P53102B',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump'},
#  'shape273': {'Point?element': '_P53102A',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump'},
#  'shape274': {'Point?element': 'MAL_OS1_417',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_122',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape275': {'Point?element': 'MAL_OS1_312',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_065',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape276': {'Point?element': 'MAL_OS1_417',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_117',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape277': {'Point?element': 'MAL_OS1_417',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_140',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape278': {'Point?element': '_P53104A',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump'},
#  'shape279': {'Point?element': '_P53104B',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump'},
#  'shape281': {'Point?element': 'MAL_OS1_271',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape282': {'Point?element': 'MAL_OS1_272',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape283': {'Point?element': 'MAL_OS1_314',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_109',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape284': {'Point?element': 'MAL_OS1_314',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_007',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape286': {'Point?element': 'MAL_OS1_270',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape287': {'Point?element': 'MAL_OS1_273',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape288': {'Point?element': 'MAL_OS1_313',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_009',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape289': {'Point?element': 'MAL_OS1_314',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_008',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape292': {'Point?element': 'MAL_OS1_314',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_108',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape293': {'Point?element': 'MAL_OS1_314',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_110',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape297': {'Point?element': 'MAL_OS1_314',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_111',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape301': {'Point?element': 'MAL_OS1_2432',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape302': {'Point?element': 'MAL_OS1_313',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape303': {'Point?element': 'MAL_OS1_2431',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape304': {'Point?element': 'MAL_OS1_2431',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape305': {'Point?element': 'MAL_OS1_2433',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape306': {'Point?element': 'MAL_OS1_313',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_067',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape307': {'Point?element': 'MAL_OS1_376',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_067',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape308': {'Point?element': '_P5399A',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump'},
#  'shape309': {'Point?element': '_P5399B',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump'},
#  'shape310': {'Point?element': 'MAL_OS1_360',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_122',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape311': {'Point?element': 'MAL_OS1_323',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_109',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape312': {'Point?element': 'MAL_OS1_289',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape313': {'Point?element': 'MAL_OS1_289',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_043',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape314': {'Point?element': 'MAL_OS1_2433',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape315': {'Point?element': 'MAL_OS1_2433',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape316': {'Point?element': 'MAL_OS1_360',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_043',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape317': {'Point?element': 'MAL_OS1_376',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_013_012',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape318': {'Point?element': 'MAL_OS1_289',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'OMAVALVE',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape319': {'Point?element': 'MAL_OS1_288',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'OMAVALVE',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape320': {'Point?element': 'MAL_OS1_288',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '_P5399BR',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape321': {'Point?element': 'MAL_OS1_288',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_136',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape322': {'Point?element': 'MAL_OS1_360',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_042',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape323': {'Point?element': 'MAL_OS1_287',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '_P5399AL',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape324': {'Point?element': 'MAL_OS1_287',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_042',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape325': {'Point?element': 'MAL_OS1_287',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'OMAVALVE',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape326': {'Point?element': 'MAL_OS1_286',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'OMAVALVE',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape327': {'Point?element': 'MAL_OS1_286',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape328': {'Point?element': 'MAL_OS1_286',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_038',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape329': {'Point?element': 'MAL_OS1_2433',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_073',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape330': {'Point?element': 'MAL_OS1_2433',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_074',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape331': {'Point?element': 'MAL_OS1_313',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_106',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape332': {'Point?element': 'MAL_OS1_313',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_107',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape333': {'Point?element': 'MAL_OS1_376',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_014_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape334': {'Point?element': 'MAL_OS1_2431',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape335': {'Point?element': 'MAL_OS1_7279',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape336': {'Point?element': 'MAL_OS1_7280',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_013_013',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape337': {'Point?element': 'MAL_OS1_7280',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'UN2400_WAXY',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape341': {'Point?element': 'MAL_OS1_491',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape347': {'Point?element': 'MAL_OS1_321',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_108',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape348': {'Point?element': 'MAL_OS1_326',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_110',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape349': {'Point?element': 'MAL_OS1_327',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape350': {'Point?element': 'MAL_OS1_323',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_072',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape352': {'Point?element': 'MAL_OS1_321',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_071',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape353': {'Point?element': 'MAL_OS1_326',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_074',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape354': {'Point?element': 'MAL_OS1_327',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape355': {'Point?element': 'MAL_OS1_220',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape356': {'Point?element': 'MAL_OS1_230',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape357': {'Point?element': 'MAL_OS1_246',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape358': {'Point?element': 'MAL_OS1_327',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_114',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape359': {'Point?element': 'MAL_OS1_368',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_114',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape360': {'Point?element': 'MAL_OS1_326',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_115',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape361': {'Point?element': 'MAL_OS1_368',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_115',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape362': {'Point?element': 'MAL_OS1_321',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_117',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape363': {'Point?element': 'MAL_OS1_368',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_117',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape364': {'Point?element': 'MAL_OS1_323',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_116',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape365': {'Point?element': 'MAL_OS1_368',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_116',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape366': {'Point?element': 'MAL_OS1_326',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_115',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape367': {'Point?element': 'MAL_OS1_321',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_117',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape368': {'Point?element': 'MAL_OS1_321',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_117',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape369': {'Point?element': 'MAL_OS1_323',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_116',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape370': {'Point?element': 'MAL_OS1_323',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_116',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape371': {'Point?element': 'MAL_OS1_2431',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_072',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape372': {'Point?element': 'MAL_OS1_323',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_116',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape373': {'Point?element': 'MAL_OS1_327',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_130',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape374': {'Point?element': 'MAL_OS1_312',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_130',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape375': {'Point?element': 'MAL_OS1_326',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_141',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape376': {'Point?element': 'MAL_OS1_323',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_134',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape377': {'Point?element': 'MAL_OS1_325',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape378': {'Point?element': 'MAL_OS1_325',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_100',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape379': {'Point?element': 'MAL_OS1_325',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_172',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape380': {'Point?element': 'MAL_OS1_2427',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape382': {'Point?element': 'MAL_OS1_325',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100',
#   'Value?ShapeID': 'Line'},
#  'shape383': {'Point?element': 'MAL_OS1_220',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape384': {'Point?element': 'MAL_OS1_2424',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_162',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape385': {'Point?element': 'MAL_OS1_7280',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_013_014~MAV_OS1_013_013',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape390': {'Point?element': 'MAL_OS1_359',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_038',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape391': {'Point?element': 'MAL_OS1_359',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_136',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape392': {'Point?element': 'MAL_OS1_359',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_136',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape393': {'Point?element': 'MAL_OS1_2431',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_033',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape394': {'Point?element': 'MAL_OS1_2431',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_057',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape395': {'Point?element': 'MAL_OS1_2428',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape396': {'Point?element': 'MAL_OS1_2426',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_060',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape397': {'Point?element': 'MAL_OS1_2426',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape398': {'Point?element': 'MAL_OS1_2424',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape399': {'Point?element': 'MAL_OS1_2426',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067~MAV_OS1_022_063~MAV_OS1_022_061',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape400': {'Point?element': 'MAL_OS1_2424',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape401': {'Point?element': 'MAL_OS1_2424',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape402': {'Point?element': 'MAL_OS1_2424',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_059',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape404': {'Point?element': 'MAL_OS1_5002',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_073',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape405': {'Point?element': 'MAL_OS1_5002',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_059',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape406': {'Point?element': 'MAL_OS1_5002',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'UN2600_WAXY',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape407': {'Point?element': 'MAL_OS1_5002',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_019_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape408': {'Point?element': 'MAL_OS1_5002',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'UN2600_WAXY',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape409': {'Point?element': 'MAL_OS1_5002',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_014_003',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape410': {'Point?element': 'MAL_OS1_5002',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'UN2600_WAXY',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape414': {'Point?element': 'MAV_OS1_054_002',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape415': {'Point?element': 'MAV_OS1_054_017',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape416': {'Point?element': 'MAV_OS1_054_021',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape417': {'Point?element': 'MAV_OS1_054_026',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape418': {'Point?element': 'MAV_OS1_053_027',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape421': {'Point?element': 'MAV_OS1_062_004',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape422': {'Point?element': 'MAV_OS1_062_013',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape423': {'Point?element': 'MAV_OS1_059_006',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape433': {'Point?element': 'MAV_OS1_013_014',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape438': {'Point?element': 'MAV_OS1_018_109',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape439': {'Point?element': 'MAV_OS1_018_108',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape442': {'Point?element': 'MAV_OS1_013_015',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape444': {'Point?element': 'MAV_OS1_017_024',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape447': {'Point?element': 'MAV_OS1_018_104',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape455': {'Point?element': 'MAV_OS1_024_031',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape457': {'Point?element': 'MAV_OS1_021_122',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape458': {'Point?element': 'MAV_OS1_021_117',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape459': {'Point?element': 'MAV_OS1_021_140',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape461': {'Point?element': 'MAV_OS1_018_110',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape462': {'Point?element': 'MAV_OS1_018_007',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape463': {'Point?element': 'MAV_OS1_018_008',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape464': {'Point?element': 'MAV_OS1_018_111',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape465': {'Point?element': 'MAV_OS1_018_072',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape467': {'Point?element': 'MAV_OS1_018_006',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape468': {'Point?element': 'MAV_OS1_018_043',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape469': {'Point?element': 'OMAVALVE',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape470': {'Point?element': 'MAV_OS1_018_042',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape471': {'Point?element': 'OMAVALVE',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape472': {'Point?element': 'MAV_OS1_018_038',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape473': {'Point?element': 'MAV_OS1_018_136',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape475': {'Point?element': 'MAV_OS1_018_071',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape476': {'Point?element': 'MAV_OS1_018_009',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape477': {'Point?element': 'MAV_OS1_018_067',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape479': {'Point?element': 'MAV_OS1_014_004',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape480': {'Point?element': 'MAV_OS1_013_012',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape481': {'Point?element': 'MAV_OS1_013_013',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape483': {'Point?element': 'MAV_OS1_018_074',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape484': {'Point?element': 'MAV_OS1_018_075',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape485': {'Point?element': 'MAV_OS1_018_114',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape486': {'Point?element': 'MAV_OS1_018_115',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape487': {'Point?element': 'MAV_OS1_018_117',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape488': {'Point?element': 'MAV_OS1_018_116',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape490': {'Point?element': 'MAV_OS1_018_130',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape491': {'Point?element': 'MAV_OS1_018_141',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape492': {'Point?element': 'MAV_OS1_018_134',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape493': {'Point?element': 'MAV_OS1_018_073',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape494': {'Point?element': 'MAV_OS1_018_065',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape506': {'Point?element': 'MAV_OS1_022_062',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape507': {'Point?element': 'OMAVALVE',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape508': {'Point?element': 'MAV_OS1_022_073',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape509': {'Point?element': 'MAV_OS1_022_074',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape510': {'Point?element': 'MAV_OS1_022_061',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape511': {'Point?element': 'MAV_OS1_022_072',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape512': {'Point?element': 'MAV_OS1_022_033',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape513': {'Point?element': 'MAV_OS1_022_057',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape514': {'Point?element': 'MAV_OS1_022_060',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape515': {'Point?element': 'OMAVALVE',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape516': {'Point?element': 'MAV_OS1_022_059',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape517': {'Point?element': 'MAV_OS1_022_162',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape518': {'Point?element': 'MAV_OS1_019_004',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape519': {'Point?element': 'MAV_OS1_014_003',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape523': {'Point?element': 'MAL_OS1_246',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape527': {'Point?element': 'MAV_OS1_018_106',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape529': {'Point?element': 'MAV_OS1_018_107',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape534': {'Point?element': 'MAL_OS1_7280',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_013_014',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape536': {'Point?element': 'MAL_OS1_7280',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_013_015',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape551': {'Point?element': 'MAL_OS1_417',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_140~MAV_OS1_021_117',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape552': {'Point?element': 'MAL_OS1_417',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_117',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape553': {'Point?element': 'MAL_OS1_314',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_007~MAV_OS1_018_109',
#   'Value?EndPoint2': 'MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110~MAV_OS1_018_108',
#   'Value?ShapeID': 'Line'},
#  'shape554': {'Point?element': 'MAL_OS1_314',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108',
#   'Value?EndPoint2': 'MAV_OS1_018_111~MAV_OS1_018_008~MAV_OS1_018_110',
#   'Value?ShapeID': 'Line'},
#  'shape558': {'Point?element': 'MAL_OS1_313',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_067~MAV_OS1_018_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape559': {'Point?element': 'MAL_OS1_313',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_067~MAV_OS1_018_006~MAV_OS1_018_106',
#   'Value?EndPoint2': 'MAV_OS1_018_107~MAV_OS1_018_009',
#   'Value?ShapeID': 'Line'},
#  'shape563': {'Point?element': 'MAL_OS1_2431',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape564': {'Point?element': 'MAL_OS1_2433',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape565': {'Point?element': 'MAL_OS1_2433',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_074',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape566': {'Point?element': 'MAL_OS1_2431',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape568': {'Point?element': 'MAL_OS1_2431',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape569': {'Point?element': 'MAL_OS1_2431',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape570': {'Point?element': 'MAL_OS1_2431',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_061',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape571': {'Point?element': 'MAL_OS1_2426',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape572': {'Point?element': 'MAL_OS1_289',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'OMAVALVE',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape573': {'Point?element': 'MAL_OS1_288',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'OMAVALVE',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape574': {'Point?element': 'MAL_OS1_360',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_042',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape575': {'Point?element': 'MAL_OS1_287',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'OMAVALVE',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape576': {'Point?element': 'MAL_OS1_286',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'OMAVALVE',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape577': {'Point?element': 'MAL_OS1_2424',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape578': {'Point?element': 'MAL_OS1_313',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_009',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape579': {'Point?element': 'MAL_OS1_376',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_014_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape580': {'Point?element': 'MAL_OS1_483',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape584': {'Point?element': 'MAL_OS1_2426',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_061',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape587': {'Point?element': 'MAL_OS1_314',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_007~MAV_OS1_018_109~MAV_OS1_018_108~MAV_OS1_018_110',
#   'Value?EndPoint2': 'MAV_OS1_018_111~MAV_OS1_018_008',
#   'Value?ShapeID': 'Line'},
#  'shape588': {'Point?element': 'MAL_OS1_314',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_008',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape589': {'Point?element': 'MAL_OS1_368',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape590': {'Point?element': 'MAL_OS1_368',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape591': {'Point?element': 'MAL_OS1_368',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_116',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape592': {'Point?element': 'MAL_OS1_2424',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_162',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape607': {'Point?element': 'MAL_OS1_359',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_038',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape608': {'Point?element': 'MAL_OS1_5002',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_059',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape609': {'Point?element': 'MAL_OS1_5002',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_019_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape610': {'Point?element': 'MAL_OS1_5002',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_014_003',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape617': {'Point?element': 'MAL_OS1_323',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_134~MAV_OS1_018_116',
#   'Value?EndPoint2': 'MAV_OS1_018_072~MAV_OS1_018_109',
#   'Value?ShapeID': 'Line'},
#  'shape619': {'Point?element': 'MAL_OS1_368',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_011',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape622': {'Point?element': 'MAL_OS1_323',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_134~MAV_OS1_018_116',
#   'Value?EndPoint2': 'MAV_OS1_018_072~MAV_OS1_018_109',
#   'Value?ShapeID': 'Line'},
#  'shape627': {'Point?element': 'MAL_OS1_483',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape637': {'Point?element': 'MAL_OS1_323',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_134~MAV_OS1_018_116',
#   'Value?EndPoint2': 'MAV_OS1_018_072~MAV_OS1_018_109',
#   'Value?ShapeID': 'Line'},
#  'shape638': {'Point?element': 'MAL_OS1_323',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_134~MAV_OS1_018_116',
#   'Value?EndPoint2': 'MAV_OS1_018_072~MAV_OS1_018_109',
#   'Value?ShapeID': 'Line'},
#  'shape640': {'Point?element': 'MAV_OS1_022_068',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape641': {'Point?element': 'MAV_OS1_022_069',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape642': {'Point?element': 'MAV_OS1_022_067',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape643': {'Point?element': 'MAL_OS1_2426',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_065',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape644': {'Point?element': 'MAL_OS1_2426',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_066',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape645': {'Point?element': 'MAL_OS1_2426',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_067',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape646': {'Point?element': 'MAL_OS1_2426',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_065~MAV_OS1_022_066~MAV_OS1_022_067',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape647': {'Point?element': 'MAL_OS1_2426',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_065~MAV_OS1_022_066',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape648': {'Point?element': 'MAL_OS1_2426',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_065',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape649': {'Point?element': 'MAV_OS1_022_064',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape650': {'Point?element': 'MAV_OS1_022_063',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape651': {'Point?element': 'MAL_OS1_325',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_064',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape655': {'Point?element': 'MAL_OS1_321',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_117',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape659': {'Point?element': 'MAL_OS1_483',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_047',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape660': {'Point?element': 'MAV_OS1_021_047',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape661': {'Point?element': 'MAL_OS1_483',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_047',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape668': {'Point?element': 'MAL_OS1_2426',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_063',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape672': {'Point?element': 'MAL_OS1_321',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_117',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape673': {'Point?element': 'MAL_OS1_321',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_117',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape674': {'Point?element': 'MAL_OS1_326',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_141~MAV_OS1_018_115',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape675': {'Point?element': 'MAL_OS1_326',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_141~MAV_OS1_018_115',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape676': {'Point?element': 'MAL_OS1_327',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape677': {'Point?element': 'MAL_OS1_220',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape678': {'Point?element': 'MAL_OS1_230',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape679': {'Point?element': 'MAL_OS1_246',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape680': {'Point?element': 'MAL_OS1_312',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_130',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape681': {'Point?element': 'MAV_OS1_018_011',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape682': {'Point?element': 'MAL_OS1_325',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_011',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape683': {'Point?element': 'MAL_OS1_325',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100',
#   'Value?ShapeID': 'Line'},
#  'shape684': {'Point?element': 'MAL_OS1_325',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172',
#   'Value?ShapeID': 'Line'},
#  'shape686': {'Point?element': 'MAL_OS1_325',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_064',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape689': {'Point?element': 'MAV_OS1_018_013',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape690': {'Point?element': 'MAV_OS1_018_100',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape691': {'Point?element': 'MAV_OS1_018_172',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape692': {'Point?element': 'MAL_OS1_491',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape693': {'Point?element': 'MAL_OS1_491',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line'},
#  'shape694': {'Point?element': 'MAV_OS1_022_065',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape695': {'Point?element': 'MAL_OS1_2430',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape696': {'Point?element': 'MAV_OS1_022_066',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan'},
#  'shape697': {'Point?element': 'MAL_OS1_2430',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape698': {'Point?element': 'MAL_OS1_483',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape699': {'Point?element': 'MAL_OS1_483',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line'},
#  'shape792': {'Point?element': 'UN2400_WAXY',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP'},
#  'shape793': {'Point?element': 'UN2600_WAXY',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP'},
#  'shape794': {'Point?element': 'UN20200_WAXY',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP'},
#  'tfgOffDisplayEndPoints': {'Point?Element1': '',
#   'Point?Element10': '',
#   'Point?Element11': '',
#   'Point?Element12': '',
#   'Point?Element13': '',
#   'Point?Element14': '',
#   'Point?Element15': '',
#   'Point?Element16': '',
#   'Point?Element17': '',
#   'Point?Element18': '',
#   'Point?Element19': '',
#   'Point?Element2': '',
#   'Point?Element20': '',
#   'Point?Element21': '',
#   'Point?Element22': '',
#   'Point?Element23': '',
#   'Point?Element24': '',
#   'Point?Element25': '',
#   'Point?Element26': '',
#   'Point?Element27': '',
#   'Point?Element28': '',
#   'Point?Element29': '',
#   'Point?Element3': '',
#   'Point?Element30': '',
#   'Point?Element31': '',
#   'Point?Element32': '',
#   'Point?Element33': '',
#   'Point?Element34': '',
#   'Point?Element35': '',
#   'Point?Element36': '',
#   'Point?Element37': '',
#   'Point?Element38': '',
#   'Point?Element39': '',
#   'Point?Element4': '',
#   'Point?Element40': '',
#   'Point?Element5': '',
#   'Point?Element6': '',
#   'Point?Element7': '',
#   'Point?Element8': '',
#   'Point?Element9': ''},
#  'tfgOperDataReInit': {},
#  'tfgPlanningData': {'Point?DestElement': '',
#   'Point?SrcElement': '',
#   'Value?IgnoreOnDataChange': '"True"'},
#  'tfgSelectTimeout': {'Point?DestElement': '',
#   'Point?SrcElement': '',
#   'Value?IgnoreOnDataChange': '"True"'}}

# %%
# make dictionary -2
total = {}
for i,div in enumerate(divs):
    if 'hsc.shape.1' in div['class']:
        total[div['id']] = {'id':i}
        param = {}
        for p in div['parameters'].split(';'):
            param.update(dict(zip(p.split(':')[::2], p.split(':')[1::2])))
        total[div['id']].update(param)
        style = {}
        for s in div['style'].split('; '):
            style.update(dict(zip(s.split(':')[::2], s.split(': ')[1::2])))
        total[div['id']].update(style)
total
# Out:
# {'PseudoValve039': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '85px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 868},
#  'PseudoValve040': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '75px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 872},
#  'PseudoValve041': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '295px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 876},
#  'PseudoValve042': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '280px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 880},
#  'PseudoValve043': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '435px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 884},
#  'PseudoValve044': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 888},
#  'PseudoValve045': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '585px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 892},
#  'PseudoValve046': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '570px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 896},
#  'PseudoValve047': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399AL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '685px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 900},
#  'PseudoValve048': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1240px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399AR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '670px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 904},
#  'PseudoValve049': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1175px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399BL',
#   'TEXT-DECORATION': 'none',
#   'TOP': '840px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 908},
#  'PseudoValve050': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '11px',
#   'LEFT': '1235px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399BR',
#   'TEXT-DECORATION': 'none',
#   'TOP': '825px',
#   'VISIBILITY': 'hidden',
#   'Value?DataBoundObj': 'ovlValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValvePseudo',
#   'WIDTH': '11px',
#   'id': 912},
#  'shape001': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '29px',
#   'LEFT': '5px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '0px',
#   'WIDTH': '103px',
#   'id': 4},
#  'shape015': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '36px',
#   'LEFT': '0px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TEXT?ACTIVITY': 'CH',
#   'TEXT?AREA': '제품운영1과',
#   'TEXT?PRODUCT': 'WAXY',
#   'TEXT?TANK': '-',
#   'TOP': '0px',
#   'WIDTH': '1910px',
#   'id': 16},
#  'shape023': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53104',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31',
#   'TOP': '115px',
#   'WIDTH': '100px',
#   'id': 67},
#  'shape024': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53105',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-96S',
#   'TOP': '220px',
#   'WIDTH': '100px',
#   'id': 102},
#  'shape025': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53106',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-20',
#   'TOP': '325px',
#   'WIDTH': '100px',
#   'id': 137},
#  'shape027': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-2400',
#   'TEXT-DECORATION': 'none',
#   'TOP': '70px',
#   'WIDTH': '95px',
#   'id': 25},
#  'shape028': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53107',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-116',
#   'TOP': '430px',
#   'WIDTH': '100px',
#   'id': 172},
#  'shape029': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53109',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-480',
#   'TOP': '540px',
#   'WIDTH': '100px',
#   'id': 207},
#  'shape030': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31S',
#   'TOP': '650px',
#   'WIDTH': '100px',
#   'id': 242},
#  'shape031': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'W-31S',
#   'TOP': '765px',
#   'WIDTH': '100px',
#   'id': 277},
#  'shape032': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '25px',
#   'POSITION': 'absolute',
#   'Parameter?Material': 'Matlcode',
#   'Parameter?TaskID': 'TaskID',
#   'Point?TankName': 'TK5397',
#   'TEXT-DECORATION': 'none',
#   'TEXT?MATERIAL': 'Mix-W',
#   'TOP': '865px',
#   'WIDTH': '100px',
#   'id': 312},
#  'shape033': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-2600',
#   'TEXT-DECORATION': 'none',
#   'TOP': '415px',
#   'WIDTH': '95px',
#   'id': 350},
#  'shape035': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'LEFT': '1810px',
#   'POSITION': 'absolute',
#   'T?T': 'U-20200',
#   'TEXT-DECORATION': 'none',
#   'TOP': '820px',
#   'WIDTH': '95px',
#   'id': 692},
#  'shape050': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53104',
#   'TEXT-DECORATION': 'none',
#   'TOP': '40px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 42},
#  'shape050_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 44},
#  'shape050_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 57},
#  'shape051': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53105',
#   'TEXT-DECORATION': 'none',
#   'TOP': '145px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 77},
#  'shape051_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 79},
#  'shape051_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 92},
#  'shape052': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53106',
#   'TEXT-DECORATION': 'none',
#   'TOP': '250px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 112},
#  'shape052_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 114},
#  'shape052_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 127},
#  'shape053': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53107',
#   'TEXT-DECORATION': 'none',
#   'TOP': '355px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 147},
#  'shape053_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 149},
#  'shape053_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 162},
#  'shape054': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53109',
#   'TEXT-DECORATION': 'none',
#   'TOP': '465px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 182},
#  'shape054_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 184},
#  'shape054_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 197},
#  'shape055': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53110',
#   'TEXT-DECORATION': 'none',
#   'TOP': '575px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 217},
#  'shape055_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 219},
#  'shape055_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 232},
#  'shape056': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK53111',
#   'TEXT-DECORATION': 'none',
#   'TOP': '690px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 252},
#  'shape056_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 254},
#  'shape056_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 267},
#  'shape057': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '80px',
#   'LEFT': '10px',
#   'POSITION': 'absolute',
#   'Point?element': 'TK5397',
#   'TEXT-DECORATION': 'none',
#   'TOP': '790px',
#   'Value?DataBoundObj': 'shaTank',
#   'Value?DefElemType': '1',
#   'Value?ShapeID': 'TankNozzle',
#   'WIDTH': '125px',
#   'id': 287},
#  'shape057_shaTank': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink) url(#HSCScriptDataBehavior) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '77.5%',
#   'LEFT': '5.38%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '15%',
#   'WIDTH': '90.76%',
#   'id': 289},
#  'shape057_shaTankService': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HSCShapeLinkBehavior#shapelinkanimator) url(#HDXFaceplateBehavior) url(#HDXVectorFactory#shapelink) url(#BindingBehavior)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '16.25%',
#   'LEFT': '23.07%',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '47.5%',
#   'WIDTH': '9.23%',
#   'id': 302},
#  'shape104': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_218',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_002',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'id': 322},
#  'shape108': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_220',
#   'TEXT-DECORATION': 'none',
#   'TOP': '180px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_017',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'id': 324},
#  'shape109': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_021',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'id': 326},
#  'shape110': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_232',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_054_026',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'id': 328},
#  'shape111': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '130px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_202',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_053_027',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '75px',
#   'id': 330},
#  'shape112': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'id': 332},
#  'shape115': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_059_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'id': 334},
#  'shape116': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '125px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '730px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_013',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '80px',
#   'id': 797},
#  'shape223': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_218',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '435px',
#   'id': 389},
#  'shape226': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1655px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_7280',
#   'TEXT-DECORATION': 'none',
#   'TOP': '110px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_013_014',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '30px',
#   'id': 760},
#  'shape232': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_220',
#   'TEXT-DECORATION': 'none',
#   'TOP': '180px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '210px',
#   'id': 391},
#  'shape240': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '255px',
#   'id': 393},
#  'shape250': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_232',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '145px',
#   'id': 399},
#  'shape254': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_202',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '275px',
#   'id': 401},
#  'shape255': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '590px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_104',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '35px',
#   'id': 403},
#  'shape262': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '275px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 789},
#  'shape266': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 409},
#  'shape269': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_059_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '170px',
#   'id': 411},
#  'shape271': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '275px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_062_004~MAV_OS1_024_031',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '120px',
#   'id': 795},
#  'shape272': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102B',
#   'TEXT-DECORATION': 'none',
#   'TOP': '280px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'id': 336},
#  'shape273': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53102A',
#   'TEXT-DECORATION': 'none',
#   'TOP': '75px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'id': 33},
#  'shape274': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_122',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 413},
#  'shape275': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '520px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '505px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_065',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '70px',
#   'id': 1179},
#  'shape276': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '785px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_117',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 421},
#  'shape277': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '395px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_417',
#   'TEXT-DECORATION': 'none',
#   'TOP': '815px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_140',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 429},
#  'shape278': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '1193px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104A',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'id': 435},
#  'shape279': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P53104B',
#   'TEXT-DECORATION': 'none',
#   'TOP': '570px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'id': 443},
#  'shape281': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1150px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_271',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 451},
#  'shape282': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1150px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_272',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 457},
#  'shape283': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '970px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_109',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '100px',
#   'id': 463},
#  'shape284': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '1070px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_007',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '60px',
#   'id': 465},
#  'shape286': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_270',
#   'TEXT-DECORATION': 'none',
#   'TOP': '80px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 696},
#  'shape287': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1225px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_273',
#   'TEXT-DECORATION': 'none',
#   'TOP': '285px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 702},
#  'shape288': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1295px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_313',
#   'TEXT-DECORATION': 'none',
#   'TOP': '285px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_009',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 708},
#  'shape289': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1070px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '300px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_008',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '60px',
#   'id': 467},
#  'shape292': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '970px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '130px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_108',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '100px',
#   'id': 926},
#  'shape293': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '970px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '170px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_110',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '100px',
#   'id': 933},
#  'shape297': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '970px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_314',
#   'TEXT-DECORATION': 'none',
#   'TOP': '210px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_111',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '100px',
#   'id': 941},
#  'shape301': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1150px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2432',
#   'TEXT-DECORATION': 'none',
#   'TOP': '440px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 471},
#  'shape302': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1295px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_313',
#   'TEXT-DECORATION': 'none',
#   'TOP': '80px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_006',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 710},
#  'shape303': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1080px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2431',
#   'TEXT-DECORATION': 'none',
#   'TOP': '440px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 477},
#  'shape304': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1080px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2431',
#   'TEXT-DECORATION': 'none',
#   'TOP': '395px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '120px',
#   'id': 481},
#  'shape305': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1220px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2433',
#   'TEXT-DECORATION': 'none',
#   'TOP': '395px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '120px',
#   'id': 487},
#  'shape306': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1345px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_313',
#   'TEXT-DECORATION': 'none',
#   'TOP': '80px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_067',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 714},
#  'shape307': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1415px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_376',
#   'TEXT-DECORATION': 'none',
#   'TOP': '80px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_067',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '50px',
#   'id': 736},
#  'shape308': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399A',
#   'TEXT-DECORATION': 'none',
#   'TOP': '670px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'id': 605},
#  'shape309': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '1195px',
#   'POSITION': 'absolute',
#   'Point?element': '_P5399B',
#   'TEXT-DECORATION': 'none',
#   'TOP': '825px',
#   'Value?DataBoundObj': 'plyPump',
#   'Value?DefElemType': '4',
#   'Value?ShapeID': 'CPump',
#   'WIDTH': '35px',
#   'id': 613},
#  'shape310': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '465px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_360',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_021_122',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '585px',
#   'id': 344},
#  'shape311': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '15px',
#   'LEFT': '735px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_323',
#   'TEXT-DECORATION': 'none',
#   'TOP': '90px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_109',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '215px',
#   'id': 947},
#  'shape312': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1155px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_289',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'PSP5383L',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '45px',
#   'id': 621},
#  'shape313': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '1110px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_289',
#   'TEXT-DECORATION': 'none',
#   'TOP': '845px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_043',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '45px',
#   'id': 627},
#  'shape314': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
# ...
#   'TEXT-DECORATION': 'none',
#   'TOP': '215px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_117',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 989},
#  'shape674': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '805px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_326',
#   'TEXT-DECORATION': 'none',
#   'TOP': '170px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_141~MAV_OS1_018_115',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 991},
#  'shape675': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '115px',
#   'LEFT': '805px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_326',
#   'TEXT-DECORATION': 'none',
#   'TOP': '215px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_141~MAV_OS1_018_115',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 993},
#  'shape676': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '150px',
#   'LEFT': '840px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_327',
#   'TEXT-DECORATION': 'none',
#   'TOP': '210px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 995},
#  'shape677': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '50px',
#   'LEFT': '435px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_220',
#   'TEXT-DECORATION': 'none',
#   'TOP': '130px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 1001},
#  'shape678': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '130px',
#   'LEFT': '480px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_230',
#   'TEXT-DECORATION': 'none',
#   'TOP': '170px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 1005},
#  'shape679': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '195px',
#   'LEFT': '530px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_246',
#   'TEXT-DECORATION': 'none',
#   'TOP': '210px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV005~MAV004',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 1009},
#  'shape680': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '145px',
#   'LEFT': '590px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_312',
#   'TEXT-DECORATION': 'none',
#   'TOP': '360px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_130',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 1064},
#  'shape681': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '905px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_011',
#   'TEXT-DECORATION': 'none',
#   'TOP': '390px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'id': 1086},
#  'shape682': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '20px',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '405px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_011',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 1090},
#  'shape683': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '425px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172~MAV_OS1_018_100',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 1098},
#  'shape684': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '45px',
#   'LEFT': '835px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '455px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_018_013~MAV_OS1_018_011~MAV_OS1_018_100',
#   'Value?EndPoint2': 'MAV_OS1_022_064~MAV_OS1_018_172',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 1100},
#  'shape686': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '835px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_325',
#   'TEXT-DECORATION': 'none',
#   'TOP': '590px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_064',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '30px',
#   'id': 1104},
#  'shape689': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '865px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_013',
#   'TEXT-DECORATION': 'none',
#   'TOP': '420px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'id': 1106},
#  'shape690': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '780px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_100',
#   'TEXT-DECORATION': 'none',
#   'TOP': '450px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'id': 1110},
#  'shape691': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '780px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_018_172',
#   'TEXT-DECORATION': 'none',
#   'TOP': '495px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'id': 1114},
#  'shape692': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '105px',
#   'id': 1130},
#  'shape693': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '35px',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_491',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_068',
#   'Value?EndPoint2': 'MAV010',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 1132},
#  'shape694': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_022_065',
#   'TEXT-DECORATION': 'none',
#   'TOP': '690px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'id': 1146},
#  'shape695': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '885px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2430',
#   'TEXT-DECORATION': 'none',
#   'TOP': '695px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '45px',
#   'id': 1150},
#  'shape696': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '920px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAV_OS1_022_066',
#   'TEXT-DECORATION': 'none',
#   'TOP': '655px',
#   'Value?DataBoundObj': 'plyValve',
#   'Value?DefElemType': '5',
#   'Value?ShapeID': 'ValveMan',
#   'WIDTH': '30px',
#   'id': 1152},
#  'shape697': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '885px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_2430',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': '',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '40px',
#   'id': 1156},
#  'shape698': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '30px',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '630px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '10px',
#   'id': 1161},
#  'shape699': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '10px',
#   'LEFT': '760px',
#   'POSITION': 'absolute',
#   'Point?element': 'MAL_OS1_483',
#   'TEXT-DECORATION': 'none',
#   'TOP': '660px',
#   'Value?DataBoundObj': 'linPipe',
#   'Value?DefElemType': '3',
#   'Value?EndPoint1': 'MAV_OS1_022_069',
#   'Value?EndPoint2': '',
#   'Value?ShapeID': 'Line',
#   'WIDTH': '105px',
#   'id': 1163},
#  'shape792': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN2400_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '70px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'id': 346},
#  'shape793': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN2600_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '415px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'id': 354},
#  'shape794': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': '400',
#   'HEIGHT': '18px',
#   'LEFT': '1780px',
#   'POSITION': 'absolute',
#   'Point?element': 'UN20200_WAXY',
#   'TEXT-DECORATION': 'none',
#   'TOP': '820px',
#   'Value?DataBoundObj': 'plyBPArrow',
#   'Value?DefElemType': '2',
#   'Value?ShapeID': 'BP',
#   'WIDTH': '26px',
#   'id': 360},
#  'tfgOffDisplayEndPoints': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'LEFT': '175px',
#   'POSITION': 'absolute',
#   'Point?Element1': '',
#   'Point?Element10': '',
#   'Point?Element11': '',
#   'Point?Element12': '',
#   'Point?Element13': '',
#   'Point?Element14': '',
#   'Point?Element15': '',
#   'Point?Element16': '',
#   'Point?Element17': '',
#   'Point?Element18': '',
#   'Point?Element19': '',
#   'Point?Element2': '',
#   'Point?Element20': '',
#   'Point?Element21': '',
#   'Point?Element22': '',
#   'Point?Element23': '',
#   'Point?Element24': '',
#   'Point?Element25': '',
#   'Point?Element26': '',
#   'Point?Element27': '',
#   'Point?Element28': '',
#   'Point?Element29': '',
#   'Point?Element3': '',
#   'Point?Element30': '',
#   'Point?Element31': '',
#   'Point?Element32': '',
#   'Point?Element33': '',
#   'Point?Element34': '',
#   'Point?Element35': '',
#   'Point?Element36': '',
#   'Point?Element37': '',
#   'Point?Element38': '',
#   'Point?Element39': '',
#   'Point?Element4': '',
#   'Point?Element40': '',
#   'Point?Element5': '',
#   'Point?Element6': '',
#   'Point?Element7': '',
#   'Point?Element8': '',
#   'Point?Element9': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '19px',
#   'WIDTH': '92px',
#   'id': 13},
#  'tfgOperDataReInit': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'LEFT': '230px',
#   'POSITION': 'absolute',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'WIDTH': '92px',
#   'id': 11},
#  'tfgPlanningData': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '14px',
#   'LEFT': '138px',
#   'POSITION': 'absolute',
#   'Point?DestElement': '',
#   'Point?SrcElement': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'Value?IgnoreOnDataChange': '"True"',
#   'WIDTH': '92px',
#   'id': 8},
#  'tfgSelectTimeout': {'BEHAVIOR': 'url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)',
#   'FONT-FAMILY': 'Arial',
#   'FONT-SIZE': '0px',
#   'FONT-STYLE': 'normal',
#   'FONT-WEIGHT': 'normal',
#   'HEIGHT': '16px',
#   'LEFT': '77px',
#   'POSITION': 'absolute',
#   'Point?DestElement': '',
#   'Point?SrcElement': '',
#   'TEXT-DECORATION': 'none',
#   'TOP': '4px',
#   'Value?IgnoreOnDataChange': '"True"',
#   'WIDTH': '60px',
#   'id': 10}}

# %%
# check
for i,div in enumerate(divs):
    if 'hsc.shape.1' in div['class']:
        if len(div['parameters'].split(';')) == 5:
            print(i,div['id'], div['parameters'].split(';'))
# Out:
# 16 shape015 ['TEXT?ACTIVITY:CH', 'TEXT?AREA:제품운영1과', 'TEXT?TANK:-', 'TEXT?PRODUCT:WAXY', '']
# 29 shape414 ['Point?element:MAV_OS1_054_002', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 33 shape273 ['Point?element:_P53102A', 'Value?DefElemType:4', 'Value?ShapeID:CPump', 'Value?DataBoundObj:plyPump', '']
# 42 shape050 ['Point?element:TK53104', 'Value?DefElemType:1', 'Value?ShapeID:TankNozzle', 'Value?DataBoundObj:shaTank', '']
# 67 shape023 ['Point?TankName:TK53104', 'Parameter?TaskID:TaskID', 'Parameter?Material:Matlcode', 'TEXT?MATERIAL:W-31', '']
# 77 shape051 ['Point?element:TK53105', 'Value?DefElemType:1', 'Value?ShapeID:TankNozzle', 'Value?DataBoundObj:shaTank', '']
# 102 shape024 ['Point?TankName:TK53105', 'Parameter?TaskID:TaskID', 'Parameter?Material:Matlcode', 'TEXT?MATERIAL:W-96S', '']
# 112 shape052 ['Point?element:TK53106', 'Value?DefElemType:1', 'Value?ShapeID:TankNozzle', 'Value?DataBoundObj:shaTank', '']
# 137 shape025 ['Point?TankName:TK53106', 'Parameter?TaskID:TaskID', 'Parameter?Material:Matlcode', 'TEXT?MATERIAL:W-20', '']
# 147 shape053 ['Point?element:TK53107', 'Value?DefElemType:1', 'Value?ShapeID:TankNozzle', 'Value?DataBoundObj:shaTank', '']
# 172 shape028 ['Point?TankName:TK53107', 'Parameter?TaskID:TaskID', 'Parameter?Material:Matlcode', 'TEXT?MATERIAL:W-116', '']
# 182 shape054 ['Point?element:TK53109', 'Value?DefElemType:1', 'Value?ShapeID:TankNozzle', 'Value?DataBoundObj:shaTank', '']
# 207 shape029 ['Point?TankName:TK53109', 'Parameter?TaskID:TaskID', 'Parameter?Material:Matlcode', 'TEXT?MATERIAL:W-480', '']
# 217 shape055 ['Point?element:TK53110', 'Value?DefElemType:1', 'Value?ShapeID:TankNozzle', 'Value?DataBoundObj:shaTank', '']
# 242 shape030 ['Point?TankName:TK53110', 'Parameter?TaskID:TaskID', 'Parameter?Material:Matlcode', 'TEXT?MATERIAL:W-31S', '']
# 252 shape056 ['Point?element:TK53111', 'Value?DefElemType:1', 'Value?ShapeID:TankNozzle', 'Value?DataBoundObj:shaTank', '']
# 277 shape031 ['Point?TankName:TK53110', 'Parameter?TaskID:TaskID', 'Parameter?Material:Matlcode', 'TEXT?MATERIAL:W-31S', '']
# 287 shape057 ['Point?element:TK5397', 'Value?DefElemType:1', 'Value?ShapeID:TankNozzle', 'Value?DataBoundObj:shaTank', '']
# 312 shape032 ['Point?TankName:TK5397', 'Parameter?TaskID:TaskID', 'Parameter?Material:Matlcode', 'TEXT?MATERIAL:Mix-W', '']
# 336 shape272 ['Point?element:_P53102B', 'Value?DefElemType:4', 'Value?ShapeID:CPump', 'Value?DataBoundObj:plyPump', '']
# 346 shape792 ['Point?element:UN2400_WAXY', 'Value?DefElemType:2', 'Value?ShapeID:BP', 'Value?DataBoundObj:plyBPArrow', '']
# 354 shape793 ['Point?element:UN2600_WAXY', 'Value?DefElemType:2', 'Value?ShapeID:BP', 'Value?DataBoundObj:plyBPArrow', '']
# 360 shape794 ['Point?element:UN20200_WAXY', 'Value?DefElemType:2', 'Value?ShapeID:BP', 'Value?DataBoundObj:plyBPArrow', '']
# 364 shape415 ['Point?element:MAV_OS1_054_017', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 369 shape416 ['Point?element:MAV_OS1_054_021', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 373 shape417 ['Point?element:MAV_OS1_054_026', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 377 shape418 ['Point?element:MAV_OS1_053_027', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 381 shape421 ['Point?element:MAV_OS1_062_004', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 385 shape423 ['Point?element:MAV_OS1_059_006', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 395 shape444 ['Point?element:MAV_OS1_017_024', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 405 shape447 ['Point?element:MAV_OS1_018_104', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 415 shape457 ['Point?element:MAV_OS1_021_122', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 423 shape458 ['Point?element:MAV_OS1_021_117', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 431 shape459 ['Point?element:MAV_OS1_021_140', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 435 shape278 ['Point?element:_P53104A', 'Value?DefElemType:4', 'Value?ShapeID:CPump', 'Value?DataBoundObj:plyPump', '']
# 443 shape279 ['Point?element:_P53104B', 'Value?DefElemType:4', 'Value?ShapeID:CPump', 'Value?DataBoundObj:plyPump', '']
# 453 shape462 ['Point?element:MAV_OS1_018_007', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 459 shape463 ['Point?element:MAV_OS1_018_008', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 473 shape506 ['Point?element:MAV_OS1_022_062', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 483 shape507 ['Point?element:OMAVALVE', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 495 shape508 ['Point?element:MAV_OS1_022_073', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 503 shape509 ['Point?element:MAV_OS1_022_074', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 513 shape510 ['Point?element:MAV_OS1_022_061', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 519 shape511 ['Point?element:MAV_OS1_022_072', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 527 shape512 ['Point?element:MAV_OS1_022_033', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 535 shape513 ['Point?element:MAV_OS1_022_057', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 543 shape514 ['Point?element:MAV_OS1_022_060', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 553 shape515 ['Point?element:OMAVALVE', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 567 shape516 ['Point?element:MAV_OS1_022_059', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 581 shape518 ['Point?element:MAV_OS1_019_004', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 591 shape519 ['Point?element:MAV_OS1_014_003', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 605 shape308 ['Point?element:_P5399A', 'Value?DefElemType:4', 'Value?ShapeID:CPump', 'Value?DataBoundObj:plyPump', '']
# 613 shape309 ['Point?element:_P5399B', 'Value?DefElemType:4', 'Value?ShapeID:CPump', 'Value?DataBoundObj:plyPump', '']
# 623 shape468 ['Point?element:MAV_OS1_018_043', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 631 shape469 ['Point?element:OMAVALVE', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 649 shape470 ['Point?element:MAV_OS1_018_042', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 659 shape471 ['Point?element:OMAVALVE', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 675 shape472 ['Point?element:MAV_OS1_018_038', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 680 shape473 ['Point?element:MAV_OS1_018_136', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 698 shape467 ['Point?element:MAV_OS1_018_006', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 704 shape476 ['Point?element:MAV_OS1_018_009', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 716 shape477 ['Point?element:MAV_OS1_018_067', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 720 shape527 ['Point?element:MAV_OS1_018_106', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 728 shape529 ['Point?element:MAV_OS1_018_107', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 744 shape479 ['Point?element:MAV_OS1_014_004', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 748 shape480 ['Point?element:MAV_OS1_013_012', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 754 shape481 ['Point?element:MAV_OS1_013_013', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 762 shape433 ['Point?element:MAV_OS1_013_014', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 768 shape442 ['Point?element:MAV_OS1_013_015', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 781 shape660 ['Point?element:MAV_OS1_021_047', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 791 shape455 ['Point?element:MAV_OS1_024_031', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 799 shape422 ['Point?element:MAV_OS1_062_013', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 835 shape640 ['Point?element:MAV_OS1_022_068', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 839 shape641 ['Point?element:MAV_OS1_022_069', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 843 shape642 ['Point?element:MAV_OS1_022_067', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 859 shape649 ['Point?element:MAV_OS1_022_064', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 868 PseudoValve039 ['Point?element:_P53102AL', 'Value?DefElemType:5', 'Value?ShapeID:ValvePseudo', 'Value?DataBoundObj:ovlValve', '']
# 872 PseudoValve040 ['Point?element:_P53102AR', 'Value?DefElemType:5', 'Value?ShapeID:ValvePseudo', 'Value?DataBoundObj:ovlValve', '']
# 876 PseudoValve041 ['Point?element:_P53102BL', 'Value?DefElemType:5', 'Value?ShapeID:ValvePseudo', 'Value?DataBoundObj:ovlValve', '']
# 880 PseudoValve042 ['Point?element:_P53102BR', 'Value?DefElemType:5', 'Value?ShapeID:ValvePseudo', 'Value?DataBoundObj:ovlValve', '']
# 884 PseudoValve043 ['Point?element:_P53104AL', 'Value?DefElemType:5', 'Value?ShapeID:ValvePseudo', 'Value?DataBoundObj:ovlValve', '']
# 888 PseudoValve044 ['Point?element:_P53104AR', 'Value?DefElemType:5', 'Value?ShapeID:ValvePseudo', 'Value?DataBoundObj:ovlValve', '']
# 892 PseudoValve045 ['Point?element:_P53104BL', 'Value?DefElemType:5', 'Value?ShapeID:ValvePseudo', 'Value?DataBoundObj:ovlValve', '']
# 896 PseudoValve046 ['Point?element:_P53104BR', 'Value?DefElemType:5', 'Value?ShapeID:ValvePseudo', 'Value?DataBoundObj:ovlValve', '']
# 900 PseudoValve047 ['Point?element:_P5399AL', 'Value?DefElemType:5', 'Value?ShapeID:ValvePseudo', 'Value?DataBoundObj:ovlValve', '']
# 904 PseudoValve048 ['Point?element:_P5399AR', 'Value?DefElemType:5', 'Value?ShapeID:ValvePseudo', 'Value?DataBoundObj:ovlValve', '']
# 908 PseudoValve049 ['Point?element:_P5399BL', 'Value?DefElemType:5', 'Value?ShapeID:ValvePseudo', 'Value?DataBoundObj:ovlValve', '']
# 912 PseudoValve050 ['Point?element:_P5399BR', 'Value?DefElemType:5', 'Value?ShapeID:ValvePseudo', 'Value?DataBoundObj:ovlValve', '']
# 918 shape650 ['Point?element:MAV_OS1_022_063', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 922 shape438 ['Point?element:MAV_OS1_018_109', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 929 shape439 ['Point?element:MAV_OS1_018_108', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 935 shape461 ['Point?element:MAV_OS1_018_110', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 943 shape464 ['Point?element:MAV_OS1_018_111', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 957 shape465 ['Point?element:MAV_OS1_018_072', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 969 shape475 ['Point?element:MAV_OS1_018_071', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 973 shape483 ['Point?element:MAV_OS1_018_074', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 977 shape484 ['Point?element:MAV_OS1_018_075', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1018 shape485 ['Point?element:MAV_OS1_018_114', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1026 shape486 ['Point?element:MAV_OS1_018_115', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1034 shape487 ['Point?element:MAV_OS1_018_117', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1042 shape488 ['Point?element:MAV_OS1_018_116', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1068 shape490 ['Point?element:MAV_OS1_018_130', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1076 shape491 ['Point?element:MAV_OS1_018_141', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1082 shape492 ['Point?element:MAV_OS1_018_134', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1086 shape681 ['Point?element:MAV_OS1_018_011', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1106 shape689 ['Point?element:MAV_OS1_018_013', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1110 shape690 ['Point?element:MAV_OS1_018_100', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1114 shape691 ['Point?element:MAV_OS1_018_172', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1140 shape493 ['Point?element:MAV_OS1_018_073', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1146 shape694 ['Point?element:MAV_OS1_022_065', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1152 shape696 ['Point?element:MAV_OS1_022_066', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1167 shape517 ['Point?element:MAV_OS1_022_162', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']
# 1175 shape494 ['Point?element:MAV_OS1_018_065', 'Value?DefElemType:5', 'Value?ShapeID:ValveMan', 'Value?DataBoundObj:plyValve', '']

# %%
# check
for i,div in enumerate(divs):
    if 'hsc.shape.1' in div['class']:
        if len(div['parameters'].split(';')) == 2:
            print(i,div['id'], div['parameters'].split(';'))
# Out:
# 25 shape027 ['T?T:U-2400', '']
# 350 shape033 ['T?T:U-2600', '']
# 692 shape035 ['T?T:U-20200', '']

# %%
for i,div in enumerate(divs):
    if 'hsc.shape.1' in div['class']:
        print(i,div['id'], div['style'].split(';')[9:])
# Out:
# 0 shape385 [' TOP: 80px', ' LEFT: 1685px']
# 2 shape554 [' TOP: 130px', ' LEFT: 1070px']
# 4 shape001 [' TOP: 0px', ' LEFT: 5px']
# 8 tfgPlanningData [' TOP: 4px', ' LEFT: 138px']
# 10 tfgSelectTimeout [' TOP: 4px', ' LEFT: 77px']
# 11 tfgOperDataReInit [' TOP: 4px', ' LEFT: 230px']
# 13 tfgOffDisplayEndPoints [' TOP: 19px', ' LEFT: 175px']
# 16 shape015 [' TOP: 0px', ' LEFT: 0px']
# 25 shape027 [' TOP: 70px', ' LEFT: 1810px']
# 29 shape414 [' TOP: 85px', ' LEFT: 200px']
# 33 shape273 [' TOP: 75px', ' LEFT: 1195px']
# 42 shape050 [' TOP: 40px', ' LEFT: 10px']
# 44 shape050_shaTank [' TOP: 15%', ' LEFT: 5.38%']
# 57 shape050_shaTankService [' TOP: 47.5%', ' LEFT: 23.07%']
# 67 shape023 [' TOP: 115px', ' LEFT: 25px']
# 77 shape051 [' TOP: 145px', ' LEFT: 10px']
# 79 shape051_shaTank [' TOP: 15%', ' LEFT: 5.38%']
# 92 shape051_shaTankService [' TOP: 47.5%', ' LEFT: 23.07%']
# 102 shape024 [' TOP: 220px', ' LEFT: 25px']
# 112 shape052 [' TOP: 250px', ' LEFT: 10px']
# 114 shape052_shaTank [' TOP: 15%', ' LEFT: 5.38%']
# 127 shape052_shaTankService [' TOP: 47.5%', ' LEFT: 23.07%']
# 137 shape025 [' TOP: 325px', ' LEFT: 25px']
# 147 shape053 [' TOP: 355px', ' LEFT: 10px']
# 149 shape053_shaTank [' TOP: 15%', ' LEFT: 5.38%']
# 162 shape053_shaTankService [' TOP: 47.5%', ' LEFT: 23.07%']
# 172 shape028 [' TOP: 430px', ' LEFT: 25px']
# 182 shape054 [' TOP: 465px', ' LEFT: 10px']
# 184 shape054_shaTank [' TOP: 15%', ' LEFT: 5.38%']
# 197 shape054_shaTankService [' TOP: 47.5%', ' LEFT: 23.07%']
# 207 shape029 [' TOP: 540px', ' LEFT: 25px']
# 217 shape055 [' TOP: 575px', ' LEFT: 10px']
# 219 shape055_shaTank [' TOP: 15%', ' LEFT: 5.38%']
# 232 shape055_shaTankService [' TOP: 47.5%', ' LEFT: 23.07%']
# 242 shape030 [' TOP: 650px', ' LEFT: 25px']
# 252 shape056 [' TOP: 690px', ' LEFT: 10px']
# 254 shape056_shaTank [' TOP: 15%', ' LEFT: 5.38%']
# 267 shape056_shaTankService [' TOP: 47.5%', ' LEFT: 23.07%']
# 277 shape031 [' TOP: 765px', ' LEFT: 25px']
# 287 shape057 [' TOP: 790px', ' LEFT: 10px']
# 289 shape057_shaTank [' TOP: 15%', ' LEFT: 5.38%']
# 302 shape057_shaTankService [' TOP: 47.5%', ' LEFT: 23.07%']
# 312 shape032 [' TOP: 865px', ' LEFT: 25px']
# 322 shape104 [' TOP: 90px', ' LEFT: 130px']
# 324 shape108 [' TOP: 180px', ' LEFT: 130px']
# 326 shape109 [' TOP: 300px', ' LEFT: 130px']
# 328 shape110 [' TOP: 405px', ' LEFT: 130px']
# 330 shape111 [' TOP: 505px', ' LEFT: 130px']
# 332 shape112 [' TOP: 630px', ' LEFT: 125px']
# 334 shape115 [' TOP: 845px', ' LEFT: 125px']
# 336 shape272 [' TOP: 280px', ' LEFT: 1195px']
# 344 shape310 [' TOP: 845px', ' LEFT: 465px']
# 346 shape792 [' TOP: 70px', ' LEFT: 1780px']
# 350 shape033 [' TOP: 415px', ' LEFT: 1810px']
# 354 shape793 [' TOP: 415px', ' LEFT: 1780px']
# 358 shape392 [' TOP: 830px', ' LEFT: 1510px']
# 360 shape794 [' TOP: 820px', ' LEFT: 1780px']
# 364 shape415 [' TOP: 175px', ' LEFT: 200px']
# 369 shape416 [' TOP: 295px', ' LEFT: 200px']
# 373 shape417 [' TOP: 400px', ' LEFT: 200px']
# 377 shape418 [' TOP: 500px', ' LEFT: 200px']
# 381 shape421 [' TOP: 625px', ' LEFT: 200px']
# 385 shape423 [' TOP: 840px', ' LEFT: 200px']
# 389 shape223 [' TOP: 90px', ' LEFT: 225px']
# 391 shape232 [' TOP: 180px', ' LEFT: 225px']
# 393 shape240 [' TOP: 300px', ' LEFT: 225px']
# 395 shape444 [' TOP: 400px', ' LEFT: 365px']
# 399 shape250 [' TOP: 405px', ' LEFT: 225px']
# 401 shape254 [' TOP: 505px', ' LEFT: 225px']
# 403 shape255 [' TOP: 505px', ' LEFT: 590px']
# 405 shape447 [' TOP: 500px', ' LEFT: 620px']
# 409 shape266 [' TOP: 630px', ' LEFT: 225px']
# 411 shape269 [' TOP: 845px', ' LEFT: 225px']
# 413 shape274 [' TOP: 845px', ' LEFT: 395px']
# 415 shape457 [' TOP: 840px', ' LEFT: 440px']
# 419 shape551 [' TOP: 815px', ' LEFT: 395px']
# 421 shape276 [' TOP: 785px', ' LEFT: 395px']
# 423 shape458 [' TOP: 780px', ' LEFT: 440px']
# 427 shape552 [' TOP: 785px', ' LEFT: 395px']
# 429 shape277 [' TOP: 815px', ' LEFT: 395px']
# 431 shape459 [' TOP: 810px', ' LEFT: 440px']
# 435 shape278 [' TOP: 420px', ' LEFT: 1193px']
# 443 shape279 [' TOP: 570px', ' LEFT: 1195px']
# 451 shape281 [' TOP: 90px', ' LEFT: 1150px']
# 453 shape462 [' TOP: 85px', ' LEFT: 1125px']
# 457 shape282 [' TOP: 300px', ' LEFT: 1150px']
# 459 shape463 [' TOP: 295px', ' LEFT: 1125px']
# 463 shape283 [' TOP: 90px', ' LEFT: 970px']
# 465 shape284 [' TOP: 90px', ' LEFT: 1070px']
# 467 shape289 [' TOP: 300px', ' LEFT: 1070px']
# 469 shape553 [' TOP: 90px', ' LEFT: 1070px']
# 471 shape301 [' TOP: 440px', ' LEFT: 1150px']
# 473 shape506 [' TOP: 435px', ' LEFT: 1125px']
# 477 shape303 [' TOP: 440px', ' LEFT: 1080px']
# 479 shape563 [' TOP: 395px', ' LEFT: 1080px']
# 481 shape304 [' TOP: 395px', ' LEFT: 1080px']
# 483 shape507 [' TOP: 390px', ' LEFT: 1195px']
# 487 shape305 [' TOP: 395px', ' LEFT: 1220px']
# 489 shape564 [' TOP: 395px', ' LEFT: 1340px']
# 491 shape314 [' TOP: 425px', ' LEFT: 1220px']
# 493 shape315 [' TOP: 425px', ' LEFT: 1340px']
# 495 shape508 [' TOP: 420px', ' LEFT: 1435px']
# 499 shape329 [' TOP: 425px', ' LEFT: 1390px']
# 501 shape565 [' TOP: 425px', ' LEFT: 1390px']
# 503 shape509 [' TOP: 450px', ' LEFT: 1435px']
# 507 shape330 [' TOP: 455px', ' LEFT: 1390px']
# 509 shape334 [' TOP: 440px', ' LEFT: 990px']
# 511 shape566 [' TOP: 440px', ' LEFT: 990px']
# 513 shape510 [' TOP: 555px', ' LEFT: 975px']
# 517 shape371 [' TOP: 475px', ' LEFT: 960px']
# 519 shape511 [' TOP: 470px', ' LEFT: 935px']
# 523 shape568 [' TOP: 475px', ' LEFT: 990px']
# 525 shape393 [' TOP: 500px', ' LEFT: 960px']
# 527 shape512 [' TOP: 495px', ' LEFT: 935px']
# 531 shape569 [' TOP: 500px', ' LEFT: 990px']
# 533 shape394 [' TOP: 525px', ' LEFT: 960px']
# 535 shape513 [' TOP: 520px', ' LEFT: 935px']
# 539 shape570 [' TOP: 525px', ' LEFT: 990px']
# 541 shape395 [' TOP: 590px', ' LEFT: 1150px']
# 543 shape514 [' TOP: 585px', ' LEFT: 1125px']
# 547 shape396 [' TOP: 590px', ' LEFT: 1080px']
# 549 shape571 [' TOP: 545px', ' LEFT: 1080px']
# 551 shape397 [' TOP: 545px', ' LEFT: 1080px']
# 553 shape515 [' TOP: 540px', ' LEFT: 1195px']
# 557 shape398 [' TOP: 545px', ' LEFT: 1220px']
# 559 shape577 [' TOP: 545px', ' LEFT: 1340px']
# 561 shape399 [' TOP: 590px', ' LEFT: 990px']
# 563 shape400 [' TOP: 575px', ' LEFT: 1225px']
# 565 shape401 [' TOP: 575px', ' LEFT: 1340px']
# 567 shape516 [' TOP: 570px', ' LEFT: 1435px']
# 571 shape404 [' TOP: 425px', ' LEFT: 1460px']
# 573 shape608 [' TOP: 425px', ' LEFT: 1510px']
# 575 shape405 [' TOP: 575px', ' LEFT: 1460px']
# 577 shape406 [' TOP: 425px', ' LEFT: 1510px']
# 579 shape609 [' TOP: 425px', ' LEFT: 1560px']
# 581 shape518 [' TOP: 450px', ' LEFT: 1605px']
# 585 shape407 [' TOP: 455px', ' LEFT: 1560px']
# 587 shape408 [' TOP: 425px', ' LEFT: 1560px']
# 589 shape610 [' TOP: 425px', ' LEFT: 1660px']
# 591 shape519 [' TOP: 450px', ' LEFT: 1705px']
# 595 shape409 [' TOP: 455px', ' LEFT: 1660px']
# 597 shape410 [' TOP: 425px', ' LEFT: 1660px']
# 599 shape523 [' TOP: 405px', ' LEFT: 390px']
# 601 shape627 [' TOP: 630px', ' LEFT: 395px']
# 603 shape651 [' TOP: 500px', ' LEFT: 835px']
# 605 shape308 [' TOP: 670px', ' LEFT: 1195px']
# 613 shape309 [' TOP: 825px', ' LEFT: 1195px']
# 621 shape312 [' TOP: 845px', ' LEFT: 1155px']
# 623 shape468 [' TOP: 840px', ' LEFT: 1085px']
# 627 shape313 [' TOP: 845px', ' LEFT: 1110px']
# 629 shape316 [' TOP: 845px', ' LEFT: 1050px']
# 631 shape469 [' TOP: 795px', ' LEFT: 1195px']
# 635 shape572 [' TOP: 800px', ' LEFT: 1155px']
# 637 shape318 [' TOP: 800px', ' LEFT: 1155px']
# 639 shape319 [' TOP: 800px', ' LEFT: 1220px']
# 641 shape573 [' TOP: 800px', ' LEFT: 1265px']
# 643 shape320 [' TOP: 830px', ' LEFT: 1225px']
# 645 shape321 [' TOP: 830px', ' LEFT: 1265px']
# 647 shape574 [' TOP: 690px', ' LEFT: 1050px']
# 649 shape470 [' TOP: 685px', ' LEFT: 1085px']
# 653 shape322 [' TOP: 690px', ' LEFT: 1050px']
# 655 shape323 [' TOP: 690px', ' LEFT: 1155px']
# 657 shape324 [' TOP: 690px', ' LEFT: 1110px']
# 659 shape471 [' TOP: 640px', ' LEFT: 1195px']
# 663 shape575 [' TOP: 645px', ' LEFT: 1155px']
# 665 shape325 [' TOP: 645px', ' LEFT: 1155px']
# 667 shape326 [' TOP: 645px', ' LEFT: 1220px']
# 669 shape576 [' TOP: 645px', ' LEFT: 1265px']
# 671 shape327 [' TOP: 675px', ' LEFT: 1225px']
# 673 shape328 [' TOP: 675px', ' LEFT: 1270px']
# 675 shape472 [' TOP: 670px', ' LEFT: 1375px']
# 680 shape473 [' TOP: 825px', ' LEFT: 1375px']
# 685 shape390 [' TOP: 675px', ' LEFT: 1400px']
# 687 shape391 [' TOP: 830px', ' LEFT: 1400px']
# 689 shape607 [' TOP: 675px', ' LEFT: 1510px']
# 692 shape035 [' TOP: 820px', ' LEFT: 1810px']
# 696 shape286 [' TOP: 80px', ' LEFT: 1225px']
# 698 shape467 [' TOP: 75px', ' LEFT: 1270px']
# 702 shape287 [' TOP: 285px', ' LEFT: 1225px']
# 704 shape476 [' TOP: 280px', ' LEFT: 1270px']
# 708 shape288 [' TOP: 285px', ' LEFT: 1295px']
# 710 shape302 [' TOP: 80px', ' LEFT: 1295px']
# 712 shape558 [' TOP: 80px', ' LEFT: 1345px']
# 714 shape306 [' TOP: 80px', ' LEFT: 1345px']
# 716 shape477 [' TOP: 75px', ' LEFT: 1390px']
# 720 shape527 [' TOP: 135px', ' LEFT: 1390px']
# 724 shape331 [' TOP: 140px', ' LEFT: 1345px']
# 726 shape559 [' TOP: 140px', ' LEFT: 1345px']
# 728 shape529 [' TOP: 215px', ' LEFT: 1390px']
# 732 shape332 [' TOP: 220px', ' LEFT: 1345px']
# 734 shape578 [' TOP: 220px', ' LEFT: 1345px']
# 736 shape307 [' TOP: 80px', ' LEFT: 1415px']
# 738 shape317 [' TOP: 80px', ' LEFT: 1465px']
# 740 shape579 [' TOP: 80px', ' LEFT: 1465px']
# 742 shape333 [' TOP: 110px', ' LEFT: 1465px']
# 744 shape479 [' TOP: 105px', ' LEFT: 1485px']
# 748 shape480 [' TOP: 75px', ' LEFT: 1580px']
# 752 shape335 [' TOP: 80px', ' LEFT: 1605px']
# 754 shape481 [' TOP: 75px', ' LEFT: 1630px']
# 758 shape534 [' TOP: 80px', ' LEFT: 1685px']
# 760 shape226 [' TOP: 110px', ' LEFT: 1655px']
# 762 shape433 [' TOP: 105px', ' LEFT: 1630px']
# 766 shape536 [' TOP: 80px', ' LEFT: 1715px']
# 768 shape442 [' TOP: 115px', ' LEFT: 1700px']
# 774 shape336 [' TOP: 80px', ' LEFT: 1655px']
# 776 shape337 [' TOP: 80px', ' LEFT: 1715px']
# 779 shape659 [' TOP: 660px', ' LEFT: 395px']
# 781 shape660 [' TOP: 655px', ' LEFT: 440px']
# 785 shape661 [' TOP: 630px', ' LEFT: 395px']
# 787 shape580 [' TOP: 630px', ' LEFT: 275px']
# 789 shape262 [' TOP: 660px', ' LEFT: 275px']
# 791 shape455 [' TOP: 655px', ' LEFT: 320px']
# 795 shape271 [' TOP: 630px', ' LEFT: 275px']
# 797 shape116 [' TOP: 730px', ' LEFT: 125px']
# 799 shape422 [' TOP: 725px', ' LEFT: 200px']
# 803 shape341 [' TOP: 730px', ' LEFT: 225px']
# 833 shape584 [' TOP: 570px', ' LEFT: 990px']
# 835 shape640 [' TOP: 690px', ' LEFT: 860px']
# 839 shape641 [' TOP: 655px', ' LEFT: 860px']
# 843 shape642 [' TOP: 620px', ' LEFT: 860px']
# 847 shape643 [' TOP: 695px', ' LEFT: 945px']
# 849 shape644 [' TOP: 660px', ' LEFT: 945px']
# 851 shape645 [' TOP: 625px', ' LEFT: 885px']
# 853 shape646 [' TOP: 590px', ' LEFT: 990px']
# 855 shape647 [' TOP: 625px', ' LEFT: 990px']
# 857 shape648 [' TOP: 660px', ' LEFT: 990px']
# 859 shape649 [' TOP: 585px', ' LEFT: 860px']
# 863 shape668 [' TOP: 590px', ' LEFT: 945px']
# 868 PseudoValve039 [' BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', ' TOP: 85px', ' LEFT: 1175px']
# 872 PseudoValve040 [' BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', ' TOP: 75px', ' LEFT: 1240px']
# 876 PseudoValve041 [' BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', ' TOP: 295px', ' LEFT: 1175px']
# 880 PseudoValve042 [' BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', ' TOP: 280px', ' LEFT: 1240px']
# 884 PseudoValve043 [' BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', ' TOP: 435px', ' LEFT: 1175px']
# 888 PseudoValve044 [' BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', ' TOP: 420px', ' LEFT: 1240px']
# 892 PseudoValve045 [' BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', ' TOP: 585px', ' LEFT: 1175px']
# 896 PseudoValve046 [' BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', ' TOP: 570px', ' LEFT: 1240px']
# 900 PseudoValve047 [' BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', ' TOP: 685px', ' LEFT: 1175px']
# 904 PseudoValve048 [' BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', ' TOP: 670px', ' LEFT: 1240px']
# 908 PseudoValve049 [' BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', ' TOP: 840px', ' LEFT: 1175px']
# 912 PseudoValve050 [' BEHAVIOR: url(#HSCShapeLinkBehavior) url(#HDXVectorFactory#shapelink)', ' TOP: 825px', ' LEFT: 1235px']
# 916 shape619 [' TOP: 360px', ' LEFT: 920px']
# 918 shape650 [' TOP: 585px', ' LEFT: 920px']
# 922 shape438 [' TOP: 85px', ' LEFT: 945px']
# 926 shape292 [' TOP: 130px', ' LEFT: 970px']
# 929 shape439 [' TOP: 125px', ' LEFT: 945px']
# 933 shape293 [' TOP: 170px', ' LEFT: 970px']
# 935 shape461 [' TOP: 165px', ' LEFT: 945px']
# 939 shape587 [' TOP: 170px', ' LEFT: 1070px']
# 941 shape297 [' TOP: 210px', ' LEFT: 970px']
# 943 shape464 [' TOP: 205px', ' LEFT: 945px']
# 947 shape311 [' TOP: 90px', ' LEFT: 735px']
# 949 shape347 [' TOP: 130px', ' LEFT: 770px']
# 951 shape348 [' TOP: 170px', ' LEFT: 805px']
# 953 shape349 [' TOP: 210px', ' LEFT: 680px']
# 955 shape588 [' TOP: 210px', ' LEFT: 1070px']
# 957 shape465 [' TOP: 85px', ' LEFT: 655px']
# 961 shape617 [' TOP: 90px', ' LEFT: 735px']
# 963 shape622 [' TOP: 135px', ' LEFT: 735px']
# 965 shape637 [' TOP: 175px', ' LEFT: 735px']
# 967 shape350 [' TOP: 90px', ' LEFT: 680px']
# 969 shape475 [' TOP: 125px', ' LEFT: 655px']
# 973 shape483 [' TOP: 165px', ' LEFT: 655px']
# 977 shape484 [' TOP: 205px', ' LEFT: 655px']
# 981 shape638 [' TOP: 215px', ' LEFT: 735px']
# 983 shape655 [' TOP: 130px', ' LEFT: 770px']
# 985 shape352 [' TOP: 130px', ' LEFT: 680px']
# 987 shape672 [' TOP: 175px', ' LEFT: 770px']
# 989 shape673 [' TOP: 215px', ' LEFT: 770px']
# 991 shape674 [' TOP: 170px', ' LEFT: 805px']
# 993 shape675 [' TOP: 215px', ' LEFT: 805px']
# 995 shape676 [' TOP: 210px', ' LEFT: 840px']
# 997 shape353 [' TOP: 170px', ' LEFT: 680px']
# 999 shape354 [' TOP: 210px', ' LEFT: 840px']
# 1001 shape677 [' TOP: 130px', ' LEFT: 435px']
# 1003 shape355 [' TOP: 130px', ' LEFT: 435px']
# 1005 shape678 [' TOP: 170px', ' LEFT: 480px']
# 1007 shape356 [' TOP: 170px', ' LEFT: 480px']
# 1009 shape679 [' TOP: 210px', ' LEFT: 530px']
# 1011 shape357 [' TOP: 210px', ' LEFT: 530px']
# 1014 shape589 [' TOP: 330px', ' LEFT: 920px']
# 1016 shape358 [' TOP: 360px', ' LEFT: 840px']
# 1018 shape485 [' TOP: 355px', ' LEFT: 865px']
# 1022 shape359 [' TOP: 360px', ' LEFT: 890px']
# 1024 shape360 [' TOP: 330px', ' LEFT: 845px']
# 1026 shape486 [' TOP: 325px', ' LEFT: 865px']
# 1030 shape361 [' TOP: 330px', ' LEFT: 890px']
# 1032 shape362 [' TOP: 300px', ' LEFT: 845px']
# 1034 shape487 [' TOP: 295px', ' LEFT: 865px']
# 1038 shape363 [' TOP: 300px', ' LEFT: 890px']
# 1040 shape364 [' TOP: 270px', ' LEFT: 845px']
# 1042 shape488 [' TOP: 265px', ' LEFT: 865px']
# 1046 shape365 [' TOP: 270px', ' LEFT: 890px']
# 1048 shape590 [' TOP: 300px', ' LEFT: 920px']
# 1050 shape591 [' TOP: 270px', ' LEFT: 920px']
# 1052 shape366 [' TOP: 330px', ' LEFT: 805px']
# 1054 shape367 [' TOP: 300px', ' LEFT: 810px']
# 1056 shape368 [' TOP: 300px', ' LEFT: 770px']
# 1058 shape369 [' TOP: 270px', ' LEFT: 810px']
# 1060 shape370 [' TOP: 270px', ' LEFT: 775px']
# 1062 shape372 [' TOP: 270px', ' LEFT: 735px']
# 1064 shape680 [' TOP: 360px', ' LEFT: 590px']
# 1066 shape373 [' TOP: 360px', ' LEFT: 795px']
# 1068 shape490 [' TOP: 355px', ' LEFT: 770px']
# 1072 shape374 [' TOP: 360px', ' LEFT: 590px']
# 1074 shape375 [' TOP: 330px', ' LEFT: 760px']
# 1076 shape491 [' TOP: 325px', ' LEFT: 735px']
# 1080 shape376 [' TOP: 270px', ' LEFT: 690px']
# 1082 shape492 [' TOP: 265px', ' LEFT: 665px']
# 1086 shape681 [' TOP: 390px', ' LEFT: 905px']
# 1090 shape682 [' TOP: 405px', ' LEFT: 920px']
# 1092 shape377 [' TOP: 425px', ' LEFT: 890px']
# 1094 shape378 [' TOP: 455px', ' LEFT: 805px']
# 1096 shape379 [' TOP: 500px', ' LEFT: 805px']
# 1098 shape683 [' TOP: 425px', ' LEFT: 920px']
# 1100 shape684 [' TOP: 455px', ' LEFT: 835px']
# 1102 shape380 [' TOP: 590px', ' LEFT: 885px']
# 1104 shape686 [' TOP: 590px', ' LEFT: 835px']
# 1106 shape689 [' TOP: 420px', ' LEFT: 865px']
# 1110 shape690 [' TOP: 450px', ' LEFT: 780px']
# 1114 shape691 [' TOP: 495px', ' LEFT: 780px']
# 1128 shape382 [' TOP: 455px', ' LEFT: 835px']
# 1130 shape692 [' TOP: 695px', ' LEFT: 760px']
# 1132 shape693 [' TOP: 695px', ' LEFT: 760px']
# 1138 shape383 [' TOP: 130px', ' LEFT: 405px']
# 1140 shape493 [' TOP: 125px', ' LEFT: 380px']
# 1146 shape694 [' TOP: 690px', ' LEFT: 920px']
# 1150 shape695 [' TOP: 695px', ' LEFT: 885px']
# 1152 shape696 [' TOP: 655px', ' LEFT: 920px']
# 1156 shape697 [' TOP: 660px', ' LEFT: 885px']
# 1161 shape698 [' TOP: 630px', ' LEFT: 760px']
# 1163 shape699 [' TOP: 660px', ' LEFT: 760px']
# 1165 shape592 [' TOP: 575px', ' LEFT: 1390px']
# 1167 shape517 [' TOP: 600px', ' LEFT: 1435px']
# 1171 shape384 [' TOP: 605px', ' LEFT: 1390px']
# 1173 shape402 [' TOP: 575px', ' LEFT: 1390px']
# 1175 shape494 [' TOP: 500px', ' LEFT: 495px']
# 1179 shape275 [' TOP: 505px', ' LEFT: 520px']
